# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/3.csv")

postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones2=pd.merge(postulaciones2,postulantes,on='idpostulante')

postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones2=pd.merge(postulaciones2,avisos,on='idaviso')

postulaciones2.head()
# Out:
#       idaviso idpostulante  sepostulo  sexo  edad Doctorado Master Otro  \
# 0  1112257047      ow2xPaj          0  MASC  40.0         -      -    -
# 1  1112257047       52KOZq          0  MASC  40.0         -      -    -
# 2  1112257047      JBrbYvE          0  MASC  27.0         -      -    -
# 3  1112257047       NDrRZl          0  MASC  29.0         -      -    -
# 4  1112257047      MVr8z8x          0  MASC  38.0         -      -    -
#
#   Posgrado Secundario       ...       secundario viajar empresa_importante  \
# 0        -   Graduado       ...             True  False              False
# 1        -   Graduado       ...             True  False              False
# 2        -   Graduado       ...             True  False              False
# 3        -          -       ...             True  False              False
# 4        -   Graduado       ...             True  False              False
#
#   capacitacion remuneracion_pretendida graduados estudiantes  \
# 0         True                   False     False       False
# 1         True                   False     False       False
# 2         True                   False     False       False
# 3         True                   False     False       False
# 4         True                   False     False       False
#
#   conocimientos_especificos  buen_ambiente  discriminacion
# 0                     False          False           False
# 1                     False          False           False
# 2                     False          False           False
# 3                     False          False           False
# 4                     False          False           False
#
# [5 rows x 35 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo sexo  edad Doctorado Master Otro  \
# 0  1112257047         NM5M          1  FEM  47.0         -      -    -
# 1  1112257047       1kJqGb          1  FEM  34.0         -      -    -
# 2  1112257047       eOE9Rr          1  FEM  39.0         -      -    -
# 3  1112257047       Zrx8Xz          1  FEM  39.0         -      -    -
# 4  1112257047       ZrKNQY          1  FEM  32.0         -      -    -
#
#   Posgrado Secundario       ...       secundario viajar empresa_importante  \
# 0        -   Graduado       ...             True  False              False
# 1        -          -       ...             True  False              False
# 2        -   Graduado       ...             True  False              False
# 3        -          -       ...             True  False              False
# 4        -   Graduado       ...             True  False              False
#
#   capacitacion remuneracion_pretendida graduados estudiantes  \
# 0         True                   False     False       False
# 1         True                   False     False       False
# 2         True                   False     False       False
# 3         True                   False     False       False
# 4         True                   False     False       False
#
#   conocimientos_especificos  buen_ambiente  discriminacion
# 0                     False          False           False
# 1                     False          False           False
# 2                     False          False           False
# 3                     False          False           False
# 4                     False          False           False
#
# [5 rows x 35 columns]

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 12377268
# 12344730

# %%
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado    Master  \
# 3407986   1112304125       YlMLGD          1   FEM  43.0         -         -
# 11761707  1112302280       EXwMz9          0  MASC  34.0         -         -
# 9405195   1112306953       aaLO9W          0   FEM  34.0         -         -
# 8514808   1112368385       5688zG          0   FEM  47.0         -         -
# 11664360  1112463328       YZjeRZ          0  MASC  46.0         -         -
# 6017853   1112430005      VNJM1rm          1   FEM  27.0         -         -
# 3629973   1112277176      dYjAZNb          1  MASC  25.0         -         -
# 2071638   1112206678      bOzVzQ0          1  MASC  27.0         -         -
# 8432005   1112296005       5Qbxjv          0  MASC  34.0         -         -
# 8959173   1112268224      JBxabBJ          0   FEM  31.0         -         -
# 9411912   1112392539      DrXeB3d          0   FEM  39.0         -  Graduado
# 10015835  1112387621      969NDV8          0   FEM  40.0         -         -
# 9676239   1112415784      pz99Jzb          0   FEM  42.0         -         -
# 6945666   1112296354       5xA5vw          0  MASC  50.0         -  Graduado
# 7779551   1112334791      ekvajO2          0  MASC  29.0         -         -
# 8615463   1112260111      6rPRZWL          0  MASC  23.0         -         -
# 7983171   1112287852       Y4W2JX          0  MASC  47.0         -         -
# 4182057   1112460309       8kN3Ez          1  MASC  33.0         -         -
# 11760002  1112260118      ak4e0jq          0  MASC  25.0         -         -
# 6240179   1112314099      kPNL6wQ          0  MASC  24.0         -         -
#
#               Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 3407986   Graduado  Graduado   Graduado    ...     False               True
# 11761707         -         -          -    ...     False              False
# 9405195          -         -   Graduado    ...     False              False
# 8514808          -         -          -    ...     False              False
# 11664360         -         -          -    ...     False              False
# 6017853          -         -   Graduado    ...     False               True
# 3629973          -         -          -    ...     False              False
# 2071638          -         -   Graduado    ...     False              False
# 8432005          -         -          -    ...     False              False
# 8959173          -         -   Graduado    ...     False              False
# 9411912   Graduado         -          -    ...     False              False
# 10015835         -         -   Graduado    ...      True              False
# 9676239          -         -   En Curso    ...     False               True
# 6945666          -  Graduado   Graduado    ...     False               True
# 7779551          -         -          -    ...     False              False
# 8615463          -         -   Graduado    ...     False              False
# 7983171          -         -   Graduado    ...     False              False
# 4182057   En Curso         -   Graduado    ...     False              False
# 11760002         -         -          -    ...     False              False
# 6240179          -         -   Graduado    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 3407986         False                   False     False       False
# 11761707         True                    True     False        True
# 9405195          True                   False     False       False
# 8514808         False                   False     False       False
# 11664360        False                   False     False       False
# 6017853         False                   False     False       False
# 3629973         False                   False     False       False
# 2071638         False                   False     False       False
# 8432005         False                   False     False       False
# 8959173         False                   False     False       False
# 9411912         False                   False     False       False
# 10015835        False                   False     False       False
# 9676239         False                   False     False       False
# 6945666         False                   False      True        True
# 7779551          True                   False     False       False
# 8615463         False                   False      True        True
# 7983171         False                   False     False       False
# 4182057         False                    True     False       False
# 11760002        False                   False     False       False
# 6240179         False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 3407986                      False         False            True       NaN
# 11761707                     False         False           False       NaN
# 9405195                      False         False           False       NaN
# 8514808                      False         False           False       NaN
# 11664360                     False          True           False       NaN
# 6017853                      False         False           False       1.0
# 3629973                      False          True           False       NaN
# 2071638                      False         False           False       NaN
# 8432005                      False         False           False       NaN
# 8959173                      False         False           False       NaN
# 9411912                      False         False           False       NaN
# 10015835                      True         False            True       NaN
# 9676239                      False         False           False       NaN
# 6945666                      False         False           False       NaN
# 7779551                      False          True           False       NaN
# 8615463                      False         False           False       NaN
# 7983171                      False         False           False       NaN
# 4182057                      False         False           False       2.0
# 11760002                     False         False           False       NaN
# 6240179                       True         False            True       NaN
#
# [20 rows x 36 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo        sexo   edad Doctorado  \
# 7564689   1112298993      96MNjMZ          0         FEM   23.0         -
# 5834712   1112256007       YvxNBD          1         FEM   38.0         -
# 11679437  1112369522      mzd65k6          0  NO_DECLARA  200.0         -
# 2618214   1112296264      JBXmxWr          1         FEM   23.0         -
# 414402    1112378885       8VRKbW          1         FEM   30.0         -
# 11503253  1112384982       E2BLo4          0         FEM   35.0         -
# 2298311   1112320527      QNrVb9N          1        MASC   29.0         -
# 63824     1112373509      BmBmokL          1        MASC   22.0         -
# 839803    1111970596      EzpGqV8          1         FEM   24.0         -
# 735799    1112433181      xkarzDY          1        MASC   34.0         -
# 8852983   1112451845       NeolXD          0        MASC   52.0         -
# 5299698   1112241525      MVrk3Po          1        MASC   33.0         -
# 9803598   1112454294      1QdW2DB          0         FEM   31.0         -
# 2417881   1112423441        5x1lq          1         FEM   43.0         -
# 9008304   1112341717       epMwA8          0         FEM   32.0         -
# 2708195   1112372110      jk55mVb          1         FEM   24.0         -
# 10581317  1112137021      lDL63OM          0         FEM   25.0         -
# 8254692   1112393325       Eje8b8          0         FEM   27.0         -
# 3914540   1112317620       5O4pWN          1         FEM   36.0         -
# 8081913   1112304044      2zQo3mQ          0        MASC   33.0         -
#
#          Master      Otro  Posgrado Secundario    ...    viajar  \
# 7564689       -         -         -   Graduado    ...     False
# 5834712       -         -         -          -    ...     False
# 11679437      -         -         -          -    ...     False
# 2618214       -         -         -   Graduado    ...     False
# 414402        -         -         -          -    ...     False
# 11503253      -         -         -   Graduado    ...     False
# 2298311       -         -         -   Graduado    ...     False
# 63824         -         -         -   Graduado    ...     False
# 839803        -         -         -   Graduado    ...     False
# 735799        -         -         -   Graduado    ...     False
# 8852983       -         -         -   Graduado    ...     False
# 5299698       -         -         -   Graduado    ...     False
# 9803598       -  Graduado  Graduado   Graduado    ...     False
# 2417881       -         -         -   Graduado    ...     False
# 9008304       -         -         -          -    ...     False
# 2708195       -         -         -          -    ...     False
# 10581317      -  En Curso         -   Graduado    ...     False
# 8254692       -  Graduado         -          -    ...     False
# 3914540       -         -         -   Graduado    ...     False
# 8081913       -         -  En Curso   Graduado    ...     False
#
#          empresa_importante capacitacion remuneracion_pretendida graduados  \
# 7564689                True        False                   False     False
# 5834712                True        False                   False     False
# 11679437              False        False                   False     False
# 2618214               False        False                   False     False
# 414402                False        False                   False     False
# 11503253               True        False                   False     False
# 2298311               False        False                   False     False
# 63824                 False        False                   False     False
# 839803                False         True                   False     False
# 735799                False        False                    True     False
# 8852983               False        False                   False     False
# 5299698               False        False                   False     False
# 9803598                True        False                   False     False
# 2417881               False        False                   False     False
# 9008304               False        False                   False     False
# 2708195                True        False                    True     False
# 10581317              False        False                   False     False
# 8254692               False         True                   False     False
# 3914540               False        False                   False     False
# 8081913               False        False                   False     False
#
#          estudiantes conocimientos_especificos buen_ambiente  discriminacion  \
# 7564689        False                     False         False            True
# 5834712        False                     False         False           False
# 11679437       False                     False         False           False
# 2618214        False                     False         False           False
# 414402          True                     False         False           False
# 11503253       False                     False         False           False
# 2298311        False                     False         False           False
# 63824          False                     False         False           False
# 839803         False                     False          True           False
# 735799         False                     False         False           False
# 8852983        False                     False         False           False
# 5299698        False                     False         False           False
# 9803598        False                     False         False           False
# 2417881        False                     False         False           False
# 9008304        False                     False         False           False
# 2708195        False                     False          True           False
# 10581317       False                     False          True           False
# 8254692        False                     False         False           False
# 3914540        False                      True         False            True
# 8081913        False                     False         False           False
#
#           cantidad
# 7564689        0.0
# 5834712        0.0
# 11679437       0.0
# 2618214        0.0
# 414402         0.0
# 11503253       0.0
# 2298311        0.0
# 63824          0.0
# 839803         0.0
# 735799         2.0
# 8852983        0.0
# 5299698        0.0
# 9803598        0.0
# 2417881        1.0
# 9008304        0.0
# 2708195        0.0
# 10581317       0.0
# 8254692        0.0
# 3914540        0.0
# 8081913        0.0
#
# [20 rows x 36 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
postulaciones2=0
# Out:
# Train:  11727493 Test:  617237

# %%
import gc
gc.collect()
# Out:
# 379

# %%
c=lgb.LGBMClassifier(learning_rate=0.005,objective='binary',num_leaves=4096,max_depth=13,n_estimators=1000,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 74.09001728671483
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV7.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV7.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado    Master  \
# 98671  98554  1112506993       aBYQ89   FEM  29.0         -  Graduado
# 34391   7512  1111716604       ZWR2Nz  MASC  38.0         -         -
# 5979   74298  1112463686      LNK2WAP  MASC  39.0         -         -
# 56413  66381  1112459509       8Pb4vR   FEM  35.0         -         -
# 53021  57520  1112451476       1kK823   FEM  32.0         -         -
# 96754  96415  1112494019       6Vp9vO  MASC  40.0         -         -
# 91352  81495  1112466058       Y0YP4w   FEM  42.0         -         -
# 26415  46169  1112429754      LNwEzlw   FEM  24.0         -         -
# 94964  94334  1112483816       e95YLp   FEM  36.0         -         -
# 81312  28976  1112367877       EOwj18  MASC  64.0         -         -
#
#            Otro Posgrado Secundario    ...    viajar empresa_importante  \
# 98671         -        -   Graduado    ...     False              False
# 34391         -        -   Graduado    ...     False              False
# 5979          -        -   Graduado    ...     False               True
# 56413         -        -   Graduado    ...     False              False
# 53021  En Curso        -          -    ...     False              False
# 96754         -        -          -    ...     False              False
# 91352         -        -          -    ...     False              False
# 26415         -        -   Graduado    ...     False              False
# 94964         -        -   Graduado    ...     False               True
# 81312         -        -          -    ...     False              False
#
#       capacitacion remuneracion_pretendida graduados estudiantes  \
# 98671         True                   False     False       False
# 34391        False                   False     False       False
# 5979         False                   False     False       False
# 56413        False                   False     False       False
# 53021        False                   False     False       False
# 96754        False                   False     False       False
# 91352        False                   False     False       False
# 26415        False                   False     False       False
# 94964        False                   False     False       False
# 81312        False                   False     False       False
#
#       conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 98671                     False         False           False       0.0
# 34391                     False         False           False       0.0
# 5979                      False         False           False       1.0
# 56413                     False         False           False       0.0
# 53021                     False         False           False       0.0
# 96754                     False         False           False       0.0
# 91352                     False         False           False       0.0
# 26415                     False         False           False       2.0
# 94964                     False         False           False       0.0
# 81312                     False         False           False       0.0
#
# [10 rows x 36 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.60293479, 0.39706521],
#        [0.56234362, 0.43765638],
#        [0.56449734, 0.43550266],
#        ...,
#        [0.82842402, 0.17157598],
#        [0.59049188, 0.40950812],
#        [0.93775201, 0.06224799]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     empresa_importante capacitacion  \
# 0   Graduado    ...                  False        False
# 1          -    ...                  False        False
# 2   Graduado    ...                  False        False
# 3   Graduado    ...                  False        False
# 4          -    ...                  False        False
#
#   remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 0                   False     False       False                     False
# 1                   False     False       False                     False
# 2                   False     False       False                     False
# 3                   False     False       False                     False
# 4                   False     False       False                     False
#
#   buen_ambiente discriminacion  cantidad  sepostulo
# 0         False          False       0.0   0.437181
# 1         False          False       0.0   0.404494
# 2         False          False       0.0   0.396515
# 3         False          False       0.0   0.223281
# 4         False          False       0.0   0.317451
#
# [5 rows x 37 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.397065
# 1   1   0.437656
# 2   2   0.435503
# 3   3   0.206046
# 4   4   0.415978

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion20.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5843051760731877
