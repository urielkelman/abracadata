# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisosONEHOT.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantesONEHOT.csv")
postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/1.csv")

postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones2=pd.merge(postulaciones2,postulantes,on='idpostulante')

postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones2=pd.merge(postulaciones2,avisos,on='idaviso')

postulaciones2.head()
# Out:
#       idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 0  1112257047      akjmXXq          0  28.0      True      False
# 1  1112257047      MV6b6R9          0  30.0      True      False
# 2  1112257047      zvxv1Rm          0  22.0      True      False
# 3  1112257047       8oqJzL          0  34.0     False       True
# 4  1112257047       ez533B          0  32.0     False       True
#
#    sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 0            False                 False               False
# 1            False                 False               False
# 2            False                 False               False
# 3            False                 False               False
# 4            False                 False               False
#
#    Doctorado_Graduado                 ...                  \
# 0               False                 ...
# 1               False                 ...
# 2               False                 ...
# 3               False                 ...
# 4               False                 ...
#
#    tipo_de_trabajo_Por Horas  tipo_de_trabajo_Primer empleo  \
# 0                      False                          False
# 1                      False                          False
# 2                      False                          False
# 3                      False                          False
# 4                      False                          False
#
#    tipo_de_trabajo_Teletrabajo  tipo_de_trabajo_Temporario  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
#
#    tipo_de_trabajo_Voluntario  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
#    nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 0                                          False                 False
# 1                                          False                 False
# 2                                          False                 False
# 3                                          False                 False
# 4                                          False                 False
#
#    nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior
# 0                True                               False
# 1                True                               False
# 2                True                               False
# 3                True                               False
# 4                True                               False
#
# [5 rows x 76 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 0  1112257047         NM5M          1  47.0      True      False
# 1  1112257047       1kJqGb          1  34.0      True      False
# 2  1112257047       eOE9Rr          1  39.0      True      False
# 3  1112257047       Zrx8Xz          1  39.0      True      False
# 4  1112257047       ZrKNQY          1  32.0      True      False
#
#    sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 0            False                 False               False
# 1            False                 False               False
# 2            False                 False               False
# 3            False                 False               False
# 4            False                 False               False
#
#    Doctorado_Graduado                 ...                  \
# 0               False                 ...
# 1               False                 ...
# 2               False                 ...
# 3               False                 ...
# 4               False                 ...
#
#    tipo_de_trabajo_Por Horas  tipo_de_trabajo_Primer empleo  \
# 0                      False                          False
# 1                      False                          False
# 2                      False                          False
# 3                      False                          False
# 4                      False                          False
#
#    tipo_de_trabajo_Teletrabajo  tipo_de_trabajo_Temporario  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
#
#    tipo_de_trabajo_Voluntario  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
#    nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 0                                          False                 False
# 1                                          False                 False
# 2                                          False                 False
# 3                                          False                 False
# 4                                          False                 False
#
#    nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior
# 0                True                               False
# 1                True                               False
# 2                True                               False
# 3                True                               False
# 4                True                               False
#
# [5 rows x 76 columns]

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 12377268
# 12332167

# %%
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 4881589   1112414894      BmDEvW2          1  37.0     False       True
# 1542534   1112340866      6r5Yaal          1  19.0      True      False
# 2671925   1112241055       ZREKd5          1  33.0     False       True
# 7960396   1112179207      4rN5w3e          0  40.0     False       True
# 10684290  1112411615      1QPoAZb          0  25.0      True      False
# 10063049  1112244630      2zPeaJx          0  26.0     False       True
# 5198572   1112411439      EzOM290          1  22.0      True      False
# 12325826  1112377817      jkM2G0B          0  30.0      True      False
# 169355    1112261212       aLeL9J          1  31.0     False       True
# 5195443   1112390898       86lYDl          1  42.0     False       True
# 3867544   1112281164      bOJMGLq          1  24.0      True      False
# 5430349   1112304139      vVDzJxx          1  45.0     False       True
# 1905228   1112410652      ZDrQBM8          1  26.0      True      False
# 4470781   1112453552      0zk88mv          1  20.0     False       True
# 11271843  1112373907      1QPNZMB          0  48.0     False       True
# 6087054   1112215643      LNKLjjQ          1  27.0      True      False
# 6699492   1112374587       exEZm8          0  47.0     False       True
# 7389962   1111455368      1QPZl4z          0  20.0      True      False
# 9663760   1112271846       6z2xL4          0  34.0      True      False
# 9114214   1112401984       Y0OxZ1          0  45.0     False       True
#
#           sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 4881589             False                 False               False
# 1542534             False                 False               False
# 2671925             False                 False               False
# 7960396             False                 False               False
# 10684290            False                 False               False
# 10063049            False                 False               False
# 5198572             False                 False               False
# 12325826            False                 False               False
# 169355              False                 False               False
# 5195443             False                 False               False
# 3867544             False                 False               False
# 5430349             False                 False               False
# 1905228             False                 False               False
# 4470781             False                 False               False
# 11271843            False                 False               False
# 6087054             False                 False               False
# 6699492             False                 False               False
# 7389962             False                 False               False
# 9663760             False                 False               False
# 9114214             False                 False               False
#
#           Doctorado_Graduado    ...     tipo_de_trabajo_Primer empleo  \
# 4881589                False    ...                             False
# 1542534                False    ...                             False
# 2671925                False    ...                             False
# 7960396                False    ...                             False
# 10684290               False    ...                             False
# 10063049               False    ...                             False
# 5198572                False    ...                             False
# 12325826               False    ...                             False
# 169355                 False    ...                             False
# 5195443                False    ...                             False
# 3867544                False    ...                             False
# 5430349                False    ...                             False
# 1905228                False    ...                             False
# 4470781                False    ...                             False
# 11271843               False    ...                             False
# 6087054                False    ...                             False
# 6699492                False    ...                             False
# 7389962                False    ...                             False
# 9663760                False    ...                             False
# 9114214                False    ...                             False
#
#           tipo_de_trabajo_Teletrabajo  tipo_de_trabajo_Temporario  \
# 4881589                         False                       False
# 1542534                         False                       False
# 2671925                         False                       False
# 7960396                         False                       False
# 10684290                        False                       False
# 10063049                        False                       False
# 5198572                         False                       False
# 12325826                        False                       False
# 169355                          False                       False
# 5195443                         False                       False
# 3867544                         False                       False
# 5430349                         False                       False
# 1905228                         False                       False
# 4470781                         False                       False
# 11271843                        False                       False
# 6087054                         False                       False
# 6699492                         False                       False
# 7389962                         False                       False
# 9663760                         False                       False
# 9114214                         False                       False
#
#           tipo_de_trabajo_Voluntario  \
# 4881589                        False
# 1542534                        False
# 2671925                        False
# 7960396                        False
# 10684290                       False
# 10063049                       False
# 5198572                        False
# 12325826                       False
# 169355                         False
# 5195443                        False
# 3867544                        False
# 5430349                        False
# 1905228                        False
# 4470781                        False
# 11271843                       False
# 6087054                        False
# 6699492                        False
# 7389962                        False
# 9663760                        False
# 9114214                        False
#
#           nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 4881589                                               False
# 1542534                                               False
# 2671925                                               False
# 7960396                                               False
# 10684290                                              False
# 10063049                                              False
# 5198572                                               False
# 12325826                                              False
# 169355                                                False
# 5195443                                               False
# 3867544                                               False
# 5430349                                               False
# 1905228                                               False
# 4470781                                               False
# 11271843                                              False
# 6087054                                               False
# 6699492                                               False
# 7389962                                               False
# 9663760                                               False
# 9114214                                               False
#
#           nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 4881589                                           False                 False
# 1542534                                           False                 False
# 2671925                                           False                 False
# 7960396                                           False                  True
# 10684290                                          False                 False
# 10063049                                          False                  True
# 5198572                                           False                 False
# 12325826                                          False                 False
# 169355                                             True                 False
# 5195443                                           False                 False
# 3867544                                           False                 False
# 5430349                                           False                 False
# 1905228                                           False                 False
# 4470781                                           False                 False
# 11271843                                          False                 False
# 6087054                                           False                 False
# 6699492                                           False                 False
# 7389962                                           False                 False
# 9663760                                           False                 False
# 9114214                                           False                 False
#
#           nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  cantidad
# 4881589                False                                True       1.0
# 1542534                False                                True       NaN
# 2671925                False                                True       NaN
# 7960396                False                               False       NaN
# 10684290               False                               False       NaN
# 10063049               False                               False       NaN
# 5198572                False                                True       NaN
# 12325826               False                                True       NaN
# 169355                 False                               False       NaN
# 5195443                False                                True       NaN
# 3867544                 True                               False       NaN
# 5430349                 True                               False       1.0
# 1905228                False                                True       NaN
# 4470781                False                                True       1.0
# 11271843               False                                True       NaN
# 6087054                False                                True       NaN
# 6699492                False                                True       NaN
# 7389962                False                                True       NaN
# 9663760                False                                True       NaN
# 9114214                False                                True       NaN
#
# [20 rows x 77 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo   edad  sexo_FEM  sexo_MASC  \
# 5670925   1112362278      QNEeZVN          1   34.0     False       True
# 4554709   1112404044      0zkjq4q          1   32.0      True      False
# 1087173   1112282953      W9WZrqN          1   31.0     False       True
# 9972466   1112300306      qe28jGR          0   21.0     False       True
# 11364085  1112442093      pzMPxrN          0   43.0     False       True
# 3422482   1112259370      0zPzJZE          1  200.0     False       True
# 5680780   1112407183      6r2LXZx          1   39.0     False       True
# 3425368   1112425807      6rPo4Vr          1   20.0      True      False
# 11332741  1112297276      X95mBwK          0   23.0     False       True
# 9879397   1111590903      4rWA3lP          0   29.0     False       True
# 1173083   1112299531      xkdA45P          1   31.0      True      False
# 2611534   1112253155      mzGV3d3          1   23.0      True      False
# 6707033   1112317212      xkdql9K          0   29.0     False       True
# 2783824   1112281113      bOjM4AE          1   45.0      True      False
# 1797774   1112458730      GNZrpmK          1   26.0      True      False
# 5860393   1112301272      mzb5231          1   29.0      True      False
# 9355079   1112298976      owzxB9a          0   34.0     False       True
# 3759476   1112264510      X9lo9KK          1   23.0     False       True
# 2941831   1112268758      pzdA5R3          1   34.0     False       True
# 11483088  1112254572       eRzXG2          0   48.0     False       True
#
#           sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 5670925             False                 False               False
# 4554709             False                 False               False
# 1087173             False                 False               False
# 9972466             False                 False               False
# 11364085            False                 False               False
# 3422482             False                 False               False
# 5680780             False                 False               False
# 3425368             False                 False               False
# 11332741            False                 False               False
# 9879397             False                 False               False
# 1173083             False                 False               False
# 2611534             False                 False               False
# 6707033             False                 False               False
# 2783824             False                 False               False
# 1797774             False                 False               False
# 5860393             False                 False               False
# 9355079             False                 False               False
# 3759476             False                 False               False
# 2941831             False                 False               False
# 11483088            False                 False               False
#
#           Doctorado_Graduado    ...     tipo_de_trabajo_Primer empleo  \
# 5670925                False    ...                             False
# 4554709                False    ...                             False
# 1087173                False    ...                             False
# 9972466                False    ...                             False
# 11364085               False    ...                             False
# 3422482                False    ...                             False
# 5680780                False    ...                             False
# 3425368                False    ...                             False
# 11332741               False    ...                             False
# 9879397                False    ...                             False
# 1173083                False    ...                             False
# 2611534                False    ...                             False
# 6707033                False    ...                             False
# 2783824                False    ...                             False
# 1797774                False    ...                             False
# 5860393                False    ...                             False
# 9355079                False    ...                             False
# 3759476                False    ...                             False
# 2941831                False    ...                             False
# 11483088               False    ...                             False
#
#           tipo_de_trabajo_Teletrabajo  tipo_de_trabajo_Temporario  \
# 5670925                         False                       False
# 4554709                         False                       False
# 1087173                         False                       False
# 9972466                         False                       False
# 11364085                        False                       False
# 3422482                         False                       False
# 5680780                         False                       False
# 3425368                         False                       False
# 11332741                        False                       False
# 9879397                         False                       False
# 1173083                         False                       False
# 2611534                         False                       False
# 6707033                         False                       False
# 2783824                         False                       False
# 1797774                         False                       False
# 5860393                         False                       False
# 9355079                         False                       False
# 3759476                         False                       False
# 2941831                         False                       False
# 11483088                        False                       False
#
#           tipo_de_trabajo_Voluntario  \
# 5670925                        False
# 4554709                        False
# 1087173                        False
# 9972466                        False
# 11364085                       False
# 3422482                        False
# 5680780                        False
# 3425368                        False
# 11332741                       False
# 9879397                        False
# 1173083                        False
# 2611534                        False
# 6707033                        False
# 2783824                        False
# 1797774                        False
# 5860393                        False
# 9355079                        False
# 3759476                        False
# 2941831                        False
# 11483088                       False
#
#           nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 5670925                                               False
# 4554709                                               False
# 1087173                                               False
# 9972466                                               False
# 11364085                                              False
# 3422482                                               False
# 5680780                                               False
# 3425368                                               False
# 11332741                                              False
# 9879397                                               False
# 1173083                                               False
# 2611534                                               False
# 6707033                                               False
# 2783824                                               False
# 1797774                                               False
# 5860393                                               False
# 9355079                                               False
# 3759476                                               False
# 2941831                                                True
# 11483088                                              False
#
#           nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 5670925                                           False                  True
# 4554709                                           False                 False
# 1087173                                           False                 False
# 9972466                                           False                 False
# 11364085                                          False                  True
# 3422482                                           False                 False
# 5680780                                           False                 False
# 3425368                                           False                 False
# 11332741                                          False                 False
# 9879397                                           False                 False
# 1173083                                           False                  True
# 2611534                                           False                  True
# 6707033                                           False                  True
# 2783824                                           False                 False
# 1797774                                           False                  True
# 5860393                                           False                 False
# 9355079                                           False                 False
# 3759476                                           False                  True
# 2941831                                           False                 False
# 11483088                                          False                 False
#
#           nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  cantidad
# 5670925                False                               False       0.0
# 4554709                False                                True       2.0
# 1087173                False                                True       0.0
# 9972466                False                                True       0.0
# 11364085               False                               False       0.0
# 3422482                False                                True       0.0
# 5680780                False                                True       2.0
# 3425368                False                               False       4.0
# 11332741               False                                True       0.0
# 9879397                False                                True       0.0
# 1173083                False                               False       0.0
# 2611534                False                               False       0.0
# 6707033                False                               False       0.0
# 2783824                False                                True       0.0
# 1797774                False                               False       4.0
# 5860393                False                                True       0.0
# 9355079                False                                True       0.0
# 3759476                False                               False       0.0
# 2941831                False                               False       0.0
# 11483088               False                                True       0.0
#
# [20 rows x 77 columns]

# %%
areas=avisos['nombre_area'].value_counts().index
postulaciones['nombre_area']=postulaciones['nombre_area'].replace(areas, range(len(areas)))
postulaciones.dtypes
# Out:
# idaviso                                                 int64
# idpostulante                                           object
# sepostulo                                               int64
# edad                                                  float64
# sexo_FEM                                                 bool
# sexo_MASC                                                bool
# sexo_NO_DECLARA                                          bool
# Doctorado_Abandonado                                     bool
# Doctorado_En Curso                                       bool
# Doctorado_Graduado                                       bool
# Master_Abandonado                                        bool
# Master_En Curso                                          bool
# Master_Graduado                                          bool
# Posgrado_Abandonado                                      bool
# Posgrado_En Curso                                        bool
# Posgrado_Graduado                                        bool
# Secundario_Abandonado                                    bool
# Secundario_En Curso                                      bool
# Secundario_Graduado                                      bool
# Terciario/Técnico_Abandonado                             bool
# Terciario/Técnico_En Curso                               bool
# Terciario/Técnico_Graduado                               bool
# Universitario_Abandonado                                 bool
# Universitario_En Curso                                   bool
# Universitario_Graduado                                   bool
# titulo                                                 object
# nombre_area                                             int64
# denominacion_empresa                                   object
# titulo_uppercase                                         bool
# pide_hombre                                              bool
#                                                        ...
# nombre_zona_Catamarca                                    bool
# nombre_zona_Ciudad de Mendoza                            bool
# nombre_zona_Cordoba                                      bool
# nombre_zona_Corrientes                                   bool
# nombre_zona_GBA Oeste                                    bool
# nombre_zona_Gran Buenos Aires                            bool
# nombre_zona_La Plata                                     bool
# nombre_zona_Mendoza                                      bool
# nombre_zona_Neuquen                                      bool
# nombre_zona_Rosario                                      bool
# nombre_zona_San Juan                                     bool
# nombre_zona_Santa Cruz                                   bool
# nombre_zona_Santa Fe                                     bool
# nombre_zona_Tucuman                                      bool
# tipo_de_trabajo_Fines de Semana                          bool
# tipo_de_trabajo_Full-time                                bool
# tipo_de_trabajo_Part-time                                bool
# tipo_de_trabajo_Pasantia                                 bool
# tipo_de_trabajo_Por Contrato                             bool
# tipo_de_trabajo_Por Horas                                bool
# tipo_de_trabajo_Primer empleo                            bool
# tipo_de_trabajo_Teletrabajo                              bool
# tipo_de_trabajo_Temporario                               bool
# tipo_de_trabajo_Voluntario                               bool
# nivel_laboral_Gerencia / Alta Gerencia / Dirección       bool
# nivel_laboral_Jefe / Supervisor / Responsable            bool
# nivel_laboral_Junior                                     bool
# nivel_laboral_Otro                                       bool
# nivel_laboral_Senior / Semi-Senior                       bool
# cantidad                                              float64
# Length: 77, dtype: object

# %%
train, test=train_test_split(postulaciones,test_size=0.10)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
postulaciones2=0
# Out:
# Train:  11098950 Test:  1233217

# %%
import gc
gc.collect()
# Out:
# 135

# %%
c=RandomForestClassifier(n_estimators=250,min_samples_split=100,n_jobs=-1,random_state=0)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl") 
dt=c.fit(x_train,y_train)

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 73.47303840281151

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/RFV3ONEHOT.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/RFV3ONEHOT.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  edad  sexo_FEM  sexo_MASC  \
# 83616  44389  1112426253       ZOQj1Z  30.0     False       True
# 20408  81897  1112466114       5Pz33v  30.0     False       True
# 13953  61270  1112455332      Rzrbjaq  28.0      True      False
# 48103  62698  1112456333      vV3aDlX  23.0     False       True
# 73909  20031  1112245617       12v8zN  33.0      True      False
# 3651   82495  1112466202      NzrlOa5  54.0      True      False
# 40239  40100  1112418587       aGpW1q  33.0      True      False
# 89740  58205  1112452415      3NdEwqK  32.0      True      False
# 80527  28019  1112356904       YO3YVY  29.0     False       True
# 27203  63881  1112457663      W9W32Xa  22.0      True      False
#
#        sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 83616            False                 False               False
# 20408            False                 False               False
# 13953            False                 False               False
# 48103            False                 False               False
# 73909            False                 False               False
# 3651             False                 False               False
# 40239            False                 False               False
# 89740            False                 False               False
# 80527            False                 False               False
# 27203            False                 False               False
#
#        Doctorado_Graduado    ...     tipo_de_trabajo_Primer empleo  \
# 83616               False    ...                             False
# 20408               False    ...                             False
# 13953               False    ...                             False
# 48103               False    ...                             False
# 73909               False    ...                             False
# 3651                False    ...                             False
# 40239               False    ...                             False
# 89740               False    ...                             False
# 80527               False    ...                             False
# 27203               False    ...                             False
#
#        tipo_de_trabajo_Teletrabajo  tipo_de_trabajo_Temporario  \
# 83616                        False                       False
# 20408                        False                       False
# 13953                        False                       False
# 48103                        False                       False
# 73909                        False                       False
# 3651                         False                       False
# 40239                        False                       False
# 89740                        False                       False
# 80527                        False                       False
# 27203                        False                       False
#
#        tipo_de_trabajo_Voluntario  \
# 83616                       False
# 20408                       False
# 13953                       False
# 48103                       False
# 73909                       False
# 3651                        False
# 40239                       False
# 89740                       False
# 80527                       False
# 27203                       False
#
#        nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 83616                                              False
# 20408                                              False
# 13953                                              False
# 48103                                              False
# 73909                                              False
# 3651                                               False
# 40239                                              False
# 89740                                              False
# 80527                                              False
# 27203                                              False
#
#        nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 83616                                           True                 False
# 20408                                           True                 False
# 13953                                          False                 False
# 48103                                          False                 False
# 73909                                          False                 False
# 3651                                           False                 False
# 40239                                          False                  True
# 89740                                          False                 False
# 80527                                          False                 False
# 27203                                          False                 False
#
#        nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  cantidad
# 83616               False                               False       0.0
# 20408               False                               False       1.0
# 13953               False                                True       0.0
# 48103               False                                True       0.0
# 73909               False                                True       0.0
# 3651                 True                               False       2.0
# 40239               False                               False       0.0
# 89740               False                                True       2.0
# 80527               False                                True       0.0
# 27203               False                                True       2.0
#
# [10 rows x 77 columns]

# %%
areas=avisos['nombre_area'].value_counts().index
prediccion['nombre_area']=prediccion['nombre_area'].replace(areas, range(len(areas)))
prediccion.dtypes
# Out:
# id                                                      int64
# idaviso                                                 int64
# idpostulante                                           object
# edad                                                  float64
# sexo_FEM                                                 bool
# sexo_MASC                                                bool
# sexo_NO_DECLARA                                          bool
# Doctorado_Abandonado                                     bool
# Doctorado_En Curso                                       bool
# Doctorado_Graduado                                       bool
# Master_Abandonado                                        bool
# Master_En Curso                                          bool
# Master_Graduado                                          bool
# Posgrado_Abandonado                                      bool
# Posgrado_En Curso                                        bool
# Posgrado_Graduado                                        bool
# Secundario_Abandonado                                    bool
# Secundario_En Curso                                      bool
# Secundario_Graduado                                      bool
# Terciario/Técnico_Abandonado                             bool
# Terciario/Técnico_En Curso                               bool
# Terciario/Técnico_Graduado                               bool
# Universitario_Abandonado                                 bool
# Universitario_En Curso                                   bool
# Universitario_Graduado                                   bool
# titulo                                                 object
# nombre_area                                             int64
# denominacion_empresa                                   object
# titulo_uppercase                                         bool
# pide_hombre                                              bool
#                                                        ...
# nombre_zona_Catamarca                                    bool
# nombre_zona_Ciudad de Mendoza                            bool
# nombre_zona_Cordoba                                      bool
# nombre_zona_Corrientes                                   bool
# nombre_zona_GBA Oeste                                    bool
# nombre_zona_Gran Buenos Aires                            bool
# nombre_zona_La Plata                                     bool
# nombre_zona_Mendoza                                      bool
# nombre_zona_Neuquen                                      bool
# nombre_zona_Rosario                                      bool
# nombre_zona_San Juan                                     bool
# nombre_zona_Santa Cruz                                   bool
# nombre_zona_Santa Fe                                     bool
# nombre_zona_Tucuman                                      bool
# tipo_de_trabajo_Fines de Semana                          bool
# tipo_de_trabajo_Full-time                                bool
# tipo_de_trabajo_Part-time                                bool
# tipo_de_trabajo_Pasantia                                 bool
# tipo_de_trabajo_Por Contrato                             bool
# tipo_de_trabajo_Por Horas                                bool
# tipo_de_trabajo_Primer empleo                            bool
# tipo_de_trabajo_Teletrabajo                              bool
# tipo_de_trabajo_Temporario                               bool
# tipo_de_trabajo_Voluntario                               bool
# nivel_laboral_Gerencia / Alta Gerencia / Dirección       bool
# nivel_laboral_Jefe / Supervisor / Responsable            bool
# nivel_laboral_Junior                                     bool
# nivel_laboral_Otro                                       bool
# nivel_laboral_Senior / Semi-Senior                       bool
# cantidad                                              float64
# Length: 77, dtype: object

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.60608565, 0.39391435],
#        [0.54745793, 0.45254207],
#        [0.61298236, 0.38701764],
#        ...,
#        [0.81203029, 0.18796971],
#        [0.61555504, 0.38444496],
#        [0.86587397, 0.13412603]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  edad  sexo_FEM  sexo_MASC  sexo_NO_DECLARA  \
# 0   0   739260       6M9ZQR  42.0      True      False            False
# 1   1   739260       6v1xdL  30.0     False       True            False
# 2   2   739260       ezRKm9  36.0      True      False            False
# 3   3   758580       1Q35ej  68.0     False       True            False
# 4   4   758580       EAN4J6  32.0      True      False            False
#
#    Doctorado_Abandonado  Doctorado_En Curso  Doctorado_Graduado    ...      \
# 0                 False               False                True    ...
# 1                 False               False               False    ...
# 2                 False               False               False    ...
# 3                 False               False               False    ...
# 4                 False               False               False    ...
#
#    tipo_de_trabajo_Teletrabajo  tipo_de_trabajo_Temporario  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
#
#    tipo_de_trabajo_Voluntario  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
#    nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 0                                           True                 False
# 1                                           True                 False
# 2                                           True                 False
# 3                                          False                 False
# 4                                          False                 False
#
#    nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  cantidad  sepostulo
# 0               False                               False       0.0   0.393914
# 1               False                               False       0.0   0.452542
# 2               False                               False       0.0   0.387018
# 3                True                               False       0.0   0.088975
# 4                True                               False       0.0   0.387839
#
# [5 rows x 78 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.393914
# 1   1   0.452542
# 2   2   0.387018
# 3   3   0.088975
# 4   4   0.387839

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion12.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5929410290726623
