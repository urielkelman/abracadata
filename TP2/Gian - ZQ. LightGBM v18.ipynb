# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')
avisos['denominacion_empresa']=avisos['denominacion_empresa'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas2=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2=vistas2.rename(columns={'idAviso': 'idaviso'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q        15
# 1        0005E        58
# 2        000R8        14
# 3        001XE        26
# 4        003k9        32

# %%
vistas2=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           2          28
# 1    48375       RwVdKR           1          15
# 2   169730        1KjXB           2          99
# 3   169730       2AKzxa           2           2
# 4   169730        6LJ64           1          23

# %%
vistas2['cantidad']=vistas2['cantidad_x']/vistas2['cantidad_y']
vistas2.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas=vistas2
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.071429
# 1    48375       RwVdKR  0.066667
# 2   169730        1KjXB  0.020202
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.043478

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/7.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/8.csv").sample(len(postulaciones2)//2).reset_index(drop=True))
print(len(postulaciones2))
postulaciones2
# Out:
# 6604534
#             idaviso idpostulante  sepostulo
# 0        1112389495       5NbOjG          0
# 1        1112024109      1QP841b          0
# 2        1112490884      96XQ6N9          0
# 3        1111474259      qe2QJj1          0
# 4        1112211292      KBzbBJm          0
# 5        1112328485      3NzZv26          0
# 6        1112474766      akDjWwE          0
# 7        1112312385       aZpBJW          0
# 8        1112285628      akDWj55          0
# 9        1112322843      GNd0KNN          0
# 10       1112355899      DrXPRJX          0
# 11       1112461865      8MPoBDR          0
# 12       1111673413       a1NjRN          0
# 13       1112299006      jkVWXRQ          0
# 14       1112501771      owz0YGW          0
# 15       1002543409       Ej5AAb          0
# 16       1112425310      KBrpAO2          0
# 17       1112498569      pzNMppM          0
# 18       1111866251       ZKqL85          0
# 19       1112289529      ow2awXr          0
# 20       1112493109      5mP1DWM          0
# 21       1112326017      0zd9GZ9          0
# 22       1112242315      3NQKV6Q          0
# 23       1112452417      DrlVEwW          0
# 24       1112402816      mzdk9dZ          0
# 25       1112359100      3NP46xq          0
# 26       1112410555      bOVKA32          0
# 27       1112511403      mzdlAQO          0
# 28       1111272539      6rPpNM4          0
# 29       1111591317      6rP4K13          0
# ...             ...          ...        ...
# 6604504  1112261798      4redE6e          0
# 6604505  1112420559      3NPGjxJ          0
# 6604506  1112363380      ak530RE          0
# 6604507  1112252533      A3DJwW6          0
# 6604508  1112215124      X9PQprx          0
# 6604509  1112104454      BmDEKmR          0
# 6604510  1112392900      ow2rR3L          0
# 6604511  1112507433      Rz9lmOZ          0
# 6604512  1112429493       EPJ61J          0
# 6604513  1112210380      OqbL8ax          0
# 6604514  1112454949      Yj5ePRX          0
# 6604515  1112257707      8M2eEND          0
# 6604516  1111714857      ZDaoE2V          0
# 6604517  1112364849      0zB3A2Y          0
# 6604518  1112088772       EX5v0o          0
# 6604519  1112457555      6r5ja3R          0
# 6604520  1112268539      X9ldw4P          0
# 6604521  1112281854      mzdLoRO          0
# 6604522  1112372007       ZLlZkR          0
# 6604523  1112218903      lDbPjY8          0
# 6604524  1112443846      JBrVQDp          0
# 6604525  1112357563      0zdEoq1          0
# 6604526  1112296494      X9k4xdQ          0
# 6604527  1112314288      akje1Eq          0
# 6604528  1112455177      X95do0J          0
# 6604529  1112416094        5xdQq          0
# 6604530  1112237658      xkd8D80          0
# 6604531  1112292393      Yj523Aq          0
# 6604532  1112322583      bOjkL0B          0
# 6604533  1112305358      ow5AKKa          0
#
# [6604534 rows x 3 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 13209068
# 13203430

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado    Master  \
# 11303866  1112513555      GNZ6rRw          0  MASC  24.0         -         -
# 222903    1112281548      pz9RqRN          0  MASC  27.0         -         -
# 2557427   1112402611       8R3YQx          1  MASC  29.0         -         -
# 4113599   1112335211       NwMvRJ          1   FEM  28.0         -         -
# 11615078  1112468750      owEVdle          0   FEM  21.0         -         -
# 8126609   1112463373      wVjVLRV          0  MASC  34.0         -         -
# 7153847   1112365693       1469wQ          0   FEM  44.0         -         -
# 10005912  1112326525      dY5zDZP          0  MASC  24.0         -         -
# 8302938   1112235241      lD52wXj          0   FEM  23.0         -         -
# 1684729   1112196813       8oV3bx          1  MASC  34.0         -  En Curso
# 11536928  1112412346       8eNNbz          1   FEM  33.0         -         -
# 973874    1112308320      X9kPw0d          1  MASC  26.0         -         -
# 4180917   1112185961      Bm5GEWZ          1   FEM  21.0         -         -
# 8022919   1112237692      lD2kwLM          0  MASC  27.0         -         -
# 1451928   1112275115       8oKG8M          0  MASC  28.0         -         -
# 7156184   1112376163      GNobNvA          0  MASC  26.0         -         -
# 2620679   1112427693      YjrQQDP          1   FEM  32.0         -         -
# 3063604   1111758154      3NQLp6P          0  MASC  44.0         -         -
# 8081266   1112408221      bOJJ8ob          0  MASC  34.0         -         -
# 7423416   1112337360       1p8qZO          1   FEM  30.0         -         -
#
#               Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 11303866         -         -   Graduado    ...     False               True
# 222903           -         -   Graduado    ...     False               True
# 2557427          -         -          -    ...     False              False
# 4113599          -         -          -    ...     False              False
# 11615078  Graduado         -   Graduado    ...     False               True
# 8126609          -         -   Graduado    ...     False              False
# 7153847          -         -   Graduado    ...     False              False
# 10005912         -         -   Graduado    ...     False              False
# 8302938          -         -          -    ...     False               True
# 1684729          -  Graduado   Graduado    ...     False              False
# 11536928  Graduado         -          -    ...     False               True
# 973874           -         -   Graduado    ...     False              False
# 4180917          -         -   Graduado    ...     False              False
# 8022919          -         -          -    ...     False              False
# 1451928          -         -          -    ...     False              False
# 7156184          -         -          -    ...     False              False
# 2620679   Graduado         -   Graduado    ...     False              False
# 3063604          -         -          -    ...     False              False
# 8081266   Graduado         -   Graduado    ...     False              False
# 7423416          -         -   Graduado    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 11303866        False                   False     False       False
# 222903          False                   False     False       False
# 2557427         False                   False     False       False
# 4113599         False                   False     False       False
# 11615078        False                   False     False       False
# 8126609         False                   False     False       False
# 7153847         False                    True     False       False
# 10005912        False                   False     False       False
# 8302938         False                   False     False       False
# 1684729         False                   False      True        True
# 11536928        False                   False     False       False
# 973874          False                   False     False       False
# 4180917          True                   False     False       False
# 8022919         False                   False     False       False
# 1451928         False                   False     False       False
# 7156184         False                   False     False        True
# 2620679         False                   False     False       False
# 3063604          True                   False     False       False
# 8081266         False                   False     False       False
# 7423416         False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 11303866                     False          True           False       NaN
# 222903                       False         False           False       NaN
# 2557427                      False          True           False       NaN
# 4113599                      False         False           False       NaN
# 11615078                     False         False           False       NaN
# 8126609                      False         False           False       NaN
# 7153847                      False         False           False       NaN
# 10005912                      True         False            True       NaN
# 8302938                      False         False           False       NaN
# 1684729                      False         False           False  0.009615
# 11536928                     False         False           False  0.030405
# 973874                       False         False           False       NaN
# 4180917                      False         False           False       NaN
# 8022919                      False          True           False       NaN
# 1451928                      False          True           False       NaN
# 7156184                      False         False           False       NaN
# 2620679                      False         False           False  0.032787
# 3063604                      False         False           False       NaN
# 8081266                      False          True           False       NaN
# 7423416                      False         False           False       NaN
#
# [20 rows x 36 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado    Master  \
# 1413484   1112033906      MVPAlLo          1   FEM  21.0         -         -
# 8990742   1112444023      ZDPpPBV          1   FEM  27.0         -         -
# 8494422   1112254343      5mrj99z          0  MASC  25.0         -         -
# 8020644   1112273003      VNrYzrd          1  MASC  20.0         -         -
# 11232677  1112431057      ak5w4OZ          0   FEM  19.0         -         -
# 6971693   1112296029       5JBQrq          0  MASC  41.0         -         -
# 9531775   1111284383      BmZk6R2          0   FEM  46.0         -  Graduado
# 8355729   1112260331       8Poaw3          1   FEM  33.0         -         -
# 8367465   1112284454      KBa1Qxj          1   FEM  21.0         -         -
# 888519    1112299531      5mP9GBv          1   FEM  33.0         -         -
# 5390778   1112237498       N11lmM          1   FEM  30.0         -         -
# 9150352   1112466623       N1YEJM          1  MASC  26.0         -         -
# 9433233   1112334950      6r5zJ2O          0  MASC  21.0         -         -
# 9492793   1112266595      BmDGP30          1  MASC  32.0         -         -
# 1863507   1112386543      akj2aNE          1   FEM  35.0         -         -
# 5888965   1111364281      xkdmV26          0   FEM  23.0         -         -
# 5142247   1112414725      xkdE6Y6          1  MASC  18.0         -         -
# 11247923  1112427236      EzeqEB8          0  MASC  38.0         -         -
# 10228504  1112341065      X95Vm8P          0  MASC  31.0         -         -
# 868486    1112206380      1QkwJ6j          1  MASC  35.0         -         -
#
#               Otro Posgrado Secundario    ...    viajar empresa_importante  \
# 1413484          -        -   Graduado    ...     False              False
# 8990742          -        -   Graduado    ...     False              False
# 8494422          -        -   Graduado    ...     False              False
# 8020644          -        -   Graduado    ...     False              False
# 11232677         -        -   Graduado    ...     False              False
# 6971693          -        -   Graduado    ...     False              False
# 9531775   Graduado        -   Graduado    ...      True              False
# 8355729          -        -   Graduado    ...     False               True
# 8367465          -        -          -    ...     False              False
# 888519           -        -          -    ...     False              False
# 5390778          -        -   Graduado    ...     False              False
# 9150352          -        -   Graduado    ...     False              False
# 9433233          -        -   Graduado    ...     False              False
# 9492793          -        -          -    ...     False              False
# 1863507          -        -          -    ...     False              False
# 5888965          -        -          -    ...     False              False
# 5142247          -        -          -    ...     False              False
# 11247923         -        -   Graduado    ...     False               True
# 10228504         -        -   Graduado    ...     False               True
# 868486    En Curso        -   Graduado    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 1413484          True                   False     False       False
# 8990742         False                    True     False       False
# 8494422         False                    True     False       False
# 8020644          True                   False     False       False
# 11232677        False                   False     False       False
# 6971693         False                   False     False       False
# 9531775         False                   False     False       False
# 8355729         False                   False     False       False
# 8367465         False                   False     False       False
# 888519          False                   False     False       False
# 5390778         False                   False     False       False
# 9150352         False                   False     False       False
# 9433233         False                   False     False       False
# 9492793         False                   False     False       False
# 1863507         False                   False     False       False
# 5888965         False                   False     False       False
# 5142247          True                   False     False       False
# 11247923        False                   False     False       False
# 10228504        False                   False     False       False
# 868486          False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 1413484                      False          True           False  0.003044
# 8990742                      False         False           False  0.051282
# 8494422                      False          True           False  0.000000
# 8020644                      False         False           False  0.000000
# 11232677                     False         False           False  0.000000
# 6971693                      False          True           False  0.000000
# 9531775                      False         False           False  0.000000
# 8355729                      False         False           False  0.000000
# 8367465                      False         False           False  0.000000
# 888519                       False         False           False  0.000000
# 5390778                      False         False           False  0.000000
# 9150352                      False         False           False  0.003604
# 9433233                      False          True           False  0.000000
# 9492793                      False          True           False  0.000000
# 1863507                      False         False           False  0.032258
# 5888965                      False         False           False  0.000000
# 5142247                      False          True           False  0.041667
# 11247923                     False          True           False  0.000000
# 10228504                     False         False           False  0.000000
# 868486                       False         False           False  0.000000
#
# [20 rows x 36 columns]

# %%
postulaciones_por_area=postulaciones.copy()
postulaciones_por_area=postulaciones_por_area.groupby(by=['idpostulante','nombre_area'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_area=postulaciones_por_area.rename(columns={'sepostulo':'postulaciones_misma_area'})
postulaciones_por_area.head()
# Out:
#   idpostulante                      nombre_area  postulaciones_misma_area
# 0      0z5Dmrd                   Administración                         1
# 1      0z5Dmrd  Almacén / Depósito / Expedición                         1
# 2      0z5Dmrd              Atención al Cliente                         1
# 3      0z5Dmrd                        Auditoría                         1
# 4      0z5Dmrd                     Contabilidad                         1

# %%
postulaciones_por_nivel=postulaciones.copy()
postulaciones_por_nivel=postulaciones_por_nivel.groupby(by=['idpostulante','nivel_laboral'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_nivel=postulaciones_por_nivel.rename(columns={'sepostulo':'postulaciones_mismo_nivel'})
postulaciones_por_nivel.head()
# Out:
#   idpostulante                         nivel_laboral  \
# 0      0z5Dmrd  Gerencia / Alta Gerencia / Dirección
# 1      0z5Dmrd                                Junior
# 2      0z5Dmrd                                  Otro
# 3      0z5Dmrd                  Senior / Semi-Senior
# 4      0z5JW1r  Gerencia / Alta Gerencia / Dirección
#
#    postulaciones_mismo_nivel
# 0                          1
# 1                          2
# 2                          1
# 3                         13
# 4                          2

# %%
postulaciones_por_tipo=postulaciones.copy()
postulaciones_por_tipo=postulaciones_por_tipo.groupby(by=['idpostulante','tipo_de_trabajo'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_tipo=postulaciones_por_tipo.rename(columns={'sepostulo':'postulaciones_mismo_tipo'})
postulaciones_por_tipo.head()
# Out:
#   idpostulante tipo_de_trabajo  postulaciones_mismo_tipo
# 0      0z5Dmrd       Full-time                        16
# 1      0z5Dmrd       Part-time                         1
# 2      0z5JW1r       Full-time                        21
# 3      0z5VvGv       Full-time                        50
# 4      0z5VvGv       Part-time                        10

# %%
postulaciones=pd.merge(postulaciones,postulaciones_por_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['postulaciones_misma_area']=postulaciones['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_nivel']=postulaciones['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_tipo']=postulaciones['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo        sexo   edad Doctorado  \
# 11888777  1112254717      W9Wja8j          0        MASC   20.0         -
# 12066142  1112117980       59xb2v          0         FEM   30.0         -
# 11742144  1111685518      X9k8oav          0         FEM   19.0         -
# 9347439   1112377301      X9k4YPx          1         FEM   30.0         -
# 3820585   1112285761       8APRox          1        MASC   26.0         -
# 12281976  1111013186      A3XX1lL          0  NO_DECLARA  200.0         -
# 10949639  1112404221      ak5PWY5          1        MASC   20.0         -
# 948220    1112109888      mzjpQad          1         FEM   21.0         -
# 1629652   1112460021       EZAZKz          1        MASC   58.0         -
# 11644841  1112408780      EzEM5E4          1         FEM   28.0         -
# 7205107   1112416453      6rPxpdO          0  NO_DECLARA  200.0         -
# 2789892   1112399046      9694bbZ          1        MASC   37.0         -
# 1114913   1112359648      owj6Doa          0        MASC   29.0         -
# 516312    1112350139      zvxNGYm          1         FEM   19.0         -
# 9726656   1112236067      pzjL3AL          0         FEM   27.0         -
# 5975761   1112291799       aEZwVW          1         FEM   27.0         -
# 2844061   1112274823       6EKYj4          0         FEM   31.0         -
# 4503201   1112447585       1P0wPL          1         FEM   38.0         -
# 8801298   1112384415      W9OMZXm          1         FEM   27.0         -
# 6156631   1112388033      rmdjYDQ          1         FEM   18.0         -
#
#          Master      Otro Posgrado Secundario            ...              \
# 11888777      -         -        -   Graduado            ...
# 12066142      -         -        -   Graduado            ...
# 11742144      -         -        -   Graduado            ...
# 9347439       -         -        -          -            ...
# 3820585       -         -        -          -            ...
# 12281976      -         -        -          -            ...
# 10949639      -         -        -   Graduado            ...
# 948220        -         -        -   Graduado            ...
# 1629652       -         -        -   Graduado            ...
# 11644841      -         -        -   Graduado            ...
# 7205107       -         -        -          -            ...
# 2789892       -         -        -   Graduado            ...
# 1114913       -         -        -          -            ...
# 516312        -         -        -          -            ...
# 9726656       -  Graduado        -   Graduado            ...
# 5975761       -  Graduado        -   Graduado            ...
# 2844061       -         -        -   Graduado            ...
# 4503201       -         -        -   Graduado            ...
# 8801298       -         -        -          -            ...
# 6156631       -         -        -   Graduado            ...
#
#          remuneracion_pretendida graduados estudiantes  \
# 11888777                   False     False       False
# 12066142                   False     False       False
# 11742144                   False     False       False
# 9347439                    False     False       False
# 3820585                    False      True        True
# 12281976                   False     False       False
# 10949639                   False     False       False
# 948220                     False     False       False
# 1629652                    False     False       False
# 11644841                   False     False       False
# 7205107                    False     False       False
# 2789892                    False     False       False
# 1114913                    False     False       False
# 516312                     False     False       False
# 9726656                    False      True       False
# 5975761                    False     False       False
# 2844061                    False     False       False
# 4503201                    False     False       False
# 8801298                    False     False       False
# 6156631                    False     False       False
#
#          conocimientos_especificos buen_ambiente discriminacion  cantidad  \
# 11888777                     False          True          False  0.000000
# 12066142                     False         False          False  0.000000
# 11742144                     False          True          False  0.000000
# 9347439                      False         False          False  0.000000
# 3820585                      False         False          False  0.000000
# 12281976                     False         False          False  0.000000
# 10949639                     False         False          False  0.000000
# 948220                       False         False          False  0.005038
# 1629652                      False         False          False  0.007937
# 11644841                     False         False          False  0.000000
# 7205107                      False         False          False  0.000000
# 2789892                      False          True          False  0.000000
# 1114913                      False         False          False  0.000000
# 516312                       False         False          False  0.000000
# 9726656                      False         False          False  0.000000
# 5975761                      False         False          False  0.000000
# 2844061                      False         False          False  0.000000
# 4503201                      False         False          False  0.008097
# 8801298                      False         False          False  0.012658
# 6156631                      False          True          False  0.004132
#
#          postulaciones_misma_area  postulaciones_mismo_tipo  \
# 11888777                        2                        57
# 12066142                        0                        15
# 11742144                        0                         4
# 9347439                         0                        14
# 3820585                        98                       702
# 12281976                        0                        12
# 10949639                       29                       141
# 948220                         10                         0
# 1629652                        32                        54
# 11644841                        4                        49
# 7205107                         2                         9
# 2789892                        20                        26
# 1114913                         1                        12
# 516312                          0                        12
# 9726656                         0                        25
# 5975761                         2                        35
# 2844061                         0                        12
# 4503201                         7                        67
# 8801298                        13                        45
# 6156631                        14                        32
#
#           postulaciones_mismo_nivel
# 11888777                         48
# 12066142                          9
# 11742144                          6
# 9347439                           9
# 3820585                         515
# 12281976                          7
# 10949639                        119
# 948220                           13
# 1629652                           4
# 11644841                         41
# 7205107                           1
# 2789892                           7
# 1114913                           7
# 516312                           11
# 9726656                           4
# 5975761                          27
# 2844061                           9
# 4503201                           0
# 8801298                          34
# 6156631                          11
#
# [20 rows x 39 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
vistas2=0
# Out:
# Train:  12148226 Test:  639381

# %%
gc.collect()
# Out:
# 92

# %%
c=lgb.LGBMClassifier(learning_rate=0.01,objective='binary',num_leaves=6000,max_depth=13,n_estimators=1200,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train,eval_set=[(x_test,y_test)],verbose=True,early_stopping_rounds=1)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")
# Out:
# [1]	valid_0's binary_logloss: 0.687243
# Training until validation scores don't improve for 1 rounds.
# [2]	valid_0's binary_logloss: 0.680494
# [3]	valid_0's binary_logloss: 0.673562
# [4]	valid_0's binary_logloss: 0.666785
# [5]	valid_0's binary_logloss: 0.661226
# [6]	valid_0's binary_logloss: 0.654655
# [7]	valid_0's binary_logloss: 0.648517
# [8]	valid_0's binary_logloss: 0.642187
# [9]	valid_0's binary_logloss: 0.636006
# [10]	valid_0's binary_logloss: 0.630024
# [11]	valid_0's binary_logloss: 0.624454
# [12]	valid_0's binary_logloss: 0.618595
# [13]	valid_0's binary_logloss: 0.613366
# [14]	valid_0's binary_logloss: 0.607878
# [15]	valid_0's binary_logloss: 0.60263
# [16]	valid_0's binary_logloss: 0.597552
# [17]	valid_0's binary_logloss: 0.592141
# [18]	valid_0's binary_logloss: 0.587337
# [19]	valid_0's binary_logloss: 0.582624
# [20]	valid_0's binary_logloss: 0.577878
# [21]	valid_0's binary_logloss: 0.572807
# [22]	valid_0's binary_logloss: 0.56785
# [23]	valid_0's binary_logloss: 0.563271
# [24]	valid_0's binary_logloss: 0.559296
# [25]	valid_0's binary_logloss: 0.554543
# [26]	valid_0's binary_logloss: 0.550016
# [27]	valid_0's binary_logloss: 0.545872
# [28]	valid_0's binary_logloss: 0.542329
# [29]	valid_0's binary_logloss: 0.538365
# [30]	valid_0's binary_logloss: 0.534919
# [31]	valid_0's binary_logloss: 0.531016
# [32]	valid_0's binary_logloss: 0.526927
# [33]	valid_0's binary_logloss: 0.522982
# [34]	valid_0's binary_logloss: 0.518838
# [35]	valid_0's binary_logloss: 0.515161
# [36]	valid_0's binary_logloss: 0.511168
# [37]	valid_0's binary_logloss: 0.50719
# [38]	valid_0's binary_logloss: 0.503702
# [39]	valid_0's binary_logloss: 0.50027
# [40]	valid_0's binary_logloss: 0.496455
# [41]	valid_0's binary_logloss: 0.493101
# [42]	valid_0's binary_logloss: 0.490122
# [43]	valid_0's binary_logloss: 0.486461
# [44]	valid_0's binary_logloss: 0.482902
# [45]	valid_0's binary_logloss: 0.480329
# [46]	valid_0's binary_logloss: 0.476812
# [47]	valid_0's binary_logloss: 0.474702
# [48]	valid_0's binary_logloss: 0.471274
# [49]	valid_0's binary_logloss: 0.467901
# [50]	valid_0's binary_logloss: 0.464934
# [51]	valid_0's binary_logloss: 0.461655
# [52]	valid_0's binary_logloss: 0.458423
# [53]	valid_0's binary_logloss: 0.455236
# [54]	valid_0's binary_logloss: 0.452115
# [55]	valid_0's binary_logloss: 0.449437
# [56]	valid_0's binary_logloss: 0.446797
# [57]	valid_0's binary_logloss: 0.443887
# [58]	valid_0's binary_logloss: 0.441204
# [59]	valid_0's binary_logloss: 0.438292
# [60]	valid_0's binary_logloss: 0.4354
# [61]	valid_0's binary_logloss: 0.432897
# [62]	valid_0's binary_logloss: 0.430408
# [63]	valid_0's binary_logloss: 0.427629
# [64]	valid_0's binary_logloss: 0.425149
# [65]	valid_0's binary_logloss: 0.422688
# [66]	valid_0's binary_logloss: 0.420309
# [67]	valid_0's binary_logloss: 0.417696
# [68]	valid_0's binary_logloss: 0.41548
# [69]	valid_0's binary_logloss: 0.413001
# [70]	valid_0's binary_logloss: 0.410564
# [71]	valid_0's binary_logloss: 0.408068
# [72]	valid_0's binary_logloss: 0.405602
# [73]	valid_0's binary_logloss: 0.403172
# [74]	valid_0's binary_logloss: 0.400787
# [75]	valid_0's binary_logloss: 0.398435
# [76]	valid_0's binary_logloss: 0.396347
# [77]	valid_0's binary_logloss: 0.394278
# [78]	valid_0's binary_logloss: 0.392237
# [79]	valid_0's binary_logloss: 0.390402
# [80]	valid_0's binary_logloss: 0.388172
# [81]	valid_0's binary_logloss: 0.38632
# [82]	valid_0's binary_logloss: 0.384375
# [83]	valid_0's binary_logloss: 0.382263
# [84]	valid_0's binary_logloss: 0.380388
# [85]	valid_0's binary_logloss: 0.378547
# [86]	valid_0's binary_logloss: 0.376645
# [87]	valid_0's binary_logloss: 0.375299
# [88]	valid_0's binary_logloss: 0.373452
# [89]	valid_0's binary_logloss: 0.371619
# [90]	valid_0's binary_logloss: 0.369987
# [91]	valid_0's binary_logloss: 0.368304
# [92]	valid_0's binary_logloss: 0.366945
# [93]	valid_0's binary_logloss: 0.365232
# [94]	valid_0's binary_logloss: 0.363334
# [95]	valid_0's binary_logloss: 0.361473
# [96]	valid_0's binary_logloss: 0.359865
# [97]	valid_0's binary_logloss: 0.358219
# [98]	valid_0's binary_logloss: 0.356905
# [99]	valid_0's binary_logloss: 0.35537
# [100]	valid_0's binary_logloss: 0.353783
# [101]	valid_0's binary_logloss: 0.352231
# [102]	valid_0's binary_logloss: 0.350495
# [103]	valid_0's binary_logloss: 0.348795
# [104]	valid_0's binary_logloss: 0.347331
# [105]	valid_0's binary_logloss: 0.34591
# [106]	valid_0's binary_logloss: 0.344456
# [107]	valid_0's binary_logloss: 0.343324
# [108]	valid_0's binary_logloss: 0.341712
# [109]	valid_0's binary_logloss: 0.340106
# [110]	valid_0's binary_logloss: 0.338528
# [111]	valid_0's binary_logloss: 0.336961
# [112]	valid_0's binary_logloss: 0.33557
# [113]	valid_0's binary_logloss: 0.334204
# [114]	valid_0's binary_logloss: 0.333091
# [115]	valid_0's binary_logloss: 0.33185
# [116]	valid_0's binary_logloss: 0.330608
# [117]	valid_0's binary_logloss: 0.329305
# [118]	valid_0's binary_logloss: 0.328103
# [119]	valid_0's binary_logloss: 0.326827
# [120]	valid_0's binary_logloss: 0.325402
# [121]	valid_0's binary_logloss: 0.323995
# [122]	valid_0's binary_logloss: 0.322599
# [123]	valid_0's binary_logloss: 0.321231
# [124]	valid_0's binary_logloss: 0.320035
# [125]	valid_0's binary_logloss: 0.318777
# [126]	valid_0's binary_logloss: 0.317669
# [127]	valid_0's binary_logloss: 0.316509
# [128]	valid_0's binary_logloss: 0.31521
# [129]	valid_0's binary_logloss: 0.31398
# [130]	valid_0's binary_logloss: 0.312872
# [131]	valid_0's binary_logloss: 0.311759
# [132]	valid_0's binary_logloss: 0.310522
# [133]	valid_0's binary_logloss: 0.309308
# [134]	valid_0's binary_logloss: 0.30829
# [135]	valid_0's binary_logloss: 0.307151
# [136]	valid_0's binary_logloss: 0.306275
# [137]	valid_0's binary_logloss: 0.305233
# [138]	valid_0's binary_logloss: 0.304121
# [139]	valid_0's binary_logloss: 0.303238
# [140]	valid_0's binary_logloss: 0.30224
# [141]	valid_0's binary_logloss: 0.301125
# [142]	valid_0's binary_logloss: 0.300078
# [143]	valid_0's binary_logloss: 0.298984
# [144]	valid_0's binary_logloss: 0.297902
# [145]	valid_0's binary_logloss: 0.297082
# [146]	valid_0's binary_logloss: 0.296025
# [147]	valid_0's binary_logloss: 0.294993
# [148]	valid_0's binary_logloss: 0.294075
# [149]	valid_0's binary_logloss: 0.293158
# [150]	valid_0's binary_logloss: 0.292203
# [151]	valid_0's binary_logloss: 0.291464
# [152]	valid_0's binary_logloss: 0.29048
# [153]	valid_0's binary_logloss: 0.289659
# [154]	valid_0's binary_logloss: 0.288831
# [155]	valid_0's binary_logloss: 0.288034
# [156]	valid_0's binary_logloss: 0.28709
# [157]	valid_0's binary_logloss: 0.286407
# [158]	valid_0's binary_logloss: 0.285569
# [159]	valid_0's binary_logloss: 0.284659
# [160]	valid_0's binary_logloss: 0.283804
# [161]	valid_0's binary_logloss: 0.28301
# [162]	valid_0's binary_logloss: 0.282244
# [163]	valid_0's binary_logloss: 0.281481
# [164]	valid_0's binary_logloss: 0.280702
# [165]	valid_0's binary_logloss: 0.279952
# [166]	valid_0's binary_logloss: 0.279184
# [167]	valid_0's binary_logloss: 0.278391
# [168]	valid_0's binary_logloss: 0.277581
# [169]	valid_0's binary_logloss: 0.27687
# [170]	valid_0's binary_logloss: 0.276145
# [171]	valid_0's binary_logloss: 0.275419
# [172]	valid_0's binary_logloss: 0.274624
# [173]	valid_0's binary_logloss: 0.273964
# [174]	valid_0's binary_logloss: 0.273169
# [175]	valid_0's binary_logloss: 0.272487
# [176]	valid_0's binary_logloss: 0.271721
# [177]	valid_0's binary_logloss: 0.271075
# [178]	valid_0's binary_logloss: 0.27032
# [179]	valid_0's binary_logloss: 0.269597
# [180]	valid_0's binary_logloss: 0.268889
# [181]	valid_0's binary_logloss: 0.268287
# [182]	valid_0's binary_logloss: 0.267562
# [183]	valid_0's binary_logloss: 0.266855
# [184]	valid_0's binary_logloss: 0.266282
# [185]	valid_0's binary_logloss: 0.2657
# [186]	valid_0's binary_logloss: 0.265073
# [187]	valid_0's binary_logloss: 0.264419
# [188]	valid_0's binary_logloss: 0.263781
# [189]	valid_0's binary_logloss: 0.263149
# [190]	valid_0's binary_logloss: 0.262557
# [191]	valid_0's binary_logloss: 0.261899
# [192]	valid_0's binary_logloss: 0.261251
# [193]	valid_0's binary_logloss: 0.260633
# [194]	valid_0's binary_logloss: 0.260107
# [195]	valid_0's binary_logloss: 0.25954
# [196]	valid_0's binary_logloss: 0.258923
# [197]	valid_0's binary_logloss: 0.258361
# [198]	valid_0's binary_logloss: 0.257763
# [199]	valid_0's binary_logloss: 0.25717
# [200]	valid_0's binary_logloss: 0.256723
# [201]	valid_0's binary_logloss: 0.256194
# [202]	valid_0's binary_logloss: 0.255605
# [203]	valid_0's binary_logloss: 0.255147
# [204]	valid_0's binary_logloss: 0.25459
# [205]	valid_0's binary_logloss: 0.254056
# [206]	valid_0's binary_logloss: 0.253504
# [207]	valid_0's binary_logloss: 0.253083
# [208]	valid_0's binary_logloss: 0.2526
# [209]	valid_0's binary_logloss: 0.252207
# [210]	valid_0's binary_logloss: 0.251769
# [211]	valid_0's binary_logloss: 0.251235
# [212]	valid_0's binary_logloss: 0.250755
# [213]	valid_0's binary_logloss: 0.250242
# [214]	valid_0's binary_logloss: 0.249729
# [215]	valid_0's binary_logloss: 0.249228
# [216]	valid_0's binary_logloss: 0.248781
# [217]	valid_0's binary_logloss: 0.248295
# [218]	valid_0's binary_logloss: 0.247958
# [219]	valid_0's binary_logloss: 0.247466
# [220]	valid_0's binary_logloss: 0.246975
# [221]	valid_0's binary_logloss: 0.246502
# [222]	valid_0's binary_logloss: 0.246025
# [223]	valid_0's binary_logloss: 0.245564
# [224]	valid_0's binary_logloss: 0.245117
# [225]	valid_0's binary_logloss: 0.244661
# [226]	valid_0's binary_logloss: 0.244207
# [227]	valid_0's binary_logloss: 0.243764
# [228]	valid_0's binary_logloss: 0.243397
# [229]	valid_0's binary_logloss: 0.24301
# [230]	valid_0's binary_logloss: 0.242582
# [231]	valid_0's binary_logloss: 0.24216
# [232]	valid_0's binary_logloss: 0.241787
# [233]	valid_0's binary_logloss: 0.241432
# [234]	valid_0's binary_logloss: 0.241042
# [235]	valid_0's binary_logloss: 0.240673
# [236]	valid_0's binary_logloss: 0.2403
# [237]	valid_0's binary_logloss: 0.239903
# [238]	valid_0's binary_logloss: 0.239533
# [239]	valid_0's binary_logloss: 0.239196
# [240]	valid_0's binary_logloss: 0.238822
# [241]	valid_0's binary_logloss: 0.238414
# [242]	valid_0's binary_logloss: 0.238109
# [243]	valid_0's binary_logloss: 0.237727
# [244]	valid_0's binary_logloss: 0.237357
# [245]	valid_0's binary_logloss: 0.237027
# [246]	valid_0's binary_logloss: 0.236749
# [247]	valid_0's binary_logloss: 0.236461
# [248]	valid_0's binary_logloss: 0.236209
# [249]	valid_0's binary_logloss: 0.235839
# [250]	valid_0's binary_logloss: 0.235559
# [251]	valid_0's binary_logloss: 0.235305
# [252]	valid_0's binary_logloss: 0.234932
# [253]	valid_0's binary_logloss: 0.234586
# [254]	valid_0's binary_logloss: 0.234277
# [255]	valid_0's binary_logloss: 0.234027
# [256]	valid_0's binary_logloss: 0.233651
# [257]	valid_0's binary_logloss: 0.233319
# [258]	valid_0's binary_logloss: 0.232983
# [259]	valid_0's binary_logloss: 0.232711
# [260]	valid_0's binary_logloss: 0.232395
# [261]	valid_0's binary_logloss: 0.232115
# [262]	valid_0's binary_logloss: 0.231792
# [263]	valid_0's binary_logloss: 0.231434
# [264]	valid_0's binary_logloss: 0.231139
# [265]	valid_0's binary_logloss: 0.23085
# [266]	valid_0's binary_logloss: 0.230643
# [267]	valid_0's binary_logloss: 0.230346
# [268]	valid_0's binary_logloss: 0.230048
# [269]	valid_0's binary_logloss: 0.229753
# [270]	valid_0's binary_logloss: 0.229465
# [271]	valid_0's binary_logloss: 0.229157
# [272]	valid_0's binary_logloss: 0.228845
# [273]	valid_0's binary_logloss: 0.228548
# [274]	valid_0's binary_logloss: 0.228261
# [275]	valid_0's binary_logloss: 0.228035
# [276]	valid_0's binary_logloss: 0.22776
# [277]	valid_0's binary_logloss: 0.227482
# [278]	valid_0's binary_logloss: 0.227207
# [279]	valid_0's binary_logloss: 0.226941
# [280]	valid_0's binary_logloss: 0.226727
# [281]	valid_0's binary_logloss: 0.226458
# [282]	valid_0's binary_logloss: 0.226241
# [283]	valid_0's binary_logloss: 0.226016
# [284]	valid_0's binary_logloss: 0.225852
# [285]	valid_0's binary_logloss: 0.225597
# [286]	valid_0's binary_logloss: 0.225311
# [287]	valid_0's binary_logloss: 0.225067
# [288]	valid_0's binary_logloss: 0.224811
# [289]	valid_0's binary_logloss: 0.224537
# [290]	valid_0's binary_logloss: 0.22434
# [291]	valid_0's binary_logloss: 0.224172
# [292]	valid_0's binary_logloss: 0.223933
# [293]	valid_0's binary_logloss: 0.223676
# [294]	valid_0's binary_logloss: 0.223445
# [295]	valid_0's binary_logloss: 0.223203
# [296]	valid_0's binary_logloss: 0.222982
# [297]	valid_0's binary_logloss: 0.222754
# [298]	valid_0's binary_logloss: 0.22253
# [299]	valid_0's binary_logloss: 0.222385
# [300]	valid_0's binary_logloss: 0.222164
# [301]	valid_0's binary_logloss: 0.221975
# [302]	valid_0's binary_logloss: 0.221756
# [303]	valid_0's binary_logloss: 0.221542
# [304]	valid_0's binary_logloss: 0.221318
# [305]	valid_0's binary_logloss: 0.221132
# [306]	valid_0's binary_logloss: 0.220934
# [307]	valid_0's binary_logloss: 0.220763
# [308]	valid_0's binary_logloss: 0.220556
# [309]	valid_0's binary_logloss: 0.220349
# [310]	valid_0's binary_logloss: 0.220152
# [311]	valid_0's binary_logloss: 0.219939
# [312]	valid_0's binary_logloss: 0.219731
# [313]	valid_0's binary_logloss: 0.219542
# [314]	valid_0's binary_logloss: 0.219383
# [315]	valid_0's binary_logloss: 0.219202
# [316]	valid_0's binary_logloss: 0.219067
# [317]	valid_0's binary_logloss: 0.218901
# [318]	valid_0's binary_logloss: 0.218709
# [319]	valid_0's binary_logloss: 0.218543
# [320]	valid_0's binary_logloss: 0.218394
# [321]	valid_0's binary_logloss: 0.218204
# [322]	valid_0's binary_logloss: 0.218061
# [323]	valid_0's binary_logloss: 0.217839
# [324]	valid_0's binary_logloss: 0.217652
# [325]	valid_0's binary_logloss: 0.2175
# [326]	valid_0's binary_logloss: 0.217328
# [327]	valid_0's binary_logloss: 0.217155
# [328]	valid_0's binary_logloss: 0.217012
# [329]	valid_0's binary_logloss: 0.216881
# [330]	valid_0's binary_logloss: 0.216706
# [331]	valid_0's binary_logloss: 0.216565
# [332]	valid_0's binary_logloss: 0.216421
# [333]	valid_0's binary_logloss: 0.216263
# [334]	valid_0's binary_logloss: 0.216104
# [335]	valid_0's binary_logloss: 0.215946
# [336]	valid_0's binary_logloss: 0.215781
# [337]	valid_0's binary_logloss: 0.215636
# [338]	valid_0's binary_logloss: 0.215476
# [339]	valid_0's binary_logloss: 0.215344
# [340]	valid_0's binary_logloss: 0.215235
# [341]	valid_0's binary_logloss: 0.215101
# [342]	valid_0's binary_logloss: 0.21493
# [343]	valid_0's binary_logloss: 0.214784
# [344]	valid_0's binary_logloss: 0.214627
# [345]	valid_0's binary_logloss: 0.21448
# [346]	valid_0's binary_logloss: 0.214311
# [347]	valid_0's binary_logloss: 0.2142
# [348]	valid_0's binary_logloss: 0.214025
# [349]	valid_0's binary_logloss: 0.213917
# [350]	valid_0's binary_logloss: 0.213759
# [351]	valid_0's binary_logloss: 0.213618
# [352]	valid_0's binary_logloss: 0.213516
# [353]	valid_0's binary_logloss: 0.213373
# [354]	valid_0's binary_logloss: 0.213216
# [355]	valid_0's binary_logloss: 0.213073
# [356]	valid_0's binary_logloss: 0.212941
# [357]	valid_0's binary_logloss: 0.212789
# [358]	valid_0's binary_logloss: 0.212644
# [359]	valid_0's binary_logloss: 0.212507
# [360]	valid_0's binary_logloss: 0.21238
# [361]	valid_0's binary_logloss: 0.212255
# [362]	valid_0's binary_logloss: 0.212129
# [363]	valid_0's binary_logloss: 0.212035
# [364]	valid_0's binary_logloss: 0.211943
# [365]	valid_0's binary_logloss: 0.211818
# [366]	valid_0's binary_logloss: 0.211677
# [367]	valid_0's binary_logloss: 0.211544
# [368]	valid_0's binary_logloss: 0.211391
# [369]	valid_0's binary_logloss: 0.211267
# [370]	valid_0's binary_logloss: 0.211157
# [371]	valid_0's binary_logloss: 0.211033
# [372]	valid_0's binary_logloss: 0.210914
# [373]	valid_0's binary_logloss: 0.210787
# [374]	valid_0's binary_logloss: 0.210659
# [375]	valid_0's binary_logloss: 0.210574
# [376]	valid_0's binary_logloss: 0.21047
# [377]	valid_0's binary_logloss: 0.210345
# [378]	valid_0's binary_logloss: 0.210244
# [379]	valid_0's binary_logloss: 0.210111
# [380]	valid_0's binary_logloss: 0.209985
# [381]	valid_0's binary_logloss: 0.209817
# [382]	valid_0's binary_logloss: 0.20974
# [383]	valid_0's binary_logloss: 0.209652
# [384]	valid_0's binary_logloss: 0.209544
# [385]	valid_0's binary_logloss: 0.2094
# [386]	valid_0's binary_logloss: 0.209313
# [387]	valid_0's binary_logloss: 0.209217
# [388]	valid_0's binary_logloss: 0.209101
# [389]	valid_0's binary_logloss: 0.209008
# [390]	valid_0's binary_logloss: 0.208906
# [391]	valid_0's binary_logloss: 0.208775
# [392]	valid_0's binary_logloss: 0.208686
# [393]	valid_0's binary_logloss: 0.208607
# [394]	valid_0's binary_logloss: 0.208497
# [395]	valid_0's binary_logloss: 0.208406
# [396]	valid_0's binary_logloss: 0.20827
# [397]	valid_0's binary_logloss: 0.208176
# [398]	valid_0's binary_logloss: 0.208087
# [399]	valid_0's binary_logloss: 0.207997
# [400]	valid_0's binary_logloss: 0.207887
# [401]	valid_0's binary_logloss: 0.207785
# [402]	valid_0's binary_logloss: 0.207689
# [403]	valid_0's binary_logloss: 0.207598
# [404]	valid_0's binary_logloss: 0.2075
# [405]	valid_0's binary_logloss: 0.207374
# [406]	valid_0's binary_logloss: 0.207288
# [407]	valid_0's binary_logloss: 0.207189
# [408]	valid_0's binary_logloss: 0.207127
# [409]	valid_0's binary_logloss: 0.207032
# [410]	valid_0's binary_logloss: 0.206954
# [411]	valid_0's binary_logloss: 0.20686
# [412]	valid_0's binary_logloss: 0.206748
# [413]	valid_0's binary_logloss: 0.206688
# [414]	valid_0's binary_logloss: 0.206611
# [415]	valid_0's binary_logloss: 0.206535
# [416]	valid_0's binary_logloss: 0.206426
# [417]	valid_0's binary_logloss: 0.2063
# [418]	valid_0's binary_logloss: 0.206214
# [419]	valid_0's binary_logloss: 0.20613
# [420]	valid_0's binary_logloss: 0.206038
# [421]	valid_0's binary_logloss: 0.205965
# [422]	valid_0's binary_logloss: 0.205902
# [423]	valid_0's binary_logloss: 0.205846
# [424]	valid_0's binary_logloss: 0.205771
# [425]	valid_0's binary_logloss: 0.205693
# [426]	valid_0's binary_logloss: 0.205625
# [427]	valid_0's binary_logloss: 0.205509
# [428]	valid_0's binary_logloss: 0.205404
# [429]	valid_0's binary_logloss: 0.205302
# [430]	valid_0's binary_logloss: 0.205229
# [431]	valid_0's binary_logloss: 0.205157
# [432]	valid_0's binary_logloss: 0.205097
# [433]	valid_0's binary_logloss: 0.205042
# [434]	valid_0's binary_logloss: 0.204968
# [435]	valid_0's binary_logloss: 0.204855
# [436]	valid_0's binary_logloss: 0.20478
# [437]	valid_0's binary_logloss: 0.2047
# [438]	valid_0's binary_logloss: 0.20463
# [439]	valid_0's binary_logloss: 0.204559
# [440]	valid_0's binary_logloss: 0.204467
# [441]	valid_0's binary_logloss: 0.204407
# [442]	valid_0's binary_logloss: 0.204329
# [443]	valid_0's binary_logloss: 0.204255
# [444]	valid_0's binary_logloss: 0.204185
# [445]	valid_0's binary_logloss: 0.204112
# [446]	valid_0's binary_logloss: 0.204054
# [447]	valid_0's binary_logloss: 0.203968
# [448]	valid_0's binary_logloss: 0.203913
# [449]	valid_0's binary_logloss: 0.203836
# [450]	valid_0's binary_logloss: 0.203772
# [451]	valid_0's binary_logloss: 0.203718
# [452]	valid_0's binary_logloss: 0.203656
# [453]	valid_0's binary_logloss: 0.2036
# [454]	valid_0's binary_logloss: 0.203534
# [455]	valid_0's binary_logloss: 0.203445
# [456]	valid_0's binary_logloss: 0.203392
# [457]	valid_0's binary_logloss: 0.203347
# [458]	valid_0's binary_logloss: 0.203301
# [459]	valid_0's binary_logloss: 0.203231
# [460]	valid_0's binary_logloss: 0.203192
# [461]	valid_0's binary_logloss: 0.203136
# [462]	valid_0's binary_logloss: 0.203082
# [463]	valid_0's binary_logloss: 0.203025
# [464]	valid_0's binary_logloss: 0.202932
# [465]	valid_0's binary_logloss: 0.202865
# [466]	valid_0's binary_logloss: 0.202809
# [467]	valid_0's binary_logloss: 0.202772
# [468]	valid_0's binary_logloss: 0.202729
# [469]	valid_0's binary_logloss: 0.202666
# [470]	valid_0's binary_logloss: 0.202595
# [471]	valid_0's binary_logloss: 0.202562
# [472]	valid_0's binary_logloss: 0.202494
# [473]	valid_0's binary_logloss: 0.202461
# [474]	valid_0's binary_logloss: 0.202396
# [475]	valid_0's binary_logloss: 0.202333
# [476]	valid_0's binary_logloss: 0.202231
# [477]	valid_0's binary_logloss: 0.202181
# [478]	valid_0's binary_logloss: 0.20214
# [479]	valid_0's binary_logloss: 0.20208
# [480]	valid_0's binary_logloss: 0.20203
# [481]	valid_0's binary_logloss: 0.201966
# [482]	valid_0's binary_logloss: 0.20189
# [483]	valid_0's binary_logloss: 0.201824
# [484]	valid_0's binary_logloss: 0.201769
# [485]	valid_0's binary_logloss: 0.201688
# [486]	valid_0's binary_logloss: 0.201659
# [487]	valid_0's binary_logloss: 0.201622
# [488]	valid_0's binary_logloss: 0.201573
# [489]	valid_0's binary_logloss: 0.201502
# [490]	valid_0's binary_logloss: 0.201452
# [491]	valid_0's binary_logloss: 0.201414
# [492]	valid_0's binary_logloss: 0.201383
# [493]	valid_0's binary_logloss: 0.20129
# [494]	valid_0's binary_logloss: 0.201258
# [495]	valid_0's binary_logloss: 0.201226
# [496]	valid_0's binary_logloss: 0.201181
# [497]	valid_0's binary_logloss: 0.201144
# [498]	valid_0's binary_logloss: 0.201093
# [499]	valid_0's binary_logloss: 0.201043
# [500]	valid_0's binary_logloss: 0.201006
# [501]	valid_0's binary_logloss: 0.200953
# [502]	valid_0's binary_logloss: 0.200907
# [503]	valid_0's binary_logloss: 0.200819
# [504]	valid_0's binary_logloss: 0.200748
# [505]	valid_0's binary_logloss: 0.200694
# [506]	valid_0's binary_logloss: 0.200599
# [507]	valid_0's binary_logloss: 0.20053
# [508]	valid_0's binary_logloss: 0.2005
# [509]	valid_0's binary_logloss: 0.200474
# [510]	valid_0's binary_logloss: 0.200457
# [511]	valid_0's binary_logloss: 0.200374
# [512]	valid_0's binary_logloss: 0.200296
# [513]	valid_0's binary_logloss: 0.200258
# [514]	valid_0's binary_logloss: 0.200221
# [515]	valid_0's binary_logloss: 0.200186
# [516]	valid_0's binary_logloss: 0.200136
# [517]	valid_0's binary_logloss: 0.200067
# [518]	valid_0's binary_logloss: 0.200039
# [519]	valid_0's binary_logloss: 0.199995
# [520]	valid_0's binary_logloss: 0.19997
# [521]	valid_0's binary_logloss: 0.199921
# [522]	valid_0's binary_logloss: 0.199889
# [523]	valid_0's binary_logloss: 0.199856
# [524]	valid_0's binary_logloss: 0.199818
# [525]	valid_0's binary_logloss: 0.199789
# [526]	valid_0's binary_logloss: 0.199747
# [527]	valid_0's binary_logloss: 0.199641
# [528]	valid_0's binary_logloss: 0.199593
# [529]	valid_0's binary_logloss: 0.199537
# [530]	valid_0's binary_logloss: 0.199505
# [531]	valid_0's binary_logloss: 0.199435
# [532]	valid_0's binary_logloss: 0.199396
# [533]	valid_0's binary_logloss: 0.199365
# [534]	valid_0's binary_logloss: 0.199338
# [535]	valid_0's binary_logloss: 0.199312
# [536]	valid_0's binary_logloss: 0.199258
# [537]	valid_0's binary_logloss: 0.199224
# [538]	valid_0's binary_logloss: 0.199193
# [539]	valid_0's binary_logloss: 0.199162
# [540]	valid_0's binary_logloss: 0.199141
# [541]	valid_0's binary_logloss: 0.199113
# [542]	valid_0's binary_logloss: 0.199093
# [543]	valid_0's binary_logloss: 0.199044
# [544]	valid_0's binary_logloss: 0.19901
# [545]	valid_0's binary_logloss: 0.198986
# [546]	valid_0's binary_logloss: 0.198947
# [547]	valid_0's binary_logloss: 0.198902
# [548]	valid_0's binary_logloss: 0.198877
# [549]	valid_0's binary_logloss: 0.198788
# [550]	valid_0's binary_logloss: 0.198765
# [551]	valid_0's binary_logloss: 0.198746
# [552]	valid_0's binary_logloss: 0.198702
# [553]	valid_0's binary_logloss: 0.198684
# [554]	valid_0's binary_logloss: 0.198657
# [555]	valid_0's binary_logloss: 0.198642
# [556]	valid_0's binary_logloss: 0.198625
# [557]	valid_0's binary_logloss: 0.198604
# [558]	valid_0's binary_logloss: 0.198584
# [559]	valid_0's binary_logloss: 0.198529
# [560]	valid_0's binary_logloss: 0.198486
# [561]	valid_0's binary_logloss: 0.198468
# [562]	valid_0's binary_logloss: 0.198443
# [563]	valid_0's binary_logloss: 0.198426
# [564]	valid_0's binary_logloss: 0.19841
# [565]	valid_0's binary_logloss: 0.198389
# [566]	valid_0's binary_logloss: 0.198373
# [567]	valid_0's binary_logloss: 0.198357
# [568]	valid_0's binary_logloss: 0.198342
# [569]	valid_0's binary_logloss: 0.198325
# [570]	valid_0's binary_logloss: 0.198298
# [571]	valid_0's binary_logloss: 0.198228
# [572]	valid_0's binary_logloss: 0.198215
# [573]	valid_0's binary_logloss: 0.198162
# [574]	valid_0's binary_logloss: 0.19814
# [575]	valid_0's binary_logloss: 0.198124
# [576]	valid_0's binary_logloss: 0.198023
# [577]	valid_0's binary_logloss: 0.198012
# [578]	valid_0's binary_logloss: 0.197999
# [579]	valid_0's binary_logloss: 0.197937
# [580]	valid_0's binary_logloss: 0.19792
# [581]	valid_0's binary_logloss: 0.197906
# [582]	valid_0's binary_logloss: 0.197821
# [583]	valid_0's binary_logloss: 0.197769
# [584]	valid_0's binary_logloss: 0.197705
# [585]	valid_0's binary_logloss: 0.197693
# [586]	valid_0's binary_logloss: 0.197681
# [587]	valid_0's binary_logloss: 0.197651
# [588]	valid_0's binary_logloss: 0.197639
# [589]	valid_0's binary_logloss: 0.197627
# [590]	valid_0's binary_logloss: 0.197613
# [591]	valid_0's binary_logloss: 0.197602
# [592]	valid_0's binary_logloss: 0.197552
# [593]	valid_0's binary_logloss: 0.197542
# [594]	valid_0's binary_logloss: 0.19753
# [595]	valid_0's binary_logloss: 0.197519
# [596]	valid_0's binary_logloss: 0.197466
# [597]	valid_0's binary_logloss: 0.197423
# [598]	valid_0's binary_logloss: 0.197413
# [599]	valid_0's binary_logloss: 0.197402
# [600]	valid_0's binary_logloss: 0.197346
# [601]	valid_0's binary_logloss: 0.197309
# [602]	valid_0's binary_logloss: 0.197298
# [603]	valid_0's binary_logloss: 0.197288
# [604]	valid_0's binary_logloss: 0.197242
# [605]	valid_0's binary_logloss: 0.197231
# [606]	valid_0's binary_logloss: 0.197197
# [607]	valid_0's binary_logloss: 0.197187
# [608]	valid_0's binary_logloss: 0.197177
# [609]	valid_0's binary_logloss: 0.197129
# [610]	valid_0's binary_logloss: 0.197119
# [611]	valid_0's binary_logloss: 0.197108
# [612]	valid_0's binary_logloss: 0.197098
# [613]	valid_0's binary_logloss: 0.197088
# [614]	valid_0's binary_logloss: 0.197081
# [615]	valid_0's binary_logloss: 0.197071
# [616]	valid_0's binary_logloss: 0.197061
# [617]	valid_0's binary_logloss: 0.197051
# [618]	valid_0's binary_logloss: 0.197042
# [619]	valid_0's binary_logloss: 0.197034
# [620]	valid_0's binary_logloss: 0.196983
# [621]	valid_0's binary_logloss: 0.196973
# [622]	valid_0's binary_logloss: 0.196929
# [623]	valid_0's binary_logloss: 0.19692
# [624]	valid_0's binary_logloss: 0.196864
# [625]	valid_0's binary_logloss: 0.196855
# [626]	valid_0's binary_logloss: 0.196845
# [627]	valid_0's binary_logloss: 0.196837
# [628]	valid_0's binary_logloss: 0.196828
# [629]	valid_0's binary_logloss: 0.196815
# [630]	valid_0's binary_logloss: 0.196806
# [631]	valid_0's binary_logloss: 0.196797
# [632]	valid_0's binary_logloss: 0.196787
# [633]	valid_0's binary_logloss: 0.196778
# [634]	valid_0's binary_logloss: 0.19676
# [635]	valid_0's binary_logloss: 0.19675
# [636]	valid_0's binary_logloss: 0.196741
# [637]	valid_0's binary_logloss: 0.196705
# [638]	valid_0's binary_logloss: 0.196648
# [639]	valid_0's binary_logloss: 0.196639
# [640]	valid_0's binary_logloss: 0.196601
# [641]	valid_0's binary_logloss: 0.196593
# [642]	valid_0's binary_logloss: 0.196585
# [643]	valid_0's binary_logloss: 0.196557
# [644]	valid_0's binary_logloss: 0.196551
# [645]	valid_0's binary_logloss: 0.196542
# [646]	valid_0's binary_logloss: 0.19649
# [647]	valid_0's binary_logloss: 0.196482
# [648]	valid_0's binary_logloss: 0.196474
# [649]	valid_0's binary_logloss: 0.196437
# [650]	valid_0's binary_logloss: 0.19643
# [651]	valid_0's binary_logloss: 0.196422
# [652]	valid_0's binary_logloss: 0.196414
# [653]	valid_0's binary_logloss: 0.196363
# [654]	valid_0's binary_logloss: 0.196355
# [655]	valid_0's binary_logloss: 0.196347
# [656]	valid_0's binary_logloss: 0.196339
# [657]	valid_0's binary_logloss: 0.196331
# [658]	valid_0's binary_logloss: 0.196298
# [659]	valid_0's binary_logloss: 0.196291
# [660]	valid_0's binary_logloss: 0.196285
# [661]	valid_0's binary_logloss: 0.196239
# [662]	valid_0's binary_logloss: 0.196231
# [663]	valid_0's binary_logloss: 0.196224
# [664]	valid_0's binary_logloss: 0.196216
# [665]	valid_0's binary_logloss: 0.196209
# [666]	valid_0's binary_logloss: 0.196201
# [667]	valid_0's binary_logloss: 0.196193
# [668]	valid_0's binary_logloss: 0.196157
# [669]	valid_0's binary_logloss: 0.196151
# [670]	valid_0's binary_logloss: 0.196096
# [671]	valid_0's binary_logloss: 0.196047
# [672]	valid_0's binary_logloss: 0.196039
# [673]	valid_0's binary_logloss: 0.196003
# [674]	valid_0's binary_logloss: 0.195963
# [675]	valid_0's binary_logloss: 0.195956
# [676]	valid_0's binary_logloss: 0.19595
# [677]	valid_0's binary_logloss: 0.195897
# [678]	valid_0's binary_logloss: 0.19589
# [679]	valid_0's binary_logloss: 0.195882
# [680]	valid_0's binary_logloss: 0.195875
# [681]	valid_0's binary_logloss: 0.195868
# [682]	valid_0's binary_logloss: 0.195862
# [683]	valid_0's binary_logloss: 0.195855
# [684]	valid_0's binary_logloss: 0.195848
# [685]	valid_0's binary_logloss: 0.19584
# [686]	valid_0's binary_logloss: 0.195834
# [687]	valid_0's binary_logloss: 0.195796
# [688]	valid_0's binary_logloss: 0.19574
# [689]	valid_0's binary_logloss: 0.195733
# [690]	valid_0's binary_logloss: 0.195726
# [691]	valid_0's binary_logloss: 0.195719
# [692]	valid_0's binary_logloss: 0.195712
# [693]	valid_0's binary_logloss: 0.195705
# [694]	valid_0's binary_logloss: 0.195698
# [695]	valid_0's binary_logloss: 0.19569
# [696]	valid_0's binary_logloss: 0.195684
# [697]	valid_0's binary_logloss: 0.195644
# [698]	valid_0's binary_logloss: 0.195635
# [699]	valid_0's binary_logloss: 0.195629
# [700]	valid_0's binary_logloss: 0.195623
# [701]	valid_0's binary_logloss: 0.195592
# [702]	valid_0's binary_logloss: 0.195586
# [703]	valid_0's binary_logloss: 0.195577
# [704]	valid_0's binary_logloss: 0.19555
# [705]	valid_0's binary_logloss: 0.195543
# [706]	valid_0's binary_logloss: 0.195484
# [707]	valid_0's binary_logloss: 0.195478
# [708]	valid_0's binary_logloss: 0.195471
# [709]	valid_0's binary_logloss: 0.195464
# [710]	valid_0's binary_logloss: 0.195457
# [711]	valid_0's binary_logloss: 0.19545
# [712]	valid_0's binary_logloss: 0.195444
# [713]	valid_0's binary_logloss: 0.195438
# [714]	valid_0's binary_logloss: 0.19543
# [715]	valid_0's binary_logloss: 0.195424
# [716]	valid_0's binary_logloss: 0.195418
# [717]	valid_0's binary_logloss: 0.195411
# [718]	valid_0's binary_logloss: 0.195379
# [719]	valid_0's binary_logloss: 0.195373
# [720]	valid_0's binary_logloss: 0.195367
# [721]	valid_0's binary_logloss: 0.195361
# [722]	valid_0's binary_logloss: 0.195356
# [723]	valid_0's binary_logloss: 0.19535
# [724]	valid_0's binary_logloss: 0.195308
# [725]	valid_0's binary_logloss: 0.195302
# [726]	valid_0's binary_logloss: 0.195296
# [727]	valid_0's binary_logloss: 0.19529
# [728]	valid_0's binary_logloss: 0.195284
# [729]	valid_0's binary_logloss: 0.195264
# [730]	valid_0's binary_logloss: 0.195259
# [731]	valid_0's binary_logloss: 0.195254
# [732]	valid_0's binary_logloss: 0.195247
# [733]	valid_0's binary_logloss: 0.195186
# [734]	valid_0's binary_logloss: 0.19518
# [735]	valid_0's binary_logloss: 0.195175
# [736]	valid_0's binary_logloss: 0.195167
# [737]	valid_0's binary_logloss: 0.195129
# [738]	valid_0's binary_logloss: 0.195123
# [739]	valid_0's binary_logloss: 0.195088
# [740]	valid_0's binary_logloss: 0.195082
# [741]	valid_0's binary_logloss: 0.195077
# [742]	valid_0's binary_logloss: 0.195071
# [743]	valid_0's binary_logloss: 0.195065
# [744]	valid_0's binary_logloss: 0.19506
# [745]	valid_0's binary_logloss: 0.195054
# [746]	valid_0's binary_logloss: 0.195048
# [747]	valid_0's binary_logloss: 0.195042
# [748]	valid_0's binary_logloss: 0.195036
# [749]	valid_0's binary_logloss: 0.195031
# [750]	valid_0's binary_logloss: 0.19502
# [751]	valid_0's binary_logloss: 0.195012
# [752]	valid_0's binary_logloss: 0.195006
# [753]	valid_0's binary_logloss: 0.195
# [754]	valid_0's binary_logloss: 0.194994
# [755]	valid_0's binary_logloss: 0.194972
# [756]	valid_0's binary_logloss: 0.194967
# [757]	valid_0's binary_logloss: 0.194961
# [758]	valid_0's binary_logloss: 0.194955
# [759]	valid_0's binary_logloss: 0.194873
# [760]	valid_0's binary_logloss: 0.194863
# [761]	valid_0's binary_logloss: 0.194856
# [762]	valid_0's binary_logloss: 0.194851
# [763]	valid_0's binary_logloss: 0.194845
# [764]	valid_0's binary_logloss: 0.19484
# [765]	valid_0's binary_logloss: 0.194835
# [766]	valid_0's binary_logloss: 0.19483
# [767]	valid_0's binary_logloss: 0.194823
# [768]	valid_0's binary_logloss: 0.194752
# [769]	valid_0's binary_logloss: 0.194744
# [770]	valid_0's binary_logloss: 0.194737
# [771]	valid_0's binary_logloss: 0.194731
# [772]	valid_0's binary_logloss: 0.194671
# [773]	valid_0's binary_logloss: 0.194634
# [774]	valid_0's binary_logloss: 0.194598
# [775]	valid_0's binary_logloss: 0.194593
# [776]	valid_0's binary_logloss: 0.194588
# [777]	valid_0's binary_logloss: 0.194582
# [778]	valid_0's binary_logloss: 0.194577
# [779]	valid_0's binary_logloss: 0.194571
# [780]	valid_0's binary_logloss: 0.194549
# [781]	valid_0's binary_logloss: 0.194543
# [782]	valid_0's binary_logloss: 0.194485
# [783]	valid_0's binary_logloss: 0.19448
# [784]	valid_0's binary_logloss: 0.194473
# [785]	valid_0's binary_logloss: 0.194468
# [786]	valid_0's binary_logloss: 0.194462
# [787]	valid_0's binary_logloss: 0.194457
# [788]	valid_0's binary_logloss: 0.194452
# [789]	valid_0's binary_logloss: 0.194447
# [790]	valid_0's binary_logloss: 0.19444
# [791]	valid_0's binary_logloss: 0.194358
# [792]	valid_0's binary_logloss: 0.194322
# [793]	valid_0's binary_logloss: 0.194317
# [794]	valid_0's binary_logloss: 0.194312
# [795]	valid_0's binary_logloss: 0.194308
# [796]	valid_0's binary_logloss: 0.1943
# [797]	valid_0's binary_logloss: 0.194295
# [798]	valid_0's binary_logloss: 0.194291
# [799]	valid_0's binary_logloss: 0.194262
# [800]	valid_0's binary_logloss: 0.194257
# [801]	valid_0's binary_logloss: 0.194251
# [802]	valid_0's binary_logloss: 0.194246
# [803]	valid_0's binary_logloss: 0.194242
# [804]	valid_0's binary_logloss: 0.194236
# [805]	valid_0's binary_logloss: 0.194222
# [806]	valid_0's binary_logloss: 0.194182
# [807]	valid_0's binary_logloss: 0.194177
# [808]	valid_0's binary_logloss: 0.194171
# [809]	valid_0's binary_logloss: 0.194165
# [810]	valid_0's binary_logloss: 0.194158
# [811]	valid_0's binary_logloss: 0.19415
# [812]	valid_0's binary_logloss: 0.194133
# [813]	valid_0's binary_logloss: 0.194128
# [814]	valid_0's binary_logloss: 0.194123
# [815]	valid_0's binary_logloss: 0.194118
# [816]	valid_0's binary_logloss: 0.194109
# [817]	valid_0's binary_logloss: 0.194051
# [818]	valid_0's binary_logloss: 0.194038
# [819]	valid_0's binary_logloss: 0.194033
# [820]	valid_0's binary_logloss: 0.194029
# [821]	valid_0's binary_logloss: 0.194024
# [822]	valid_0's binary_logloss: 0.194018
# [823]	valid_0's binary_logloss: 0.194011
# [824]	valid_0's binary_logloss: 0.194004
# [825]	valid_0's binary_logloss: 0.194
# [826]	valid_0's binary_logloss: 0.193985
# [827]	valid_0's binary_logloss: 0.19398
# [828]	valid_0's binary_logloss: 0.193925
# [829]	valid_0's binary_logloss: 0.193909
# [830]	valid_0's binary_logloss: 0.193904
# [831]	valid_0's binary_logloss: 0.193899
# [832]	valid_0's binary_logloss: 0.193888
# [833]	valid_0's binary_logloss: 0.193843
# [834]	valid_0's binary_logloss: 0.193805
# [835]	valid_0's binary_logloss: 0.1938
# [836]	valid_0's binary_logloss: 0.193789
# [837]	valid_0's binary_logloss: 0.193783
# [838]	valid_0's binary_logloss: 0.193753
# [839]	valid_0's binary_logloss: 0.193749
# [840]	valid_0's binary_logloss: 0.193716
# [841]	valid_0's binary_logloss: 0.193712
# [842]	valid_0's binary_logloss: 0.193705
# [843]	valid_0's binary_logloss: 0.19368
# [844]	valid_0's binary_logloss: 0.193675
# [845]	valid_0's binary_logloss: 0.19367
# [846]	valid_0's binary_logloss: 0.193666
# [847]	valid_0's binary_logloss: 0.193643
# [848]	valid_0's binary_logloss: 0.193636
# [849]	valid_0's binary_logloss: 0.193631
# [850]	valid_0's binary_logloss: 0.193606
# [851]	valid_0's binary_logloss: 0.193602
# [852]	valid_0's binary_logloss: 0.193598
# [853]	valid_0's binary_logloss: 0.193575
# [854]	valid_0's binary_logloss: 0.193569
# [855]	valid_0's binary_logloss: 0.193563
# [856]	valid_0's binary_logloss: 0.193559
# [857]	valid_0's binary_logloss: 0.193552
# [858]	valid_0's binary_logloss: 0.193548
# [859]	valid_0's binary_logloss: 0.193543
# [860]	valid_0's binary_logloss: 0.19351
# [861]	valid_0's binary_logloss: 0.193496
# [862]	valid_0's binary_logloss: 0.193485
# [863]	valid_0's binary_logloss: 0.193481
# [864]	valid_0's binary_logloss: 0.193459
# [865]	valid_0's binary_logloss: 0.193455
# [866]	valid_0's binary_logloss: 0.193451
# [867]	valid_0's binary_logloss: 0.193444
# [868]	valid_0's binary_logloss: 0.193438
# [869]	valid_0's binary_logloss: 0.193389
# [870]	valid_0's binary_logloss: 0.193384
# [871]	valid_0's binary_logloss: 0.193305
# [872]	valid_0's binary_logloss: 0.1933
# [873]	valid_0's binary_logloss: 0.193296
# [874]	valid_0's binary_logloss: 0.193274
# [875]	valid_0's binary_logloss: 0.193263
# [876]	valid_0's binary_logloss: 0.193259
# [877]	valid_0's binary_logloss: 0.193201
# [878]	valid_0's binary_logloss: 0.193197
# [879]	valid_0's binary_logloss: 0.193193
# [880]	valid_0's binary_logloss: 0.193169
# [881]	valid_0's binary_logloss: 0.193155
# [882]	valid_0's binary_logloss: 0.193146
# [883]	valid_0's binary_logloss: 0.193142
# [884]	valid_0's binary_logloss: 0.193136
# [885]	valid_0's binary_logloss: 0.193131
# [886]	valid_0's binary_logloss: 0.193125
# [887]	valid_0's binary_logloss: 0.19312
# [888]	valid_0's binary_logloss: 0.193113
# [889]	valid_0's binary_logloss: 0.193109
# [890]	valid_0's binary_logloss: 0.193105
# [891]	valid_0's binary_logloss: 0.193101
# [892]	valid_0's binary_logloss: 0.193097
# [893]	valid_0's binary_logloss: 0.193088
# [894]	valid_0's binary_logloss: 0.193084
# [895]	valid_0's binary_logloss: 0.19308
# [896]	valid_0's binary_logloss: 0.193047
# [897]	valid_0's binary_logloss: 0.193042
# [898]	valid_0's binary_logloss: 0.193018
# [899]	valid_0's binary_logloss: 0.19299
# [900]	valid_0's binary_logloss: 0.192983
# [901]	valid_0's binary_logloss: 0.192948
# [902]	valid_0's binary_logloss: 0.192925
# [903]	valid_0's binary_logloss: 0.19292
# [904]	valid_0's binary_logloss: 0.19289
# [905]	valid_0's binary_logloss: 0.19284
# [906]	valid_0's binary_logloss: 0.192836
# [907]	valid_0's binary_logloss: 0.192828
# [908]	valid_0's binary_logloss: 0.192824
# [909]	valid_0's binary_logloss: 0.19282
# [910]	valid_0's binary_logloss: 0.192815
# [911]	valid_0's binary_logloss: 0.192802
# [912]	valid_0's binary_logloss: 0.19273
# [913]	valid_0's binary_logloss: 0.192724
# [914]	valid_0's binary_logloss: 0.192718
# [915]	valid_0's binary_logloss: 0.192712
# [916]	valid_0's binary_logloss: 0.192708
# [917]	valid_0's binary_logloss: 0.192704
# [918]	valid_0's binary_logloss: 0.1927
# [919]	valid_0's binary_logloss: 0.192654
# [920]	valid_0's binary_logloss: 0.192651
# [921]	valid_0's binary_logloss: 0.192647
# [922]	valid_0's binary_logloss: 0.192636
# [923]	valid_0's binary_logloss: 0.192632
# [924]	valid_0's binary_logloss: 0.192627
# [925]	valid_0's binary_logloss: 0.192574
# [926]	valid_0's binary_logloss: 0.19257
# [927]	valid_0's binary_logloss: 0.192565
# [928]	valid_0's binary_logloss: 0.192557
# [929]	valid_0's binary_logloss: 0.192546
# [930]	valid_0's binary_logloss: 0.192541
# [931]	valid_0's binary_logloss: 0.192537
# [932]	valid_0's binary_logloss: 0.192533
# [933]	valid_0's binary_logloss: 0.192523
# [934]	valid_0's binary_logloss: 0.192516
# [935]	valid_0's binary_logloss: 0.192511
# [936]	valid_0's binary_logloss: 0.192508
# [937]	valid_0's binary_logloss: 0.192503
# [938]	valid_0's binary_logloss: 0.192427
# [939]	valid_0's binary_logloss: 0.1924
# [940]	valid_0's binary_logloss: 0.192396
# [941]	valid_0's binary_logloss: 0.192391
# [942]	valid_0's binary_logloss: 0.192388
# [943]	valid_0's binary_logloss: 0.192378
# [944]	valid_0's binary_logloss: 0.192374
# [945]	valid_0's binary_logloss: 0.192332
# [946]	valid_0's binary_logloss: 0.192322
# [947]	valid_0's binary_logloss: 0.192315
# [948]	valid_0's binary_logloss: 0.192311
# [949]	valid_0's binary_logloss: 0.192282
# [950]	valid_0's binary_logloss: 0.192278
# [951]	valid_0's binary_logloss: 0.19227
# [952]	valid_0's binary_logloss: 0.192264
# [953]	valid_0's binary_logloss: 0.192245
# [954]	valid_0's binary_logloss: 0.192235
# [955]	valid_0's binary_logloss: 0.192231
# [956]	valid_0's binary_logloss: 0.192226
# [957]	valid_0's binary_logloss: 0.192222
# [958]	valid_0's binary_logloss: 0.192218
# [959]	valid_0's binary_logloss: 0.192214
# [960]	valid_0's binary_logloss: 0.192173
# [961]	valid_0's binary_logloss: 0.192169
# [962]	valid_0's binary_logloss: 0.192146
# [963]	valid_0's binary_logloss: 0.192142
# [964]	valid_0's binary_logloss: 0.192136
# [965]	valid_0's binary_logloss: 0.192087
# [966]	valid_0's binary_logloss: 0.192079
# [967]	valid_0's binary_logloss: 0.192075
# [968]	valid_0's binary_logloss: 0.19207
# [969]	valid_0's binary_logloss: 0.192058
# [970]	valid_0's binary_logloss: 0.191996
# [971]	valid_0's binary_logloss: 0.191968
# [972]	valid_0's binary_logloss: 0.191964
# [973]	valid_0's binary_logloss: 0.191946
# [974]	valid_0's binary_logloss: 0.19194
# [975]	valid_0's binary_logloss: 0.191936
# [976]	valid_0's binary_logloss: 0.191932
# [977]	valid_0's binary_logloss: 0.191918
# [978]	valid_0's binary_logloss: 0.191894
# [979]	valid_0's binary_logloss: 0.191882
# [980]	valid_0's binary_logloss: 0.191878
# [981]	valid_0's binary_logloss: 0.191874
# [982]	valid_0's binary_logloss: 0.19187
# [983]	valid_0's binary_logloss: 0.191821
# [984]	valid_0's binary_logloss: 0.191814
# [985]	valid_0's binary_logloss: 0.191805
# [986]	valid_0's binary_logloss: 0.191801
# [987]	valid_0's binary_logloss: 0.191797
# [988]	valid_0's binary_logloss: 0.19179
# [989]	valid_0's binary_logloss: 0.191786
# [990]	valid_0's binary_logloss: 0.191781
# [991]	valid_0's binary_logloss: 0.191778
# [992]	valid_0's binary_logloss: 0.191714
# [993]	valid_0's binary_logloss: 0.191706
# [994]	valid_0's binary_logloss: 0.191643
# [995]	valid_0's binary_logloss: 0.191607
# [996]	valid_0's binary_logloss: 0.191602
# [997]	valid_0's binary_logloss: 0.191596
# [998]	valid_0's binary_logloss: 0.191589
# [999]	valid_0's binary_logloss: 0.191586
# [1000]	valid_0's binary_logloss: 0.191582
# [1001]	valid_0's binary_logloss: 0.191578
# [1002]	valid_0's binary_logloss: 0.191563
# [1003]	valid_0's binary_logloss: 0.191557
# [1004]	valid_0's binary_logloss: 0.191552
# [1005]	valid_0's binary_logloss: 0.191548
# [1006]	valid_0's binary_logloss: 0.191539
# [1007]	valid_0's binary_logloss: 0.191535
# [1008]	valid_0's binary_logloss: 0.191531
# [1009]	valid_0's binary_logloss: 0.191528
# [1010]	valid_0's binary_logloss: 0.191521
# [1011]	valid_0's binary_logloss: 0.191515
# [1012]	valid_0's binary_logloss: 0.191504
# [1013]	valid_0's binary_logloss: 0.191498
# [1014]	valid_0's binary_logloss: 0.19148
# [1015]	valid_0's binary_logloss: 0.191467
# [1016]	valid_0's binary_logloss: 0.191457
# [1017]	valid_0's binary_logloss: 0.191452
# [1018]	valid_0's binary_logloss: 0.191418
# [1019]	valid_0's binary_logloss: 0.19141
# [1020]	valid_0's binary_logloss: 0.191406
# [1021]	valid_0's binary_logloss: 0.191402
# [1022]	valid_0's binary_logloss: 0.19137
# [1023]	valid_0's binary_logloss: 0.191334
# [1024]	valid_0's binary_logloss: 0.191329
# [1025]	valid_0's binary_logloss: 0.191325
# [1026]	valid_0's binary_logloss: 0.191322
# [1027]	valid_0's binary_logloss: 0.191295
# [1028]	valid_0's binary_logloss: 0.191291
# [1029]	valid_0's binary_logloss: 0.191288
# [1030]	valid_0's binary_logloss: 0.191277
# [1031]	valid_0's binary_logloss: 0.191273
# [1032]	valid_0's binary_logloss: 0.19127
# [1033]	valid_0's binary_logloss: 0.191266
# [1034]	valid_0's binary_logloss: 0.191263
# [1035]	valid_0's binary_logloss: 0.191232
# [1036]	valid_0's binary_logloss: 0.191228
# [1037]	valid_0's binary_logloss: 0.191209
# [1038]	valid_0's binary_logloss: 0.191204
# [1039]	valid_0's binary_logloss: 0.191201
# [1040]	valid_0's binary_logloss: 0.191181
# [1041]	valid_0's binary_logloss: 0.191173
# [1042]	valid_0's binary_logloss: 0.191165
# [1043]	valid_0's binary_logloss: 0.191162
# [1044]	valid_0's binary_logloss: 0.191158
# [1045]	valid_0's binary_logloss: 0.191151
# [1046]	valid_0's binary_logloss: 0.191147
# [1047]	valid_0's binary_logloss: 0.191121
# [1048]	valid_0's binary_logloss: 0.191117
# [1049]	valid_0's binary_logloss: 0.191112
# [1050]	valid_0's binary_logloss: 0.191104
# [1051]	valid_0's binary_logloss: 0.191101
# [1052]	valid_0's binary_logloss: 0.191097
# [1053]	valid_0's binary_logloss: 0.191094
# [1054]	valid_0's binary_logloss: 0.191038
# [1055]	valid_0's binary_logloss: 0.191022
# [1056]	valid_0's binary_logloss: 0.191019
# [1057]	valid_0's binary_logloss: 0.191016
# [1058]	valid_0's binary_logloss: 0.191011
# [1059]	valid_0's binary_logloss: 0.191007
# [1060]	valid_0's binary_logloss: 0.190997
# [1061]	valid_0's binary_logloss: 0.190949
# [1062]	valid_0's binary_logloss: 0.190941
# [1063]	valid_0's binary_logloss: 0.190938
# [1064]	valid_0's binary_logloss: 0.190923
# [1065]	valid_0's binary_logloss: 0.190918
# [1066]	valid_0's binary_logloss: 0.190915
# [1067]	valid_0's binary_logloss: 0.190912
# [1068]	valid_0's binary_logloss: 0.190908
# [1069]	valid_0's binary_logloss: 0.190881
# [1070]	valid_0's binary_logloss: 0.190877
# [1071]	valid_0's binary_logloss: 0.190873
# [1072]	valid_0's binary_logloss: 0.19087
# [1073]	valid_0's binary_logloss: 0.190845
# [1074]	valid_0's binary_logloss: 0.190799
# [1075]	valid_0's binary_logloss: 0.190792
# [1076]	valid_0's binary_logloss: 0.19078
# [1077]	valid_0's binary_logloss: 0.190726
# [1078]	valid_0's binary_logloss: 0.19072
# [1079]	valid_0's binary_logloss: 0.190715
# [1080]	valid_0's binary_logloss: 0.190702
# [1081]	valid_0's binary_logloss: 0.190679
# [1082]	valid_0's binary_logloss: 0.190675
# [1083]	valid_0's binary_logloss: 0.190667
# [1084]	valid_0's binary_logloss: 0.190663
# [1085]	valid_0's binary_logloss: 0.190659
# [1086]	valid_0's binary_logloss: 0.19063
# [1087]	valid_0's binary_logloss: 0.190587
# [1088]	valid_0's binary_logloss: 0.190579
# [1089]	valid_0's binary_logloss: 0.190576
# [1090]	valid_0's binary_logloss: 0.190546
# [1091]	valid_0's binary_logloss: 0.190542
# [1092]	valid_0's binary_logloss: 0.190538
# [1093]	valid_0's binary_logloss: 0.190533
# [1094]	valid_0's binary_logloss: 0.190529
# [1095]	valid_0's binary_logloss: 0.190526
# [1096]	valid_0's binary_logloss: 0.190522
# [1097]	valid_0's binary_logloss: 0.190518
# [1098]	valid_0's binary_logloss: 0.190508
# [1099]	valid_0's binary_logloss: 0.190501
# [1100]	valid_0's binary_logloss: 0.190492
# [1101]	valid_0's binary_logloss: 0.190489
# [1102]	valid_0's binary_logloss: 0.190486
# [1103]	valid_0's binary_logloss: 0.19048
# [1104]	valid_0's binary_logloss: 0.190477
# [1105]	valid_0's binary_logloss: 0.190473
# [1106]	valid_0's binary_logloss: 0.190469
# [1107]	valid_0's binary_logloss: 0.190438
# [1108]	valid_0's binary_logloss: 0.190432
# [1109]	valid_0's binary_logloss: 0.190429
# [1110]	valid_0's binary_logloss: 0.190425
# [1111]	valid_0's binary_logloss: 0.190398
# [1112]	valid_0's binary_logloss: 0.190347
# [1113]	valid_0's binary_logloss: 0.190345
# [1114]	valid_0's binary_logloss: 0.19034
# [1115]	valid_0's binary_logloss: 0.190328
# [1116]	valid_0's binary_logloss: 0.190324
# [1117]	valid_0's binary_logloss: 0.190321
# [1118]	valid_0's binary_logloss: 0.190317
# [1119]	valid_0's binary_logloss: 0.19031
# [1120]	valid_0's binary_logloss: 0.190301
# [1121]	valid_0's binary_logloss: 0.190297
# [1122]	valid_0's binary_logloss: 0.190294
# [1123]	valid_0's binary_logloss: 0.190285
# [1124]	valid_0's binary_logloss: 0.190278
# [1125]	valid_0's binary_logloss: 0.190271
# [1126]	valid_0's binary_logloss: 0.190267
# [1127]	valid_0's binary_logloss: 0.190264
# [1128]	valid_0's binary_logloss: 0.190261
# [1129]	valid_0's binary_logloss: 0.190255
# [1130]	valid_0's binary_logloss: 0.190251
# [1131]	valid_0's binary_logloss: 0.190246
# [1132]	valid_0's binary_logloss: 0.190241
# [1133]	valid_0's binary_logloss: 0.190236
# [1134]	valid_0's binary_logloss: 0.190224
# [1135]	valid_0's binary_logloss: 0.190221
# [1136]	valid_0's binary_logloss: 0.190217
# [1137]	valid_0's binary_logloss: 0.190208
# [1138]	valid_0's binary_logloss: 0.19018
# [1139]	valid_0's binary_logloss: 0.190177
# [1140]	valid_0's binary_logloss: 0.190169
# [1141]	valid_0's binary_logloss: 0.19016
# [1142]	valid_0's binary_logloss: 0.190155
# [1143]	valid_0's binary_logloss: 0.190142
# [1144]	valid_0's binary_logloss: 0.190138
# [1145]	valid_0's binary_logloss: 0.190133
# [1146]	valid_0's binary_logloss: 0.190128
# [1147]	valid_0's binary_logloss: 0.190107
# [1148]	valid_0's binary_logloss: 0.19009
# [1149]	valid_0's binary_logloss: 0.190082
# [1150]	valid_0's binary_logloss: 0.190076
# [1151]	valid_0's binary_logloss: 0.19007
# [1152]	valid_0's binary_logloss: 0.190066
# [1153]	valid_0's binary_logloss: 0.190056
# [1154]	valid_0's binary_logloss: 0.190044
# [1155]	valid_0's binary_logloss: 0.190038
# [1156]	valid_0's binary_logloss: 0.190034
# [1157]	valid_0's binary_logloss: 0.190028
# [1158]	valid_0's binary_logloss: 0.190024
# [1159]	valid_0's binary_logloss: 0.19002
# [1160]	valid_0's binary_logloss: 0.190015
# [1161]	valid_0's binary_logloss: 0.19001
# [1162]	valid_0's binary_logloss: 0.189988
# [1163]	valid_0's binary_logloss: 0.189961
# [1164]	valid_0's binary_logloss: 0.189957
# [1165]	valid_0's binary_logloss: 0.189948
# [1166]	valid_0's binary_logloss: 0.18994
# [1167]	valid_0's binary_logloss: 0.189937
# [1168]	valid_0's binary_logloss: 0.18992
# [1169]	valid_0's binary_logloss: 0.189916
# [1170]	valid_0's binary_logloss: 0.189906
# [1171]	valid_0's binary_logloss: 0.189902
# [1172]	valid_0's binary_logloss: 0.189878
# [1173]	valid_0's binary_logloss: 0.189874
# [1174]	valid_0's binary_logloss: 0.189864
# [1175]	valid_0's binary_logloss: 0.189821
# [1176]	valid_0's binary_logloss: 0.189804
# [1177]	valid_0's binary_logloss: 0.189759
# [1178]	valid_0's binary_logloss: 0.189756
# [1179]	valid_0's binary_logloss: 0.18975
# [1180]	valid_0's binary_logloss: 0.189747
# [1181]	valid_0's binary_logloss: 0.189741
# [1182]	valid_0's binary_logloss: 0.189732
# [1183]	valid_0's binary_logloss: 0.189726
# [1184]	valid_0's binary_logloss: 0.189723
# [1185]	valid_0's binary_logloss: 0.189719
# [1186]	valid_0's binary_logloss: 0.18968
# [1187]	valid_0's binary_logloss: 0.189643
# [1188]	valid_0's binary_logloss: 0.18964
# [1189]	valid_0's binary_logloss: 0.189623
# [1190]	valid_0's binary_logloss: 0.189616
# [1191]	valid_0's binary_logloss: 0.189613
# [1192]	valid_0's binary_logloss: 0.18961
# [1193]	valid_0's binary_logloss: 0.189605
# [1194]	valid_0's binary_logloss: 0.189576
# [1195]	valid_0's binary_logloss: 0.189542
# [1196]	valid_0's binary_logloss: 0.189526
# [1197]	valid_0's binary_logloss: 0.189489
# [1198]	valid_0's binary_logloss: 0.189463
# [1199]	valid_0's binary_logloss: 0.189457
# [1200]	valid_0's binary_logloss: 0.189455
# Did not meet early stopping. Best iteration is:
# [1200]	valid_0's binary_logloss: 0.189455

# %%
score=c.roc_auc_score(x_test,y_test)*100
print(score)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-1d3e95a8267b> in <module>()
# ----> 1 score=c.roc_auc_score(x_test,y_test)*100
#       2 print(score)
#
# AttributeError: 'LGBMClassifier' object has no attribute 'roc_auc_score'

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV18.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV18.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion=pd.merge(prediccion,postulaciones_por_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['postulaciones_misma_area']=prediccion['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion['postulaciones_mismo_nivel']=prediccion['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion['postulaciones_mismo_tipo']=prediccion['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado Master      Otro  \
# 57149  62362  1112456072       N01KLJ  MASC  33.0         -      -         -
# 41016  29541  1112372247      lDLGxo6  MASC  19.0         -      -         -
# 51666  20142  1112248723       8k0Kql   FEM  32.0         -      -  En Curso
# 33704  45606  1112428517      wVkARkm  MASC  20.0         -      -         -
# 47075  84361  1112466548      zv6BjOJ  MASC  33.0         -      -  Graduado
# 31622  34807  1112409290      xk94VO0  MASC  34.0         -      -         -
# 39804  63162  1112457309      wVYN9RZ  MASC  22.0         -      -         -
# 67110  13280  1112034433       YWreBY   FEM  32.0         -      -         -
# 68715  52102  1112442467       6krvp4   FEM  42.0         -      -         -
# 36661  85642  1112466646      kP6VEaQ  MASC  24.0         -      -         -
#
#       Posgrado Secundario            ...             remuneracion_pretendida  \
# 57149        -          -            ...                               False
# 41016        -   En Curso            ...                               False
# 51666        -          -            ...                               False
# 33704        -   Graduado            ...                               False
# 47075        -   Graduado            ...                               False
# 31622        -   Graduado            ...                               False
# 39804        -   Graduado            ...                               False
# 67110        -          -            ...                               False
# 68715        -   Graduado            ...                               False
# 36661        -   Graduado            ...                               False
#
#       graduados estudiantes conocimientos_especificos buen_ambiente  \
# 57149     False       False                     False         False
# 41016     False       False                     False         False
# 51666      True       False                     False         False
# 33704     False       False                     False         False
# 47075     False       False                      True         False
# 31622     False       False                      True         False
# 39804     False       False                     False         False
# 67110     False       False                     False         False
# 68715     False       False                     False          True
# 36661     False        True                     False         False
#
#       discriminacion  cantidad postulaciones_misma_area  \
# 57149          False  0.000000                      0.0
# 41016          False  0.000000                      1.0
# 51666          False  0.000000                      0.0
# 33704          False  0.026316                     16.0
# 47075           True  0.000000                    171.0
# 31622           True  0.000000                     18.0
# 39804          False  0.000000                      1.0
# 67110          False  0.000000                      0.0
# 68715          False  0.000000                      0.0
# 36661          False  0.031250                      0.0
#
#        postulaciones_mismo_tipo  postulaciones_mismo_nivel
# 57149                      13.0                        9.0
# 41016                      11.0                       10.0
# 51666                      34.0                        0.0
# 33704                      49.0                       39.0
# 47075                     400.0                      275.0
# 31622                      29.0                       21.0
# 39804                       8.0                        7.0
# 67110                       1.0                        2.0
# 68715                       1.0                        0.0
# 36661                      13.0                        3.0
#
# [10 rows x 39 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.98468452, 0.01531548],
#        [0.91707531, 0.08292469],
#        [0.99507161, 0.00492839],
#        ...,
#        [0.98484307, 0.01515693],
#        [0.98797481, 0.01202519],
#        [0.99410825, 0.00589175]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     graduados estudiantes conocimientos_especificos  \
# 0   Graduado    ...         False       False                     False
# 1          -    ...         False       False                     False
# 2   Graduado    ...         False       False                     False
# 3   Graduado    ...         False       False                     False
# 4          -    ...         False       False                     False
#
#   buen_ambiente discriminacion cantidad postulaciones_misma_area  \
# 0         False          False      0.0                      0.0
# 1         False          False      0.0                      5.0
# 2         False          False      0.0                      2.0
# 3         False          False      0.0                      0.0
# 4         False          False      0.0                      0.0
#
#   postulaciones_mismo_tipo  postulaciones_mismo_nivel  sepostulo
# 0                     13.0                        0.0   0.015315
# 1                     55.0                        0.0   0.082925
# 2                     10.0                        0.0   0.004928
# 3                     12.0                        0.0   0.002338
# 4                     10.0                        0.0   0.000976
#
# [5 rows x 40 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.015315
# 1   1   0.082925
# 2   2   0.004928
# 3   3   0.002338
# 4   4   0.000976

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion36.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.4772061416245788
