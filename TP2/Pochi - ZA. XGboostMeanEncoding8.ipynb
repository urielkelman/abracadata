# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import gc
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score

SAMPLE_SIZE = 0.5
#Caso con edad en mean en vez de 200 para los nan unicamente
#nuevos features
#denominacion empresa mean encoding

# %matplotlib inline

# %%
avisos = pd.read_csv("Data/fiuba_entrenamiento/pocho/avisosONEHOT.csv")
postulaciones = pd.read_csv("Data/fiuba_entrenamiento/pocho/postulaciones.csv")
postulantes = pd.read_csv("Data/fiuba_entrenamiento/pocho/postulantesONEHOT.csv")

avisos['nombre_area']=avisos['nombre_area'].astype('category')
avisos_normales = pd.read_csv("Data/fiuba_entrenamiento/pocho/avisos.csv")
avisos_normales = avisos_normales.loc[:,["nombre_area","idaviso","tipo_de_trabajo","nivel_laboral"]]

vistas = pd.read_csv("Data/fiuba_entrenamiento/pocho/vistas.csv")

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
avisos.denominacion_empresa
# Out:
# 0                                   VENTOR
# 1                      Wurth Argentina S.A
# 2                       ELECTRO OUTLET SRL
# 3                      Wurth Argentina S.A
# 4                      Wurth Argentina S.A
# 5                      Wurth Argentina S.A
# 6        Agencia Oficial Alejandro Arizaga
# 7                                cerantola
# 8                        Hochschild Mining
# 9                               YAMANIL SA
# 10                   Adecco -Región Office
# 11                Romasanta y Asociados SA
# 12                          Bairestron SRL
# 13                          Directway S.A.
# 14                     Wurth Argentina S.A
# 15           SC Johnson & Son de Argentina
# 16                          Unión Personal
# 17                            Motomel S.A.
# 18                          Asoko Tempo SA
# 19                         TELEDIFUSORA SA
# 20                         RE/MAX TITANIUM
# 21                    Grupo Pujol Figueras
# 22                                  VENTOR
# 23                            Food Service
# 24        Nini Centro de Compras Mayorista
# 25                     Wurth Argentina S.A
# 26                              Mimo & Co.
# 27                            BBVA Francés
# 28                                JELS SRL
# 29                      GI GROUP Argentina
#                        ...
# 25258      Onix Human Resources Consulting
# 25259                            Hada Soft
# 25260                            Consignia
# 25261                           Direcciona
# 25262                   GI GROUP Argentina
# 25263                              Frávega
# 25264                           NEW TALENT
# 25265                           NEW TALENT
# 25266                          Back Office
# 25267                              WNPOWER
# 25268              Gestion Compartida S.A.
# 25269                                   CL
# 25270                    Natura Cosméticos
# 25271              Estrategia Laboral S.A.
# 25272              Estrategia Laboral S.A.
# 25273              Estrategia Laboral S.A.
# 25274              Estrategia Laboral S.A.
# 25275              Estrategia Laboral S.A.
# 25276                   Supermercados DIA%
# 25277              Estrategia Laboral S.A.
# 25278                    Banco Columbia SA
# 25279                     HENDEL HOGAR S A
# 25280           Sanatorio Veterinario Glew
# 25281              Gestion Compartida S.A.
# 25282              Gestion Compartida S.A.
# 25283              Gestion Compartida S.A.
# 25284                           NEW TALENT
# 25285              Estrategia Laboral S.A.
# 25286                  NG Estilista Unisex
# 25287              Gestion Compartida S.A.
# Name: denominacion_empresa, Length: 25288, dtype: object

# %%
vistas['cantidad']=0
vistas2=vistas.groupby(['idaviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         1
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         1
# 3   169730       2AKzxa         1
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q         3
# 1        0005E        25
# 2        000R8         4
# 3        001XE        12
# 4        003k9        26

# %%
vistas3=pd.merge(vistas2,vistas,on='idpostulante',how='left')
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           1          20
# 1    48375       RwVdKR           1          10
# 2   169730        1KjXB           1          34
# 3   169730       2AKzxa           1           1
# 4   169730        6LJ64           1          10

# %%
vistas3['cantidad']=vistas3['cantidad_x']/vistas3['cantidad_y']
vistas3.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.050000
# 1    48375       RwVdKR  0.100000
# 2   169730        1KjXB  0.029412
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.100000

# %%
vistas=vistas.rename(columns={'cantidad': 'vistas_postulante'})
vistas2=vistas2.rename(columns={'cantidad': 'vistas_al_aviso'})
vistas_final = pd.merge(vistas3,avisos_normales, on= "idaviso", how = "left")
vistas_final.head()
# Out:
#    idaviso idpostulante  cantidad nombre_area tipo_de_trabajo nivel_laboral
# 0       18        BolNL  0.050000         NaN             NaN           NaN
# 1    48375       RwVdKR  0.100000         NaN             NaN           NaN
# 2   169730        1KjXB  0.029412         NaN             NaN           NaN
# 3   169730       2AKzxa  1.000000         NaN             NaN           NaN
# 4   169730        6LJ64  0.100000         NaN             NaN           NaN

# %%
no_postulaciones = pd.read_csv("Data/fiuba_entrenamiento/pocho/no-postulaciones/azar_total.csv")
postulaciones=postulaciones.append(no_postulaciones.sample(len(postulaciones)*3//4), ignore_index=True)
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
postulaciones = postulaciones.sample(int(round(len(postulaciones)*SAMPLE_SIZE)))
no_postulaciones = 0
gc.collect()
# Out:
# C:\Users\Pocho\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)
# 71

# %%
vistas_final["vistas_por_area"]=0
vistas_final["vistas_por_tipo"]=0
vistas_final["vistas_por_nivel"]=0

vistas_area = vistas_final.groupby(['idpostulante','nombre_area'],as_index=False).agg({'vistas_por_area':'count'})
vistas_tipo= vistas_final.groupby(['idpostulante','tipo_de_trabajo'],as_index=False).agg({'vistas_por_tipo':'count'})
vistas_nivel=vistas_final.groupby(['idpostulante','nivel_laboral'],as_index=False).agg({'vistas_por_nivel':'count'})

vistas_final = 0
gc.collect()
# Out:
# 7

# %%
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones = pd.merge(postulaciones,avisos_normales, on = "idaviso", how = "left")
postulaciones.drop("nombre_area_y", axis = 1, inplace=True)
postulaciones.rename({"nombre_area_x":"nombre_area"},axis=1,inplace=True)
postulaciones=pd.merge(postulaciones,vistas,on=['idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas2,on=['idaviso','idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas3,on=['idaviso','idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,vistas_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,vistas_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['vistas_por_area']=postulaciones['vistas_por_area'].fillna(0)
postulaciones['vistas_por_tipo']=postulaciones['vistas_por_tipo'].fillna(0)
postulaciones['vistas_por_nivel']=postulaciones['vistas_por_tipo'].fillna(0)
postulaciones["vistas_al_aviso"] = postulaciones["vistas_al_aviso"].fillna(0)
postulaciones['lo_vio']=(postulaciones['vistas_al_aviso']>0)
postulaciones.cantidad = postulaciones.cantidad.fillna(0)
postulaciones.vistas_postulante = postulaciones.vistas_postulante.fillna(0)

postulaciones.sample(20)
# Out:
#             idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 4675337  1112160043      JBd1qJE          0  26.0      True      False
# 4996619  1112227997      ekO0e6B          0  18.0      True      False
# 520004   1112447162      Yjr6X0Z          1  32.0      True      False
# 645796   1112369306       54Pozw          1  27.0      True      False
# 2400952  1112308574      LNKVKp5          1  21.0     False       True
# 477797   1112440735      GNJ2Odw          0  34.0     False       True
# 3748534  1112432515      pzd2eYM          0  17.0     False       True
# 2717540  1112299516       a5jYKE          1  35.0     False       True
# 2833917  1112263487      zvPALDb          0  26.0     False       True
# 870944   1112156805      MVP2xN9          1  35.0     False       True
# 5441455  1112049150      DrJp3rA          0  54.0      True      False
# 4769642  1112177785      Bm5e132          1  22.0     False       True
# 4835735  1112490022       5LRNRM          0  41.0      True      False
# 137794   1112312626      ak4Qor0          1  31.0     False       True
# 2358091  1112461175      MVrzl49          1  31.0      True      False
# 4378402  1112325796      ZDrqdW1          0  21.0     False       True
# 3984353  1111822480      MV6Bwdv          1  50.0     False       True
# 468772   1112302327      LN88VMB          0  31.0      True      False
# 122968   1112400993      EzeYkZz          0  57.0      True      False
# 715401   1112328869      pzePmzZ          1  24.0      True      False
#
#          sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 4675337            False                 False               False
# 4996619            False                 False               False
# 520004             False                 False               False
# 645796             False                 False               False
# 2400952            False                 False               False
# 477797             False                 False               False
# 3748534            False                 False               False
# 2717540            False                 False               False
# 2833917            False                 False               False
# 870944             False                 False               False
# 5441455            False                 False               False
# 4769642            False                 False               False
# 4835735            False                 False               False
# 137794             False                 False               False
# 2358091            False                 False               False
# 4378402            False                 False               False
# 3984353            False                 False               False
# 468772             False                 False               False
# 122968             False                 False               False
# 715401             False                 False               False
#
#          Doctorado_Graduado   ...    nivel_laboral_Senior / Semi-Senior  \
# 4675337               False   ...                                  True
# 4996619               False   ...                                 False
# 520004                False   ...                                  True
# 645796                False   ...                                 False
# 2400952               False   ...                                 False
# 477797                False   ...                                  True
# 3748534               False   ...                                  True
# 2717540               False   ...                                 False
# 2833917               False   ...                                  True
# 870944                False   ...                                 False
# 5441455               False   ...                                 False
# 4769642               False   ...                                 False
# 4835735               False   ...                                  True
# 137794                False   ...                                  True
# 2358091               False   ...                                  True
# 4378402               False   ...                                  True
# 3984353               False   ...                                  True
# 468772                False   ...                                  True
# 122968                False   ...                                 False
# 715401                False   ...                                 False
#
#          tipo_de_trabajo                    nivel_laboral  vistas_postulante  \
# 4675337        Full-time             Senior / Semi-Senior                7.0
# 4996619        Full-time                             Otro                0.0
# 520004         Full-time             Senior / Semi-Senior               42.0
# 645796         Full-time                           Junior              173.0
# 2400952        Full-time                           Junior                8.0
# 477797         Full-time             Senior / Semi-Senior                1.0
# 3748534        Full-time             Senior / Semi-Senior                9.0
# 2717540        Full-time  Jefe / Supervisor / Responsable                5.0
# 2833917        Full-time             Senior / Semi-Senior                5.0
# 870944         Part-time                                -                0.0
# 5441455        Full-time  Jefe / Supervisor / Responsable                2.0
# 4769642        Full-time                           Junior               23.0
# 4835735        Full-time             Senior / Semi-Senior               36.0
# 137794         Por Horas             Senior / Semi-Senior                0.0
# 2358091        Full-time             Senior / Semi-Senior                8.0
# 4378402        Full-time             Senior / Semi-Senior                1.0
# 3984353        Full-time             Senior / Semi-Senior               45.0
# 468772         Full-time             Senior / Semi-Senior               11.0
# 122968         Part-time                           Junior               53.0
# 715401         Por Horas                           Junior               44.0
#
#          vistas_al_aviso  cantidad  vistas_por_area  vistas_por_tipo  \
# 4675337              0.0   0.00000              0.0              4.0
# 4996619              0.0   0.00000              0.0              0.0
# 520004               1.0   0.02381              8.0             32.0
# 645796               0.0   0.00000             20.0            146.0
# 2400952              1.0   0.12500              1.0              6.0
# 477797               0.0   0.00000              0.0              1.0
# 3748534              0.0   0.00000              0.0              6.0
# 2717540              0.0   0.00000              2.0              4.0
# 2833917              0.0   0.00000              0.0              4.0
# 870944               0.0   0.00000              0.0              0.0
# 5441455              0.0   0.00000              0.0              1.0
# 4769642              0.0   0.00000              0.0             16.0
# 4835735              0.0   0.00000              0.0             32.0
# 137794               0.0   0.00000              0.0              0.0
# 2358091              1.0   0.12500              1.0              7.0
# 4378402              0.0   0.00000              0.0              1.0
# 3984353              0.0   0.00000             32.0             44.0
# 468772               0.0   0.00000              3.0              2.0
# 122968               0.0   0.00000              0.0             18.0
# 715401               0.0   0.00000              0.0              0.0
#
#          vistas_por_nivel  lo_vio
# 4675337               4.0   False
# 4996619               0.0   False
# 520004               32.0    True
# 645796              146.0   False
# 2400952               6.0    True
# 477797                1.0   False
# 3748534               6.0   False
# 2717540               4.0   False
# 2833917               4.0   False
# 870944                0.0   False
# 5441455               1.0   False
# 4769642              16.0   False
# 4835735              32.0   False
# 137794                0.0   False
# 2358091               7.0    True
# 4378402               1.0   False
# 3984353              44.0   False
# 468772                2.0   False
# 122968               18.0   False
# 715401                0.0   False
#
# [20 rows x 112 columns]

# %%
postulaciones_area = postulaciones.groupby(['idpostulante','nombre_area'],as_index=False).agg({'sepostulo':'count'})
postulaciones_tipo= postulaciones.groupby(['idpostulante','tipo_de_trabajo'],as_index=False).agg({'sepostulo':'count'})
postulaciones_nivel =postulaciones.groupby(['idpostulante','nivel_laboral'],as_index=False).agg({'sepostulo':'count'})
postulaciones_area=postulaciones_area.rename(columns={'sepostulo':'postulaciones_misma_area'})
postulaciones_tipo=postulaciones_tipo.rename(columns={'sepostulo':'postulaciones_mismo_tipo'})
postulaciones_nivel=postulaciones_nivel.rename(columns={'sepostulo':'postulaciones_mismo_nivel'})

# %%
postulaciones.dropna(axis = 1, inplace=True)

# %%
postulaciones_area.head()
# Out:
#   idpostulante           nombre_area  postulaciones_misma_area
# 0      0z5Dmrd             Cadetería                         1
# 1      0z5Dmrd             Comercial                         1
# 2      0z5Dmrd           Facturación                         1
# 3      0z5Dmrd  Ingeniería  Mecánica                         1
# 4      0z5Dmrd                 Otros                         1

# %%
postulaciones=pd.merge(postulaciones,postulaciones_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_nivel,on=['idpostulante','nivel_laboral'],how='left')

postulaciones['postulaciones_misma_area']=postulaciones['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_nivel']=postulaciones['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_tipo']=postulaciones['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones.drop(["tipo_de_trabajo","nivel_laboral"], axis = 1, inplace=True)

# %%
#mean encoding
area_mean = postulaciones.groupby("nombre_area").agg({"sepostulo":"mean"})
area_mean.head()

means = area_mean.to_dict()["sepostulo"]
postulaciones.nombre_area = postulaciones.nombre_area.replace(means)
postulaciones.sample(10)
# Out:
#             idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 212869   1112357659      bOjdZZE          1  35.0     False       True
# 3276723  1112271520       YROLqD          0  39.0     False       True
# 2016560  1111393762      zvP5Nx3          1  26.0      True      False
# 989296   1112461642      6rBr46x          1  25.0      True      False
# 2382477  1112267536      lDLDj03          0  36.0      True      False
# 903545   1112133514      lD5VEGX          0  32.0     False       True
# 3202724  1112368162      wVoxYbB          0  30.0      True      False
# 5175392  1112125908      lD55a6G          0  35.0     False       True
# 5104778  1002519184      BmZXZZw          0  26.0     False       True
# 2573441  1112297413      5mPKPmX          1  53.0     False       True
#
#          sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 212869             False                 False               False
# 3276723            False                 False               False
# 2016560            False                 False               False
# 989296             False                 False               False
# 2382477            False                 False               False
# 903545             False                 False               False
# 3202724            False                 False               False
# 5175392            False                 False               False
# 5104778            False                 False               False
# 2573441            False                 False               False
#
#          Doctorado_Graduado            ...              vistas_postulante  \
# 212869                False            ...                            0.0
# 3276723               False            ...                           21.0
# 2016560               False            ...                           67.0
# 989296                False            ...                            1.0
# 2382477               False            ...                            1.0
# 903545                False            ...                            1.0
# 3202724               False            ...                            5.0
# 5175392               False            ...                            2.0
# 5104778               False            ...                           12.0
# 2573441               False            ...                           25.0
#
#          vistas_al_aviso  cantidad  vistas_por_area  vistas_por_tipo  \
# 212869               0.0  0.000000              0.0              0.0
# 3276723              0.0  0.000000              0.0              1.0
# 2016560              1.0  0.014925              9.0             55.0
# 989296               0.0  0.000000              0.0              1.0
# 2382477              0.0  0.000000              0.0              1.0
# 903545               0.0  0.000000              0.0              1.0
# 3202724              0.0  0.000000              0.0              4.0
# 5175392              0.0  0.000000              0.0              2.0
# 5104778              0.0  0.000000              0.0              0.0
# 2573441              0.0  0.000000             13.0             21.0
#
#          vistas_por_nivel  lo_vio  postulaciones_misma_area  \
# 212869                0.0   False                         9
# 3276723               1.0   False                         0
# 2016560              55.0    True                         1
# 989296                1.0   False                         6
# 2382477               1.0   False                         0
# 903545                1.0   False                         0
# 3202724               4.0   False                         0
# 5175392               2.0   False                         0
# 5104778               0.0   False                         0
# 2573441              21.0   False                         7
#
#          postulaciones_mismo_tipo  postulaciones_mismo_nivel
# 212869                         20                         14
# 3276723                         0                          0
# 2016560                         6                          5
# 989296                         31                          6
# 2382477                         3                          2
# 903545                          2                          0
# 3202724                         3                          5
# 5175392                         6                          6
# 5104778                         0                          8
# 2573441                        17                          2
#
# [10 rows x 113 columns]

# %%
denom_mean = postulaciones.groupby("denominacion_empresa").agg({"sepostulo":"mean"})
means2 = denom_mean.to_dict()["sepostulo"]
postulaciones.denominacion_empresa = postulaciones.denominacion_empresa.replace(means2)
postulaciones.sample(10)
# Out:
#             idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 5063747  1111397672      3NkwVxq          0  24.0     False       True
# 4614672  1112235594      X954Nqd          0  29.0      True      False
# 3086428  1112363383      mzV1ZaO          0  33.0      True      False
# 4276024  1111195487      LNKERYQ          0  18.0     False       True
# 3077747  1112282632       EMjJ0N          1  27.0      True      False
# 2025484  1112364688       YAGBYr          1  41.0      True      False
# 2785671  1112408552      MVPYpw9          0  23.0     False       True
# 630699   1112319620      xkOrBra          1  26.0     False       True
# 4390382  1112447995       ZQJqYb          1  40.0      True      False
# 4329468  1112368442      NzrKAR5          1  30.0     False       True
#
#          sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 5063747            False                 False               False
# 4614672            False                 False               False
# 3086428            False                 False               False
# 4276024            False                 False               False
# 3077747            False                 False               False
# 2025484            False                 False               False
# 2785671            False                 False               False
# 630699             False                 False               False
# 4390382            False                 False               False
# 4329468            False                 False               False
#
#          Doctorado_Graduado            ...              vistas_postulante  \
# 5063747               False            ...                            0.0
# 4614672               False            ...                           14.0
# 3086428               False            ...                           19.0
# 4276024               False            ...                            0.0
# 3077747               False            ...                           33.0
# 2025484               False            ...                           29.0
# 2785671               False            ...                            9.0
# 630699                False            ...                            0.0
# 4390382               False            ...                          112.0
# 4329468               False            ...                            0.0
#
#          vistas_al_aviso  cantidad  vistas_por_area  vistas_por_tipo  \
# 5063747              0.0  0.000000              0.0              0.0
# 4614672              0.0  0.000000              2.0             11.0
# 3086428              0.0  0.000000              0.0             18.0
# 4276024              0.0  0.000000              0.0              0.0
# 3077747              0.0  0.000000              7.0              4.0
# 2025484              1.0  0.034483             11.0             25.0
# 2785671              0.0  0.000000              0.0              9.0
# 630699               0.0  0.000000              0.0              0.0
# 4390382              1.0  0.008929              2.0             93.0
# 4329468              0.0  0.000000              0.0              0.0
#
#          vistas_por_nivel  lo_vio  postulaciones_misma_area  \
# 5063747               0.0   False                         0
# 4614672              11.0   False                         0
# 3086428              18.0   False                         0
# 4276024               0.0   False                         0
# 3077747               4.0   False                        19
# 2025484              25.0    True                         8
# 2785671               9.0   False                         0
# 630699                0.0   False                        26
# 4390382              93.0    True                         1
# 4329468               0.0   False                         4
#
#          postulaciones_mismo_tipo  postulaciones_mismo_nivel
# 5063747                         0                          1
# 4614672                         5                          5
# 3086428                         8                          6
# 4276024                         3                          3
# 3077747                         7                         13
# 2025484                        18                          6
# 2785671                         7                          7
# 630699                         29                          7
# 4390382                        28                         14
# 4329468                         3                          0
#
# [10 rows x 113 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.10)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
#features.remove('denominacion_empresa')
#features.remove("ciudad")
#features.remove("mapacalle")

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']

postulaciones=0

gc.collect()
# Out:
# Train:  5012176 Test:  556909
# 7

# %%
model = XGBClassifier(objective='binary:logistic',max_depth=18,learning_rate=0.07,subsample=0.8,colsample_bytree=0.8,n_estimators=1200,silent=False,n_jobs=-1,verbose=1)
dt=model.fit(x_train,y_train,eval_set=[(x_test,y_test)],verbose=True,early_stopping_rounds=5)
# Out:
# [0]	validation_0-error:0.108414
# Will train until validation_0-error hasn't improved in 5 rounds.
# [1]	validation_0-error:0.101361
# [2]	validation_0-error:0.095955
# [3]	validation_0-error:0.095378
# [4]	validation_0-error:0.093035
# [5]	validation_0-error:0.09143
# [6]	validation_0-error:0.090632
# [7]	validation_0-error:0.089912
# [8]	validation_0-error:0.089445
# [9]	validation_0-error:0.088817
# [10]	validation_0-error:0.088445
# [11]	validation_0-error:0.08816
# [12]	validation_0-error:0.088128
# [13]	validation_0-error:0.087772
# [14]	validation_0-error:0.087427
# [15]	validation_0-error:0.087409
# [16]	validation_0-error:0.087355
# [17]	validation_0-error:0.086772
# [18]	validation_0-error:0.086533
# [19]	validation_0-error:0.086122
# [20]	validation_0-error:0.08579
# [21]	validation_0-error:0.085454
# [22]	validation_0-error:0.085167
# [23]	validation_0-error:0.085037
# [24]	validation_0-error:0.08489
# [25]	validation_0-error:0.084782
# [26]	validation_0-error:0.084574
# [27]	validation_0-error:0.084324
# [28]	validation_0-error:0.08387
# [29]	validation_0-error:0.083735
# [30]	validation_0-error:0.083419
# [31]	validation_0-error:0.083123
# [32]	validation_0-error:0.083014
# [33]	validation_0-error:0.082766
# [34]	validation_0-error:0.082728
# [35]	validation_0-error:0.082534
# [36]	validation_0-error:0.082236
# [37]	validation_0-error:0.082159
# [38]	validation_0-error:0.081985
# [39]	validation_0-error:0.081744
# [40]	validation_0-error:0.081678
# [41]	validation_0-error:0.081397
# [42]	validation_0-error:0.081153
# [43]	validation_0-error:0.081114
# [44]	validation_0-error:0.08101
# [45]	validation_0-error:0.080826
# [46]	validation_0-error:0.08069
# [47]	validation_0-error:0.080376
# [48]	validation_0-error:0.080162
# [49]	validation_0-error:0.080096
# [50]	validation_0-error:0.079832
# [51]	validation_0-error:0.079579
# [52]	validation_0-error:0.079404
# [53]	validation_0-error:0.079255
# [54]	validation_0-error:0.079101
# [55]	validation_0-error:0.078896
# [56]	validation_0-error:0.078835
# [57]	validation_0-error:0.078582
# [58]	validation_0-error:0.078539
# [59]	validation_0-error:0.078343
# [60]	validation_0-error:0.078253
# [61]	validation_0-error:0.078174
# [62]	validation_0-error:0.07811
# [63]	validation_0-error:0.077873
# [64]	validation_0-error:0.077758
# [65]	validation_0-error:0.077673
# [66]	validation_0-error:0.077479
# [67]	validation_0-error:0.077345
# [68]	validation_0-error:0.077181
# [69]	validation_0-error:0.077075
# [70]	validation_0-error:0.077
# [71]	validation_0-error:0.076899
# [72]	validation_0-error:0.076653
# [73]	validation_0-error:0.076456
# [74]	validation_0-error:0.076389
# [75]	validation_0-error:0.076248
# [76]	validation_0-error:0.076093
# [77]	validation_0-error:0.076109
# [78]	validation_0-error:0.075948
# [79]	validation_0-error:0.075774
# [80]	validation_0-error:0.075641
# [81]	validation_0-error:0.075524
# [82]	validation_0-error:0.075438
# [83]	validation_0-error:0.075292
# [84]	validation_0-error:0.075177
# [85]	validation_0-error:0.075124
# [86]	validation_0-error:0.074993
# [87]	validation_0-error:0.074775
# [88]	validation_0-error:0.074664
# [89]	validation_0-error:0.074574
# [90]	validation_0-error:0.074563
# [91]	validation_0-error:0.074342
# [92]	validation_0-error:0.074177
# [93]	validation_0-error:0.074116
# [94]	validation_0-error:0.074014
# [95]	validation_0-error:0.0738
# [96]	validation_0-error:0.073606
# [97]	validation_0-error:0.073606
# [98]	validation_0-error:0.073457
# [99]	validation_0-error:0.073416
# [100]	validation_0-error:0.073337
# [101]	validation_0-error:0.073191
# [102]	validation_0-error:0.073121
# [103]	validation_0-error:0.073012
# [104]	validation_0-error:0.072822
# [105]	validation_0-error:0.072735
# [106]	validation_0-error:0.072619
# [107]	validation_0-error:0.072522
# [108]	validation_0-error:0.072518
# [109]	validation_0-error:0.07236
# [110]	validation_0-error:0.072312
# [111]	validation_0-error:0.072145
# [112]	validation_0-error:0.072008
# [113]	validation_0-error:0.071865
# [114]	validation_0-error:0.071496
# [115]	validation_0-error:0.071356
# [116]	validation_0-error:0.07134
# [117]	validation_0-error:0.071247
# [118]	validation_0-error:0.071083
# [119]	validation_0-error:0.070995
# [120]	validation_0-error:0.070927
# [121]	validation_0-error:0.070925
# [122]	validation_0-error:0.070924
# [123]	validation_0-error:0.070913
# [124]	validation_0-error:0.070606
# [125]	validation_0-error:0.070475
# [126]	validation_0-error:0.070358
# [127]	validation_0-error:0.07034
# [128]	validation_0-error:0.070207
# [129]	validation_0-error:0.070058
# [130]	validation_0-error:0.069958
# [131]	validation_0-error:0.06985
# [132]	validation_0-error:0.069789
# [133]	validation_0-error:0.069713
# [134]	validation_0-error:0.069704
# [135]	validation_0-error:0.069595
# [136]	validation_0-error:0.069606
# [137]	validation_0-error:0.06943
# [138]	validation_0-error:0.069406
# [139]	validation_0-error:0.069297
# [140]	validation_0-error:0.069273
# [141]	validation_0-error:0.06909
# [142]	validation_0-error:0.069018
# [143]	validation_0-error:0.068882
# [144]	validation_0-error:0.068794
# [145]	validation_0-error:0.068667
# [146]	validation_0-error:0.068643
# [147]	validation_0-error:0.068632
# [148]	validation_0-error:0.068604
# [149]	validation_0-error:0.068471
# [150]	validation_0-error:0.068523
# [151]	validation_0-error:0.068419
# [152]	validation_0-error:0.068367
# [153]	validation_0-error:0.068343
# [154]	validation_0-error:0.068297
# [155]	validation_0-error:0.068246
# [156]	validation_0-error:0.068194
# [157]	validation_0-error:0.068137
# [158]	validation_0-error:0.068092
# [159]	validation_0-error:0.06807
# [160]	validation_0-error:0.068025
# [161]	validation_0-error:0.068047
# [162]	validation_0-error:0.068022
# [163]	validation_0-error:0.068013
# [164]	validation_0-error:0.06785
# [165]	validation_0-error:0.067733
# [166]	validation_0-error:0.067638
# [167]	validation_0-error:0.067638
# [168]	validation_0-error:0.067598
# [169]	validation_0-error:0.0676
# [170]	validation_0-error:0.067528
# [171]	validation_0-error:0.067496
# [172]	validation_0-error:0.06741
# [173]	validation_0-error:0.067406
# [174]	validation_0-error:0.067356
# [175]	validation_0-error:0.067332
# [176]	validation_0-error:0.0673
# [177]	validation_0-error:0.067138
# [178]	validation_0-error:0.067104
# [179]	validation_0-error:0.067011
# [180]	validation_0-error:0.067022
# [181]	validation_0-error:0.066988
# [182]	validation_0-error:0.066991
# [183]	validation_0-error:0.066896
# [184]	validation_0-error:0.066817
# [185]	validation_0-error:0.066772
# [186]	validation_0-error:0.066733
# [187]	validation_0-error:0.066584
# [188]	validation_0-error:0.066555
# [189]	validation_0-error:0.066418
# [190]	validation_0-error:0.066379
# [191]	validation_0-error:0.066352
# [192]	validation_0-error:0.066359
# [193]	validation_0-error:0.066298
# [194]	validation_0-error:0.06626
# [195]	validation_0-error:0.066244
# [196]	validation_0-error:0.066189
# [197]	validation_0-error:0.066165
# [198]	validation_0-error:0.066133
# [199]	validation_0-error:0.066129
# [200]	validation_0-error:0.066124
# [201]	validation_0-error:0.066068
# [202]	validation_0-error:0.066025
# [203]	validation_0-error:0.066032
# [204]	validation_0-error:0.06595
# [205]	validation_0-error:0.065873
# [206]	validation_0-error:0.065788
# [207]	validation_0-error:0.065795
# [208]	validation_0-error:0.06572
# [209]	validation_0-error:0.065698
# [210]	validation_0-error:0.0657
# [211]	validation_0-error:0.065671
# [212]	validation_0-error:0.06563
# [213]	validation_0-error:0.06561
# [214]	validation_0-error:0.065621
# [215]	validation_0-error:0.065594
# [216]	validation_0-error:0.065535
# [217]	validation_0-error:0.065494
# [218]	validation_0-error:0.065499
# [219]	validation_0-error:0.065456
# [220]	validation_0-error:0.065355
# [221]	validation_0-error:0.065336
# [222]	validation_0-error:0.065345
# [223]	validation_0-error:0.065336
# [224]	validation_0-error:0.065237
# [225]	validation_0-error:0.065136
# [226]	validation_0-error:0.065111
# [227]	validation_0-error:0.065122
# [228]	validation_0-error:0.065111
# [229]	validation_0-error:0.065079
# [230]	validation_0-error:0.065043
# [231]	validation_0-error:0.065032
# [232]	validation_0-error:0.064964
# [233]	validation_0-error:0.064946
# [234]	validation_0-error:0.064917
# [235]	validation_0-error:0.064928
# [236]	validation_0-error:0.06491
# [237]	validation_0-error:0.064921
# [238]	validation_0-error:0.06493
# [239]	validation_0-error:0.064917
# [240]	validation_0-error:0.064881
# [241]	validation_0-error:0.064835
# [242]	validation_0-error:0.064849
# [243]	validation_0-error:0.064811
# [244]	validation_0-error:0.064788
# [245]	validation_0-error:0.06481
# [246]	validation_0-error:0.064757
# [247]	validation_0-error:0.064765
# [248]	validation_0-error:0.064756
# [249]	validation_0-error:0.064774
# [250]	validation_0-error:0.064711
# [251]	validation_0-error:0.064666
# [252]	validation_0-error:0.064677
# [253]	validation_0-error:0.064666
# [254]	validation_0-error:0.064644
# [255]	validation_0-error:0.064628
# [256]	validation_0-error:0.064576
# [257]	validation_0-error:0.064531
# [258]	validation_0-error:0.064571
# [259]	validation_0-error:0.064549
# [260]	validation_0-error:0.064549
# [261]	validation_0-error:0.064531
# [262]	validation_0-error:0.064528
# [263]	validation_0-error:0.064501
# [264]	validation_0-error:0.064425
# [265]	validation_0-error:0.064379
# [266]	validation_0-error:0.064425
# [267]	validation_0-error:0.064452
# [268]	validation_0-error:0.064418
# [269]	validation_0-error:0.064361
# [270]	validation_0-error:0.064346
# [271]	validation_0-error:0.064344
# [272]	validation_0-error:0.064352
# [273]	validation_0-error:0.064326
# [274]	validation_0-error:0.064307
# [275]	validation_0-error:0.0643
# [276]	validation_0-error:0.064298
# [277]	validation_0-error:0.064255
# [278]	validation_0-error:0.064267
# [279]	validation_0-error:0.064246
# [280]	validation_0-error:0.064249
# [281]	validation_0-error:0.064219
# [282]	validation_0-error:0.064208
# [283]	validation_0-error:0.064147
# [284]	validation_0-error:0.064195
# [285]	validation_0-error:0.064181
# [286]	validation_0-error:0.06414
# [287]	validation_0-error:0.064098
# [288]	validation_0-error:0.064143
# [289]	validation_0-error:0.064124
# [290]	validation_0-error:0.064109
# [291]	validation_0-error:0.064107
# [292]	validation_0-error:0.064098
# Stopping. Best iteration:
# [287]	validation_0-error:0.064098

# %%
from sklearn.metrics import roc_auc_score
x_final=x_test[features]
y_final=model.predict_proba(x_final)
y_pred=[]
for elem in y_final:
    y_pred.append(elem[1])
score=roc_auc_score(y_test, y_pred)
print(score)
# Out:
# 0.9834769474279553

# %%
print("dale mono")
# Out:
# dale mono

# %%
joblib.dump(model, "Data/fiuba_entrenamiento/pocho/modelos/XGBoostMean8.pkl")
# Out:
# ['Data/fiuba_entrenamiento/pocho/modelos/XGBoostMean8.pkl']

# %%
prediccion = pd.read_csv("Data/fiuba_entrenamiento/test_final_100k.csv")
prediccion = pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
prediccion = pd.merge(prediccion,avisos,on='idaviso',how='inner')
prediccion = pd.merge(prediccion,avisos_normales,on='idaviso',how='inner')
prediccion.drop("nombre_area_y", axis = 1, inplace=True)
prediccion.rename({"nombre_area_x":"nombre_area"},axis=1,inplace=True)

prediccion = pd.merge(prediccion,vistas,on='idpostulante',how='left')
prediccion.sample(10)


prediccion=pd.merge(prediccion,vistas2,on=['idaviso','idpostulante'],how='left')
prediccion=pd.merge(prediccion,vistas3,on=['idaviso','idpostulante'],how='left')
prediccion['cantidad']=prediccion['cantidad'].fillna(0)
prediccion['vistas_postulante']=prediccion['vistas_postulante'].fillna(0)
prediccion['vistas_al_aviso']=prediccion['vistas_al_aviso'].fillna(0)
prediccion['lo_vio']=(prediccion['vistas_al_aviso']>0)

prediccion=pd.merge(prediccion,postulaciones_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,postulaciones_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,postulaciones_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion=pd.merge(prediccion,vistas_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,vistas_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,vistas_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['vistas_por_area']=prediccion['vistas_por_area'].fillna(0)
prediccion['vistas_por_tipo']=prediccion['vistas_por_tipo'].fillna(0)
prediccion['vistas_por_nivel']=prediccion['vistas_por_tipo'].fillna(0)
prediccion['postulaciones_misma_area']=prediccion['postulaciones_misma_area'].fillna(0)
prediccion['postulaciones_mismo_nivel']=prediccion['postulaciones_mismo_nivel'].fillna(0)
prediccion['postulaciones_mismo_tipo']=prediccion['postulaciones_mismo_tipo'].fillna(0)
prediccion.nombre_area = prediccion.nombre_area.replace(means)
prediccion.denominacion_empresa = prediccion.denominacion_empresa.replace(means2)
prediccion.sample(10)
# Out:
#           id     idaviso idpostulante  edad  sexo_FEM  sexo_MASC  \
# 15490  66441  1112459541      PmJDqe1  19.0     False       True
# 62820  10451  1111913263       6o2lmx  34.0      True      False
# 86043  38784  1112415933       YN3reP  45.0     False       True
# 36095  69112  1112461076       ZlJ5L8  35.0      True      False
# 17656  72682  1112463155      rmv2VoQ  26.0      True      False
# 69422  15005  1112113451       NDP9NL  32.0      True      False
# 29299  52792  1112444023      MVr0BVK  21.0     False       True
# 25846  87068  1112466773      VNxez0m  48.0     False       True
# 26821  88836  1112467018       5oWMkZ  35.0      True      False
# 80601  28088  1112358506       E89Opo  39.0     False       True
#
#        sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 15490            False                 False               False
# 62820            False                 False               False
# 86043            False                 False               False
# 36095            False                 False               False
# 17656            False                 False               False
# 69422            False                 False               False
# 29299            False                 False               False
# 25846            False                 False               False
# 26821            False                 False               False
# 80601            False                 False               False
#
#        Doctorado_Graduado        ...         vistas_postulante  \
# 15490               False        ...                     214.0
# 62820               False        ...                      27.0
# 86043               False        ...                      14.0
# 36095               False        ...                      26.0
# 17656               False        ...                       0.0
# 69422               False        ...                       3.0
# 29299               False        ...                       3.0
# 25846               False        ...                       0.0
# 26821               False        ...                      11.0
# 80601               False        ...                       5.0
#
#        vistas_al_aviso  cantidad  lo_vio  postulaciones_misma_area  \
# 15490              1.0  0.004673    True                       0.0
# 62820              0.0  0.000000   False                       0.0
# 86043              0.0  0.000000   False                       1.0
# 36095              1.0  0.038462    True                       0.0
# 17656              0.0  0.000000   False                       6.0
# 69422              0.0  0.000000   False                       1.0
# 29299              0.0  0.000000   False                      11.0
# 25846              0.0  0.000000   False                      14.0
# 26821              1.0  0.090909    True                       2.0
# 80601              0.0  0.000000   False                       0.0
#
#        postulaciones_mismo_tipo  postulaciones_mismo_nivel  vistas_por_area  \
# 15490                      41.0                       31.0              1.0
# 62820                       5.0                        5.0              0.0
# 86043                      16.0                       14.0              0.0
# 36095                       2.0                        2.0              9.0
# 17656                       9.0                       23.0              0.0
# 69422                       4.0                        5.0              0.0
# 29299                      19.0                       16.0              1.0
# 25846                      25.0                        9.0              0.0
# 26821                       4.0                        7.0              2.0
# 80601                      13.0                       13.0              0.0
#
#        vistas_por_tipo  vistas_por_nivel
# 15490            124.0             124.0
# 62820             16.0              16.0
# 86043             12.0              12.0
# 36095             18.0              18.0
# 17656              0.0               0.0
# 69422              2.0               2.0
# 29299              1.0               1.0
# 25846              0.0               0.0
# 26821              6.0               6.0
# 80601              5.0               5.0
#
# [10 rows x 115 columns]

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  edad  sexo_FEM  sexo_MASC  sexo_NO_DECLARA  \
# 0   0   739260       6M9ZQR  42.0      True      False            False
# 1   1   739260       6v1xdL  31.0     False       True            False
# 2   2   739260       ezRKm9  36.0      True      False            False
# 3   3   758580       1Q35ej  68.0     False       True            False
# 4   4   758580       EAN4J6  32.0      True      False            False
#
#    Doctorado_Abandonado  Doctorado_En Curso  Doctorado_Graduado  \
# 0                 False               False                True
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 4                 False               False               False
#
#          ...         vistas_postulante  vistas_al_aviso  cantidad  lo_vio  \
# 0        ...                      26.0              0.0       0.0   False
# 1        ...                       4.0              0.0       0.0   False
# 2        ...                      10.0              0.0       0.0   False
# 3        ...                       0.0              0.0       0.0   False
# 4        ...                       1.0              0.0       0.0   False
#
#    postulaciones_misma_area  postulaciones_mismo_tipo  \
# 0                       0.0                       4.0
# 1                       3.0                      29.0
# 2                       0.0                       9.0
# 3                       0.0                       3.0
# 4                       1.0                       8.0
#
#    postulaciones_mismo_nivel  vistas_por_area  vistas_por_tipo  \
# 0                        1.0              3.0             20.0
# 1                        0.0              0.0              3.0
# 2                        1.0              1.0              6.0
# 3                        1.0              0.0              0.0
# 4                        0.0              0.0              1.0
#
#    vistas_por_nivel
# 0              20.0
# 1               3.0
# 2               6.0
# 3               0.0
# 4               1.0
#
# [5 rows x 115 columns]

# %%
x_final=prediccion[features]
y_final=model.predict_proba(x_final)
y_final2=[]
print(model.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))

prediccion['sepostulo']=y_final2
prediccion.head()
# Out:
# [0 1]
# 100000
# 100000
#    id  idaviso idpostulante  edad  sexo_FEM  sexo_MASC  sexo_NO_DECLARA  \
# 0   0   739260       6M9ZQR  42.0      True      False            False
# 1   1   739260       6v1xdL  31.0     False       True            False
# 2   2   739260       ezRKm9  36.0      True      False            False
# 3   3   758580       1Q35ej  68.0     False       True            False
# 4   4   758580       EAN4J6  32.0      True      False            False
#
#    Doctorado_Abandonado  Doctorado_En Curso  Doctorado_Graduado    ...      \
# 0                 False               False                True    ...
# 1                 False               False               False    ...
# 2                 False               False               False    ...
# 3                 False               False               False    ...
# 4                 False               False               False    ...
#
#    vistas_al_aviso  cantidad  lo_vio  postulaciones_misma_area  \
# 0              0.0       0.0   False                       0.0
# 1              0.0       0.0   False                       3.0
# 2              0.0       0.0   False                       0.0
# 3              0.0       0.0   False                       0.0
# 4              0.0       0.0   False                       1.0
#
#    postulaciones_mismo_tipo  postulaciones_mismo_nivel  vistas_por_area  \
# 0                       4.0                        1.0              3.0
# 1                      29.0                        0.0              0.0
# 2                       9.0                        1.0              1.0
# 3                       3.0                        1.0              0.0
# 4                       8.0                        0.0              0.0
#
#    vistas_por_tipo  vistas_por_nivel  sepostulo
# 0             20.0              20.0   0.025413
# 1              3.0               3.0   0.149005
# 2              6.0               6.0   0.150898
# 3              0.0               0.0   0.002785
# 4              1.0               1.0   0.003579
#
# [5 rows x 116 columns]

# %%
prediccion=prediccion[['id','sepostulo']]
print(prediccion.sepostulo.mean())
prediccion.head()
# Out:
# 0.49386143934388754
#    id  sepostulo
# 0   0   0.025413
# 1   1   0.149005
# 2   2   0.150898
# 3   3   0.002785
# 4   4   0.003579

# %%
prediccion.to_csv("Data/fiuba_entrenamiento/pocho/predicciones/xgbmean8.csv",index=False)
