# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc
from lightgbm import LGBMClassifier



SAMPLE_SIZE = 0.5
# %matplotlib inline

# %%
from sklearn.metrics import roc_auc_score
from sklearn.naive_bayes import GaussianNB
import random
import gc
class RandomLightGBM:

    
    def __init__(self,  n_iterations, n_features, retries, subset_sample, verbose, meta_parameters = []):
        self.n_iterations=n_iterations
        self.n_features=n_features
        self.retries=retries
        self.subset_sample=subset_sample
        self.verbose=verbose
        self.LGBMs = []
        self.chosen_features=[]
        self.meta_parameters = meta_parameters
    
    
    def roc_auc_score(self, test, to_predict):
        y_test=test[to_predict]
        return roc_auc_score(y_test, self.predict_proba_class(1,test))
    
    def predict_proba_class(self,number,data):
        n_models = len(self.LGBMs)
        if(n_models == 0):
            raise Exception('No naive bayes has been trained.')
        preds=[]
        for i in range(0,n_models):
            y=self.LGBMs[i].predict_proba(data[self.chosen_features[i]])
            y_pred=[]
            for elem in y:
                y_pred.append(elem[number])
            preds.append(y_pred)
            
        y_pred=[sum(x) for x in zip(*preds)]
        y_pred=[i / n_models for i in y_pred]
        return y_pred
    
    def score_iteration(self,train,features,to_predict):
        #TODO: Configurar para pasarle metaparametros
        c=LGBMClassifier(learning_rate=0.05,objective='binary',num_leaves=300,max_depth=9,n_estimators=1000,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)
        subsample=train.sample(int(round(len(train)*self.subset_sample)))
        c.fit(subsample[features],subsample[to_predict])
        self.LGBMs.append(c)
        self.chosen_features.append(features)
        return self.roc_auc_score(test,to_predict)
        
    def fit(self,train, test, to_predict, features):
        best=0
        
        #Por cada iteracion, entrena un clasificador LGBM con los meta parametros, un subsample aleatorio del set de entrenamiento
        #de tamano subsample y compara los scores
        for i in range(1,self.n_iterations+1):
            features_aux=[]
            for j in range(0,self.n_features):
                feat = random.choice(features)
                if(feat not in features_aux): features_aux.append(feat)
               
            if(self.verbose):
                print("Iteration "+str(i)+" with features "+str(features_aux))
            score = self.score_iteration(train,features_aux,to_predict)
            if(self.verbose):
                print("Score: "+str(score)+" with features "+str(features_aux))
           
            if(score<=best):
                for k in range(0,self.retries):
                    features_aux=[]
                    self.LGBMs.pop()
                    self.chosen_features.pop()
                    for j in range(0,self.n_features*i):
                        feat = random.choice(features)
                        if(feat not in features_aux): features_aux.append(feat)
                    score = self.score_iteration(train,features_aux,to_predict)
                    if(self.verbose):
                        print("Retry number "+str(k+1)+" with score: "+str(score)+" and features: "+str(features_aux))
                    if(score>best):
                        break
            if(score<=best):
                self.LGBMs.pop()
                self.chosen_features.pop()
                print("Stopping")
                return;
            best=score
            subsample=0
            gc.collect()

# %%
avisos = pd.read_csv("Data/fiuba_entrenamiento/pocho/avisos.csv")
postulaciones = pd.read_csv("Data/fiuba_entrenamiento/pocho/postulaciones.csv")
postulantes = pd.read_csv("Data/fiuba_entrenamiento/pocho/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

vistas = pd.read_csv("Data/fiuba_entrenamiento/pocho/vistas.csv")

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas['cantidad']=0
vistas2=vistas.groupby(['idaviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         1
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         1
# 3   169730       2AKzxa         1
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q         3
# 1        0005E        25
# 2        000R8         4
# 3        001XE        12
# 4        003k9        26

# %%
vistas3=pd.merge(vistas2,vistas,on='idpostulante',how='left')
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           1          20
# 1    48375       RwVdKR           1          10
# 2   169730        1KjXB           1          34
# 3   169730       2AKzxa           1           1
# 4   169730        6LJ64           1          10

# %%
vistas3['cantidad']=vistas3['cantidad_x']/vistas3['cantidad_y']
vistas3.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.050000
# 1    48375       RwVdKR  0.100000
# 2   169730        1KjXB  0.029412
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.100000

# %%
vistas=vistas.rename(columns={'cantidad': 'vistas_postulante'})
vistas2=vistas2.rename(columns={'cantidad': 'vistas_al_aviso'})
vistas_final = pd.merge(vistas3,avisos, on= "idaviso", how = "left")
vistas_final.head()
# Out:
#    idaviso idpostulante  cantidad titulo nombre_zona tipo_de_trabajo  \
# 0       18        BolNL  0.050000    NaN         NaN             NaN
# 1    48375       RwVdKR  0.100000    NaN         NaN             NaN
# 2   169730        1KjXB  0.029412    NaN         NaN             NaN
# 3   169730       2AKzxa  1.000000    NaN         NaN             NaN
# 4   169730        6LJ64  0.100000    NaN         NaN             NaN
#
#   nivel_laboral nombre_area denominacion_empresa titulo_uppercase  \
# 0           NaN         NaN                  NaN              NaN
# 1           NaN         NaN                  NaN              NaN
# 2           NaN         NaN                  NaN              NaN
# 3           NaN         NaN                  NaN              NaN
# 4           NaN         NaN                  NaN              NaN
#
#        ...      estudiantes conocimientos_especificos  buen_ambiente  \
# 0      ...              NaN                       NaN            NaN
# 1      ...              NaN                       NaN            NaN
# 2      ...              NaN                       NaN            NaN
# 3      ...              NaN                       NaN            NaN
# 4      ...              NaN                       NaN            NaN
#
#   indica_sueldo part_time full_time ofrece_crecimiento ofrece_beneficios  \
# 0           NaN       NaN       NaN                NaN               NaN
# 1           NaN       NaN       NaN                NaN               NaN
# 2           NaN       NaN       NaN                NaN               NaN
# 3           NaN       NaN       NaN                NaN               NaN
# 4           NaN       NaN       NaN                NaN               NaN
#
#   obra_social multinacional
# 0         NaN           NaN
# 1         NaN           NaN
# 2         NaN           NaN
# 3         NaN           NaN
# 4         NaN           NaN
#
# [5 rows x 36 columns]

# %%
no_postulaciones = pd.read_csv("Data/fiuba_entrenamiento/pocho/no-postulaciones/azar_total.csv")
postulaciones=postulaciones.append(no_postulaciones, ignore_index=True)
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
postulaciones = postulaciones.sample(int(round(len(postulaciones)*SAMPLE_SIZE)))
no_postulaciones = 0
gc.collect()
# Out:
# 945

# %%
vistas_final["vistas_por_area"]=0
vistas_final["vistas_por_tipo"]=0
vistas_final["vistas_por_nivel"]=0

vistas_area = vistas_final.groupby(['idpostulante','nombre_area'],as_index=False).agg({'vistas_por_area':'count'})
vistas_tipo= vistas_final.groupby(['idpostulante','tipo_de_trabajo'],as_index=False).agg({'vistas_por_tipo':'count'})
vistas_nivel=vistas_final.groupby(['idpostulante','nivel_laboral'],as_index=False).agg({'vistas_por_nivel':'count'})

vistas_final = 0
gc.collect()
# Out:
# 126

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas2,on=['idaviso','idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas3,on=['idaviso','idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,vistas_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,vistas_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['vistas_por_area']=postulaciones['vistas_por_area'].fillna(0)
postulaciones['vistas_por_tipo']=postulaciones['vistas_por_tipo'].fillna(0)
postulaciones['vistas_por_nivel']=postulaciones['vistas_por_tipo'].fillna(0)
postulaciones["vistas_al_aviso"] = postulaciones["vistas_al_aviso"].fillna(0)
postulaciones['lo_vio']=(postulaciones['vistas_al_aviso']>0)


postulaciones.sample(20)
# Out:
#             idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 1988416  1112366912       YNaqNw          0  MASC  45.0         -      -
# 3143536  1112393194      6rPJ3oj          1  MASC  19.0         -      -
# 5164511  1111947372      ekOOZd8          1  MASC  29.0         -      -
# 5864248  1112206351      4rPRr2e          0  MASC  29.0         -      -
# 2626116  1112358080       6aGWNv          1  MASC  30.0         -      -
# 5140718  1112275218      xkvX6p0          1  MASC  20.0         -      -
# 2994678  1112431054      X9x5X08          1   FEM  38.0         -      -
# 4634912  1112445434      96M6d69          0  MASC  57.0         -      -
# 1909303  1112283238      3NP1w6X          1   FEM  48.0         -      -
# 2542193  1112386877      ZDPm6Kb          1  MASC  27.0         -      -
# 3958924  1112441852      akjXo4m          0   FEM  35.0         -      -
# 1848901  1112301112      2zwX8PV          0  MASC  21.0  En Curso      -
# 1451172  1112327287      96MeorZ          1   FEM  22.0         -      -
# 5742687  1112336441      vV9BQWe          0  MASC  26.0         -      -
# 890251   1112295719       533LPM          0   FEM  31.0         -      -
# 2251035  1112455132      ow2RGmk          0   FEM  23.0         -      -
# 3002063  1112372065      VNJRrxR          1  MASC  21.0         -      -
# 1585002  1112391090       Y58rwJ          1  MASC  31.0         -      -
# 781687   1112397496       ZZ0e9b          1   FEM  40.0         -      -
# 2907810  1111533977      PmawZmj          0  MASC  25.0         -      -
#
#              Otro Posgrado Secundario   ...   ofrece_beneficios obra_social  \
# 1988416         -        -          -   ...               False       False
# 3143536         -        -   Graduado   ...               False       False
# 5164511         -        -          -   ...               False       False
# 5864248         -        -   Graduado   ...               False       False
# 2626116         -        -          -   ...               False       False
# 5140718         -        -   Graduado   ...               False       False
# 2994678  En Curso        -   Graduado   ...                True       False
# 4634912         -        -          -   ...               False       False
# 1909303         -        -          -   ...               False       False
# 2542193         -        -   Graduado   ...               False       False
# 3958924         -        -   Graduado   ...               False       False
# 1848901         -        -   En Curso   ...                True        True
# 1451172         -        -   Graduado   ...               False       False
# 5742687         -        -   Graduado   ...               False       False
# 890251   Graduado        -   Graduado   ...               False       False
# 2251035         -        -          -   ...                True        True
# 3002063         -        -          -   ...               False       False
# 1585002         -        -   Graduado   ...               False       False
# 781687          -        -          -   ...               False       False
# 2907810         -        -   Graduado   ...               False       False
#
#         multinacional vistas_postulante vistas_al_aviso  cantidad  \
# 1988416         False              39.0             0.0       NaN
# 3143536          True               9.0             0.0       NaN
# 5164511          True              52.0             0.0       NaN
# 5864248         False              10.0             0.0       NaN
# 2626116          True              39.0             0.0       NaN
# 5140718         False               NaN             0.0       NaN
# 2994678         False             148.0             1.0  0.006757
# 4634912         False               2.0             0.0       NaN
# 1909303         False               5.0             0.0       NaN
# 2542193         False              41.0             1.0  0.024390
# 3958924         False              19.0             0.0       NaN
# 1848901          True               1.0             0.0       NaN
# 1451172         False              18.0             0.0       NaN
# 5742687         False               2.0             0.0       NaN
# 890251          False               6.0             0.0       NaN
# 2251035         False               7.0             0.0       NaN
# 3002063         False               2.0             0.0       NaN
# 1585002         False              48.0             0.0       NaN
# 781687          False              29.0             0.0       NaN
# 2907810         False               NaN             0.0       NaN
#
#         vistas_por_area vistas_por_tipo  vistas_por_nivel  lo_vio
# 1988416             0.0            29.0              29.0   False
# 3143536             1.0             2.0               2.0   False
# 5164511             1.0            31.0              31.0   False
# 5864248             0.0            10.0              10.0   False
# 2626116             4.0            35.0              35.0   False
# 5140718             0.0             0.0               0.0   False
# 2994678             2.0           102.0             102.0    True
# 4634912             0.0             2.0               2.0   False
# 1909303             2.0             4.0               4.0   False
# 2542193             7.0            39.0              39.0    True
# 3958924             0.0            12.0              12.0   False
# 1848901             0.0             0.0               0.0   False
# 1451172             1.0            18.0              18.0   False
# 5742687             0.0             1.0               1.0   False
# 890251              0.0             6.0               6.0   False
# 2251035             0.0             4.0               4.0   False
# 3002063             0.0             2.0               2.0   False
# 1585002            10.0            44.0              44.0   False
# 781687              4.0            19.0              19.0   False
# 2907810             0.0             0.0               0.0   False
#
# [20 rows x 52 columns]

# %%
postulaciones_area = postulaciones.groupby(['idpostulante','nombre_area'],as_index=False).agg({'sepostulo':'count'})
postulaciones_tipo= postulaciones.groupby(['idpostulante','tipo_de_trabajo'],as_index=False).agg({'sepostulo':'count'})
postulaciones_nivel =postulaciones.groupby(['idpostulante','nivel_laboral'],as_index=False).agg({'sepostulo':'count'})
postulaciones_area=postulaciones_area.rename(columns={'sepostulo':'postulaciones_misma_area'})
postulaciones_tipo=postulaciones_tipo.rename(columns={'sepostulo':'postulaciones_mismo_tipo'})
postulaciones_nivel=postulaciones_nivel.rename(columns={'sepostulo':'postulaciones_mismo_nivel'})

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo  sexo  edad Doctorado Master      Otro  \
# 0  1112271497      zv642lk          1   FEM  32.0         -      -         -
# 1  1112271497      X9xaNv8          1   FEM  41.0         -      -         -
# 2  1112271497      6rQdqjl          1  MASC  32.0         -      -         -
# 3  1112271497       ar8OeE          1  MASC  38.0         -      -         -
# 4  1112271497      5mraqEZ          1  MASC  28.0         -      -  Graduado
#
#    Posgrado Secundario   ...   ofrece_beneficios obra_social multinacional  \
# 0  Graduado   Graduado   ...               False       False         False
# 1  Graduado          -   ...               False       False         False
# 2         -   Graduado   ...               False       False         False
# 3         -          -   ...               False       False         False
# 4  Graduado   Graduado   ...               False       False         False
#
#   vistas_postulante vistas_al_aviso cantidad vistas_por_area vistas_por_tipo  \
# 0               NaN             0.0      NaN             0.0             0.0
# 1              22.0             0.0      NaN             2.0            22.0
# 2              14.0             0.0      NaN             1.0            14.0
# 3             430.0             0.0      NaN            30.0           358.0
# 4             249.0             0.0      NaN            33.0           240.0
#
#    vistas_por_nivel  lo_vio
# 0               0.0   False
# 1              22.0   False
# 2              14.0   False
# 3             358.0   False
# 4             240.0   False
#
# [5 rows x 52 columns]

# %%
postulaciones=pd.merge(postulaciones,postulaciones_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['postulaciones_misma_area']=postulaciones['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_nivel']=postulaciones['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_tipo']=postulaciones['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)

# %%
postulaciones.sample(10)
# Out:
#             idaviso idpostulante  sepostulo        sexo   edad Doctorado  \
# 836951   1112344955      LNKvk4P          1  NO_DECLARA  200.0         -
# 718056   1112371554      qe24dq9          0         FEM   21.0         -
# 1569298  1112444243      A3X1Rw1          1        MASC   31.0         -
# 3550848  1112298991      Nzrb8q4          0        MASC   36.0         -
# 5511037  1112157764       eMG8A4          0        MASC   30.0         -
# 6118090  1112207320      5mkJvNw          0        MASC   35.0         -
# 3421588  1112437934      lDLK053          0         FEM   24.0         -
# 4375593  1112308845      lDLRWq6          0        MASC   19.0         -
# 5130717  1112241117      vVkxYVX          1        MASC   24.0         -
# 1806787  1112343977      jk6Br4e          1         FEM   47.0         -
#
#         Master      Otro Posgrado Secundario            ...              \
# 836951       -         -        -   Graduado            ...
# 718056       -         -        -          -            ...
# 1569298      -         -        -   Graduado            ...
# 3550848      -         -        -   Graduado            ...
# 5511037      -         -        -   Graduado            ...
# 6118090      -         -        -   Graduado            ...
# 3421588      -  Graduado        -   Graduado            ...
# 4375593      -         -        -   En Curso            ...
# 5130717      -         -        -   Graduado            ...
# 1806787      -         -        -   Graduado            ...
#
#         vistas_postulante vistas_al_aviso  cantidad vistas_por_area  \
# 836951               26.0             1.0  0.038462             1.0
# 718056                NaN             0.0       NaN             0.0
# 1569298              64.0             0.0       NaN             0.0
# 3550848              18.0             0.0       NaN             0.0
# 5511037               2.0             0.0       NaN             0.0
# 6118090               1.0             0.0       NaN             0.0
# 3421588               NaN             0.0       NaN             0.0
# 4375593               1.0             0.0       NaN             0.0
# 5130717               NaN             0.0       NaN             0.0
# 1806787              26.0             0.0       NaN             9.0
#
#         vistas_por_tipo vistas_por_nivel lo_vio postulaciones_misma_area  \
# 836951             24.0             24.0   True                        0
# 718056              0.0              0.0  False                        1
# 1569298            44.0             44.0  False                        1
# 3550848            18.0             18.0  False                        0
# 5511037             1.0              1.0  False                        0
# 6118090             1.0              1.0  False                        0
# 3421588             0.0              0.0  False                        0
# 4375593             1.0              1.0  False                        0
# 5130717             0.0              0.0  False                       10
# 1806787            16.0             16.0  False                        0
#
#          postulaciones_mismo_tipo  postulaciones_mismo_nivel
# 836951                         10                          4
# 718056                          4                          2
# 1569298                        31                          7
# 3550848                         7                          3
# 5511037                        11                          5
# 6118090                         6                          1
# 3421588                         8                          2
# 4375593                         9                          3
# 5130717                        81                         63
# 1806787                        10                          6
#
# [10 rows x 55 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.10)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']

postulaciones=0

gc.collect()
# Out:
# Train:  5754323 Test:  639370
# 98

# %%
model = RandomLightGBM(n_iterations=5,n_features=15,retries=3,subset_sample=0.3,verbose=True)
dt = model.fit(train,test,'sepostulo',features)
# Out:
# Iteration 1 with features ['vistas_por_area', 'liderazgo', 'vistas_por_nivel', 'titulo_uppercase', 'nombre_area', 'ingles', 'supera_largo_medio', 'sexo', 'postulaciones_mismo_tipo', 'largo_descripcion', 'estudiantes', 'buen_ambiente', 'pide_mujer']
# Score: 0.955272660975176 with features ['vistas_por_area', 'liderazgo', 'vistas_por_nivel', 'titulo_uppercase', 'nombre_area', 'ingles', 'supera_largo_medio', 'sexo', 'postulaciones_mismo_tipo', 'largo_descripcion', 'estudiantes', 'buen_ambiente', 'pide_mujer']
# Iteration 2 with features ['tipo_de_trabajo', 'pide_mujer', 'Secundario', 'postulaciones_misma_area', 'vistas_por_area', 'secundario', 'empresa_importante', 'postulaciones_mismo_nivel', 'pide_excel', 'sexo', 'Posgrado', 'part_time', 'viajar']
# Score: 0.9514566263993018 with features ['tipo_de_trabajo', 'pide_mujer', 'Secundario', 'postulaciones_misma_area', 'vistas_por_area', 'secundario', 'empresa_importante', 'postulaciones_mismo_nivel', 'pide_excel', 'sexo', 'Posgrado', 'part_time', 'viajar']
# Retry number 1 with score: 0.9659087728707161 and features: ['vistas_por_tipo', 'nivel_laboral', 'Terciario/Técnico', 'vistas_por_nivel', 'Posgrado', 'remuneracion_pretendida', 'ofrece_crecimiento', 'pide_hombre', 'nombre_zona', 'Secundario', 'largo_descripcion', 'tipo_de_trabajo', 'postulaciones_mismo_tipo', 'ingles', 'experiencia', 'lo_vio', 'tecnico', 'postulaciones_misma_area', 'pide_mujer', 'capacitacion', 'cantidad', 'postulaciones_mismo_nivel', 'Master']
# Iteration 3 with features ['Secundario', 'postulaciones_mismo_nivel', 'postulaciones_misma_area', 'titulo_uppercase', 'paquete_office', 'vistas_por_area', 'ofrece_crecimiento', 'nombre_zona', 'multinacional', 'cantidad', 'pide_mujer', 'empresa_importante', 'part_time', 'tecnico']
# Score: 0.9624114581177714 with features ['Secundario', 'postulaciones_mismo_nivel', 'postulaciones_misma_area', 'titulo_uppercase', 'paquete_office', 'vistas_por_area', 'ofrece_crecimiento', 'nombre_zona', 'multinacional', 'cantidad', 'pide_mujer', 'empresa_importante', 'part_time', 'tecnico']
# Retry number 1 with score: 0.9648553822548802 and features: ['vistas_por_tipo', 'nombre_zona', 'remuneracion_pretendida', 'indica_sueldo', 'vistas_por_nivel', 'tipo_de_trabajo', 'nombre_area', 'estudiantes', 'experiencia', 'postulaciones_mismo_tipo', 'pide_hombre', 'Otro', 'ingles', 'postulaciones_misma_area', 'postulaciones_mismo_nivel', 'full_time', 'sexo', 'multinacional', 'obra_social', 'empresa_importante', 'capacitacion', 'buen_ambiente', 'Master', 'Doctorado', 'pide_mujer', 'liderazgo']
# Retry number 2 with score: 0.9698936056489474 and features: ['Posgrado', 'vistas_postulante', 'postulaciones_mismo_tipo', 'pide_hombre', 'conocimientos_especificos', 'liderazgo', 'tecnico', 'buen_ambiente', 'nombre_zona', 'paquete_office', 'pide_excel', 'tipo_de_trabajo', 'largo_descripcion', 'obra_social', 'nombre_area', 'estudiantes', 'Universitario', 'postulaciones_misma_area', 'titulo_uppercase', 'remuneracion_pretendida', 'graduados', 'indica_sueldo', 'secundario', 'vistas_por_area', 'vistas_por_nivel', 'pide_mujer', 'experiencia', 'Master', 'multinacional', 'Secundario', 'part_time', 'sexo', 'nivel_laboral']
# Iteration 4 with features ['conocimientos_especificos', 'pide_mujer', 'Terciario/Técnico', 'titulo_uppercase', 'postulaciones_misma_area', 'secundario', 'indica_sueldo', 'liderazgo', 'multinacional', 'vistas_por_area', 'vistas_al_aviso', 'tipo_de_trabajo', 'nombre_zona', 'ofrece_beneficios']
# Score: 0.9676612638884337 with features ['conocimientos_especificos', 'pide_mujer', 'Terciario/Técnico', 'titulo_uppercase', 'postulaciones_misma_area', 'secundario', 'indica_sueldo', 'liderazgo', 'multinacional', 'vistas_por_area', 'vistas_al_aviso', 'tipo_de_trabajo', 'nombre_zona', 'ofrece_beneficios']
# Retry number 1 with score: 0.9725412767790866 and features: ['obra_social', 'vistas_por_area', 'buen_ambiente', 'pide_hombre', 'edad', 'capacitacion', 'part_time', 'lo_vio', 'vistas_por_nivel', 'vistas_por_tipo', 'paquete_office', 'experiencia', 'Otro', 'vistas_al_aviso', 'ingles', 'multinacional', 'postulaciones_misma_area', 'conocimientos_especificos', 'estudiantes', 'nombre_area', 'supera_largo_medio', 'Master', 'indica_sueldo', 'vistas_postulante', 'secundario', 'pide_mujer', 'largo_descripcion', 'tipo_de_trabajo', 'empresa_importante', 'viajar', 'nombre_zona', 'remuneracion_pretendida', 'full_time', 'Terciario/Técnico']
# Iteration 5 with features ['nivel_laboral', 'supera_largo_medio', 'sexo', 'conocimientos_especificos', 'full_time', 'graduados', 'vistas_por_nivel', 'liderazgo', 'estudiantes', 'viajar', 'cantidad', 'ingles']
# Score: 0.9709216510896103 with features ['nivel_laboral', 'supera_largo_medio', 'sexo', 'conocimientos_especificos', 'full_time', 'graduados', 'vistas_por_nivel', 'liderazgo', 'estudiantes', 'viajar', 'cantidad', 'ingles']
# Retry number 1 with score: 0.9734617505869821 and features: ['vistas_por_tipo', 'obra_social', 'tipo_de_trabajo', 'graduados', 'Secundario', 'edad', 'capacitacion', 'vistas_por_area', 'nivel_laboral', 'remuneracion_pretendida', 'ofrece_beneficios', 'largo_descripcion', 'liderazgo', 'empresa_importante', 'estudiantes', 'pide_mujer', 'conocimientos_especificos', 'lo_vio', 'indica_sueldo', 'postulaciones_mismo_nivel', 'Universitario', 'nombre_zona', 'tecnico', 'pide_hombre', 'cantidad', 'ingles', 'secundario', 'multinacional', 'Doctorado', 'viajar', 'ofrece_crecimiento', 'supera_largo_medio', 'pide_excel', 'Terciario/Técnico', 'experiencia', 'paquete_office', 'vistas_postulante', 'full_time', 'vistas_por_nivel']

# %%
score=roc_auc_score(y_test, model.predict_proba_class(1,test))
print(score)
# Out:
# 0.9734617505869821

# %%
joblib.dump(model, "Data/fiuba_entrenamiento/pocho/modelos/RandomLGBM6.pkl")
# Out:
# ['Data/fiuba_entrenamiento/pocho/modelos/RandomLGBM6.pkl']

# %%
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.050000
# 1    48375       RwVdKR  0.100000
# 2   169730        1KjXB  0.029412
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.100000

# %%
prediccion = pd.read_csv("Data/fiuba_entrenamiento/test_final_100k.csv")
prediccion = pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
prediccion = pd.merge(prediccion,avisos,on='idaviso',how='inner')
prediccion = pd.merge(prediccion,vistas,on='idpostulante',how='left')
prediccion.sample(10)


prediccion=pd.merge(prediccion,vistas2,on=['idaviso','idpostulante'],how='left')
prediccion=pd.merge(prediccion,vistas3,on=['idaviso','idpostulante'],how='left')
prediccion['cantidad']=prediccion['cantidad'].fillna(0)
prediccion['vistas_postulante']=prediccion['vistas_postulante'].fillna(0)
prediccion['vistas_al_aviso']=prediccion['vistas_al_aviso'].fillna(0)
prediccion['lo_vio']=(prediccion['vistas_al_aviso']>0)

prediccion=pd.merge(prediccion,postulaciones_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,postulaciones_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,postulaciones_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion=pd.merge(prediccion,vistas_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,vistas_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,vistas_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['vistas_por_area']=prediccion['vistas_por_area'].fillna(0)
prediccion['vistas_por_tipo']=prediccion['vistas_por_tipo'].fillna(0)
prediccion['vistas_por_nivel']=prediccion['vistas_por_tipo'].fillna(0)
prediccion['postulaciones_misma_area']=prediccion['postulaciones_misma_area'].fillna(0)
prediccion['postulaciones_mismo_nivel']=prediccion['postulaciones_mismo_nivel'].fillna(0)
prediccion['postulaciones_mismo_tipo']=prediccion['postulaciones_mismo_tipo'].fillna(0)
prediccion.sample(10)
# Out:
#           id     idaviso idpostulante  sexo  edad Doctorado    Master  \
# 76506  22749  1112296264       8894zz  MASC  39.0         -         -
# 11115  25912  1112334809       8XoxzR  MASC  31.0         -         -
# 48116  63026  1112456971       avao4W   FEM  29.0         -         -
# 39724  50478  1112439336      RzrmGbq  MASC  23.0         -         -
# 1514   86524  1112466769      BmaVDME   FEM  31.0         -         -
# 38004  21989  1112280954        6QQNr  MASC  43.0         -  Graduado
# 88380  44793  1112427197       6jOrpr   FEM  47.0         -         -
# 25606  20912  1112264647       ZW0208  MASC  32.0         -         -
# 60615   8784  1111793352       NAlOm4   FEM  36.0         -         -
# 80395  45694  1112428575        8GEYj  MASC  43.0         -         -
#
#            Otro Posgrado Secundario        ...        vistas_postulante  \
# 76506         -        -   Graduado        ...                     14.0
# 11115         -        -   Graduado        ...                      5.0
# 48116  En Curso        -   Graduado        ...                    189.0
# 39724  Graduado        -   Graduado        ...                      1.0
# 1514          -        -          -        ...                      1.0
# 38004         -        -   Graduado        ...                      3.0
# 88380         -        -          -        ...                      1.0
# 25606         -        -   Graduado        ...                     24.0
# 60615         -        -          -        ...                     20.0
# 80395         -        -   Graduado        ...                      0.0
#
#       vistas_al_aviso  cantidad lo_vio postulaciones_misma_area  \
# 76506             0.0  0.000000  False                      0.0
# 11115             0.0  0.000000  False                      0.0
# 48116             1.0  0.005291   True                     23.0
# 39724             0.0  0.000000  False                     16.0
# 1514              0.0  0.000000  False                      9.0
# 38004             0.0  0.000000  False                      0.0
# 88380             0.0  0.000000  False                      0.0
# 25606             1.0  0.041667   True                      0.0
# 60615             0.0  0.000000  False                      2.0
# 80395             0.0  0.000000  False                      0.0
#
#       postulaciones_mismo_tipo postulaciones_mismo_nivel vistas_por_area  \
# 76506                      8.0                       1.0             0.0
# 11115                      3.0                       2.0             0.0
# 48116                    184.0                     130.0            20.0
# 39724                     23.0                      16.0             1.0
# 1514                      33.0                       7.0             0.0
# 38004                     12.0                       1.0             0.0
# 88380                      9.0                       8.0             0.0
# 25606                     24.0                      17.0             1.0
# 60615                      7.0                       5.0             0.0
# 80395                      8.0                       7.0             0.0
#
#        vistas_por_tipo  vistas_por_nivel
# 76506             14.0              14.0
# 11115              5.0               5.0
# 48116            172.0             172.0
# 39724              1.0               1.0
# 1514               1.0               1.0
# 38004              2.0               2.0
# 88380              1.0               1.0
# 25606             15.0              15.0
# 60615              0.0               0.0
# 80395              0.0               0.0
#
# [10 rows x 55 columns]

# %%
y_final=model.predict_proba_class(1,prediccion)
prediccion['sepostulo']=y_final
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     vistas_al_aviso cantidad lo_vio  \
# 0   Graduado    ...                 0.0      0.0  False
# 1          -    ...                 0.0      0.0  False
# 2   Graduado    ...                 0.0      0.0  False
# 3   Graduado    ...                 0.0      0.0  False
# 4          -    ...                 0.0      0.0  False
#
#   postulaciones_misma_area postulaciones_mismo_tipo postulaciones_mismo_nivel  \
# 0                      0.0                      8.0                       1.0
# 1                      2.0                     30.0                       0.0
# 2                      0.0                      5.0                       0.0
# 3                      0.0                      6.0                       0.0
# 4                      1.0                     10.0                       0.0
#
#   vistas_por_area vistas_por_tipo  vistas_por_nivel  sepostulo
# 0             3.0            20.0              20.0   0.319913
# 1             0.0             3.0               3.0   0.402862
# 2             1.0             6.0               6.0   0.158007
# 3             0.0             0.0               0.0   0.098621
# 4             0.0             1.0               1.0   0.211196
#
# [5 rows x 56 columns]

# %%
prediccion=prediccion[['id','sepostulo']]
print(prediccion.sepostulo.mean())
prediccion.head()
# Out:
# 0.5409887203457424
#    id  sepostulo
# 0   0   0.319913
# 1   1   0.402862
# 2   2   0.158007
# 3   3   0.098621
# 4   4   0.211196

# %%
prediccion.to_csv("Data/fiuba_entrenamiento/pocho/predicciones/pred-rlgbm5.csv",index=False)
