# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['total']=0
vistas2=vistas
vistas['puntos']=0
vistas2=vistas2.groupby(['idAviso','idpostulante'],as_index=False).agg({'puntos':'count'})
vistas2=vistas2.rename(columns={'idAviso': 'idaviso'})
vistas2.head()
# Out:
#    idaviso idpostulante  puntos
# 0       18        BolNL       2
# 1    48375       RwVdKR       1
# 2   169730        1KjXB       2
# 3   169730       2AKzxa       2
# 4   169730        6LJ64       1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'total':'count'});
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#   idpostulante  total
# 0        0002q     15
# 1        0005E     58
# 2        000R8     14
# 3        001XE     26
# 4        003k9     32

# %%
vistas2=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas2.head()
# Out:
#    idaviso idpostulante  puntos  total
# 0       18        BolNL       2     28
# 1    48375       RwVdKR       1     15
# 2   169730        1KjXB       2     99
# 3   169730       2AKzxa       2      2
# 4   169730        6LJ64       1     23

# %%
vistas2['vistas']=vistas2['puntos']
vistas2['puntos']=(vistas2['puntos']*10)/vistas2['total']
vistas=vistas2
vistas2.head()
# Out:
#    idaviso idpostulante     puntos  total  vistas
# 0       18        BolNL   0.714286     28       2
# 1    48375       RwVdKR   0.666667     15       1
# 2   169730        1KjXB   0.202020     99       2
# 3   169730       2AKzxa  10.000000      2       2
# 4   169730        6LJ64   0.434783     23       1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/3.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/4.csv").iloc[0:len(postulaciones2)//2], ignore_index=True)
print(len(postulaciones2))
postulaciones2.head()
# Out:
# 9906801
#       idaviso idpostulante  sepostulo
# 0  1112257047      ow2xPaj          0
# 1  1111920714      LNKXqJB          0
# 2  1112346945      8MBPqYD          0
# 3  1112345547      ek4P2Wr          0
# 4  1112237522       NpqMD5          0

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 16511335
# 16450211

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado    Master  \
# 2714889   1112179207      dYjlNZM          0   FEM  18.0         -         -
# 14119907  1112425062      8MPwakz          0   FEM  49.0         -         -
# 6054252   1112405351       N9r4Al          1   FEM  31.0         -         -
# 6308561   1112371208       YYEJar          0  MASC  44.0  En Curso  Graduado
# 2714699   1112179207       1LL9qb          0   FEM  37.0         -         -
# 11032167  1112346459      GNZ2JOv          0  MASC  39.0         -         -
# 4022222   1111414856       8oG9L3          0  MASC  26.0         -         -
# 9892695   1112437516      DrzRL0Z          1   FEM  50.0         -         -
# 12147213  1112301407      MVr1X6o          1   FEM  28.0         -         -
# 1402338   1112305232      bOjr18b          0  MASC  19.0         -         -
# 8591203   1112299350      dYjkB92          0   FEM  22.0         -         -
# 3587095   1112443869      ZDlD4pR          0  MASC  26.0         -         -
# 9283376   1112351982       YWLpbD          0  MASC  30.0         -         -
# 7932018   1112287852       Z12kJb          1   FEM  33.0         -         -
# 11264346  1112399795      2zP8bv6          0  MASC  18.0         -         -
# 7549083   1112200023      JBm3lzJ          0  MASC  32.0         -         -
# 7942977   1112374671      zvaJxED          0   FEM  31.0         -         -
# 691378    1112350129      pzdRZVL          0   FEM  18.0         -         -
# 598668    1112033906       eNqJEj          0   FEM  45.0         -         -
# 12030452  1112451579      bO4N9Qq          0   FEM  29.0         -         -
#
#               Otro  Posgrado Secundario   ...   capacitacion  \
# 2714889          -         -   En Curso   ...           True
# 14119907         -         -          -   ...          False
# 6054252          -         -   Graduado   ...          False
# 6308561          -         -   Graduado   ...          False
# 2714699          -         -   Graduado   ...           True
# 11032167         -         -          -   ...           True
# 4022222          -         -   Graduado   ...          False
# 9892695          -  Graduado   Graduado   ...          False
# 12147213         -         -          -   ...           True
# 1402338          -         -          -   ...          False
# 8591203          -         -          -   ...          False
# 3587095          -         -          -   ...           True
# 9283376          -         -          -   ...          False
# 7932018          -         -          -   ...          False
# 11264346         -         -   Graduado   ...          False
# 7549083          -         -   Graduado   ...           True
# 7942977          -         -   Graduado   ...           True
# 691378           -         -   Graduado   ...          False
# 598668    Graduado         -   Graduado   ...           True
# 12030452         -         -          -   ...          False
#
#          remuneracion_pretendida graduados estudiantes  \
# 2714889                    False     False       False
# 14119907                   False     False       False
# 6054252                    False     False       False
# 6308561                    False     False       False
# 2714699                    False     False       False
# 11032167                   False      True        True
# 4022222                    False     False       False
# 9892695                    False     False       False
# 12147213                   False     False       False
# 1402338                    False     False       False
# 8591203                    False     False       False
# 3587095                    False     False       False
# 9283376                    False     False       False
# 7932018                    False     False       False
# 11264346                   False      True       False
# 7549083                    False     False       False
# 7942977                    False     False       False
# 691378                     False      True        True
# 598668                     False     False       False
# 12030452                   False     False       False
#
#          conocimientos_especificos buen_ambiente discriminacion puntos  total  \
# 2714889                      False          True          False    NaN    NaN
# 14119907                     False         False          False    NaN    NaN
# 6054252                      False         False          False    NaN    NaN
# 6308561                      False         False          False    NaN    NaN
# 2714699                      False          True          False    NaN    NaN
# 11032167                     False         False          False    NaN    NaN
# 4022222                      False         False          False    NaN    NaN
# 9892695                      False          True          False    NaN    NaN
# 12147213                     False         False          False    NaN    NaN
# 1402338                      False         False          False    NaN    NaN
# 8591203                       True         False           True    NaN    NaN
# 3587095                      False          True          False    NaN    NaN
# 9283376                      False         False          False    NaN    NaN
# 7932018                      False         False          False    NaN    NaN
# 11264346                     False         False          False    NaN    NaN
# 7549083                      False         False          False    NaN    NaN
# 7942977                      False         False          False    NaN    NaN
# 691378                       False         False          False    NaN    NaN
# 598668                       False          True          False    NaN    NaN
# 12030452                     False         False          False    NaN    NaN
#
#           vistas
# 2714889      NaN
# 14119907     NaN
# 6054252      NaN
# 6308561      NaN
# 2714699      NaN
# 11032167     NaN
# 4022222      NaN
# 9892695      NaN
# 12147213     NaN
# 1402338      NaN
# 8591203      NaN
# 3587095      NaN
# 9283376      NaN
# 7932018      NaN
# 11264346     NaN
# 7549083      NaN
# 7942977      NaN
# 691378       NaN
# 598668       NaN
# 12030452     NaN
#
# [20 rows x 38 columns]

# %%
postulaciones.puntos=postulaciones.puntos.fillna(0)
postulaciones.total=postulaciones.total.fillna(0)
postulaciones.vistas=postulaciones.vistas.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 2726979   1112394499      VNP22dE          1   FEM  20.0         -      -
# 11262341  1112418587      0zkKkN9          0  MASC  43.0         -      -
# 10799616  1112314232      DrJ3x8A          0   FEM  33.0         -      -
# 6299035   1112268639      jkjlxkG          1  MASC  18.0         -      -
# 13747415  1112289798      X95evjO          1  MASC  18.0         -      -
# 1864849   1112334791      Ezp3Y3J          1   FEM  23.0         -      -
# 6078339   1112429705      96z8Yea          0  MASC  23.0         -      -
# 10982394  1112313151       ZqD9lP          0   FEM  39.0         -      -
# 12726846  1112350617      BmBlJDE          1  MASC  20.0         -      -
# 14454354  1112254360       6jo9BO          0  MASC  32.0         -      -
# 2622469   1112336468      bOjxWk9          0  MASC  20.0         -      -
# 12571461  1112146317       ZE3aWV          1  MASC  44.0         -      -
# 13840424  1112422078      GNXBprp          0   FEM  23.0         -      -
# 7584502   1112227091      W9VA8NN          1  MASC  22.0         -      -
# 2310830   1112322294      1QPoeBL          0  MASC  24.0         -      -
# 13098533  1112455374      GNZ33MN          0   FEM  50.0         -      -
# 13174074  1112245590      VNr28wl          0   FEM  18.0         -      -
# 5069978   1112282953      dY5b5OD          0   FEM  22.0         -      -
# 4762386   1112308457      X9WVXDx          1  MASC  41.0         -      -
# 6484190   1111444020      YjVkvBw          0  MASC  30.0         -      -
#
#               Otro Posgrado Secundario   ...   capacitacion  \
# 2726979          -        -   Graduado   ...          False
# 11262341         -        -   Graduado   ...          False
# 10799616         -        -   Graduado   ...          False
# 6299035   Graduado        -   Graduado   ...          False
# 13747415         -        -          -   ...          False
# 1864849          -        -   Graduado   ...           True
# 6078339          -        -          -   ...          False
# 10982394         -        -          -   ...          False
# 12726846         -        -          -   ...          False
# 14454354         -        -   Graduado   ...          False
# 2622469          -        -   Graduado   ...          False
# 12571461         -        -          -   ...          False
# 13840424  Graduado        -   Graduado   ...          False
# 7584502   Graduado        -   Graduado   ...           True
# 2310830          -        -   Graduado   ...          False
# 13098533  Graduado        -          -   ...           True
# 13174074         -        -   En Curso   ...          False
# 5069978          -        -          -   ...           True
# 4762386          -        -   Graduado   ...          False
# 6484190          -        -   Graduado   ...          False
#
#          remuneracion_pretendida graduados estudiantes  \
# 2726979                    False     False       False
# 11262341                   False     False       False
# 10799616                   False     False       False
# 6299035                    False     False       False
# 13747415                   False     False       False
# 1864849                    False     False       False
# 6078339                    False     False       False
# 10982394                   False     False       False
# 12726846                   False     False       False
# 14454354                   False     False       False
# 2622469                    False     False       False
# 12571461                   False     False       False
# 13840424                   False     False       False
# 7584502                    False     False        True
# 2310830                    False     False       False
# 13098533                   False     False       False
# 13174074                   False     False       False
# 5069978                    False      True        True
# 4762386                    False     False       False
# 6484190                    False     False       False
#
#          conocimientos_especificos buen_ambiente discriminacion    puntos  \
# 2726979                      False         False          False  0.066667
# 11262341                     False          True          False  0.000000
# 10799616                     False          True          False  0.000000
# 6299035                       True         False           True  0.000000
# 13747415                     False         False          False  0.000000
# 1864849                      False          True          False  0.212766
# 6078339                      False         False          False  0.000000
# 10982394                     False         False          False  0.000000
# 12726846                     False          True          False  0.833333
# 14454354                     False         False          False  0.000000
# 2622469                      False         False          False  0.000000
# 12571461                     False         False          False  0.540541
# 13840424                     False         False          False  0.000000
# 7584502                      False          True          False  0.000000
# 2310830                       True         False           True  0.000000
# 13098533                     False         False          False  0.000000
# 13174074                     False         False          False  0.000000
# 5069978                      False         False          False  0.000000
# 4762386                      False          True          False  0.000000
# 6484190                      False         False          False  0.000000
#
#           total  vistas
# 2726979   150.0     1.0
# 11262341    0.0     0.0
# 10799616    0.0     0.0
# 6299035     0.0     0.0
# 13747415    0.0     0.0
# 1864849    47.0     1.0
# 6078339     0.0     0.0
# 10982394    0.0     0.0
# 12726846   24.0     2.0
# 14454354    0.0     0.0
# 2622469     0.0     0.0
# 12571461   37.0     2.0
# 13840424    0.0     0.0
# 7584502     0.0     0.0
# 2310830     0.0     0.0
# 13098533    0.0     0.0
# 13174074    0.0     0.0
# 5069978     0.0     0.0
# 4762386     0.0     0.0
# 6484190     0.0     0.0
#
# [20 rows x 38 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
vistas2=0
# Out:
# Train:  14560399 Test:  766337

# %%
gc.collect()
# Out:
# 175

# %%
c=lgb.LGBMClassifier(learning_rate=0.005,objective='binary',num_leaves=6000,max_depth=13,n_estimators=1200,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 75.48558923815501
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV12.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV12.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.puntos=prediccion.puntos.fillna(0)
prediccion.total=prediccion.total.fillna(0)
prediccion.vistas=prediccion.vistas.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado    Master Otro  \
# 49861   3202  1111353878       ZvqVwE  MASC  46.0         -         -    -
# 82879  31350  1112385711       6qOVZ4  MASC  35.0         -  Graduado    -
# 39603  69731  1112461551      JBdPl6e  MASC  25.0         -         -    -
# 12366   4512  1111473085      dY92Vp0   FEM  19.0         -         -    -
# 12656  17687  1112205105      LNPkkQQ   FEM  29.0         -         -    -
# 14239  62438  1112456089      DrlWNLd   FEM  25.0         -         -    -
# 94789  94138  1112483253       ea0X9W   FEM  41.0         -         -    -
# 18761  76595  1112464229      owz0jPZ  MASC  31.0         -         -    -
# 54579  35159  1112410012      JBmm8MO   FEM  32.0         -         -    -
# 47718  88116  1112466977      LNMp3w5  MASC  31.0         -         -    -
#
#          Posgrado Secundario   ...   capacitacion remuneracion_pretendida  \
# 49861  Abandonado          -   ...           True                   False
# 82879           -   Graduado   ...          False                   False
# 39603           -   Graduado   ...          False                   False
# 12366           -   Graduado   ...          False                   False
# 12656           -   Graduado   ...          False                   False
# 14239           -   Graduado   ...           True                   False
# 94789           -   Graduado   ...          False                   False
# 18761           -          -   ...          False                   False
# 54579           -          -   ...          False                   False
# 47718           -   Graduado   ...          False                   False
#
#       graduados estudiantes conocimientos_especificos buen_ambiente  \
# 49861     False       False                     False         False
# 82879     False       False                     False         False
# 39603     False       False                     False         False
# 12366     False        True                      True         False
# 12656     False       False                     False         False
# 14239     False       False                     False         False
# 94789     False       False                     False         False
# 18761     False       False                     False         False
# 54579     False       False                     False         False
# 47718     False       False                     False         False
#
#       discriminacion    puntos  total  vistas
# 49861          False  0.000000    0.0     0.0
# 82879          False  0.000000    0.0     0.0
# 39603          False  0.000000    0.0     0.0
# 12366           True  0.227273   88.0     2.0
# 12656          False  1.212121   33.0     4.0
# 14239          False  0.094937  632.0     6.0
# 94789          False  0.000000    0.0     0.0
# 18761          False  0.000000    0.0     0.0
# 54579          False  0.146520  273.0     4.0
# 47718          False  0.042194  237.0     1.0
#
# [10 rows x 38 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.69800741, 0.30199259],
#        [0.65576447, 0.34423553],
#        [0.67069296, 0.32930704],
#        ...,
#        [0.86754174, 0.13245826],
#        [0.6383185 , 0.3616815 ],
#        [0.95734159, 0.04265841]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     remuneracion_pretendida graduados estudiantes  \
# 0   Graduado    ...                       False     False       False
# 1          -    ...                       False     False       False
# 2   Graduado    ...                       False     False       False
# 3   Graduado    ...                       False     False       False
# 4          -    ...                       False     False       False
#
#   conocimientos_especificos buen_ambiente discriminacion puntos total  vistas  \
# 0                     False         False          False    0.0   0.0     0.0
# 1                     False         False          False    0.0   0.0     0.0
# 2                     False         False          False    0.0   0.0     0.0
# 3                     False         False          False    0.0   0.0     0.0
# 4                     False         False          False    0.0   0.0     0.0
#
#    sepostulo
# 0   0.301993
# 1   0.344236
# 2   0.329307
# 3   0.114699
# 4   0.316637
#
# [5 rows x 39 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.301993
# 1   1   0.344236
# 2   2   0.329307
# 3   3   0.114699
# 4   4   0.316637

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion27.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5400703143864202
