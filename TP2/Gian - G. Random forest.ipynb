# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/1.csv")

postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones2=pd.merge(postulaciones2,postulantes,on='idpostulante')

postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones2=pd.merge(postulaciones2,avisos,on='idaviso')

postulaciones2.head()
# Out:
#       idaviso idpostulante  sepostulo  sexo  edad Doctorado Master Otro  \
# 0  1112257047      akjmXXq          0   FEM  28.0         -      -    -
# 1  1112257047      MV6b6R9          0   FEM  30.0         -      -    -
# 2  1112257047      zvxv1Rm          0   FEM  22.0         -      -    -
# 3  1112257047       8oqJzL          0  MASC  34.0         -      -    -
# 4  1112257047       ez533B          0  MASC  32.0         -      -    -
#
#   Posgrado Secundario       ...       secundario viajar empresa_importante  \
# 0        -   Graduado       ...             True  False              False
# 1        -          -       ...             True  False              False
# 2        -   Graduado       ...             True  False              False
# 3        -          -       ...             True  False              False
# 4        -   Graduado       ...             True  False              False
#
#   capacitacion remuneracion_pretendida graduados estudiantes  \
# 0         True                   False     False       False
# 1         True                   False     False       False
# 2         True                   False     False       False
# 3         True                   False     False       False
# 4         True                   False     False       False
#
#   conocimientos_especificos  buen_ambiente  discriminacion
# 0                     False          False           False
# 1                     False          False           False
# 2                     False          False           False
# 3                     False          False           False
# 4                     False          False           False
#
# [5 rows x 33 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo sexo  edad Doctorado Master Otro  \
# 0  1112257047         NM5M          1  FEM  47.0         -      -    -
# 1  1112257047       1kJqGb          1  FEM  34.0         -      -    -
# 2  1112257047       eOE9Rr          1  FEM  39.0         -      -    -
# 3  1112257047       Zrx8Xz          1  FEM  39.0         -      -    -
# 4  1112257047       ZrKNQY          1  FEM  32.0         -      -    -
#
#   Posgrado Secundario       ...       secundario viajar empresa_importante  \
# 0        -   Graduado       ...             True  False              False
# 1        -          -       ...             True  False              False
# 2        -   Graduado       ...             True  False              False
# 3        -          -       ...             True  False              False
# 4        -   Graduado       ...             True  False              False
#
#   capacitacion remuneracion_pretendida graduados estudiantes  \
# 0         True                   False     False       False
# 1         True                   False     False       False
# 2         True                   False     False       False
# 3         True                   False     False       False
# 4         True                   False     False       False
#
#   conocimientos_especificos  buen_ambiente  discriminacion
# 0                     False          False           False
# 1                     False          False           False
# 2                     False          False           False
# 3                     False          False           False
# 4                     False          False           False
#
# [5 rows x 33 columns]

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 12377268
# 12332167

# %%
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 5929667   1112396117       1j9XVj          1  MASC  32.0         -      -
# 7667740   1112252543      Yj5xm9P          0   FEM  42.0         -      -
# 11897407  1112387107      KBeBbvQ          0   FEM  32.0         -      -
# 3545185   1112232179       ajG6JN          1   FEM  32.0         -      -
# 464014    1112360052      JBmav1r          1   FEM  30.0         -      -
# 6639697   1112280937      JBrRb5J          0   FEM  26.0         -      -
# 9088555   1112208550      zv8x88J          0   FEM  33.0         -      -
# 10477276  1112270453      VNrR3DN          0  MASC  53.0         -      -
# 5050707   1112299395      0zPlBld          1  MASC  19.0         -      -
# 7847913   1112460365      JBxANXe          0   FEM  25.0         -      -
# 2389282   1112246257      MVrxWWK          1   FEM  22.0         -      -
# 2162002   1111752538      kPL58DV          1  MASC  39.0         -      -
# 1893743   1112200639      xka1JBY          1  MASC  24.0         -      -
# 8936405   1112267885      KBakeG2          0   FEM  19.0         -      -
# 7498215   1112362725      GNZPB2e          0   FEM  34.0         -      -
# 2434646   1110478929      xk9zqqa          1  MASC  29.0         -      -
# 8243407   1112418661      96X00p1          0   FEM  21.0         -      -
# 7390055   1111455368      mzdlXR1          0  MASC  37.0         -      -
# 9170822   1112303392      JBeEQYE          0   FEM  30.0         -      -
# 4242326   1112425552      vV9NNRE          1  MASC  25.0         -      -
#
#               Otro Posgrado Secundario    ...    viajar empresa_importante  \
# 5929667          -        -   Graduado    ...     False              False
# 7667740          -        -   Graduado    ...     False              False
# 11897407         -        -          -    ...     False              False
# 3545185          -        -   Graduado    ...     False              False
# 464014    Graduado        -   Graduado    ...     False              False
# 6639697          -        -          -    ...     False               True
# 9088555          -        -          -    ...     False              False
# 10477276         -        -          -    ...     False              False
# 5050707          -        -   Graduado    ...     False               True
# 7847913          -        -   Graduado    ...     False               True
# 2389282          -        -   Graduado    ...     False              False
# 2162002          -        -   Graduado    ...     False              False
# 1893743          -        -   Graduado    ...     False              False
# 8936405          -        -   En Curso    ...     False              False
# 7498215          -        -          -    ...     False              False
# 2434646          -        -          -    ...     False              False
# 8243407          -        -   Graduado    ...     False              False
# 7390055   Graduado        -   Graduado    ...     False              False
# 9170822          -        -   Graduado    ...     False               True
# 4242326          -        -          -    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 5929667         False                   False     False       False
# 7667740         False                   False     False       False
# 11897407        False                   False     False       False
# 3545185         False                   False      True        True
# 464014           True                   False     False       False
# 6639697         False                   False     False       False
# 9088555         False                   False     False       False
# 10477276        False                   False     False       False
# 5050707         False                   False     False       False
# 7847913         False                   False     False       False
# 2389282         False                   False     False       False
# 2162002         False                   False     False       False
# 1893743         False                    True     False       False
# 8936405          True                   False      True        True
# 7498215         False                   False     False       False
# 2434646          True                   False     False       False
# 8243407         False                   False     False       False
# 7390055         False                   False     False        True
# 9170822         False                   False     False       False
# 4242326         False                   False      True        True
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 5929667                      False         False           False       NaN
# 7667740                      False         False           False       NaN
# 11897407                     False         False           False       NaN
# 3545185                      False         False           False       NaN
# 464014                       False          True           False       NaN
# 6639697                      False         False           False       NaN
# 9088555                      False          True           False       NaN
# 10477276                     False         False           False       NaN
# 5050707                      False         False           False       1.0
# 7847913                      False         False           False       NaN
# 2389282                      False         False           False       NaN
# 2162002                      False         False           False       6.0
# 1893743                      False         False           False       NaN
# 8936405                      False         False           False       NaN
# 7498215                      False         False           False       NaN
# 2434646                      False         False           False       NaN
# 8243407                      False         False           False       NaN
# 7390055                      False         False           False       NaN
# 9170822                      False         False           False       NaN
# 4242326                      False         False           False       NaN
#
# [20 rows x 34 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 7577732   1112349077      JBdbXQ5          0   FEM  24.0         -      -
# 1754367   1112352347      ZDr6mK1          1  MASC  23.0         -      -
# 6419817   1112094756      8MPwLkx          0   FEM  25.0         -      -
# 2081376   1112362627      EzlXNmJ          1   FEM  49.0         -      -
# 4620012   1112354604      KBrXwPX          1  MASC  38.0         -      -
# 10137361  1112366989       E8xJ1N          0   FEM  42.0         -      -
# 5236956   1111995554      akjaW2q          1   FEM  34.0         -      -
# 10910256  1112420745      Yj539aY          0  MASC  21.0         -      -
# 925847    1112280868      YjrX6RX          1  MASC  22.0         -      -
# 1625603   1112393836      rmvrev1          1  MASC  27.0         -      -
# 10070979  1112372095      QNrYbwe          0  MASC  24.0         -      -
# 8909437   1112341365       6V2mZr          0   FEM  42.0         -      -
# 8847344   1112366913      4rWzx4P          0   FEM  25.0         -      -
# 8622883   1112293428      96XvpxY          0   FEM  19.0         -      -
# 4969481   1112429967      qe2VLPL          1   FEM  19.0         -      -
# 11196030  1112433312      4rP0vM0          0  MASC  28.0         -      -
# 8530638   1112279014       6Oea3j          0   FEM  34.0         -      -
# 5737048   1112464175      pzjXxQb          1  MASC  30.0         -      -
# 821500    1112431304      JBrXlxp          1   FEM  20.0         -      -
# 6419810   1112094756       81RMp3          0   FEM  37.0         -      -
#
#               Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 7577732          -         -   Graduado    ...     False              False
# 1754367          -         -   Graduado    ...     False              False
# 6419817          -         -          -    ...     False              False
# 2081376          -         -   Graduado    ...     False              False
# 4620012   Graduado  Graduado   Graduado    ...     False               True
# 10137361         -         -          -    ...     False              False
# 5236956   Graduado         -   Graduado    ...     False               True
# 10910256         -         -          -    ...     False               True
# 925847           -         -   Graduado    ...     False              False
# 1625603          -         -   Graduado    ...     False               True
# 10070979         -         -   Graduado    ...     False              False
# 8909437          -         -          -    ...     False              False
# 8847344          -         -   En Curso    ...     False              False
# 8622883          -         -   Graduado    ...     False              False
# 4969481          -         -   En Curso    ...     False               True
# 11196030         -         -   Graduado    ...     False               True
# 8530638          -         -   Graduado    ...     False              False
# 5737048   En Curso         -   Graduado    ...     False              False
# 821500           -         -          -    ...     False              False
# 6419810          -  Graduado   Graduado    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 7577732          True                   False     False       False
# 1754367         False                   False     False       False
# 6419817         False                   False     False       False
# 2081376         False                   False     False       False
# 4620012         False                   False     False        True
# 10137361        False                   False     False       False
# 5236956         False                   False     False       False
# 10910256        False                   False     False       False
# 925847          False                   False     False       False
# 1625603          True                    True     False       False
# 10070979        False                   False     False       False
# 8909437          True                   False     False       False
# 8847344         False                   False     False       False
# 8622883         False                   False     False       False
# 4969481         False                   False     False       False
# 11196030        False                   False     False       False
# 8530638         False                   False     False       False
# 5737048         False                   False     False       False
# 821500          False                   False     False       False
# 6419810         False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 7577732                      False          True           False       0.0
# 1754367                      False         False           False       0.0
# 6419817                      False         False           False       0.0
# 2081376                      False         False           False       1.0
# 4620012                      False         False           False       0.0
# 10137361                     False         False           False       0.0
# 5236956                      False         False           False       0.0
# 10910256                     False         False           False       0.0
# 925847                       False         False           False       0.0
# 1625603                      False         False           False       0.0
# 10070979                     False          True           False       0.0
# 8909437                      False         False           False       0.0
# 8847344                      False         False           False       0.0
# 8622883                      False         False           False       0.0
# 4969481                      False         False           False       4.0
# 11196030                     False          True           False       0.0
# 8530638                      False          True           False       0.0
# 5737048                      False         False           False       1.0
# 821500                       False         False           False       1.0
# 6419810                      False         False           False       0.0
#
# [20 rows x 34 columns]

# %%
zonas=avisos['nombre_zona'].value_counts().index
postulaciones['nombre_zona']=postulaciones['nombre_zona'].replace(zonas, range(len(zonas)))

tipos_de_trabajo=avisos['tipo_de_trabajo'].value_counts().index
postulaciones['tipo_de_trabajo']=postulaciones['tipo_de_trabajo'].replace(tipos_de_trabajo, range(len(tipos_de_trabajo)))

niveles=avisos['nivel_laboral'].value_counts().index
postulaciones['nivel_laboral']=postulaciones['nivel_laboral'].replace(niveles, range(len(niveles)))

areas=avisos['nombre_area'].value_counts().index
postulaciones['nombre_area']=postulaciones['nombre_area'].replace(areas, range(len(areas)))

doct=postulantes['Doctorado'].value_counts().index
postulaciones['Doctorado']=postulaciones['Doctorado'].replace(doct, range(len(doct)))

master=postulantes['Master'].value_counts().index
postulaciones['Master']=postulaciones['Master'].replace(master, range(len(master)))

otro=postulantes['Otro'].value_counts().index
postulaciones['Otro']=postulaciones['Otro'].replace(otro, range(len(otro)))

posgrado=postulantes['Posgrado'].value_counts().index
postulaciones['Posgrado']=postulaciones['Posgrado'].replace(posgrado, range(len(posgrado)))

sec=postulantes['Secundario'].value_counts().index
postulaciones['Secundario']=postulaciones['Secundario'].replace(sec, range(len(sec)))

terc=postulantes['Terciario/Técnico'].value_counts().index
postulaciones['Terciario/Técnico']=postulaciones['Terciario/Técnico'].replace(terc, range(len(terc)))

univ=postulantes['Universitario'].value_counts().index
postulaciones['Universitario']=postulaciones['Universitario'].replace(univ, range(len(univ)))

sexo=postulantes['sexo'].value_counts().index
postulaciones['sexo']=postulaciones['sexo'].replace(sexo, range(len(sexo)))
postulaciones.dtypes
# Out:
# idaviso                        int64
# idpostulante                  object
# sepostulo                      int64
# sexo                           int64
# edad                         float64
# Doctorado                      int64
# Master                         int64
# Otro                           int64
# Posgrado                       int64
# Secundario                     int64
# Terciario/Técnico              int64
# Universitario                  int64
# titulo                        object
# nombre_zona                    int64
# tipo_de_trabajo                int64
# nivel_laboral                  int64
# nombre_area                    int64
# denominacion_empresa          object
# titulo_uppercase                bool
# ingles                          bool
# experiencia                     bool
# paquete_office                  bool
# liderazgo                       bool
# secundario                      bool
# viajar                          bool
# empresa_importante              bool
# capacitacion                    bool
# remuneracion_pretendida         bool
# graduados                       bool
# estudiantes                     bool
# conocimientos_especificos       bool
# buen_ambiente                   bool
# discriminacion                  bool
# cantidad                     float64
# dtype: object

# %%
train, test=train_test_split(postulaciones,test_size=0.10)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
# Out:
# Train:  11098950 Test:  1233217

# %%
c=RandomForestClassifier(n_estimators=100,min_samples_split=100,n_jobs=-1,random_state=0)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl") 
dt=c.fit(x_train,y_train)

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 73.7946363048839

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/RF.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/RF.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo   edad Doctorado    Master Otro  \
# 537    71018  1112461994       E9BlVz  MASC   32.0         -         -    -
# 10229  89962  1112467175      LNKolNk  MASC   19.0         -         -    -
# 82030  29966  1112374943       YRBeP1   FEM   32.0         -         -    -
# 88501  45259  1112428081       YAWjZY   FEM   38.0         -         -    -
# 33460   8072  1111753681      kPjOY9j  MASC   24.0         -         -    -
# 46722   2300  1111234719         eZ3p  MASC   42.0         -  Graduado    -
# 62326  78566  1112464512      rm2Rd4b   FEM   26.0         -         -    -
# 63675  40767  1112420109        E813J  MASC   49.0         -         -    -
# 53232  32181  1112392176      xkP3Prx   FEM   27.0         -         -    -
# 11073  25848  1112334806      0zPVmrv  MASC  200.0         -         -    -
#
#        Posgrado Secundario    ...    viajar empresa_importante capacitacion  \
# 537           -          -    ...     False              False        False
# 10229         -          -    ...     False              False         True
# 82030         -   Graduado    ...     False              False        False
# 88501         -   Graduado    ...     False              False        False
# 33460         -   Graduado    ...     False              False        False
# 46722         -   Graduado    ...     False              False        False
# 62326         -   Graduado    ...     False              False         True
# 63675  Graduado   Graduado    ...     False              False        False
# 53232         -   Graduado    ...     False              False        False
# 11073         -   Graduado    ...     False              False         True
#
#       remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 537                     False     False        True                     False
# 10229                   False     False        True                     False
# 82030                   False     False        True                     False
# 88501                   False      True       False                     False
# 33460                    True     False       False                     False
# 46722                   False     False       False                      True
# 62326                   False     False       False                     False
# 63675                   False     False       False                     False
# 53232                   False     False       False                     False
# 11073                   False     False       False                     False
#
#       buen_ambiente  discriminacion  cantidad
# 537           False           False       4.0
# 10229          True           False       0.0
# 82030         False           False       0.0
# 88501         False           False       0.0
# 33460         False           False       0.0
# 46722         False            True       0.0
# 62326          True           False       1.0
# 63675         False           False       0.0
# 53232          True           False       1.0
# 11073          True           False       1.0
#
# [10 rows x 34 columns]

# %%
zonas=avisos['nombre_zona'].value_counts().index
prediccion['nombre_zona']=prediccion['nombre_zona'].replace(zonas, range(len(zonas)))

tipos_de_trabajo=avisos['tipo_de_trabajo'].value_counts().index
prediccion['tipo_de_trabajo']=prediccion['tipo_de_trabajo'].replace(tipos_de_trabajo, range(len(tipos_de_trabajo)))

niveles=avisos['nivel_laboral'].value_counts().index
prediccion['nivel_laboral']=prediccion['nivel_laboral'].replace(niveles, range(len(niveles)))

areas=avisos['nombre_area'].value_counts().index
prediccion['nombre_area']=prediccion['nombre_area'].replace(areas, range(len(areas)))

doct=postulantes['Doctorado'].value_counts().index
prediccion['Doctorado']=prediccion['Doctorado'].replace(doct, range(len(doct)))

master=postulantes['Master'].value_counts().index
prediccion['Master']=prediccion['Master'].replace(master, range(len(master)))

otro=postulantes['Otro'].value_counts().index
prediccion['Otro']=prediccion['Otro'].replace(otro, range(len(otro)))

posgrado=postulantes['Posgrado'].value_counts().index
prediccion['Posgrado']=prediccion['Posgrado'].replace(posgrado, range(len(posgrado)))

sec=postulantes['Secundario'].value_counts().index
prediccion['Secundario']=prediccion['Secundario'].replace(sec, range(len(sec)))

terc=postulantes['Terciario/Técnico'].value_counts().index
prediccion['Terciario/Técnico']=prediccion['Terciario/Técnico'].replace(terc, range(len(terc)))

univ=postulantes['Universitario'].value_counts().index
prediccion['Universitario']=prediccion['Universitario'].replace(univ, range(len(univ)))

sexo=postulantes['sexo'].value_counts().index
prediccion['sexo']=prediccion['sexo'].replace(sexo, range(len(sexo)))
prediccion.dtypes
# Out:
# id                             int64
# idaviso                        int64
# idpostulante                  object
# sexo                           int64
# edad                         float64
# Doctorado                      int64
# Master                         int64
# Otro                           int64
# Posgrado                       int64
# Secundario                     int64
# Terciario/Técnico              int64
# Universitario                  int64
# titulo                        object
# nombre_zona                    int64
# tipo_de_trabajo                int64
# nivel_laboral                  int64
# nombre_area                    int64
# denominacion_empresa          object
# titulo_uppercase                bool
# ingles                          bool
# experiencia                     bool
# paquete_office                  bool
# liderazgo                       bool
# secundario                      bool
# viajar                          bool
# empresa_importante              bool
# capacitacion                    bool
# remuneracion_pretendida         bool
# graduados                       bool
# estudiantes                     bool
# conocimientos_especificos       bool
# buen_ambiente                   bool
# discriminacion                  bool
# cantidad                     float64
# dtype: object

# %%
x_final=prediccion[features]
y_final=c.predict(x_final)
y_final
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
prediccion['sepostulo']=y_final

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad  Doctorado  Master  Otro  Posgrado  \
# 0   0   739260       6M9ZQR     0  42.0          1       0     0         0
# 1   1   739260       6v1xdL     1  30.0          0       0     1         0
# 2   2   739260       ezRKm9     0  36.0          0       0     0         0
# 3   3   758580       1Q35ej     1  68.0          0       0     0         1
# 4   4   758580       EAN4J6     0  32.0          0       0     0         0
#
#    Secundario    ...      empresa_importante  capacitacion  \
# 0           0    ...                   False         False
# 1           1    ...                   False         False
# 2           0    ...                   False         False
# 3           0    ...                   False         False
# 4           1    ...                   False         False
#
#   remuneracion_pretendida  graduados  estudiantes  conocimientos_especificos  \
# 0                   False      False        False                      False
# 1                   False      False        False                      False
# 2                   False      False        False                      False
# 3                   False      False        False                      False
# 4                   False      False        False                      False
#
#    buen_ambiente discriminacion  cantidad  sepostulo
# 0          False          False       0.0          0
# 1          False          False       0.0          0
# 2          False          False       0.0          0
# 3          False          False       0.0          0
# 4          False          False       0.0          0
#
# [5 rows x 35 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0          0
# 1   1          0
# 2   2          0
# 3   3          0
# 4   4          0

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion4.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.51894
