# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas2=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2=vistas2.rename(columns={'idAviso': 'idaviso'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q        15
# 1        0005E        58
# 2        000R8        14
# 3        001XE        26
# 4        003k9        32

# %%
vistas2=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           2          28
# 1    48375       RwVdKR           1          15
# 2   169730        1KjXB           2          99
# 3   169730       2AKzxa           2           2
# 4   169730        6LJ64           1          23

# %%
vistas2['cantidad']=vistas2['cantidad_x']/vistas2['cantidad_y']
vistas2.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas=vistas2
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.071429
# 1    48375       RwVdKR  0.066667
# 2   169730        1KjXB  0.020202
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.043478

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/5.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/3.csv").sample(len(postulaciones2)//2).reset_index(drop=True))
print(len(postulaciones2))
postulaciones2
# Out:
# 9906801
#             idaviso idpostulante  sepostulo
# 0        1112045232         NM5M          0
# 1        1112486703         NM5M          0
# 2        1112463030         NM5M          0
# 3        1112017891         NM5M          0
# 4        1112445183         5awk          0
# 5        1111353195         5awk          0
# 6        1112119639         5awk          0
# 7        1112466739         5awk          0
# 8        1112107934         5awk          0
# 9        1112261241         5awk          0
# 10       1112448566         5awk          0
# 11       1112297661         5awk          0
# 12       1112466364         5awk          0
# 13       1112260565         5awk          0
# 14       1112475815         5awk          0
# 15       1112344665         5awk          0
# 16       1112425007         5awk          0
# 17       1112354695         5awk          0
# 18       1112321928         5awk          0
# 19       1111946213         5awk          0
# 20       1112312221         ZaO5          0
# 21       1112400993         ZaO5          0
# 22       1112425130         ZaO5          0
# 23       1111866407         ZaO5          0
# 24       1112386793         ZaO5          0
# 25       1111673400         ZaO5          0
# 26       1112254888         ZaO5          0
# 27       1112308845         ZaO5          0
# 28       1112468033         ZaO5          0
# 29       1112202307         ZaO5          0
# ...             ...          ...        ...
# 3302237  1112185882      5mPKZwG          0
# 3302238  1112249640      VNr4DBz          0
# 3302239  1112431346      jkMqBBb          0
# 3302240  1112280950      JBr2EZE          0
# 3302241  1112285027      6rPDzxv          0
# 3302242  1112254466      2zk1oxV          0
# 3302243  1112205105      Yj5dXWY          0
# 3302244  1112371964      bOz8xEb          0
# 3302245  1112451853      1QrVeoO          0
# 3302246  1112447963      VNrMrmE          0
# 3302247  1112270216      DrXP0WP          0
# 3302248  1112406827      2zPXMPo          0
# 3302249  1111703496       5qB6Mw          0
# 3302250  1112278621      qevW0W1          0
# 3302251  1112417494       amGwM0          0
# 3302252  1112398356      8MPdDEO          0
# 3302253  1112271164      JBdAl5E          0
# 3302254  1111709950      PmaxxAj          0
# 3302255  1112378735      EzpBoj4          0
# 3302256  1112421812       EDl5v8          0
# 3302257  1112308564      6rPXJjr          0
# 3302258  1112430727      RzMN0A6          0
# 3302259  1112322540      KBrRNMm          0
# 3302260  1112320768      2zPj1Kv          0
# 3302261  1112300306      QNPJb8N          0
# 3302262  1112282545      akjYZPN          0
# 3302263  1111753928       6vQGZj          0
# 3302264  1112393067       Y9jqR1          0
# 3302265  1111636821      96Xk5pw          0
# 3302266  1112231821      ow20jOa          0
#
# [9906801 rows x 3 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 16511335
# 16455043

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 7883970   1112429440      4rPZzZ5          0   FEM  26.0         -      -
# 4509375   1112286522      GNJv4RA          0  MASC  25.0         -      -
# 15455405  1112341765       ZOejK8          0  MASC  32.0         -      -
# 9969388   1112229354      bOj1d2B          1  MASC  22.0         -      -
# 15292323  1111765305      6r2kON3          0   FEM  31.0         -      -
# 14422348  1112325437      96ZOA3Z          0  MASC  22.0         -      -
# 9542442   1112452103       64bLOj          1  MASC  28.0         -      -
# 13576708  1111686486      0zP08Dr          0  MASC  22.0         -      -
# 15580496  1112355121      ow20YVe          0   FEM  19.0         -      -
# 11732038  1112411633       1ZdLVE          0  MASC  57.0         -      -
# 13939644  1112463331      Pm4z9p0          0   FEM  31.0         -      -
# 14601693  1112402544      VNkb39j          0  MASC  36.0         -      -
# 12722292  1112311781      PmLDNjj          0  MASC  21.0         -      -
# 6670093   1112356526      KBekrYA          1   FEM  21.0         -      -
# 10605859  1112226419      bOV23r9          0  MASC  19.0         -      -
# 5392228   1112312443      2zL5eD0          0   FEM  29.0         -      -
# 5666303   1112451302       866k4j          1  MASC  53.0         -      -
# 9055446   1111009679      Bm5mGRa          1   FEM  28.0         -      -
# 15039043  1112369374      BmD11RR          0   FEM  45.0         -      -
# 13676102  1111766789      rmRK4Gb          1   FEM  28.0         -      -
#
#               Otro Posgrado Secundario    ...    viajar empresa_importante  \
# 7883970          -        -          -    ...     False              False
# 4509375          -        -   Graduado    ...     False               True
# 15455405         -        -   Graduado    ...     False               True
# 9969388          -        -          -    ...     False               True
# 15292323  Graduado        -          -    ...     False               True
# 14422348         -        -   Graduado    ...     False              False
# 9542442          -        -          -    ...     False               True
# 13576708         -        -   Graduado    ...     False               True
# 15580496         -        -   Graduado    ...     False              False
# 11732038         -        -   Graduado    ...     False              False
# 13939644         -        -   Graduado    ...     False              False
# 14601693         -        -   Graduado    ...     False              False
# 12722292         -        -   Graduado    ...     False               True
# 6670093          -        -   Graduado    ...     False               True
# 10605859         -        -   En Curso    ...     False               True
# 5392228          -        -          -    ...     False               True
# 5666303          -        -   Graduado    ...     False              False
# 9055446          -        -   Graduado    ...     False               True
# 15039043         -        -   Graduado    ...     False              False
# 13676102         -        -   Graduado    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 7883970         False                   False     False       False
# 4509375         False                   False     False       False
# 15455405        False                   False     False       False
# 9969388         False                   False     False        True
# 15292323        False                   False     False       False
# 14422348        False                   False     False       False
# 9542442         False                   False     False       False
# 13576708        False                   False     False       False
# 15580496        False                   False     False       False
# 11732038        False                   False     False       False
# 13939644        False                   False     False       False
# 14601693        False                   False     False       False
# 12722292         True                   False     False       False
# 6670093         False                   False     False       False
# 10605859        False                   False     False       False
# 5392228         False                   False     False       False
# 5666303         False                   False     False       False
# 9055446         False                   False     False       False
# 15039043        False                   False     False       False
# 13676102        False                   False      True        True
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 7883970                      False         False           False       NaN
# 4509375                      False         False           False       NaN
# 15455405                     False         False           False       NaN
# 9969388                      False          True           False       NaN
# 15292323                     False         False           False       NaN
# 14422348                     False         False           False       NaN
# 9542442                      False         False           False  0.001818
# 13576708                     False         False           False       NaN
# 15580496                     False          True           False       NaN
# 11732038                     False          True           False       NaN
# 13939644                     False         False           False       NaN
# 14601693                     False         False           False       NaN
# 12722292                     False         False           False       NaN
# 6670093                      False         False           False       NaN
# 10605859                     False         False           False       NaN
# 5392228                      False          True           False       NaN
# 5666303                      False         False           False  0.021739
# 9055446                      False         False           False       NaN
# 15039043                     False         False           False       NaN
# 13676102                     False         False           False       NaN
#
# [20 rows x 36 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 7141768   1112316657       8QlXr3          0   FEM  32.0         -      -
# 9754172   1112426761      vVjbGAX          1   FEM  55.0         -      -
# 12928759  1112367899      YjAe8NV          0   FEM  20.0         -      -
# 6395965   1112339930      VNJmpvz          1  MASC  42.0         -      -
# 8863263   1112432391      8MP8E6z          0   FEM  43.0         -      -
# 6942640   1112283554      kP6o5rV          1   FEM  25.0         -      -
# 12364197  1112444553       536R1k          0   FEM  27.0         -      -
# 7568474   1112264061      qekpkAL          0   FEM  35.0         -      -
# 10614694  1112396117       8jPpBz          0   FEM  54.0         -      -
# 14721816  1112288883      RzrQbBO          1   FEM  29.0         -      -
# 4389395   1112457744       ZL8oeZ          1  MASC  46.0         -      -
# 9077188   1112297717      Bm5oN6R          1   FEM  36.0         -      -
# 12178324  1112353096       1JLA6Q          0   FEM  27.0         -      -
# 9404368   1112174457      NzrW185          0   FEM  43.0         -      -
# 1197790   1112366314      QNrZZMl          0   FEM  32.0         -      -
# 14833351  1112202349      8MrJJ9O          0  MASC  22.0         -      -
# 12264194  1111574485      BmaVlp2          0   FEM  27.0         -      -
# 10951808  1112264834      DrJRZ35          1   FEM  23.0         -      -
# 6607776   1112426116       5Q0xwZ          1  MASC  35.0         -      -
# 2766971   1112349052       ZBZOk1          0   FEM  28.0         -      -
#
#               Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 7141768          -         -          -    ...     False              False
# 9754172          -  Graduado   Graduado    ...     False              False
# 12928759  Graduado         -          -    ...     False              False
# 6395965          -         -   Graduado    ...     False              False
# 8863263   Graduado         -   Graduado    ...     False              False
# 6942640   Graduado         -   Graduado    ...     False              False
# 12364197         -         -          -    ...     False              False
# 7568474          -         -   Graduado    ...     False              False
# 10614694         -         -          -    ...     False              False
# 14721816         -         -   Graduado    ...     False              False
# 4389395          -         -   Graduado    ...     False               True
# 9077188          -         -   Graduado    ...     False              False
# 12178324         -         -   Graduado    ...     False               True
# 9404368          -  Graduado   Graduado    ...     False               True
# 1197790          -         -   Graduado    ...     False              False
# 14833351  Graduado         -   En Curso    ...     False              False
# 12264194         -         -   Graduado    ...     False              False
# 10951808         -         -   Graduado    ...     False              False
# 6607776   Graduado         -          -    ...     False              False
# 2766971          -         -          -    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 7141768          True                   False     False       False
# 9754172          True                   False     False       False
# 12928759         True                   False     False       False
# 6395965         False                   False     False       False
# 8863263          True                   False     False       False
# 6942640          True                   False     False       False
# 12364197        False                   False     False       False
# 7568474          True                   False     False       False
# 10614694        False                   False     False       False
# 14721816        False                   False     False       False
# 4389395         False                   False      True        True
# 9077188         False                   False     False       False
# 12178324        False                    True     False       False
# 9404368         False                   False     False       False
# 1197790         False                   False     False       False
# 14833351        False                   False     False       False
# 12264194        False                   False     False       False
# 10951808        False                   False     False       False
# 6607776         False                   False     False       False
# 2766971         False                   False     False        True
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 7141768                      False          True           False  0.000000
# 9754172                      False         False           False  0.111111
# 12928759                     False          True           False  0.000000
# 6395965                      False         False           False  0.000000
# 8863263                      False          True           False  0.000000
# 6942640                      False         False           False  0.000000
# 12364197                     False         False           False  0.000000
# 7568474                      False          True           False  0.000000
# 10614694                     False         False           False  0.000000
# 14721816                     False         False           False  0.000000
# 4389395                      False         False           False  0.010309
# 9077188                      False         False           False  0.000000
# 12178324                     False         False           False  0.000000
# 9404368                      False         False           False  0.000000
# 1197790                      False         False           False  0.000000
# 14833351                     False         False           False  0.000000
# 12264194                     False         False           False  0.000000
# 10951808                     False         False           False  0.000000
# 6607776                      False         False           False  0.003831
# 2766971                      False         False           False  0.000000
#
# [20 rows x 36 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
vistas2=0
# Out:
# Train:  15040283 Test:  791594

# %%
gc.collect()
# Out:
# 156

# %%
c=lgb.LGBMClassifier(learning_rate=0.005,objective='binary',num_leaves=6000,max_depth=13,n_estimators=1200,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 77.48176464197556
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV14.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV14.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado Master      Otro  \
# 2884   74837  1112463897       EPdBv0   FEM  29.0         -      -         -
# 84511  45336  1112428183       88joxR   FEM  32.0         -      -         -
# 89322  49774  1112438527       5d1oYZ  MASC  38.0         -      -         -
# 92179  91157  1112470541       1lGv8L   FEM  45.0         -      -         -
# 96885  96564  1112494684       YRNqdr  MASC  41.0         -      -         -
# 37686  71165  1112462019      96M1Dxw  MASC  29.0         -      -         -
# 80344  64404  1112458199      kPjkLaV   FEM  42.0         -      -         -
# 51864   3919  1111417142       e0YwEE  MASC  43.0         -      -  Graduado
# 21314  82192  1112466195      mzb5qOQ   FEM  26.0         -      -         -
# 7685   89181  1112467020      ekojk52   FEM  22.0         -      -         -
#
#        Posgrado Secundario    ...    viajar empresa_importante capacitacion  \
# 2884          -          -    ...     False              False        False
# 84511         -          -    ...     False               True        False
# 89322  Graduado          -    ...     False              False        False
# 92179         -          -    ...     False              False        False
# 96885         -   Graduado    ...     False               True        False
# 37686         -   Graduado    ...     False               True         True
# 80344         -   Graduado    ...     False              False        False
# 51864         -          -    ...     False               True        False
# 21314         -   Graduado    ...     False              False         True
# 7685          -   Graduado    ...     False              False         True
#
#       remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 2884                    False     False       False                     False
# 84511                   False     False       False                     False
# 89322                   False     False       False                     False
# 92179                   False     False       False                     False
# 96885                   False     False       False                     False
# 37686                   False     False       False                     False
# 80344                   False     False       False                     False
# 51864                   False     False       False                     False
# 21314                   False     False       False                     False
# 7685                    False     False       False                     False
#
#       buen_ambiente  discriminacion  cantidad
# 2884          False           False  0.009259
# 84511         False           False  0.000000
# 89322         False           False  0.000000
# 92179          True           False  0.000000
# 96885          True           False  0.000000
# 37686         False           False  0.020833
# 80344         False           False  0.100000
# 51864         False           False  0.000000
# 21314         False           False  0.019608
# 7685           True           False  0.015152
#
# [10 rows x 36 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.76953096, 0.23046904],
#        [0.80345631, 0.19654369],
#        [0.7779683 , 0.2220317 ],
#        ...,
#        [0.94066048, 0.05933952],
#        [0.87010911, 0.12989089],
#        [0.96729075, 0.03270925]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     empresa_importante capacitacion  \
# 0   Graduado    ...                  False        False
# 1          -    ...                  False        False
# 2   Graduado    ...                  False        False
# 3   Graduado    ...                  False        False
# 4          -    ...                  False        False
#
#   remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 0                   False     False       False                     False
# 1                   False     False       False                     False
# 2                   False     False       False                     False
# 3                   False     False       False                     False
# 4                   False     False       False                     False
#
#   buen_ambiente discriminacion  cantidad  sepostulo
# 0         False          False       0.0   0.230469
# 1         False          False       0.0   0.196544
# 2         False          False       0.0   0.222032
# 3         False          False       0.0   0.086806
# 4         False          False       0.0   0.032458
#
# [5 rows x 37 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.230469
# 1   1   0.196544
# 2   2   0.222032
# 3   3   0.086806
# 4   4   0.032458

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion29.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5210018234370081
