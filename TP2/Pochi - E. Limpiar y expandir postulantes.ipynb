# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
postulantes_ge = pd.read_csv("Data/fiuba_entrenamiento/postulantes_ge.csv")
postulantes_ge.head()
# Out:
#   idpostulante fechanacimiento  sexo
# 0         NM5M      1970-12-03   FEM
# 1         5awk      1962-12-04   FEM
# 2         ZaO5      1978-08-10   FEM
# 3         NdJl      1969-05-09  MASC
# 4         eo2p      1981-02-16  MASC

# %%
postulantes_educacion = pd.read_csv("Data/fiuba_entrenamiento/postulantes_educacion.csv")
postulantes_educacion.head()
# Out:
#   idpostulante         nombre    estado
# 0         NdJl       Posgrado  En Curso
# 1         8BkL  Universitario  En Curso
# 2         1d2B  Universitario  En Curso
# 3         NPBx  Universitario  En Curso
# 4         NPBx         Master  En Curso

# %%
postulantes_ge['fechanacimiento'] = pd.to_datetime(postulantes_ge['fechanacimiento'], errors = 'coerce')
postulantes_ge['edad'] = datetime.now() - postulantes_ge['fechanacimiento']
postulantes_ge['edad']=pd.TimedeltaIndex(postulantes_ge['edad']).days;
postulantes_ge['edad']=np.floor(postulantes_ge['edad']/365);
postulantes_ge.drop(['fechanacimiento'],axis=1, inplace=True);
postulantes_ge.head()
# Out:
#   idpostulante  sexo  edad
# 0         NM5M   FEM  47.0
# 1         5awk   FEM  55.0
# 2         ZaO5   FEM  39.0
# 3         NdJl  MASC  49.0
# 4         eo2p  MASC  37.0

# %%
postulantes_ge.edad.mean()
# Out:
# 30.77759137933916

# %%
def mayor_estado(estados):
    retval="Abandonado"
    for elem in estados:
        if(elem=="En Curso"): retval=elem;
        if(elem=="Graduado"): retval=elem;
    return retval
group = postulantes_educacion.groupby(['idpostulante','nombre'], as_index=False).agg({'estado':mayor_estado})
group.head()
# Out:
#   idpostulante             nombre      estado
# 0      0z5Dmrd      Universitario    Graduado
# 1      0z5JW1r               Otro    Graduado
# 2      0z5JW1r         Secundario    Graduado
# 3      0z5JW1r  Terciario/Técnico    Graduado
# 4      0z5JW1r      Universitario  Abandonado

# %%
group2=group.pivot_table(values='estado', index=['idpostulante'], columns='nombre', aggfunc='first').reset_index()
group2=group2.fillna("-")
group2.head()
# Out:
# nombre idpostulante Doctorado Master      Otro Posgrado Secundario  \
# 0           0z5Dmrd         -      -         -        -          -
# 1           0z5JW1r         -      -  Graduado        -   Graduado
# 2           0z5VvGv         -      -         -        -   Graduado
# 3           0zB01pE         -      -         -        -          -
# 4           0zB026d         -      -         -        -   Graduado
#
# nombre Terciario/Técnico Universitario
# 0                      -      Graduado
# 1               Graduado    Abandonado
# 2                      -             -
# 3               Graduado    Abandonado
# 4               Graduado             -

# %%
postulantes=pd.merge(postulantes_ge,group2, on='idpostulante',how='left');
postulantes.fillna("-")
postulantes.head()
# Out:
#   idpostulante  sexo  edad Doctorado    Master Otro  Posgrado Secundario  \
# 0         NM5M   FEM  47.0         -         -    -         -   Graduado
# 1         5awk   FEM  55.0         -         -    -         -          -
# 2         ZaO5   FEM  39.0         -         -    -         -          -
# 3         NdJl  MASC  49.0         -         -    -  En Curso          -
# 4         eo2p  MASC  37.0         -  Graduado    -         -   Graduado
#
#   Terciario/Técnico Universitario
# 0                 -             -
# 1          Graduado      Graduado
# 2          Graduado    Abandonado
# 3                 -      Graduado
# 4                 -      Graduado

# %%
edad_mean = postulantes.edad.mean()
postulantes.edad=postulantes.edad.fillna(200)
postulantes=postulantes.fillna("-")
postulantes=postulantes.replace("NaN", "-")
postulantes.sample(20)
# Out:
#        idpostulante  sexo  edad Doctorado    Master      Otro Posgrado  \
# 81340       3Nz5NV6   FEM  41.0         -         -         -        -
# 125612      JBxdW8b   FEM  52.0         -         -         -        -
# 96688       RzlxbOx   FEM  27.0         -  Graduado  En Curso        -
# 218959       EAV1G0   FEM  31.0         -         -         -        -
# 449074      KBrbwG2   FEM  23.0         -         -         -        -
# 246347       5wbRoz  MASC  31.0         -         -         -        -
# 22862        88LRDz  MASC  36.0         -         -  Graduado        -
# 221269       ZRYjVE   FEM  33.0         -         -         -        -
# 330296      6r5K3DL   FEM  31.0         -         -         -        -
# 309851      MVPpJNe   FEM  42.0         -         -         -        -
# 340029      DrXAzWX   FEM  57.0         -         -         -        -
# 268580      GNXBDdK  MASC  57.0         -         -         -        -
# 339898      pzd3DkZ   FEM  31.0         -         -         -        -
# 400438      VNrAe3z   FEM  20.0         -         -         -        -
# 123779      4rN61k5   FEM  20.0         -         -         -        -
# 263082      VNk8d4M  MASC  28.0         -         -         -        -
# 351631      X95GK2O  MASC  27.0         -         -         -        -
# 283883      mzVLGG9   FEM  46.0         -         -  Graduado        -
# 28077        64kQlL   FEM  38.0         -         -         -        -
# 47692       MVdrYzv  MASC  30.0         -         -         -        -
#
#        Secundario Terciario/Técnico Universitario
# 81340           -                 -      Graduado
# 125612   Graduado                 -             -
# 96688           -                 -      Graduado
# 218959          -                 -      En Curso
# 449074   Graduado                 -      En Curso
# 246347   Graduado                 -             -
# 22862           -          En Curso      Graduado
# 221269   Graduado          Graduado             -
# 330296          -                 -      Graduado
# 309851          -        Abandonado             -
# 340029          -                 -             -
# 268580          -                 -      Graduado
# 339898   Graduado                 -      Graduado
# 400438          -          En Curso             -
# 123779          -                 -      En Curso
# 263082   En Curso                 -             -
# 351631   En Curso                 -             -
# 283883   Graduado          En Curso             -
# 28077           -                 -      En Curso
# 47692    Graduado                 -             -

# %%
def completar_estudio_menor(estudio_menor,estudio_mayor):
    if(estudio_mayor=="Graduado"):
        return "Graduado"
    return estudio_menor;
completar_estudio_menor=np.vectorize(completar_estudio_menor)
postulantes['Secundario']=completar_estudio_menor(postulantes['Secundario'],postulantes['Universitario'])
postulantes.head()
# Out:
#   idpostulante  sexo  edad Doctorado    Master Otro  Posgrado Secundario  \
# 0         NM5M   FEM  47.0         -         -    -         -   Graduado
# 1         5awk   FEM  55.0         -         -    -         -   Graduado
# 2         ZaO5   FEM  39.0         -         -    -         -          -
# 3         NdJl  MASC  49.0         -         -    -  En Curso   Graduado
# 4         eo2p  MASC  37.0         -  Graduado    -         -   Graduado
#
#   Terciario/Técnico Universitario
# 0                 -             -
# 1          Graduado      Graduado
# 2          Graduado    Abandonado
# 3                 -      Graduado
# 4                 -      Graduado

# %%
print(postulantes.shape)
# Out:
# (505382, 10)

# %%
postulantes.drop_duplicates(['idpostulante'],keep='first',inplace=True)
postulantes.to_csv("Data/fiuba_entrenamiento/pocho/postulantes_old.csv",index=False)

# %%
# Out:
# 39.74332830432567
