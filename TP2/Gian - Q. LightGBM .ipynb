# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/1.csv")

postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones2=pd.merge(postulaciones2,postulantes,on='idpostulante')

postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones2=pd.merge(postulaciones2,avisos,on='idaviso')

postulaciones2.head()
# Out:
#       idaviso idpostulante  sepostulo  sexo  edad Doctorado Master Otro  \
# 0  1112257047      akjmXXq          0   FEM  28.0         -      -    -
# 1  1112257047      MV6b6R9          0   FEM  30.0         -      -    -
# 2  1112257047      zvxv1Rm          0   FEM  22.0         -      -    -
# 3  1112257047       8oqJzL          0  MASC  34.0         -      -    -
# 4  1112257047       ez533B          0  MASC  32.0         -      -    -
#
#   Posgrado Secundario       ...       secundario viajar empresa_importante  \
# 0        -   Graduado       ...             True  False              False
# 1        -          -       ...             True  False              False
# 2        -   Graduado       ...             True  False              False
# 3        -          -       ...             True  False              False
# 4        -   Graduado       ...             True  False              False
#
#   capacitacion remuneracion_pretendida graduados estudiantes  \
# 0         True                   False     False       False
# 1         True                   False     False       False
# 2         True                   False     False       False
# 3         True                   False     False       False
# 4         True                   False     False       False
#
#   conocimientos_especificos  buen_ambiente  discriminacion
# 0                     False          False           False
# 1                     False          False           False
# 2                     False          False           False
# 3                     False          False           False
# 4                     False          False           False
#
# [5 rows x 35 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo sexo  edad Doctorado Master Otro  \
# 0  1112257047         NM5M          1  FEM  47.0         -      -    -
# 1  1112257047       1kJqGb          1  FEM  34.0         -      -    -
# 2  1112257047       eOE9Rr          1  FEM  39.0         -      -    -
# 3  1112257047       Zrx8Xz          1  FEM  39.0         -      -    -
# 4  1112257047       ZrKNQY          1  FEM  32.0         -      -    -
#
#   Posgrado Secundario       ...       secundario viajar empresa_importante  \
# 0        -   Graduado       ...             True  False              False
# 1        -          -       ...             True  False              False
# 2        -   Graduado       ...             True  False              False
# 3        -          -       ...             True  False              False
# 4        -   Graduado       ...             True  False              False
#
#   capacitacion remuneracion_pretendida graduados estudiantes  \
# 0         True                   False     False       False
# 1         True                   False     False       False
# 2         True                   False     False       False
# 3         True                   False     False       False
# 4         True                   False     False       False
#
#   conocimientos_especificos  buen_ambiente  discriminacion
# 0                     False          False           False
# 1                     False          False           False
# 2                     False          False           False
# 3                     False          False           False
# 4                     False          False           False
#
# [5 rows x 35 columns]

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 12377268
# 12332167

# %%
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado    Master  \
# 5318269   1112461848      EzEQWE0          1  MASC  33.0         -         -
# 5833640   1112318473      GNZQGw8          1  MASC  29.0         -         -
# 7766775   1112383388      LNP4YRQ          0  MASC  22.0         -         -
# 8682406   1112205105      2zQWZZY          0   FEM  24.0         -         -
# 5924620   1112453824      LNPox2j          1  MASC  21.0         -         -
# 12279670  1112328290      akDL49m          0   FEM  26.0         -         -
# 10614215  1112308404      vVwmrjQ          0  MASC  68.0         -         -
# 9342536   1112411732      NzrAJEx          0   FEM  22.0         -         -
# 1773772   1112309688      mzVVeKO          1  MASC  55.0         -         -
# 1559061   1112410555      Pm4lXGZ          1   FEM  32.0         -         -
# 9880702   1112432540      akbP3rD          0  MASC  39.0         -         -
# 11541301  1112368036      Nzr8oQD          0  MASC  28.0         -  Graduado
# 11285457  1112274751      ak4YKjJ          0  MASC  20.0         -         -
# 8361772   1112296457      ekvzv3E          0   FEM  24.0         -         -
# 5899950   1112305844       aEO2X9          1   FEM  30.0         -         -
# 11239878  1112432715      96Zz1ba          0  MASC  23.0         -         -
# 822237    1112431304      4rm5vkK          1   FEM  40.0         -         -
# 822899    1112431304      ZDrxWRE          1   FEM  50.0         -         -
# 10435458  1111683983      xkvXNAP          0   FEM  21.0         -         -
# 4230631   1112423926      mzdOJ8Y          1  MASC  35.0         -         -
#
#               Otro Posgrado Secundario    ...    viajar empresa_importante  \
# 5318269          -        -   Graduado    ...     False              False
# 5833640          -        -          -    ...     False              False
# 7766775          -        -   Graduado    ...     False              False
# 8682406          -        -   Graduado    ...     False               True
# 5924620          -        -          -    ...     False              False
# 12279670         -        -   Graduado    ...     False              False
# 10614215  Graduado        -   Graduado    ...     False               True
# 9342536   Graduado        -   Graduado    ...     False              False
# 1773772          -        -          -    ...     False              False
# 1559061          -        -   Graduado    ...     False              False
# 9880702          -        -          -    ...     False              False
# 11541301         -        -   Graduado    ...     False               True
# 11285457         -        -   En Curso    ...     False              False
# 8361772          -        -   Graduado    ...     False               True
# 5899950          -        -   Graduado    ...     False              False
# 11239878         -        -          -    ...     False              False
# 822237           -        -          -    ...     False              False
# 822899    Graduado        -   Graduado    ...     False              False
# 10435458         -        -   Graduado    ...     False               True
# 4230631   Graduado        -          -    ...      True              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 5318269         False                   False     False       False
# 5833640         False                   False     False       False
# 7766775         False                   False     False       False
# 8682406         False                   False     False       False
# 5924620         False                   False     False       False
# 12279670        False                   False     False       False
# 10614215        False                   False     False       False
# 9342536         False                   False     False       False
# 1773772         False                   False     False       False
# 1559061         False                   False      True        True
# 9880702         False                   False     False       False
# 11541301        False                   False     False       False
# 11285457        False                    True     False       False
# 8361772         False                   False     False       False
# 5899950         False                   False     False       False
# 11239878         True                   False     False       False
# 822237          False                   False     False       False
# 822899          False                   False     False       False
# 10435458        False                   False     False       False
# 4230631          True                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 5318269                      False         False           False       3.0
# 5833640                      False         False           False       1.0
# 7766775                       True         False            True       NaN
# 8682406                      False         False           False       NaN
# 5924620                      False         False           False       2.0
# 12279670                     False         False           False       NaN
# 10614215                     False         False           False       NaN
# 9342536                      False         False           False       NaN
# 1773772                      False         False           False       NaN
# 1559061                      False         False           False       1.0
# 9880702                      False         False           False       NaN
# 11541301                     False         False           False       NaN
# 11285457                     False         False           False       NaN
# 8361772                       True         False            True       NaN
# 5899950                       True         False            True       NaN
# 11239878                     False         False           False       NaN
# 822237                       False         False           False       1.0
# 822899                       False         False           False       1.0
# 10435458                     False         False           False       NaN
# 4230631                      False          True           False       NaN
#
# [20 rows x 36 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 12248679  1112412376      xkPVL4a          0   FEM  25.0         -      -
# 11153970  1112416008      Ezez1J0          0  MASC  20.0         -      -
# 3146609   1112412238      RzrBbXo          1  MASC  26.0         -      -
# 9276123   1112316313      JBmGmBk          0  MASC  31.0         -      -
# 11417231  1112411348      1QPLppR          0  MASC  21.0         -      -
# 3095391   1112418871       1jlbKN          1   FEM  30.0         -      -
# 10952346  1112421965       1Pejjb          0  MASC  40.0         -      -
# 6620082   1112345977      JBxkzYO          0  MASC  55.0         -      -
# 8897567   1112322826       6jXGQM          0  MASC  37.0         -      -
# 5902717   1112277833      96z4Eq5          1  MASC  23.0         -      -
# 12161663  1112367793       Z1QJl5          0  MASC  30.0         -      -
# 3979394   1112373075      vVjRGKQ          1  MASC  23.0         -      -
# 9224399   1112459290      969Gzl9          0   FEM  27.0         -      -
# 8132514   1112382557      6rPEebL          0   FEM  36.0         -      -
# 8465784   1112277176      Yj5Lz9P          0  MASC  34.0         -      -
# 584620    1111455368      0zPGEZv          1  MASC  21.0         -      -
# 2162776   1112426116      wVk5EQV          1  MASC  30.0         -      -
# 8523960   1112339449      3NzeelQ          0  MASC  23.0         -      -
# 4196261   1112212786      96M2rQ5          1   FEM  47.0         -      -
# 11767102  1112274977      LNPG2QP          0   FEM  35.0         -      -
#
#               Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 12248679         -         -   Graduado    ...     False               True
# 11153970         -         -          -    ...     False              False
# 3146609          -         -   Graduado    ...     False              False
# 9276123   Graduado  Graduado   Graduado    ...     False              False
# 11417231         -         -   Graduado    ...     False              False
# 3095391          -         -   Graduado    ...     False              False
# 10952346         -         -   Graduado    ...     False              False
# 6620082          -         -   Graduado    ...     False              False
# 8897567          -         -   Graduado    ...     False              False
# 5902717          -         -          -    ...     False              False
# 12161663         -         -          -    ...     False              False
# 3979394          -         -   Graduado    ...     False               True
# 9224399          -         -   Graduado    ...     False              False
# 8132514          -         -   Graduado    ...     False              False
# 8465784          -         -   En Curso    ...     False              False
# 584620           -         -   Graduado    ...     False              False
# 2162776          -         -   Graduado    ...     False              False
# 8523960          -         -   Graduado    ...     False              False
# 4196261          -         -   Graduado    ...     False              False
# 11767102         -         -   Graduado    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 12248679        False                   False     False       False
# 11153970         True                   False     False       False
# 3146609         False                   False      True        True
# 9276123         False                   False     False       False
# 11417231        False                   False     False       False
# 3095391          True                   False     False       False
# 10952346         True                   False     False       False
# 6620082         False                   False     False       False
# 8897567          True                   False     False       False
# 5902717         False                   False     False        True
# 12161663        False                   False     False       False
# 3979394         False                   False     False       False
# 9224399          True                   False     False       False
# 8132514         False                   False     False       False
# 8465784         False                   False     False       False
# 584620          False                   False     False        True
# 2162776         False                   False     False       False
# 8523960         False                   False     False       False
# 4196261         False                   False     False       False
# 11767102        False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 12248679                     False         False           False       0.0
# 11153970                     False         False           False       0.0
# 3146609                      False         False           False       2.0
# 9276123                      False         False           False       0.0
# 11417231                     False         False           False       0.0
# 3095391                      False          True           False       1.0
# 10952346                     False          True           False       0.0
# 6620082                      False          True           False       0.0
# 8897567                      False          True           False       0.0
# 5902717                      False         False           False       0.0
# 12161663                     False         False           False       0.0
# 3979394                      False         False           False       0.0
# 9224399                      False          True           False       0.0
# 8132514                      False         False           False       0.0
# 8465784                      False          True           False       0.0
# 584620                       False         False           False       1.0
# 2162776                      False         False           False       1.0
# 8523960                      False         False           False       0.0
# 4196261                      False         False           False       0.0
# 11767102                     False         False           False       0.0
#
# [20 rows x 36 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.10)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
postulaciones2=0
# Out:
# Train:  11098950 Test:  1233217

# %%
import gc
gc.collect()
# Out:
# 0

# %%
c=lgb.LGBMClassifier(learning_rate=0.01,objective='binary',num_leaves=4096,max_depth=13,n_estimators=250,colsample_bytree=0.8,n_jobs=-1,random_state=0,max_features=None)

dt=c.fit(x_train,y_train)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 72.67626054457568
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBM.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBM.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado    Master Otro  \
# 67902  42291  1112423293       YWELWX  MASC  40.0         -         -    -
# 70941  32832  1112397590       ZRKoJ8   FEM  38.0         -         -    -
# 46768   2331  1111238486       E5axqN  MASC  46.0         -         -    -
# 6434   84550  1112466576      Rz634G9   FEM  24.0         -         -    -
# 8766   76228  1112464225      8MPdK3M  MASC  22.0         -         -    -
# 35713  84262  1112466544      zv4jKx3  MASC  36.0         -         -    -
# 19514  78959  1112464612      dYo0EWD   FEM  22.0         -         -    -
# 11069  25847  1112334806      8MrLJRL   FEM  21.0         -         -    -
# 90471  57869  1112451926       a6GvZN  MASC  48.0         -  En Curso    -
# 71839  17352  1112197441       6P2wAx   FEM  32.0         -         -    -
#
#       Posgrado Secundario    ...    viajar empresa_importante capacitacion  \
# 67902        -   Graduado    ...     False               True        False
# 70941        -          -    ...     False               True        False
# 46768        -   Graduado    ...     False              False        False
# 6434         -   Graduado    ...     False              False         True
# 8766         -   Graduado    ...     False               True        False
# 35713        -   Graduado    ...     False               True        False
# 19514        -   Graduado    ...     False              False        False
# 11069        -   Graduado    ...     False              False         True
# 90471        -   Graduado    ...     False              False        False
# 71839        -          -    ...     False               True        False
#
#       remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 67902                   False     False       False                     False
# 70941                   False     False       False                     False
# 46768                   False     False       False                     False
# 6434                    False     False       False                     False
# 8766                    False     False       False                     False
# 35713                   False      True       False                     False
# 19514                   False     False       False                     False
# 11069                   False     False       False                     False
# 90471                   False     False       False                     False
# 71839                   False     False        True                     False
#
#       buen_ambiente  discriminacion  cantidad
# 67902         False           False       1.0
# 70941          True           False       0.0
# 46768         False           False       0.0
# 6434           True           False       0.0
# 8766          False           False       0.0
# 35713         False           False       1.0
# 19514         False           False       2.0
# 11069          True           False       0.0
# 90471         False           False       0.0
# 71839         False           False       0.0
#
# [10 rows x 36 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.55287913, 0.44712087],
#        [0.58212795, 0.41787205],
#        [0.58130103, 0.41869897],
#        ...,
#        [0.84196037, 0.15803963],
#        [0.57297411, 0.42702589],
#        [0.90957099, 0.09042901]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     empresa_importante capacitacion  \
# 0   Graduado    ...                  False        False
# 1          -    ...                  False        False
# 2   Graduado    ...                  False        False
# 3   Graduado    ...                  False        False
# 4          -    ...                  False        False
#
#   remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 0                   False     False       False                     False
# 1                   False     False       False                     False
# 2                   False     False       False                     False
# 3                   False     False       False                     False
# 4                   False     False       False                     False
#
#   buen_ambiente discriminacion  cantidad  sepostulo
# 0         False          False       0.0   0.447121
# 1         False          False       0.0   0.417872
# 2         False          False       0.0   0.418699
# 3         False          False       0.0   0.329989
# 4         False          False       0.0   0.369424
#
# [5 rows x 37 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.447121
# 1   1   0.417872
# 2   2   0.418699
# 3   3   0.329989
# 4   4   0.369424

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion14.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5890557084917467
