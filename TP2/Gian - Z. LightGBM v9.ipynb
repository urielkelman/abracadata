# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/3.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/4.csv").iloc[0:len(postulaciones2)//2], ignore_index=True)
print(len(postulaciones2))
postulaciones2.head()
# Out:
# 9906801
#       idaviso idpostulante  sepostulo
# 0  1112257047      ow2xPaj          0
# 1  1111920714      LNKXqJB          0
# 2  1112346945      8MBPqYD          0
# 3  1112345547      ek4P2Wr          0
# 4  1112237522       NpqMD5          0

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 16511335
# 16450211

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo        sexo   edad Doctorado  \
# 1299229   1112270219      NzdzaaV          0        MASC   28.0         -
# 13265979  1112295959       ameLW5          1        MASC   28.0         -
# 3501161   1112320214      5mk5XwG          0        MASC   34.0         -
# 4331643   1112364685      GNZamN9          1        MASC   27.0         -
# 12901084  1112443807       ZOXB88          1         FEM   31.0         -
# 13745080  1112267771      4rlkjdq          0         FEM   27.0         -
# 13975736  1112141113      xkd8ALK          0  NO_DECLARA  200.0         -
# 8730884   1112422710      JBrDrze          1        MASC   34.0         -
# 1621661   1112350139      JBr2zEE          0         FEM   29.0         -
# 7199819   1112319451      mzdWqOE          0         FEM   22.0         -
# 14588420  1112339367      ak48zpm          0        MASC   33.0         -
# 5828702   1112345890      qe2R3WL          0         FEM   25.0         -
# 11074637  1112266305       ZWvk21          1        MASC   35.0         -
# 7080441   1112405311      dYjDapX          1         FEM   23.0         -
# 6555797   1111786150      JBxqBw3          1         FEM   19.0         -
# 13946717  1112464306      LNw00OB          1        MASC   37.0         -
# 2412035   1112335686      bOjk32B          0         FEM   17.0         -
# 2520044   1112378604      kPLDNBZ          1         FEM   33.0         -
# 11938433  1112378780      wVozbpw          0         FEM   23.0         -
# 7165955   1112394641      lD5d9z3          0        MASC   31.0         -
#
#             Master      Otro Posgrado Secundario    ...    viajar  \
# 1299229          -         -        -   Graduado    ...     False
# 13265979         -         -        -          -    ...     False
# 3501161          -         -        -   Graduado    ...     False
# 4331643          -         -        -          -    ...     False
# 12901084         -         -        -   Graduado    ...     False
# 13745080         -         -        -   Graduado    ...     False
# 13975736         -         -        -          -    ...     False
# 8730884          -         -        -   Graduado    ...     False
# 1621661          -         -        -          -    ...     False
# 7199819          -         -        -          -    ...     False
# 14588420         -         -        -          -    ...     False
# 5828702          -         -        -   Graduado    ...     False
# 11074637         -         -        -   Graduado    ...      True
# 7080441          -         -        -          -    ...     False
# 6555797          -         -        -   Graduado    ...     False
# 13946717         -         -        -   Graduado    ...     False
# 2412035          -         -        -          -    ...     False
# 2520044          -         -        -   Graduado    ...     False
# 11938433         -  Graduado        -   Graduado    ...     False
# 7165955   Graduado         -        -   Graduado    ...     False
#
#          empresa_importante capacitacion remuneracion_pretendida graduados  \
# 1299229               False        False                   False     False
# 13265979              False        False                   False     False
# 3501161                True        False                   False     False
# 4331643               False        False                   False     False
# 12901084              False         True                   False     False
# 13745080              False        False                   False     False
# 13975736              False        False                    True     False
# 8730884                True        False                   False     False
# 1621661               False        False                   False     False
# 7199819               False         True                   False     False
# 14588420              False        False                   False     False
# 5828702               False         True                   False     False
# 11074637              False        False                   False     False
# 7080441               False        False                   False     False
# 6555797               False        False                   False     False
# 13946717               True        False                   False     False
# 2412035               False        False                   False     False
# 2520044               False        False                   False     False
# 11938433              False        False                   False     False
# 7165955               False        False                   False     False
#
#          estudiantes conocimientos_especificos buen_ambiente  discriminacion  \
# 1299229        False                     False         False           False
# 13265979       False                     False          True           False
# 3501161        False                     False         False           False
# 4331643        False                     False         False           False
# 12901084       False                     False         False           False
# 13745080       False                     False         False           False
# 13975736       False                     False         False           False
# 8730884        False                     False         False           False
# 1621661        False                     False         False           False
# 7199819        False                     False          True           False
# 14588420       False                     False         False           False
# 5828702        False                     False          True           False
# 11074637       False                     False         False           False
# 7080441        False                     False         False           False
# 6555797        False                     False         False           False
# 13946717       False                     False         False           False
# 2412035        False                      True         False            True
# 2520044        False                     False         False           False
# 11938433       False                     False         False           False
# 7165955        False                     False         False           False
#
#           cantidad
# 1299229        NaN
# 13265979       NaN
# 3501161        NaN
# 4331643        NaN
# 12901084       2.0
# 13745080       NaN
# 13975736       NaN
# 8730884        1.0
# 1621661        NaN
# 7199819        NaN
# 14588420       NaN
# 5828702        NaN
# 11074637       NaN
# 7080441        NaN
# 6555797        2.0
# 13946717       2.0
# 2412035        NaN
# 2520044        NaN
# 11938433       NaN
# 7165955        NaN
#
# [20 rows x 36 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 10239710  1112388955      2zkEQ50          1   FEM  21.0         -      -
# 13712402  1112416238      YjQv04w          1  MASC  52.0         -      -
# 7849531   1112329035      xk9XLw6          0   FEM  28.0         -      -
# 11293151  1112290068      6rPKpLv          0  MASC  38.0         -      -
# 14738563  1112336931      DrXYrWL          0  MASC  55.0         -      -
# 4077856   1112447442      QNlex0z          1   FEM  23.0         -      -
# 10479437  1112213148      VNeJJwR          1  MASC  33.0         -      -
# 12425479  1112423655       EBJG09          0  MASC  38.0         -      -
# 8577667   1112353008      ow22vK0          0  MASC  22.0         -      -
# 12450565  1112203791      8MZrpDR          0   FEM  24.0         -      -
# 10264474  1112316287       6EMq9R          1  MASC  49.0         -      -
# 5153538   1111308362       1dxXBO          0   FEM  41.0         -      -
# 13717140  1112306773      QNrJVdV          0  MASC  19.0         -      -
# 1348655   1112286978      LNKW5Nk          1  MASC  25.0         -      -
# 8967594   1112273382      Oqr3oDW          0  MASC  23.0         -      -
# 12155313  1112260986      ow20ZEa          0   FEM  24.0         -      -
# 8161939   1112312545      mzdjoed          0  MASC  30.0         -      -
# 5710295   1112264908      kP0EB9b          0  MASC  25.0         -      -
# 3182246   1112340866      6rZXW5x          1   FEM  26.0         -      -
# 8674463   1112259708      bO4YGl4          1   FEM  32.0         -      -
#
#               Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 10239710         -         -   Graduado    ...     False              False
# 13712402         -         -   Graduado    ...      True              False
# 7849531          -         -   Graduado    ...     False              False
# 11293151         -         -   Graduado    ...     False              False
# 14738563         -         -          -    ...     False               True
# 4077856          -         -   Graduado    ...     False              False
# 10479437         -         -   Graduado    ...     False               True
# 12425479         -         -   Graduado    ...     False              False
# 8577667          -         -   Graduado    ...     False              False
# 12450565         -         -   Graduado    ...     False              False
# 10264474  Graduado         -          -    ...     False              False
# 5153538          -         -          -    ...     False              False
# 13717140         -         -   Graduado    ...     False              False
# 1348655          -         -   Graduado    ...     False              False
# 8967594          -         -          -    ...     False              False
# 12155313         -         -   Graduado    ...     False              False
# 8161939          -         -          -    ...     False              False
# 5710295          -         -   Graduado    ...     False              False
# 3182246          -         -   Graduado    ...     False              False
# 8674463          -  Graduado          -    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 10239710        False                   False     False       False
# 13712402        False                   False     False       False
# 7849531         False                   False     False       False
# 11293151        False                   False      True       False
# 14738563        False                   False     False       False
# 4077856         False                   False     False        True
# 10479437        False                   False     False       False
# 12425479        False                   False     False       False
# 8577667         False                   False     False        True
# 12450565        False                   False     False       False
# 10264474        False                   False     False       False
# 5153538         False                   False     False        True
# 13717140        False                    True     False       False
# 1348655         False                    True     False       False
# 8967594         False                   False     False       False
# 12155313        False                    True     False       False
# 8161939         False                   False     False       False
# 5710295         False                   False     False       False
# 3182246         False                   False     False       False
# 8674463         False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 10239710                     False         False           False       2.0
# 13712402                      True         False            True       5.0
# 7849531                      False         False           False       0.0
# 11293151                     False         False           False       0.0
# 14738563                     False         False           False       0.0
# 4077856                      False         False           False       1.0
# 10479437                     False         False           False       0.0
# 12425479                     False         False           False       0.0
# 8577667                      False         False           False       0.0
# 12450565                     False         False           False       0.0
# 10264474                     False         False           False       0.0
# 5153538                      False         False           False       0.0
# 13717140                     False         False           False       0.0
# 1348655                      False         False           False       0.0
# 8967594                      False         False           False       0.0
# 12155313                     False         False           False       0.0
# 8161939                      False         False           False       0.0
# 5710295                      False          True           False       0.0
# 3182246                      False          True           False       0.0
# 8674463                      False         False           False       0.0
#
# [20 rows x 36 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
# Out:
# Train:  14560399 Test:  766337

# %%
gc.collect()
# Out:
# 156

# %%
c=lgb.LGBMClassifier(learning_rate=0.005,objective='binary',num_leaves=4096,max_depth=13,n_estimators=3000,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 76.14456825130458
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV9.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV9.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado Master Otro  \
# 26708  88748  1112467018      JBrNDJO   FEM  24.0         -      -    -
# 60054   8472  1111780418        YZ8xP   FEM  44.0         -      -    -
# 79180  26692  1112343364       ZrkwVZ  MASC  53.0         -      -    -
# 25181  84206  1112466532       NwzmNl   FEM  28.0         -      -    -
# 3358   42005  1112422210      JBxxKrE   FEM  20.0         -      -    -
# 47806   2788  1111301974       5Zqbjk   FEM  39.0         -      -    -
# 55696   5487  1111558613       ZrKoYE  MASC  39.0         -      -    -
# 29634  78737  1112464571      owE3G0e  MASC  29.0         -      -    -
# 68986  37820  1112414480       exYjVo  MASC  52.0         -      -    -
# 38158  15068  1112115684       6RZX5R  MASC  46.0         -      -    -
#
#       Posgrado Secundario    ...    viajar empresa_importante capacitacion  \
# 26708        -   Graduado    ...     False              False         True
# 60054        -   Graduado    ...     False               True        False
# 79180        -   Graduado    ...     False              False        False
# 25181        -          -    ...     False              False        False
# 3358         -   Graduado    ...     False              False        False
# 47806        -   Graduado    ...     False              False        False
# 55696        -          -    ...     False              False        False
# 29634        -   Graduado    ...     False              False        False
# 68986        -          -    ...     False              False        False
# 38158        -   En Curso    ...     False              False        False
#
#       remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 26708                   False     False       False                     False
# 60054                   False     False       False                      True
# 79180                   False     False       False                     False
# 25181                    True     False       False                     False
# 3358                    False     False       False                     False
# 47806                   False     False       False                     False
# 55696                   False     False       False                     False
# 29634                   False     False       False                     False
# 68986                   False     False       False                     False
# 38158                   False     False       False                     False
#
#       buen_ambiente  discriminacion  cantidad
# 26708         False           False       0.0
# 60054         False            True       0.0
# 79180          True           False       0.0
# 25181         False           False       0.0
# 3358           True           False       1.0
# 47806         False           False       0.0
# 55696          True           False       0.0
# 29634         False           False       0.0
# 68986         False           False       0.0
# 38158          True           False       0.0
#
# [10 rows x 36 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.82517391, 0.17482609],
#        [0.6740859 , 0.3259141 ],
#        [0.68893989, 0.31106011],
#        ...,
#        [0.89813383, 0.10186617],
#        [0.70970782, 0.29029218],
#        [0.97744906, 0.02255094]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     empresa_importante capacitacion  \
# 0   Graduado    ...                  False        False
# 1          -    ...                  False        False
# 2   Graduado    ...                  False        False
# 3   Graduado    ...                  False        False
# 4          -    ...                  False        False
#
#   remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 0                   False     False       False                     False
# 1                   False     False       False                     False
# 2                   False     False       False                     False
# 3                   False     False       False                     False
# 4                   False     False       False                     False
#
#   buen_ambiente discriminacion  cantidad  sepostulo
# 0         False          False       0.0   0.174826
# 1         False          False       0.0   0.325914
# 2         False          False       0.0   0.311060
# 3         False          False       0.0   0.087415
# 4         False          False       0.0   0.276297
#
# [5 rows x 37 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.174826
# 1   1   0.325914
# 2   2   0.311060
# 3   3   0.087415
# 4   4   0.276297

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion23.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5342532727094954
