# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisosONEHOT.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantesONEHOT.csv")
postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/1.csv")

postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones2=pd.merge(postulaciones2,postulantes,on='idpostulante')

postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones2=pd.merge(postulaciones2,avisos,on='idaviso')

postulaciones2.head()
# Out:
#       idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 0  1112257047      akjmXXq          0  28.0      True      False
# 1  1112257047      MV6b6R9          0  30.0      True      False
# 2  1112257047      zvxv1Rm          0  22.0      True      False
# 3  1112257047       8oqJzL          0  34.0     False       True
# 4  1112257047       ez533B          0  32.0     False       True
#
#    sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 0            False                 False               False
# 1            False                 False               False
# 2            False                 False               False
# 3            False                 False               False
# 4            False                 False               False
#
#    Doctorado_Graduado                 ...                  \
# 0               False                 ...
# 1               False                 ...
# 2               False                 ...
# 3               False                 ...
# 4               False                 ...
#
#    tipo_de_trabajo_Por Horas  tipo_de_trabajo_Primer empleo  \
# 0                      False                          False
# 1                      False                          False
# 2                      False                          False
# 3                      False                          False
# 4                      False                          False
#
#    tipo_de_trabajo_Teletrabajo  tipo_de_trabajo_Temporario  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
#
#    tipo_de_trabajo_Voluntario  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
#    nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 0                                          False                 False
# 1                                          False                 False
# 2                                          False                 False
# 3                                          False                 False
# 4                                          False                 False
#
#    nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior
# 0                True                               False
# 1                True                               False
# 2                True                               False
# 3                True                               False
# 4                True                               False
#
# [5 rows x 76 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 0  1112257047         NM5M          1  47.0      True      False
# 1  1112257047       1kJqGb          1  34.0      True      False
# 2  1112257047       eOE9Rr          1  39.0      True      False
# 3  1112257047       Zrx8Xz          1  39.0      True      False
# 4  1112257047       ZrKNQY          1  32.0      True      False
#
#    sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 0            False                 False               False
# 1            False                 False               False
# 2            False                 False               False
# 3            False                 False               False
# 4            False                 False               False
#
#    Doctorado_Graduado                 ...                  \
# 0               False                 ...
# 1               False                 ...
# 2               False                 ...
# 3               False                 ...
# 4               False                 ...
#
#    tipo_de_trabajo_Por Horas  tipo_de_trabajo_Primer empleo  \
# 0                      False                          False
# 1                      False                          False
# 2                      False                          False
# 3                      False                          False
# 4                      False                          False
#
#    tipo_de_trabajo_Teletrabajo  tipo_de_trabajo_Temporario  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
#
#    tipo_de_trabajo_Voluntario  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
#    nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 0                                          False                 False
# 1                                          False                 False
# 2                                          False                 False
# 3                                          False                 False
# 4                                          False                 False
#
#    nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior
# 0                True                               False
# 1                True                               False
# 2                True                               False
# 3                True                               False
# 4                True                               False
#
# [5 rows x 76 columns]

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 12377268
# 12332167

# %%
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 4768382   1112398577      vV3AzbX          1  24.0      True      False
# 12085329  1112297115      akjZ3K9          0  25.0      True      False
# 4401621   1112452799       YA9OBq          1  34.0     False       True
# 10429917  1112281717      zv8Gw3J          0  24.0      True      False
# 9546784   1112418975       eAM91o          0  37.0     False       True
# 346062    1112343194      6rQBxVj          1  28.0     False       True
# 4702675   1111953613      NzeBJox          1  28.0      True      False
# 6515478   1112334806      lDXLEqR          0  31.0     False       True
# 2283563   1112284291      X9kox8v          1  26.0     False       True
# 9218950   1112260942      NzP8YJl          0  24.0      True      False
# 2695143   1112309025      QNE5LVz          1  34.0      True      False
# 814295    1112355061      jk5NWY0          1  28.0     False       True
# 4845215   1112273169      969VQBZ          1  22.0      True      False
# 6698562   1112033906      X9xjBlO          0  50.0     False       True
# 1128744   1112255773      QNM9Zqe          1  23.0      True      False
# 11570193  1112451333      rm0AGwA          0  50.0      True      False
# 1347870   1112414466       YVoPXP          1  46.0      True      False
# 7298470   1112262197      PmGbwQE          0  21.0      True      False
# 6316690   1112318545      4rdJzD0          0  26.0     False       True
# 10730601  1112455942      ZDleJxY          0  24.0     False       True
#
#           sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 4768382             False                 False               False
# 12085329            False                 False               False
# 4401621             False                 False               False
# 10429917            False                 False               False
# 9546784             False                 False               False
# 346062              False                 False               False
# 4702675             False                 False               False
# 6515478             False                 False               False
# 2283563             False                 False               False
# 9218950             False                 False               False
# 2695143             False                 False               False
# 814295              False                 False               False
# 4845215             False                 False               False
# 6698562             False                 False               False
# 1128744             False                 False               False
# 11570193            False                 False               False
# 1347870             False                 False               False
# 7298470             False                 False               False
# 6316690             False                 False               False
# 10730601            False                 False               False
#
#           Doctorado_Graduado    ...     tipo_de_trabajo_Primer empleo  \
# 4768382                False    ...                             False
# 12085329               False    ...                             False
# 4401621                False    ...                             False
# 10429917               False    ...                             False
# 9546784                False    ...                             False
# 346062                 False    ...                             False
# 4702675                False    ...                             False
# 6515478                False    ...                             False
# 2283563                False    ...                             False
# 9218950                False    ...                             False
# 2695143                False    ...                             False
# 814295                 False    ...                             False
# 4845215                False    ...                             False
# 6698562                False    ...                             False
# 1128744                False    ...                             False
# 11570193               False    ...                             False
# 1347870                False    ...                             False
# 7298470                False    ...                             False
# 6316690                False    ...                             False
# 10730601               False    ...                             False
#
#           tipo_de_trabajo_Teletrabajo  tipo_de_trabajo_Temporario  \
# 4768382                         False                       False
# 12085329                        False                       False
# 4401621                         False                       False
# 10429917                        False                       False
# 9546784                         False                       False
# 346062                          False                       False
# 4702675                         False                        True
# 6515478                         False                       False
# 2283563                         False                       False
# 9218950                         False                       False
# 2695143                         False                       False
# 814295                          False                       False
# 4845215                         False                       False
# 6698562                         False                       False
# 1128744                         False                       False
# 11570193                        False                       False
# 1347870                         False                       False
# 7298470                         False                       False
# 6316690                         False                       False
# 10730601                        False                       False
#
#           tipo_de_trabajo_Voluntario  \
# 4768382                        False
# 12085329                       False
# 4401621                        False
# 10429917                       False
# 9546784                        False
# 346062                         False
# 4702675                        False
# 6515478                        False
# 2283563                        False
# 9218950                        False
# 2695143                        False
# 814295                         False
# 4845215                        False
# 6698562                        False
# 1128744                        False
# 11570193                       False
# 1347870                        False
# 7298470                        False
# 6316690                        False
# 10730601                       False
#
#           nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 4768382                                               False
# 12085329                                              False
# 4401621                                               False
# 10429917                                              False
# 9546784                                               False
# 346062                                                False
# 4702675                                               False
# 6515478                                               False
# 2283563                                               False
# 9218950                                               False
# 2695143                                               False
# 814295                                                False
# 4845215                                               False
# 6698562                                               False
# 1128744                                               False
# 11570193                                              False
# 1347870                                               False
# 7298470                                               False
# 6316690                                               False
# 10730601                                              False
#
#           nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 4768382                                           False                 False
# 12085329                                          False                 False
# 4401621                                           False                 False
# 10429917                                          False                 False
# 9546784                                           False                 False
# 346062                                            False                 False
# 4702675                                           False                 False
# 6515478                                           False                 False
# 2283563                                           False                 False
# 9218950                                           False                 False
# 2695143                                           False                 False
# 814295                                            False                 False
# 4845215                                           False                 False
# 6698562                                           False                 False
# 1128744                                           False                 False
# 11570193                                          False                 False
# 1347870                                           False                 False
# 7298470                                           False                 False
# 6316690                                           False                 False
# 10730601                                          False                 False
#
#           nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  cantidad
# 4768382                False                                True       2.0
# 12085329                True                               False       NaN
# 4401621                False                                True       3.0
# 10429917               False                                True       NaN
# 9546784                 True                               False       NaN
# 346062                 False                                True       NaN
# 4702675                False                                True       2.0
# 6515478                False                                True       NaN
# 2283563                False                                True       NaN
# 9218950                 True                               False       NaN
# 2695143                False                                True       1.0
# 814295                 False                                True       NaN
# 4845215                False                                True       NaN
# 6698562                False                                True       1.0
# 1128744                False                                True       NaN
# 11570193                True                               False       NaN
# 1347870                False                                True       3.0
# 7298470                False                                True       NaN
# 6316690                False                                True       NaN
# 10730601               False                                True       NaN
#
# [20 rows x 77 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 3442406   1111322505      qeYmOvL          1  22.0      True      False
# 11803876  1112375786      ZDPkPQZ          0  23.0     False       True
# 1785835   1112205158      3NQOWkw          1  34.0      True      False
# 1652181   1112306344      8ML4Lwx          1  28.0      True      False
# 7380544   1112453077      X9x3qDJ          0  28.0      True      False
# 715830    1112299083      qe295Wb          1  31.0     False       True
# 221992    1112355399      akDmqOD          1  22.0     False       True
# 2090402   1112280912      Nz0X13V          1  27.0     False       True
# 5187894   1112441908      W9OPjN9          1  31.0      True      False
# 4930797   1112344991       EKbw20          1  29.0      True      False
# 1965209   1112278041      VNrQmwz          1  23.0      True      False
# 11232270  1112148951      qe28Mza          0  19.0     False       True
# 5651094   1112250927      A3AOKpm          1  32.0     False       True
# 10577036  1112443823      xkaWqRb          0  21.0      True      False
# 5712362   1112353582      ekNNR4p          1  25.0      True      False
# 3974351   1112351314      akbjNPm          1  26.0      True      False
# 4514472   1112327140      dYzWk3D          1  21.0      True      False
# 232034    1112280067      96ZxKBP          1  23.0      True      False
# 982542    1112204682      2zk5wAv          1  22.0      True      False
# 5852489   1112400239      96WEpLZ          1  27.0      True      False
#
#           sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 3442406             False                 False               False
# 11803876            False                 False               False
# 1785835             False                 False               False
# 1652181             False                 False               False
# 7380544             False                 False               False
# 715830              False                 False               False
# 221992              False                 False               False
# 2090402             False                 False               False
# 5187894             False                 False               False
# 4930797             False                 False               False
# 1965209             False                 False               False
# 11232270            False                 False               False
# 5651094             False                 False               False
# 10577036            False                 False               False
# 5712362             False                 False               False
# 3974351             False                 False               False
# 4514472             False                 False               False
# 232034              False                 False               False
# 982542              False                 False               False
# 5852489             False                 False               False
#
#           Doctorado_Graduado    ...     tipo_de_trabajo_Primer empleo  \
# 3442406                False    ...                             False
# 11803876               False    ...                             False
# 1785835                False    ...                             False
# 1652181                False    ...                             False
# 7380544                False    ...                             False
# 715830                 False    ...                             False
# 221992                 False    ...                             False
# 2090402                False    ...                             False
# 5187894                False    ...                             False
# 4930797                False    ...                             False
# 1965209                False    ...                             False
# 11232270               False    ...                             False
# 5651094                False    ...                             False
# 10577036               False    ...                             False
# 5712362                False    ...                             False
# 3974351                False    ...                             False
# 4514472                False    ...                             False
# 232034                 False    ...                             False
# 982542                 False    ...                             False
# 5852489                False    ...                             False
#
#           tipo_de_trabajo_Teletrabajo  tipo_de_trabajo_Temporario  \
# 3442406                         False                       False
# 11803876                        False                       False
# 1785835                         False                       False
# 1652181                         False                       False
# 7380544                         False                       False
# 715830                          False                       False
# 221992                          False                       False
# 2090402                         False                       False
# 5187894                         False                       False
# 4930797                         False                       False
# 1965209                         False                       False
# 11232270                        False                       False
# 5651094                         False                       False
# 10577036                        False                       False
# 5712362                         False                       False
# 3974351                         False                       False
# 4514472                         False                       False
# 232034                          False                       False
# 982542                          False                       False
# 5852489                         False                       False
#
#           tipo_de_trabajo_Voluntario  \
# 3442406                        False
# 11803876                       False
# 1785835                        False
# 1652181                        False
# 7380544                        False
# 715830                         False
# 221992                         False
# 2090402                        False
# 5187894                        False
# 4930797                        False
# 1965209                        False
# 11232270                       False
# 5651094                        False
# 10577036                       False
# 5712362                        False
# 3974351                        False
# 4514472                        False
# 232034                         False
# 982542                         False
# 5852489                        False
#
#           nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 3442406                                               False
# 11803876                                              False
# 1785835                                               False
# 1652181                                               False
# 7380544                                               False
# 715830                                                False
# 221992                                                False
# 2090402                                               False
# 5187894                                               False
# 4930797                                               False
# 1965209                                               False
# 11232270                                              False
# 5651094                                               False
# 10577036                                              False
# 5712362                                               False
# 3974351                                               False
# 4514472                                               False
# 232034                                                False
# 982542                                                False
# 5852489                                               False
#
#           nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 3442406                                           False                 False
# 11803876                                          False                 False
# 1785835                                           False                  True
# 1652181                                           False                 False
# 7380544                                           False                  True
# 715830                                            False                 False
# 221992                                            False                 False
# 2090402                                           False                 False
# 5187894                                           False                 False
# 4930797                                           False                 False
# 1965209                                           False                 False
# 11232270                                          False                 False
# 5651094                                           False                 False
# 10577036                                          False                 False
# 5712362                                           False                 False
# 3974351                                           False                 False
# 4514472                                           False                 False
# 232034                                            False                 False
# 982542                                            False                 False
# 5852489                                           False                 False
#
#           nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  cantidad
# 3442406                 True                               False       1.0
# 11803876               False                                True       0.0
# 1785835                False                               False      13.0
# 1652181                False                                True       0.0
# 7380544                False                               False       0.0
# 715830                 False                                True       0.0
# 221992                 False                                True       0.0
# 2090402                False                                True       0.0
# 5187894                False                                True       1.0
# 4930797                False                                True       0.0
# 1965209                False                                True       0.0
# 11232270               False                                True       0.0
# 5651094                False                                True       0.0
# 10577036               False                                True       0.0
# 5712362                False                                True       0.0
# 3974351                False                                True       0.0
# 4514472                False                                True       0.0
# 232034                 False                                True       0.0
# 982542                 False                                True       0.0
# 5852489                 True                               False       0.0
#
# [20 rows x 77 columns]

# %%
areas=avisos['nombre_area'].value_counts().index
postulaciones['nombre_area']=postulaciones['nombre_area'].replace(areas, range(len(areas)))
postulaciones.dtypes
# Out:
# idaviso                                                 int64
# idpostulante                                           object
# sepostulo                                               int64
# edad                                                  float64
# sexo_FEM                                                 bool
# sexo_MASC                                                bool
# sexo_NO_DECLARA                                          bool
# Doctorado_Abandonado                                     bool
# Doctorado_En Curso                                       bool
# Doctorado_Graduado                                       bool
# Master_Abandonado                                        bool
# Master_En Curso                                          bool
# Master_Graduado                                          bool
# Posgrado_Abandonado                                      bool
# Posgrado_En Curso                                        bool
# Posgrado_Graduado                                        bool
# Secundario_Abandonado                                    bool
# Secundario_En Curso                                      bool
# Secundario_Graduado                                      bool
# Terciario/Técnico_Abandonado                             bool
# Terciario/Técnico_En Curso                               bool
# Terciario/Técnico_Graduado                               bool
# Universitario_Abandonado                                 bool
# Universitario_En Curso                                   bool
# Universitario_Graduado                                   bool
# titulo                                                 object
# nombre_area                                             int64
# denominacion_empresa                                   object
# titulo_uppercase                                         bool
# pide_hombre                                              bool
#                                                        ...
# nombre_zona_Catamarca                                    bool
# nombre_zona_Ciudad de Mendoza                            bool
# nombre_zona_Cordoba                                      bool
# nombre_zona_Corrientes                                   bool
# nombre_zona_GBA Oeste                                    bool
# nombre_zona_Gran Buenos Aires                            bool
# nombre_zona_La Plata                                     bool
# nombre_zona_Mendoza                                      bool
# nombre_zona_Neuquen                                      bool
# nombre_zona_Rosario                                      bool
# nombre_zona_San Juan                                     bool
# nombre_zona_Santa Cruz                                   bool
# nombre_zona_Santa Fe                                     bool
# nombre_zona_Tucuman                                      bool
# tipo_de_trabajo_Fines de Semana                          bool
# tipo_de_trabajo_Full-time                                bool
# tipo_de_trabajo_Part-time                                bool
# tipo_de_trabajo_Pasantia                                 bool
# tipo_de_trabajo_Por Contrato                             bool
# tipo_de_trabajo_Por Horas                                bool
# tipo_de_trabajo_Primer empleo                            bool
# tipo_de_trabajo_Teletrabajo                              bool
# tipo_de_trabajo_Temporario                               bool
# tipo_de_trabajo_Voluntario                               bool
# nivel_laboral_Gerencia / Alta Gerencia / Dirección       bool
# nivel_laboral_Jefe / Supervisor / Responsable            bool
# nivel_laboral_Junior                                     bool
# nivel_laboral_Otro                                       bool
# nivel_laboral_Senior / Semi-Senior                       bool
# cantidad                                              float64
# Length: 77, dtype: object

# %%
train, test=train_test_split(postulaciones,test_size=0.10)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
postulaciones2=0
# Out:
# Train:  11098950 Test:  1233217

# %%
import gc
gc.collect()
# Out:
# 135

# %%
c=RandomForestClassifier(n_estimators=100,min_samples_split=100,n_jobs=-1,random_state=0)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl") 
dt=c.fit(x_train,y_train)

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 73.48179598562135

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/RFONEHOT.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/RFVONEHOT.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  edad  sexo_FEM  sexo_MASC  \
# 27479  63012  1112456956      RzNz409  20.0      True      False
# 33832  46778  1112430574       8ZakRD  57.0     False       True
# 19843  80140  1112464788      DrpEZ1d  32.0     False       True
# 76983  23241  1112303210       EJXq40  32.0     False       True
# 84267  33005  1112399632       61GkRO  27.0      True      False
# 85532  34574  1112408910       NkddBJ  35.0     False       True
# 90934  85506  1112466645      akjOWO0  32.0     False       True
# 61669  20815  1112263307      vVDmNrx  27.0     False       True
# 73991  91383  1112471375       6aLaoL  33.0      True      False
# 65186  74311  1112463693       aoebxE  38.0      True      False
#
#        sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 27479            False                 False               False
# 33832            False                 False               False
# 19843            False                 False               False
# 76983            False                 False               False
# 84267            False                 False               False
# 85532            False                 False               False
# 90934            False                 False               False
# 61669            False                 False               False
# 73991            False                 False                True
# 65186            False                 False               False
#
#        Doctorado_Graduado    ...     tipo_de_trabajo_Primer empleo  \
# 27479               False    ...                             False
# 33832               False    ...                             False
# 19843               False    ...                             False
# 76983               False    ...                             False
# 84267               False    ...                             False
# 85532               False    ...                             False
# 90934               False    ...                             False
# 61669               False    ...                             False
# 73991               False    ...                             False
# 65186               False    ...                             False
#
#        tipo_de_trabajo_Teletrabajo  tipo_de_trabajo_Temporario  \
# 27479                        False                       False
# 33832                        False                       False
# 19843                        False                       False
# 76983                        False                       False
# 84267                        False                       False
# 85532                        False                       False
# 90934                        False                       False
# 61669                        False                       False
# 73991                        False                       False
# 65186                        False                       False
#
#        tipo_de_trabajo_Voluntario  \
# 27479                       False
# 33832                       False
# 19843                       False
# 76983                       False
# 84267                       False
# 85532                       False
# 90934                       False
# 61669                       False
# 73991                       False
# 65186                       False
#
#        nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 27479                                              False
# 33832                                              False
# 19843                                              False
# 76983                                              False
# 84267                                              False
# 85532                                              False
# 90934                                              False
# 61669                                              False
# 73991                                              False
# 65186                                              False
#
#        nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 27479                                          False                 False
# 33832                                          False                 False
# 19843                                          False                  True
# 76983                                          False                 False
# 84267                                          False                 False
# 85532                                          False                 False
# 90934                                          False                 False
# 61669                                          False                 False
# 73991                                          False                  True
# 65186                                          False                 False
#
#        nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  cantidad
# 27479               False                                True       1.0
# 33832               False                                True       0.0
# 19843               False                               False       1.0
# 76983                True                               False       0.0
# 84267               False                                True       0.0
# 85532               False                                True       0.0
# 90934               False                                True       4.0
# 61669                True                               False       0.0
# 73991               False                               False       0.0
# 65186               False                                True       0.0
#
# [10 rows x 77 columns]

# %%
areas=avisos['nombre_area'].value_counts().index
prediccion['nombre_area']=prediccion['nombre_area'].replace(areas, range(len(areas)))
prediccion.dtypes
# Out:
# id                                                      int64
# idaviso                                                 int64
# idpostulante                                           object
# edad                                                  float64
# sexo_FEM                                                 bool
# sexo_MASC                                                bool
# sexo_NO_DECLARA                                          bool
# Doctorado_Abandonado                                     bool
# Doctorado_En Curso                                       bool
# Doctorado_Graduado                                       bool
# Master_Abandonado                                        bool
# Master_En Curso                                          bool
# Master_Graduado                                          bool
# Posgrado_Abandonado                                      bool
# Posgrado_En Curso                                        bool
# Posgrado_Graduado                                        bool
# Secundario_Abandonado                                    bool
# Secundario_En Curso                                      bool
# Secundario_Graduado                                      bool
# Terciario/Técnico_Abandonado                             bool
# Terciario/Técnico_En Curso                               bool
# Terciario/Técnico_Graduado                               bool
# Universitario_Abandonado                                 bool
# Universitario_En Curso                                   bool
# Universitario_Graduado                                   bool
# titulo                                                 object
# nombre_area                                             int64
# denominacion_empresa                                   object
# titulo_uppercase                                         bool
# pide_hombre                                              bool
#                                                        ...
# nombre_zona_Catamarca                                    bool
# nombre_zona_Ciudad de Mendoza                            bool
# nombre_zona_Cordoba                                      bool
# nombre_zona_Corrientes                                   bool
# nombre_zona_GBA Oeste                                    bool
# nombre_zona_Gran Buenos Aires                            bool
# nombre_zona_La Plata                                     bool
# nombre_zona_Mendoza                                      bool
# nombre_zona_Neuquen                                      bool
# nombre_zona_Rosario                                      bool
# nombre_zona_San Juan                                     bool
# nombre_zona_Santa Cruz                                   bool
# nombre_zona_Santa Fe                                     bool
# nombre_zona_Tucuman                                      bool
# tipo_de_trabajo_Fines de Semana                          bool
# tipo_de_trabajo_Full-time                                bool
# tipo_de_trabajo_Part-time                                bool
# tipo_de_trabajo_Pasantia                                 bool
# tipo_de_trabajo_Por Contrato                             bool
# tipo_de_trabajo_Por Horas                                bool
# tipo_de_trabajo_Primer empleo                            bool
# tipo_de_trabajo_Teletrabajo                              bool
# tipo_de_trabajo_Temporario                               bool
# tipo_de_trabajo_Voluntario                               bool
# nivel_laboral_Gerencia / Alta Gerencia / Dirección       bool
# nivel_laboral_Jefe / Supervisor / Responsable            bool
# nivel_laboral_Junior                                     bool
# nivel_laboral_Otro                                       bool
# nivel_laboral_Senior / Semi-Senior                       bool
# cantidad                                              float64
# Length: 77, dtype: object

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.60959355, 0.39040645],
#        [0.567324  , 0.432676  ],
#        [0.58031447, 0.41968553],
#        ...,
#        [0.78992381, 0.21007619],
#        [0.58332485, 0.41667515],
#        [0.90279107, 0.09720893]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  edad  sexo_FEM  sexo_MASC  sexo_NO_DECLARA  \
# 0   0   739260       6M9ZQR  42.0      True      False            False
# 1   1   739260       6v1xdL  30.0     False       True            False
# 2   2   739260       ezRKm9  36.0      True      False            False
# 3   3   758580       1Q35ej  68.0     False       True            False
# 4   4   758580       EAN4J6  32.0      True      False            False
#
#    Doctorado_Abandonado  Doctorado_En Curso  Doctorado_Graduado    ...      \
# 0                 False               False                True    ...
# 1                 False               False               False    ...
# 2                 False               False               False    ...
# 3                 False               False               False    ...
# 4                 False               False               False    ...
#
#    tipo_de_trabajo_Teletrabajo  tipo_de_trabajo_Temporario  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
#
#    tipo_de_trabajo_Voluntario  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
#
#    nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 0                                           True                 False
# 1                                           True                 False
# 2                                           True                 False
# 3                                          False                 False
# 4                                          False                 False
#
#    nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  cantidad  sepostulo
# 0               False                               False       0.0   0.390406
# 1               False                               False       0.0   0.432676
# 2               False                               False       0.0   0.419686
# 3                True                               False       0.0   0.082840
# 4                True                               False       0.0   0.347555
#
# [5 rows x 78 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.390406
# 1   1   0.432676
# 2   2   0.419686
# 3   3   0.082840
# 4   4   0.347555

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion7_ONEHOT.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5927015134609176
