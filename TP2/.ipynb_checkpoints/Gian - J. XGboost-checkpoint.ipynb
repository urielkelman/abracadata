# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/1.csv")

postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones2=pd.merge(postulaciones2,postulantes,on='idpostulante')

postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones2=pd.merge(postulaciones2,avisos,on='idaviso')

postulaciones2.head()
# Out:
#       idaviso idpostulante  sepostulo  sexo  edad Doctorado Master Otro  \
# 0  1112257047      akjmXXq          0   FEM  28.0         -      -    -
# 1  1112257047      MV6b6R9          0   FEM  30.0         -      -    -
# 2  1112257047      zvxv1Rm          0   FEM  22.0         -      -    -
# 3  1112257047       8oqJzL          0  MASC  34.0         -      -    -
# 4  1112257047       ez533B          0  MASC  32.0         -      -    -
#
#   Posgrado Secundario       ...       secundario viajar empresa_importante  \
# 0        -   Graduado       ...             True  False              False
# 1        -          -       ...             True  False              False
# 2        -   Graduado       ...             True  False              False
# 3        -          -       ...             True  False              False
# 4        -   Graduado       ...             True  False              False
#
#   capacitacion remuneracion_pretendida graduados estudiantes  \
# 0         True                   False     False       False
# 1         True                   False     False       False
# 2         True                   False     False       False
# 3         True                   False     False       False
# 4         True                   False     False       False
#
#   conocimientos_especificos  buen_ambiente  discriminacion
# 0                     False          False           False
# 1                     False          False           False
# 2                     False          False           False
# 3                     False          False           False
# 4                     False          False           False
#
# [5 rows x 33 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo sexo  edad Doctorado Master Otro  \
# 0  1112257047         NM5M          1  FEM  47.0         -      -    -
# 1  1112257047       1kJqGb          1  FEM  34.0         -      -    -
# 2  1112257047       eOE9Rr          1  FEM  39.0         -      -    -
# 3  1112257047       Zrx8Xz          1  FEM  39.0         -      -    -
# 4  1112257047       ZrKNQY          1  FEM  32.0         -      -    -
#
#   Posgrado Secundario       ...       secundario viajar empresa_importante  \
# 0        -   Graduado       ...             True  False              False
# 1        -          -       ...             True  False              False
# 2        -   Graduado       ...             True  False              False
# 3        -          -       ...             True  False              False
# 4        -   Graduado       ...             True  False              False
#
#   capacitacion remuneracion_pretendida graduados estudiantes  \
# 0         True                   False     False       False
# 1         True                   False     False       False
# 2         True                   False     False       False
# 3         True                   False     False       False
# 4         True                   False     False       False
#
#   conocimientos_especificos  buen_ambiente  discriminacion
# 0                     False          False           False
# 1                     False          False           False
# 2                     False          False           False
# 3                     False          False           False
# 4                     False          False           False
#
# [5 rows x 33 columns]

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 12377268
# 12332167

# %%
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 9464624   1111644946      96zGMPP          0   FEM  20.0         -      -
# 6593037   1112255594      Yj5zKaD          0  MASC  30.0         -      -
# 11637556  1112341662      4rPQvJq          0  MASC  23.0         -      -
# 11026987  1112161921      Eze9D52          0   FEM  19.0         -      -
# 6982689   1112334788      mzdWqb6          0   FEM  28.0         -      -
# 6680818   1112033906       55x5Bq          0   FEM  30.0         -      -
# 2142686   1112234599      MVr45Nx          1   FEM  34.0         -      -
# 660824    1112340979       NWlxRx          1  MASC  26.0         -      -
# 5705974   1112432565      JBrLEek          1  MASC  25.0         -      -
# 6228248   1112334791      bOVz4od          0  MASC  29.0         -      -
# 11837004  1112281658      A3XKGXD          0  MASC  19.0         -      -
# 8112763   1112285124       e019D9          0  MASC  46.0         -      -
# 1796628   1112458730      vVkJbp5          1  MASC  28.0         -      -
# 1661718   1112336556      qe6ma89          1   FEM  22.0         -      -
# 5993101   1112292092      Dr6wW4Z          1  MASC  36.0         -      -
# 11360774  1112361534      qe2AQY1          0   FEM  26.0         -      -
# 8747937   1112397910      owjwP9e          0   FEM  28.0         -      -
# 2456821   1112416484       EqPAvb          1  MASC  31.0         -      -
# 10580002  1112452207        EEL9z          0  MASC  45.0         -      -
# 6723667   1112432822      dYjj3mX          0  MASC  46.0         -      -
#
#               Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 9464624          -         -   Graduado    ...     False              False
# 6593037          -         -   Graduado    ...     False               True
# 11637556  Graduado         -   Graduado    ...     False              False
# 11026987         -         -          -    ...     False              False
# 6982689          -         -   Graduado    ...     False              False
# 6680818          -         -   Graduado    ...     False              False
# 2142686   Graduado         -          -    ...     False               True
# 660824           -         -   Graduado    ...     False              False
# 5705974          -         -   Graduado    ...     False              False
# 6228248          -         -   Graduado    ...     False              False
# 11837004         -         -   Graduado    ...     False              False
# 8112763          -         -   Graduado    ...     False              False
# 1796628          -         -   Graduado    ...      True              False
# 1661718          -         -   Graduado    ...     False              False
# 5993101          -         -   Graduado    ...     False              False
# 11360774         -         -   Graduado    ...     False               True
# 8747937          -         -   Graduado    ...     False              False
# 2456821          -  En Curso   Graduado    ...     False              False
# 10580002         -  Graduado   Graduado    ...     False              False
# 6723667          -         -          -    ...     False               True
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 9464624         False                   False     False        True
# 6593037         False                   False     False       False
# 11637556        False                   False     False       False
# 11026987        False                    True     False       False
# 6982689          True                   False     False       False
# 6680818          True                   False     False       False
# 2142686         False                   False     False       False
# 660824          False                   False     False       False
# 5705974         False                   False     False       False
# 6228248          True                   False     False       False
# 11837004        False                   False     False       False
# 8112763         False                   False     False       False
# 1796628          True                   False     False       False
# 1661718         False                   False      True       False
# 5993101         False                   False     False       False
# 11360774        False                   False     False       False
# 8747937         False                   False      True       False
# 2456821         False                   False     False       False
# 10580002        False                   False     False       False
# 6723667         False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 9464624                      False         False           False       NaN
# 6593037                      False         False           False       NaN
# 11637556                     False         False           False       NaN
# 11026987                     False         False           False       NaN
# 6982689                      False          True           False       NaN
# 6680818                      False          True           False       NaN
# 2142686                      False         False           False       NaN
# 660824                       False         False           False       NaN
# 5705974                      False         False           False       2.0
# 6228248                      False          True           False       NaN
# 11837004                     False         False           False       NaN
# 8112763                      False         False           False       NaN
# 1796628                      False         False           False       NaN
# 1661718                      False         False           False       NaN
# 5993101                      False         False           False       NaN
# 11360774                     False         False           False       NaN
# 8747937                      False         False           False       NaN
# 2456821                      False         False           False       NaN
# 10580002                     False         False           False       NaN
# 6723667                      False          True           False       NaN
#
# [20 rows x 34 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 8611289   1112233828      vVjW2Dx          0   FEM  23.0         -      -
# 3564085   1112235513      GNZ1QaE          1   FEM  49.0         -      -
# 3111938   1112268189      96XjjlZ          1   FEM  23.0         -      -
# 9423691   1112415468      zvPJ0N3          0   FEM  22.0         -      -
# 601585    1112319103        eNje9          1  MASC  44.0         -      -
# 9722362   1112224292       1MBR5B          0  MASC  32.0         -      -
# 11146135  1112378264      xk9XVkY          0  MASC  39.0         -      -
# 2066045   1112206678      Pmq1PRY          1  MASC  27.0         -      -
# 3910172   1112256350      owzq21e          1   FEM  27.0         -      -
# 8003206   1112379261      5mPL5ov          0  MASC  30.0         -      -
# 8610492   1112233828      6r5BRkl          0  MASC  27.0         -      -
# 10364895  1112253469      8M2qxPz          0  MASC  30.0         -      -
# 8348606   1112309025      owjo1Ra          0   FEM  36.0         -      -
# 2781093   1112281392      NzeD0ZL          1  MASC  23.0         -      -
# 515763    1112267850      3N2OVMa          1  MASC  27.0         -      -
# 9866941   1112338331      Yj5z3KY          0   FEM  22.0         -      -
# 6912451   1112364849      Ezeb8L0          0   FEM  23.0         -      -
# 4297051   1112427934      mzj9pOQ          1   FEM  28.0         -      -
# 9273845   1112384362      owEddbL          0   FEM  28.0         -      -
# 2237095   1112219986       5KBZJM          1   FEM  29.0         -      -
#
#                 Otro  Posgrado  Secundario    ...    viajar  \
# 8611289            -         -           -    ...     False
# 3564085            -         -           -    ...      True
# 3111938            -         -    Graduado    ...     False
# 9423691            -         -    Graduado    ...     False
# 601585             -  Graduado    Graduado    ...     False
# 9722362            -         -           -    ...     False
# 11146135           -         -  Abandonado    ...     False
# 2066045            -         -    Graduado    ...     False
# 3910172            -         -    Graduado    ...      True
# 8003206            -         -    Graduado    ...     False
# 8610492   Abandonado         -    Graduado    ...     False
# 10364895           -         -    Graduado    ...     False
# 8348606            -         -    Graduado    ...     False
# 2781093            -         -    Graduado    ...     False
# 515763             -         -    Graduado    ...     False
# 9866941            -         -           -    ...     False
# 6912451            -         -    Graduado    ...     False
# 4297051            -         -    Graduado    ...     False
# 9273845            -         -           -    ...     False
# 2237095            -         -    Graduado    ...     False
#
#          empresa_importante capacitacion remuneracion_pretendida graduados  \
# 8611289               False        False                   False     False
# 3564085               False        False                   False     False
# 3111938               False        False                   False     False
# 9423691               False        False                   False     False
# 601585                False        False                   False     False
# 9722362               False        False                   False     False
# 11146135              False        False                   False     False
# 2066045               False        False                   False     False
# 3910172               False        False                   False     False
# 8003206               False        False                   False     False
# 8610492               False        False                   False     False
# 10364895               True        False                   False     False
# 8348606               False        False                   False     False
# 2781093                True        False                   False     False
# 515763                 True         True                   False     False
# 9866941                True         True                   False     False
# 6912451               False        False                   False     False
# 4297051               False        False                   False     False
# 9273845               False        False                   False     False
# 2237095               False        False                    True     False
#
#          estudiantes conocimientos_especificos buen_ambiente  discriminacion  \
# 8611289        False                     False         False           False
# 3564085        False                     False         False           False
# 3111938         True                     False         False           False
# 9423691        False                     False         False           False
# 601585         False                     False         False           False
# 9722362        False                     False         False           False
# 11146135       False                     False         False           False
# 2066045        False                     False         False           False
# 3910172        False                     False         False           False
# 8003206        False                      True         False            True
# 8610492        False                     False         False           False
# 10364895       False                     False         False           False
# 8348606        False                     False         False           False
# 2781093        False                     False         False           False
# 515763         False                     False         False           False
# 9866941        False                     False          True           False
# 6912451        False                     False         False           False
# 4297051        False                     False         False           False
# 9273845        False                     False         False           False
# 2237095        False                      True         False            True
#
#           cantidad
# 8611289        0.0
# 3564085        0.0
# 3111938        0.0
# 9423691        0.0
# 601585         0.0
# 9722362        0.0
# 11146135       0.0
# 2066045        0.0
# 3910172        0.0
# 8003206        0.0
# 8610492        0.0
# 10364895       0.0
# 8348606        0.0
# 2781093        0.0
# 515763         0.0
# 9866941        0.0
# 6912451        0.0
# 4297051        3.0
# 9273845        0.0
# 2237095        1.0
#
# [20 rows x 34 columns]

# %%
zonas=avisos['nombre_zona'].value_counts().index
postulaciones['nombre_zona']=postulaciones['nombre_zona'].replace(zonas, range(len(zonas)))

tipos_de_trabajo=avisos['tipo_de_trabajo'].value_counts().index
postulaciones['tipo_de_trabajo']=postulaciones['tipo_de_trabajo'].replace(tipos_de_trabajo, range(len(tipos_de_trabajo)))

niveles=avisos['nivel_laboral'].value_counts().index
postulaciones['nivel_laboral']=postulaciones['nivel_laboral'].replace(niveles, range(len(niveles)))

areas=avisos['nombre_area'].value_counts().index
postulaciones['nombre_area']=postulaciones['nombre_area'].replace(areas, range(len(areas)))

doct=postulantes['Doctorado'].value_counts().index
postulaciones['Doctorado']=postulaciones['Doctorado'].replace(doct, range(len(doct)))

master=postulantes['Master'].value_counts().index
postulaciones['Master']=postulaciones['Master'].replace(master, range(len(master)))

otro=postulantes['Otro'].value_counts().index
postulaciones['Otro']=postulaciones['Otro'].replace(otro, range(len(otro)))

posgrado=postulantes['Posgrado'].value_counts().index
postulaciones['Posgrado']=postulaciones['Posgrado'].replace(posgrado, range(len(posgrado)))

sec=postulantes['Secundario'].value_counts().index
postulaciones['Secundario']=postulaciones['Secundario'].replace(sec, range(len(sec)))

terc=postulantes['Terciario/Técnico'].value_counts().index
postulaciones['Terciario/Técnico']=postulaciones['Terciario/Técnico'].replace(terc, range(len(terc)))

univ=postulantes['Universitario'].value_counts().index
postulaciones['Universitario']=postulaciones['Universitario'].replace(univ, range(len(univ)))

sexo=postulantes['sexo'].value_counts().index
postulaciones['sexo']=postulaciones['sexo'].replace(sexo, range(len(sexo)))
postulaciones.dtypes
# Out:
# idaviso                        int64
# idpostulante                  object
# sepostulo                      int64
# sexo                           int64
# edad                         float64
# Doctorado                      int64
# Master                         int64
# Otro                           int64
# Posgrado                       int64
# Secundario                     int64
# Terciario/Técnico              int64
# Universitario                  int64
# titulo                        object
# nombre_zona                    int64
# tipo_de_trabajo                int64
# nivel_laboral                  int64
# nombre_area                    int64
# denominacion_empresa          object
# titulo_uppercase                bool
# ingles                          bool
# experiencia                     bool
# paquete_office                  bool
# liderazgo                       bool
# secundario                      bool
# viajar                          bool
# empresa_importante              bool
# capacitacion                    bool
# remuneracion_pretendida         bool
# graduados                       bool
# estudiantes                     bool
# conocimientos_especificos       bool
# buen_ambiente                   bool
# discriminacion                  bool
# cantidad                     float64
# dtype: object

# %%
train, test=train_test_split(postulaciones,test_size=0.10)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
# Out:
# Train:  11098950 Test:  1233217

# %%
c=XGBClassifier(objective='binary:logistic',max_depth=12,learning_rate=0.1,n_estimators=250,silent=False,n_jobs=-1)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl"
dt=c.fit(x_train,y_train)

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 74.08639355441905
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/XG1.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/XG1.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado    Master Otro  \
# 66051  56259  1112448524      zv8A6Pm   FEM  28.0         -         -    -
# 9699     748  1001457766       eAVkkE   FEM  28.0         -         -    -
# 19820  79752  1112464734      VNrRoBd  MASC  31.0         -         -    -
# 22117  14178  1112094756      8MPd0lx  MASC  36.0         -         -    -
# 11336  39435  1112417504       ZG5DBE  MASC  33.0         -         -    -
# 83701  32387  1112393571       111KmE  MASC  32.0         -         -    -
# 69817  22522  1112291389       8Lk6DO  MASC  57.0         -         -    -
# 98435  98276  1112505454       YQErYV   FEM  38.0         -         -    -
# 98628  98505  1112506439       EbRo14   FEM  31.0         -         -    -
# 69539  34392  1112408635        5mX6M  MASC  41.0         -  En Curso    -
#
#        Posgrado Secundario    ...    viajar empresa_importante capacitacion  \
# 66051         -          -    ...     False              False        False
# 9699          -   Graduado    ...     False              False        False
# 19820         -   Graduado    ...     False              False        False
# 22117         -          -    ...     False              False        False
# 11336         -          -    ...     False              False        False
# 83701         -   Graduado    ...     False              False        False
# 69817         -          -    ...     False               True        False
# 98435         -   Graduado    ...     False              False        False
# 98628  En Curso          -    ...     False              False        False
# 69539         -   Graduado    ...     False              False        False
#
#       remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 66051                   False     False       False                     False
# 9699                    False     False       False                     False
# 19820                   False     False       False                     False
# 22117                   False     False       False                     False
# 11336                   False     False       False                     False
# 83701                   False     False       False                     False
# 69817                   False     False       False                     False
# 98435                   False     False       False                     False
# 98628                   False     False       False                     False
# 69539                   False     False       False                     False
#
#       buen_ambiente  discriminacion  cantidad
# 66051         False           False       1.0
# 9699          False           False       0.0
# 19820         False           False       1.0
# 22117         False           False       5.0
# 11336         False           False       0.0
# 83701         False           False       0.0
# 69817          True           False       0.0
# 98435          True           False       0.0
# 98628         False           False       0.0
# 69539         False           False       0.0
#
# [10 rows x 34 columns]

# %%
zonas=avisos['nombre_zona'].value_counts().index
prediccion['nombre_zona']=prediccion['nombre_zona'].replace(zonas, range(len(zonas)))

tipos_de_trabajo=avisos['tipo_de_trabajo'].value_counts().index
prediccion['tipo_de_trabajo']=prediccion['tipo_de_trabajo'].replace(tipos_de_trabajo, range(len(tipos_de_trabajo)))

niveles=avisos['nivel_laboral'].value_counts().index
prediccion['nivel_laboral']=prediccion['nivel_laboral'].replace(niveles, range(len(niveles)))

areas=avisos['nombre_area'].value_counts().index
prediccion['nombre_area']=prediccion['nombre_area'].replace(areas, range(len(areas)))

doct=postulantes['Doctorado'].value_counts().index
prediccion['Doctorado']=prediccion['Doctorado'].replace(doct, range(len(doct)))

master=postulantes['Master'].value_counts().index
prediccion['Master']=prediccion['Master'].replace(master, range(len(master)))

otro=postulantes['Otro'].value_counts().index
prediccion['Otro']=prediccion['Otro'].replace(otro, range(len(otro)))

posgrado=postulantes['Posgrado'].value_counts().index
prediccion['Posgrado']=prediccion['Posgrado'].replace(posgrado, range(len(posgrado)))

sec=postulantes['Secundario'].value_counts().index
prediccion['Secundario']=prediccion['Secundario'].replace(sec, range(len(sec)))

terc=postulantes['Terciario/Técnico'].value_counts().index
prediccion['Terciario/Técnico']=prediccion['Terciario/Técnico'].replace(terc, range(len(terc)))

univ=postulantes['Universitario'].value_counts().index
prediccion['Universitario']=prediccion['Universitario'].replace(univ, range(len(univ)))

sexo=postulantes['sexo'].value_counts().index
prediccion['sexo']=prediccion['sexo'].replace(sexo, range(len(sexo)))
prediccion.dtypes
# Out:
# id                             int64
# idaviso                        int64
# idpostulante                  object
# sexo                           int64
# edad                         float64
# Doctorado                      int64
# Master                         int64
# Otro                           int64
# Posgrado                       int64
# Secundario                     int64
# Terciario/Técnico              int64
# Universitario                  int64
# titulo                        object
# nombre_zona                    int64
# tipo_de_trabajo                int64
# nivel_laboral                  int64
# nombre_area                    int64
# denominacion_empresa          object
# titulo_uppercase                bool
# ingles                          bool
# experiencia                     bool
# paquete_office                  bool
# liderazgo                       bool
# secundario                      bool
# viajar                          bool
# empresa_importante              bool
# capacitacion                    bool
# remuneracion_pretendida         bool
# graduados                       bool
# estudiantes                     bool
# conocimientos_especificos       bool
# buen_ambiente                   bool
# discriminacion                  bool
# cantidad                     float64
# dtype: object

# %%
x_final=prediccion[features]
y_final=c.predict(x_final)
y_final
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
prediccion['sepostulo']=y_final

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad  Doctorado  Master  Otro  Posgrado  \
# 0   0   739260       6M9ZQR     0  42.0          1       0     0         0
# 1   1   739260       6v1xdL     1  30.0          0       0     1         0
# 2   2   739260       ezRKm9     0  36.0          0       0     0         0
# 3   3   758580       1Q35ej     1  68.0          0       0     0         1
# 4   4   758580       EAN4J6     0  32.0          0       0     0         0
#
#    Secundario    ...      empresa_importante  capacitacion  \
# 0           0    ...                   False         False
# 1           1    ...                   False         False
# 2           0    ...                   False         False
# 3           0    ...                   False         False
# 4           1    ...                   False         False
#
#   remuneracion_pretendida  graduados  estudiantes  conocimientos_especificos  \
# 0                   False      False        False                      False
# 1                   False      False        False                      False
# 2                   False      False        False                      False
# 3                   False      False        False                      False
# 4                   False      False        False                      False
#
#    buen_ambiente discriminacion  cantidad  sepostulo
# 0          False          False       0.0          0
# 1          False          False       0.0          1
# 2          False          False       0.0          0
# 3          False          False       0.0          0
# 4          False          False       0.0          0
#
# [5 rows x 35 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0          0
# 1   1          1
# 2   2          0
# 3   3          0
# 4   4          0

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion8.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.54145

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado Master      Otro  \
# 7461   89284  1112467020      3NkKNAq   FEM  24.0         -      -  Graduado
# 28397  21146  1112269993       ZEQq01  MASC  38.0         -      -         -
# 78975  47196  1112431256       a4ae99   FEM  42.0         -      -         -
# 7394   88910  1112467020      ow2MYl0   FEM  22.0         -      -         -
# 56245  48217  1112432694      VNr90l2   FEM  19.0         -      -         -
# 16174  68876  1112460892       ZrNJmz   FEM  33.0         -      -         -
# 49962   3274  1111363105       YG5E6X   FEM  32.0         -      -         -
# 28372  51431  1112441702       Z9r9AP   FEM  40.0         -      -         -
# 740    73684  1112463429       12LMZb  MASC  40.0         -      -         -
# 1554   86561  1112466769      BmVY3Y2  MASC  28.0         -      -  Graduado
#
#          Posgrado Secundario    ...    viajar empresa_importante capacitacion  \
# 7461            -   Graduado    ...     False              False         True
# 28397           -   Graduado    ...     False              False        False
# 78975           -   Graduado    ...     False              False        False
# 7394            -   En Curso    ...     False              False         True
# 56245           -   Graduado    ...     False              False        False
# 16174           -          -    ...     False               True        False
# 49962           -   Graduado    ...     False               True        False
# 28372  Abandonado   Graduado    ...     False              False        False
# 740             -   Graduado    ...     False              False        False
# 1554            -   Graduado    ...     False               True        False
#
#       remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 7461                    False     False       False                     False
# 28397                   False     False       False                     False
# 78975                   False     False        True                     False
# 7394                    False     False       False                     False
# 56245                   False     False       False                     False
# 16174                   False     False       False                     False
# 49962                   False     False       False                     False
# 28372                   False     False       False                     False
# 740                     False     False       False                     False
# 1554                    False     False        True                     False
#
#       buen_ambiente  discriminacion  cantidad
# 7461           True           False       1.0
# 28397         False           False       0.0
# 78975          True           False       0.0
# 7394           True           False       3.0
# 56245          True           False       2.0
# 16174         False           False       0.0
# 49962         False           False       0.0
# 28372          True           False       2.0
# 740           False           False       0.0
# 1554          False           False       1.0
#
# [10 rows x 34 columns]

# %%
zonas=avisos['nombre_zona'].value_counts().index
prediccion['nombre_zona']=prediccion['nombre_zona'].replace(zonas, range(len(zonas)))

tipos_de_trabajo=avisos['tipo_de_trabajo'].value_counts().index
prediccion['tipo_de_trabajo']=prediccion['tipo_de_trabajo'].replace(tipos_de_trabajo, range(len(tipos_de_trabajo)))

niveles=avisos['nivel_laboral'].value_counts().index
prediccion['nivel_laboral']=prediccion['nivel_laboral'].replace(niveles, range(len(niveles)))

areas=avisos['nombre_area'].value_counts().index
prediccion['nombre_area']=prediccion['nombre_area'].replace(areas, range(len(areas)))

doct=postulantes['Doctorado'].value_counts().index
prediccion['Doctorado']=prediccion['Doctorado'].replace(doct, range(len(doct)))

master=postulantes['Master'].value_counts().index
prediccion['Master']=prediccion['Master'].replace(master, range(len(master)))

otro=postulantes['Otro'].value_counts().index
prediccion['Otro']=prediccion['Otro'].replace(otro, range(len(otro)))

posgrado=postulantes['Posgrado'].value_counts().index
prediccion['Posgrado']=prediccion['Posgrado'].replace(posgrado, range(len(posgrado)))

sec=postulantes['Secundario'].value_counts().index
prediccion['Secundario']=prediccion['Secundario'].replace(sec, range(len(sec)))

terc=postulantes['Terciario/Técnico'].value_counts().index
prediccion['Terciario/Técnico']=prediccion['Terciario/Técnico'].replace(terc, range(len(terc)))

univ=postulantes['Universitario'].value_counts().index
prediccion['Universitario']=prediccion['Universitario'].replace(univ, range(len(univ)))

sexo=postulantes['sexo'].value_counts().index
prediccion['sexo']=prediccion['sexo'].replace(sexo, range(len(sexo)))
prediccion.dtypes
# Out:
# id                             int64
# idaviso                        int64
# idpostulante                  object
# sexo                           int64
# edad                         float64
# Doctorado                      int64
# Master                         int64
# Otro                           int64
# Posgrado                       int64
# Secundario                     int64
# Terciario/Técnico              int64
# Universitario                  int64
# titulo                        object
# nombre_zona                    int64
# tipo_de_trabajo                int64
# nivel_laboral                  int64
# nombre_area                    int64
# denominacion_empresa          object
# titulo_uppercase                bool
# ingles                          bool
# experiencia                     bool
# paquete_office                  bool
# liderazgo                       bool
# secundario                      bool
# viajar                          bool
# empresa_importante              bool
# capacitacion                    bool
# remuneracion_pretendida         bool
# graduados                       bool
# estudiantes                     bool
# conocimientos_especificos       bool
# buen_ambiente                   bool
# discriminacion                  bool
# cantidad                     float64
# dtype: object

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.8283851 , 0.17161489],
#        [0.48534966, 0.51465034],
#        [0.63955516, 0.36044484],
#        ...,
#        [0.9723678 , 0.02763215],
#        [0.7130018 , 0.2869982 ],
#        [0.9654636 , 0.03453643]], dtype=float32)

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad  Doctorado  Master  Otro  Posgrado  \
# 0   0   739260       6M9ZQR     0  42.0          1       0     0         0
# 1   1   739260       6v1xdL     1  30.0          0       0     1         0
# 2   2   739260       ezRKm9     0  36.0          0       0     0         0
# 3   3   758580       1Q35ej     1  68.0          0       0     0         1
# 4   4   758580       EAN4J6     0  32.0          0       0     0         0
#
#    Secundario    ...      empresa_importante  capacitacion  \
# 0           0    ...                   False         False
# 1           1    ...                   False         False
# 2           0    ...                   False         False
# 3           0    ...                   False         False
# 4           1    ...                   False         False
#
#   remuneracion_pretendida  graduados  estudiantes  conocimientos_especificos  \
# 0                   False      False        False                      False
# 1                   False      False        False                      False
# 2                   False      False        False                      False
# 3                   False      False        False                      False
# 4                   False      False        False                      False
#
#    buen_ambiente discriminacion  cantidad  sepostulo
# 0          False          False       0.0   0.171615
# 1          False          False       0.0   0.514650
# 2          False          False       0.0   0.360445
# 3          False          False       0.0   0.117248
# 4          False          False       0.0   0.311030
#
# [5 rows x 35 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.171615
# 1   1   0.514650
# 2   2   0.360445
# 3   3   0.117248
# 4   4   0.311030

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion9.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.6008477204817586
