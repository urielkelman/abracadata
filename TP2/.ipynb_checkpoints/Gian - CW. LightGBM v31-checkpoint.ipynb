# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')
avisos['denominacion_empresa']=avisos['denominacion_empresa'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#       idaviso idpostulante
# 0  1111780242      YjVJQ6Z
# 1  1112263876      BmVpYoR
# 2  1112327963      wVkBzZd
# 3  1112318643      OqmP9pv
# 4  1111903673      DrpbXDP

# %%
vistas_por_area=vistas.copy()
vistas_por_area['vistas_por_area']=0;
vistas_por_area=pd.merge(vistas_por_area,avisos,on='idaviso', how='left')
vistas_por_area=vistas_por_area.groupby(['idpostulante','nombre_area'],as_index=False).agg({'vistas_por_area':'count'})
vistas_por_area.head()
# Out:
#   idpostulante            nombre_area  vistas_por_area
# 0        0005E  Tecnologia / Sistemas                2
# 1        00Lkv      Comercio Exterior                2
# 2        00dMd      Comercio Exterior                4
# 3        01QAq           Contabilidad                1
# 4        021OM      Comercio Exterior                5

# %%
vistas_por_nivel=vistas.copy()
vistas_por_nivel['vistas_por_nivel']=0;
vistas_por_nivel=pd.merge(vistas_por_nivel,avisos,on='idaviso', how='left')
vistas_por_nivel=vistas_por_nivel.groupby(['idpostulante','nivel_laboral'],as_index=False).agg({'vistas_por_nivel':'count'})
vistas_por_nivel.head()
# Out:
#   idpostulante nivel_laboral  vistas_por_nivel
# 0        0005E          Otro                 2
# 1        00Lkv          Otro                 2
# 2        00dMd          Otro                 4
# 3        01QAq          Otro                 1
# 4        021OM          Otro                 5

# %%
vistas_por_tipo=vistas.copy()
vistas_por_tipo['vistas_por_tipo']=0;
vistas_por_tipo=pd.merge(vistas_por_tipo,avisos,on='idaviso', how='left')
vistas_por_tipo=vistas_por_tipo.groupby(['idpostulante','tipo_de_trabajo'],as_index=False).agg({'vistas_por_tipo':'count'})
vistas_por_tipo.head()
# Out:
#   idpostulante tipo_de_trabajo  vistas_por_tipo
# 0        0005E       Full-time                2
# 1        00Lkv       Full-time                2
# 2        00dMd       Full-time                4
# 3        01QAq       Full-time                1
# 4        021OM       Full-time                5

# %%
vistas['cantidad']=0
vistas2=vistas.groupby(['idaviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q        15
# 1        0005E        58
# 2        000R8        14
# 3        001XE        26
# 4        003k9        32

# %%
vistas3=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           2          28
# 1    48375       RwVdKR           1          15
# 2   169730        1KjXB           2          99
# 3   169730       2AKzxa           2           2
# 4   169730        6LJ64           1          23

# %%
vistas3['cantidad']=vistas3['cantidad_x']/vistas3['cantidad_y']
vistas3.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.071429
# 1    48375       RwVdKR  0.066667
# 2   169730        1KjXB  0.020202
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.043478

# %%
vistas=vistas.rename(columns={'cantidad': 'vistas_postulante'})
vistas2=vistas2.rename(columns={'cantidad': 'vistas_al_aviso'})

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/7.csv")
print(len(postulaciones2))
postulaciones2
# Out:
# 6604534
#             idaviso idpostulante  sepostulo
# 0        1112389495       5NbOjG          0
# 1        1112024109      1QP841b          0
# 2        1112490884      96XQ6N9          0
# 3        1111474259      qe2QJj1          0
# 4        1112211292      KBzbBJm          0
# 5        1112328485      3NzZv26          0
# 6        1112474766      akDjWwE          0
# 7        1112312385       aZpBJW          0
# 8        1112285628      akDWj55          0
# 9        1112322843      GNd0KNN          0
# 10       1112355899      DrXPRJX          0
# 11       1112461865      8MPoBDR          0
# 12       1111673413       a1NjRN          0
# 13       1112299006      jkVWXRQ          0
# 14       1112501771      owz0YGW          0
# 15       1002543409       Ej5AAb          0
# 16       1112425310      KBrpAO2          0
# 17       1112498569      pzNMppM          0
# 18       1111866251       ZKqL85          0
# 19       1112289529      ow2awXr          0
# 20       1112493109      5mP1DWM          0
# 21       1112326017      0zd9GZ9          0
# 22       1112242315      3NQKV6Q          0
# 23       1112452417      DrlVEwW          0
# 24       1112402816      mzdk9dZ          0
# 25       1112359100      3NP46xq          0
# 26       1112410555      bOVKA32          0
# 27       1112511403      mzdlAQO          0
# 28       1111272539      6rPpNM4          0
# 29       1111591317      6rP4K13          0
# ...             ...          ...        ...
# 6604504  1112261798      4redE6e          0
# 6604505  1112420559      3NPGjxJ          0
# 6604506  1112363380      ak530RE          0
# 6604507  1112252533      A3DJwW6          0
# 6604508  1112215124      X9PQprx          0
# 6604509  1112104454      BmDEKmR          0
# 6604510  1112392900      ow2rR3L          0
# 6604511  1112507433      Rz9lmOZ          0
# 6604512  1112429493       EPJ61J          0
# 6604513  1112210380      OqbL8ax          0
# 6604514  1112454949      Yj5ePRX          0
# 6604515  1112257707      8M2eEND          0
# 6604516  1111714857      ZDaoE2V          0
# 6604517  1112364849      0zB3A2Y          0
# 6604518  1112088772       EX5v0o          0
# 6604519  1112457555      6r5ja3R          0
# 6604520  1112268539      X9ldw4P          0
# 6604521  1112281854      mzdLoRO          0
# 6604522  1112372007       ZLlZkR          0
# 6604523  1112218903      lDbPjY8          0
# 6604524  1112443846      JBrVQDp          0
# 6604525  1112357563      0zdEoq1          0
# 6604526  1112296494      X9k4xdQ          0
# 6604527  1112314288      akje1Eq          0
# 6604528  1112455177      X95do0J          0
# 6604529  1112416094        5xdQq          0
# 6604530  1112237658      xkd8D80          0
# 6604531  1112292393      Yj523Aq          0
# 6604532  1112322583      bOjkL0B          0
# 6604533  1112305358      ow5AKKa          0
#
# [6604534 rows x 3 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 13209068
# 13203430

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas2,on=['idaviso','idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas3,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 4428928   1112403685      rm2YLoz          0   FEM  24.0         -      -
# 8047149   1112505479       ZrdYJb          0   FEM  30.0         -      -
# 10465144  1111683400      X9oe9D8          0   FEM  35.0         -      -
# 6048648   1112495397      EzldO1z          0   FEM  30.0         -      -
# 530227    1112355444      owjGRza          1   FEM  26.0         -      -
# 8576109   1112357005      8MPzLEj          0   FEM  19.0         -      -
# 5539821   1112438273       1JW6pb          1   FEM  28.0         -      -
# 5127396   1112356544      kPXM6Zj          0   FEM  25.0         -      -
# 1238882   1112432922       aOG6wq          1  MASC  39.0         -      -
# 1411019   1112033906      Ez0aLPo          1   FEM  28.0         -      -
# 5533046   1112338278      Yj5RV1X          1  MASC  31.0         -      -
# 7899730   1112118387      mz3NJ1Q          0   FEM  23.0         -      -
# 8700818   1112438126      5mr3QxZ          0  MASC  23.0         -      -
# 1614126   1112396755      6rPE3q4          1  MASC  23.0         -      -
# 4771054   1112105602      rmdkd41          0   FEM  22.0         -      -
# 1975441   1112414507      ZD8qEb8          1   FEM  22.0         -      -
# 9331451   1112275843       5vXYaG          0  MASC  39.0         -      -
# 9534226   1112470166      kPXbWdj          0  MASC  30.0         -      -
# 10547042  1112444567      3NPJrlJ          0  MASC  32.0         -      -
# 9451722   1112262303      PmVwNbY          1   FEM  33.0         -      -
#
#               Otro  Posgrado  Secundario    ...    capacitacion  \
# 4428928          -         -    Graduado    ...           False
# 8047149          -         -    Graduado    ...           False
# 10465144  Graduado         -    Graduado    ...            True
# 6048648          -         -  Abandonado    ...            True
# 530227           -         -           -    ...           False
# 8576109          -         -           -    ...           False
# 5539821   Graduado         -    Graduado    ...           False
# 5127396          -         -    Graduado    ...           False
# 1238882          -  En Curso    Graduado    ...           False
# 1411019          -         -           -    ...            True
# 5533046          -         -    Graduado    ...           False
# 7899730          -         -    Graduado    ...           False
# 8700818          -         -    Graduado    ...           False
# 1614126          -         -    Graduado    ...           False
# 4771054          -         -           -    ...           False
# 1975441          -         -    Graduado    ...           False
# 9331451   Graduado         -    Graduado    ...           False
# 9534226          -         -           -    ...            True
# 10547042  Graduado         -    Graduado    ...            True
# 9451722          -         -    Graduado    ...            True
#
#          remuneracion_pretendida graduados estudiantes  \
# 4428928                    False      True        True
# 8047149                    False     False       False
# 10465144                   False      True       False
# 6048648                    False     False       False
# 530227                     False     False       False
# 8576109                    False     False       False
# 5539821                    False     False       False
# 5127396                     True     False        True
# 1238882                    False     False       False
# 1411019                    False     False       False
# 5533046                    False     False       False
# 7899730                    False     False       False
# 8700818                    False     False       False
# 1614126                    False     False       False
# 4771054                    False     False       False
# 1975441                    False     False       False
# 9331451                    False      True        True
# 9534226                    False     False       False
# 10547042                   False     False       False
# 9451722                    False     False       False
#
#          conocimientos_especificos buen_ambiente discriminacion  \
# 4428928                      False         False          False
# 8047149                      False         False          False
# 10465144                     False         False          False
# 6048648                      False         False          False
# 530227                       False         False          False
# 8576109                      False         False          False
# 5539821                      False         False          False
# 5127396                      False         False          False
# 1238882                      False         False          False
# 1411019                      False          True          False
# 5533046                      False          True          False
# 7899730                      False         False          False
# 8700818                      False          True          False
# 1614126                      False         False          False
# 4771054                      False         False          False
# 1975441                      False          True          False
# 9331451                      False          True          False
# 9534226                      False         False          False
# 10547042                     False         False          False
# 9451722                      False         False          False
#
#          vistas_postulante  vistas_al_aviso  cantidad
# 4428928                NaN              NaN       NaN
# 8047149                NaN              NaN       NaN
# 10465144              44.0              NaN       NaN
# 6048648               25.0              NaN       NaN
# 530227               127.0              NaN       NaN
# 8576109               97.0              NaN       NaN
# 5539821              659.0              2.0  0.003035
# 5127396                NaN              NaN       NaN
# 1238882              102.0              3.0  0.029412
# 1411019                NaN              NaN       NaN
# 5533046              322.0              NaN       NaN
# 7899730               10.0              NaN       NaN
# 8700818               18.0              NaN       NaN
# 1614126               30.0              1.0  0.033333
# 4771054                2.0              NaN       NaN
# 1975441               39.0              8.0  0.205128
# 9331451                1.0              NaN       NaN
# 9534226                2.0              NaN       NaN
# 10547042             308.0              NaN       NaN
# 9451722              117.0              NaN       NaN
#
# [20 rows x 38 columns]

# %%
postulaciones['cantidad']=postulaciones['cantidad'].fillna(0)
postulaciones['vistas_postulante']=postulaciones['vistas_postulante'].fillna(0)
postulaciones['vistas_al_aviso']=postulaciones['vistas_al_aviso'].fillna(0)
postulaciones['lo_vio']=(postulaciones['vistas_al_aviso']>0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado    Master  \
# 12198641  1112206184      2zrz0d1          0  MASC  31.0         -  En Curso
# 3566069   1112406683       56xjeX          0   FEM  30.0         -         -
# 2971296   1112252542       8kG0kj          0   FEM  48.0         -         -
# 3575255   1112280912      PmLa1Pv          0  MASC  31.0         -         -
# 9585270   1112296636      2zQ0bBo          1   FEM  21.0         -         -
# 11680985  1112492731      akjmDGW          0   FEM  35.0         -         -
# 3765670   1112413895      1Q4ZkZb          0   FEM  27.0         -         -
# 10213598  1112502951       1DNdDR          0   FEM  28.0         -         -
# 10856927  1112245459      qekdDYa          0   FEM  24.0         -         -
# 419759    1112303105      EzZGwk2          1   FEM  26.0         -         -
# 9386448   1112277435      bOzxBZY          0   FEM  25.0         -         -
# 138984    1112431016      PmG6zMa          0   FEM  33.0         -         -
# 6185397   1112369190      EzZr02o          1  MASC  28.0         -         -
# 7639265   1112300119        ZEAKb          0  MASC  48.0         -         -
# 12267475  1112247726      YjA90bD          0   FEM  49.0         -         -
# 3865766   1112239122      MVrlpve          0  MASC  52.0         -         -
# 8470253   1112298672      DrXj1NZ          0   FEM  35.0         -         -
# 4147958   1112377276      zvxDvOm          0   FEM  40.0         -         -
# 3759719   1112353739      xk9WDJj          1   FEM  25.0         -         -
# 9355850   1112455774      8MaQjP3          1   FEM  24.0         -         -
#
#               Otro  Posgrado Secundario   ...   remuneracion_pretendida  \
# 12198641         -         -   Graduado   ...                      True
# 3566069   En Curso         -          -   ...                     False
# 2971296          -         -   Graduado   ...                     False
# 3575255          -         -          -   ...                     False
# 9585270          -         -          -   ...                     False
# 11680985         -         -          -   ...                     False
# 3765670          -         -          -   ...                     False
# 10213598         -  Graduado          -   ...                     False
# 10856927  Graduado         -   Graduado   ...                     False
# 419759           -         -   Graduado   ...                     False
# 9386448          -         -   Graduado   ...                     False
# 138984           -         -          -   ...                     False
# 6185397          -         -   Graduado   ...                     False
# 7639265          -         -          -   ...                     False
# 12267475         -         -          -   ...                     False
# 3865766          -         -          -   ...                     False
# 8470253          -         -   Graduado   ...                     False
# 4147958          -         -   Graduado   ...                     False
# 3759719          -         -          -   ...                      True
# 9355850          -         -          -   ...                      True
#
#          graduados estudiantes conocimientos_especificos buen_ambiente  \
# 12198641      True       False                     False          True
# 3566069      False       False                      True         False
# 2971296      False       False                     False         False
# 3575255      False       False                     False         False
# 9585270      False       False                     False         False
# 11680985     False       False                     False          True
# 3765670      False       False                     False         False
# 10213598     False       False                     False         False
# 10856927     False       False                     False         False
# 419759       False       False                     False          True
# 9386448      False       False                     False          True
# 138984       False       False                     False         False
# 6185397      False       False                     False         False
# 7639265      False        True                     False         False
# 12267475     False       False                     False         False
# 3865766      False       False                     False         False
# 8470253      False       False                     False         False
# 4147958      False       False                     False         False
# 3759719      False       False                     False         False
# 9355850      False       False                     False         False
#
#          discriminacion vistas_postulante vistas_al_aviso  cantidad  lo_vio
# 12198641          False               0.0             0.0   0.00000   False
# 3566069            True             141.0             0.0   0.00000   False
# 2971296           False              25.0             0.0   0.00000   False
# 3575255           False              21.0             0.0   0.00000   False
# 9585270           False              60.0             0.0   0.00000   False
# 11680985          False              15.0             0.0   0.00000   False
# 3765670           False               2.0             0.0   0.00000   False
# 10213598          False               5.0             0.0   0.00000   False
# 10856927          False              13.0             0.0   0.00000   False
# 419759            False               3.0             0.0   0.00000   False
# 9386448            True              15.0             0.0   0.00000   False
# 138984            False               0.0             0.0   0.00000   False
# 6185397           False               5.0             0.0   0.00000   False
# 7639265           False             204.0             0.0   0.00000   False
# 12267475          False               1.0             0.0   0.00000   False
# 3865766           False              23.0             0.0   0.00000   False
# 8470253           False              21.0             0.0   0.00000   False
# 4147958           False               0.0             0.0   0.00000   False
# 3759719           False              10.0             1.0   0.10000    True
# 9355850           False            4443.0             2.0   0.00045    True
#
# [20 rows x 39 columns]

# %%
postulaciones_por_area=postulaciones.copy()
postulaciones_por_area=postulaciones_por_area.groupby(by=['idpostulante','nombre_area'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_area=postulaciones_por_area.rename(columns={'sepostulo':'postulaciones_misma_area'})
postulaciones_por_area.head()
# Out:
#   idpostulante                      nombre_area  postulaciones_misma_area
# 0      0z5Dmrd                   Administración                         1
# 1      0z5Dmrd  Almacén / Depósito / Expedición                         1
# 2      0z5Dmrd              Atención al Cliente                         1
# 3      0z5Dmrd                        Auditoría                         1
# 4      0z5Dmrd                     Contabilidad                         1

# %%
postulaciones_por_nivel=postulaciones.copy()
postulaciones_por_nivel=postulaciones_por_nivel.groupby(by=['idpostulante','nivel_laboral'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_nivel=postulaciones_por_nivel.rename(columns={'sepostulo':'postulaciones_mismo_nivel'})
postulaciones_por_nivel.head()
# Out:
#   idpostulante                         nivel_laboral  \
# 0      0z5Dmrd  Gerencia / Alta Gerencia / Dirección
# 1      0z5Dmrd                                Junior
# 2      0z5Dmrd                                  Otro
# 3      0z5Dmrd                  Senior / Semi-Senior
# 4      0z5JW1r  Gerencia / Alta Gerencia / Dirección
#
#    postulaciones_mismo_nivel
# 0                          1
# 1                          2
# 2                          1
# 3                         13
# 4                          2

# %%
postulaciones_por_tipo=postulaciones.copy()
postulaciones_por_tipo=postulaciones_por_tipo.groupby(by=['idpostulante','tipo_de_trabajo'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_tipo=postulaciones_por_tipo.rename(columns={'sepostulo':'postulaciones_mismo_tipo'})
postulaciones_por_tipo.head()
# Out:
#   idpostulante tipo_de_trabajo  postulaciones_mismo_tipo
# 0      0z5Dmrd       Full-time                        16
# 1      0z5Dmrd       Part-time                         1
# 2      0z5JW1r       Full-time                        21
# 3      0z5VvGv       Full-time                        50
# 4      0z5VvGv       Part-time                        10

# %%
postulaciones=pd.merge(postulaciones,postulaciones_por_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['postulaciones_misma_area']=postulaciones['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_nivel']=postulaciones['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_tipo']=postulaciones['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones=pd.merge(postulaciones,vistas_por_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,vistas_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,vistas_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['vistas_por_area']=postulaciones['vistas_por_area'].fillna(0)
postulaciones['vistas_por_tipo']=postulaciones['vistas_por_tipo'].fillna(0)
postulaciones['vistas_por_nivel']=postulaciones['vistas_por_tipo'].fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 12336699  1112203522      qe20WbN          0  MASC  18.0         -      -
# 8910627   1112363711      0zPv0zd          1  MASC  19.0         -      -
# 5528785   1112423240      5mqV2bq          0  MASC  22.0         -      -
# 10505681  1112220097      X95L0qv          0  MASC  20.0         -      -
# 10108229  1112245437      mzd1MAE          1  MASC  26.0         -      -
# 8342842   1112306500       ErRxr2          1   FEM  30.0         -      -
# 9080154   1112361447      bOVAxV2          0   FEM  21.0         -      -
# 6318608   1112463897      NzjOApx          0   FEM  48.0         -      -
# 5984268   1111431474      8MPA63x          0   FEM  21.0         -      -
# 11455310  1112224987      Yj5O4qX          0  MASC  27.0         -      -
# 1942771   1112461808      mzVbl1G          0  MASC  27.0         -      -
# 9814559   1112396117      mzdeqDd          0   FEM  26.0         -      -
# 6855235   1112366307      X9WzvdL          0   FEM  24.0         -      -
# 11759463  1112268576      4rmlYJE          1  MASC  26.0         -      -
# 430223    1112308667      MVdmxQp          1   FEM  24.0         -      -
# 11847269  1112503512      jkj9vre          0   FEM  17.0         -      -
# 12052530  1112364947      A3Xwp6j          1  MASC  41.0         -      -
# 9378695   1112215097       6q9Mk3          0  MASC  38.0         -      -
# 3200796   1112189900      akDjDX5          1   FEM  26.0         -      -
# 4463116   1112359485      GNdBkWN          0   FEM  22.0         -      -
#
#               Otro Posgrado Secundario        ...        vistas_postulante  \
# 12336699         -        -   Graduado        ...                      1.0
# 8910627          -        -   Graduado        ...                     22.0
# 5528785          -        -   Graduado        ...                      4.0
# 10505681         -        -   Graduado        ...                     36.0
# 10108229         -        -   En Curso        ...                      0.0
# 8342842          -        -   Graduado        ...                     13.0
# 9080154          -        -          -        ...                      3.0
# 6318608          -        -   Graduado        ...                      9.0
# 5984268          -        -   Graduado        ...                      0.0
# 11455310         -        -   Graduado        ...                      0.0
# 1942771          -        -   Graduado        ...                      8.0
# 9814559          -        -          -        ...                      0.0
# 6855235          -        -   Graduado        ...                    106.0
# 11759463  En Curso        -   Graduado        ...                     53.0
# 430223           -        -   Graduado        ...                      0.0
# 11847269         -        -   En Curso        ...                      1.0
# 12052530         -        -   Graduado        ...                      0.0
# 9378695          -        -          -        ...                      0.0
# 3200796          -        -   Graduado        ...                      1.0
# 4463116          -        -   Graduado        ...                      0.0
#
#          vistas_al_aviso  cantidad lo_vio postulaciones_misma_area  \
# 12336699             0.0  0.000000  False                        0
# 8910627              2.0  0.090909   True                        1
# 5528785              0.0  0.000000  False                        0
# 10505681             0.0  0.000000  False                        0
# 10108229             0.0  0.000000  False                        1
# 8342842              0.0  0.000000  False                       18
# 9080154              0.0  0.000000  False                        0
# 6318608              0.0  0.000000  False                        0
# 5984268              0.0  0.000000  False                        8
# 11455310             0.0  0.000000  False                        0
# 1942771              0.0  0.000000  False                        0
# 9814559              0.0  0.000000  False                        0
# 6855235              0.0  0.000000  False                        0
# 11759463             0.0  0.000000  False                       16
# 430223               0.0  0.000000  False                        5
# 11847269             0.0  0.000000  False                        0
# 12052530             0.0  0.000000  False                        0
# 9378695              0.0  0.000000  False                        9
# 3200796              0.0  0.000000  False                        4
# 4463116              0.0  0.000000  False                        0
#
#          postulaciones_mismo_tipo postulaciones_mismo_nivel vistas_por_area  \
# 12336699                       12                         8             0.0
# 8910627                         4                         4             2.0
# 5528785                        10                         0             0.0
# 10505681                       38                        21             0.0
# 10108229                       14                         7             0.0
# 8342842                        66                        51             2.0
# 9080154                        19                        16             0.0
# 6318608                        12                         6             0.0
# 5984268                        32                        35             0.0
# 11455310                       14                        12             0.0
# 1942771                         0                         0             0.0
# 9814559                        15                        10             0.0
# 6855235                        10                         7             0.0
# 11759463                       70                        57             0.0
# 430223                         35                       103             0.0
# 11847269                       12                         9             0.0
# 12052530                      374                       345             0.0
# 9378695                        21                        11             0.0
# 3200796                        15                        10             0.0
# 4463116                        17                         0             0.0
#
#           vistas_por_tipo  vistas_por_nivel
# 12336699              1.0               1.0
# 8910627              22.0              22.0
# 5528785               4.0               4.0
# 10505681             28.0              28.0
# 10108229              0.0               0.0
# 8342842              13.0              13.0
# 9080154               3.0               3.0
# 6318608               9.0               9.0
# 5984268               0.0               0.0
# 11455310              0.0               0.0
# 1942771               0.0               0.0
# 9814559               0.0               0.0
# 6855235              72.0              72.0
# 11759463             41.0              41.0
# 430223                0.0               0.0
# 11847269              1.0               1.0
# 12052530              0.0               0.0
# 9378695               0.0               0.0
# 3200796               1.0               1.0
# 4463116               0.0               0.0
#
# [20 rows x 45 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
# Out:
# Train:  12148226 Test:  639381

# %%
gc.collect()
# Out:
# 312

# %%
c=lgb.LGBMClassifier(learning_rate=0.05,objective='binary',num_leaves=12000,max_depth=18,n_estimators=1200,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train,eval_set=[(x_test,y_test)],verbose=True,early_stopping_rounds=5)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")
# Out:
# [1]	valid_0's binary_logloss: 0.659126
# Training until validation scores don't improve for 5 rounds.
# [2]	valid_0's binary_logloss: 0.628227
# [3]	valid_0's binary_logloss: 0.598954
# [4]	valid_0's binary_logloss: 0.571159
# [5]	valid_0's binary_logloss: 0.546025
# [6]	valid_0's binary_logloss: 0.523624
# [7]	valid_0's binary_logloss: 0.502844
# [8]	valid_0's binary_logloss: 0.482801
# [9]	valid_0's binary_logloss: 0.46505
# [10]	valid_0's binary_logloss: 0.44863
# [11]	valid_0's binary_logloss: 0.432504
# [12]	valid_0's binary_logloss: 0.417547
# [13]	valid_0's binary_logloss: 0.403727
# [14]	valid_0's binary_logloss: 0.392309
# [15]	valid_0's binary_logloss: 0.381115
# [16]	valid_0's binary_logloss: 0.371263
# [17]	valid_0's binary_logloss: 0.360395
# [18]	valid_0's binary_logloss: 0.351295
# [19]	valid_0's binary_logloss: 0.341677
# [20]	valid_0's binary_logloss: 0.33365
# [21]	valid_0's binary_logloss: 0.32525
# [22]	valid_0's binary_logloss: 0.317281
# [23]	valid_0's binary_logloss: 0.310709
# [24]	valid_0's binary_logloss: 0.304738
# [25]	valid_0's binary_logloss: 0.297927
# [26]	valid_0's binary_logloss: 0.291576
# [27]	valid_0's binary_logloss: 0.285571
# [28]	valid_0's binary_logloss: 0.281086
# [29]	valid_0's binary_logloss: 0.276437
# [30]	valid_0's binary_logloss: 0.271357
# [31]	valid_0's binary_logloss: 0.267387
# [32]	valid_0's binary_logloss: 0.263047
# [33]	valid_0's binary_logloss: 0.259393
# [34]	valid_0's binary_logloss: 0.255534
# [35]	valid_0's binary_logloss: 0.252009
# [36]	valid_0's binary_logloss: 0.248854
# [37]	valid_0's binary_logloss: 0.245936
# [38]	valid_0's binary_logloss: 0.24322
# [39]	valid_0's binary_logloss: 0.240093
# [40]	valid_0's binary_logloss: 0.237221
# [41]	valid_0's binary_logloss: 0.234513
# [42]	valid_0's binary_logloss: 0.231729
# [43]	valid_0's binary_logloss: 0.229165
# [44]	valid_0's binary_logloss: 0.226692
# [45]	valid_0's binary_logloss: 0.224368
# [46]	valid_0's binary_logloss: 0.222324
# [47]	valid_0's binary_logloss: 0.22012
# [48]	valid_0's binary_logloss: 0.218093
# [49]	valid_0's binary_logloss: 0.216278
# [50]	valid_0's binary_logloss: 0.214459
# [51]	valid_0's binary_logloss: 0.212754
# [52]	valid_0's binary_logloss: 0.211023
# [53]	valid_0's binary_logloss: 0.209534
# [54]	valid_0's binary_logloss: 0.207976
# [55]	valid_0's binary_logloss: 0.20666
# [56]	valid_0's binary_logloss: 0.205413
# [57]	valid_0's binary_logloss: 0.20421
# [58]	valid_0's binary_logloss: 0.203304
# [59]	valid_0's binary_logloss: 0.202077
# [60]	valid_0's binary_logloss: 0.201166
# [61]	valid_0's binary_logloss: 0.200066
# [62]	valid_0's binary_logloss: 0.199154
# [63]	valid_0's binary_logloss: 0.19816
# [64]	valid_0's binary_logloss: 0.197292
# [65]	valid_0's binary_logloss: 0.196643
# [66]	valid_0's binary_logloss: 0.19603
# [67]	valid_0's binary_logloss: 0.195241
# [68]	valid_0's binary_logloss: 0.194379
# [69]	valid_0's binary_logloss: 0.193725
# [70]	valid_0's binary_logloss: 0.193029
# [71]	valid_0's binary_logloss: 0.192248
# [72]	valid_0's binary_logloss: 0.191481
# [73]	valid_0's binary_logloss: 0.19086
# [74]	valid_0's binary_logloss: 0.190263
# [75]	valid_0's binary_logloss: 0.18985
# [76]	valid_0's binary_logloss: 0.189287
# [77]	valid_0's binary_logloss: 0.188796
# [78]	valid_0's binary_logloss: 0.188191
# [79]	valid_0's binary_logloss: 0.187737
# [80]	valid_0's binary_logloss: 0.187392
# [81]	valid_0's binary_logloss: 0.187095
# [82]	valid_0's binary_logloss: 0.186651
# [83]	valid_0's binary_logloss: 0.18606
# [84]	valid_0's binary_logloss: 0.185575
# [85]	valid_0's binary_logloss: 0.185153
# [86]	valid_0's binary_logloss: 0.184673
# [87]	valid_0's binary_logloss: 0.184363
# [88]	valid_0's binary_logloss: 0.183894
# [89]	valid_0's binary_logloss: 0.18361
# [90]	valid_0's binary_logloss: 0.183179
# [91]	valid_0's binary_logloss: 0.182871
# [92]	valid_0's binary_logloss: 0.182591
# [93]	valid_0's binary_logloss: 0.182344
# [94]	valid_0's binary_logloss: 0.182103
# [95]	valid_0's binary_logloss: 0.181656
# [96]	valid_0's binary_logloss: 0.181242
# [97]	valid_0's binary_logloss: 0.181016
# [98]	valid_0's binary_logloss: 0.180839
# [99]	valid_0's binary_logloss: 0.180646
# [100]	valid_0's binary_logloss: 0.180468
# [101]	valid_0's binary_logloss: 0.1803
# [102]	valid_0's binary_logloss: 0.180146
# [103]	valid_0's binary_logloss: 0.179997
# [104]	valid_0's binary_logloss: 0.179654
# [105]	valid_0's binary_logloss: 0.179471
# [106]	valid_0's binary_logloss: 0.179358
# [107]	valid_0's binary_logloss: 0.179266
# [108]	valid_0's binary_logloss: 0.179128
# [109]	valid_0's binary_logloss: 0.179022
# [110]	valid_0's binary_logloss: 0.17888
# [111]	valid_0's binary_logloss: 0.178778
# [112]	valid_0's binary_logloss: 0.178531
# [113]	valid_0's binary_logloss: 0.178401
# [114]	valid_0's binary_logloss: 0.178196
# [115]	valid_0's binary_logloss: 0.178116
# [116]	valid_0's binary_logloss: 0.177782
# [117]	valid_0's binary_logloss: 0.177676
# [118]	valid_0's binary_logloss: 0.177615
# [119]	valid_0's binary_logloss: 0.177402
# [120]	valid_0's binary_logloss: 0.177326
# [121]	valid_0's binary_logloss: 0.177049
# [122]	valid_0's binary_logloss: 0.176754
# [123]	valid_0's binary_logloss: 0.176705
# [124]	valid_0's binary_logloss: 0.17667
# [125]	valid_0's binary_logloss: 0.176638
# [126]	valid_0's binary_logloss: 0.176599
# [127]	valid_0's binary_logloss: 0.176568
# [128]	valid_0's binary_logloss: 0.176535
# [129]	valid_0's binary_logloss: 0.17649
# [130]	valid_0's binary_logloss: 0.17646
# [131]	valid_0's binary_logloss: 0.176424
# [132]	valid_0's binary_logloss: 0.176395
# [133]	valid_0's binary_logloss: 0.176132
# [134]	valid_0's binary_logloss: 0.176109
# [135]	valid_0's binary_logloss: 0.176087
# [136]	valid_0's binary_logloss: 0.176022
# [137]	valid_0's binary_logloss: 0.176
# [138]	valid_0's binary_logloss: 0.17598
# [139]	valid_0's binary_logloss: 0.175952
# [140]	valid_0's binary_logloss: 0.175798
# [141]	valid_0's binary_logloss: 0.175774
# [142]	valid_0's binary_logloss: 0.175504
# [143]	valid_0's binary_logloss: 0.175293
# [144]	valid_0's binary_logloss: 0.175273
# [145]	valid_0's binary_logloss: 0.175246
# [146]	valid_0's binary_logloss: 0.175229
# [147]	valid_0's binary_logloss: 0.175037
# [148]	valid_0's binary_logloss: 0.17502
# [149]	valid_0's binary_logloss: 0.174999
# [150]	valid_0's binary_logloss: 0.174978
# [151]	valid_0's binary_logloss: 0.174678
# [152]	valid_0's binary_logloss: 0.174655
# [153]	valid_0's binary_logloss: 0.174633
# [154]	valid_0's binary_logloss: 0.174616
# [155]	valid_0's binary_logloss: 0.174585
# [156]	valid_0's binary_logloss: 0.174545
# [157]	valid_0's binary_logloss: 0.174438
# [158]	valid_0's binary_logloss: 0.174406
# [159]	valid_0's binary_logloss: 0.174392
# [160]	valid_0's binary_logloss: 0.174366
# [161]	valid_0's binary_logloss: 0.174352
# [162]	valid_0's binary_logloss: 0.174309
# [163]	valid_0's binary_logloss: 0.174286
# [164]	valid_0's binary_logloss: 0.174211
# [165]	valid_0's binary_logloss: 0.173901
# [166]	valid_0's binary_logloss: 0.173803
# [167]	valid_0's binary_logloss: 0.173776
# [168]	valid_0's binary_logloss: 0.173759
# [169]	valid_0's binary_logloss: 0.173723
# [170]	valid_0's binary_logloss: 0.173713
# [171]	valid_0's binary_logloss: 0.173671
# [172]	valid_0's binary_logloss: 0.17349
# [173]	valid_0's binary_logloss: 0.173476
# [174]	valid_0's binary_logloss: 0.173372
# [175]	valid_0's binary_logloss: 0.173356
# [176]	valid_0's binary_logloss: 0.173166
# [177]	valid_0's binary_logloss: 0.172828
# [178]	valid_0's binary_logloss: 0.172812
# [179]	valid_0's binary_logloss: 0.172627
# [180]	valid_0's binary_logloss: 0.172468
# [181]	valid_0's binary_logloss: 0.172335
# [182]	valid_0's binary_logloss: 0.17231
# [183]	valid_0's binary_logloss: 0.172297
# [184]	valid_0's binary_logloss: 0.172281
# [185]	valid_0's binary_logloss: 0.172269
# [186]	valid_0's binary_logloss: 0.172256
# [187]	valid_0's binary_logloss: 0.17224
# [188]	valid_0's binary_logloss: 0.172222
# [189]	valid_0's binary_logloss: 0.172203
# [190]	valid_0's binary_logloss: 0.172125
# [191]	valid_0's binary_logloss: 0.172101
# [192]	valid_0's binary_logloss: 0.172052
# [193]	valid_0's binary_logloss: 0.172013
# [194]	valid_0's binary_logloss: 0.171928
# [195]	valid_0's binary_logloss: 0.171912
# [196]	valid_0's binary_logloss: 0.171852
# [197]	valid_0's binary_logloss: 0.171647
# [198]	valid_0's binary_logloss: 0.171635
# [199]	valid_0's binary_logloss: 0.171611
# [200]	valid_0's binary_logloss: 0.171571
# [201]	valid_0's binary_logloss: 0.171551
# [202]	valid_0's binary_logloss: 0.171531
# [203]	valid_0's binary_logloss: 0.171464
# [204]	valid_0's binary_logloss: 0.171443
# [205]	valid_0's binary_logloss: 0.171425
# [206]	valid_0's binary_logloss: 0.171299
# [207]	valid_0's binary_logloss: 0.171282
# [208]	valid_0's binary_logloss: 0.17119
# [209]	valid_0's binary_logloss: 0.17117
# [210]	valid_0's binary_logloss: 0.171108
# [211]	valid_0's binary_logloss: 0.170887
# [212]	valid_0's binary_logloss: 0.17084
# [213]	valid_0's binary_logloss: 0.17082
# [214]	valid_0's binary_logloss: 0.170799
# [215]	valid_0's binary_logloss: 0.170789
# [216]	valid_0's binary_logloss: 0.170676
# [217]	valid_0's binary_logloss: 0.170649
# [218]	valid_0's binary_logloss: 0.17061
# [219]	valid_0's binary_logloss: 0.170549
# [220]	valid_0's binary_logloss: 0.170535
# [221]	valid_0's binary_logloss: 0.17028
# [222]	valid_0's binary_logloss: 0.17025
# [223]	valid_0's binary_logloss: 0.170214
# [224]	valid_0's binary_logloss: 0.170159
# [225]	valid_0's binary_logloss: 0.170131
# [226]	valid_0's binary_logloss: 0.170123
# [227]	valid_0's binary_logloss: 0.170115
# [228]	valid_0's binary_logloss: 0.169847
# [229]	valid_0's binary_logloss: 0.169793
# [230]	valid_0's binary_logloss: 0.16978
# [231]	valid_0's binary_logloss: 0.169561
# [232]	valid_0's binary_logloss: 0.16955
# [233]	valid_0's binary_logloss: 0.169431
# [234]	valid_0's binary_logloss: 0.169419
# [235]	valid_0's binary_logloss: 0.169409
# [236]	valid_0's binary_logloss: 0.169388
# [237]	valid_0's binary_logloss: 0.169353
# [238]	valid_0's binary_logloss: 0.169334
# [239]	valid_0's binary_logloss: 0.16926
# [240]	valid_0's binary_logloss: 0.169229
# [241]	valid_0's binary_logloss: 0.169216
# [242]	valid_0's binary_logloss: 0.169177
# [243]	valid_0's binary_logloss: 0.169137
# [244]	valid_0's binary_logloss: 0.169114
# [245]	valid_0's binary_logloss: 0.16905
# [246]	valid_0's binary_logloss: 0.168869
# [247]	valid_0's binary_logloss: 0.168787
# [248]	valid_0's binary_logloss: 0.16868
# [249]	valid_0's binary_logloss: 0.168562
# [250]	valid_0's binary_logloss: 0.168551
# [251]	valid_0's binary_logloss: 0.168511
# [252]	valid_0's binary_logloss: 0.168323
# [253]	valid_0's binary_logloss: 0.168307
# [254]	valid_0's binary_logloss: 0.168161
# [255]	valid_0's binary_logloss: 0.168125
# [256]	valid_0's binary_logloss: 0.168095
# [257]	valid_0's binary_logloss: 0.168057
# [258]	valid_0's binary_logloss: 0.167942
# [259]	valid_0's binary_logloss: 0.167923
# [260]	valid_0's binary_logloss: 0.167774
# [261]	valid_0's binary_logloss: 0.167747
# [262]	valid_0's binary_logloss: 0.167669
# [263]	valid_0's binary_logloss: 0.167599
# [264]	valid_0's binary_logloss: 0.167417
# [265]	valid_0's binary_logloss: 0.16739
# [266]	valid_0's binary_logloss: 0.167347
# [267]	valid_0's binary_logloss: 0.167314
# [268]	valid_0's binary_logloss: 0.167305
# [269]	valid_0's binary_logloss: 0.167289
# [270]	valid_0's binary_logloss: 0.167278
# [271]	valid_0's binary_logloss: 0.167229
# [272]	valid_0's binary_logloss: 0.167214
# [273]	valid_0's binary_logloss: 0.167076
# [274]	valid_0's binary_logloss: 0.166989
# [275]	valid_0's binary_logloss: 0.166932
# [276]	valid_0's binary_logloss: 0.166922
# [277]	valid_0's binary_logloss: 0.16691
# [278]	valid_0's binary_logloss: 0.166804
# [279]	valid_0's binary_logloss: 0.16678
# [280]	valid_0's binary_logloss: 0.166773
# [281]	valid_0's binary_logloss: 0.166767
# [282]	valid_0's binary_logloss: 0.166688
# [283]	valid_0's binary_logloss: 0.166675
# [284]	valid_0's binary_logloss: 0.166637
# [285]	valid_0's binary_logloss: 0.166622
# [286]	valid_0's binary_logloss: 0.166581
# [287]	valid_0's binary_logloss: 0.166529
# [288]	valid_0's binary_logloss: 0.166522
# [289]	valid_0's binary_logloss: 0.166478
# [290]	valid_0's binary_logloss: 0.16645
# [291]	valid_0's binary_logloss: 0.166439
# [292]	valid_0's binary_logloss: 0.166424
# [293]	valid_0's binary_logloss: 0.166409
# [294]	valid_0's binary_logloss: 0.166401
# [295]	valid_0's binary_logloss: 0.166276
# [296]	valid_0's binary_logloss: 0.166216
# [297]	valid_0's binary_logloss: 0.166165
# [298]	valid_0's binary_logloss: 0.166151
# [299]	valid_0's binary_logloss: 0.166123
# [300]	valid_0's binary_logloss: 0.166108
# [301]	valid_0's binary_logloss: 0.166076
# [302]	valid_0's binary_logloss: 0.165998
# [303]	valid_0's binary_logloss: 0.165964
# [304]	valid_0's binary_logloss: 0.165882
# [305]	valid_0's binary_logloss: 0.165828
# [306]	valid_0's binary_logloss: 0.165819
# [307]	valid_0's binary_logloss: 0.165775
# [308]	valid_0's binary_logloss: 0.165747
# [309]	valid_0's binary_logloss: 0.165735
# [310]	valid_0's binary_logloss: 0.165657
# [311]	valid_0's binary_logloss: 0.165625
# [312]	valid_0's binary_logloss: 0.165597
# [313]	valid_0's binary_logloss: 0.165497
# [314]	valid_0's binary_logloss: 0.165464
# [315]	valid_0's binary_logloss: 0.165455
# [316]	valid_0's binary_logloss: 0.165419
# [317]	valid_0's binary_logloss: 0.165405
# [318]	valid_0's binary_logloss: 0.165378
# [319]	valid_0's binary_logloss: 0.165301
# [320]	valid_0's binary_logloss: 0.165212
# [321]	valid_0's binary_logloss: 0.165206
# [322]	valid_0's binary_logloss: 0.16514
# [323]	valid_0's binary_logloss: 0.165104
# [324]	valid_0's binary_logloss: 0.165091
# [325]	valid_0's binary_logloss: 0.165054
# [326]	valid_0's binary_logloss: 0.165012
# [327]	valid_0's binary_logloss: 0.165004
# [328]	valid_0's binary_logloss: 0.164995
# [329]	valid_0's binary_logloss: 0.164968
# [330]	valid_0's binary_logloss: 0.164939
# [331]	valid_0's binary_logloss: 0.164901
# [332]	valid_0's binary_logloss: 0.164873
# [333]	valid_0's binary_logloss: 0.164868
# [334]	valid_0's binary_logloss: 0.164863
# [335]	valid_0's binary_logloss: 0.164853
# [336]	valid_0's binary_logloss: 0.16479
# [337]	valid_0's binary_logloss: 0.164762
# [338]	valid_0's binary_logloss: 0.16475
# [339]	valid_0's binary_logloss: 0.164741
# [340]	valid_0's binary_logloss: 0.164731
# [341]	valid_0's binary_logloss: 0.164709
# [342]	valid_0's binary_logloss: 0.164628
# [343]	valid_0's binary_logloss: 0.16459
# [344]	valid_0's binary_logloss: 0.164533
# [345]	valid_0's binary_logloss: 0.164514
# [346]	valid_0's binary_logloss: 0.164461
# [347]	valid_0's binary_logloss: 0.164435
# [348]	valid_0's binary_logloss: 0.164354
# [349]	valid_0's binary_logloss: 0.164256
# [350]	valid_0's binary_logloss: 0.164208
# [351]	valid_0's binary_logloss: 0.164191
# [352]	valid_0's binary_logloss: 0.164153
# [353]	valid_0's binary_logloss: 0.164104
# [354]	valid_0's binary_logloss: 0.164014
# [355]	valid_0's binary_logloss: 0.163982
# [356]	valid_0's binary_logloss: 0.16394
# [357]	valid_0's binary_logloss: 0.163897
# [358]	valid_0's binary_logloss: 0.163813
# [359]	valid_0's binary_logloss: 0.163793
# [360]	valid_0's binary_logloss: 0.163782
# [361]	valid_0's binary_logloss: 0.163757
# [362]	valid_0's binary_logloss: 0.163738
# [363]	valid_0's binary_logloss: 0.16372
# [364]	valid_0's binary_logloss: 0.163707
# [365]	valid_0's binary_logloss: 0.163687
# [366]	valid_0's binary_logloss: 0.163663
# [367]	valid_0's binary_logloss: 0.163643
# [368]	valid_0's binary_logloss: 0.163611
# [369]	valid_0's binary_logloss: 0.163582
# [370]	valid_0's binary_logloss: 0.163577
# [371]	valid_0's binary_logloss: 0.163514
# [372]	valid_0's binary_logloss: 0.163492
# [373]	valid_0's binary_logloss: 0.163476
# [374]	valid_0's binary_logloss: 0.163458
# [375]	valid_0's binary_logloss: 0.163346
# [376]	valid_0's binary_logloss: 0.163326
# [377]	valid_0's binary_logloss: 0.163171
# [378]	valid_0's binary_logloss: 0.163137
# [379]	valid_0's binary_logloss: 0.163052
# [380]	valid_0's binary_logloss: 0.163028
# [381]	valid_0's binary_logloss: 0.163003
# [382]	valid_0's binary_logloss: 0.162942
# [383]	valid_0's binary_logloss: 0.162916
# [384]	valid_0's binary_logloss: 0.162843
# [385]	valid_0's binary_logloss: 0.16282
# [386]	valid_0's binary_logloss: 0.162779
# [387]	valid_0's binary_logloss: 0.162771
# [388]	valid_0's binary_logloss: 0.162757
# [389]	valid_0's binary_logloss: 0.162753
# [390]	valid_0's binary_logloss: 0.162728
# [391]	valid_0's binary_logloss: 0.162718
# [392]	valid_0's binary_logloss: 0.162699
# [393]	valid_0's binary_logloss: 0.162635
# [394]	valid_0's binary_logloss: 0.162628
# [395]	valid_0's binary_logloss: 0.162603
# [396]	valid_0's binary_logloss: 0.162474
# [397]	valid_0's binary_logloss: 0.162458
# [398]	valid_0's binary_logloss: 0.162449
# [399]	valid_0's binary_logloss: 0.162355
# [400]	valid_0's binary_logloss: 0.162328
# [401]	valid_0's binary_logloss: 0.162264
# [402]	valid_0's binary_logloss: 0.162255
# [403]	valid_0's binary_logloss: 0.162244
# [404]	valid_0's binary_logloss: 0.162222
# [405]	valid_0's binary_logloss: 0.162205
# [406]	valid_0's binary_logloss: 0.162181
# [407]	valid_0's binary_logloss: 0.162168
# [408]	valid_0's binary_logloss: 0.162131
# [409]	valid_0's binary_logloss: 0.162109
# [410]	valid_0's binary_logloss: 0.162032
# [411]	valid_0's binary_logloss: 0.162
# [412]	valid_0's binary_logloss: 0.161977
# [413]	valid_0's binary_logloss: 0.161839
# [414]	valid_0's binary_logloss: 0.161744
# [415]	valid_0's binary_logloss: 0.161672
# [416]	valid_0's binary_logloss: 0.161659
# [417]	valid_0's binary_logloss: 0.16164
# [418]	valid_0's binary_logloss: 0.161632
# [419]	valid_0's binary_logloss: 0.161572
# [420]	valid_0's binary_logloss: 0.161544
# [421]	valid_0's binary_logloss: 0.161495
# [422]	valid_0's binary_logloss: 0.161377
# [423]	valid_0's binary_logloss: 0.16136
# [424]	valid_0's binary_logloss: 0.16134
# [425]	valid_0's binary_logloss: 0.161311
# [426]	valid_0's binary_logloss: 0.161292
# [427]	valid_0's binary_logloss: 0.161285
# [428]	valid_0's binary_logloss: 0.161266
# [429]	valid_0's binary_logloss: 0.16125
# [430]	valid_0's binary_logloss: 0.161231
# [431]	valid_0's binary_logloss: 0.161226
# [432]	valid_0's binary_logloss: 0.161161
# [433]	valid_0's binary_logloss: 0.161124
# [434]	valid_0's binary_logloss: 0.161118
# [435]	valid_0's binary_logloss: 0.161064
# [436]	valid_0's binary_logloss: 0.161051
# [437]	valid_0's binary_logloss: 0.161035
# [438]	valid_0's binary_logloss: 0.161024
# [439]	valid_0's binary_logloss: 0.161013
# [440]	valid_0's binary_logloss: 0.161008
# [441]	valid_0's binary_logloss: 0.160983
# [442]	valid_0's binary_logloss: 0.160971
# [443]	valid_0's binary_logloss: 0.160947
# [444]	valid_0's binary_logloss: 0.160939
# [445]	valid_0's binary_logloss: 0.160929
# [446]	valid_0's binary_logloss: 0.160895
# [447]	valid_0's binary_logloss: 0.160891
# [448]	valid_0's binary_logloss: 0.160877
# [449]	valid_0's binary_logloss: 0.160855
# [450]	valid_0's binary_logloss: 0.160837
# [451]	valid_0's binary_logloss: 0.160822
# [452]	valid_0's binary_logloss: 0.160816
# [453]	valid_0's binary_logloss: 0.160809
# [454]	valid_0's binary_logloss: 0.160802
# [455]	valid_0's binary_logloss: 0.160784
# [456]	valid_0's binary_logloss: 0.160696
# [457]	valid_0's binary_logloss: 0.160677
# [458]	valid_0's binary_logloss: 0.160668
# [459]	valid_0's binary_logloss: 0.16065
# [460]	valid_0's binary_logloss: 0.1606
# [461]	valid_0's binary_logloss: 0.160563
# [462]	valid_0's binary_logloss: 0.160544
# [463]	valid_0's binary_logloss: 0.160501
# [464]	valid_0's binary_logloss: 0.160482
# [465]	valid_0's binary_logloss: 0.160475
# [466]	valid_0's binary_logloss: 0.160461
# [467]	valid_0's binary_logloss: 0.160431
# [468]	valid_0's binary_logloss: 0.160401
# [469]	valid_0's binary_logloss: 0.160392
# [470]	valid_0's binary_logloss: 0.160298
# [471]	valid_0's binary_logloss: 0.160273
# [472]	valid_0's binary_logloss: 0.160217
# [473]	valid_0's binary_logloss: 0.160152
# [474]	valid_0's binary_logloss: 0.160133
# [475]	valid_0's binary_logloss: 0.160116
# [476]	valid_0's binary_logloss: 0.160079
# [477]	valid_0's binary_logloss: 0.160024
# [478]	valid_0's binary_logloss: 0.160007
# [479]	valid_0's binary_logloss: 0.159989
# [480]	valid_0's binary_logloss: 0.159982
# [481]	valid_0's binary_logloss: 0.159968
# [482]	valid_0's binary_logloss: 0.159957
# [483]	valid_0's binary_logloss: 0.159943
# [484]	valid_0's binary_logloss: 0.159931
# [485]	valid_0's binary_logloss: 0.15992
# [486]	valid_0's binary_logloss: 0.159902
# [487]	valid_0's binary_logloss: 0.159892
# [488]	valid_0's binary_logloss: 0.159877
# [489]	valid_0's binary_logloss: 0.159862
# [490]	valid_0's binary_logloss: 0.159843
# [491]	valid_0's binary_logloss: 0.159815
# [492]	valid_0's binary_logloss: 0.159801
# [493]	valid_0's binary_logloss: 0.159775
# [494]	valid_0's binary_logloss: 0.159768
# [495]	valid_0's binary_logloss: 0.159761
# [496]	valid_0's binary_logloss: 0.159756
# [497]	valid_0's binary_logloss: 0.159755
# [498]	valid_0's binary_logloss: 0.159751
# [499]	valid_0's binary_logloss: 0.159748
# [500]	valid_0's binary_logloss: 0.159745
# [501]	valid_0's binary_logloss: 0.159732
# [502]	valid_0's binary_logloss: 0.159714
# [503]	valid_0's binary_logloss: 0.159693
# [504]	valid_0's binary_logloss: 0.159661
# [505]	valid_0's binary_logloss: 0.159579
# [506]	valid_0's binary_logloss: 0.159567
# [507]	valid_0's binary_logloss: 0.159564
# [508]	valid_0's binary_logloss: 0.159532
# [509]	valid_0's binary_logloss: 0.15949
# [510]	valid_0's binary_logloss: 0.159484
# [511]	valid_0's binary_logloss: 0.159467
# [512]	valid_0's binary_logloss: 0.159454
# [513]	valid_0's binary_logloss: 0.15945
# [514]	valid_0's binary_logloss: 0.159429
# [515]	valid_0's binary_logloss: 0.159426
# [516]	valid_0's binary_logloss: 0.159416
# [517]	valid_0's binary_logloss: 0.159401
# [518]	valid_0's binary_logloss: 0.159306
# [519]	valid_0's binary_logloss: 0.159294
# [520]	valid_0's binary_logloss: 0.159282
# [521]	valid_0's binary_logloss: 0.159275
# [522]	valid_0's binary_logloss: 0.159257
# [523]	valid_0's binary_logloss: 0.159254
# [524]	valid_0's binary_logloss: 0.159246
# [525]	valid_0's binary_logloss: 0.159234
# [526]	valid_0's binary_logloss: 0.159223
# [527]	valid_0's binary_logloss: 0.159202
# [528]	valid_0's binary_logloss: 0.159198
# [529]	valid_0's binary_logloss: 0.159133
# [530]	valid_0's binary_logloss: 0.15912
# [531]	valid_0's binary_logloss: 0.159108
# [532]	valid_0's binary_logloss: 0.159093
# [533]	valid_0's binary_logloss: 0.159084
# [534]	valid_0's binary_logloss: 0.15908
# [535]	valid_0's binary_logloss: 0.159076
# [536]	valid_0's binary_logloss: 0.159067
# [537]	valid_0's binary_logloss: 0.159058
# [538]	valid_0's binary_logloss: 0.159045
# [539]	valid_0's binary_logloss: 0.158966
# [540]	valid_0's binary_logloss: 0.158914
# [541]	valid_0's binary_logloss: 0.158909
# [542]	valid_0's binary_logloss: 0.158892
# [543]	valid_0's binary_logloss: 0.158887
# [544]	valid_0's binary_logloss: 0.158872
# [545]	valid_0's binary_logloss: 0.15883
# [546]	valid_0's binary_logloss: 0.15882
# [547]	valid_0's binary_logloss: 0.158788
# [548]	valid_0's binary_logloss: 0.158768
# [549]	valid_0's binary_logloss: 0.158752
# [550]	valid_0's binary_logloss: 0.158692
# [551]	valid_0's binary_logloss: 0.15868
# [552]	valid_0's binary_logloss: 0.158665
# [553]	valid_0's binary_logloss: 0.158655
# [554]	valid_0's binary_logloss: 0.158634
# [555]	valid_0's binary_logloss: 0.158631
# [556]	valid_0's binary_logloss: 0.158622
# [557]	valid_0's binary_logloss: 0.158561
# [558]	valid_0's binary_logloss: 0.158556
# [559]	valid_0's binary_logloss: 0.158551
# [560]	valid_0's binary_logloss: 0.158524
# [561]	valid_0's binary_logloss: 0.15852
# [562]	valid_0's binary_logloss: 0.158471
# [563]	valid_0's binary_logloss: 0.158464
# [564]	valid_0's binary_logloss: 0.158384
# [565]	valid_0's binary_logloss: 0.158333
# [566]	valid_0's binary_logloss: 0.158311
# [567]	valid_0's binary_logloss: 0.158298
# [568]	valid_0's binary_logloss: 0.158289
# [569]	valid_0's binary_logloss: 0.158282
# [570]	valid_0's binary_logloss: 0.158269
# [571]	valid_0's binary_logloss: 0.158263
# [572]	valid_0's binary_logloss: 0.15824
# [573]	valid_0's binary_logloss: 0.158222
# [574]	valid_0's binary_logloss: 0.158195
# [575]	valid_0's binary_logloss: 0.158178
# [576]	valid_0's binary_logloss: 0.158167
# [577]	valid_0's binary_logloss: 0.158162
# [578]	valid_0's binary_logloss: 0.158146
# [579]	valid_0's binary_logloss: 0.158135
# [580]	valid_0's binary_logloss: 0.158085
# [581]	valid_0's binary_logloss: 0.158081
# [582]	valid_0's binary_logloss: 0.158073
# [583]	valid_0's binary_logloss: 0.158065
# [584]	valid_0's binary_logloss: 0.158051
# [585]	valid_0's binary_logloss: 0.158025
# [586]	valid_0's binary_logloss: 0.158023
# [587]	valid_0's binary_logloss: 0.158019
# [588]	valid_0's binary_logloss: 0.158007
# [589]	valid_0's binary_logloss: 0.158004
# [590]	valid_0's binary_logloss: 0.157928
# [591]	valid_0's binary_logloss: 0.157921
# [592]	valid_0's binary_logloss: 0.157919
# [593]	valid_0's binary_logloss: 0.157914
# [594]	valid_0's binary_logloss: 0.157899
# [595]	valid_0's binary_logloss: 0.157887
# [596]	valid_0's binary_logloss: 0.15788
# [597]	valid_0's binary_logloss: 0.157842
# [598]	valid_0's binary_logloss: 0.157836
# [599]	valid_0's binary_logloss: 0.157831
# [600]	valid_0's binary_logloss: 0.15782
# [601]	valid_0's binary_logloss: 0.157786
# [602]	valid_0's binary_logloss: 0.157745
# [603]	valid_0's binary_logloss: 0.157729
# [604]	valid_0's binary_logloss: 0.157725
# [605]	valid_0's binary_logloss: 0.157689
# [606]	valid_0's binary_logloss: 0.157687
# [607]	valid_0's binary_logloss: 0.157678
# [608]	valid_0's binary_logloss: 0.157662
# [609]	valid_0's binary_logloss: 0.157655
# [610]	valid_0's binary_logloss: 0.157597
# [611]	valid_0's binary_logloss: 0.157586
# [612]	valid_0's binary_logloss: 0.157583
# [613]	valid_0's binary_logloss: 0.157564
# [614]	valid_0's binary_logloss: 0.157557
# [615]	valid_0's binary_logloss: 0.157548
# [616]	valid_0's binary_logloss: 0.157545
# [617]	valid_0's binary_logloss: 0.157537
# [618]	valid_0's binary_logloss: 0.157528
# [619]	valid_0's binary_logloss: 0.157523
# [620]	valid_0's binary_logloss: 0.15752
# [621]	valid_0's binary_logloss: 0.157515
# [622]	valid_0's binary_logloss: 0.157509
# [623]	valid_0's binary_logloss: 0.157506
# [624]	valid_0's binary_logloss: 0.157486
# [625]	valid_0's binary_logloss: 0.157481
# [626]	valid_0's binary_logloss: 0.157419
# [627]	valid_0's binary_logloss: 0.157408
# [628]	valid_0's binary_logloss: 0.157397
# [629]	valid_0's binary_logloss: 0.157382
# [630]	valid_0's binary_logloss: 0.157378
# [631]	valid_0's binary_logloss: 0.157338
# [632]	valid_0's binary_logloss: 0.157331
# [633]	valid_0's binary_logloss: 0.157325
# [634]	valid_0's binary_logloss: 0.157321
# [635]	valid_0's binary_logloss: 0.157307
# [636]	valid_0's binary_logloss: 0.157298
# [637]	valid_0's binary_logloss: 0.157258
# [638]	valid_0's binary_logloss: 0.157246
# [639]	valid_0's binary_logloss: 0.157239
# [640]	valid_0's binary_logloss: 0.157227
# [641]	valid_0's binary_logloss: 0.15722
# [642]	valid_0's binary_logloss: 0.157218
# [643]	valid_0's binary_logloss: 0.157162
# [644]	valid_0's binary_logloss: 0.157161
# [645]	valid_0's binary_logloss: 0.157142
# [646]	valid_0's binary_logloss: 0.157141
# [647]	valid_0's binary_logloss: 0.157126
# [648]	valid_0's binary_logloss: 0.157119
# [649]	valid_0's binary_logloss: 0.157105
# [650]	valid_0's binary_logloss: 0.157099
# [651]	valid_0's binary_logloss: 0.157082
# [652]	valid_0's binary_logloss: 0.157082
# [653]	valid_0's binary_logloss: 0.157067
# [654]	valid_0's binary_logloss: 0.157042
# [655]	valid_0's binary_logloss: 0.15704
# [656]	valid_0's binary_logloss: 0.157039
# [657]	valid_0's binary_logloss: 0.157033
# [658]	valid_0's binary_logloss: 0.157028
# [659]	valid_0's binary_logloss: 0.157024
# [660]	valid_0's binary_logloss: 0.156998
# [661]	valid_0's binary_logloss: 0.156921
# [662]	valid_0's binary_logloss: 0.156916
# [663]	valid_0's binary_logloss: 0.156903
# [664]	valid_0's binary_logloss: 0.156898
# [665]	valid_0's binary_logloss: 0.156879
# [666]	valid_0's binary_logloss: 0.15687
# [667]	valid_0's binary_logloss: 0.156842
# [668]	valid_0's binary_logloss: 0.156834
# [669]	valid_0's binary_logloss: 0.156831
# [670]	valid_0's binary_logloss: 0.156827
# [671]	valid_0's binary_logloss: 0.156824
# [672]	valid_0's binary_logloss: 0.156819
# [673]	valid_0's binary_logloss: 0.156815
# [674]	valid_0's binary_logloss: 0.156814
# [675]	valid_0's binary_logloss: 0.156812
# [676]	valid_0's binary_logloss: 0.156797
# [677]	valid_0's binary_logloss: 0.156791
# [678]	valid_0's binary_logloss: 0.156779
# [679]	valid_0's binary_logloss: 0.156769
# [680]	valid_0's binary_logloss: 0.156761
# [681]	valid_0's binary_logloss: 0.15675
# [682]	valid_0's binary_logloss: 0.156731
# [683]	valid_0's binary_logloss: 0.156726
# [684]	valid_0's binary_logloss: 0.156721
# [685]	valid_0's binary_logloss: 0.156714
# [686]	valid_0's binary_logloss: 0.156712
# [687]	valid_0's binary_logloss: 0.156709
# [688]	valid_0's binary_logloss: 0.156707
# [689]	valid_0's binary_logloss: 0.156696
# [690]	valid_0's binary_logloss: 0.156641
# [691]	valid_0's binary_logloss: 0.156633
# [692]	valid_0's binary_logloss: 0.156619
# [693]	valid_0's binary_logloss: 0.156605
# [694]	valid_0's binary_logloss: 0.156597
# [695]	valid_0's binary_logloss: 0.156591
# [696]	valid_0's binary_logloss: 0.156565
# [697]	valid_0's binary_logloss: 0.156545
# [698]	valid_0's binary_logloss: 0.156536
# [699]	valid_0's binary_logloss: 0.156527
# [700]	valid_0's binary_logloss: 0.156517
# [701]	valid_0's binary_logloss: 0.156509
# [702]	valid_0's binary_logloss: 0.156508
# [703]	valid_0's binary_logloss: 0.156477
# [704]	valid_0's binary_logloss: 0.156469
# [705]	valid_0's binary_logloss: 0.156466
# [706]	valid_0's binary_logloss: 0.156462
# [707]	valid_0's binary_logloss: 0.156464
# [708]	valid_0's binary_logloss: 0.156431
# [709]	valid_0's binary_logloss: 0.156397
# [710]	valid_0's binary_logloss: 0.156392
# [711]	valid_0's binary_logloss: 0.156381
# [712]	valid_0's binary_logloss: 0.156379
# [713]	valid_0's binary_logloss: 0.156377
# [714]	valid_0's binary_logloss: 0.156363
# [715]	valid_0's binary_logloss: 0.156361
# [716]	valid_0's binary_logloss: 0.156334
# [717]	valid_0's binary_logloss: 0.156322
# [718]	valid_0's binary_logloss: 0.156273
# [719]	valid_0's binary_logloss: 0.156271
# [720]	valid_0's binary_logloss: 0.15627
# [721]	valid_0's binary_logloss: 0.156255
# [722]	valid_0's binary_logloss: 0.156223
# [723]	valid_0's binary_logloss: 0.156222
# [724]	valid_0's binary_logloss: 0.156214
# [725]	valid_0's binary_logloss: 0.156214
# [726]	valid_0's binary_logloss: 0.156175
# [727]	valid_0's binary_logloss: 0.156166
# [728]	valid_0's binary_logloss: 0.156145
# [729]	valid_0's binary_logloss: 0.15613
# [730]	valid_0's binary_logloss: 0.156128
# [731]	valid_0's binary_logloss: 0.156081
# [732]	valid_0's binary_logloss: 0.156079
# [733]	valid_0's binary_logloss: 0.156074
# [734]	valid_0's binary_logloss: 0.156068
# [735]	valid_0's binary_logloss: 0.156059
# [736]	valid_0's binary_logloss: 0.156041
# [737]	valid_0's binary_logloss: 0.156026
# [738]	valid_0's binary_logloss: 0.156015
# [739]	valid_0's binary_logloss: 0.156013
# [740]	valid_0's binary_logloss: 0.155983
# [741]	valid_0's binary_logloss: 0.155977
# [742]	valid_0's binary_logloss: 0.155976
# [743]	valid_0's binary_logloss: 0.155965
# [744]	valid_0's binary_logloss: 0.155958
# [745]	valid_0's binary_logloss: 0.155931
# [746]	valid_0's binary_logloss: 0.15592
# [747]	valid_0's binary_logloss: 0.155913
# [748]	valid_0's binary_logloss: 0.155908
# [749]	valid_0's binary_logloss: 0.155892
# [750]	valid_0's binary_logloss: 0.155887
# [751]	valid_0's binary_logloss: 0.155883
# [752]	valid_0's binary_logloss: 0.155871
# [753]	valid_0's binary_logloss: 0.155865
# [754]	valid_0's binary_logloss: 0.15585
# [755]	valid_0's binary_logloss: 0.155847
# [756]	valid_0's binary_logloss: 0.155842
# [757]	valid_0's binary_logloss: 0.155828
# [758]	valid_0's binary_logloss: 0.155809
# [759]	valid_0's binary_logloss: 0.15581
# [760]	valid_0's binary_logloss: 0.155805
# [761]	valid_0's binary_logloss: 0.155797
# [762]	valid_0's binary_logloss: 0.155775
# [763]	valid_0's binary_logloss: 0.155741
# [764]	valid_0's binary_logloss: 0.155738
# [765]	valid_0's binary_logloss: 0.155736
# [766]	valid_0's binary_logloss: 0.155733
# [767]	valid_0's binary_logloss: 0.155716
# [768]	valid_0's binary_logloss: 0.155707
# [769]	valid_0's binary_logloss: 0.155705
# [770]	valid_0's binary_logloss: 0.155695
# [771]	valid_0's binary_logloss: 0.155693
# [772]	valid_0's binary_logloss: 0.15569
# [773]	valid_0's binary_logloss: 0.155685
# [774]	valid_0's binary_logloss: 0.155664
# [775]	valid_0's binary_logloss: 0.15566
# [776]	valid_0's binary_logloss: 0.155655
# [777]	valid_0's binary_logloss: 0.155636
# [778]	valid_0's binary_logloss: 0.155625
# [779]	valid_0's binary_logloss: 0.155619
# [780]	valid_0's binary_logloss: 0.155586
# [781]	valid_0's binary_logloss: 0.155582
# [782]	valid_0's binary_logloss: 0.155567
# [783]	valid_0's binary_logloss: 0.155549
# [784]	valid_0's binary_logloss: 0.155524
# [785]	valid_0's binary_logloss: 0.155521
# [786]	valid_0's binary_logloss: 0.155516
# [787]	valid_0's binary_logloss: 0.155502
# [788]	valid_0's binary_logloss: 0.155495
# [789]	valid_0's binary_logloss: 0.155469
# [790]	valid_0's binary_logloss: 0.155469
# [791]	valid_0's binary_logloss: 0.155466
# [792]	valid_0's binary_logloss: 0.155455
# [793]	valid_0's binary_logloss: 0.155437
# [794]	valid_0's binary_logloss: 0.155435
# [795]	valid_0's binary_logloss: 0.155433
# [796]	valid_0's binary_logloss: 0.155428
# [797]	valid_0's binary_logloss: 0.155417
# [798]	valid_0's binary_logloss: 0.155412
# [799]	valid_0's binary_logloss: 0.15541
# [800]	valid_0's binary_logloss: 0.155412
# [801]	valid_0's binary_logloss: 0.155411
# [802]	valid_0's binary_logloss: 0.155405
# [803]	valid_0's binary_logloss: 0.155397
# [804]	valid_0's binary_logloss: 0.155395
# [805]	valid_0's binary_logloss: 0.155391
# [806]	valid_0's binary_logloss: 0.155389
# [807]	valid_0's binary_logloss: 0.155387
# [808]	valid_0's binary_logloss: 0.155383
# [809]	valid_0's binary_logloss: 0.15538
# [810]	valid_0's binary_logloss: 0.155366
# [811]	valid_0's binary_logloss: 0.155334
# [812]	valid_0's binary_logloss: 0.15533
# [813]	valid_0's binary_logloss: 0.155322
# [814]	valid_0's binary_logloss: 0.155318
# [815]	valid_0's binary_logloss: 0.155312
# [816]	valid_0's binary_logloss: 0.155311
# [817]	valid_0's binary_logloss: 0.155312
# [818]	valid_0's binary_logloss: 0.155282
# [819]	valid_0's binary_logloss: 0.155283
# [820]	valid_0's binary_logloss: 0.155269
# [821]	valid_0's binary_logloss: 0.155266
# [822]	valid_0's binary_logloss: 0.155265
# [823]	valid_0's binary_logloss: 0.155265
# [824]	valid_0's binary_logloss: 0.155265
# [825]	valid_0's binary_logloss: 0.155232
# [826]	valid_0's binary_logloss: 0.155226
# [827]	valid_0's binary_logloss: 0.155227
# [828]	valid_0's binary_logloss: 0.15522
# [829]	valid_0's binary_logloss: 0.155219
# [830]	valid_0's binary_logloss: 0.155218
# [831]	valid_0's binary_logloss: 0.155209
# [832]	valid_0's binary_logloss: 0.155208
# [833]	valid_0's binary_logloss: 0.155171
# [834]	valid_0's binary_logloss: 0.155166
# [835]	valid_0's binary_logloss: 0.155165
# [836]	valid_0's binary_logloss: 0.155161
# [837]	valid_0's binary_logloss: 0.155155
# [838]	valid_0's binary_logloss: 0.155154
# [839]	valid_0's binary_logloss: 0.155151
# [840]	valid_0's binary_logloss: 0.155151
# [841]	valid_0's binary_logloss: 0.155123
# [842]	valid_0's binary_logloss: 0.155106
# [843]	valid_0's binary_logloss: 0.155104
# [844]	valid_0's binary_logloss: 0.155101
# [845]	valid_0's binary_logloss: 0.155093
# [846]	valid_0's binary_logloss: 0.155085
# [847]	valid_0's binary_logloss: 0.155081
# [848]	valid_0's binary_logloss: 0.155081
# [849]	valid_0's binary_logloss: 0.155078
# [850]	valid_0's binary_logloss: 0.155072
# [851]	valid_0's binary_logloss: 0.155061
# [852]	valid_0's binary_logloss: 0.155063
# [853]	valid_0's binary_logloss: 0.155055
# [854]	valid_0's binary_logloss: 0.155053
# [855]	valid_0's binary_logloss: 0.155052
# [856]	valid_0's binary_logloss: 0.155036
# [857]	valid_0's binary_logloss: 0.155023
# [858]	valid_0's binary_logloss: 0.155024
# [859]	valid_0's binary_logloss: 0.155016
# [860]	valid_0's binary_logloss: 0.155013
# [861]	valid_0's binary_logloss: 0.154993
# [862]	valid_0's binary_logloss: 0.154991
# [863]	valid_0's binary_logloss: 0.154984
# [864]	valid_0's binary_logloss: 0.154976
# [865]	valid_0's binary_logloss: 0.154972
# [866]	valid_0's binary_logloss: 0.154971
# [867]	valid_0's binary_logloss: 0.154956
# [868]	valid_0's binary_logloss: 0.154927
# [869]	valid_0's binary_logloss: 0.154922
# [870]	valid_0's binary_logloss: 0.154912
# [871]	valid_0's binary_logloss: 0.15491
# [872]	valid_0's binary_logloss: 0.154903
# [873]	valid_0's binary_logloss: 0.1549
# [874]	valid_0's binary_logloss: 0.154888
# [875]	valid_0's binary_logloss: 0.154885
# [876]	valid_0's binary_logloss: 0.154882
# [877]	valid_0's binary_logloss: 0.154882
# [878]	valid_0's binary_logloss: 0.154872
# [879]	valid_0's binary_logloss: 0.154866
# [880]	valid_0's binary_logloss: 0.154863
# [881]	valid_0's binary_logloss: 0.154866
# [882]	valid_0's binary_logloss: 0.154866
# [883]	valid_0's binary_logloss: 0.154863
# [884]	valid_0's binary_logloss: 0.154864
# [885]	valid_0's binary_logloss: 0.154856
# [886]	valid_0's binary_logloss: 0.154857
# [887]	valid_0's binary_logloss: 0.154848
# [888]	valid_0's binary_logloss: 0.15484
# [889]	valid_0's binary_logloss: 0.154837
# [890]	valid_0's binary_logloss: 0.154808
# [891]	valid_0's binary_logloss: 0.154804
# [892]	valid_0's binary_logloss: 0.154794
# [893]	valid_0's binary_logloss: 0.15478
# [894]	valid_0's binary_logloss: 0.154773
# [895]	valid_0's binary_logloss: 0.154766
# [896]	valid_0's binary_logloss: 0.154737
# [897]	valid_0's binary_logloss: 0.154714
# [898]	valid_0's binary_logloss: 0.154708
# [899]	valid_0's binary_logloss: 0.154708
# [900]	valid_0's binary_logloss: 0.154686
# [901]	valid_0's binary_logloss: 0.154685
# [902]	valid_0's binary_logloss: 0.154649
# [903]	valid_0's binary_logloss: 0.154646
# [904]	valid_0's binary_logloss: 0.154641
# [905]	valid_0's binary_logloss: 0.154641
# [906]	valid_0's binary_logloss: 0.154638
# [907]	valid_0's binary_logloss: 0.15463
# [908]	valid_0's binary_logloss: 0.154627
# [909]	valid_0's binary_logloss: 0.154623
# [910]	valid_0's binary_logloss: 0.154619
# [911]	valid_0's binary_logloss: 0.154616
# [912]	valid_0's binary_logloss: 0.154608
# [913]	valid_0's binary_logloss: 0.154597
# [914]	valid_0's binary_logloss: 0.154591
# [915]	valid_0's binary_logloss: 0.154577
# [916]	valid_0's binary_logloss: 0.154574
# [917]	valid_0's binary_logloss: 0.154575
# [918]	valid_0's binary_logloss: 0.154574
# [919]	valid_0's binary_logloss: 0.154573
# [920]	valid_0's binary_logloss: 0.154571
# [921]	valid_0's binary_logloss: 0.15457
# [922]	valid_0's binary_logloss: 0.154566
# [923]	valid_0's binary_logloss: 0.15456
# [924]	valid_0's binary_logloss: 0.154547
# [925]	valid_0's binary_logloss: 0.154544
# [926]	valid_0's binary_logloss: 0.154542
# [927]	valid_0's binary_logloss: 0.154536
# [928]	valid_0's binary_logloss: 0.154533
# [929]	valid_0's binary_logloss: 0.154515
# [930]	valid_0's binary_logloss: 0.154515
# [931]	valid_0's binary_logloss: 0.154513
# [932]	valid_0's binary_logloss: 0.154509
# [933]	valid_0's binary_logloss: 0.154499
# [934]	valid_0's binary_logloss: 0.154475
# [935]	valid_0's binary_logloss: 0.154468
# [936]	valid_0's binary_logloss: 0.154462
# [937]	valid_0's binary_logloss: 0.154456
# [938]	valid_0's binary_logloss: 0.154452
# [939]	valid_0's binary_logloss: 0.154449
# [940]	valid_0's binary_logloss: 0.154452
# [941]	valid_0's binary_logloss: 0.154448
# [942]	valid_0's binary_logloss: 0.154437
# [943]	valid_0's binary_logloss: 0.154435
# [944]	valid_0's binary_logloss: 0.154431
# [945]	valid_0's binary_logloss: 0.15443
# [946]	valid_0's binary_logloss: 0.15443
# [947]	valid_0's binary_logloss: 0.154428
# [948]	valid_0's binary_logloss: 0.154426
# [949]	valid_0's binary_logloss: 0.154424
# [950]	valid_0's binary_logloss: 0.154416
# [951]	valid_0's binary_logloss: 0.154404
# [952]	valid_0's binary_logloss: 0.154382
# [953]	valid_0's binary_logloss: 0.154382
# [954]	valid_0's binary_logloss: 0.154382
# [955]	valid_0's binary_logloss: 0.154376
# [956]	valid_0's binary_logloss: 0.154373
# [957]	valid_0's binary_logloss: 0.154372
# [958]	valid_0's binary_logloss: 0.154369
# [959]	valid_0's binary_logloss: 0.15437
# [960]	valid_0's binary_logloss: 0.15437
# [961]	valid_0's binary_logloss: 0.154369
# [962]	valid_0's binary_logloss: 0.154361
# [963]	valid_0's binary_logloss: 0.154362
# [964]	valid_0's binary_logloss: 0.154351
# [965]	valid_0's binary_logloss: 0.154346
# [966]	valid_0's binary_logloss: 0.154339
# [967]	valid_0's binary_logloss: 0.154341
# [968]	valid_0's binary_logloss: 0.154335
# [969]	valid_0's binary_logloss: 0.154319
# [970]	valid_0's binary_logloss: 0.154311
# [971]	valid_0's binary_logloss: 0.154309
# [972]	valid_0's binary_logloss: 0.154308
# [973]	valid_0's binary_logloss: 0.154307
# [974]	valid_0's binary_logloss: 0.154302
# [975]	valid_0's binary_logloss: 0.154301
# [976]	valid_0's binary_logloss: 0.154296
# [977]	valid_0's binary_logloss: 0.154298
# [978]	valid_0's binary_logloss: 0.154298
# [979]	valid_0's binary_logloss: 0.154277
# [980]	valid_0's binary_logloss: 0.154269
# [981]	valid_0's binary_logloss: 0.154267
# [982]	valid_0's binary_logloss: 0.154265
# [983]	valid_0's binary_logloss: 0.154258
# [984]	valid_0's binary_logloss: 0.15426
# [985]	valid_0's binary_logloss: 0.15426
# [986]	valid_0's binary_logloss: 0.154255
# [987]	valid_0's binary_logloss: 0.154242
# [988]	valid_0's binary_logloss: 0.154241
# [989]	valid_0's binary_logloss: 0.154241
# [990]	valid_0's binary_logloss: 0.154227
# [991]	valid_0's binary_logloss: 0.154226
# [992]	valid_0's binary_logloss: 0.154215
# [993]	valid_0's binary_logloss: 0.154201
# [994]	valid_0's binary_logloss: 0.154201
# [995]	valid_0's binary_logloss: 0.154201
# [996]	valid_0's binary_logloss: 0.154198
# [997]	valid_0's binary_logloss: 0.154199
# [998]	valid_0's binary_logloss: 0.154195
# [999]	valid_0's binary_logloss: 0.154184
# [1000]	valid_0's binary_logloss: 0.154176
# [1001]	valid_0's binary_logloss: 0.154176
# [1002]	valid_0's binary_logloss: 0.154175
# [1003]	valid_0's binary_logloss: 0.154171
# [1004]	valid_0's binary_logloss: 0.154165
# [1005]	valid_0's binary_logloss: 0.154161
# [1006]	valid_0's binary_logloss: 0.154164
# [1007]	valid_0's binary_logloss: 0.154164
# [1008]	valid_0's binary_logloss: 0.15416
# [1009]	valid_0's binary_logloss: 0.154163
# [1010]	valid_0's binary_logloss: 0.154148
# [1011]	valid_0's binary_logloss: 0.154145
# [1012]	valid_0's binary_logloss: 0.154145
# [1013]	valid_0's binary_logloss: 0.154148
# [1014]	valid_0's binary_logloss: 0.154145
# [1015]	valid_0's binary_logloss: 0.154143
# [1016]	valid_0's binary_logloss: 0.154142
# [1017]	valid_0's binary_logloss: 0.15411
# [1018]	valid_0's binary_logloss: 0.154103
# [1019]	valid_0's binary_logloss: 0.154094
# [1020]	valid_0's binary_logloss: 0.154092
# [1021]	valid_0's binary_logloss: 0.154093
# [1022]	valid_0's binary_logloss: 0.154096
# [1023]	valid_0's binary_logloss: 0.154093
# [1024]	valid_0's binary_logloss: 0.154085
# [1025]	valid_0's binary_logloss: 0.154084
# [1026]	valid_0's binary_logloss: 0.154083
# [1027]	valid_0's binary_logloss: 0.154077
# [1028]	valid_0's binary_logloss: 0.154073
# [1029]	valid_0's binary_logloss: 0.154072
# [1030]	valid_0's binary_logloss: 0.15407
# [1031]	valid_0's binary_logloss: 0.154068
# [1032]	valid_0's binary_logloss: 0.154063
# [1033]	valid_0's binary_logloss: 0.154058
# [1034]	valid_0's binary_logloss: 0.15405
# [1035]	valid_0's binary_logloss: 0.154041
# [1036]	valid_0's binary_logloss: 0.154041
# [1037]	valid_0's binary_logloss: 0.154044
# [1038]	valid_0's binary_logloss: 0.154041
# [1039]	valid_0's binary_logloss: 0.154039
# [1040]	valid_0's binary_logloss: 0.15404
# [1041]	valid_0's binary_logloss: 0.154035
# [1042]	valid_0's binary_logloss: 0.154031
# [1043]	valid_0's binary_logloss: 0.154024
# [1044]	valid_0's binary_logloss: 0.154025
# [1045]	valid_0's binary_logloss: 0.154017
# [1046]	valid_0's binary_logloss: 0.154016
# [1047]	valid_0's binary_logloss: 0.154014
# [1048]	valid_0's binary_logloss: 0.154012
# [1049]	valid_0's binary_logloss: 0.154008
# [1050]	valid_0's binary_logloss: 0.154008
# [1051]	valid_0's binary_logloss: 0.154014
# [1052]	valid_0's binary_logloss: 0.154007
# [1053]	valid_0's binary_logloss: 0.154003
# [1054]	valid_0's binary_logloss: 0.154005
# [1055]	valid_0's binary_logloss: 0.154006
# [1056]	valid_0's binary_logloss: 0.154003
# [1057]	valid_0's binary_logloss: 0.154004
# [1058]	valid_0's binary_logloss: 0.153994
# [1059]	valid_0's binary_logloss: 0.153993
# [1060]	valid_0's binary_logloss: 0.153989
# [1061]	valid_0's binary_logloss: 0.15399
# [1062]	valid_0's binary_logloss: 0.153989
# [1063]	valid_0's binary_logloss: 0.153988
# [1064]	valid_0's binary_logloss: 0.153977
# [1065]	valid_0's binary_logloss: 0.153974
# [1066]	valid_0's binary_logloss: 0.153968
# [1067]	valid_0's binary_logloss: 0.153968
# [1068]	valid_0's binary_logloss: 0.153962
# [1069]	valid_0's binary_logloss: 0.153945
# [1070]	valid_0's binary_logloss: 0.153937
# [1071]	valid_0's binary_logloss: 0.153919
# [1072]	valid_0's binary_logloss: 0.153915
# [1073]	valid_0's binary_logloss: 0.153915
# [1074]	valid_0's binary_logloss: 0.153911
# [1075]	valid_0's binary_logloss: 0.153909
# [1076]	valid_0's binary_logloss: 0.153908
# [1077]	valid_0's binary_logloss: 0.153906
# [1078]	valid_0's binary_logloss: 0.153906
# [1079]	valid_0's binary_logloss: 0.153907
# [1080]	valid_0's binary_logloss: 0.153902
# [1081]	valid_0's binary_logloss: 0.153895
# [1082]	valid_0's binary_logloss: 0.153893
# [1083]	valid_0's binary_logloss: 0.153889
# [1084]	valid_0's binary_logloss: 0.153892
# [1085]	valid_0's binary_logloss: 0.153887
# [1086]	valid_0's binary_logloss: 0.153882
# [1087]	valid_0's binary_logloss: 0.153867
# [1088]	valid_0's binary_logloss: 0.153872
# [1089]	valid_0's binary_logloss: 0.153868
# [1090]	valid_0's binary_logloss: 0.153862
# [1091]	valid_0's binary_logloss: 0.15386
# [1092]	valid_0's binary_logloss: 0.153854
# [1093]	valid_0's binary_logloss: 0.153831
# [1094]	valid_0's binary_logloss: 0.153829
# [1095]	valid_0's binary_logloss: 0.153826
# [1096]	valid_0's binary_logloss: 0.153815
# [1097]	valid_0's binary_logloss: 0.153812
# [1098]	valid_0's binary_logloss: 0.15381
# [1099]	valid_0's binary_logloss: 0.153806
# [1100]	valid_0's binary_logloss: 0.153799
# [1101]	valid_0's binary_logloss: 0.153794
# [1102]	valid_0's binary_logloss: 0.153792
# [1103]	valid_0's binary_logloss: 0.15378
# [1104]	valid_0's binary_logloss: 0.153777
# [1105]	valid_0's binary_logloss: 0.153753
# [1106]	valid_0's binary_logloss: 0.15374
# [1107]	valid_0's binary_logloss: 0.153742
# [1108]	valid_0's binary_logloss: 0.153737
# [1109]	valid_0's binary_logloss: 0.153737
# [1110]	valid_0's binary_logloss: 0.153737
# [1111]	valid_0's binary_logloss: 0.153735
# [1112]	valid_0's binary_logloss: 0.153731
# [1113]	valid_0's binary_logloss: 0.15373
# [1114]	valid_0's binary_logloss: 0.153731
# [1115]	valid_0's binary_logloss: 0.153733
# [1116]	valid_0's binary_logloss: 0.153735
# [1117]	valid_0's binary_logloss: 0.153731
# [1118]	valid_0's binary_logloss: 0.153728
# [1119]	valid_0's binary_logloss: 0.153724
# [1120]	valid_0's binary_logloss: 0.153722
# [1121]	valid_0's binary_logloss: 0.153719
# [1122]	valid_0's binary_logloss: 0.153718
# [1123]	valid_0's binary_logloss: 0.153711
# [1124]	valid_0's binary_logloss: 0.153712
# [1125]	valid_0's binary_logloss: 0.153713
# [1126]	valid_0's binary_logloss: 0.153712
# [1127]	valid_0's binary_logloss: 0.153704
# [1128]	valid_0's binary_logloss: 0.153701
# [1129]	valid_0's binary_logloss: 0.153703
# [1130]	valid_0's binary_logloss: 0.153691
# [1131]	valid_0's binary_logloss: 0.153688
# [1132]	valid_0's binary_logloss: 0.153688
# [1133]	valid_0's binary_logloss: 0.153688
# [1134]	valid_0's binary_logloss: 0.153679
# [1135]	valid_0's binary_logloss: 0.153677
# [1136]	valid_0's binary_logloss: 0.153673
# [1137]	valid_0's binary_logloss: 0.153676
# [1138]	valid_0's binary_logloss: 0.153673
# [1139]	valid_0's binary_logloss: 0.153667
# [1140]	valid_0's binary_logloss: 0.153672
# [1141]	valid_0's binary_logloss: 0.153662
# [1142]	valid_0's binary_logloss: 0.153634
# [1143]	valid_0's binary_logloss: 0.153631
# [1144]	valid_0's binary_logloss: 0.153626
# [1145]	valid_0's binary_logloss: 0.15363
# [1146]	valid_0's binary_logloss: 0.15363
# [1147]	valid_0's binary_logloss: 0.153627
# [1148]	valid_0's binary_logloss: 0.15363
# [1149]	valid_0's binary_logloss: 0.153629
# Early stopping, best iteration is:
# [1144]	valid_0's binary_logloss: 0.153626

# %%
from sklearn.metrics import roc_auc_score
x_final=x_test[features]
y_final=c.predict_proba(x_final)
y_pred=[]
for elem in y_final:
    y_pred.append(elem[1])
score=roc_auc_score(y_test, y_pred)
print(score)

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV31.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV29.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idpostulante'],how='left')
prediccion=pd.merge(prediccion,vistas2,on=['idaviso','idpostulante'],how='left')
prediccion=pd.merge(prediccion,vistas3,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion['lo_vio']=(prediccion['cantidad']>0)
prediccion=pd.merge(prediccion,postulaciones_por_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['postulaciones_misma_area']=prediccion['postulaciones_misma_area'].fillna(0)
prediccion['postulaciones_mismo_nivel']=prediccion['postulaciones_mismo_nivel'].fillna(0)
prediccion['postulaciones_mismo_tipo']=prediccion['postulaciones_mismo_tipo'].fillna(0)
prediccion=pd.merge(prediccion,vistas_por_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,vistas_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,vistas_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['vistas_por_area']=prediccion['vistas_por_area'].fillna(0)
prediccion['vistas_por_tipo']=prediccion['vistas_por_tipo'].fillna(0)
prediccion['vistas_por_nivel']=prediccion['vistas_por_tipo'].fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado    Master  \
# 7823   89618  1112467034      GNX3b8v  MASC  21.0         -         -
# 12852  46566  1112430193      1QraqqR   FEM  26.0         -         -
# 39282  83816  1112466410      4rPY4N5   FEM  21.0         -         -
# 22684  18392  1112213212      kPjDdvm   FEM  21.0         -         -
# 12208  54749  1112446968       56XeZX   FEM  46.0  En Curso         -
# 63411  10796  1111926843       e4rxlr   FEM  37.0         -         -
# 90581  91966  1112473393       8KljOO  MASC  42.0         -         -
# 57535  69151  1112461125       8PL3KR   FEM  33.0         -         -
# 99675  99639  1112513109       NmZM0V   FEM  45.0         -         -
# 79936  27396  1112350157       Y0m81J   FEM  44.0         -  En Curso
#
#            Otro  Posgrado Secundario        ...        vistas_postulante  \
# 7823          -         -   Graduado        ...                    216.0
# 12852  Graduado         -   Graduado        ...                     27.0
# 39282         -         -   Graduado        ...                    183.0
# 22684         -         -   Graduado        ...                      4.0
# 12208         -  Graduado   Graduado        ...                      6.0
# 63411  Graduado         -   Graduado        ...                      1.0
# 90581         -         -   Graduado        ...                      8.0
# 57535         -         -          -        ...                     54.0
# 99675         -         -          -        ...                      NaN
# 79936         -         -   Graduado        ...                      NaN
#
#       vistas_al_aviso  cantidad lo_vio postulaciones_misma_area  \
# 7823              1.0  0.004630   True                     17.0
# 12852             2.0  0.074074   True                      1.0
# 39282             1.0  0.005464   True                     48.0
# 22684             NaN  0.000000  False                      0.0
# 12208             NaN  0.000000  False                      0.0
# 63411             NaN  0.000000  False                      0.0
# 90581             NaN  0.000000  False                      0.0
# 57535             NaN  0.000000  False                      1.0
# 99675             NaN  0.000000  False                      0.0
# 79936             NaN  0.000000  False                      0.0
#
#       postulaciones_mismo_tipo postulaciones_mismo_nivel vistas_por_area  \
# 7823                      36.0                      47.0            17.0
# 12852                     20.0                      17.0             5.0
# 39282                    103.0                     175.0            33.0
# 22684                     36.0                       0.0             0.0
# 12208                     15.0                       0.0             0.0
# 63411                     17.0                      13.0             0.0
# 90581                     16.0                       1.0             0.0
# 57535                     34.0                      25.0             0.0
# 99675                      8.0                       0.0             0.0
# 79936                     13.0                      10.0             0.0
#
#        vistas_por_tipo  vistas_por_nivel
# 7823              45.0              45.0
# 12852             12.0              12.0
# 39282             80.0              80.0
# 22684              4.0               4.0
# 12208              4.0               4.0
# 63411              1.0               1.0
# 90581              8.0               8.0
# 57535             42.0              42.0
# 99675              0.0               0.0
# 79936              0.0               0.0
#
# [10 rows x 45 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[9.92020452e-01, 7.97954761e-03],
#        [9.91404663e-01, 8.59533741e-03],
#        [9.98815507e-01, 1.18449256e-03],
#        ...,
#        [9.98491955e-01, 1.50804533e-03],
#        [9.98925622e-01, 1.07437792e-03],
#        [9.99580496e-01, 4.19503931e-04]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     vistas_al_aviso cantidad lo_vio  \
# 0   Graduado    ...                 NaN      0.0  False
# 1          -    ...                 NaN      0.0  False
# 2   Graduado    ...                 NaN      0.0  False
# 3   Graduado    ...                 NaN      0.0  False
# 4          -    ...                 NaN      0.0  False
#
#   postulaciones_misma_area postulaciones_mismo_tipo postulaciones_mismo_nivel  \
# 0                      0.0                     17.0                       0.0
# 1                      5.0                     58.0                       0.0
# 2                      2.0                     11.0                       0.0
# 3                      0.0                     14.0                       0.0
# 4                      0.0                     11.0                       0.0
#
#   vistas_por_area vistas_por_tipo  vistas_por_nivel  sepostulo
# 0             4.0            24.0              24.0   0.007980
# 1             0.0             6.0               6.0   0.008595
# 2             1.0             7.0               7.0   0.001184
# 3             0.0             0.0               0.0   0.000408
# 4             0.0             3.0               3.0   0.000084
#
# [5 rows x 46 columns]

# %%
prediccion=prediccion[['id','sepostulo']]
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.007980
# 1   1   0.008595
# 2   2   0.001184
# 3   3   0.000408
# 4   4   0.000084

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion63.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.4618903067183211
