# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc
from xgboost import XGBClassifier

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisosONEHOT.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantesONEHOT.csv")
areas=avisos['nombre_area'].value_counts()
avisos['nombre_area']=avisos['nombre_area'].replace(areas.index, areas.values)

avisos_no_one_hot= pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
avisos_no_one_hot=avisos_no_one_hot[['idaviso','tipo_de_trabajo','nivel_laboral','nombre_area']];
avisos_no_one_hot['tipo_de_trabajo']=avisos_no_one_hot['tipo_de_trabajo'].astype('category')
avisos_no_one_hot['nivel_laboral']=avisos_no_one_hot['nivel_laboral'].astype('category')
avisos_no_one_hot['nombre_area']=avisos_no_one_hot['nombre_area'].astype('category')
avisos_no_one_hot=avisos_no_one_hot.rename(columns={'nombre_area': 'nombre_area_aux'})

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas2=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2=vistas2.rename(columns={'idAviso': 'idaviso'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q        15
# 1        0005E        58
# 2        000R8        14
# 3        001XE        26
# 4        003k9        32

# %%
vistas2=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           2          28
# 1    48375       RwVdKR           1          15
# 2   169730        1KjXB           2          99
# 3   169730       2AKzxa           2           2
# 4   169730        6LJ64           1          23

# %%
vistas2['cantidad']=vistas2['cantidad_x']/vistas2['cantidad_y']
vistas2.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas=vistas2
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.071429
# 1    48375       RwVdKR  0.066667
# 2   169730        1KjXB  0.020202
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.043478

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/7.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/8.csv").sample(len(postulaciones2)//2).reset_index(drop=True))
print(len(postulaciones2))
postulaciones2
# Out:
# 9906801
#             idaviso idpostulante  sepostulo
# 0        1112389495       5NbOjG          0
# 1        1112024109      1QP841b          0
# 2        1112490884      96XQ6N9          0
# 3        1111474259      qe2QJj1          0
# 4        1112211292      KBzbBJm          0
# 5        1112328485      3NzZv26          0
# 6        1112474766      akDjWwE          0
# 7        1112312385       aZpBJW          0
# 8        1112285628      akDWj55          0
# 9        1112322843      GNd0KNN          0
# 10       1112355899      DrXPRJX          0
# 11       1112461865      8MPoBDR          0
# 12       1111673413       a1NjRN          0
# 13       1112299006      jkVWXRQ          0
# 14       1112501771      owz0YGW          0
# 15       1002543409       Ej5AAb          0
# 16       1112425310      KBrpAO2          0
# 17       1112498569      pzNMppM          0
# 18       1111866251       ZKqL85          0
# 19       1112289529      ow2awXr          0
# 20       1112493109      5mP1DWM          0
# 21       1112326017      0zd9GZ9          0
# 22       1112242315      3NQKV6Q          0
# 23       1112452417      DrlVEwW          0
# 24       1112402816      mzdk9dZ          0
# 25       1112359100      3NP46xq          0
# 26       1112410555      bOVKA32          0
# 27       1112511403      mzdlAQO          0
# 28       1111272539      6rPpNM4          0
# 29       1111591317      6rP4K13          0
# ...             ...          ...        ...
# 3302237  1112160397      A3XJZz1          0
# 3302238  1112414499      akx1b3E          0
# 3302239  1112447905      akjWa5N          0
# 3302240  1111658002      6rBDXj4          0
# 3302241  1112409567      1QkVZzz          0
# 3302242  1112435842      xkvdkNb          0
# 3302243  1112361227       Y8KrPJ          0
# 3302244  1112356687       8xorXL          0
# 3302245  1112397889       N6KoqB          0
# 3302246  1112145421      dYo0NZA          0
# 3302247  1112381804       53B4mw          0
# 3302248  1112250031      A3RrLRj          0
# 3302249  1111422076      Eze94p4          0
# 3302250  1112202132       Y8ApjP          0
# 3302251  1111393842      dY5OOab          0
# 3302252  1112366078       aXBpzm          0
# 3302253  1112396215      VNPJLYd          0
# 3302254  1111773990      xkd6lxa          0
# 3302255  1112422950      A3DWLlG          0
# 3302256  1111785554      PmGV96J          0
# 3302257  1112487990      96X63Ew          0
# 3302258  1112475003       Y23lxZ          0
# 3302259  1112293815      wVkEYEd          0
# 3302260  1112477193       52KVjZ          0
# 3302261  1112361603       EPMYW9          0
# 3302262  1112355615      ow28410          0
# 3302263  1111235977      9696L1p          0
# 3302264  1112138272       6LxALR          0
# 3302265  1112428127       1oBPxL          0
# 3302266     1527720      xk9rBMV          0
#
# [9906801 rows x 3 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 16511335
# 16502019

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,avisos_no_one_hot,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 1820057   1112266459      KBr0kBd          0  19.0     False       True
# 14947405  1112057618      A3XPxGD          0  36.0     False       True
# 2352269   1112245557       5JoMDq          0  31.0     False       True
# 1863529   1112365308      KBe56VQ          0  28.0      True      False
# 15941414  1112217861      zv8XxoD          0  25.0      True      False
# 5146531   1112452139      6rZYVZl          1  22.0     False       True
# 4559354   1112289711      ZD81W0V          1  33.0     False       True
# 12032024  1112428442      EzewKbo          1  19.0     False       True
# 13696184  1112432674      W9P2MLl          0  52.0     False       True
# 14980730  1112416016      VNJRDB2          0  26.0     False       True
# 345544    1112212782      ekvkDa2          0  29.0      True      False
# 5361765   1112455867      QNPwJol          0  28.0      True      False
# 15341623  1112010738      akRYpEW          0  28.0      True      False
# 5814823   1112224962      3NkdDpJ          1  34.0     False       True
# 3978552   1112260100      pzdozzp          0  32.0     False       True
# 5417428   1112379049      VNrMzJj          0  25.0      True      False
# 6053150   1112427186      ekNp8XB          0  25.0      True      False
# 2049899   1112438648      owjjlj4          0  26.0      True      False
# 3334376   1112335406       EMz1E6          1  30.0      True      False
# 5966341   1112113517       alWK15          0  49.0      True      False
#
#           sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 1820057             False                 False               False
# 14947405            False                 False               False
# 2352269             False                 False               False
# 1863529             False                 False               False
# 15941414            False                 False               False
# 5146531             False                 False               False
# 4559354             False                 False               False
# 12032024            False                 False               False
# 13696184            False                 False               False
# 14980730            False                 False               False
# 345544              False                 False               False
# 5361765             False                 False               False
# 15341623            False                 False               False
# 5814823             False                 False               False
# 3978552             False                 False               False
# 5417428             False                 False               False
# 6053150             False                 False               False
# 2049899             False                 False               False
# 3334376             False                 False               False
# 5966341             False                 False               False
#
#           Doctorado_Graduado    ...     tipo_de_trabajo_Voluntario  \
# 1820057                False    ...                          False
# 14947405               False    ...                          False
# 2352269                False    ...                          False
# 1863529                False    ...                          False
# 15941414               False    ...                          False
# 5146531                False    ...                          False
# 4559354                False    ...                          False
# 12032024               False    ...                          False
# 13696184               False    ...                          False
# 14980730               False    ...                          False
# 345544                 False    ...                          False
# 5361765                False    ...                          False
# 15341623               False    ...                          False
# 5814823                False    ...                          False
# 3978552                False    ...                          False
# 5417428                False    ...                          False
# 6053150                False    ...                          False
# 2049899                False    ...                          False
# 3334376                False    ...                          False
# 5966341                False    ...                          False
#
#           nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 1820057                                               False
# 14947405                                              False
# 2352269                                               False
# 1863529                                               False
# 15941414                                              False
# 5146531                                               False
# 4559354                                               False
# 12032024                                              False
# 13696184                                              False
# 14980730                                              False
# 345544                                                False
# 5361765                                               False
# 15341623                                              False
# 5814823                                               False
# 3978552                                               False
# 5417428                                               False
# 6053150                                               False
# 2049899                                               False
# 3334376                                               False
# 5966341                                               False
#
#           nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 1820057                                           False                 False
# 14947405                                          False                  True
# 2352269                                           False                 False
# 1863529                                           False                 False
# 15941414                                          False                 False
# 5146531                                           False                 False
# 4559354                                           False                 False
# 12032024                                          False                 False
# 13696184                                          False                 False
# 14980730                                          False                 False
# 345544                                            False                 False
# 5361765                                            True                 False
# 15341623                                          False                 False
# 5814823                                           False                 False
# 3978552                                           False                 False
# 5417428                                           False                 False
# 6053150                                           False                 False
# 2049899                                           False                 False
# 3334376                                           False                  True
# 5966341                                           False                 False
#
#           nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  \
# 1820057                False                                True
# 14947405               False                               False
# 2352269                False                                True
# 1863529                False                                True
# 15941414               False                                True
# 5146531                False                                True
# 4559354                False                                True
# 12032024               False                                True
# 13696184                True                               False
# 14980730               False                                True
# 345544                 False                                True
# 5361765                False                               False
# 15341623               False                                True
# 5814823                False                                True
# 3978552                False                                True
# 5417428                False                                True
# 6053150                False                                True
# 2049899                False                                True
# 3334376                False                               False
# 5966341                False                                True
#
#           tipo_de_trabajo                    nivel_laboral  \
# 1820057         Full-time             Senior / Semi-Senior
# 14947405        Part-time                           Junior
# 2352269         Full-time             Senior / Semi-Senior
# 1863529         Full-time             Senior / Semi-Senior
# 15941414        Full-time             Senior / Semi-Senior
# 5146531         Full-time             Senior / Semi-Senior
# 4559354         Full-time             Senior / Semi-Senior
# 12032024        Full-time             Senior / Semi-Senior
# 13696184        Full-time                             Otro
# 14980730        Full-time             Senior / Semi-Senior
# 345544          Full-time             Senior / Semi-Senior
# 5361765         Full-time  Jefe / Supervisor / Responsable
# 15341623        Full-time             Senior / Semi-Senior
# 5814823         Full-time             Senior / Semi-Senior
# 3978552         Full-time             Senior / Semi-Senior
# 5417428         Part-time             Senior / Semi-Senior
# 6053150         Full-time             Senior / Semi-Senior
# 2049899         Full-time             Senior / Semi-Senior
# 3334376         Full-time                           Junior
# 5966341         Full-time             Senior / Semi-Senior
#
#                               nombre_area_aux  cantidad
# 1820057                         Mantenimiento       NaN
# 14947405                        Telemarketing       NaN
# 2352269                             Tesorería       NaN
# 1863529                Ingeniería  Industrial       NaN
# 15941414  Ingeniería  Eléctrica y Electrónica       NaN
# 5146531       Almacén / Depósito / Expedición  0.008696
# 4559354                         Mantenimiento       NaN
# 12032024                           Producción  0.006711
# 13696184                               Ventas       NaN
# 14980730                    Diseño Industrial       NaN
# 345544                  Tecnologia / Sistemas       NaN
# 5361765                    Telecomunicaciones       NaN
# 15341623                           Producción       NaN
# 5814823                               Compras       NaN
# 3978552                        Administración       NaN
# 5417428                           Call Center       NaN
# 6053150                 Tecnologia / Sistemas       NaN
# 2049899                        Administración       NaN
# 3334376                                 Legal  0.019231
# 5966341                      Ingeniería Civil       NaN
#
# [20 rows x 80 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo   edad  sexo_FEM  sexo_MASC  \
# 3917317   1112437620      3NPJ30K          0   22.0     False       True
# 983225    1111455368      VNr5ErD          1   19.0      True      False
# 2838936   1112402915      MVPdMlv          1   25.0      True      False
# 5033232   1112280984      lDbmaA2          0   36.0      True      False
# 96184     1112348995      JBdD6b3          1   24.0      True      False
# 4398921   1112285511      8MZwYpM          1   28.0      True      False
# 15965110  1112405655      zv44DL6          1   24.0      True      False
# 15194088  1112297025      owa6NOe          1   34.0     False       True
# 7931845   1112269957      JBxQ9w5          1   27.0      True      False
# 14956965  1112245044      YjrwG3Z          0   53.0      True      False
# 12082425  1111726535      qe2ZBw9          0   49.0      True      False
# 15281794  1111971838      Drp4dqL          0   20.0     False       True
# 4237926   1112351925      bOjVZRB          0   22.0      True      False
# 7861996   1112208206       ERKXV2          0   38.0      True      False
# 9287488   1112389241      JBrjXob          0  200.0      True      False
# 3620500   1112204023       8KQmBz          0   37.0      True      False
# 3421469   1112315833       8QA8px          1   29.0      True      False
# 13466808  1112320395      lDLK1BG          0   22.0      True      False
# 10340345  1112359300      rmdmLP6          1   28.0      True      False
# 9065563   1112370921      JBxOl3e          0   25.0     False       True
#
#           sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 3917317             False                 False               False
# 983225              False                 False               False
# 2838936             False                 False               False
# 5033232             False                 False               False
# 96184               False                 False               False
# 4398921             False                 False               False
# 15965110            False                 False               False
# 15194088            False                 False               False
# 7931845             False                 False               False
# 14956965            False                 False               False
# 12082425            False                 False               False
# 15281794            False                 False               False
# 4237926             False                 False               False
# 7861996             False                 False               False
# 9287488             False                 False               False
# 3620500             False                 False               False
# 3421469             False                 False               False
# 13466808            False                 False               False
# 10340345            False                 False               False
# 9065563             False                 False               False
#
#           Doctorado_Graduado    ...     tipo_de_trabajo_Voluntario  \
# 3917317                False    ...                          False
# 983225                 False    ...                          False
# 2838936                False    ...                          False
# 5033232                False    ...                          False
# 96184                  False    ...                          False
# 4398921                False    ...                          False
# 15965110               False    ...                          False
# 15194088               False    ...                          False
# 7931845                False    ...                          False
# 14956965               False    ...                          False
# 12082425               False    ...                          False
# 15281794               False    ...                          False
# 4237926                False    ...                          False
# 7861996                False    ...                          False
# 9287488                False    ...                          False
# 3620500                False    ...                          False
# 3421469                False    ...                          False
# 13466808               False    ...                          False
# 10340345               False    ...                          False
# 9065563                False    ...                          False
#
#           nivel_laboral_Gerencia / Alta Gerencia / Dirección  \
# 3917317                                               False
# 983225                                                False
# 2838936                                               False
# 5033232                                               False
# 96184                                                 False
# 4398921                                               False
# 15965110                                              False
# 15194088                                              False
# 7931845                                               False
# 14956965                                              False
# 12082425                                              False
# 15281794                                              False
# 4237926                                               False
# 7861996                                               False
# 9287488                                               False
# 3620500                                               False
# 3421469                                               False
# 13466808                                              False
# 10340345                                              False
# 9065563                                               False
#
#           nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 3917317                                           False                 False
# 983225                                            False                 False
# 2838936                                           False                 False
# 5033232                                           False                 False
# 96184                                             False                 False
# 4398921                                           False                  True
# 15965110                                          False                 False
# 15194088                                          False                 False
# 7931845                                           False                  True
# 14956965                                          False                 False
# 12082425                                          False                 False
# 15281794                                          False                  True
# 4237926                                           False                 False
# 7861996                                           False                  True
# 9287488                                           False                 False
# 3620500                                           False                  True
# 3421469                                           False                 False
# 13466808                                          False                 False
# 10340345                                          False                  True
# 9065563                                           False                 False
#
#           nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  \
# 3917317                False                                True
# 983225                 False                                True
# 2838936                False                                True
# 5033232                False                                True
# 96184                  False                                True
# 4398921                False                               False
# 15965110               False                                True
# 15194088                True                               False
# 7931845                False                               False
# 14956965               False                                True
# 12082425               False                                True
# 15281794               False                               False
# 4237926                False                                True
# 7861996                False                               False
# 9287488                False                                True
# 3620500                False                               False
# 3421469                False                                True
# 13466808               False                                True
# 10340345               False                               False
# 9065563                 True                               False
#
#           tipo_de_trabajo         nivel_laboral  \
# 3917317         Full-time  Senior / Semi-Senior
# 983225          Full-time  Senior / Semi-Senior
# 2838936         Full-time  Senior / Semi-Senior
# 5033232         Full-time  Senior / Semi-Senior
# 96184           Full-time  Senior / Semi-Senior
# 4398921         Full-time                Junior
# 15965110        Full-time  Senior / Semi-Senior
# 15194088        Full-time                  Otro
# 7931845         Full-time                Junior
# 14956965        Full-time  Senior / Semi-Senior
# 12082425        Full-time  Senior / Semi-Senior
# 15281794        Full-time                Junior
# 4237926         Full-time  Senior / Semi-Senior
# 7861996         Full-time                Junior
# 9287488         Full-time  Senior / Semi-Senior
# 3620500         Full-time                Junior
# 3421469         Full-time  Senior / Semi-Senior
# 13466808        Full-time  Senior / Semi-Senior
# 10340345        Full-time                Junior
# 9065563         Part-time                  Otro
#
#                                 nombre_area_aux  cantidad
# 3917317                                 Compras      0.00
# 983225                      Atención al Cliente      0.00
# 2838936                                  Ventas      0.00
# 5033232                             Gastronomia      0.00
# 96184                             Recepcionista      0.15
# 4398921                                  Ventas      0.00
# 15965110                               Medicina      1.00
# 15194088  Ingeniería Oficina Técnica / Proyecto      0.00
# 7931845                               Comercial      0.00
# 14956965                 Ingeniería  Industrial      0.00
# 12082425                              Comercial      0.00
# 15281794                    Atención al Cliente      0.00
# 4237926                            Contabilidad      0.00
# 7861996                                  Ventas      0.00
# 9287488                   Tecnologia / Sistemas      0.00
# 3620500                            Contabilidad      0.00
# 3421469                                   Legal      0.00
# 13466808                   Ingeniería  Mecánica      0.00
# 10340345               Mantenimiento y Limpieza      0.00
# 9065563                     Educación/ Docentes      0.00
#
# [20 rows x 80 columns]

# %%
postulaciones_por_area=postulaciones.copy()
postulaciones_por_area=postulaciones_por_area.groupby(by=['idpostulante','nombre_area_aux'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_area=postulaciones_por_area.rename(columns={'sepostulo':'postulaciones_misma_area'})
postulaciones_por_area.head()
# Out:
#   idpostulante                  nombre_area_aux  postulaciones_misma_area
# 0      0z5Dmrd                   Administración                         2
# 1      0z5Dmrd       Administración de Personal                         1
# 2      0z5Dmrd  Almacén / Depósito / Expedición                         1
# 3      0z5Dmrd              Atención al Cliente                         1
# 4      0z5Dmrd                        Auditoría                         1

# %%
postulaciones_por_nivel=postulaciones.copy()
postulaciones_por_nivel=postulaciones_por_nivel.groupby(by=['idpostulante','nivel_laboral'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_nivel=postulaciones_por_nivel.rename(columns={'sepostulo':'postulaciones_mismo_nivel'})
postulaciones_por_nivel.head()
# Out:
#   idpostulante                         nivel_laboral  \
# 0      0z5Dmrd                                     -
# 1      0z5Dmrd  Gerencia / Alta Gerencia / Dirección
# 2      0z5Dmrd                                Junior
# 3      0z5Dmrd                                  Otro
# 4      0z5Dmrd                  Senior / Semi-Senior
#
#    postulaciones_mismo_nivel
# 0                          1
# 1                          2
# 2                          4
# 3                          1
# 4                         16

# %%
postulaciones_por_tipo=postulaciones.copy()
postulaciones_por_tipo=postulaciones_por_tipo.groupby(by=['idpostulante','tipo_de_trabajo'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_tipo=postulaciones_por_tipo.rename(columns={'sepostulo':'postulaciones_mismo_tipo'})
postulaciones_por_tipo.head()
# Out:
#   idpostulante tipo_de_trabajo  postulaciones_mismo_tipo
# 0      0z5Dmrd       Full-time                        23
# 1      0z5Dmrd       Part-time                         1
# 2      0z5JW1r       Full-time                        27
# 3      0z5VvGv       Full-time                        58
# 4      0z5VvGv       Part-time                        11

# %%
postulaciones=pd.merge(postulaciones,postulaciones_por_area,on=['idpostulante','nombre_area_aux'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['postulaciones_misma_area']=postulaciones['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_nivel']=postulaciones['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_tipo']=postulaciones['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo   edad  sexo_FEM  sexo_MASC  \
# 2535305   1112271407      xkp5KLV          0   23.0     False       True
# 7823015   1112277176      OqdqBMW          1   22.0      True      False
# 6344897   1112349612       YReqAw          1   45.0     False       True
# 9763930   1112285298       NRdEBJ          0   31.0     False       True
# 14597945  1112488733      GNdEmQ9          0   28.0      True      False
# 15614075  1112214749       Z2bOpR          0   34.0      True      False
# 479447    1112260584      5mdRWJX          1   24.0     False       True
# 6962867   1112346591       8k1Grx          1   33.0     False       True
# 10559447  1112305190      6r28a9x          0   26.0      True      False
# 6748193   1112406509      3N2ddXa          1   38.0     False       True
# 5213077   1112308989      JBdr0D3          1   25.0     False       True
# 2439075   1112298966       EBvAA6          1   29.0     False       True
# 4690144   1112490840      DrX21Aa          0   30.0     False       True
# 6235619   1112094404      ZDrEK18          0   25.0      True      False
# 3017841   1112448418      Bm5JM4L          1  200.0     False      False
# 11876604  1112423634      EzZJDjb          0   38.0     False       True
# 15545330  1111171294      owzO1j3          0   23.0     False       True
# 7752962   1112208794      X9oldNv          0   31.0      True      False
# 3850987   1112245800      0zPe1N9          0   22.0      True      False
# 401085    1112284291       Nr2Ndl          1   30.0      True      False
#
#           sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 2535305             False                 False               False
# 7823015             False                 False               False
# 6344897             False                 False               False
# 9763930             False                 False               False
# 14597945            False                 False               False
# 15614075            False                 False               False
# 479447              False                 False               False
# 6962867             False                 False               False
# 10559447            False                 False               False
# 6748193             False                 False               False
# 5213077             False                 False               False
# 2439075             False                 False               False
# 4690144             False                 False               False
# 6235619             False                 False               False
# 3017841              True                 False               False
# 11876604            False                 False               False
# 15545330            False                 False               False
# 7752962             False                 False               False
# 3850987             False                 False               False
# 401085              False                 False               False
#
#           Doctorado_Graduado            ...              nivel_laboral_Junior  \
# 2535305                False            ...                             False
# 7823015                False            ...                             False
# 6344897                False            ...                             False
# 9763930                False            ...                             False
# 14597945               False            ...                             False
# 15614075               False            ...                             False
# 479447                 False            ...                             False
# 6962867                False            ...                             False
# 10559447               False            ...                             False
# 6748193                False            ...                              True
# 5213077                False            ...                              True
# 2439075                False            ...                              True
# 4690144                False            ...                             False
# 6235619                False            ...                             False
# 3017841                False            ...                             False
# 11876604               False            ...                             False
# 15545330               False            ...                             False
# 7752962                False            ...                             False
# 3850987                False            ...                             False
# 401085                 False            ...                             False
#
#           nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  \
# 2535305                False                                True
# 7823015                False                                True
# 6344897                False                                True
# 9763930                 True                               False
# 14597945               False                                True
# 15614075               False                                True
# 479447                 False                                True
# 6962867                False                                True
# 10559447               False                                True
# 6748193                False                               False
# 5213077                False                               False
# 2439075                False                               False
# 4690144                False                                True
# 6235619                False                                True
# 3017841                False                                True
# 11876604               False                                True
# 15545330               False                                True
# 7752962                False                                True
# 3850987                False                                True
# 401085                 False                                True
#
#           tipo_de_trabajo         nivel_laboral  \
# 2535305         Full-time  Senior / Semi-Senior
# 7823015         Full-time  Senior / Semi-Senior
# 6344897         Full-time  Senior / Semi-Senior
# 9763930         Full-time                  Otro
# 14597945        Full-time  Senior / Semi-Senior
# 15614075        Full-time  Senior / Semi-Senior
# 479447          Part-time  Senior / Semi-Senior
# 6962867         Full-time  Senior / Semi-Senior
# 10559447        Full-time  Senior / Semi-Senior
# 6748193         Full-time                Junior
# 5213077         Part-time                Junior
# 2439075         Full-time                Junior
# 4690144         Full-time  Senior / Semi-Senior
# 6235619         Full-time  Senior / Semi-Senior
# 3017841         Full-time  Senior / Semi-Senior
# 11876604        Part-time  Senior / Semi-Senior
# 15545330        Full-time  Senior / Semi-Senior
# 7752962         Full-time  Senior / Semi-Senior
# 3850987         Full-time  Senior / Semi-Senior
# 401085          Full-time  Senior / Semi-Senior
#
#                           nombre_area_aux  cantidad  postulaciones_misma_area  \
# 2535305                        Producción  0.000000                         1
# 7823015                            Ventas  0.000000                        29
# 6344897                   Soporte Técnico  0.012821                        22
# 9763930             Oficios y Profesiones  0.000000                         1
# 14597945                   Administración  0.000000                         3
# 15614075                    Mantenimiento  0.000000                         0
# 479447                      Recepcionista  0.000000                         0
# 6962867          Mantenimiento y Limpieza  0.000000                         2
# 10559447                           Ventas  0.000000                         4
# 6748193                    Administración  0.000000                         4
# 5213077               Atención al Cliente  0.000000                        15
# 2439075                       Call Center  0.000000                        10
# 4690144                        Producción  0.000000                        56
# 6235619                      Programación  0.000000                         1
# 3017841               Atención al Cliente  0.076923                         0
# 11876604                    Telemarketing  0.000000                         1
# 15545330                    Mantenimiento  0.000000                         0
# 7752962   Almacén / Depósito / Expedición  0.000000                         0
# 3850987                   Soporte Técnico  0.000000                         0
# 401085                           Finanzas  0.000000                         0
#
#           postulaciones_mismo_tipo  postulaciones_mismo_nivel
# 2535305                         26                         20
# 7823015                         53                         53
# 6344897                         86                         59
# 9763930                         27                          3
# 14597945                        18                         15
# 15614075                        14                         12
# 479447                           2                         34
# 6962867                        159                        126
# 10559447                        67                         49
# 6748193                         40                          2
# 5213077                         24                         37
# 2439075                         45                         16
# 4690144                         92                         61
# 6235619                         96                         84
# 3017841                         21                         20
# 11876604                         2                         19
# 15545330                        17                         14
# 7752962                         21                         19
# 3850987                         14                         11
# 401085                          29                         25
#
# [20 rows x 83 columns]

# %%
train, test=train_test_split(postulaciones.sample(len(postulaciones)//2),test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')
features.remove('nombre_area_aux')
features.remove('tipo_de_trabajo')
features.remove('nivel_laboral')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
vistas2=0
# Out:
# Train:  15281886 Test:  804310

# %%
c=0
gc.collect()
# Out:
# 117

# %%
c=XGBClassifier(objective='binary:logistic',max_depth=20,learning_rate=0.01,subsample=0.8,colsample_bytree=0.8,n_estimators=100,silent=False,n_jobs=-1,verbose=1)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")
dt=c.fit(x_train,y_train,eval_set=[(x_test,y_test)],verbose=True,early_stopping_rounds=1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-41-7944bdb13790> in <module>()
#       1 c=lgb.LGBMClassifier(learning_rate=0.01,objective='binary',num_leaves=6000,max_depth=18,n_estimators=10,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)
#       2 #c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")
# ----> 3 dt=c.fit(x_train,y_train,eval_set=[(x_test,y_test)],verbose=True,early_stopping_rounds=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     673                                         verbose=verbose, feature_name=feature_name,
#     674                                         categorical_feature=categorical_feature,
# --> 675                                         callbacks=callbacks)
#     676         return self
#     677
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     467                               verbose_eval=verbose, feature_name=feature_name,
#     468                               categorical_feature=categorical_feature,
# --> 469                               callbacks=callbacks)
#     470
#     471         if evals_result:
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     178     # construct booster
#     179     try:
# --> 180         booster = Booster(params=params, train_set=train_set)
#     181         if is_valid_contain_train:
#     182             booster.set_train_data_name(train_data_name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in __init__(self, params, train_set, model_file, silent)
#    1301             self.handle = ctypes.c_void_p()
#    1302             _safe_call(_LIB.LGBM_BoosterCreate(
# -> 1303                 train_set.construct().handle,
#    1304                 c_str(params_str),
#    1305                 ctypes.byref(self.handle)))
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in construct(self)
#     854                                 weight=self.weight, group=self.group, init_score=self.init_score,
#     855                                 predictor=self._predictor, silent=self.silent, feature_name=self.feature_name,
# --> 856                                 categorical_feature=self.categorical_feature, params=self.params)
#     857             if self.free_raw_data:
#     858                 self.data = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#     646             self.pandas_categorical = reference.pandas_categorical
#     647             categorical_feature = reference.categorical_feature
# --> 648         data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data, feature_name, categorical_feature, self.pandas_categorical)
#     649         label = _label_from_pandas(label)
#     650         self.data_has_header = False
#
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     240     if isinstance(data, DataFrame):
#     241         if feature_name == 'auto' or feature_name is None:
# --> 242             data = data.rename(columns=str)
#     243         cat_cols = data.select_dtypes(include=['category']).columns
#     244         if pandas_categorical is None:  # train dataset
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     125         @wraps(func)
#     126         def wrapper(*args, **kwargs):
# --> 127             return func(*args, **kwargs)
#     128
#     129         if not PY2:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in rename(self, *args, **kwargs)
#    3025         kwargs.pop('axis', None)
#    3026         kwargs.pop('mapper', None)
# -> 3027         return super(DataFrame, self).rename(**kwargs)
#    3028
#    3029     @Appender(_shared_docs['fillna'] % _shared_doc_kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in rename(self, *args, **kwargs)
#     882                 level = self.axes[axis]._get_level_number(level)
#     883             result._data = result._data.rename_axis(f, axis=baxis, copy=copy,
# --> 884                                                     level=level)
#     885             result._clear_item_cache()
#     886
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in rename_axis(self, mapper, axis, copy, level)
#    3088
#    3089         """
# -> 3090         obj = self.copy(deep=copy)
#    3091         obj.set_axis(axis, _transform_index(self.axes[axis], mapper, level))
#    3092         return obj
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in copy(self, deep, mgr)
#    3662             new_axes = list(self.axes)
#    3663         return self.apply('copy', axes=new_axes, deep=deep,
# -> 3664                           do_integrity_check=False)
#    3665
#    3666     def as_matrix(self, items=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3327
#    3328             kwargs['mgr'] = self
# -> 3329             applied = getattr(b, f)(**kwargs)
#    3330             result_blocks = _extend_blocks(applied, result_blocks)
#    3331
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in copy(self, deep, mgr)
#     734         values = self.values
#     735         if deep:
# --> 736             values = values.copy()
#     737         return self.make_block_same_class(values)
#     738
#
# MemoryError:

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-1d3e95a8267b> in <module>()
# ----> 1 score=c.roc_auc_score(x_test,y_test)*100
#       2 print(score)
#
# AttributeError: 'LGBMClassifier' object has no attribute 'roc_auc_score'

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/XGBoost v3.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV18.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos_no_one_hot,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion=pd.merge(prediccion,postulaciones_por_area,on=['idpostulante','nombre_area_aux'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['postulaciones_misma_area']=prediccion['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion['postulaciones_mismo_nivel']=prediccion['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion['postulaciones_mismo_tipo']=prediccion['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado Master      Otro  \
# 57149  62362  1112456072       N01KLJ  MASC  33.0         -      -         -
# 41016  29541  1112372247      lDLGxo6  MASC  19.0         -      -         -
# 51666  20142  1112248723       8k0Kql   FEM  32.0         -      -  En Curso
# 33704  45606  1112428517      wVkARkm  MASC  20.0         -      -         -
# 47075  84361  1112466548      zv6BjOJ  MASC  33.0         -      -  Graduado
# 31622  34807  1112409290      xk94VO0  MASC  34.0         -      -         -
# 39804  63162  1112457309      wVYN9RZ  MASC  22.0         -      -         -
# 67110  13280  1112034433       YWreBY   FEM  32.0         -      -         -
# 68715  52102  1112442467       6krvp4   FEM  42.0         -      -         -
# 36661  85642  1112466646      kP6VEaQ  MASC  24.0         -      -         -
#
#       Posgrado Secundario            ...             remuneracion_pretendida  \
# 57149        -          -            ...                               False
# 41016        -   En Curso            ...                               False
# 51666        -          -            ...                               False
# 33704        -   Graduado            ...                               False
# 47075        -   Graduado            ...                               False
# 31622        -   Graduado            ...                               False
# 39804        -   Graduado            ...                               False
# 67110        -          -            ...                               False
# 68715        -   Graduado            ...                               False
# 36661        -   Graduado            ...                               False
#
#       graduados estudiantes conocimientos_especificos buen_ambiente  \
# 57149     False       False                     False         False
# 41016     False       False                     False         False
# 51666      True       False                     False         False
# 33704     False       False                     False         False
# 47075     False       False                      True         False
# 31622     False       False                      True         False
# 39804     False       False                     False         False
# 67110     False       False                     False         False
# 68715     False       False                     False          True
# 36661     False        True                     False         False
#
#       discriminacion  cantidad postulaciones_misma_area  \
# 57149          False  0.000000                      0.0
# 41016          False  0.000000                      1.0
# 51666          False  0.000000                      0.0
# 33704          False  0.026316                     16.0
# 47075           True  0.000000                    171.0
# 31622           True  0.000000                     18.0
# 39804          False  0.000000                      1.0
# 67110          False  0.000000                      0.0
# 68715          False  0.000000                      0.0
# 36661          False  0.031250                      0.0
#
#        postulaciones_mismo_tipo  postulaciones_mismo_nivel
# 57149                      13.0                        9.0
# 41016                      11.0                       10.0
# 51666                      34.0                        0.0
# 33704                      49.0                       39.0
# 47075                     400.0                      275.0
# 31622                      29.0                       21.0
# 39804                       8.0                        7.0
# 67110                       1.0                        2.0
# 68715                       1.0                        0.0
# 36661                      13.0                        3.0
#
# [10 rows x 39 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.98468452, 0.01531548],
#        [0.91707531, 0.08292469],
#        [0.99507161, 0.00492839],
#        ...,
#        [0.98484307, 0.01515693],
#        [0.98797481, 0.01202519],
#        [0.99410825, 0.00589175]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     graduados estudiantes conocimientos_especificos  \
# 0   Graduado    ...         False       False                     False
# 1          -    ...         False       False                     False
# 2   Graduado    ...         False       False                     False
# 3   Graduado    ...         False       False                     False
# 4          -    ...         False       False                     False
#
#   buen_ambiente discriminacion cantidad postulaciones_misma_area  \
# 0         False          False      0.0                      0.0
# 1         False          False      0.0                      5.0
# 2         False          False      0.0                      2.0
# 3         False          False      0.0                      0.0
# 4         False          False      0.0                      0.0
#
#   postulaciones_mismo_tipo  postulaciones_mismo_nivel  sepostulo
# 0                     13.0                        0.0   0.015315
# 1                     55.0                        0.0   0.082925
# 2                     10.0                        0.0   0.004928
# 3                     12.0                        0.0   0.002338
# 4                     10.0                        0.0   0.000976
#
# [5 rows x 40 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.015315
# 1   1   0.082925
# 2   2   0.004928
# 3   3   0.002338
# 4   4   0.000976

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion37.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.4772061416245788
