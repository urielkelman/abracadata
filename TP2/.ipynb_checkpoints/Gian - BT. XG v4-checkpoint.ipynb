# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc
from xgboost import XGBClassifier

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisosONEHOT.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantesONEHOT.csv")
areas=avisos['nombre_area'].value_counts()
avisos['nombre_area']=avisos['nombre_area'].replace(areas.index, areas.values)

avisos_no_one_hot= pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
avisos_no_one_hot=avisos_no_one_hot[['idaviso','tipo_de_trabajo','nivel_laboral','nombre_area']];
avisos_no_one_hot['tipo_de_trabajo']=avisos_no_one_hot['tipo_de_trabajo'].astype('category')
avisos_no_one_hot['nivel_laboral']=avisos_no_one_hot['nivel_laboral'].astype('category')
avisos_no_one_hot['nombre_area']=avisos_no_one_hot['nombre_area'].astype('category')
avisos_no_one_hot=avisos_no_one_hot.rename(columns={'nombre_area': 'nombre_area_aux'})

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas2=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2=vistas2.rename(columns={'idAviso': 'idaviso'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q        15
# 1        0005E        58
# 2        000R8        14
# 3        001XE        26
# 4        003k9        32

# %%
vistas2=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           2          28
# 1    48375       RwVdKR           1          15
# 2   169730        1KjXB           2          99
# 3   169730       2AKzxa           2           2
# 4   169730        6LJ64           1          23

# %%
vistas2['cantidad']=vistas2['cantidad_x']/vistas2['cantidad_y']
vistas2.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas=vistas2
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.071429
# 1    48375       RwVdKR  0.066667
# 2   169730        1KjXB  0.020202
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.043478

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/7.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/8.csv").sample(len(postulaciones2)//2).reset_index(drop=True))
print(len(postulaciones2))
postulaciones2
# Out:
# 9906801
#             idaviso idpostulante  sepostulo
# 0        1112389495       5NbOjG          0
# 1        1112024109      1QP841b          0
# 2        1112490884      96XQ6N9          0
# 3        1111474259      qe2QJj1          0
# 4        1112211292      KBzbBJm          0
# 5        1112328485      3NzZv26          0
# 6        1112474766      akDjWwE          0
# 7        1112312385       aZpBJW          0
# 8        1112285628      akDWj55          0
# 9        1112322843      GNd0KNN          0
# 10       1112355899      DrXPRJX          0
# 11       1112461865      8MPoBDR          0
# 12       1111673413       a1NjRN          0
# 13       1112299006      jkVWXRQ          0
# 14       1112501771      owz0YGW          0
# 15       1002543409       Ej5AAb          0
# 16       1112425310      KBrpAO2          0
# 17       1112498569      pzNMppM          0
# 18       1111866251       ZKqL85          0
# 19       1112289529      ow2awXr          0
# 20       1112493109      5mP1DWM          0
# 21       1112326017      0zd9GZ9          0
# 22       1112242315      3NQKV6Q          0
# 23       1112452417      DrlVEwW          0
# 24       1112402816      mzdk9dZ          0
# 25       1112359100      3NP46xq          0
# 26       1112410555      bOVKA32          0
# 27       1112511403      mzdlAQO          0
# 28       1111272539      6rPpNM4          0
# 29       1111591317      6rP4K13          0
# ...             ...          ...        ...
# 3302237  1112399661      pzd2NBW          0
# 3302238  1111871930      96X33bv          0
# 3302239  1111635223        NYe5L          0
# 3302240  1112460194      EzOzkM9          0
# 3302241  1112085369      pzjz82b          0
# 3302242  1112269957      3NLqoxr          0
# 3302243  1112274185      MV6v8Pe          0
# 3302244  1112170115      JBrpzNp          0
# 3302245  1112496395      DrzGWzA          0
# 3302246  1112291983      wVj5owZ          0
# 3302247  1112401047      ow2bPqj          0
# 3302248  1112288059      ZDPmVNE          0
# 3302249  1111950248      2zmLO8V          0
# 3302250  1111863380      X95j5mL          0
# 3302251  1112336938      W9OWBGR          0
# 3302252  1112437699      vVD032o          0
# 3302253  1111481194      DrJ1465          0
# 3302254  1112306501      jkd4XRY          0
# 3302255  1111857302      0zPdPAd          0
# 3302256  1112264251       5P30YN          0
# 3302257  1112421487      MVrZBKo          0
# 3302258  1112150220      PmGroEJ          0
# 3302259  1112389038      PmLXkBb          0
# 3302260  1112419288      vVDYpYP          0
# 3302261  1112344315      bO4d3pq          0
# 3302262  1112476885      5mPj52X          0
# 3302263  1112444151      akb83E0          0
# 3302264  1111729574      96zD51a          0
# 3302265  1112065899      6rP61kL          0
# 3302266  1112446933      1QrrMjN          0
#
# [9906801 rows x 3 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 16511335
# 16501973

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,avisos_no_one_hot,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostul
# 9946093                                           False                 False
# 3571511                                           False                 False
# 8417256                                           False                 False
# 12252527                                           True                 False
# 8101050                                           False                 False
# 12461306                                          False                 False
# 8103938                                           False                  True
# 343920                                            False                 False
# 15822150                                          False                 False
# 8870012                                           False                 False
# 12498997                                          False                 False
# 3374755                                           False                 False
# 881977                                            False                 False
# 2742105                                           False                  True
# 2407328                                           False                 False
# 9520192                                           False                  True
# 13133466                                          False                 False
# 3440023                                           False                 False
# 14899225                                          False                 False
# 7741384                                           False                 False
#
#           nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  \
# 9946093                 True                               False
# 3571511                False                                True
# 8417256                False                                True
# 12252527               False                               False
# 8101050                False                                True
# 12461306               False                                True
# 8103938                False                               False
# 343920                 False                                True
# 15822150               False                                True
# 8870012                False                                True
# 12498997               False                                True
# 3374755                False                                True
# 881977                 False                                True
# 2742105                False                               False
# 2407328                False                                True
# 9520192                False                               False
# 13133466               False                                True
# 3440023                False                                True
# 14899225               False                                True
# 7741384                False                                True
#
#           tipo_de_trabajo                    nivel_laboral  \
# 9946093         Part-time                             Otro
# 3571511         Full-time             Senior / Semi-Senior
# 8417256         Full-time             Senior / Semi-Senior
# 12252527      Teletrabajo  Jefe / Supervisor / Responsable
# 8101050         Full-time             Senior / Semi-Senior
# 12461306        Full-time             Senior / Semi-Senior
# 8103938         Full-time                           Junior
# 343920          Full-time             Senior / Semi-Senior
# 15822150        Full-time             Senior / Semi-Senior
# 8870012        Temporario             Senior / Semi-Senior
# 12498997        Full-time             Senior / Semi-Senior
# 3374755         Full-time             Senior / Semi-Senior
# 881977          Full-time             Senior / Semi-Senior
# 2742105         Part-time                           Junior
# 2407328         Full-time             Senior / Semi-Senior
# 9520192         Full-time                           Junior
# 13133466        Full-time             Senior / Semi-Senior
# 3440023         Full-time             Senior / Semi-Senior
# 14899225        Full-time             Senior / Semi-Senior
# 7741384         Full-time             Senior / Semi-Senior
#
#                        nombre_area_aux  cantidad
# 9946093            Educación/ Docentes       NaN
# 3571511                Soporte Técnico       NaN
# 8417256                Soporte Técnico       NaN
# 12252527                     Comercial       NaN
# 8101050   Otras Especialidades médicas  0.006270
# 12461306    Administración de Personal       NaN
# 8103938                        Compras  0.008264
# 343920           Tecnologia / Sistemas       NaN
# 15822150               Soporte Técnico       NaN
# 8870012                     Producción       NaN
# 12498997        Planeamiento comercial       NaN
# 3374755                      Selección  0.076923
# 881977                       Comercial       NaN
# 2742105                         Ventas       NaN
# 2407328            Atención al Cliente       NaN
# 9520192                      Comercial       NaN
# 13133466                    Producción       NaN
# 3440023                         Ventas       NaN
# 14899225                     Comercial       NaN
# 7741384             Farmacia comercial  0.023810
#
# [20 rows x 80 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostul
ivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  \
# 13594293                True                               False
# 7015032                False                               False
# 6860339                False                                True
# 11886238               False                                True
# 16031792               False                                True
# 13115641               False                                True
# 12824781               False                                True
# 8279130                False                                True
# 7821014                False                                True
# 15257754               False                                True
# 8124596                 True                               False
# 1081594                False                               False
# 10034721               False                               False
# 13508760                True                               False
# 11329012               False                                True
# 2251825                False                                True
# 14418611                True                               False
# 12320306               False                                True
# 14053921               False                               False
# 6612693                False                                True
#
#           tipo_de_trabajo         nivel_laboral        nombre_area_aux  \
# 13594293        Full-time                  Otro                  Salud
# 7015032         Full-time                     -  Oficios y Profesiones
# 6860339         Full-time  Senior / Semi-Senior             Producción
# 11886238        Full-time  Senior / Semi-Senior              Comercial
# 16031792        Full-time  Senior / Semi-Senior           Programación
# 13115641        Part-time  Senior / Semi-Senior  Tecnologia / Sistemas
# 12824781        Full-time  Senior / Semi-Senior           Programación
# 8279130         Full-time  Senior / Semi-Senior            Gastronomia
# 7821014         Full-time  Senior / Semi-Senior                 Ventas
# 15257754        Full-time  Senior / Semi-Senior           Programación
# 8124596         Full-time                  Otro             Producción
# 1081594         Part-time                Junior          Telemarketing
# 10034721        Full-time                     -                 Ventas
# 13508760        Full-time                  Otro                 Ventas
# 11329012        Full-time  Senior / Semi-Senior                 Ventas
# 2251825         Full-time  Senior / Semi-Senior           Capacitación
# 14418611        Por Horas                  Otro               Medicina
# 12320306        Full-time  Senior / Semi-Senior         Administración
# 14053921        Full-time                Junior              Tesorería
# 6612693         Full-time  Senior / Semi-Senior  Oficios y Profesiones
#
#           cantidad
# 13594293  0.000000
# 7015032   0.000000
# 6860339   0.000000
# 11886238  0.000000
# 16031792  0.000000
# 13115641  0.000000
# 12824781  0.000000
# 8279130   0.000000
# 7821014   0.000000
# 15257754  0.000000
# 8124596   0.000000
# 1081594   0.916667
# 10034721  0.000000
# 13508760  0.000000
# 11329012  0.000000
# 2251825   0.000000
# 14418611  0.000000
# 12320306  0.000000
# 14053921  0.250000
# 6612693   0.000000
#
# [20 rows x 80 columns]

# %%
postulaciones_por_area=postulaciones.copy()
postulaciones_por_area=postulaciones_por_area.groupby(by=['idpostulante','nombre_area_aux'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_area=postulaciones_por_area.rename(columns={'sepostulo':'postulaciones_misma_area'})
postulaciones_por_area.head()
# Out:
#   idpostulante                  nombre_area_aux  postulaciones_misma_area
# 0      0z5Dmrd                   Administración                         1
# 1      0z5Dmrd       Administración de Personal                         1
# 2      0z5Dmrd  Almacén / Depósito / Expedición                         2
# 3      0z5Dmrd              Atención al Cliente                         1
# 4      0z5Dmrd                        Auditoría                         1

# %%
postulaciones_por_nivel=postulaciones.copy()
postulaciones_por_nivel=postulaciones_por_nivel.groupby(by=['idpostulante','nivel_laboral'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_nivel=postulaciones_por_nivel.rename(columns={'sepostulo':'postulaciones_mismo_nivel'})
postulaciones_por_nivel.head()
# Out:
#   idpostulante                         nivel_laboral  \
# 0      0z5Dmrd                                     -
# 1      0z5Dmrd  Gerencia / Alta Gerencia / Dirección
# 2      0z5Dmrd                                Junior
# 3      0z5Dmrd                                  Otro
# 4      0z5Dmrd                  Senior / Semi-Senior
#
#    postulaciones_mismo_nivel
# 0                          1
# 1                          1
# 2                          4
# 3                          1
# 4                         19

# %%
postulaciones_por_tipo=postulaciones.copy()
postulaciones_por_tipo=postulaciones_por_tipo.groupby(by=['idpostulante','tipo_de_trabajo'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_tipo=postulaciones_por_tipo.rename(columns={'sepostulo':'postulaciones_mismo_tipo'})
postulaciones_por_tipo.head()
# Out:
#   idpostulante tipo_de_trabajo  postulaciones_mismo_tipo
# 0      0z5Dmrd       Full-time                        24
# 1      0z5Dmrd       Part-time                         1
# 2      0z5Dmrd     Teletrabajo                         1
# 3      0z5JW1r       Full-time                        26
# 4      0z5JW1r       Part-time                         1

# %%
postulaciones=pd.merge(postulaciones,postulaciones_por_area,on=['idpostulante','nombre_area_aux'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['postulaciones_misma_area']=postulaciones['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_nivel']=postulaciones['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_tipo']=postulaciones['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 7569875   1112267946       1DJ0Pz          1  27.0      True      False
# 7020067   1112256865      owaR4zZ          0  27.0     False       True
# 10147573  1112485611       e4GOkr          0  33.0      True      False
# 7994002   1112263288       YalrXD          0  27.0      True      False
# 10863050  1112247187      xkdOEQ0          1  55.0     False       True
# 11451145  1112471405       YRkOAX          0  30.0      True      False
# 15199584  1112297025      4rPjBqK          1  30.0     False       True
# 14505774  1112243832      8MPQEx3          0  28.0      True      False
# 7308897   1112347217      ZDPmRQ1          0  39.0      True      False
# 1700661   1112422003      2zwm9vQ          1  28.0     False       True
# 8980688   1112415796      96MNdq1          1  26.0      True      False
# 2051735   1112277689      NzeX4B5          1  27.0      True      False
# 2338165   1112365029      3NdDNdP          0  21.0     False       True
# 10980532  1112390462      mzJ60BO          0  31.0      True      False
# 4390160   1112285529      BmaN4jw          1  26.0      True      False
# 3081023   1112422220      PmGqqzJ          1  21.0     False       True
# 10649776  1112312917      wVjOAaL          0  33.0      True      False
# 9101316   1111966217      2zwePR0          0  24.0     False       True
# 4879637   1112437827      pzNvklN          1  34.0     False       True
# 11966358  1112277687      VNkJkbD          1  29.0     False       True
#
#           sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 7569875             False                 False               False
# 7020067             False                 False               False
# 10147573            False                 False               False
# 7994002             False                 False               False
# 10863050            False                 False               False
# 11451145            False                 False               False
# 15199584            False                 False               False
# 14505774            False                 False               False
# 7308897             False                 False               False
# 1700661             False                 False               False
# 8980688             False                 False               False
# 2051735             False                 False               False
# 2338165             False                 False               False
# 10980532            False                 False               False
# 4390160             False                 False               False
# 3081023             False                 False               False
# 10649776            False                 False               False
# 9101316             False                 False               False
# 4879637             False                 False               False
# 11966358            False                 False               False
#
#           Doctorado_Graduado            ...              nivel_laboral_Junior  \
# 7569875                False            ...                             False
# 7020067                False            ...                             False
# 4390160                         14                        98
# 3081023                         18                       148
# 10649776                         0                        12
# 9101316                          0                        19
# 4879637                          3                       137
# 11966358                        15                        91
#
#           postulaciones_mismo_nivel
# 7569875                           3
# 7020067                          14
# 10147573                         13
# 7994002                          12
# 10863050                         34
# 11451145                         41
# 15199584                          4
# 14505774                          2
# 7308897                          16
# 1700661                           7
# 8980688                          34
# 2051735                          19
# 2338165                           1
# 10980532                         14
# 4390160                          71
# 3081023                           8
# 10649776                         11
# 9101316                           4
# 4879637                         123
# 11966358                         70
#
# [20 rows x 83 columns]

# %%
train, test=train_test_split(postulaciones.sample(2*(len(postulaciones)//3)),test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')
features.remove('nombre_area_aux')
features.remove('tipo_de_trabajo')
features.remove('nivel_laboral')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
vistas2=0
# Out:
# Train:  10187895 Test:  536205

# %%
c=0
gc.collect()
# Out:
# 95

# %%
c=XGBClassifier(objective='binary:logistic',max_depth=18,learning_rate=0.01,subsample=0.8,colsample_bytree=0.8,n_estimators=400,silent=False,n_jobs=-1,verbose=1)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")
dt=c.fit(x_train,y_train,eval_set=[(x_test,y_test)],verbose=True,early_stopping_rounds=10)
# Out:
# [0]	validation_0-error:0.100879
# Will train until validation_0-error hasn't improved in 10 rounds.
# [1]	validation_0-error:0.094268
# [2]	validation_0-error:0.092049
# [3]	validation_0-error:0.09092
# [4]	validation_0-error:0.091564
# [5]	validation_0-error:0.091909
# [6]	validation_0-error:0.089874
# [7]	validation_0-error:0.090538
# [8]	validation_0-error:0.090204
# [9]	validation_0-error:0.090865
# [10]	validation_0-error:0.0904
# [11]	validation_0-error:0.09035
# [12]	validation_0-error:0.090294
# [13]	validation_0-error:0.090747
# [14]	validation_0-error:0.090077
# [15]	validation_0-error:0.089947
# [16]	validation_0-error:0.089656
# [17]	validation_0-error:0.08963
# [18]	validation_0-error:0.089451
# [19]	validation_0-error:0.089164
# [20]	validation_0-error:0.08905
# [21]	validation_0-error:0.089089
# [22]	validation_0-error:0.08902
# [23]	validation_0-error:0.089117
# [24]	validation_0-error:0.089048
# [25]	validation_0-error:0.089294
# [26]	validation_0-error:0.089341
# [27]	validation_0-error:0.089283
# [28]	validation_0-error:0.089292
# [29]	validation_0-error:0.089443
# [30]	validation_0-error:0.089417
# [31]	validation_0-error:0.089376
# [32]	validation_0-error:0.08922
# Stopping. Best iteration:
# [22]	validation_0-error:0.08902

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 91.07803918277526

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/XGBoost v4.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/XGBoost v4.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos_no_one_hot,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion=pd.merge(prediccion,postulaciones_por_area,on=['idpostulante','nombre_area_aux'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['postulaciones_misma_area']=prediccion['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion['postulaciones_mismo_nivel']=prediccion['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion['postulaciones_mismo_tipo']=prediccion['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  edad  sexo_FEM  sexo_MASC  \
# 97461  97218  1112498755       8VQGXL  64.0      True      False
# 32186  13761  1112054318       1apbJN  38.0      True      False
# 9665   75655  1112464172      vV3ZAD1  24.0      True      False
# 31643  10967  1111933464       EPOlj0  35.0     False       True
# 79875  88030  1112466951      owEYW4W  25.0     False       True
# 58930   7671  1111728385       8RRvEW  43.0     False       True
# 84450  33218  1112401076       epw33o  35.0      True      False
# 66447  12566  1112011933       eLZGLE  29.0     False       True
# 51346  76969  1112464276      ak4DRd9  19.0      True      False
# 15553  66540  1112459934      ZDrAYjZ  25.0      True      False
#
#        sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 97461            False                 False               False
# 32186            False                 False               False
# 9665             False                 False               False
# 31643            False                 False               False
# 79875            False                 False               False
# 58930            False                 False               False
# 84450            False                 False               False
# 66447            False                 False               False
# 51346            False                 False               False
# 15553            False                 False               False
#
#        Doctorado_Graduado            ...              nivel_laboral_Junior  \
# 97461               False            ...                             False
# 32186               False            ...                             False
# 9665                False            ...                              True
# 31643               False            ...                             False
# 79875               False            ...                             False
# 58930               False            ...                              True
# 84450               False            ...                             False
# 66447               False            ...                             False
# 51346               False            ...                             False
# 15553               False            ...                             False
#
#        nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  \
# 97461                True                               False
# 32186               False                               False
# 9665                False                               False
# 31643               False                                True
# 79875               False                                True
# 58930               False                               False
# 84450               False                                True
# 66447               False                                True
# 51346               False                               False
# 15553               False                                True
#
#        tipo_de_trabajo         nivel_laboral         nombre_area_aux  \
# 97461        Full-time                  Otro                  Ventas
# 32186        Full-time                     -               Comercial
# 9665         Full-time                Junior               Selección
# 31643        Full-time  Senior / Semi-Senior  Ingeniería de Procesos
# 79875        Full-time  Senior / Semi-Senior               Comercial
# 58930        Full-time                Junior          Administración
# 84450        Full-time  Senior / Semi-Senior            Capacitación
# 66447        Full-time  Senior / Semi-Senior             Laboratorio
# 51346        Part-time                     -           Telemarketing
# 15553        Full-time  Senior / Semi-Senior           Recepcionista
#
#        cantidad  postulaciones_misma_area  postulaciones_mismo_tipo  \
# 97461  0.000000                       1.0                      17.0
# 32186  0.000000                       0.0                      23.0
# 9665   0.000000                       0.0                      18.0
# 31643  0.000000                       0.0                      18.0
# 79875  0.034483                       6.0                      29.0
# 58930  0.000000                       1.0                      22.0
# 84450  0.000000                       0.0                      21.0
# 66447  0.000000                       0.0                      19.0
# 51346  0.003185                      11.0                      84.0
# 15553  0.000000                       0.0                      20.0
#
#        postulaciones_mismo_nivel
# 97461                        2.0
# 32186                        0.0
# 9665                         6.0
# 31643                       14.0
# 79875                       24.0
# 58930                        2.0
# 84450                       15.0
# 66447                       17.0
# 51346                       11.0
# 15553                       12.0
#
# [10 rows x 83 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.63626504, 0.36373493],
#        [0.512385  , 0.48761496],
#        [0.6256599 , 0.37434012],
#        ...,
#        [0.63166684, 0.36833316],
#        [0.6316451 , 0.3683549 ],
#        [0.6350863 , 0.3649137 ]], dtype=float32)

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  edad  sexo_FEM  sexo_MASC  sexo_NO_DECLARA  \
# 0   0   739260       6M9ZQR  42.0      True      False            False
# 1   1   739260       6v1xdL  30.0     False       True            False
# 2   2   739260       ezRKm9  36.0      True      False            False
# 3   3   758580       1Q35ej  68.0     False       True            False
# 4   4   758580       EAN4J6  32.0      True      False            False
#
#    Doctorado_Abandonado  Doctorado_En Curso  Doctorado_Graduado    ...      \
# 0                 False               False                True    ...
# 1                 False               False               False    ...
# 2                 False               False               False    ...
# 3                 False               False               False    ...
# 4                 False               False               False    ...
#
#    nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  tipo_de_trabajo  \
# 0               False                               False        Full-time
# 1               False                               False        Full-time
# 2               False                               False        Full-time
# 3                True                               False        Full-time
# 4                True                               False        Full-time
#
#                      nivel_laboral        nombre_area_aux  cantidad  \
# 0  Jefe / Supervisor / Responsable              Comercial       0.0
# 1  Jefe / Supervisor / Responsable              Comercial       0.0
# 2  Jefe / Supervisor / Responsable              Comercial       0.0
# 3                             Otro  Tecnologia / Sistemas       0.0
# 4                             Otro  Tecnologia / Sistemas       0.0
#
#    postulaciones_misma_area  postulaciones_mismo_tipo  \
# 0                       0.0                      16.0
# 1                       5.0                      62.0
# 2                       3.0                      16.0
# 3                       0.0                      21.0
# 4                       1.0                      15.0
#
#    postulaciones_mismo_nivel  sepostulo
# 0                        0.0   0.363735
# 1                        0.0   0.487615
# 2                        1.0   0.374340
# 3                        0.0   0.368996
# 4                        2.0   0.361764
#
# [5 rows x 84 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.drop(['tipo_de_trabajo','nivel_laboral','nombre_area_aux'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.363735
# 1   1   0.487615
# 2   2   0.374340
# 3   3   0.368996
# 4   4   0.361764

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion38.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.4867469890096784
