# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')
avisos['denominacion_empresa']=avisos['denominacion_empresa'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#       idaviso idpostulante
# 0  1111780242      YjVJQ6Z
# 1  1112263876      BmVpYoR
# 2  1112327963      wVkBzZd
# 3  1112318643      OqmP9pv
# 4  1111903673      DrpbXDP

# %%
vistas_por_area=vistas.copy()
vistas_por_area['vistas_por_area']=0;
vistas_por_area=pd.merge(vistas_por_area,avisos,on='idaviso', how='left')
vistas_por_area=vistas_por_area.groupby(['idpostulante','nombre_area'],as_index=False).agg({'vistas_por_area':'count'})
vistas_por_area.head()
# Out:
#   idpostulante            nombre_area  vistas_por_area
# 0        0005E  Tecnologia / Sistemas                2
# 1        00Lkv      Comercio Exterior                2
# 2        00dMd      Comercio Exterior                4
# 3        01QAq           Contabilidad                1
# 4        021OM      Comercio Exterior                5

# %%
vistas_por_nivel=vistas.copy()
vistas_por_nivel['vistas_por_nivel']=0;
vistas_por_nivel=pd.merge(vistas_por_nivel,avisos,on='idaviso', how='left')
vistas_por_nivel=vistas_por_nivel.groupby(['idpostulante','nivel_laboral'],as_index=False).agg({'vistas_por_nivel':'count'})
vistas_por_nivel.head()
# Out:
#   idpostulante nivel_laboral  vistas_por_nivel
# 0        0005E          Otro                 2
# 1        00Lkv          Otro                 2
# 2        00dMd          Otro                 4
# 3        01QAq          Otro                 1
# 4        021OM          Otro                 5

# %%
vistas_por_tipo=vistas.copy()
vistas_por_tipo['vistas_por_tipo']=0;
vistas_por_tipo=pd.merge(vistas_por_tipo,avisos,on='idaviso', how='left')
vistas_por_tipo=vistas_por_tipo.groupby(['idpostulante','tipo_de_trabajo'],as_index=False).agg({'vistas_por_tipo':'count'})
vistas_por_tipo.head()
# Out:
#   idpostulante tipo_de_trabajo  vistas_por_tipo
# 0        0005E       Full-time                2
# 1        00Lkv       Full-time                2
# 2        00dMd       Full-time                4
# 3        01QAq       Full-time                1
# 4        021OM       Full-time                5

# %%
vistas['cantidad']=0
vistas2=vistas.groupby(['idaviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q        15
# 1        0005E        58
# 2        000R8        14
# 3        001XE        26
# 4        003k9        32

# %%
vistas3=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           2          28
# 1    48375       RwVdKR           1          15
# 2   169730        1KjXB           2          99
# 3   169730       2AKzxa           2           2
# 4   169730        6LJ64           1          23

# %%
vistas3['cantidad']=vistas3['cantidad_x']/vistas3['cantidad_y']
vistas3.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.071429
# 1    48375       RwVdKR  0.066667
# 2   169730        1KjXB  0.020202
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.043478

# %%
vistas=vistas.rename(columns={'cantidad': 'vistas_postulante'})
vistas2=vistas2.rename(columns={'cantidad': 'vistas_al_aviso'})

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/7.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/8.csv").sample(len(postulaciones2)//2).reset_index(drop=True))
print(len(postulaciones2))
postulaciones2
# Out:
# 9906801
#             idaviso idpostulante  sepostulo
# 0        1112389495       5NbOjG          0
# 1        1112024109      1QP841b          0
# 2        1112490884      96XQ6N9          0
# 3        1111474259      qe2QJj1          0
# 4        1112211292      KBzbBJm          0
# 5        1112328485      3NzZv26          0
# 6        1112474766      akDjWwE          0
# 7        1112312385       aZpBJW          0
# 8        1112285628      akDWj55          0
# 9        1112322843      GNd0KNN          0
# 10       1112355899      DrXPRJX          0
# 11       1112461865      8MPoBDR          0
# 12       1111673413       a1NjRN          0
# 13       1112299006      jkVWXRQ          0
# 14       1112501771      owz0YGW          0
# 15       1002543409       Ej5AAb          0
# 16       1112425310      KBrpAO2          0
# 17       1112498569      pzNMppM          0
# 18       1111866251       ZKqL85          0
# 19       1112289529      ow2awXr          0
# 20       1112493109      5mP1DWM          0
# 21       1112326017      0zd9GZ9          0
# 22       1112242315      3NQKV6Q          0
# 23       1112452417      DrlVEwW          0
# 24       1112402816      mzdk9dZ          0
# 25       1112359100      3NP46xq          0
# 26       1112410555      bOVKA32          0
# 27       1112511403      mzdlAQO          0
# 28       1111272539      6rPpNM4          0
# 29       1111591317      6rP4K13          0
# ...             ...          ...        ...
# 3302237  1001378303       aNb9Jq          0
# 3302238  1112460917       edqAj8          0
# 3302239  1112406702      mzjZDVE          0
# 3302240  1112473131       EMwow0          0
# 3302241  1112413200      GNZ8V48          0
# 3302242  1112322187      pzdjokr          0
# 3302243  1112413164       EDG9oz          0
# 3302244  1112019656      KBrxkXd          0
# 3302245  1112410322      96WBY09          0
# 3302246  1112480641      bOJQNwE          0
# 3302247  1112478031       Y1A8NY          0
# 3302248  1112440104      X95JkkL          0
# 3302249  1112441060      Yj5XZXr          0
# 3302250  1112470468       8ArvR3          0
# 3302251  1112274751      YjAXxAD          0
# 3302252  1112458666      2zkjp2Y          0
# 3302253  1112269749      zvxxo0E          0
# 3302254  1112383695       EDPYJ9          0
# 3302255  1112220209      Yj51qxw          0
# 3302256  1112264956      PmVz1Q0          0
# 3302257  1112364783      Rz9NxVx          0
# 3302258  1112445738      3Nd0xxx          0
# 3302259  1112428426      A3618eY          0
# 3302260  1112365178       1pkqWR          0
# 3302261  1112390572      bOZeAaB          0
# 3302262  1112309254      GNO5Opv          0
# 3302263  1112264713       Y1lwEw          0
# 3302264  1112357106      ow2MkVk          0
# 3302265  1112489727      wVjdajp          0
# 3302266  1112505304      Nzr429l          0
#
# [9906801 rows x 3 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 16511335
# 16501935

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas2,on=['idaviso','idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas3,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo        sexo   edad Doctorado  \
# 10849515  1112343777      8Mrrd3z          1        MASC   44.0         -
# 13441158  1111951329      RzPLjaq          0         FEM   26.0         -
# 5657512   1112351903      Bm5bEma          0        MASC   33.0         -
# 3969067   1111228402      akjXJbE          1         FEM   28.0         -
# 8809392   1112299492      vVjaVRP          0         FEM   47.0  Graduado
# 6787466   1112288123      xkdAJp6          1  NO_DECLARA  200.0         -
# 7348544   1112421993      2zN9Q5a          1         FEM   29.0         -
# 4776528   1112424887      Nzrl6zD          1         FEM   32.0         -
# 11677540  1112247230      2zP00rx          0        MASC   53.0         -
# 1914756   1112426244      LNMrd5Q          0         FEM   30.0         -
# 7726423   1112432423      0zPvvPr          1         FEM   25.0         -
# 7654800   1111364281      X9k6mxO          0         FEM   21.0         -
# 10631701  1112400071        e0WQp          0        MASC   52.0         -
# 1765338   1112431304      kPX1B01          1         FEM   34.0         -
# 15269686  1112447925      wVjldVZ          0        MASC   38.0         -
# 8875291   1112452402       8ozYZW          0         FEM   28.0         -
# 2237266   1112433569       YAGzXr          1         FEM   34.0         -
# 11592741  1112460142      qe2e6zN          1         FEM   28.0         -
# 4178540   1111934356      Nzr6l35          1         FEM   28.0         -
# 8836464   1112371232      xkPWzzz          0         FEM   24.0         -
#
#          Master      Otro  Posgrado Secundario    ...    capacitacion  \
# 10849515      -         -         -          -    ...           False
# 13441158      -         -         -   Graduado    ...           False
# 5657512       -         -         -   Graduado    ...           False
# 3969067       -         -         -   Graduado    ...           False
# 8809392       -         -  Graduado   Graduado    ...           False
# 6787466       -         -         -          -    ...            True
# 7348544       -         -         -   Graduado    ...           False
# 4776528       -         -         -   Graduado    ...           False
# 11677540      -         -         -          -    ...           False
# 1914756       -  Graduado         -   Graduado    ...           False
# 7726423       -         -         -   Graduado    ...           False
# 7654800       -         -         -          -    ...           False
# 10631701      -  Graduado         -   Graduado    ...           False
# 1765338       -         -  Graduado          -    ...           False
# 15269686      -         -  Graduado   Graduado    ...           False
# 8875291       -         -         -          -    ...           False
# 2237266       -         -         -   Graduado    ...            True
# 11592741      -         -         -   Graduado    ...           False
# 4178540       -         -         -   Graduado    ...           False
# 8836464       -         -         -   Graduado    ...           False
#
#          remuneracion_pretendida graduados estudiantes  \
# 10849515                   False     False       False
# 13441158                   False     False       False
# 5657512                    False     False       False
# 3969067                    False     False       False
# 8809392                    False     False       False
# 6787466                    False     False       False
# 7348544                    False     False       False
# 4776528                    False     False       False
# 11677540                   False     False       False
# 1914756                    False     False       False
# 7726423                    False     False       False
# 7654800                    False     False       False
# 10631701                   False     False       False
# 1765338                    False     False       False
# 15269686                   False      True        True
# 8875291                    False      True        True
# 2237266                    False     False       False
# 11592741                   False     False       False
# 4178540                    False     False        True
# 8836464                    False     False       False
#
#          conocimientos_especificos buen_ambiente discriminacion  \
# 10849515                      True         False           True
# 13441158                     False         False          False
# 5657512                      False         False          False
# 3969067                      False         False          False
# 8809392                      False         False          False
# 6787466                      False         False          False
# 7348544                      False         False          False
# 4776528                      False         False          False
# 11677540                     False         False          False
# 1914756                      False         False          False
# 7726423                      False         False          False
# 7654800                      False         False          False
# 10631701                     False         False          False
# 1765338                      False         False          False
# 15269686                     False         False          False
# 8875291                      False         False          False
# 2237266                      False          True          False
# 11592741                     False         False          False
# 4178540                       True         False           True
# 8836464                      False         False          False
#
#          vistas_postulante  vistas_al_aviso  cantidad
# 10849515             185.0              NaN       NaN
# 13441158              18.0              NaN       NaN
# 5657512               62.0              NaN       NaN
# 3969067               94.0              NaN       NaN
# 8809392               26.0              NaN       NaN
# 6787466               16.0              NaN       NaN
# 7348544               96.0              4.0  0.041667
# 4776528               23.0              NaN       NaN
# 11677540               7.0              NaN       NaN
# 1914756               22.0              NaN       NaN
# 7726423               42.0              1.0  0.023810
# 7654800                NaN              NaN       NaN
# 10631701               2.0              NaN       NaN
# 1765338               73.0              1.0  0.013699
# 15269686               NaN              NaN       NaN
# 8875291               31.0              NaN       NaN
# 2237266               49.0              1.0  0.020408
# 11592741             164.0              1.0  0.006098
# 4178540                3.0              NaN       NaN
# 8836464               21.0              NaN       NaN
#
# [20 rows x 38 columns]

# %%
postulaciones['cantidad']=postulaciones['cantidad'].fillna(0)
postulaciones['vistas_postulante']=postulaciones['vistas_postulante'].fillna(0)
postulaciones['vistas_al_aviso']=postulaciones['vistas_al_aviso'].fillna(0)
postulaciones['lo_vio']=(postulaciones['vistas_al_aviso']>0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 11855632  1111692660       Z6QOlP          0  MASC  32.0         -      -
# 14929819  1112443846      Rzreo5Y          0   FEM  20.0         -      -
# 8773798   1112393325      qewRpox          1  MASC  28.0         -      -
# 4306343   1112507363      Eze1Baz          0  MASC  24.0         -      -
# 14694841  1112423670      ow2lzDZ          1  MASC  40.0         -      -
# 9590750   1112422288      kPLjE60          0   FEM  34.0         -      -
# 5245362   1112153851       EWAwXN          0   FEM  33.0         -      -
# 1330891   1112228541      ak5mkBq          0   FEM  19.0         -      -
# 6537613   1112104772       ZjYlk1          0   FEM  39.0         -      -
# 4900049   1112362740      rmdJdAx          1   FEM  28.0         -      -
# 11714454  1111472619       5rMzlz          0  MASC  58.0         -      -
# 9991098   1112412272      pz9ELGw          1   FEM  29.0         -      -
# 12638464  1112389257      8MBY56M          1  MASC  20.0         -      -
# 3924179   1112315832      MVa9Edv          1  MASC  26.0         -      -
# 4200063   1112452076      pzjVjxw          0  MASC  24.0         -      -
# 6819258   1112420529      GNZMj6b          1   FEM  24.0         -      -
# 6636380   1112410345      Bm5mo62          1  MASC  28.0         -      -
# 5379305   1112252487      GNOj23K          0  MASC  28.0         -      -
# 3807454   1112393194      NzMa5xJ          1   FEM  24.0         -      -
# 969057    1112094756      6rZRDQl          1  MASC  25.0         -      -
#
#               Otro Posgrado Secundario   ...   remuneracion_pretendida  \
# 11855632         -        -   Graduado   ...                     False
# 14929819         -        -   Graduado   ...                     False
# 8773798          -        -   Graduado   ...                     False
# 4306343          -        -   Graduado   ...                     False
# 14694841         -        -   Graduado   ...                     False
# 9590750          -        -   Graduado   ...                     False
# 5245362          -        -          -   ...                     False
# 1330891   Graduado        -   Graduado   ...                     False
# 6537613          -        -          -   ...                     False
# 4900049          -        -   Graduado   ...                     False
# 11714454         -        -   Graduado   ...                      True
# 9991098   Graduado        -   Graduado   ...                     False
# 12638464         -        -          -   ...                     False
# 3924179          -        -   Graduado   ...                     False
# 4200063          -        -   Graduado   ...                     False
# 6819258          -        -          -   ...                     False
# 6636380          -        -   Graduado   ...                     False
# 5379305          -        -   Graduado   ...                     False
# 3807454          -        -   Graduado   ...                     False
# 969057           -        -   Graduado   ...                     False
#
#          graduados estudiantes conocimientos_especificos buen_ambiente  \
# 11855632     False       False                     False         False
# 14929819     False       False                      True         False
# 8773798      False       False                     False         False
# 4306343      False       False                     False         False
# 14694841     False       False                     False         False
# 9590750      False        True                     False         False
# 5245362      False       False                     False         False
# 1330891      False        True                     False         False
# 6537613       True        True                     False         False
# 4900049       True        True                     False         False
# 11714454     False       False                     False         False
# 9991098      False       False                     False         False
# 12638464     False       False                      True         False
# 3924179       True        True                      True         False
# 4200063       True        True                     False         False
# 6819258      False       False                     False         False
# 6636380      False       False                     False         False
# 5379305      False       False                     False         False
# 3807454      False       False                     False         False
# 969057       False       False                     False         False
#
#          discriminacion vistas_postulante vistas_al_aviso  cantidad  lo_vio
# 11855632          False              68.0             0.0  0.000000   False
# 14929819           True               2.0             0.0  0.000000   False
# 8773798           False              97.0             0.0  0.000000   False
# 4306343           False               0.0             0.0  0.000000   False
# 14694841          False             186.0             2.0  0.010753    True
# 9590750           False               0.0             0.0  0.000000   False
# 5245362           False              71.0             0.0  0.000000   False
# 1330891           False               2.0             0.0  0.000000   False
# 6537613           False               0.0             0.0  0.000000   False
# 4900049           False               0.0             0.0  0.000000   False
# 11714454          False               0.0             0.0  0.000000   False
# 9991098           False              67.0             1.0  0.014925    True
# 12638464           True              23.0             0.0  0.000000   False
# 3924179            True              38.0             0.0  0.000000   False
# 4200063           False               8.0             0.0  0.000000   False
# 6819258           False              33.0             2.0  0.060606    True
# 6636380            True             294.0             0.0  0.000000   False
# 5379305           False               2.0             0.0  0.000000   False
# 3807454           False               2.0             0.0  0.000000   False
# 969057            False              66.0             0.0  0.000000   False
#
# [20 rows x 39 columns]

# %%
postulaciones_por_area=postulaciones.copy()
postulaciones_por_area=postulaciones_por_area.groupby(by=['idpostulante','nombre_area'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_area=postulaciones_por_area.rename(columns={'sepostulo':'postulaciones_misma_area'})
postulaciones_por_area.head()
# Out:
#   idpostulante                      nombre_area  postulaciones_misma_area
# 0      0z5Dmrd                   Abastecimiento                         1
# 1      0z5Dmrd                   Administración                         1
# 2      0z5Dmrd  Almacén / Depósito / Expedición                         2
# 3      0z5Dmrd              Atención al Cliente                         1
# 4      0z5Dmrd                        Auditoría                         1

# %%
postulaciones_por_nivel=postulaciones.copy()
postulaciones_por_nivel=postulaciones_por_nivel.groupby(by=['idpostulante','nivel_laboral'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_nivel=postulaciones_por_nivel.rename(columns={'sepostulo':'postulaciones_mismo_nivel'})
postulaciones_por_nivel.head()
# Out:
#   idpostulante                         nivel_laboral  \
# 0      0z5Dmrd                                     -
# 1      0z5Dmrd  Gerencia / Alta Gerencia / Dirección
# 2      0z5Dmrd                                Junior
# 3      0z5Dmrd                                  Otro
# 4      0z5Dmrd                  Senior / Semi-Senior
#
#    postulaciones_mismo_nivel
# 0                          1
# 1                          1
# 2                          3
# 3                          1
# 4                         16

# %%
postulaciones_por_tipo=postulaciones.copy()
postulaciones_por_tipo=postulaciones_por_tipo.groupby(by=['idpostulante','tipo_de_trabajo'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_tipo=postulaciones_por_tipo.rename(columns={'sepostulo':'postulaciones_mismo_tipo'})
postulaciones_por_tipo.head()
# Out:
#   idpostulante tipo_de_trabajo  postulaciones_mismo_tipo
# 0      0z5Dmrd       Full-time                        21
# 1      0z5Dmrd       Part-time                         1
# 2      0z5JW1r       Full-time                        27
# 3      0z5JW1r       Part-time                         1
# 4      0z5VvGv       Full-time                        55

# %%
postulaciones=pd.merge(postulaciones,postulaciones_por_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['postulaciones_misma_area']=postulaciones['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_nivel']=postulaciones['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_tipo']=postulaciones['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones=pd.merge(postulaciones,vistas_por_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,vistas_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,vistas_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['vistas_por_area']=postulaciones['vistas_por_area'].fillna(0)
postulaciones['vistas_por_tipo']=postulaciones['vistas_por_tipo'].fillna(0)
postulaciones['vistas_por_nivel']=postulaciones['vistas_por_tipo'].fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo        sexo   edad Doctorado  \
# 9298134   1112460516       1j6XeL          0        MASC   32.0         -
# 11113825  1112337758      Nzl4p6D          0         FEM   27.0         -
# 6436805   1112342984      NzrlMpD          1        MASC   29.0         -
# 13413847  1110917932      jkVKOaj          0        MASC   36.0         -
# 9078874   1112290423      EzEa1N8          0         FEM   31.0         -
# 12728142  1112369484      wVkeA1Z          0  NO_DECLARA  200.0         -
# 13655153  1112464572      Yj5MBr1          0  NO_DECLARA  200.0         -
# 13011879  1112368697      3NP4NaJ          0  NO_DECLARA  200.0         -
# 13066594  1112087663      qekO6XL          0         FEM   29.0         -
# 15410904  1112417925       ekB0a9          0        MASC   37.0         -
# 1329598   1112414527      3NPNlAr          0        MASC   25.0         -
# 8778937   1112399812      MVe65pN          0        MASC   22.0         -
# 16007205  1112189896      KBdp3OA          0        MASC   35.0         -
# 14092840  1112254572      mz51Ka9          1        MASC   24.0         -
# 78312     1112345203      dYJxRrM          1         FEM   22.0         -
# 7128588   1112455080      vV98qOX          1         FEM   20.0         -
# 9685583   1112350270      Yj53ppD          1        MASC   30.0         -
# 1185835   1112425798      6rLlNL3          0        MASC   30.0         -
# 7132547   1112467175      ak52dpm          1         FEM   19.0         -
# 14694266  1112423670      Bm5X6ow          1         FEM   19.0         -
#
#          Master      Otro Posgrado Secundario        ...         \
# 9298134       -         -        -   Graduado        ...
# 11113825      -         -        -          -        ...
# 6436805       -         -        -   Graduado        ...
# 13413847      -         -        -          -        ...
# 9078874       -         -        -          -        ...
# 12728142      -         -        -          -        ...
# 13655153      -         -        -          -        ...
# 13011879      -         -        -          -        ...
# 13066594      -         -        -          -        ...
# 15410904      -         -        -   Graduado        ...
# 1329598       -         -        -          -        ...
# 8778937       -         -        -   Graduado        ...
# 16007205      -         -        -   Graduado        ...
# 14092840      -         -        -          -        ...
# 78312         -  En Curso        -   Graduado        ...
# 7128588       -         -        -   Graduado        ...
# 9685583       -         -        -          -        ...
# 1185835       -         -        -   Graduado        ...
# 7132547       -  Graduado        -   Graduado        ...
# 14694266      -         -        -   Graduado        ...
#
#          vistas_postulante vistas_al_aviso  cantidad lo_vio  \
# 9298134                0.0             0.0  0.000000  False
# 11113825               4.0             0.0  0.000000  False
# 6436805                0.0             0.0  0.000000  False
# 13413847               0.0             0.0  0.000000  False
# 9078874               21.0             0.0  0.000000  False
# 12728142               0.0             0.0  0.000000  False
# 13655153              40.0             0.0  0.000000  False
# 13011879               8.0             0.0  0.000000  False
# 13066594              10.0             0.0  0.000000  False
# 15410904              23.0             0.0  0.000000  False
# 1329598                0.0             0.0  0.000000  False
# 8778937                0.0             0.0  0.000000  False
# 16007205              26.0             0.0  0.000000  False
# 14092840               0.0             0.0  0.000000  False
# 78312                 36.0             1.0  0.027778   True
# 7128588               43.0             1.0  0.023256   True
# 9685583               98.0             0.0  0.000000  False
# 1185835                7.0             0.0  0.000000  False
# 7132547              100.0             1.0  0.010000   True
# 14694266              61.0             2.0  0.032787   True
#
#          postulaciones_misma_area postulaciones_mismo_tipo  \
# 9298134                         0                       25
# 11113825                        0                       22
# 6436805                        68                      116
# 13413847                        0                       17
# 9078874                         0                       16
# 12728142                        1                       15
# 13655153                        0                       35
# 13011879                        0                       17
# 13066594                        0                       18
# 15410904                        0                       49
# 1329598                         1                       44
# 8778937                         0                       19
# 16007205                        6                      120
# 14092840                       24                       81
# 78312                           8                       35
# 7128588                        16                       49
# 9685583                        10                      267
# 1185835                         0                        0
# 7132547                         0                        6
# 14694266                       19                       61
#
#          postulaciones_mismo_nivel vistas_por_area  vistas_por_tipo  \
# 9298134                         16             0.0              0.0
# 11113825                        17             0.0              2.0
# 6436805                         84             0.0              0.0
# 13413847                        12             0.0              0.0
# 9078874                          0             0.0             12.0
# 12728142                         1             0.0              0.0
# 13655153                         3             0.0             40.0
# 13011879                        13             0.0              6.0
# 13066594                         1             0.0             10.0
# 15410904                        37             0.0             20.0
# 1329598                         26             0.0              0.0
# 8778937                          9             0.0              0.0
# 16007205                        91             2.0             23.0
# 14092840                        74             0.0              0.0
# 78312                           12             8.0             34.0
# 7128588                         20             8.0             22.0
# 9685583                        194             1.0             97.0
# 1185835                         15             0.0              0.0
# 7132547                          9             3.0             13.0
# 14694266                        61             8.0             40.0
#
#           vistas_por_nivel
# 9298134                0.0
# 11113825               2.0
# 6436805                0.0
# 13413847               0.0
# 9078874               12.0
# 12728142               0.0
# 13655153              40.0
# 13011879               6.0
# 13066594              10.0
# 15410904              20.0
# 1329598                0.0
# 8778937                0.0
# 16007205              23.0
# 14092840               0.0
# 78312                 34.0
# 7128588               22.0
# 9685583               97.0
# 1185835                0.0
# 7132547               13.0
# 14694266              40.0
#
# [20 rows x 45 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
# Out:
# Train:  15281806 Test:  804306

# %%
gc.collect()
# Out:
# 312

# %%
c=lgb.LGBMClassifier(learning_rate=0.05,objective='binary',num_leaves=6000,max_depth=13,n_estimators=1200,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train,eval_set=[(x_test,y_test)],verbose=True,early_stopping_rounds=1)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")
# Out:
# [1]	valid_0's binary_logloss: 0.659343
# Training until validation scores don't improve for 1 rounds.
# [2]	valid_0's binary_logloss: 0.629218
# [3]	valid_0's binary_logloss: 0.600262
# [4]	valid_0's binary_logloss: 0.573202
# [5]	valid_0's binary_logloss: 0.548646
# [6]	valid_0's binary_logloss: 0.526635
# [7]	valid_0's binary_logloss: 0.506085
# [8]	valid_0's binary_logloss: 0.486559
# [9]	valid_0's binary_logloss: 0.469045
# [10]	valid_0's binary_logloss: 0.453013
# [11]	valid_0's binary_logloss: 0.437395
# [12]	valid_0's binary_logloss: 0.422861
# [13]	valid_0's binary_logloss: 0.409518
# [14]	valid_0's binary_logloss: 0.398238
# [15]	valid_0's binary_logloss: 0.387319
# [16]	valid_0's binary_logloss: 0.37777
# [17]	valid_0's binary_logloss: 0.367286
# [18]	valid_0's binary_logloss: 0.358466
# [19]	valid_0's binary_logloss: 0.349237
# [20]	valid_0's binary_logloss: 0.341394
# [21]	valid_0's binary_logloss: 0.333264
# [22]	valid_0's binary_logloss: 0.325725
# [23]	valid_0's binary_logloss: 0.319287
# [24]	valid_0's binary_logloss: 0.313383
# [25]	valid_0's binary_logloss: 0.306827
# [26]	valid_0's binary_logloss: 0.300756
# [27]	valid_0's binary_logloss: 0.295011
# [28]	valid_0's binary_logloss: 0.290725
# [29]	valid_0's binary_logloss: 0.286115
# [30]	valid_0's binary_logloss: 0.281271
# [31]	valid_0's binary_logloss: 0.277303
# [32]	valid_0's binary_logloss: 0.273038
# [33]	valid_0's binary_logloss: 0.269433
# [34]	valid_0's binary_logloss: 0.265645
# [35]	valid_0's binary_logloss: 0.262139
# [36]	valid_0's binary_logloss: 0.259068
# [37]	valid_0's binary_logloss: 0.25621
# [38]	valid_0's binary_logloss: 0.253592
# [39]	valid_0's binary_logloss: 0.250699
# [40]	valid_0's binary_logloss: 0.24793
# [41]	valid_0's binary_logloss: 0.245295
# [42]	valid_0's binary_logloss: 0.242688
# [43]	valid_0's binary_logloss: 0.240182
# [44]	valid_0's binary_logloss: 0.237846
# [45]	valid_0's binary_logloss: 0.235653
# [46]	valid_0's binary_logloss: 0.233652
# [47]	valid_0's binary_logloss: 0.231547
# [48]	valid_0's binary_logloss: 0.229535
# [49]	valid_0's binary_logloss: 0.227763
# [50]	valid_0's binary_logloss: 0.22603
# [51]	valid_0's binary_logloss: 0.224432
# [52]	valid_0's binary_logloss: 0.222749
# [53]	valid_0's binary_logloss: 0.221324
# [54]	valid_0's binary_logloss: 0.219903
# [55]	valid_0's binary_logloss: 0.218649
# [56]	valid_0's binary_logloss: 0.21738
# [57]	valid_0's binary_logloss: 0.216222
# [58]	valid_0's binary_logloss: 0.215267
# [59]	valid_0's binary_logloss: 0.214025
# [60]	valid_0's binary_logloss: 0.213046
# [61]	valid_0's binary_logloss: 0.211987
# [62]	valid_0's binary_logloss: 0.211092
# [63]	valid_0's binary_logloss: 0.210106
# [64]	valid_0's binary_logloss: 0.209248
# [65]	valid_0's binary_logloss: 0.208598
# [66]	valid_0's binary_logloss: 0.207951
# [67]	valid_0's binary_logloss: 0.207077
# [68]	valid_0's binary_logloss: 0.206161
# [69]	valid_0's binary_logloss: 0.205439
# [70]	valid_0's binary_logloss: 0.204731
# [71]	valid_0's binary_logloss: 0.204014
# [72]	valid_0's binary_logloss: 0.203269
# [73]	valid_0's binary_logloss: 0.202676
# [74]	valid_0's binary_logloss: 0.202084
# [75]	valid_0's binary_logloss: 0.20163
# [76]	valid_0's binary_logloss: 0.201064
# [77]	valid_0's binary_logloss: 0.200548
# [78]	valid_0's binary_logloss: 0.199978
# [79]	valid_0's binary_logloss: 0.199516
# [80]	valid_0's binary_logloss: 0.199074
# [81]	valid_0's binary_logloss: 0.198736
# [82]	valid_0's binary_logloss: 0.198308
# [83]	valid_0's binary_logloss: 0.19769
# [84]	valid_0's binary_logloss: 0.197271
# [85]	valid_0's binary_logloss: 0.19688
# [86]	valid_0's binary_logloss: 0.196509
# [87]	valid_0's binary_logloss: 0.196165
# [88]	valid_0's binary_logloss: 0.195731
# [89]	valid_0's binary_logloss: 0.195402
# [90]	valid_0's binary_logloss: 0.194951
# [91]	valid_0's binary_logloss: 0.19451
# [92]	valid_0's binary_logloss: 0.194199
# [93]	valid_0's binary_logloss: 0.193917
# [94]	valid_0's binary_logloss: 0.193686
# [95]	valid_0's binary_logloss: 0.193336
# [96]	valid_0's binary_logloss: 0.193012
# [97]	valid_0's binary_logloss: 0.192758
# [98]	valid_0's binary_logloss: 0.192552
# [99]	valid_0's binary_logloss: 0.192377
# [100]	valid_0's binary_logloss: 0.192209
# [101]	valid_0's binary_logloss: 0.191995
# [102]	valid_0's binary_logloss: 0.191804
# [103]	valid_0's binary_logloss: 0.191627
# [104]	valid_0's binary_logloss: 0.191246
# [105]	valid_0's binary_logloss: 0.191038
# [106]	valid_0's binary_logloss: 0.190919
# [107]	valid_0's binary_logloss: 0.190808
# [108]	valid_0's binary_logloss: 0.190659
# [109]	valid_0's binary_logloss: 0.190515
# [110]	valid_0's binary_logloss: 0.190196
# [111]	valid_0's binary_logloss: 0.190077
# [112]	valid_0's binary_logloss: 0.189869
# [113]	valid_0's binary_logloss: 0.189819
# [114]	valid_0's binary_logloss: 0.189629
# [115]	valid_0's binary_logloss: 0.189549
# [116]	valid_0's binary_logloss: 0.18922
# [117]	valid_0's binary_logloss: 0.189145
# [118]	valid_0's binary_logloss: 0.18909
# [119]	valid_0's binary_logloss: 0.188764
# [120]	valid_0's binary_logloss: 0.188716
# [121]	valid_0's binary_logloss: 0.188426
# [122]	valid_0's binary_logloss: 0.188174
# [123]	valid_0's binary_logloss: 0.188135
# [124]	valid_0's binary_logloss: 0.188098
# [125]	valid_0's binary_logloss: 0.188062
# [126]	valid_0's binary_logloss: 0.18802
# [127]	valid_0's binary_logloss: 0.187987
# [128]	valid_0's binary_logloss: 0.187955
# [129]	valid_0's binary_logloss: 0.187921
# [130]	valid_0's binary_logloss: 0.187871
# [131]	valid_0's binary_logloss: 0.18784
# [132]	valid_0's binary_logloss: 0.18781
# [133]	valid_0's binary_logloss: 0.187563
# [134]	valid_0's binary_logloss: 0.187534
# [135]	valid_0's binary_logloss: 0.187457
# [136]	valid_0's binary_logloss: 0.187411
# [137]	valid_0's binary_logloss: 0.187378
# [138]	valid_0's binary_logloss: 0.187349
# [139]	valid_0's binary_logloss: 0.18724
# [140]	valid_0's binary_logloss: 0.187035
# [141]	valid_0's binary_logloss: 0.187005
# [142]	valid_0's binary_logloss: 0.186756
# [143]	valid_0's binary_logloss: 0.186558
# [144]	valid_0's binary_logloss: 0.18653
# [145]	valid_0's binary_logloss: 0.186499
# [146]	valid_0's binary_logloss: 0.186475
# [147]	valid_0's binary_logloss: 0.186288
# [148]	valid_0's binary_logloss: 0.186263
# [149]	valid_0's binary_logloss: 0.186236
# [150]	valid_0's binary_logloss: 0.186168
# [151]	valid_0's binary_logloss: 0.185813
# [152]	valid_0's binary_logloss: 0.185788
# [153]	valid_0's binary_logloss: 0.185764
# [154]	valid_0's binary_logloss: 0.18574
# [155]	valid_0's binary_logloss: 0.185711
# [156]	valid_0's binary_logloss: 0.185688
# [157]	valid_0's binary_logloss: 0.185665
# [158]	valid_0's binary_logloss: 0.185632
# [159]	valid_0's binary_logloss: 0.185605
# [160]	valid_0's binary_logloss: 0.185583
# [161]	valid_0's binary_logloss: 0.185513
# [162]	valid_0's binary_logloss: 0.185485
# [163]	valid_0's binary_logloss: 0.185391
# [164]	valid_0's binary_logloss: 0.185312
# [165]	valid_0's binary_logloss: 0.185142
# [166]	valid_0's binary_logloss: 0.18512
# [167]	valid_0's binary_logloss: 0.185094
# [168]	valid_0's binary_logloss: 0.185033
# [169]	valid_0's binary_logloss: 0.185012
# [170]	valid_0's binary_logloss: 0.184921
# [171]	valid_0's binary_logloss: 0.184895
# [172]	valid_0's binary_logloss: 0.184831
# [173]	valid_0's binary_logloss: 0.184774
# [174]	valid_0's binary_logloss: 0.184671
# [175]	valid_0's binary_logloss: 0.184651
# [176]	valid_0's binary_logloss: 0.18463
# [177]	valid_0's binary_logloss: 0.18443
# [178]	valid_0's binary_logloss: 0.184411
# [179]	valid_0's binary_logloss: 0.184272
# [180]	valid_0's binary_logloss: 0.183911
# [181]	valid_0's binary_logloss: 0.183776
# [182]	valid_0's binary_logloss: 0.183735
# [183]	valid_0's binary_logloss: 0.183717
# [184]	valid_0's binary_logloss: 0.183697
# [185]	valid_0's binary_logloss: 0.183674
# [186]	valid_0's binary_logloss: 0.183659
# [187]	valid_0's binary_logloss: 0.183632
# [188]	valid_0's binary_logloss: 0.183614
# [189]	valid_0's binary_logloss: 0.183593
# [190]	valid_0's binary_logloss: 0.183574
# [191]	valid_0's binary_logloss: 0.183546
# [192]	valid_0's binary_logloss: 0.18353
# [193]	valid_0's binary_logloss: 0.183514
# [194]	valid_0's binary_logloss: 0.183394
# [195]	valid_0's binary_logloss: 0.183373
# [196]	valid_0's binary_logloss: 0.183355
# [197]	valid_0's binary_logloss: 0.183205
# [198]	valid_0's binary_logloss: 0.183178
# [199]	valid_0's binary_logloss: 0.18316
# [200]	valid_0's binary_logloss: 0.183143
# [201]	valid_0's binary_logloss: 0.183126
# [202]	valid_0's binary_logloss: 0.183096
# [203]	valid_0's binary_logloss: 0.182972
# [204]	valid_0's binary_logloss: 0.182956
# [205]	valid_0's binary_logloss: 0.182934
# [206]	valid_0's binary_logloss: 0.18273
# [207]	valid_0's binary_logloss: 0.182713
# [208]	valid_0's binary_logloss: 0.18267
# [209]	valid_0's binary_logloss: 0.182651
# [210]	valid_0's binary_logloss: 0.182636
# [211]	valid_0's binary_logloss: 0.182482
# [212]	valid_0's binary_logloss: 0.182465
# [213]	valid_0's binary_logloss: 0.182448
# [214]	valid_0's binary_logloss: 0.182419
# [215]	valid_0's binary_logloss: 0.182405
# [216]	valid_0's binary_logloss: 0.18228
# [217]	valid_0's binary_logloss: 0.182248
# [218]	valid_0's binary_logloss: 0.182231
# [219]	valid_0's binary_logloss: 0.182199
# [220]	valid_0's binary_logloss: 0.182171
# [221]	valid_0's binary_logloss: 0.182063
# [222]	valid_0's binary_logloss: 0.182049
# [223]	valid_0's binary_logloss: 0.18201
# [224]	valid_0's binary_logloss: 0.181969
# [225]	valid_0's binary_logloss: 0.181956
# [226]	valid_0's binary_logloss: 0.181934
# [227]	valid_0's binary_logloss: 0.181922
# [228]	valid_0's binary_logloss: 0.181622
# [229]	valid_0's binary_logloss: 0.181504
# [230]	valid_0's binary_logloss: 0.181489
# [231]	valid_0's binary_logloss: 0.181307
# [232]	valid_0's binary_logloss: 0.181285
# [233]	valid_0's binary_logloss: 0.181166
# [234]	valid_0's binary_logloss: 0.181142
# [235]	valid_0's binary_logloss: 0.181101
# [236]	valid_0's binary_logloss: 0.181089
# [237]	valid_0's binary_logloss: 0.181065
# [238]	valid_0's binary_logloss: 0.18103
# [239]	valid_0's binary_logloss: 0.181014
# [240]	valid_0's binary_logloss: 0.180996
# [241]	valid_0's binary_logloss: 0.180946
# [242]	valid_0's binary_logloss: 0.180917
# [243]	valid_0's binary_logloss: 0.180864
# [244]	valid_0's binary_logloss: 0.180837
# [245]	valid_0's binary_logloss: 0.180828
# [246]	valid_0's binary_logloss: 0.180666
# [247]	valid_0's binary_logloss: 0.180617
# [248]	valid_0's binary_logloss: 0.180501
# [249]	valid_0's binary_logloss: 0.180391
# [250]	valid_0's binary_logloss: 0.180375
# [251]	valid_0's binary_logloss: 0.180339
# [252]	valid_0's binary_logloss: 0.180238
# [253]	valid_0's binary_logloss: 0.180226
# [254]	valid_0's binary_logloss: 0.180077
# [255]	valid_0's binary_logloss: 0.180062
# [256]	valid_0's binary_logloss: 0.18005
# [257]	valid_0's binary_logloss: 0.180037
# [258]	valid_0's binary_logloss: 0.179928
# [259]	valid_0's binary_logloss: 0.179908
# [260]	valid_0's binary_logloss: 0.179783
# [261]	valid_0's binary_logloss: 0.179771
# [262]	valid_0's binary_logloss: 0.179515
# [263]	valid_0's binary_logloss: 0.17944
# [264]	valid_0's binary_logloss: 0.179214
# [265]	valid_0's binary_logloss: 0.179203
# [266]	valid_0's binary_logloss: 0.179146
# [267]	valid_0's binary_logloss: 0.179081
# [268]	valid_0's binary_logloss: 0.179061
# [269]	valid_0's binary_logloss: 0.179036
# [270]	valid_0's binary_logloss: 0.179021
# [271]	valid_0's binary_logloss: 0.178998
# [272]	valid_0's binary_logloss: 0.178984
# [273]	valid_0's binary_logloss: 0.178888
# [274]	valid_0's binary_logloss: 0.178743
# [275]	valid_0's binary_logloss: 0.178656
# [276]	valid_0's binary_logloss: 0.178641
# [277]	valid_0's binary_logloss: 0.178615
# [278]	valid_0's binary_logloss: 0.178545
# [279]	valid_0's binary_logloss: 0.178533
# [280]	valid_0's binary_logloss: 0.17852
# [281]	valid_0's binary_logloss: 0.178503
# [282]	valid_0's binary_logloss: 0.17834
# [283]	valid_0's binary_logloss: 0.178327
# [284]	valid_0's binary_logloss: 0.178279
# [285]	valid_0's binary_logloss: 0.178268
# [286]	valid_0's binary_logloss: 0.178254
# [287]	valid_0's binary_logloss: 0.17824
# [288]	valid_0's binary_logloss: 0.178225
# [289]	valid_0's binary_logloss: 0.178195
# [290]	valid_0's binary_logloss: 0.178134
# [291]	valid_0's binary_logloss: 0.178122
# [292]	valid_0's binary_logloss: 0.178099
# [293]	valid_0's binary_logloss: 0.178047
# [294]	valid_0's binary_logloss: 0.178019
# [295]	valid_0's binary_logloss: 0.177907
# [296]	valid_0's binary_logloss: 0.177802
# [297]	valid_0's binary_logloss: 0.177734
# [298]	valid_0's binary_logloss: 0.177723
# [299]	valid_0's binary_logloss: 0.177704
# [300]	valid_0's binary_logloss: 0.177687
# [301]	valid_0's binary_logloss: 0.177665
# [302]	valid_0's binary_logloss: 0.17757
# [303]	valid_0's binary_logloss: 0.177558
# [304]	valid_0's binary_logloss: 0.177507
# [305]	valid_0's binary_logloss: 0.17749
# [306]	valid_0's binary_logloss: 0.177476
# [307]	valid_0's binary_logloss: 0.177445
# [308]	valid_0's binary_logloss: 0.177415
# [309]	valid_0's binary_logloss: 0.177404
# [310]	valid_0's binary_logloss: 0.177283
# [311]	valid_0's binary_logloss: 0.177269
# [312]	valid_0's binary_logloss: 0.177244
# [313]	valid_0's binary_logloss: 0.177171
# [314]	valid_0's binary_logloss: 0.177152
# [315]	valid_0's binary_logloss: 0.177139
# [316]	valid_0's binary_logloss: 0.177052
# [317]	valid_0's binary_logloss: 0.17703
# [318]	valid_0's binary_logloss: 0.177013
# [319]	valid_0's binary_logloss: 0.17696
# [320]	valid_0's binary_logloss: 0.176818
# [321]	valid_0's binary_logloss: 0.176804
# [322]	valid_0's binary_logloss: 0.176739
# [323]	valid_0's binary_logloss: 0.176724
# [324]	valid_0's binary_logloss: 0.176711
# [325]	valid_0's binary_logloss: 0.176688
# [326]	valid_0's binary_logloss: 0.176672
# [327]	valid_0's binary_logloss: 0.176652
# [328]	valid_0's binary_logloss: 0.176642
# [329]	valid_0's binary_logloss: 0.176617
# [330]	valid_0's binary_logloss: 0.176599
# [331]	valid_0's binary_logloss: 0.176591
# [332]	valid_0's binary_logloss: 0.176539
# [333]	valid_0's binary_logloss: 0.176506
# [334]	valid_0's binary_logloss: 0.176492
# [335]	valid_0's binary_logloss: 0.176471
# [336]	valid_0's binary_logloss: 0.17646
# [337]	valid_0's binary_logloss: 0.176445
# [338]	valid_0's binary_logloss: 0.176423
# [339]	valid_0's binary_logloss: 0.176412
# [340]	valid_0's binary_logloss: 0.176405
# [341]	valid_0's binary_logloss: 0.176381
# [342]	valid_0's binary_logloss: 0.176324
# [343]	valid_0's binary_logloss: 0.176304
# [344]	valid_0's binary_logloss: 0.176283
# [345]	valid_0's binary_logloss: 0.176264
# [346]	valid_0's binary_logloss: 0.176249
# [347]	valid_0's binary_logloss: 0.176207
# [348]	valid_0's binary_logloss: 0.176129
# [349]	valid_0's binary_logloss: 0.176056
# [350]	valid_0's binary_logloss: 0.176022
# [351]	valid_0's binary_logloss: 0.176003
# [352]	valid_0's binary_logloss: 0.175961
# [353]	valid_0's binary_logloss: 0.175945
# [354]	valid_0's binary_logloss: 0.175888
# [355]	valid_0's binary_logloss: 0.17588
# [356]	valid_0's binary_logloss: 0.17587
# [357]	valid_0's binary_logloss: 0.175856
# [358]	valid_0's binary_logloss: 0.175805
# [359]	valid_0's binary_logloss: 0.175787
# [360]	valid_0's binary_logloss: 0.175754
# [361]	valid_0's binary_logloss: 0.175736
# [362]	valid_0's binary_logloss: 0.175727
# [363]	valid_0's binary_logloss: 0.175714
# [364]	valid_0's binary_logloss: 0.175701
# [365]	valid_0's binary_logloss: 0.17566
# [366]	valid_0's binary_logloss: 0.17564
# [367]	valid_0's binary_logloss: 0.175607
# [368]	valid_0's binary_logloss: 0.175582
# [369]	valid_0's binary_logloss: 0.175541
# [370]	valid_0's binary_logloss: 0.175523
# [371]	valid_0's binary_logloss: 0.175387
# [372]	valid_0's binary_logloss: 0.175373
# [373]	valid_0's binary_logloss: 0.175362
# [374]	valid_0's binary_logloss: 0.175344
# [375]	valid_0's binary_logloss: 0.175229
# [376]	valid_0's binary_logloss: 0.175199
# [377]	valid_0's binary_logloss: 0.175154
# [378]	valid_0's binary_logloss: 0.175145
# [379]	valid_0's binary_logloss: 0.17512
# [380]	valid_0's binary_logloss: 0.175106
# [381]	valid_0's binary_logloss: 0.175096
# [382]	valid_0's binary_logloss: 0.175019
# [383]	valid_0's binary_logloss: 0.174967
# [384]	valid_0's binary_logloss: 0.174905
# [385]	valid_0's binary_logloss: 0.174872
# [386]	valid_0's binary_logloss: 0.174855
# [387]	valid_0's binary_logloss: 0.174841
# [388]	valid_0's binary_logloss: 0.17481
# [389]	valid_0's binary_logloss: 0.174778
# [390]	valid_0's binary_logloss: 0.174767
# [391]	valid_0's binary_logloss: 0.174744
# [392]	valid_0's binary_logloss: 0.174729
# [393]	valid_0's binary_logloss: 0.17462
# [394]	valid_0's binary_logloss: 0.174602
# [395]	valid_0's binary_logloss: 0.174561
# [396]	valid_0's binary_logloss: 0.174489
# [397]	valid_0's binary_logloss: 0.174449
# [398]	valid_0's binary_logloss: 0.174433
# [399]	valid_0's binary_logloss: 0.174338
# [400]	valid_0's binary_logloss: 0.174328
# [401]	valid_0's binary_logloss: 0.174267
# [402]	valid_0's binary_logloss: 0.174255
# [403]	valid_0's binary_logloss: 0.174249
# [404]	valid_0's binary_logloss: 0.174239
# [405]	valid_0's binary_logloss: 0.174216
# [406]	valid_0's binary_logloss: 0.174179
# [407]	valid_0's binary_logloss: 0.174169
# [408]	valid_0's binary_logloss: 0.174141
# [409]	valid_0's binary_logloss: 0.174108
# [410]	valid_0's binary_logloss: 0.174041
# [411]	valid_0's binary_logloss: 0.17397
# [412]	valid_0's binary_logloss: 0.173935
# [413]	valid_0's binary_logloss: 0.173893
# [414]	valid_0's binary_logloss: 0.17385
# [415]	valid_0's binary_logloss: 0.173789
# [416]	valid_0's binary_logloss: 0.17378
# [417]	valid_0's binary_logloss: 0.173757
# [418]	valid_0's binary_logloss: 0.173722
# [419]	valid_0's binary_logloss: 0.173671
# [420]	valid_0's binary_logloss: 0.173644
# [421]	valid_0's binary_logloss: 0.173601
# [422]	valid_0's binary_logloss: 0.173538
# [423]	valid_0's binary_logloss: 0.173513
# [424]	valid_0's binary_logloss: 0.173471
# [425]	valid_0's binary_logloss: 0.173392
# [426]	valid_0's binary_logloss: 0.173381
# [427]	valid_0's binary_logloss: 0.173368
# [428]	valid_0's binary_logloss: 0.173345
# [429]	valid_0's binary_logloss: 0.173306
# [430]	valid_0's binary_logloss: 0.173268
# [431]	valid_0's binary_logloss: 0.173261
# [432]	valid_0's binary_logloss: 0.173157
# [433]	valid_0's binary_logloss: 0.173127
# [434]	valid_0's binary_logloss: 0.173118
# [435]	valid_0's binary_logloss: 0.173009
# [436]	valid_0's binary_logloss: 0.172989
# [437]	valid_0's binary_logloss: 0.172969
# [438]	valid_0's binary_logloss: 0.172939
# [439]	valid_0's binary_logloss: 0.172931
# [440]	valid_0's binary_logloss: 0.172912
# [441]	valid_0's binary_logloss: 0.17285
# [442]	valid_0's binary_logloss: 0.172822
# [443]	valid_0's binary_logloss: 0.172789
# [444]	valid_0's binary_logloss: 0.172767
# [445]	valid_0's binary_logloss: 0.172615
# [446]	valid_0's binary_logloss: 0.172509
# [447]	valid_0's binary_logloss: 0.172485
# [448]	valid_0's binary_logloss: 0.172472
# [449]	valid_0's binary_logloss: 0.172429
# [450]	valid_0's binary_logloss: 0.172406
# [451]	valid_0's binary_logloss: 0.172375
# [452]	valid_0's binary_logloss: 0.17236
# [453]	valid_0's binary_logloss: 0.172353
# [454]	valid_0's binary_logloss: 0.172341
# [455]	valid_0's binary_logloss: 0.172328
# [456]	valid_0's binary_logloss: 0.17227
# [457]	valid_0's binary_logloss: 0.172248
# [458]	valid_0's binary_logloss: 0.172238
# [459]	valid_0's binary_logloss: 0.172232
# [460]	valid_0's binary_logloss: 0.172182
# [461]	valid_0's binary_logloss: 0.172172
# [462]	valid_0's binary_logloss: 0.172134
# [463]	valid_0's binary_logloss: 0.17211
# [464]	valid_0's binary_logloss: 0.172063
# [465]	valid_0's binary_logloss: 0.172054
# [466]	valid_0's binary_logloss: 0.172045
# [467]	valid_0's binary_logloss: 0.17203
# [468]	valid_0's binary_logloss: 0.172013
# [469]	valid_0's binary_logloss: 0.171994
# [470]	valid_0's binary_logloss: 0.171972
# [471]	valid_0's binary_logloss: 0.171936
# [472]	valid_0's binary_logloss: 0.17185
# [473]	valid_0's binary_logloss: 0.17182
# [474]	valid_0's binary_logloss: 0.171796
# [475]	valid_0's binary_logloss: 0.171779
# [476]	valid_0's binary_logloss: 0.171634
# [477]	valid_0's binary_logloss: 0.171593
# [478]	valid_0's binary_logloss: 0.171549
# [479]	valid_0's binary_logloss: 0.17153
# [480]	valid_0's binary_logloss: 0.171515
# [481]	valid_0's binary_logloss: 0.171493
# [482]	valid_0's binary_logloss: 0.171472
# [483]	valid_0's binary_logloss: 0.171465
# [484]	valid_0's binary_logloss: 0.171406
# [485]	valid_0's binary_logloss: 0.171385
# [486]	valid_0's binary_logloss: 0.171378
# [487]	valid_0's binary_logloss: 0.171367
# [488]	valid_0's binary_logloss: 0.171341
# [489]	valid_0's binary_logloss: 0.171313
# [490]	valid_0's binary_logloss: 0.171299
# [491]	valid_0's binary_logloss: 0.17127
# [492]	valid_0's binary_logloss: 0.171239
# [493]	valid_0's binary_logloss: 0.171134
# [494]	valid_0's binary_logloss: 0.171122
# [495]	valid_0's binary_logloss: 0.171114
# [496]	valid_0's binary_logloss: 0.171098
# [497]	valid_0's binary_logloss: 0.171081
# [498]	valid_0's binary_logloss: 0.171049
# [499]	valid_0's binary_logloss: 0.171028
# [500]	valid_0's binary_logloss: 0.171016
# [501]	valid_0's binary_logloss: 0.170998
# [502]	valid_0's binary_logloss: 0.170987
# [503]	valid_0's binary_logloss: 0.170954
# [504]	valid_0's binary_logloss: 0.170903
# [505]	valid_0's binary_logloss: 0.170814
# [506]	valid_0's binary_logloss: 0.170796
# [507]	valid_0's binary_logloss: 0.170777
# [508]	valid_0's binary_logloss: 0.170722
# [509]	valid_0's binary_logloss: 0.170615
# [510]	valid_0's binary_logloss: 0.170608
# [511]	valid_0's binary_logloss: 0.170599
# [512]	valid_0's binary_logloss: 0.170567
# [513]	valid_0's binary_logloss: 0.170558
# [514]	valid_0's binary_logloss: 0.170529
# [515]	valid_0's binary_logloss: 0.170518
# [516]	valid_0's binary_logloss: 0.170482
# [517]	valid_0's binary_logloss: 0.170463
# [518]	valid_0's binary_logloss: 0.170402
# [519]	valid_0's binary_logloss: 0.170372
# [520]	valid_0's binary_logloss: 0.17034
# [521]	valid_0's binary_logloss: 0.170317
# [522]	valid_0's binary_logloss: 0.170304
# [523]	valid_0's binary_logloss: 0.17028
# [524]	valid_0's binary_logloss: 0.170255
# [525]	valid_0's binary_logloss: 0.170242
# [526]	valid_0's binary_logloss: 0.170226
# [527]	valid_0's binary_logloss: 0.170165
# [528]	valid_0's binary_logloss: 0.170148
# [529]	valid_0's binary_logloss: 0.170115
# [530]	valid_0's binary_logloss: 0.170101
# [531]	valid_0's binary_logloss: 0.170092
# [532]	valid_0's binary_logloss: 0.170072
# [533]	valid_0's binary_logloss: 0.17006
# [534]	valid_0's binary_logloss: 0.170046
# [535]	valid_0's binary_logloss: 0.17003
# [536]	valid_0's binary_logloss: 0.170015
# [537]	valid_0's binary_logloss: 0.170006
# [538]	valid_0's binary_logloss: 0.169963
# [539]	valid_0's binary_logloss: 0.169918
# [540]	valid_0's binary_logloss: 0.169906
# [541]	valid_0's binary_logloss: 0.1699
# [542]	valid_0's binary_logloss: 0.169888
# [543]	valid_0's binary_logloss: 0.169879
# [544]	valid_0's binary_logloss: 0.169862
# [545]	valid_0's binary_logloss: 0.169835
# [546]	valid_0's binary_logloss: 0.169824
# [547]	valid_0's binary_logloss: 0.169799
# [548]	valid_0's binary_logloss: 0.169784
# [549]	valid_0's binary_logloss: 0.169776
# [550]	valid_0's binary_logloss: 0.169753
# [551]	valid_0's binary_logloss: 0.169735
# [552]	valid_0's binary_logloss: 0.169728
# [553]	valid_0's binary_logloss: 0.169716
# [554]	valid_0's binary_logloss: 0.16971
# [555]	valid_0's binary_logloss: 0.169704
# [556]	valid_0's binary_logloss: 0.169673
# [557]	valid_0's binary_logloss: 0.169637
# [558]	valid_0's binary_logloss: 0.169622
# [559]	valid_0's binary_logloss: 0.169618
# [560]	valid_0's binary_logloss: 0.169594
# [561]	valid_0's binary_logloss: 0.169589
# [562]	valid_0's binary_logloss: 0.169577
# [563]	valid_0's binary_logloss: 0.169547
# [564]	valid_0's binary_logloss: 0.169513
# [565]	valid_0's binary_logloss: 0.169493
# [566]	valid_0's binary_logloss: 0.169479
# [567]	valid_0's binary_logloss: 0.169467
# [568]	valid_0's binary_logloss: 0.169439
# [569]	valid_0's binary_logloss: 0.169423
# [570]	valid_0's binary_logloss: 0.16935
# [571]	valid_0's binary_logloss: 0.169343
# [572]	valid_0's binary_logloss: 0.169331
# [573]	valid_0's binary_logloss: 0.1693
# [574]	valid_0's binary_logloss: 0.169254
# [575]	valid_0's binary_logloss: 0.169245
# [576]	valid_0's binary_logloss: 0.169227
# [577]	valid_0's binary_logloss: 0.169215
# [578]	valid_0's binary_logloss: 0.169112
# [579]	valid_0's binary_logloss: 0.169107
# [580]	valid_0's binary_logloss: 0.169077
# [581]	valid_0's binary_logloss: 0.169067
# [582]	valid_0's binary_logloss: 0.169051
# [583]	valid_0's binary_logloss: 0.169045
# [584]	valid_0's binary_logloss: 0.169011
# [585]	valid_0's binary_logloss: 0.168986
# [586]	valid_0's binary_logloss: 0.168979
# [587]	valid_0's binary_logloss: 0.168973
# [588]	valid_0's binary_logloss: 0.168939
# [589]	valid_0's binary_logloss: 0.168913
# [590]	valid_0's binary_logloss: 0.168904
# [591]	valid_0's binary_logloss: 0.168898
# [592]	valid_0's binary_logloss: 0.168892
# [593]	valid_0's binary_logloss: 0.168876
# [594]	valid_0's binary_logloss: 0.168866
# [595]	valid_0's binary_logloss: 0.168861
# [596]	valid_0's binary_logloss: 0.168849
# [597]	valid_0's binary_logloss: 0.168797
# [598]	valid_0's binary_logloss: 0.168787
# [599]	valid_0's binary_logloss: 0.168776
# [600]	valid_0's binary_logloss: 0.168757
# [601]	valid_0's binary_logloss: 0.168678
# [602]	valid_0's binary_logloss: 0.168587
# [603]	valid_0's binary_logloss: 0.168576
# [604]	valid_0's binary_logloss: 0.168568
# [605]	valid_0's binary_logloss: 0.168517
# [606]	valid_0's binary_logloss: 0.16851
# [607]	valid_0's binary_logloss: 0.168493
# [608]	valid_0's binary_logloss: 0.16847
# [609]	valid_0's binary_logloss: 0.168454
# [610]	valid_0's binary_logloss: 0.168433
# [611]	valid_0's binary_logloss: 0.168422
# [612]	valid_0's binary_logloss: 0.168418
# [613]	valid_0's binary_logloss: 0.168407
# [614]	valid_0's binary_logloss: 0.168397
# [615]	valid_0's binary_logloss: 0.168387
# [616]	valid_0's binary_logloss: 0.168381
# [617]	valid_0's binary_logloss: 0.168371
# [618]	valid_0's binary_logloss: 0.168363
# [619]	valid_0's binary_logloss: 0.168357
# [620]	valid_0's binary_logloss: 0.168353
# [621]	valid_0's binary_logloss: 0.168345
# [622]	valid_0's binary_logloss: 0.168331
# [623]	valid_0's binary_logloss: 0.168317
# [624]	valid_0's binary_logloss: 0.168284
# [625]	valid_0's binary_logloss: 0.168276
# [626]	valid_0's binary_logloss: 0.168265
# [627]	valid_0's binary_logloss: 0.168255
# [628]	valid_0's binary_logloss: 0.168177
# [629]	valid_0's binary_logloss: 0.168162
# [630]	valid_0's binary_logloss: 0.16814
# [631]	valid_0's binary_logloss: 0.168046
# [632]	valid_0's binary_logloss: 0.168027
# [633]	valid_0's binary_logloss: 0.168017
# [634]	valid_0's binary_logloss: 0.168007
# [635]	valid_0's binary_logloss: 0.167999
# [636]	valid_0's binary_logloss: 0.167977
# [637]	valid_0's binary_logloss: 0.16788
# [638]	valid_0's binary_logloss: 0.167875
# [639]	valid_0's binary_logloss: 0.167866
# [640]	valid_0's binary_logloss: 0.167842
# [641]	valid_0's binary_logloss: 0.167828
# [642]	valid_0's binary_logloss: 0.167813
# [643]	valid_0's binary_logloss: 0.167792
# [644]	valid_0's binary_logloss: 0.167781
# [645]	valid_0's binary_logloss: 0.167729
# [646]	valid_0's binary_logloss: 0.167721
# [647]	valid_0's binary_logloss: 0.16771
# [648]	valid_0's binary_logloss: 0.167703
# [649]	valid_0's binary_logloss: 0.167657
# [650]	valid_0's binary_logloss: 0.167641
# [651]	valid_0's binary_logloss: 0.167599
# [652]	valid_0's binary_logloss: 0.167587
# [653]	valid_0's binary_logloss: 0.167574
# [654]	valid_0's binary_logloss: 0.167532
# [655]	valid_0's binary_logloss: 0.167523
# [656]	valid_0's binary_logloss: 0.167516
# [657]	valid_0's binary_logloss: 0.167508
# [658]	valid_0's binary_logloss: 0.167501
# [659]	valid_0's binary_logloss: 0.167492
# [660]	valid_0's binary_logloss: 0.167478
# [661]	valid_0's binary_logloss: 0.167443
# [662]	valid_0's binary_logloss: 0.167437
# [663]	valid_0's binary_logloss: 0.167433
# [664]	valid_0's binary_logloss: 0.167429
# [665]	valid_0's binary_logloss: 0.167357
# [666]	valid_0's binary_logloss: 0.167344
# [667]	valid_0's binary_logloss: 0.167219
# [668]	valid_0's binary_logloss: 0.1672
# [669]	valid_0's binary_logloss: 0.167182
# [670]	valid_0's binary_logloss: 0.167176
# [671]	valid_0's binary_logloss: 0.167172
# [672]	valid_0's binary_logloss: 0.167161
# [673]	valid_0's binary_logloss: 0.167154
# [674]	valid_0's binary_logloss: 0.167149
# [675]	valid_0's binary_logloss: 0.167143
# [676]	valid_0's binary_logloss: 0.167136
# [677]	valid_0's binary_logloss: 0.16713
# [678]	valid_0's binary_logloss: 0.16712
# [679]	valid_0's binary_logloss: 0.167109
# [680]	valid_0's binary_logloss: 0.167102
# [681]	valid_0's binary_logloss: 0.167096
# [682]	valid_0's binary_logloss: 0.167059
# [683]	valid_0's binary_logloss: 0.167052
# [684]	valid_0's binary_logloss: 0.167033
# [685]	valid_0's binary_logloss: 0.167027
# [686]	valid_0's binary_logloss: 0.167016
# [687]	valid_0's binary_logloss: 0.167014
# [688]	valid_0's binary_logloss: 0.167005
# [689]	valid_0's binary_logloss: 0.167002
# [690]	valid_0's binary_logloss: 0.166975
# [691]	valid_0's binary_logloss: 0.16697
# [692]	valid_0's binary_logloss: 0.166953
# [693]	valid_0's binary_logloss: 0.166937
# [694]	valid_0's binary_logloss: 0.16693
# [695]	valid_0's binary_logloss: 0.166922
# [696]	valid_0's binary_logloss: 0.166901
# [697]	valid_0's binary_logloss: 0.166847
# [698]	valid_0's binary_logloss: 0.166843
# [699]	valid_0's binary_logloss: 0.166838
# [700]	valid_0's binary_logloss: 0.166826
# [701]	valid_0's binary_logloss: 0.166819
# [702]	valid_0's binary_logloss: 0.166799
# [703]	valid_0's binary_logloss: 0.166742
# [704]	valid_0's binary_logloss: 0.166736
# [705]	valid_0's binary_logloss: 0.166721
# [706]	valid_0's binary_logloss: 0.166718
# [707]	valid_0's binary_logloss: 0.166715
# [708]	valid_0's binary_logloss: 0.166709
# [709]	valid_0's binary_logloss: 0.1667
# [710]	valid_0's binary_logloss: 0.16669
# [711]	valid_0's binary_logloss: 0.166678
# [712]	valid_0's binary_logloss: 0.166668
# [713]	valid_0's binary_logloss: 0.166659
# [714]	valid_0's binary_logloss: 0.166652
# [715]	valid_0's binary_logloss: 0.166642
# [716]	valid_0's binary_logloss: 0.166567
# [717]	valid_0's binary_logloss: 0.166562
# [718]	valid_0's binary_logloss: 0.166492
# [719]	valid_0's binary_logloss: 0.166485
# [720]	valid_0's binary_logloss: 0.166479
# [721]	valid_0's binary_logloss: 0.166468
# [722]	valid_0's binary_logloss: 0.166464
# [723]	valid_0's binary_logloss: 0.166461
# [724]	valid_0's binary_logloss: 0.166438
# [725]	valid_0's binary_logloss: 0.16642
# [726]	valid_0's binary_logloss: 0.166395
# [727]	valid_0's binary_logloss: 0.166385
# [728]	valid_0's binary_logloss: 0.166347
# [729]	valid_0's binary_logloss: 0.166324
# [730]	valid_0's binary_logloss: 0.166323
# [731]	valid_0's binary_logloss: 0.166282
# [732]	valid_0's binary_logloss: 0.166278
# [733]	valid_0's binary_logloss: 0.166274
# [734]	valid_0's binary_logloss: 0.166265
# [735]	valid_0's binary_logloss: 0.166257
# [736]	valid_0's binary_logloss: 0.166248
# [737]	valid_0's binary_logloss: 0.166235
# [738]	valid_0's binary_logloss: 0.166228
# [739]	valid_0's binary_logloss: 0.166163
# [740]	valid_0's binary_logloss: 0.166135
# [741]	valid_0's binary_logloss: 0.16613
# [742]	valid_0's binary_logloss: 0.166127
# [743]	valid_0's binary_logloss: 0.16612
# [744]	valid_0's binary_logloss: 0.16609
# [745]	valid_0's binary_logloss: 0.16605
# [746]	valid_0's binary_logloss: 0.166015
# [747]	valid_0's binary_logloss: 0.16601
# [748]	valid_0's binary_logloss: 0.166007
# [749]	valid_0's binary_logloss: 0.165978
# [750]	valid_0's binary_logloss: 0.16597
# [751]	valid_0's binary_logloss: 0.165966
# [752]	valid_0's binary_logloss: 0.165954
# [753]	valid_0's binary_logloss: 0.165951
# [754]	valid_0's binary_logloss: 0.165937
# [755]	valid_0's binary_logloss: 0.165932
# [756]	valid_0's binary_logloss: 0.165927
# [757]	valid_0's binary_logloss: 0.165901
# [758]	valid_0's binary_logloss: 0.165893
# [759]	valid_0's binary_logloss: 0.165889
# [760]	valid_0's binary_logloss: 0.165884
# [761]	valid_0's binary_logloss: 0.165877
# [762]	valid_0's binary_logloss: 0.165874
# [763]	valid_0's binary_logloss: 0.165869
# [764]	valid_0's binary_logloss: 0.165865
# [765]	valid_0's binary_logloss: 0.165862
# [766]	valid_0's binary_logloss: 0.165856
# [767]	valid_0's binary_logloss: 0.16585
# [768]	valid_0's binary_logloss: 0.165841
# [769]	valid_0's binary_logloss: 0.165836
# [770]	valid_0's binary_logloss: 0.165779
# [771]	valid_0's binary_logloss: 0.165773
# [772]	valid_0's binary_logloss: 0.165768
# [773]	valid_0's binary_logloss: 0.165762
# [774]	valid_0's binary_logloss: 0.165753
# [775]	valid_0's binary_logloss: 0.165749
# [776]	valid_0's binary_logloss: 0.165746
# [777]	valid_0's binary_logloss: 0.165735
# [778]	valid_0's binary_logloss: 0.165728
# [779]	valid_0's binary_logloss: 0.16572
# [780]	valid_0's binary_logloss: 0.165676
# [781]	valid_0's binary_logloss: 0.16567
# [782]	valid_0's binary_logloss: 0.165661
# [783]	valid_0's binary_logloss: 0.165635
# [784]	valid_0's binary_logloss: 0.165628
# [785]	valid_0's binary_logloss: 0.165624
# [786]	valid_0's binary_logloss: 0.165605
# [787]	valid_0's binary_logloss: 0.165583
# [788]	valid_0's binary_logloss: 0.16558
# [789]	valid_0's binary_logloss: 0.165545
# [790]	valid_0's binary_logloss: 0.16554
# [791]	valid_0's binary_logloss: 0.16553
# [792]	valid_0's binary_logloss: 0.165503
# [793]	valid_0's binary_logloss: 0.165427
# [794]	valid_0's binary_logloss: 0.165423
# [795]	valid_0's binary_logloss: 0.165416
# [796]	valid_0's binary_logloss: 0.165349
# [797]	valid_0's binary_logloss: 0.165343
# [798]	valid_0's binary_logloss: 0.165325
# [799]	valid_0's binary_logloss: 0.16532
# [800]	valid_0's binary_logloss: 0.165311
# [801]	valid_0's binary_logloss: 0.165302
# [802]	valid_0's binary_logloss: 0.165297
# [803]	valid_0's binary_logloss: 0.165293
# [804]	valid_0's binary_logloss: 0.16529
# [805]	valid_0's binary_logloss: 0.165286
# [806]	valid_0's binary_logloss: 0.165281
# [807]	valid_0's binary_logloss: 0.165273
# [808]	valid_0's binary_logloss: 0.165265
# [809]	valid_0's binary_logloss: 0.165262
# [810]	valid_0's binary_logloss: 0.165244
# [811]	valid_0's binary_logloss: 0.165199
# [812]	valid_0's binary_logloss: 0.165189
# [813]	valid_0's binary_logloss: 0.165182
# [814]	valid_0's binary_logloss: 0.16518
# [815]	valid_0's binary_logloss: 0.165175
# [816]	valid_0's binary_logloss: 0.165173
# [817]	valid_0's binary_logloss: 0.165152
# [818]	valid_0's binary_logloss: 0.16508
# [819]	valid_0's binary_logloss: 0.165076
# [820]	valid_0's binary_logloss: 0.165075
# [821]	valid_0's binary_logloss: 0.165071
# [822]	valid_0's binary_logloss: 0.165067
# [823]	valid_0's binary_logloss: 0.165063
# [824]	valid_0's binary_logloss: 0.165014
# [825]	valid_0's binary_logloss: 0.164977
# [826]	valid_0's binary_logloss: 0.164973
# [827]	valid_0's binary_logloss: 0.164965
# [828]	valid_0's binary_logloss: 0.164954
# [829]	valid_0's binary_logloss: 0.164947
# [830]	valid_0's binary_logloss: 0.164945
# [831]	valid_0's binary_logloss: 0.164941
# [832]	valid_0's binary_logloss: 0.164935
# [833]	valid_0's binary_logloss: 0.164896
# [834]	valid_0's binary_logloss: 0.164885
# [835]	valid_0's binary_logloss: 0.164879
# [836]	valid_0's binary_logloss: 0.16487
# [837]	valid_0's binary_logloss: 0.164867
# [838]	valid_0's binary_logloss: 0.164865
# [839]	valid_0's binary_logloss: 0.164857
# [840]	valid_0's binary_logloss: 0.164853
# [841]	valid_0's binary_logloss: 0.16484
# [842]	valid_0's binary_logloss: 0.164825
# [843]	valid_0's binary_logloss: 0.164819
# [844]	valid_0's binary_logloss: 0.164809
# [845]	valid_0's binary_logloss: 0.164804
# [846]	valid_0's binary_logloss: 0.164793
# [847]	valid_0's binary_logloss: 0.164785
# [848]	valid_0's binary_logloss: 0.164782
# [849]	valid_0's binary_logloss: 0.164778
# [850]	valid_0's binary_logloss: 0.164771
# [851]	valid_0's binary_logloss: 0.16475
# [852]	valid_0's binary_logloss: 0.164746
# [853]	valid_0's binary_logloss: 0.164743
# [854]	valid_0's binary_logloss: 0.164741
# [855]	valid_0's binary_logloss: 0.164736
# [856]	valid_0's binary_logloss: 0.164651
# [857]	valid_0's binary_logloss: 0.164645
# [858]	valid_0's binary_logloss: 0.164644
# [859]	valid_0's binary_logloss: 0.16464
# [860]	valid_0's binary_logloss: 0.164638
# [861]	valid_0's binary_logloss: 0.16463
# [862]	valid_0's binary_logloss: 0.164626
# [863]	valid_0's binary_logloss: 0.16462
# [864]	valid_0's binary_logloss: 0.164617
# [865]	valid_0's binary_logloss: 0.164613
# [866]	valid_0's binary_logloss: 0.16461
# [867]	valid_0's binary_logloss: 0.164601
# [868]	valid_0's binary_logloss: 0.164581
# [869]	valid_0's binary_logloss: 0.164577
# [870]	valid_0's binary_logloss: 0.164573
# [871]	valid_0's binary_logloss: 0.164571
# [872]	valid_0's binary_logloss: 0.164562
# [873]	valid_0's binary_logloss: 0.164557
# [874]	valid_0's binary_logloss: 0.164551
# [875]	valid_0's binary_logloss: 0.164546
# [876]	valid_0's binary_logloss: 0.164542
# [877]	valid_0's binary_logloss: 0.164536
# [878]	valid_0's binary_logloss: 0.16453
# [879]	valid_0's binary_logloss: 0.164526
# [880]	valid_0's binary_logloss: 0.164521
# [881]	valid_0's binary_logloss: 0.164488
# [882]	valid_0's binary_logloss: 0.164475
# [883]	valid_0's binary_logloss: 0.164473
# [884]	valid_0's binary_logloss: 0.164472
# [885]	valid_0's binary_logloss: 0.164463
# [886]	valid_0's binary_logloss: 0.164461
# [887]	valid_0's binary_logloss: 0.164457
# [888]	valid_0's binary_logloss: 0.164451
# [889]	valid_0's binary_logloss: 0.164419
# [890]	valid_0's binary_logloss: 0.16438
# [891]	valid_0's binary_logloss: 0.164376
# [892]	valid_0's binary_logloss: 0.164371
# [893]	valid_0's binary_logloss: 0.164364
# [894]	valid_0's binary_logloss: 0.164361
# [895]	valid_0's binary_logloss: 0.164331
# [896]	valid_0's binary_logloss: 0.164287
# [897]	valid_0's binary_logloss: 0.164245
# [898]	valid_0's binary_logloss: 0.164238
# [899]	valid_0's binary_logloss: 0.164229
# [900]	valid_0's binary_logloss: 0.164211
# [901]	valid_0's binary_logloss: 0.164205
# [902]	valid_0's binary_logloss: 0.164182
# [903]	valid_0's binary_logloss: 0.164177
# [904]	valid_0's binary_logloss: 0.164172
# [905]	valid_0's binary_logloss: 0.164171
# [906]	valid_0's binary_logloss: 0.164159
# [907]	valid_0's binary_logloss: 0.164151
# [908]	valid_0's binary_logloss: 0.164147
# [909]	valid_0's binary_logloss: 0.164139
# [910]	valid_0's binary_logloss: 0.164114
# [911]	valid_0's binary_logloss: 0.164111
# [912]	valid_0's binary_logloss: 0.164103
# [913]	valid_0's binary_logloss: 0.164098
# [914]	valid_0's binary_logloss: 0.164093
# [915]	valid_0's binary_logloss: 0.164052
# [916]	valid_0's binary_logloss: 0.164042
# [917]	valid_0's binary_logloss: 0.164037
# [918]	valid_0's binary_logloss: 0.164035
# [919]	valid_0's binary_logloss: 0.164035
# [920]	valid_0's binary_logloss: 0.164029
# [921]	valid_0's binary_logloss: 0.164023
# [922]	valid_0's binary_logloss: 0.164016
# [923]	valid_0's binary_logloss: 0.164007
# [924]	valid_0's binary_logloss: 0.163977
# [925]	valid_0's binary_logloss: 0.163973
# [926]	valid_0's binary_logloss: 0.163964
# [927]	valid_0's binary_logloss: 0.163954
# [928]	valid_0's binary_logloss: 0.163932
# [929]	valid_0's binary_logloss: 0.163925
# [930]	valid_0's binary_logloss: 0.163921
# [931]	valid_0's binary_logloss: 0.163918
# [932]	valid_0's binary_logloss: 0.163917
# [933]	valid_0's binary_logloss: 0.16386
# [934]	valid_0's binary_logloss: 0.163847
# [935]	valid_0's binary_logloss: 0.163844
# [936]	valid_0's binary_logloss: 0.163838
# [937]	valid_0's binary_logloss: 0.16382
# [938]	valid_0's binary_logloss: 0.163814
# [939]	valid_0's binary_logloss: 0.16381
# [940]	valid_0's binary_logloss: 0.163799
# [941]	valid_0's binary_logloss: 0.163796
# [942]	valid_0's binary_logloss: 0.163788
# [943]	valid_0's binary_logloss: 0.163785
# [944]	valid_0's binary_logloss: 0.163782
# [945]	valid_0's binary_logloss: 0.16377
# [946]	valid_0's binary_logloss: 0.163767
# [947]	valid_0's binary_logloss: 0.163753
# [948]	valid_0's binary_logloss: 0.163747
# [949]	valid_0's binary_logloss: 0.16374
# [950]	valid_0's binary_logloss: 0.163733
# [951]	valid_0's binary_logloss: 0.16373
# [952]	valid_0's binary_logloss: 0.163724
# [953]	valid_0's binary_logloss: 0.163724
# [954]	valid_0's binary_logloss: 0.163705
# [955]	valid_0's binary_logloss: 0.163702
# [956]	valid_0's binary_logloss: 0.163693
# [957]	valid_0's binary_logloss: 0.163685
# [958]	valid_0's binary_logloss: 0.163666
# [959]	valid_0's binary_logloss: 0.163664
# [960]	valid_0's binary_logloss: 0.163659
# [961]	valid_0's binary_logloss: 0.163656
# [962]	valid_0's binary_logloss: 0.163652
# [963]	valid_0's binary_logloss: 0.163643
# [964]	valid_0's binary_logloss: 0.16364
# [965]	valid_0's binary_logloss: 0.163639
# [966]	valid_0's binary_logloss: 0.163638
# [967]	valid_0's binary_logloss: 0.16361
# [968]	valid_0's binary_logloss: 0.163603
# [969]	valid_0's binary_logloss: 0.1636
# [970]	valid_0's binary_logloss: 0.163595
# [971]	valid_0's binary_logloss: 0.163586
# [972]	valid_0's binary_logloss: 0.163585
# [973]	valid_0's binary_logloss: 0.163582
# [974]	valid_0's binary_logloss: 0.163574
# [975]	valid_0's binary_logloss: 0.163573
# [976]	valid_0's binary_logloss: 0.163562
# [977]	valid_0's binary_logloss: 0.163561
# [978]	valid_0's binary_logloss: 0.163557
# [979]	valid_0's binary_logloss: 0.16352
# [980]	valid_0's binary_logloss: 0.163518
# [981]	valid_0's binary_logloss: 0.163511
# [982]	valid_0's binary_logloss: 0.163507
# [983]	valid_0's binary_logloss: 0.163494
# [984]	valid_0's binary_logloss: 0.163465
# [985]	valid_0's binary_logloss: 0.163459
# [986]	valid_0's binary_logloss: 0.163455
# [987]	valid_0's binary_logloss: 0.163451
# [988]	valid_0's binary_logloss: 0.163448
# [989]	valid_0's binary_logloss: 0.163445
# [990]	valid_0's binary_logloss: 0.163436
# [991]	valid_0's binary_logloss: 0.163432
# [992]	valid_0's binary_logloss: 0.163411
# [993]	valid_0's binary_logloss: 0.163387
# [994]	valid_0's binary_logloss: 0.163376
# [995]	valid_0's binary_logloss: 0.163375
# [996]	valid_0's binary_logloss: 0.163365
# [997]	valid_0's binary_logloss: 0.163364
# [998]	valid_0's binary_logloss: 0.163362
# [999]	valid_0's binary_logloss: 0.163333
# [1000]	valid_0's binary_logloss: 0.163329
# [1001]	valid_0's binary_logloss: 0.163325
# [1002]	valid_0's binary_logloss: 0.163321
# [1003]	valid_0's binary_logloss: 0.163315
# [1004]	valid_0's binary_logloss: 0.163312
# [1005]	valid_0's binary_logloss: 0.1633
# [1006]	valid_0's binary_logloss: 0.163291
# [1007]	valid_0's binary_logloss: 0.163289
# [1008]	valid_0's binary_logloss: 0.163273
# [1009]	valid_0's binary_logloss: 0.163271
# [1010]	valid_0's binary_logloss: 0.163269
# [1011]	valid_0's binary_logloss: 0.16327
# Early stopping, best iteration is:
# [1010]	valid_0's binary_logloss: 0.163269

# %%
from sklearn.metrics import roc_auc_score
x_final=x_test[features]
y_final=c.predict_proba(x_final)
y_pred=[]
for elem in y_final:
    y_pred.append(elem[1])
score=roc_auc_score(y_test, y_pred)
print(score)
# Out:
# 0.9825216059822158

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV27.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV27.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idpostulante'],how='left')
prediccion=pd.merge(prediccion,vistas2,on=['idaviso','idpostulante'],how='left')
prediccion=pd.merge(prediccion,vistas3,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion['lo_vio']=(prediccion['cantidad']>0)
prediccion=pd.merge(prediccion,postulaciones_por_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['postulaciones_misma_area']=prediccion['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion['postulaciones_mismo_nivel']=prediccion['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion['postulaciones_mismo_tipo']=prediccion['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion=pd.merge(prediccion,vistas_por_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,vistas_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,vistas_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['vistas_por_area']=prediccion['vistas_por_area'].fillna(0)
prediccion['vistas_por_tipo']=prediccion['vistas_por_tipo'].fillna(0)
prediccion['vistas_por_nivel']=prediccion['vistas_por_tipo'].fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado      Master  \
# 6428   84527  1112466576      3Nz0Qza   FEM  24.0         -           -
# 28595  29476  1112372029      zv46m0E   FEM  26.0         -  Abandonado
# 9322   86189  1112466706      2zQxNKw  MASC  32.0         -           -
# 56154   5764  1111587152       aBBzPD  MASC  31.0         -    En Curso
# 34807  56366  1112448621      xkvWw5P  MASC  19.0         -           -
# 5908   43152  1112424668      bOJBQM2   FEM  25.0         -           -
# 2898   74836  1112463897      Drz3k1A   FEM  24.0         -           -
# 73058  19115  1112222867       Nroz4B   FEM  39.0         -           -
# 39547  40640  1112420043      bOjeqDV   FEM  37.0         -           -
# 51310  51909  1112442182      LN8kvm5   FEM  25.0         -           -
#
#            Otro  Posgrado Secundario        ...        vistas_postulante  \
# 6428   Graduado         -   Graduado        ...                    292.0
# 28595         -  Graduado   Graduado        ...                      NaN
# 9322          -         -   Graduado        ...                      NaN
# 56154         -  Graduado   Graduado        ...                     10.0
# 34807  En Curso         -   Graduado        ...                    334.0
# 5908          -         -   Graduado        ...                     51.0
# 2898          -         -   Graduado        ...                     61.0
# 73058         -         -   Graduado        ...                      3.0
# 39547         -         -          -        ...                      9.0
# 51310  Graduado         -   Graduado        ...                    145.0
#
#       vistas_al_aviso  cantidad lo_vio postulaciones_misma_area  \
# 6428              1.0  0.003425   True                     24.0
# 28595             NaN  0.000000  False                      0.0
# 9322              NaN  0.000000  False                      0.0
# 56154             NaN  0.000000  False                      0.0
# 34807             1.0  0.002994   True                      2.0
# 5908              9.0  0.176471   True                      1.0
# 2898              1.0  0.016393   True                     49.0
# 73058             NaN  0.000000  False                      1.0
# 39547             2.0  0.222222   True                      1.0
# 51310             3.0  0.020690   True                     49.0
#
#       postulaciones_mismo_tipo postulaciones_mismo_nivel vistas_por_area  \
# 6428                      51.0                      19.0            84.0
# 28595                     16.0                      13.0             0.0
# 9322                      17.0                      14.0             0.0
# 56154                      1.0                       5.0             0.0
# 34807                    492.0                     368.0             1.0
# 5908                      18.0                      15.0            33.0
# 2898                      77.0                      84.0            25.0
# 73058                     19.0                      17.0             0.0
# 39547                     17.0                      15.0             2.0
# 51310                    102.0                     106.0            46.0
#
#        vistas_por_tipo  vistas_por_nivel
# 6428             183.0             183.0
# 28595              0.0               0.0
# 9322               0.0               0.0
# 56154              0.0               0.0
# 34807            240.0             240.0
# 5908              30.0              30.0
# 2898              33.0              33.0
# 73058              3.0               3.0
# 39547              7.0               7.0
# 51310             98.0              98.0
#
# [10 rows x 45 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[9.94681439e-01, 5.31856136e-03],
#        [9.85462004e-01, 1.45379962e-02],
#        [9.95929268e-01, 4.07073218e-03],
#        ...,
#        [9.99411222e-01, 5.88778267e-04],
#        [9.99222528e-01, 7.77472213e-04],
#        [9.99763768e-01, 2.36231703e-04]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     vistas_al_aviso cantidad lo_vio  \
# 0   Graduado    ...                 NaN      0.0  False
# 1          -    ...                 NaN      0.0  False
# 2   Graduado    ...                 NaN      0.0  False
# 3   Graduado    ...                 NaN      0.0  False
# 4          -    ...                 NaN      0.0  False
#
#   postulaciones_misma_area postulaciones_mismo_tipo postulaciones_mismo_nivel  \
# 0                      0.0                     18.0                       0.0
# 1                      5.0                     60.0                       0.0
# 2                      2.0                     19.0                       1.0
# 3                      0.0                     19.0                       0.0
# 4                      0.0                     12.0                       0.0
#
#   vistas_por_area vistas_por_tipo  vistas_por_nivel  sepostulo
# 0             4.0            24.0              24.0   0.005319
# 1             0.0             6.0               6.0   0.014538
# 2             1.0             7.0               7.0   0.004071
# 3             0.0             0.0               0.0   0.000399
# 4             0.0             3.0               3.0   0.000061
#
# [5 rows x 46 columns]

# %%
prediccion=prediccion[['id','sepostulo']]
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.005319
# 1   1   0.014538
# 2   2   0.004071
# 3   3   0.000399
# 4   4   0.000061

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion58.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.4575268134795598
