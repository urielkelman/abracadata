# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/1.csv")

postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones2=pd.merge(postulaciones2,postulantes,on='idpostulante')

postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones2=pd.merge(postulaciones2,avisos,on='idaviso')

postulaciones2.head()
# Out:
#       idaviso idpostulante  sepostulo  sexo  edad Doctorado Master Otro  \
# 0  1112257047      akjmXXq          0   FEM  28.0         -      -    -
# 1  1112257047      MV6b6R9          0   FEM  30.0         -      -    -
# 2  1112257047      zvxv1Rm          0   FEM  22.0         -      -    -
# 3  1112257047       8oqJzL          0  MASC  34.0         -      -    -
# 4  1112257047       ez533B          0  MASC  32.0         -      -    -
#
#   Posgrado Secundario       ...       secundario viajar empresa_importante  \
# 0        -   Graduado       ...             True  False              False
# 1        -          -       ...             True  False              False
# 2        -   Graduado       ...             True  False              False
# 3        -          -       ...             True  False              False
# 4        -   Graduado       ...             True  False              False
#
#   capacitacion remuneracion_pretendida graduados estudiantes  \
# 0         True                   False     False       False
# 1         True                   False     False       False
# 2         True                   False     False       False
# 3         True                   False     False       False
# 4         True                   False     False       False
#
#   conocimientos_especificos  buen_ambiente  discriminacion
# 0                     False          False           False
# 1                     False          False           False
# 2                     False          False           False
# 3                     False          False           False
# 4                     False          False           False
#
# [5 rows x 35 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo sexo  edad Doctorado Master Otro  \
# 0  1112257047         NM5M          1  FEM  47.0         -      -    -
# 1  1112257047       1kJqGb          1  FEM  34.0         -      -    -
# 2  1112257047       eOE9Rr          1  FEM  39.0         -      -    -
# 3  1112257047       Zrx8Xz          1  FEM  39.0         -      -    -
# 4  1112257047       ZrKNQY          1  FEM  32.0         -      -    -
#
#   Posgrado Secundario       ...       secundario viajar empresa_importante  \
# 0        -   Graduado       ...             True  False              False
# 1        -          -       ...             True  False              False
# 2        -   Graduado       ...             True  False              False
# 3        -          -       ...             True  False              False
# 4        -   Graduado       ...             True  False              False
#
#   capacitacion remuneracion_pretendida graduados estudiantes  \
# 0         True                   False     False       False
# 1         True                   False     False       False
# 2         True                   False     False       False
# 3         True                   False     False       False
# 4         True                   False     False       False
#
#   conocimientos_especificos  buen_ambiente  discriminacion
# 0                     False          False           False
# 1                     False          False           False
# 2                     False          False           False
# 3                     False          False           False
# 4                     False          False           False
#
# [5 rows x 35 columns]

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 12377268
# 12332167

# %%
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 395895    1112369306      6rP8A9r          1  MASC  35.0         -      -
# 5454125   1112396113      mzda94E          1   FEM  24.0         -      -
# 5401233   1112357032      kP0ZjaQ          1  MASC  26.0         -      -
# 11184290  1112373477       1bZB8L          0  MASC  35.0         -      -
# 11579210  1112337804      96zewX9          0   FEM  19.0         -      -
# 2220979   1112305215      96LqQ0w          1  MASC  27.0         -      -
# 3528669   1112381105      2zPD4Ax          1   FEM  20.0         -      -
# 243285    1112260584      W9Wm80e          1   FEM  24.0         -      -
# 6402860   1111305364       Z302Vz          0   FEM  26.0         -      -
# 1588988   1112457520      lDLlY03          1  MASC  18.0         -      -
# 5883775   1112382162      X95J8QJ          1  MASC  40.0         -      -
# 12269087  1112458318       Z1YPP1          0  MASC  31.0         -      -
# 5088840   1112318490       ZOmd28          1  MASC  33.0         -      -
# 8057962   1112326450       5NaX5w          0  MASC  30.0         -      -
# 7142336   1112303576      xkpYOb0          0   FEM  23.0         -      -
# 9166360   1112244139       NjGLAl          0  MASC  38.0         -      -
# 12188734  1112254649      Eze3aY2          0   FEM  24.0         -      -
# 474857    1112397484       ZZzJKZ          1  MASC  29.0         -      -
# 3092946   1112361693      mzdz89G          1   FEM  51.0         -      -
# 2013155   1112334806      ZDlOJQR          1  MASC  21.0         -      -
#
#               Otro  Posgrado  Secundario    ...    viajar empresa_importante  \
# 395895           -         -    Graduado    ...     False              False
# 5454125          -         -    Graduado    ...     False              False
# 5401233          -         -    En Curso    ...     False              False
# 11184290         -         -    Graduado    ...     False              False
# 11579210         -         -    Graduado    ...     False              False
# 2220979          -         -    Graduado    ...     False              False
# 3528669          -         -           -    ...     False               True
# 243285           -         -    Graduado    ...     False              False
# 6402860          -  En Curso    Graduado    ...     False              False
# 1588988          -         -    Graduado    ...     False              False
# 5883775          -         -           -    ...     False               True
# 12269087         -         -    Graduado    ...     False              False
# 5088840   Graduado         -    Graduado    ...     False               True
# 8057962          -         -  Abandonado    ...     False               True
# 7142336          -         -    Graduado    ...     False              False
# 9166360          -  Graduado    Graduado    ...     False              False
# 12188734         -         -    Graduado    ...     False               True
# 474857           -         -           -    ...     False              False
# 3092946          -         -    Graduado    ...     False               True
# 2013155          -         -    Graduado    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 395895           True                   False     False       False
# 5454125          True                   False     False       False
# 5401233         False                   False     False       False
# 11184290         True                   False     False       False
# 11579210        False                   False     False       False
# 2220979         False                   False     False       False
# 3528669         False                   False     False       False
# 243285          False                   False     False       False
# 6402860         False                   False     False       False
# 1588988          True                   False     False       False
# 5883775         False                   False     False       False
# 12269087        False                   False      True        True
# 5088840         False                   False     False       False
# 8057962         False                    True     False       False
# 7142336         False                   False     False       False
# 9166360         False                   False     False       False
# 12188734        False                   False     False       False
# 474857          False                   False     False        True
# 3092946         False                   False     False       False
# 2013155          True                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 395895                       False         False           False       NaN
# 5454125                      False          True           False       NaN
# 5401233                      False         False           False       NaN
# 11184290                     False         False           False       NaN
# 11579210                     False         False           False       NaN
# 2220979                      False         False           False       NaN
# 3528669                      False          True           False       NaN
# 243285                        True         False            True       NaN
# 6402860                      False          True           False       NaN
# 1588988                      False         False           False       1.0
# 5883775                      False         False           False       NaN
# 12269087                     False         False           False       NaN
# 5088840                      False         False           False       NaN
# 8057962                      False         False           False       NaN
# 7142336                      False         False           False       NaN
# 9166360                       True         False            True       NaN
# 12188734                     False         False           False       NaN
# 474857                       False          True           False       1.0
# 3092946                      False         False           False       1.0
# 2013155                      False          True           False       NaN
#
# [20 rows x 36 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 4664890   1112378617      96lkPBP          1  MASC  25.0         -      -
# 8184428   1112383417      zvxWqb3          0  MASC  22.0         -      -
# 12104610  1112426253       ZpEKl8          0  MASC  41.0         -      -
# 5559299   1112245098      xk9AqN6          1  MASC  32.0         -      -
# 8036523   1112357771      zv8p3Jk          0   FEM  25.0         -      -
# 2689515   1112408026      MVORvdo          1   FEM  26.0         -      -
# 11371691  1112338147       8Wokmx          0   FEM  29.0         -      -
# 8896776   1112423974      8MZkb6L          0   FEM  32.0         -      -
# 488702    1112284410      RzML4A6          1   FEM  34.0         -      -
# 10282171  1112375096       8jpkeL          0   FEM  32.0         -      -
# 2738047   1112323391      kP02NpJ          1   FEM  27.0         -      -
# 6409676   1112094756       6DlXGl          0  MASC  34.0         -      -
# 6282586   1112416123       E2a4jN          0  MASC  39.0         -      -
# 5842460   1112454407      PmLEkVY          1   FEM  20.0         -      -
# 10850043  1112459934       EdZa2J          0   FEM  26.0         -      -
# 11670130  1112327516       6OD9aM          0   FEM  26.0         -      -
# 3055085   1112320214      jkjboEB          1   FEM  20.0         -      -
# 12269234  1112457499      96X3GW5          0  MASC  25.0         -      -
# 3824858   1112426706      rmd8ljQ          1   FEM  23.0         -      -
# 9101079   1112300893      JBXrvVp          0  MASC  34.0         -      -
#
#               Otro Posgrado Secundario    ...    viajar empresa_importante  \
# 4664890          -        -   Graduado    ...     False              False
# 8184428          -        -          -    ...     False              False
# 12104610         -        -          -    ...     False              False
# 5559299          -        -   Graduado    ...      True               True
# 8036523          -        -          -    ...      True              False
# 2689515          -        -   Graduado    ...     False              False
# 11371691  Graduado        -   Graduado    ...     False               True
# 8896776          -        -   Graduado    ...     False              False
# 488702           -        -   Graduado    ...     False              False
# 10282171         -        -   Graduado    ...     False              False
# 2738047          -        -          -    ...     False              False
# 6409676          -        -   Graduado    ...     False              False
# 6282586   En Curso        -   Graduado    ...     False              False
# 5842460          -        -   Graduado    ...     False              False
# 10850043         -        -   Graduado    ...     False              False
# 11670130         -        -   Graduado    ...     False              False
# 3055085          -        -          -    ...     False               True
# 12269234         -        -          -    ...     False              False
# 3824858          -        -   Graduado    ...     False              False
# 9101079          -        -   Graduado    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 4664890         False                   False     False       False
# 8184428         False                   False     False       False
# 12104610         True                   False     False       False
# 5559299         False                   False     False       False
# 8036523         False                   False     False       False
# 2689515         False                    True     False       False
# 11371691        False                   False     False        True
# 8896776         False                   False     False       False
# 488702          False                   False     False       False
# 10282171        False                   False     False       False
# 2738047         False                   False     False       False
# 6409676         False                   False     False       False
# 6282586         False                   False     False       False
# 5842460         False                   False     False        True
# 10850043        False                   False     False       False
# 11670130        False                   False     False       False
# 3055085         False                   False     False       False
# 12269234        False                   False      True       False
# 3824858         False                   False     False       False
# 9101079         False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 4664890                      False         False           False       1.0
# 8184428                      False         False           False       0.0
# 12104610                     False         False           False       0.0
# 5559299                      False         False           False       0.0
# 8036523                      False         False           False       0.0
# 2689515                      False          True           False       0.0
# 11371691                     False         False           False       0.0
# 8896776                      False         False           False       0.0
# 488702                       False          True           False       0.0
# 10282171                     False         False           False       0.0
# 2738047                      False         False           False       0.0
# 6409676                      False         False           False       0.0
# 6282586                      False         False           False       0.0
# 5842460                      False         False           False       0.0
# 10850043                     False         False           False       0.0
# 11670130                     False         False           False       0.0
# 3055085                      False         False           False       0.0
# 12269234                     False         False           False       0.0
# 3824858                      False         False            True       1.0
# 9101079                       True         False            True       0.0
#
# [20 rows x 36 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.10)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
postulaciones2=0
# Out:
# Train:  11098950 Test:  1233217

# %%
import gc
gc.collect()
# Out:
# 379

# %%
c=lgb.LGBMClassifier(learning_rate=0.01,objective='binary',num_leaves=4096,max_depth=13,n_estimators=500,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 73.05956696996554
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV2.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV2.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante        sexo   edad Doctorado    Master  \
# 9768   45227  1112428056        eAqLB         FEM   42.0         -         -
# 59400  11690  1111967568       1rr21z         FEM   45.0         -  Graduado
# 80866  28370  1112361855       62ozqM        MASC   44.0         -  Graduado
# 7468   88872  1112467020       59ZX6v         FEM   27.0         -         -
# 67687  13718  1112053350       eRmNkW  NO_DECLARA  200.0         -         -
# 87441  40951  1112420315       Nk2kMB         FEM   29.0         -         -
# 17827  73243  1112463356      akxx2MZ         FEM   22.0         -         -
# 45864   1931  1111159295       ZxdjaP         FEM   28.0         -         -
# 3628   82420  1112466202      vVD1O11         FEM   21.0         -         -
# 12356   4529  1111473085      ZDlp3BR        MASC   33.0         -         -
#
#            Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 9768          -         -   Graduado    ...     False               True
# 59400         -         -   Graduado    ...     False               True
# 80866  Graduado  Graduado   Graduado    ...     False              False
# 7468          -         -          -    ...     False              False
# 67687         -         -          -    ...     False              False
# 87441         -  En Curso   Graduado    ...     False              False
# 17827         -         -   Graduado    ...     False              False
# 45864         -         -          -    ...     False              False
# 3628          -         -   Graduado    ...     False              False
# 12356         -         -   Graduado    ...     False              False
#
#       capacitacion remuneracion_pretendida graduados estudiantes  \
# 9768         False                   False     False       False
# 59400        False                   False     False       False
# 80866        False                   False     False       False
# 7468          True                   False     False       False
# 67687        False                   False     False       False
# 87441        False                   False     False       False
# 17827        False                   False     False       False
# 45864        False                   False     False       False
# 3628         False                   False     False       False
# 12356        False                   False     False        True
#
#       conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 9768                       True         False            True       0.0
# 59400                     False         False           False       0.0
# 80866                     False         False           False       0.0
# 7468                      False          True           False       2.0
# 67687                     False         False           False       0.0
# 87441                     False         False           False       0.0
# 17827                     False         False           False       2.0
# 45864                     False          True           False       0.0
# 3628                      False         False           False       4.0
# 12356                      True         False            True       1.0
#
# [10 rows x 36 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.56776242, 0.43223758],
#        [0.59290862, 0.40709138],
#        [0.6106354 , 0.3893646 ],
#        ...,
#        [0.88392471, 0.11607529],
#        [0.66282231, 0.33717769],
#        [0.95549022, 0.04450978]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     empresa_importante capacitacion  \
# 0   Graduado    ...                  False        False
# 1          -    ...                  False        False
# 2   Graduado    ...                  False        False
# 3   Graduado    ...                  False        False
# 4          -    ...                  False        False
#
#   remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 0                   False     False       False                     False
# 1                   False     False       False                     False
# 2                   False     False       False                     False
# 3                   False     False       False                     False
# 4                   False     False       False                     False
#
#   buen_ambiente discriminacion  cantidad  sepostulo
# 0         False          False       0.0   0.432238
# 1         False          False       0.0   0.407091
# 2         False          False       0.0   0.389365
# 3         False          False       0.0   0.193142
# 4         False          False       0.0   0.330751
#
# [5 rows x 37 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.432238
# 1   1   0.407091
# 2   2   0.389365
# 3   3   0.193142
# 4   4   0.330751

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion15.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5999344636156241
