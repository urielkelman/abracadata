# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')
avisos['denominacion_empresa']=avisos['denominacion_empresa'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#       idaviso idpostulante
# 0  1111780242      YjVJQ6Z
# 1  1112263876      BmVpYoR
# 2  1112327963      wVkBzZd
# 3  1112318643      OqmP9pv
# 4  1111903673      DrpbXDP

# %%
vistas_por_area=vistas.copy()
vistas_por_area['vistas_por_area']=0;
vistas_por_area=pd.merge(vistas_por_area,avisos,on='idaviso', how='left')
vistas_por_area=vistas_por_area.groupby(['idpostulante','nombre_area'],as_index=False).agg({'vistas_por_area':'count'})
vistas_por_area.head()
# Out:
#   idpostulante            nombre_area  vistas_por_area
# 0        0005E  Tecnologia / Sistemas                2
# 1        00Lkv      Comercio Exterior                2
# 2        00dMd      Comercio Exterior                4
# 3        01QAq           Contabilidad                1
# 4        021OM      Comercio Exterior                5

# %%
vistas_por_nivel=vistas.copy()
vistas_por_nivel['vistas_por_nivel']=0;
vistas_por_nivel=pd.merge(vistas_por_nivel,avisos,on='idaviso', how='left')
vistas_por_nivel=vistas_por_nivel.groupby(['idpostulante','nivel_laboral'],as_index=False).agg({'vistas_por_nivel':'count'})
vistas_por_nivel.head()
# Out:
#   idpostulante nivel_laboral  vistas_por_nivel
# 0        0005E          Otro                 2
# 1        00Lkv          Otro                 2
# 2        00dMd          Otro                 4
# 3        01QAq          Otro                 1
# 4        021OM          Otro                 5

# %%
vistas_por_tipo=vistas.copy()
vistas_por_tipo['vistas_por_tipo']=0;
vistas_por_tipo=pd.merge(vistas_por_tipo,avisos,on='idaviso', how='left')
vistas_por_tipo=vistas_por_tipo.groupby(['idpostulante','tipo_de_trabajo'],as_index=False).agg({'vistas_por_tipo':'count'})
vistas_por_tipo.head()
# Out:
#   idpostulante tipo_de_trabajo  vistas_por_tipo
# 0        0005E       Full-time                2
# 1        00Lkv       Full-time                2
# 2        00dMd       Full-time                4
# 3        01QAq       Full-time                1
# 4        021OM       Full-time                5

# %%
vistas['cantidad']=0
vistas2=vistas.groupby(['idaviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q        15
# 1        0005E        58
# 2        000R8        14
# 3        001XE        26
# 4        003k9        32

# %%
vistas3=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           2          28
# 1    48375       RwVdKR           1          15
# 2   169730        1KjXB           2          99
# 3   169730       2AKzxa           2           2
# 4   169730        6LJ64           1          23

# %%
vistas3['cantidad']=vistas3['cantidad_x']/vistas3['cantidad_y']
vistas3.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.071429
# 1    48375       RwVdKR  0.066667
# 2   169730        1KjXB  0.020202
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.043478

# %%
vistas=vistas.rename(columns={'cantidad': 'vistas_postulante'})
vistas2=vistas2.rename(columns={'cantidad': 'vistas_al_aviso'})

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/7.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/8.csv").sample(len(postulaciones2)//2).reset_index(drop=True))
print(len(postulaciones2))
postulaciones2
# Out:
# 9906801
#             idaviso idpostulante  sepostulo
# 0        1112389495       5NbOjG          0
# 1        1112024109      1QP841b          0
# 2        1112490884      96XQ6N9          0
# 3        1111474259      qe2QJj1          0
# 4        1112211292      KBzbBJm          0
# 5        1112328485      3NzZv26          0
# 6        1112474766      akDjWwE          0
# 7        1112312385       aZpBJW          0
# 8        1112285628      akDWj55          0
# 9        1112322843      GNd0KNN          0
# 10       1112355899      DrXPRJX          0
# 11       1112461865      8MPoBDR          0
# 12       1111673413       a1NjRN          0
# 13       1112299006      jkVWXRQ          0
# 14       1112501771      owz0YGW          0
# 15       1002543409       Ej5AAb          0
# 16       1112425310      KBrpAO2          0
# 17       1112498569      pzNMppM          0
# 18       1111866251       ZKqL85          0
# 19       1112289529      ow2awXr          0
# 20       1112493109      5mP1DWM          0
# 21       1112326017      0zd9GZ9          0
# 22       1112242315      3NQKV6Q          0
# 23       1112452417      DrlVEwW          0
# 24       1112402816      mzdk9dZ          0
# 25       1112359100      3NP46xq          0
# 26       1112410555      bOVKA32          0
# 27       1112511403      mzdlAQO          0
# 28       1111272539      6rPpNM4          0
# 29       1111591317      6rP4K13          0
# ...             ...          ...        ...
# 3302237  1112511361      4rdGdjA          0
# 3302238  1112261522      W9OXGBm          0
# 3302239  1111946162       ZR5aeE          0
# 3302240  1112242646      ek4k4M2          0
# 3302241  1112463152      6rPN1XL          0
# 3302242  1112136749      4re0Xez          0
# 3302243  1112289599      lDbkPY3          0
# 3302244  1112423441      PmJ3OeY          0
# 3302245  1112487440       8JbKbL          0
# 3302246  1112513114      ow2Ov4L          0
# 3302247  1111260976      kPjbPkW          0
# 3302248  1112121318       e0jEm8          0
# 3302249  1111339678      GNZq0QE          0
# 3302250  1112250437       ZjOKMY          0
# 3302251  1112217568      3NQv0Za          0
# 3302252  1112298069      JBrQ6vp          0
# 3302253  1112396959      8MZNaVM          0
# 3302254  1112492888      96X6KvY          0
# 3302255  1112504203      dYJRL4b          0
# 3302256  1112317933      GNZQGw8          0
# 3302257  1112430740       83GZKL          0
# 3302258  1110968766      VNrMJZD          0
# 3302259  1112445889       52Zkvv          0
# 3302260  1112359883      4rNrAYM          0
# 3302261  1112508180      0zrkapa          0
# 3302262  1111925981      lDXDQ2R          0
# 3302263     1604840      Eze855z          0
# 3302264  1112495050      zvxO1xE          0
# 3302265  1112454941      ak5vq1D          0
# 3302266  1112266293      4rW1Lm0          0
#
# [9906801 rows x 3 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 16511335
# 16502034

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas2,on=['idaviso','idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas3,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 12054403  1112365284      Bm5bmeE          1  MASC  21.0         -      -
# 12796942  1112224374      ZDPbBmY          0  MASC  36.0         -      -
# 4078381   1112444252      Ezep99N          0   FEM  19.0         -      -
# 8201952   1112312932      6r5w8E4          0   FEM  23.0         -      -
# 15193946  1111787924      DrJ0kmA          0  MASC  21.0         -      -
# 8275865   1112265025      zv4BG2b          1  MASC  24.0         -      -
# 10808724  1112248694      LNKao5q          0  MASC  23.0         -      -
# 5143496   1112249093      5mq3Q5z          1   FEM  19.0         -      -
# 4246301   1112460892      pz9LLY3          0  MASC  29.0         -      -
# 8852817   1112257536       EKdKz8          1   FEM  43.0         -      -
# 4607743   1112385543      dY5RlW0          1   FEM  37.0         -      -
# 4260972   1112262596       a4Ad89          0   FEM  32.0         -      -
# 11459658  1112383908      ak5AdrJ          0  MASC  35.0         -      -
# 6181758   1112257616      A3RQY1l          0  MASC  28.0         -      -
# 4279124   1112268696       1WKOKb          0  MASC  46.0         -      -
# 12052350  1112355899      X9xZvOP          1  MASC  37.0         -      -
# 12427535  1112356859       N0Q2bL          0   FEM  48.0         -      -
# 12413856  1112368074      mzVpXD9          0  MASC  38.0         -      -
# 9128492   1112369774      Bm5dRDa          1  MASC  22.0         -      -
# 7983077   1112309579      6r5doA3          1  MASC  20.0         -      -
#
#               Otro Posgrado Secundario    ...    capacitacion  \
# 12054403         -        -   Graduado    ...            True
# 12796942         -        -   Graduado    ...           False
# 4078381          -        -   Graduado    ...           False
# 8201952          -        -          -    ...           False
# 15193946         -        -   Graduado    ...           False
# 8275865   Graduado        -   Graduado    ...           False
# 10808724         -        -          -    ...           False
# 5143496          -        -   Graduado    ...            True
# 4246301   Graduado        -   Graduado    ...           False
# 8852817   En Curso        -   Graduado    ...           False
# 4607743          -        -          -    ...           False
# 4260972          -        -   Graduado    ...           False
# 11459658  Graduado        -   Graduado    ...           False
# 6181758          -        -   Graduado    ...           False
# 4279124          -        -          -    ...           False
# 12052350  Graduado        -   Graduado    ...           False
# 12427535         -        -          -    ...            True
# 12413856         -        -   Graduado    ...           False
# 9128492          -        -   Graduado    ...           False
# 7983077          -        -          -    ...            True
#
#          remuneracion_pretendida graduados estudiantes  \
# 12054403                   False     False       False
# 12796942                   False     False       False
# 4078381                    False     False       False
# 8201952                     True     False       False
# 15193946                   False     False       False
# 8275865                    False     False       False
# 10808724                   False     False       False
# 5143496                    False     False       False
# 4246301                    False     False       False
# 8852817                    False     False       False
# 4607743                    False     False       False
# 4260972                    False     False       False
# 11459658                   False     False       False
# 6181758                    False     False       False
# 4279124                    False     False       False
# 12052350                   False     False       False
# 12427535                   False     False       False
# 12413856                   False     False       False
# 9128492                    False     False       False
# 7983077                    False     False       False
#
#          conocimientos_especificos buen_ambiente discriminacion  \
# 12054403                     False         False          False
# 12796942                     False         False          False
# 4078381                      False         False          False
# 8201952                      False          True          False
# 15193946                     False         False          False
# 8275865                      False         False          False
# 10808724                     False         False          False
# 5143496                      False          True          False
# 4246301                      False         False          False
# 8852817                      False          True          False
# 4607743                      False         False          False
# 4260972                      False         False          False
# 11459658                      True         False           True
# 6181758                      False         False          False
# 4279124                       True         False           True
# 12052350                     False         False          False
# 12427535                     False          True          False
# 12413856                      True         False           True
# 9128492                      False         False          False
# 7983077                      False         False          False
#
#          vistas_postulante  vistas_al_aviso  cantidad
# 12054403              22.0              NaN       NaN
# 12796942              89.0              NaN       NaN
# 4078381                NaN              NaN       NaN
# 8201952               27.0              NaN       NaN
# 15193946             132.0              NaN       NaN
# 8275865               15.0              NaN       NaN
# 10808724               1.0              NaN       NaN
# 5143496              121.0              NaN       NaN
# 4246301               29.0              NaN       NaN
# 8852817                NaN              NaN       NaN
# 4607743               19.0              NaN       NaN
# 4260972                NaN              NaN       NaN
# 11459658              16.0              NaN       NaN
# 6181758               28.0              NaN       NaN
# 4279124                NaN              NaN       NaN
# 12052350               6.0              NaN       NaN
# 12427535               5.0              NaN       NaN
# 12413856              40.0              NaN       NaN
# 9128492               13.0              NaN       NaN
# 7983077               13.0              NaN       NaN
#
# [20 rows x 38 columns]

# %%
postulaciones['cantidad']=postulaciones['cantidad'].fillna(0)
postulaciones['vistas_postulante']=postulaciones['vistas_postulante'].fillna(0)
postulaciones['vistas_al_aviso']=postulaciones['vistas_al_aviso'].fillna(0)
postulaciones['lo_vio']=(postulaciones['vistas_al_aviso']>0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo        sexo   edad Doctorado  \
# 1672564   1112419038      jk5pbzr          1         FEM   39.0         -
# 12902602  1111931601      bOzQlGb          0        MASC   20.0         -
# 11958208  1112230196      MVd5Aex          0        MASC   41.0         -
# 8671354   1112382258       eJWD59          1         FEM   28.0         -
# 11235275  1112246784      ekO6Wbr          0         FEM   36.0         -
# 4231151   1112362565       8VAvLW          1        MASC   32.0         -
# 5229150   1112084995       aGPrp9          0        MASC   45.0         -
# 9555560   1112393693      A3X11Mj          1        MASC  200.0         -
# 9037221   1112079850      PmG4P3a          0        MASC   29.0         -
# 13857351  1112494488      DrJOxkL          0        MASC   28.0         -
# 11379262  1112442250       E4PDk4          1        MASC   34.0         -
# 5268773   1112199970       EJDP69          0         FEM   30.0         -
# 3387551   1112393836      vVD1A9G          1  NO_DECLARA   24.0         -
# 13831803  1110768790      kPjO5bJ          0         FEM   23.0         -
# 9715221   1112341717      8MP3J6x          1         FEM   19.0         -
# 8311939   1112218995       Z601e8          0        MASC   31.0         -
# 8348564   1112443761       ed1qWj          0        MASC   35.0         -
# 12041972  1112417472      RzNlZ1Y          0        MASC   24.0         -
# 7440243   1112291131      Bm52e1E          0         FEM   21.0         -
# 1629075   1112437803      2zwKkW1          0        MASC   32.0         -
#
#             Master      Otro Posgrado  Secundario   ...    \
# 1672564          -         -        -    Graduado   ...
# 12902602         -         -        -    Graduado   ...
# 11958208         -         -        -  Abandonado   ...
# 8671354          -         -        -    Graduado   ...
# 11235275         -         -        -    Graduado   ...
# 4231151          -         -        -           -   ...
# 5229150          -         -        -           -   ...
# 9555560          -         -        -    Graduado   ...
# 9037221          -         -        -           -   ...
# 13857351         -         -        -           -   ...
# 11379262         -         -        -    Graduado   ...
# 5268773          -         -        -           -   ...
# 3387551          -         -        -           -   ...
# 13831803         -         -        -           -   ...
# 9715221          -         -        -    Graduado   ...
# 8311939          -         -        -    Graduado   ...
# 8348564   Graduado         -        -    Graduado   ...
# 12041972         -  Graduado        -    Graduado   ...
# 7440243          -         -        -           -   ...
# 1629075          -         -        -    Graduado   ...
#
#          remuneracion_pretendida graduados estudiantes  \
# 1672564                    False     False       False
# 12902602                   False     False       False
# 11958208                   False     False       False
# 8671354                    False     False       False
# 11235275                   False     False       False
# 4231151                    False     False       False
# 5229150                    False     False       False
# 9555560                    False     False       False
# 9037221                    False     False       False
# 13857351                   False     False       False
# 11379262                   False     False       False
# 5268773                    False     False       False
# 3387551                     True     False       False
# 13831803                   False     False       False
# 9715221                    False     False       False
# 8311939                    False      True        True
# 8348564                    False     False       False
# 12041972                   False     False       False
# 7440243                    False     False       False
# 1629075                    False     False       False
#
#          conocimientos_especificos buen_ambiente discriminacion  \
# 1672564                      False          True          False
# 12902602                     False         False          False
# 11958208                     False         False          False
# 8671354                      False         False          False
# 11235275                     False         False          False
# 4231151                      False         False          False
# 5229150                      False          True          False
# 9555560                      False         False          False
# 9037221                      False          True          False
# 13857351                     False         False          False
# 11379262                     False         False          False
# 5268773                      False         False          False
# 3387551                      False         False          False
# 13831803                     False         False          False
# 9715221                      False         False          False
# 8311939                      False         False          False
# 8348564                      False         False          False
# 12041972                     False         False          False
# 7440243                      False          True          False
# 1629075                      False         False          False
#
#          vistas_postulante vistas_al_aviso  cantidad  lo_vio
# 1672564               31.0             0.0  0.000000   False
# 12902602               1.0             0.0  0.000000   False
# 11958208               2.0             0.0  0.000000   False
# 8671354              126.0             0.0  0.000000   False
# 11235275               0.0             0.0  0.000000   False
# 4231151             1299.0             2.0  0.001540    True
# 5229150               24.0             0.0  0.000000   False
# 9555560                2.0             0.0  0.000000   False
# 9037221               18.0             0.0  0.000000   False
# 13857351               9.0             0.0  0.000000   False
# 11379262              73.0             1.0  0.013699    True
# 5268773              116.0             0.0  0.000000   False
# 3387551              164.0             1.0  0.006098    True
# 13831803               2.0             0.0  0.000000   False
# 9715221              132.0             1.0  0.007576    True
# 8311939                0.0             0.0  0.000000   False
# 8348564               18.0             0.0  0.000000   False
# 12041972               0.0             0.0  0.000000   False
# 7440243                9.0             0.0  0.000000   False
# 1629075                0.0             0.0  0.000000   False
#
# [20 rows x 39 columns]

# %%
postulaciones_por_area=postulaciones.copy()
postulaciones_por_area=postulaciones_por_area.groupby(by=['idpostulante','nombre_area'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_area=postulaciones_por_area.rename(columns={'sepostulo':'postulaciones_misma_area'})
postulaciones_por_area.head()
# Out:
#   idpostulante                      nombre_area  postulaciones_misma_area
# 0      0z5Dmrd                   Abastecimiento                         1
# 1      0z5Dmrd                   Administración                         1
# 2      0z5Dmrd  Almacén / Depósito / Expedición                         1
# 3      0z5Dmrd              Atención al Cliente                         1
# 4      0z5Dmrd                        Auditoría                         1

# %%
postulaciones_por_nivel=postulaciones.copy()
postulaciones_por_nivel=postulaciones_por_nivel.groupby(by=['idpostulante','nivel_laboral'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_nivel=postulaciones_por_nivel.rename(columns={'sepostulo':'postulaciones_mismo_nivel'})
postulaciones_por_nivel.head()
# Out:
#   idpostulante                         nivel_laboral  \
# 0      0z5Dmrd                                     -
# 1      0z5Dmrd  Gerencia / Alta Gerencia / Dirección
# 2      0z5Dmrd                                Junior
# 3      0z5Dmrd                                  Otro
# 4      0z5Dmrd                  Senior / Semi-Senior
#
#    postulaciones_mismo_nivel
# 0                          1
# 1                          1
# 2                          4
# 3                          1
# 4                         16

# %%
postulaciones_por_tipo=postulaciones.copy()
postulaciones_por_tipo=postulaciones_por_tipo.groupby(by=['idpostulante','tipo_de_trabajo'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_tipo=postulaciones_por_tipo.rename(columns={'sepostulo':'postulaciones_mismo_tipo'})
postulaciones_por_tipo.head()
# Out:
#   idpostulante tipo_de_trabajo  postulaciones_mismo_tipo
# 0      0z5Dmrd       Full-time                        22
# 1      0z5Dmrd       Part-time                         1
# 2      0z5JW1r       Full-time                        25
# 3      0z5JW1r     Teletrabajo                         1
# 4      0z5VvGv       Full-time                        54

# %%
postulaciones=pd.merge(postulaciones,postulaciones_por_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['postulaciones_misma_area']=postulaciones['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_nivel']=postulaciones['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_tipo']=postulaciones['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones=pd.merge(postulaciones,vistas_por_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,vistas_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,vistas_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['vistas_por_area']=postulaciones['vistas_por_area'].fillna(0)
postulaciones['vistas_por_tipo']=postulaciones['vistas_por_tipo'].fillna(0)
postulaciones['vistas_por_nivel']=postulaciones['vistas_por_tipo'].fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado    Master  \
# 7893083   1112467497      Eze4EXz          0   FEM  25.0         -         -
# 12081947  1112373831      969Wqd5          1  MASC  33.0         -         -
# 1248102   1112295763      8M2NQVR          0  MASC  21.0         -         -
# 8912685   1112411627      akxkGrq          0  MASC  33.0         -         -
# 12638749  1112328929      ZDPoxJb          1  MASC  25.0         -         -
# 3073869   1112378542      JBeojok          1  MASC  64.0         -  Graduado
# 4818956   1112341591      bOABLjB          0   FEM  27.0         -         -
# 3713027   1112219991      mzb5Zo9          0  MASC  26.0         -         -
# 8785900   1111848493      JBxQAMO          0   FEM  20.0         -         -
# 9725815   1112454264      OqmBl5r          0  MASC  28.0         -         -
# 3752091   1112323293      Ezej6G8          0   FEM  34.0         -         -
# 12415897  1112480284      wVj1k3m          0   FEM  21.0         -         -
# 5829680   1112269433      KBaM66j          1  MASC  20.0         -         -
# 1257006   1112402769       6QKa2j          1   FEM  39.0         -         -
# 14874726  1111219943      X9xO4bO          0   FEM  35.0         -         -
# 13448056  1111049709      JBXjm2e          0   FEM  29.0         -         -
# 1656755   1112230537      wVoGxal          1  MASC  36.0         -         -
# 12341533  1112345896      akjK4e5          0  MASC  19.0         -         -
# 9877633   1112351763      3NPbAz6          0  MASC  31.0         -         -
# 11193610  1112494643      VNebRxd          0   FEM  27.0         -         -
#
#               Otro  Posgrado Secundario        ...        vistas_postulante  \
# 7893083          -         -   Graduado        ...                     77.0
# 12081947         -         -   Graduado        ...                     26.0
# 1248102   Graduado         -   Graduado        ...                     38.0
# 8912685          -         -          -        ...                     43.0
# 12638749         -         -   Graduado        ...                      0.0
# 3073869          -         -   Graduado        ...                      6.0
# 4818956   Graduado         -   Graduado        ...                      0.0
# 3713027          -         -   Graduado        ...                     19.0
# 8785900          -         -          -        ...                      0.0
# 9725815          -         -   Graduado        ...                      0.0
# 3752091          -         -   Graduado        ...                      4.0
# 12415897         -         -   Graduado        ...                     30.0
# 5829680          -         -   Graduado        ...                    766.0
# 1257006   Graduado  Graduado   Graduado        ...                    238.0
# 14874726  En Curso         -   Graduado        ...                     91.0
# 13448056  Graduado         -   Graduado        ...                      0.0
# 1656755          -         -          -        ...                    351.0
# 12341533         -         -   Graduado        ...                    145.0
# 9877633          -         -   Graduado        ...                      0.0
# 11193610         -         -   Graduado        ...                      3.0
#
#          vistas_al_aviso  cantidad lo_vio postulaciones_misma_area  \
# 7893083              0.0  0.000000  False                        0
# 12081947             0.0  0.000000  False                        4
# 1248102              0.0  0.000000  False                        0
# 8912685              0.0  0.000000  False                        1
# 12638749             0.0  0.000000  False                        5
# 3073869              0.0  0.000000  False                        3
# 4818956              0.0  0.000000  False                        0
# 3713027              0.0  0.000000  False                        1
# 8785900              0.0  0.000000  False                        1
# 9725815              0.0  0.000000  False                        3
# 3752091              0.0  0.000000  False                        0
# 12415897             0.0  0.000000  False                        0
# 5829680              0.0  0.000000  False                        2
# 1257006              0.0  0.000000  False                       23
# 14874726             0.0  0.000000  False                        6
# 13448056             0.0  0.000000  False                        0
# 1656755              1.0  0.002849   True                      228
# 12341533             0.0  0.000000  False                        4
# 9877633              0.0  0.000000  False                        0
# 11193610             0.0  0.000000  False                        0
#
#          postulaciones_mismo_tipo postulaciones_mismo_nivel vistas_por_area  \
# 7893083                        17                         4             3.0
# 12081947                       24                         4            18.0
# 1248102                        23                        16             0.0
# 8912685                        21                        17             0.0
# 12638749                       33                         4             0.0
# 3073869                        31                         1             0.0
# 4818956                        15                        11             0.0
# 3713027                        88                        22             2.0
# 8785900                         6                         3             0.0
# 9725815                        28                        17             0.0
# 3752091                        26                         2             0.0
# 12415897                       21                        17             0.0
# 5829680                       903                       249             4.0
# 1257006                       148                        23            21.0
# 14874726                       36                        29             8.0
# 13448056                       49                        37             0.0
# 1656755                       293                         7           267.0
# 12341533                        7                        93             4.0
# 9877633                        45                        37             0.0
# 11193610                       19                        11             0.0
#
#           vistas_por_tipo  vistas_por_nivel
# 7893083              44.0              44.0
# 12081947             24.0              24.0
# 1248102              21.0              21.0
# 8912685              34.0              34.0
# 12638749              0.0               0.0
# 3073869               6.0               6.0
# 4818956               0.0               0.0
# 3713027              17.0              17.0
# 8785900               0.0               0.0
# 9725815               0.0               0.0
# 3752091               4.0               4.0
# 12415897             12.0              12.0
# 5829680             595.0             595.0
# 1257006             209.0             209.0
# 14874726             56.0              56.0
# 13448056              0.0               0.0
# 1656755             307.0             307.0
# 12341533              8.0               8.0
# 9877633               0.0               0.0
# 11193610              3.0               3.0
#
# [20 rows x 45 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
# Out:
# Train:  15281900 Test:  804311

# %%
gc.collect()
# Out:
# 312

# %%
c=lgb.LGBMClassifier(learning_rate=0.05,objective='binary',num_leaves=12000,max_depth=18,n_estimators=1200,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train,eval_set=[(x_test,y_test)],verbose=True,early_stopping_rounds=1)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")
# Out:
# [1]	valid_0's binary_logloss: 0.658312
# Training until validation scores don't improve for 1 rounds.
# [2]	valid_0's binary_logloss: 0.627033
# [3]	valid_0's binary_logloss: 0.597556
# [4]	valid_0's binary_logloss: 0.569665
# [5]	valid_0's binary_logloss: 0.544345
# [6]	valid_0's binary_logloss: 0.52181
# [7]	valid_0's binary_logloss: 0.500921
# [8]	valid_0's binary_logloss: 0.480833
# [9]	valid_0's binary_logloss: 0.463009
# [10]	valid_0's binary_logloss: 0.446528
# [11]	valid_0's binary_logloss: 0.430401
# [12]	valid_0's binary_logloss: 0.415403
# [13]	valid_0's binary_logloss: 0.401543
# [14]	valid_0's binary_logloss: 0.390044
# [15]	valid_0's binary_logloss: 0.378887
# [16]	valid_0's binary_logloss: 0.369044
# [17]	valid_0's binary_logloss: 0.358196
# [18]	valid_0's binary_logloss: 0.349108
# [19]	valid_0's binary_logloss: 0.339544
# [20]	valid_0's binary_logloss: 0.331544
# [21]	valid_0's binary_logloss: 0.323127
# [22]	valid_0's binary_logloss: 0.315192
# [23]	valid_0's binary_logloss: 0.308528
# [24]	valid_0's binary_logloss: 0.302594
# [25]	valid_0's binary_logloss: 0.29583
# [26]	valid_0's binary_logloss: 0.289505
# [27]	valid_0's binary_logloss: 0.283561
# [28]	valid_0's binary_logloss: 0.279119
# [29]	valid_0's binary_logloss: 0.274481
# [30]	valid_0's binary_logloss: 0.26942
# [31]	valid_0's binary_logloss: 0.26546
# [32]	valid_0's binary_logloss: 0.261094
# [33]	valid_0's binary_logloss: 0.257429
# [34]	valid_0's binary_logloss: 0.253612
# [35]	valid_0's binary_logloss: 0.250094
# [36]	valid_0's binary_logloss: 0.246993
# [37]	valid_0's binary_logloss: 0.244079
# [38]	valid_0's binary_logloss: 0.241382
# [39]	valid_0's binary_logloss: 0.238183
# [40]	valid_0's binary_logloss: 0.235336
# [41]	valid_0's binary_logloss: 0.232635
# [42]	valid_0's binary_logloss: 0.229903
# [43]	valid_0's binary_logloss: 0.22732
# [44]	valid_0's binary_logloss: 0.224888
# [45]	valid_0's binary_logloss: 0.2226
# [46]	valid_0's binary_logloss: 0.220535
# [47]	valid_0's binary_logloss: 0.218348
# [48]	valid_0's binary_logloss: 0.216336
# [49]	valid_0's binary_logloss: 0.214529
# [50]	valid_0's binary_logloss: 0.212774
# [51]	valid_0's binary_logloss: 0.211051
# [52]	valid_0's binary_logloss: 0.209312
# [53]	valid_0's binary_logloss: 0.207901
# [54]	valid_0's binary_logloss: 0.206384
# [55]	valid_0's binary_logloss: 0.20506
# [56]	valid_0's binary_logloss: 0.203758
# [57]	valid_0's binary_logloss: 0.202584
# [58]	valid_0's binary_logloss: 0.20167
# [59]	valid_0's binary_logloss: 0.200412
# [60]	valid_0's binary_logloss: 0.199449
# [61]	valid_0's binary_logloss: 0.198363
# [62]	valid_0's binary_logloss: 0.19747
# [63]	valid_0's binary_logloss: 0.196473
# [64]	valid_0's binary_logloss: 0.195624
# [65]	valid_0's binary_logloss: 0.194981
# [66]	valid_0's binary_logloss: 0.194351
# [67]	valid_0's binary_logloss: 0.193512
# [68]	valid_0's binary_logloss: 0.192616
# [69]	valid_0's binary_logloss: 0.19188
# [70]	valid_0's binary_logloss: 0.191143
# [71]	valid_0's binary_logloss: 0.190384
# [72]	valid_0's binary_logloss: 0.18965
# [73]	valid_0's binary_logloss: 0.189047
# [74]	valid_0's binary_logloss: 0.188437
# [75]	valid_0's binary_logloss: 0.18802
# [76]	valid_0's binary_logloss: 0.18752
# [77]	valid_0's binary_logloss: 0.18703
# [78]	valid_0's binary_logloss: 0.186485
# [79]	valid_0's binary_logloss: 0.186002
# [80]	valid_0's binary_logloss: 0.185679
# [81]	valid_0's binary_logloss: 0.185372
# [82]	valid_0's binary_logloss: 0.184952
# [83]	valid_0's binary_logloss: 0.184333
# [84]	valid_0's binary_logloss: 0.18388
# [85]	valid_0's binary_logloss: 0.183541
# [86]	valid_0's binary_logloss: 0.183169
# [87]	valid_0's binary_logloss: 0.18286
# [88]	valid_0's binary_logloss: 0.182345
# [89]	valid_0's binary_logloss: 0.182064
# [90]	valid_0's binary_logloss: 0.181664
# [91]	valid_0's binary_logloss: 0.181419
# [92]	valid_0's binary_logloss: 0.181161
# [93]	valid_0's binary_logloss: 0.180891
# [94]	valid_0's binary_logloss: 0.180641
# [95]	valid_0's binary_logloss: 0.18023
# [96]	valid_0's binary_logloss: 0.179802
# [97]	valid_0's binary_logloss: 0.179583
# [98]	valid_0's binary_logloss: 0.179431
# [99]	valid_0's binary_logloss: 0.179254
# [100]	valid_0's binary_logloss: 0.179081
# [101]	valid_0's binary_logloss: 0.178884
# [102]	valid_0's binary_logloss: 0.178743
# [103]	valid_0's binary_logloss: 0.178558
# [104]	valid_0's binary_logloss: 0.178174
# [105]	valid_0's binary_logloss: 0.177992
# [106]	valid_0's binary_logloss: 0.177891
# [107]	valid_0's binary_logloss: 0.177781
# [108]	valid_0's binary_logloss: 0.177649
# [109]	valid_0's binary_logloss: 0.177485
# [110]	valid_0's binary_logloss: 0.177388
# [111]	valid_0's binary_logloss: 0.177272
# [112]	valid_0's binary_logloss: 0.177036
# [113]	valid_0's binary_logloss: 0.176958
# [114]	valid_0's binary_logloss: 0.176784
# [115]	valid_0's binary_logloss: 0.1767
# [116]	valid_0's binary_logloss: 0.176426
# [117]	valid_0's binary_logloss: 0.176331
# [118]	valid_0's binary_logloss: 0.176254
# [119]	valid_0's binary_logloss: 0.175943
# [120]	valid_0's binary_logloss: 0.175866
# [121]	valid_0's binary_logloss: 0.175612
# [122]	valid_0's binary_logloss: 0.175382
# [123]	valid_0's binary_logloss: 0.175328
# [124]	valid_0's binary_logloss: 0.175272
# [125]	valid_0's binary_logloss: 0.17524
# [126]	valid_0's binary_logloss: 0.175205
# [127]	valid_0's binary_logloss: 0.175177
# [128]	valid_0's binary_logloss: 0.175123
# [129]	valid_0's binary_logloss: 0.175096
# [130]	valid_0's binary_logloss: 0.175065
# [131]	valid_0's binary_logloss: 0.175019
# [132]	valid_0's binary_logloss: 0.174994
# [133]	valid_0's binary_logloss: 0.174754
# [134]	valid_0's binary_logloss: 0.174722
# [135]	valid_0's binary_logloss: 0.174701
# [136]	valid_0's binary_logloss: 0.174659
# [137]	valid_0's binary_logloss: 0.174635
# [138]	valid_0's binary_logloss: 0.174604
# [139]	valid_0's binary_logloss: 0.17458
# [140]	valid_0's binary_logloss: 0.174381
# [141]	valid_0's binary_logloss: 0.174347
# [142]	valid_0's binary_logloss: 0.174095
# [143]	valid_0's binary_logloss: 0.173922
# [144]	valid_0's binary_logloss: 0.173903
# [145]	valid_0's binary_logloss: 0.173884
# [146]	valid_0's binary_logloss: 0.173863
# [147]	valid_0's binary_logloss: 0.173698
# [148]	valid_0's binary_logloss: 0.173679
# [149]	valid_0's binary_logloss: 0.17366
# [150]	valid_0's binary_logloss: 0.173645
# [151]	valid_0's binary_logloss: 0.173311
# [152]	valid_0's binary_logloss: 0.173291
# [153]	valid_0's binary_logloss: 0.173268
# [154]	valid_0's binary_logloss: 0.173254
# [155]	valid_0's binary_logloss: 0.17323
# [156]	valid_0's binary_logloss: 0.173214
# [157]	valid_0's binary_logloss: 0.173195
# [158]	valid_0's binary_logloss: 0.173157
# [159]	valid_0's binary_logloss: 0.173134
# [160]	valid_0's binary_logloss: 0.173042
# [161]	valid_0's binary_logloss: 0.172941
# [162]	valid_0's binary_logloss: 0.172924
# [163]	valid_0's binary_logloss: 0.172889
# [164]	valid_0's binary_logloss: 0.172859
# [165]	valid_0's binary_logloss: 0.172675
# [166]	valid_0's binary_logloss: 0.172655
# [167]	valid_0's binary_logloss: 0.172643
# [168]	valid_0's binary_logloss: 0.172624
# [169]	valid_0's binary_logloss: 0.172599
# [170]	valid_0's binary_logloss: 0.172532
# [171]	valid_0's binary_logloss: 0.172511
# [172]	valid_0's binary_logloss: 0.172487
# [173]	valid_0's binary_logloss: 0.172413
# [174]	valid_0's binary_logloss: 0.172326
# [175]	valid_0's binary_logloss: 0.172313
# [176]	valid_0's binary_logloss: 0.172291
# [177]	valid_0's binary_logloss: 0.172109
# [178]	valid_0's binary_logloss: 0.172055
# [179]	valid_0's binary_logloss: 0.171889
# [180]	valid_0's binary_logloss: 0.17168
# [181]	valid_0's binary_logloss: 0.171501
# [182]	valid_0's binary_logloss: 0.171482
# [183]	valid_0's binary_logloss: 0.171469
# [184]	valid_0's binary_logloss: 0.171456
# [185]	valid_0's binary_logloss: 0.171408
# [186]	valid_0's binary_logloss: 0.17139
# [187]	valid_0's binary_logloss: 0.171368
# [188]	valid_0's binary_logloss: 0.171357
# [189]	valid_0's binary_logloss: 0.171342
# [190]	valid_0's binary_logloss: 0.171331
# [191]	valid_0's binary_logloss: 0.171319
# [192]	valid_0's binary_logloss: 0.171307
# [193]	valid_0's binary_logloss: 0.171287
# [194]	valid_0's binary_logloss: 0.171169
# [195]	valid_0's binary_logloss: 0.171146
# [196]	valid_0's binary_logloss: 0.171132
# [197]	valid_0's binary_logloss: 0.170871
# [198]	valid_0's binary_logloss: 0.170852
# [199]	valid_0's binary_logloss: 0.170833
# [200]	valid_0's binary_logloss: 0.170811
# [201]	valid_0's binary_logloss: 0.170795
# [202]	valid_0's binary_logloss: 0.170765
# [203]	valid_0's binary_logloss: 0.170698
# [204]	valid_0's binary_logloss: 0.170687
# [205]	valid_0's binary_logloss: 0.170652
# [206]	valid_0's binary_logloss: 0.170419
# [207]	valid_0's binary_logloss: 0.170401
# [208]	valid_0's binary_logloss: 0.170349
# [209]	valid_0's binary_logloss: 0.170337
# [210]	valid_0's binary_logloss: 0.170325
# [211]	valid_0's binary_logloss: 0.170091
# [212]	valid_0's binary_logloss: 0.170076
# [213]	valid_0's binary_logloss: 0.170053
# [214]	valid_0's binary_logloss: 0.170021
# [215]	valid_0's binary_logloss: 0.170011
# [216]	valid_0's binary_logloss: 0.16991
# [217]	valid_0's binary_logloss: 0.169882
# [218]	valid_0's binary_logloss: 0.169852
# [219]	valid_0's binary_logloss: 0.169839
# [220]	valid_0's binary_logloss: 0.169806
# [221]	valid_0's binary_logloss: 0.169649
# [222]	valid_0's binary_logloss: 0.169638
# [223]	valid_0's binary_logloss: 0.16961
# [224]	valid_0's binary_logloss: 0.169562
# [225]	valid_0's binary_logloss: 0.169529
# [226]	valid_0's binary_logloss: 0.169499
# [227]	valid_0's binary_logloss: 0.169419
# [228]	valid_0's binary_logloss: 0.169162
# [229]	valid_0's binary_logloss: 0.169155
# [230]	valid_0's binary_logloss: 0.169141
# [231]	valid_0's binary_logloss: 0.168894
# [232]	valid_0's binary_logloss: 0.168875
# [233]	valid_0's binary_logloss: 0.16875
# [234]	valid_0's binary_logloss: 0.168675
# [235]	valid_0's binary_logloss: 0.168659
# [236]	valid_0's binary_logloss: 0.168652
# [237]	valid_0's binary_logloss: 0.16862
# [238]	valid_0's binary_logloss: 0.168551
# [239]	valid_0's binary_logloss: 0.16854
# [240]	valid_0's binary_logloss: 0.168527
# [241]	valid_0's binary_logloss: 0.168464
# [242]	valid_0's binary_logloss: 0.168455
# [243]	valid_0's binary_logloss: 0.168422
# [244]	valid_0's binary_logloss: 0.168416
# [245]	valid_0's binary_logloss: 0.168397
# [246]	valid_0's binary_logloss: 0.168261
# [247]	valid_0's binary_logloss: 0.168255
# [248]	valid_0's binary_logloss: 0.168163
# [249]	valid_0's binary_logloss: 0.16809
# [250]	valid_0's binary_logloss: 0.168067
# [251]	valid_0's binary_logloss: 0.168048
# [252]	valid_0's binary_logloss: 0.167884
# [253]	valid_0's binary_logloss: 0.167832
# [254]	valid_0's binary_logloss: 0.167706
# [255]	valid_0's binary_logloss: 0.167663
# [256]	valid_0's binary_logloss: 0.167651
# [257]	valid_0's binary_logloss: 0.167586
# [258]	valid_0's binary_logloss: 0.167406
# [259]	valid_0's binary_logloss: 0.167372
# [260]	valid_0's binary_logloss: 0.167056
# [261]	valid_0's binary_logloss: 0.167037
# [262]	valid_0's binary_logloss: 0.16695
# [263]	valid_0's binary_logloss: 0.166893
# [264]	valid_0's binary_logloss: 0.166823
# [265]	valid_0's binary_logloss: 0.166803
# [266]	valid_0's binary_logloss: 0.166747
# [267]	valid_0's binary_logloss: 0.166685
# [268]	valid_0's binary_logloss: 0.166668
# [269]	valid_0's binary_logloss: 0.166659
# [270]	valid_0's binary_logloss: 0.166645
# [271]	valid_0's binary_logloss: 0.166631
# [272]	valid_0's binary_logloss: 0.166621
# [273]	valid_0's binary_logloss: 0.166572
# [274]	valid_0's binary_logloss: 0.166459
# [275]	valid_0's binary_logloss: 0.166371
# [276]	valid_0's binary_logloss: 0.166361
# [277]	valid_0's binary_logloss: 0.16633
# [278]	valid_0's binary_logloss: 0.166157
# [279]	valid_0's binary_logloss: 0.166152
# [280]	valid_0's binary_logloss: 0.16612
# [281]	valid_0's binary_logloss: 0.166105
# [282]	valid_0's binary_logloss: 0.166019
# [283]	valid_0's binary_logloss: 0.166003
# [284]	valid_0's binary_logloss: 0.165982
# [285]	valid_0's binary_logloss: 0.165963
# [286]	valid_0's binary_logloss: 0.165935
# [287]	valid_0's binary_logloss: 0.16592
# [288]	valid_0's binary_logloss: 0.165904
# [289]	valid_0's binary_logloss: 0.165876
# [290]	valid_0's binary_logloss: 0.16585
# [291]	valid_0's binary_logloss: 0.165814
# [292]	valid_0's binary_logloss: 0.165801
# [293]	valid_0's binary_logloss: 0.165792
# [294]	valid_0's binary_logloss: 0.165777
# [295]	valid_0's binary_logloss: 0.165551
# [296]	valid_0's binary_logloss: 0.165403
# [297]	valid_0's binary_logloss: 0.165356
# [298]	valid_0's binary_logloss: 0.16535
# [299]	valid_0's binary_logloss: 0.16534
# [300]	valid_0's binary_logloss: 0.165329
# [301]	valid_0's binary_logloss: 0.165287
# [302]	valid_0's binary_logloss: 0.1652
# [303]	valid_0's binary_logloss: 0.165164
# [304]	valid_0's binary_logloss: 0.165103
# [305]	valid_0's binary_logloss: 0.16508
# [306]	valid_0's binary_logloss: 0.165011
# [307]	valid_0's binary_logloss: 0.16499
# [308]	valid_0's binary_logloss: 0.16497
# [309]	valid_0's binary_logloss: 0.164944
# [310]	valid_0's binary_logloss: 0.164797
# [311]	valid_0's binary_logloss: 0.164783
# [312]	valid_0's binary_logloss: 0.164767
# [313]	valid_0's binary_logloss: 0.164515
# [314]	valid_0's binary_logloss: 0.164492
# [315]	valid_0's binary_logloss: 0.164482
# [316]	valid_0's binary_logloss: 0.164448
# [317]	valid_0's binary_logloss: 0.1644
# [318]	valid_0's binary_logloss: 0.164381
# [319]	valid_0's binary_logloss: 0.164317
# [320]	valid_0's binary_logloss: 0.164194
# [321]	valid_0's binary_logloss: 0.164185
# [322]	valid_0's binary_logloss: 0.164126
# [323]	valid_0's binary_logloss: 0.1641
# [324]	valid_0's binary_logloss: 0.164088
# [325]	valid_0's binary_logloss: 0.164054
# [326]	valid_0's binary_logloss: 0.164043
# [327]	valid_0's binary_logloss: 0.164022
# [328]	valid_0's binary_logloss: 0.164017
# [329]	valid_0's binary_logloss: 0.163992
# [330]	valid_0's binary_logloss: 0.163965
# [331]	valid_0's binary_logloss: 0.16392
# [332]	valid_0's binary_logloss: 0.163897
# [333]	valid_0's binary_logloss: 0.163886
# [334]	valid_0's binary_logloss: 0.163879
# [335]	valid_0's binary_logloss: 0.16384
# [336]	valid_0's binary_logloss: 0.16382
# [337]	valid_0's binary_logloss: 0.163808
# [338]	valid_0's binary_logloss: 0.1638
# [339]	valid_0's binary_logloss: 0.163768
# [340]	valid_0's binary_logloss: 0.163764
# [341]	valid_0's binary_logloss: 0.163741
# [342]	valid_0's binary_logloss: 0.163693
# [343]	valid_0's binary_logloss: 0.163639
# [344]	valid_0's binary_logloss: 0.163615
# [345]	valid_0's binary_logloss: 0.163602
# [346]	valid_0's binary_logloss: 0.163557
# [347]	valid_0's binary_logloss: 0.163517
# [348]	valid_0's binary_logloss: 0.163431
# [349]	valid_0's binary_logloss: 0.16339
# [350]	valid_0's binary_logloss: 0.163362
# [351]	valid_0's binary_logloss: 0.163321
# [352]	valid_0's binary_logloss: 0.163299
# [353]	valid_0's binary_logloss: 0.163277
# [354]	valid_0's binary_logloss: 0.163126
# [355]	valid_0's binary_logloss: 0.163106
# [356]	valid_0's binary_logloss: 0.163088
# [357]	valid_0's binary_logloss: 0.163067
# [358]	valid_0's binary_logloss: 0.163016
# [359]	valid_0's binary_logloss: 0.162998
# [360]	valid_0's binary_logloss: 0.162984
# [361]	valid_0's binary_logloss: 0.162945
# [362]	valid_0's binary_logloss: 0.162927
# [363]	valid_0's binary_logloss: 0.16289
# [364]	valid_0's binary_logloss: 0.162857
# [365]	valid_0's binary_logloss: 0.162826
# [366]	valid_0's binary_logloss: 0.162815
# [367]	valid_0's binary_logloss: 0.162789
# [368]	valid_0's binary_logloss: 0.162772
# [369]	valid_0's binary_logloss: 0.162743
# [370]	valid_0's binary_logloss: 0.162726
# [371]	valid_0's binary_logloss: 0.162597
# [372]	valid_0's binary_logloss: 0.162565
# [373]	valid_0's binary_logloss: 0.16255
# [374]	valid_0's binary_logloss: 0.162512
# [375]	valid_0's binary_logloss: 0.162444
# [376]	valid_0's binary_logloss: 0.162421
# [377]	valid_0's binary_logloss: 0.162331
# [378]	valid_0's binary_logloss: 0.16232
# [379]	valid_0's binary_logloss: 0.162269
# [380]	valid_0's binary_logloss: 0.162256
# [381]	valid_0's binary_logloss: 0.162251
# [382]	valid_0's binary_logloss: 0.162169
# [383]	valid_0's binary_logloss: 0.16212
# [384]	valid_0's binary_logloss: 0.16204
# [385]	valid_0's binary_logloss: 0.162025
# [386]	valid_0's binary_logloss: 0.162016
# [387]	valid_0's binary_logloss: 0.162008
# [388]	valid_0's binary_logloss: 0.161993
# [389]	valid_0's binary_logloss: 0.161982
# [390]	valid_0's binary_logloss: 0.16197
# [391]	valid_0's binary_logloss: 0.161926
# [392]	valid_0's binary_logloss: 0.161899
# [393]	valid_0's binary_logloss: 0.161807
# [394]	valid_0's binary_logloss: 0.1618
# [395]	valid_0's binary_logloss: 0.161787
# [396]	valid_0's binary_logloss: 0.161719
# [397]	valid_0's binary_logloss: 0.161702
# [398]	valid_0's binary_logloss: 0.161688
# [399]	valid_0's binary_logloss: 0.161644
# [400]	valid_0's binary_logloss: 0.161619
# [401]	valid_0's binary_logloss: 0.161582
# [402]	valid_0's binary_logloss: 0.161569
# [403]	valid_0's binary_logloss: 0.161564
# [404]	valid_0's binary_logloss: 0.161556
# [405]	valid_0's binary_logloss: 0.161534
# [406]	valid_0's binary_logloss: 0.161507
# [407]	valid_0's binary_logloss: 0.161501
# [408]	valid_0's binary_logloss: 0.161495
# [409]	valid_0's binary_logloss: 0.161457
# [410]	valid_0's binary_logloss: 0.161407
# [411]	valid_0's binary_logloss: 0.161385
# [412]	valid_0's binary_logloss: 0.161368
# [413]	valid_0's binary_logloss: 0.161279
# [414]	valid_0's binary_logloss: 0.161237
# [415]	valid_0's binary_logloss: 0.161199
# [416]	valid_0's binary_logloss: 0.161185
# [417]	valid_0's binary_logloss: 0.161172
# [418]	valid_0's binary_logloss: 0.161155
# [419]	valid_0's binary_logloss: 0.161099
# [420]	valid_0's binary_logloss: 0.161083
# [421]	valid_0's binary_logloss: 0.16104
# [422]	valid_0's binary_logloss: 0.160994
# [423]	valid_0's binary_logloss: 0.160982
# [424]	valid_0's binary_logloss: 0.160953
# [425]	valid_0's binary_logloss: 0.160912
# [426]	valid_0's binary_logloss: 0.160894
# [427]	valid_0's binary_logloss: 0.160872
# [428]	valid_0's binary_logloss: 0.160864
# [429]	valid_0's binary_logloss: 0.160845
# [430]	valid_0's binary_logloss: 0.160833
# [431]	valid_0's binary_logloss: 0.160817
# [432]	valid_0's binary_logloss: 0.160697
# [433]	valid_0's binary_logloss: 0.160643
# [434]	valid_0's binary_logloss: 0.160639
# [435]	valid_0's binary_logloss: 0.16057
# [436]	valid_0's binary_logloss: 0.160561
# [437]	valid_0's binary_logloss: 0.160554
# [438]	valid_0's binary_logloss: 0.160538
# [439]	valid_0's binary_logloss: 0.160525
# [440]	valid_0's binary_logloss: 0.160523
# [441]	valid_0's binary_logloss: 0.160471
# [442]	valid_0's binary_logloss: 0.160464
# [443]	valid_0's binary_logloss: 0.16045
# [444]	valid_0's binary_logloss: 0.160443
# [445]	valid_0's binary_logloss: 0.160308
# [446]	valid_0's binary_logloss: 0.16024
# [447]	valid_0's binary_logloss: 0.160216
# [448]	valid_0's binary_logloss: 0.160204
# [449]	valid_0's binary_logloss: 0.160194
# [450]	valid_0's binary_logloss: 0.160186
# [451]	valid_0's binary_logloss: 0.160175
# [452]	valid_0's binary_logloss: 0.160166
# [453]	valid_0's binary_logloss: 0.160159
# [454]	valid_0's binary_logloss: 0.160141
# [455]	valid_0's binary_logloss: 0.160134
# [456]	valid_0's binary_logloss: 0.160035
# [457]	valid_0's binary_logloss: 0.160025
# [458]	valid_0's binary_logloss: 0.159999
# [459]	valid_0's binary_logloss: 0.159978
# [460]	valid_0's binary_logloss: 0.159933
# [461]	valid_0's binary_logloss: 0.159922
# [462]	valid_0's binary_logloss: 0.159907
# [463]	valid_0's binary_logloss: 0.159898
# [464]	valid_0's binary_logloss: 0.159873
# [465]	valid_0's binary_logloss: 0.159866
# [466]	valid_0's binary_logloss: 0.159843
# [467]	valid_0's binary_logloss: 0.159832
# [468]	valid_0's binary_logloss: 0.159818
# [469]	valid_0's binary_logloss: 0.159815
# [470]	valid_0's binary_logloss: 0.159745
# [471]	valid_0's binary_logloss: 0.159736
# [472]	valid_0's binary_logloss: 0.159703
# [473]	valid_0's binary_logloss: 0.15966
# [474]	valid_0's binary_logloss: 0.159652
# [475]	valid_0's binary_logloss: 0.159646
# [476]	valid_0's binary_logloss: 0.159593
# [477]	valid_0's binary_logloss: 0.159577
# [478]	valid_0's binary_logloss: 0.159559
# [479]	valid_0's binary_logloss: 0.159541
# [480]	valid_0's binary_logloss: 0.159517
# [481]	valid_0's binary_logloss: 0.159506
# [482]	valid_0's binary_logloss: 0.159491
# [483]	valid_0's binary_logloss: 0.159487
# [484]	valid_0's binary_logloss: 0.15948
# [485]	valid_0's binary_logloss: 0.159469
# [486]	valid_0's binary_logloss: 0.159455
# [487]	valid_0's binary_logloss: 0.159442
# [488]	valid_0's binary_logloss: 0.159432
# [489]	valid_0's binary_logloss: 0.15942
# [490]	valid_0's binary_logloss: 0.159403
# [491]	valid_0's binary_logloss: 0.15939
# [492]	valid_0's binary_logloss: 0.159381
# [493]	valid_0's binary_logloss: 0.15935
# [494]	valid_0's binary_logloss: 0.159339
# [495]	valid_0's binary_logloss: 0.159333
# [496]	valid_0's binary_logloss: 0.159329
# [497]	valid_0's binary_logloss: 0.159328
# [498]	valid_0's binary_logloss: 0.159305
# [499]	valid_0's binary_logloss: 0.159294
# [500]	valid_0's binary_logloss: 0.159289
# [501]	valid_0's binary_logloss: 0.159279
# [502]	valid_0's binary_logloss: 0.15927
# [503]	valid_0's binary_logloss: 0.159246
# [504]	valid_0's binary_logloss: 0.159159
# [505]	valid_0's binary_logloss: 0.159108
# [506]	valid_0's binary_logloss: 0.1591
# [507]	valid_0's binary_logloss: 0.159097
# [508]	valid_0's binary_logloss: 0.159068
# [509]	valid_0's binary_logloss: 0.159022
# [510]	valid_0's binary_logloss: 0.159009
# [511]	valid_0's binary_logloss: 0.158999
# [512]	valid_0's binary_logloss: 0.158993
# [513]	valid_0's binary_logloss: 0.158987
# [514]	valid_0's binary_logloss: 0.158971
# [515]	valid_0's binary_logloss: 0.158966
# [516]	valid_0's binary_logloss: 0.158956
# [517]	valid_0's binary_logloss: 0.158947
# [518]	valid_0's binary_logloss: 0.158843
# [519]	valid_0's binary_logloss: 0.158836
# [520]	valid_0's binary_logloss: 0.158817
# [521]	valid_0's binary_logloss: 0.158811
# [522]	valid_0's binary_logloss: 0.158805
# [523]	valid_0's binary_logloss: 0.158797
# [524]	valid_0's binary_logloss: 0.158784
# [525]	valid_0's binary_logloss: 0.158776
# [526]	valid_0's binary_logloss: 0.15876
# [527]	valid_0's binary_logloss: 0.158737
# [528]	valid_0's binary_logloss: 0.158733
# [529]	valid_0's binary_logloss: 0.158693
# [530]	valid_0's binary_logloss: 0.158675
# [531]	valid_0's binary_logloss: 0.158672
# [532]	valid_0's binary_logloss: 0.158664
# [533]	valid_0's binary_logloss: 0.15866
# [534]	valid_0's binary_logloss: 0.158656
# [535]	valid_0's binary_logloss: 0.158655
# [536]	valid_0's binary_logloss: 0.158657
# Early stopping, best iteration is:
# [535]	valid_0's binary_logloss: 0.158655

# %%
from sklearn.metrics import roc_auc_score
x_final=x_test[features]
y_final=c.predict_proba(x_final)
y_pred=[]
for elem in y_final:
    y_pred.append(elem[1])
score=roc_auc_score(y_test, y_pred)
print(score)
# Out:
# 0.9834746984375518

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV28.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV28.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idpostulante'],how='left')
prediccion=pd.merge(prediccion,vistas2,on=['idaviso','idpostulante'],how='left')
prediccion=pd.merge(prediccion,vistas3,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion['lo_vio']=(prediccion['cantidad']>0)
prediccion=pd.merge(prediccion,postulaciones_por_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['postulaciones_misma_area']=prediccion['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion['postulaciones_mismo_nivel']=prediccion['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion['postulaciones_mismo_tipo']=prediccion['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion=pd.merge(prediccion,vistas_por_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,vistas_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,vistas_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['vistas_por_area']=prediccion['vistas_por_area'].fillna(0)
prediccion['vistas_por_tipo']=prediccion['vistas_por_tipo'].fillna(0)
prediccion['vistas_por_nivel']=prediccion['vistas_por_tipo'].fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante        sexo   edad Doctorado Master  \
# 38288  46953  1112430862      mzdlkW9         FEM   27.0         -      -
# 86544  45007  1112427740      96Xq1V1  NO_DECLARA  200.0         -      -
# 20988  80556  1112464970      vVwaWYj         FEM   30.0         -      -
# 41343  52285  1112442711       11jjXz        MASC   36.0         -      -
# 4880   78357  1112464507      QNE55jz         FEM   41.0         -      -
# 83061  31564  1112387330       YqaG3V        MASC   31.0         -      -
# 58677   7852  1111742601       6qA3OO        MASC   60.0         -      -
# 75887  66160  1112459159       52OR6z        MASC   39.0         -      -
# 8858   76115  1112464225       EAjVW4        MASC   30.0         -      -
# 42671   1527  1110843523       EkxWDJ        MASC   44.0         -      -
#
#              Otro Posgrado Secundario        ...        vistas_postulante  \
# 38288  Abandonado        -   Graduado        ...                     11.0
# 86544           -        -          -        ...                    156.0
# 20988           -        -          -        ...                     77.0
# 41343           -        -          -        ...                    183.0
# 4880            -        -   Graduado        ...                      NaN
# 83061           -        -   Graduado        ...                     74.0
# 58677           -        -          -        ...                     12.0
# 75887           -        -          -        ...                     19.0
# 8858            -        -   Graduado        ...                      NaN
# 42671           -        -          -        ...                     34.0
#
#       vistas_al_aviso  cantidad lo_vio postulaciones_misma_area  \
# 38288             NaN  0.000000  False                      4.0
# 86544             1.0  0.006410   True                      0.0
# 20988             1.0  0.012987   True                     15.0
# 41343             2.0  0.010929   True                      0.0
# 4880              NaN  0.000000  False                      0.0
# 83061             NaN  0.000000  False                      0.0
# 58677             NaN  0.000000  False                      0.0
# 75887             NaN  0.000000  False                      0.0
# 8858              NaN  0.000000  False                      0.0
# 42671             NaN  0.000000  False                      0.0
#
#       postulaciones_mismo_tipo postulaciones_mismo_nivel vistas_por_area  \
# 38288                     22.0                       8.0             2.0
# 86544                     34.0                      24.0             1.0
# 20988                     54.0                     116.0            13.0
# 41343                     17.0                      10.0             5.0
# 4880                      13.0                       7.0             0.0
# 83061                    162.0                     118.0             0.0
# 58677                     20.0                       0.0             0.0
# 75887                     17.0                       0.0             0.0
# 8858                      17.0                      14.0             0.0
# 42671                     22.0                       0.0             0.0
#
#        vistas_por_tipo  vistas_por_nivel
# 38288              7.0               7.0
# 86544            145.0             145.0
# 20988             26.0              26.0
# 41343            125.0             125.0
# 4880               0.0               0.0
# 83061             54.0              54.0
# 58677             12.0              12.0
# 75887              0.0               0.0
# 8858               0.0               0.0
# 42671             33.0              33.0
#
# [10 rows x 45 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[9.86608640e-01, 1.33913601e-02],
#        [9.93295852e-01, 6.70414765e-03],
#        [9.98779612e-01, 1.22038782e-03],
#        ...,
#        [9.98696529e-01, 1.30347098e-03],
#        [9.98967568e-01, 1.03243181e-03],
#        [9.99313265e-01, 6.86734865e-04]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     vistas_al_aviso cantidad lo_vio  \
# 0   Graduado    ...                 NaN      0.0  False
# 1          -    ...                 NaN      0.0  False
# 2   Graduado    ...                 NaN      0.0  False
# 3   Graduado    ...                 NaN      0.0  False
# 4          -    ...                 NaN      0.0  False
#
#   postulaciones_misma_area postulaciones_mismo_tipo postulaciones_mismo_nivel  \
# 0                      0.0                     20.0                       0.0
# 1                      5.0                     63.0                       0.0
# 2                      3.0                     15.0                       0.0
# 3                      0.0                     15.0                       0.0
# 4                      1.0                     14.0                       1.0
#
#   vistas_por_area vistas_por_tipo  vistas_por_nivel  sepostulo
# 0             4.0            24.0              24.0   0.013391
# 1             0.0             6.0               6.0   0.006704
# 2             1.0             7.0               7.0   0.001220
# 3             0.0             0.0               0.0   0.000329
# 4             0.0             3.0               3.0   0.000147
#
# [5 rows x 46 columns]

# %%
prediccion=prediccion[['id','sepostulo']]
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.013391
# 1   1   0.006704
# 2   2   0.001220
# 3   3   0.000329
# 4   4   0.000147

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion59.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.4569467252175478
