# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')
avisos['denominacion_empresa']=avisos['denominacion_empresa'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#       idaviso idpostulante
# 0  1111780242      YjVJQ6Z
# 1  1112263876      BmVpYoR
# 2  1112327963      wVkBzZd
# 3  1112318643      OqmP9pv
# 4  1111903673      DrpbXDP

# %%
vistas_por_area=vistas.copy()
vistas_por_area['vistas_por_area']=0;
vistas_por_area=pd.merge(vistas_por_area,avisos,on='idaviso', how='left')
vistas_por_area=vistas_por_area.groupby(['idpostulante','nombre_area'],as_index=False).agg({'vistas_por_area':'count'})
vistas_por_area.head()
# Out:
#   idpostulante            nombre_area  vistas_por_area
# 0        0005E  Tecnologia / Sistemas                2
# 1        00Lkv      Comercio Exterior                2
# 2        00dMd      Comercio Exterior                4
# 3        01QAq           Contabilidad                1
# 4        021OM      Comercio Exterior                5

# %%
vistas_por_nivel=vistas.copy()
vistas_por_nivel['vistas_por_nivel']=0;
vistas_por_nivel=pd.merge(vistas_por_nivel,avisos,on='idaviso', how='left')
vistas_por_nivel=vistas_por_nivel.groupby(['idpostulante','nivel_laboral'],as_index=False).agg({'vistas_por_nivel':'count'})
vistas_por_nivel.head()
# Out:
#   idpostulante nivel_laboral  vistas_por_nivel
# 0        0005E          Otro                 2
# 1        00Lkv          Otro                 2
# 2        00dMd          Otro                 4
# 3        01QAq          Otro                 1
# 4        021OM          Otro                 5

# %%
vistas_por_tipo=vistas.copy()
vistas_por_tipo['vistas_por_tipo']=0;
vistas_por_tipo=pd.merge(vistas_por_tipo,avisos,on='idaviso', how='left')
vistas_por_tipo=vistas_por_tipo.groupby(['idpostulante','tipo_de_trabajo'],as_index=False).agg({'vistas_por_tipo':'count'})
vistas_por_tipo.head()
# Out:
#   idpostulante tipo_de_trabajo  vistas_por_tipo
# 0        0005E       Full-time                2
# 1        00Lkv       Full-time                2
# 2        00dMd       Full-time                4
# 3        01QAq       Full-time                1
# 4        021OM       Full-time                5

# %%
vistas['cantidad']=0
vistas2=vistas.groupby(['idaviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q        15
# 1        0005E        58
# 2        000R8        14
# 3        001XE        26
# 4        003k9        32

# %%
vistas3=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           2          28
# 1    48375       RwVdKR           1          15
# 2   169730        1KjXB           2          99
# 3   169730       2AKzxa           2           2
# 4   169730        6LJ64           1          23

# %%
vistas3['cantidad']=vistas3['cantidad_x']/vistas3['cantidad_y']
vistas3.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.071429
# 1    48375       RwVdKR  0.066667
# 2   169730        1KjXB  0.020202
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.043478

# %%
vistas=vistas.rename(columns={'cantidad': 'vistas_postulante'})
vistas2=vistas2.rename(columns={'cantidad': 'vistas_al_aviso'})

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/7.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/8.csv").sample(len(postulaciones2)//4).reset_index(drop=True))
print(len(postulaciones2))
postulaciones2
# Out:
# 8255667
#             idaviso idpostulante  sepostulo
# 0        1112389495       5NbOjG          0
# 1        1112024109      1QP841b          0
# 2        1112490884      96XQ6N9          0
# 3        1111474259      qe2QJj1          0
# 4        1112211292      KBzbBJm          0
# 5        1112328485      3NzZv26          0
# 6        1112474766      akDjWwE          0
# 7        1112312385       aZpBJW          0
# 8        1112285628      akDWj55          0
# 9        1112322843      GNd0KNN          0
# 10       1112355899      DrXPRJX          0
# 11       1112461865      8MPoBDR          0
# 12       1111673413       a1NjRN          0
# 13       1112299006      jkVWXRQ          0
# 14       1112501771      owz0YGW          0
# 15       1002543409       Ej5AAb          0
# 16       1112425310      KBrpAO2          0
# 17       1112498569      pzNMppM          0
# 18       1111866251       ZKqL85          0
# 19       1112289529      ow2awXr          0
# 20       1112493109      5mP1DWM          0
# 21       1112326017      0zd9GZ9          0
# 22       1112242315      3NQKV6Q          0
# 23       1112452417      DrlVEwW          0
# 24       1112402816      mzdk9dZ          0
# 25       1112359100      3NP46xq          0
# 26       1112410555      bOVKA32          0
# 27       1112511403      mzdlAQO          0
# 28       1111272539      6rPpNM4          0
# 29       1111591317      6rP4K13          0
# ...             ...          ...        ...
# 1651103  1112389738      8MP0mjj          0
# 1651104  1112380154      MVrYLWL          0
# 1651105  1112512755      1QdYOmR          0
# 1651106  1112252790      W9Pbp4N          0
# 1651107  1111263475       Z8YVEb          0
# 1651108  1112291380       NloleD          0
# 1651109  1112204810      GNZE1rE          0
# 1651110  1112404579       8AXdMO          0
# 1651111  1112461266      xkaVpNY          0
# 1651112  1112359554      xkdRYE0          0
# 1651113  1112426903      bO4L3A4          0
# 1651114  1112201875       52ONKG          0
# 1651115  1112390700       66ZQDj          0
# 1651116  1112477353      GNoMexe          0
# 1651117  1112378905      A3DNxMl          0
# 1651118  1112252772      bOjk6RB          0
# 1651119  1111855103      0zB4a69          0
# 1651120  1112342762       ZvMP9Y          0
# 1651121  1112274685      vVjRNox          0
# 1651122  1112367015      8Ma1oRL          0
# 1651123  1112210643      EzeE5EN          0
# 1651124  1112419972      RzPB6Vx          0
# 1651125  1112427459      dY9GxMA          0
# 1651126  1112466113      2zkzoVx          0
# 1651127  1112476486       ND89vD          0
# 1651128  1112259527      dYj09A0          0
# 1651129  1112350458       Z0014Z          0
# 1651130  1112313971       Y4KX8w          0
# 1651131  1112403358      bO41kbY          0
# 1651132  1111947711      rm20Opd          0
#
# [8255667 rows x 3 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 14860201
# 14852823

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas2,on=['idaviso','idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas3,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 11164717  1112368696      qekzOa1          0  MASC  24.0         -      -
# 3007886   1112378214       Zw8d1P          1   FEM  45.0         -      -
# 6264932   1112237146      owPO460          0   FEM  35.0         -      -
# 2644859   1112241774       N1zLb5          1   FEM  36.0         -      -
# 7844626   1112295236      8MZ1ZxL          1  MASC  38.0         -      -
# 3291705   1112272845      PmGxorj          0  MASC  38.0         -      -
# 4671056   1112272763      rmPY5Wb          0   FEM  32.0         -      -
# 12875214  1112055574      KBrQQ62          0   FEM  22.0         -      -
# 9410590   1111704414      969rlZa          0  MASC  28.0         -      -
# 4947503   1112267993      KBrLXL2          1   FEM  19.0         -      -
# 3684819   1111846947      vVjOKAx          0  MASC  21.0         -      -
# 3076475   1110092958      1QP05rj          1  MASC  26.0         -      -
# 6628178   1112049150       eDDLoB          0  MASC  33.0         -      -
# 13629672  1112003506      zva8P25          0   FEM  22.0         -      -
# 7159924   1112451494      KBaojjj          1   FEM  19.0         -      -
# 4504000   1112484946       a3qRqq          0  MASC  25.0         -      -
# 3574771   1112365550      zvazEDE          0  MASC  20.0         -      -
# 7512692   1112407559      6rP9G14          0   FEM  20.0         -      -
# 3963818   1112138138      owYOAMe          1   FEM  25.0         -      -
# 6409358   1112264259       1j8V2O          0   FEM  30.0         -      -
#
#               Otro  Posgrado Secundario    ...    capacitacion  \
# 11164717         -         -   Graduado    ...           False
# 3007886          -         -   Graduado    ...            True
# 6264932          -         -   Graduado    ...           False
# 2644859   En Curso  Graduado          -    ...           False
# 7844626          -         -   Graduado    ...           False
# 3291705          -         -   Graduado    ...           False
# 4671056          -         -   Graduado    ...           False
# 12875214         -         -          -    ...            True
# 9410590          -         -   Graduado    ...            True
# 4947503          -         -   Graduado    ...           False
# 3684819          -         -          -    ...           False
# 3076475          -         -          -    ...           False
# 6628178          -         -   Graduado    ...           False
# 13629672         -         -          -    ...           False
# 7159924          -         -   Graduado    ...           False
# 4504000          -         -   Graduado    ...           False
# 3574771          -         -          -    ...           False
# 7512692          -         -   Graduado    ...           False
# 3963818          -         -   Graduado    ...           False
# 6409358          -         -   Graduado    ...           False
#
#          remuneracion_pretendida graduados estudiantes  \
# 11164717                   False     False       False
# 3007886                    False     False       False
# 6264932                    False     False       False
# 2644859                    False     False       False
# 7844626                    False     False       False
# 3291705                    False     False       False
# 4671056                    False     False       False
# 12875214                   False     False       False
# 9410590                     True     False       False
# 4947503                    False     False       False
# 3684819                    False     False       False
# 3076475                    False     False       False
# 6628178                    False     False       False
# 13629672                   False     False       False
# 7159924                    False     False       False
# 4504000                    False     False       False
# 3574771                    False     False       False
# 7512692                    False     False       False
# 3963818                    False     False       False
# 6409358                    False     False        True
#
#          conocimientos_especificos buen_ambiente discriminacion  \
# 11164717                     False         False          False
# 3007886                      False          True          False
# 6264932                      False         False          False
# 2644859                      False         False          False
# 7844626                      False         False          False
# 3291705                      False         False          False
# 4671056                      False         False          False
# 12875214                     False          True          False
# 9410590                      False         False          False
# 4947503                      False         False          False
# 3684819                      False         False          False
# 3076475                      False         False          False
# 6628178                      False         False          False
# 13629672                     False         False          False
# 7159924                      False         False          False
# 4504000                      False         False          False
# 3574771                      False         False          False
# 7512692                      False         False          False
# 3963818                      False         False          False
# 6409358                      False         False          False
#
#          vistas_postulante  vistas_al_aviso  cantidad
# 11164717              63.0              NaN       NaN
# 3007886              147.0              NaN       NaN
# 6264932               25.0              NaN       NaN
# 2644859                6.0              NaN       NaN
# 7844626               21.0              NaN       NaN
# 3291705               96.0              NaN       NaN
# 4671056               40.0              NaN       NaN
# 12875214              30.0              NaN       NaN
# 9410590                4.0              NaN       NaN
# 4947503                NaN              NaN       NaN
# 3684819                2.0              NaN       NaN
# 3076475               18.0              NaN       NaN
# 6628178                NaN              NaN       NaN
# 13629672              32.0              NaN       NaN
# 7159924               43.0              1.0  0.023256
# 4504000              113.0              NaN       NaN
# 3574771                2.0              NaN       NaN
# 7512692                5.0              NaN       NaN
# 3963818              336.0              1.0  0.002976
# 6409358               57.0              NaN       NaN
#
# [20 rows x 38 columns]

# %%
postulaciones['cantidad']=postulaciones['cantidad'].fillna(0)
postulaciones['vistas_postulante']=postulaciones['vistas_postulante'].fillna(0)
postulaciones['vistas_al_aviso']=postulaciones['vistas_al_aviso'].fillna(0)
postulaciones['lo_vio']=(postulaciones['vistas_al_aviso']>0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado    Master  \
# 10987323  1112337886      DrXEd15          0   FEM  19.0         -         -
# 6065393   1112351502      pzdXav3          1   FEM  18.0         -         -
# 8962046   1112410180      owzxBEW          1   FEM  20.0         -         -
# 859506    1112268571      Bm5XJAR          1   FEM  29.0         -         -
# 7169801   1112314890      VNxG3LR          0   FEM  20.0         -         -
# 11798135  1112508165       6Rxvqx          0  MASC  35.0         -         -
# 2105307   1112274973      4rWMpzP          1  MASC  29.0         -         -
# 13055108  1112393260      Ezlv216          0  MASC  21.0         -         -
# 1961550   1112316583       EXDzwb          1   FEM  28.0         -         -
# 10561920  1112296501      ZD8Gvk8          1   FEM  26.0         -         -
# 9875871   1112296171      GNZ4z2K          1  MASC  21.0         -  En Curso
# 3350640   1112205158      ZDr4Gz5          1  MASC  20.0         -         -
# 1561386   1112345850      6r5QXDj          1  MASC  21.0         -         -
# 682288    1112247394      1QzNOAj          0  MASC  68.0         -         -
# 477162    1112308667      vVD3qmQ          1  MASC  22.0         -         -
# 6962203   1112496495       869lLR          0   FEM  35.0         -         -
# 1041793   1112441702      vV99LZj          1   FEM  24.0         -         -
# 3503509   1112015871      ZDrpdv5          0  MASC  27.0         -         -
# 4000266   1112320892      3NQdp8X          1  MASC  35.0         -         -
# 7427752   1111170148      akj0Od0          0  MASC  46.0         -         -
#
#               Otro  Posgrado Secundario   ...   remuneracion_pretendida  \
# 10987323         -         -   Graduado   ...                     False
# 6065393   En Curso         -   Graduado   ...                     False
# 8962046          -         -   Graduado   ...                     False
# 859506           -         -          -   ...                     False
# 7169801          -         -          -   ...                     False
# 11798135         -         -   Graduado   ...                     False
# 2105307          -         -   Graduado   ...                     False
# 13055108         -         -   Graduado   ...                     False
# 1961550          -         -   Graduado   ...                      True
# 10561920         -         -   Graduado   ...                     False
# 9875871          -         -   Graduado   ...                     False
# 3350640          -         -   Graduado   ...                     False
# 1561386          -         -          -   ...                     False
# 682288           -         -   Graduado   ...                     False
# 477162    Graduado         -   Graduado   ...                     False
# 6962203   Graduado         -   Graduado   ...                     False
# 1041793          -         -   Graduado   ...                     False
# 3503509          -         -   Graduado   ...                     False
# 4000266          -  Graduado          -   ...                     False
# 7427752          -         -   Graduado   ...                     False
#
#          graduados estudiantes conocimientos_especificos buen_ambiente  \
# 10987323     False       False                     False         False
# 6065393      False       False                     False         False
# 8962046      False       False                     False         False
# 859506       False       False                     False         False
# 7169801      False       False                     False         False
# 11798135     False       False                     False         False
# 2105307      False        True                     False         False
# 13055108      True        True                     False         False
# 1961550      False       False                     False          True
# 10561920     False       False                     False         False
# 9875871      False       False                     False         False
# 3350640      False       False                     False         False
# 1561386      False       False                     False          True
# 682288       False       False                     False         False
# 477162       False        True                     False          True
# 6962203      False       False                     False          True
# 1041793      False       False                     False          True
# 3503509      False       False                     False         False
# 4000266      False       False                     False         False
# 7427752      False        True                     False         False
#
#          discriminacion vistas_postulante vistas_al_aviso  cantidad  lo_vio
# 10987323          False             108.0             0.0  0.000000   False
# 6065393           False               0.0             0.0  0.000000   False
# 8962046           False             133.0             3.0  0.022556    True
# 859506            False              18.0             0.0  0.000000   False
# 7169801           False               5.0             0.0  0.000000   False
# 11798135          False               0.0             0.0  0.000000   False
# 2105307           False              29.0             0.0  0.000000   False
# 13055108          False               6.0             0.0  0.000000   False
# 1961550           False               2.0             0.0  0.000000   False
# 10561920          False               8.0             0.0  0.000000   False
# 9875871           False               0.0             0.0  0.000000   False
# 3350640           False              12.0             0.0  0.000000   False
# 1561386           False              43.0             1.0  0.023256    True
# 682288            False              11.0             0.0  0.000000   False
# 477162            False               0.0             0.0  0.000000   False
# 6962203           False               3.0             0.0  0.000000   False
# 1041793           False               3.0             0.0  0.000000   False
# 3503509           False               6.0             0.0  0.000000   False
# 4000266           False               0.0             0.0  0.000000   False
# 7427752           False              10.0             0.0  0.000000   False
#
# [20 rows x 39 columns]

# %%
postulaciones_por_area=postulaciones.copy()
postulaciones_por_area=postulaciones_por_area.groupby(by=['idpostulante','nombre_area'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_area=postulaciones_por_area.rename(columns={'sepostulo':'postulaciones_misma_area'})
postulaciones_por_area.head()
# Out:
#   idpostulante                      nombre_area  postulaciones_misma_area
# 0      0z5Dmrd                   Administración                         2
# 1      0z5Dmrd  Almacén / Depósito / Expedición                         1
# 2      0z5Dmrd              Atención al Cliente                         1
# 3      0z5Dmrd                        Auditoría                         1
# 4      0z5Dmrd                      Consultoria                         1

# %%
postulaciones_por_nivel=postulaciones.copy()
postulaciones_por_nivel=postulaciones_por_nivel.groupby(by=['idpostulante','nivel_laboral'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_nivel=postulaciones_por_nivel.rename(columns={'sepostulo':'postulaciones_mismo_nivel'})
postulaciones_por_nivel.head()
# Out:
#   idpostulante                         nivel_laboral  \
# 0      0z5Dmrd  Gerencia / Alta Gerencia / Dirección
# 1      0z5Dmrd                                Junior
# 2      0z5Dmrd                                  Otro
# 3      0z5Dmrd                  Senior / Semi-Senior
# 4      0z5JW1r  Gerencia / Alta Gerencia / Dirección
#
#    postulaciones_mismo_nivel
# 0                          2
# 1                          2
# 2                          1
# 3                         15
# 4                          2

# %%
postulaciones_por_tipo=postulaciones.copy()
postulaciones_por_tipo=postulaciones_por_tipo.groupby(by=['idpostulante','tipo_de_trabajo'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_tipo=postulaciones_por_tipo.rename(columns={'sepostulo':'postulaciones_mismo_tipo'})
postulaciones_por_tipo.head()
# Out:
#   idpostulante tipo_de_trabajo  postulaciones_mismo_tipo
# 0      0z5Dmrd       Full-time                        19
# 1      0z5Dmrd       Part-time                         1
# 2      0z5JW1r       Full-time                        21
# 3      0z5JW1r     Teletrabajo                         1
# 4      0z5VvGv       Full-time                        53

# %%
postulaciones=pd.merge(postulaciones,postulaciones_por_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['postulaciones_misma_area']=postulaciones['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_nivel']=postulaciones['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_tipo']=postulaciones['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones=pd.merge(postulaciones,vistas_por_area,on=['idpostulante','nombre_area'],how='left')
postulaciones=pd.merge(postulaciones,vistas_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,vistas_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['vistas_por_area']=postulaciones['vistas_por_area'].fillna(0)
postulaciones['vistas_por_tipo']=postulaciones['vistas_por_tipo'].fillna(0)
postulaciones['vistas_por_nivel']=postulaciones['vistas_por_tipo'].fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo        sexo   edad Doctorado  \
# 11484139  1112308574      GNJW81E          1        MASC   26.0         -
# 3816750   1112422957       eYMD2W          0        MASC   64.0         -
# 6879673   1112418736      PmazAoj          1        MASC   23.0         -
# 43131     1112293018      ekoDvP8          1         FEM   23.0         -
# 11057648  1112470849       axlAeN          0         FEM   46.0         -
# 11887830  1112230343      QNrl3EV          0  NO_DECLARA  200.0         -
# 1625407   1112265195      5mP4LKN          1         FEM   26.0         -
# 6911598   1112414952      dYjGOm2          0         FEM   21.0         -
# 4261215   1112271873       YQZpz1          0         FEM   42.0         -
# 55556     1112347076       6OWoYr          0         FEM   43.0         -
# 10360620  1112292384      0zdDNrd          0        MASC   23.0         -
# 4211875   1112362764      A36V1rm          1         FEM   26.0         -
# 8899199   1112323764      EzljrM8          1         FEM   32.0         -
# 8792525   1112309197      pzMrJob          0        MASC   24.0         -
# 6554044   1112385047      RzrwGr6          1        MASC   25.0         -
# 5202210   1111603706      W9OKqoN          0         FEM   25.0         -
# 5732920   1112274885      bOVomkV          1        MASC   25.0         -
# 12836016  1111113935      xkaNARb          0         FEM   23.0         -
# 8546430   1112264554      0zP6mma          1  NO_DECLARA  200.0         -
# 13335231  1111995819       aQdbkZ          0        MASC   43.0         -
#
#          Master      Otro  Posgrado Secundario        ...         \
# 11484139      -         -         -   Graduado        ...
# 3816750       -         -  Graduado   Graduado        ...
# 6879673       -         -         -   Graduado        ...
# 43131         -         -         -   Graduado        ...
# 11057648      -         -         -          -        ...
# 11887830      -         -         -          -        ...
# 1625407       -         -         -   Graduado        ...
# 6911598       -         -         -   Graduado        ...
# 4261215       -         -         -   Graduado        ...
# 55556         -         -         -   Graduado        ...
# 10360620      -         -         -          -        ...
# 4211875       -         -         -   Graduado        ...
# 8899199       -         -         -   Graduado        ...
# 8792525       -         -         -          -        ...
# 6554044       -  Graduado         -          -        ...
# 5202210       -         -         -   Graduado        ...
# 5732920       -         -         -   Graduado        ...
# 12836016      -  Graduado         -   Graduado        ...
# 8546430       -         -         -   Graduado        ...
# 13335231      -         -         -          -        ...
#
#          vistas_postulante vistas_al_aviso  cantidad lo_vio  \
# 11484139              50.0             0.0  0.000000  False
# 3816750                6.0             0.0  0.000000  False
# 6879673               67.0             1.0  0.014925   True
# 43131                 43.0             0.0  0.000000  False
# 11057648               0.0             0.0  0.000000  False
# 11887830               3.0             0.0  0.000000  False
# 1625407                4.0             0.0  0.000000  False
# 6911598                1.0             0.0  0.000000  False
# 4261215               86.0             0.0  0.000000  False
# 55556                  3.0             0.0  0.000000  False
# 10360620              11.0             0.0  0.000000  False
# 4211875                9.0             1.0  0.111111   True
# 8899199               72.0             0.0  0.000000  False
# 8792525                6.0             0.0  0.000000  False
# 6554044               58.0             0.0  0.000000  False
# 5202210               16.0             0.0  0.000000  False
# 5732920                0.0             0.0  0.000000  False
# 12836016               7.0             0.0  0.000000  False
# 8546430               11.0             0.0  0.000000  False
# 13335231               5.0             0.0  0.000000  False
#
#          postulaciones_misma_area postulaciones_mismo_tipo  \
# 11484139                        7                       61
# 3816750                         2                        1
# 6879673                        16                       93
# 43131                           3                      166
# 11057648                        2                        0
# 11887830                        1                       12
# 1625407                        11                      101
# 6911598                         0                       17
# 4261215                         1                       18
# 55556                           0                       12
# 10360620                        2                       18
# 4211875                         0                       30
# 8899199                         6                      157
# 8792525                         5                       18
# 6554044                        25                       80
# 5202210                         0                        2
# 5732920                       197                      308
# 12836016                        0                       24
# 8546430                         4                      119
# 13335231                        2                       14
#
#          postulaciones_mismo_nivel vistas_por_area  vistas_por_tipo  \
# 11484139                         8             5.0             45.0
# 3816750                          2             0.0              0.0
# 6879673                         68            16.0             60.0
# 43131                          113             0.0             38.0
# 11057648                        12             0.0              0.0
# 11887830                        10             0.0              3.0
# 1625407                         80             4.0              0.0
# 6911598                          3             0.0              1.0
# 4261215                          9             0.0             59.0
# 55556                            9             0.0              3.0
# 10360620                         4             0.0             11.0
# 4211875                         17             1.0              9.0
# 8899199                        105             2.0             52.0
# 8792525                         16             0.0              6.0
# 6554044                         51            13.0             50.0
# 5202210                          5             0.0              0.0
# 5732920                        225             0.0              0.0
# 12836016                        16             0.0              7.0
# 8546430                         99             0.0             11.0
# 13335231                        10             0.0              5.0
#
#           vistas_por_nivel
# 11484139              45.0
# 3816750                0.0
# 6879673               60.0
# 43131                 38.0
# 11057648               0.0
# 11887830               3.0
# 1625407                0.0
# 6911598                1.0
# 4261215               59.0
# 55556                  3.0
# 10360620              11.0
# 4211875                9.0
# 8899199               52.0
# 8792525                6.0
# 6554044               50.0
# 5202210                0.0
# 5732920                0.0
# 12836016               7.0
# 8546430               11.0
# 13335231               5.0
#
# [20 rows x 45 columns]

# %%
areas=postulaciones.nombre_area.value_counts().index
means={}
for area in areas:
    mean=postulaciones[postulaciones['nombre_area']==area].sepostulo.mean()
    print("Area "+area+" :"+str(mean))
    means[area]=mean
postulaciones['nombre_area']=postulaciones["nombre_area"].replace(means)
postulaciones['nombre_area'].sample(10)
# Out:
# Area Ventas :0.45547998144999224
# Area Administración :0.510770375609555
# Area Comercial :0.4279670737002116
# Area Producción :0.5032232078904605
# Area Atención al Cliente :0.6486689145398014
# Area Recepcionista :0.7539121586995863
# Area Call Center :0.6647496234692348
# Area Contabilidad :0.3089288565035162
# Area Programación :0.045156208978734576
# Area Tecnologia / Sistemas :0.11744075390192003
# Area Telemarketing :0.6333208401909821
# Area Almacén / Depósito / Expedición :0.48347966486662847
# Area Tesorería :0.662019441058939
# Area Recursos Humanos :0.3974439079806873
# Area Mantenimiento :0.22290263319044704
# Area Logística :0.3964383662840627
# Area Gastronomia :0.40617946345975947
# Area Mantenimiento y Limpieza :0.5498809406855384
# Area Soporte Técnico :0.292038462411734
# Area Marketing :0.3761700050015481
# Area Oficios y Profesiones :0.25140233021298364
# Area Administración de Personal :0.42555258982275307
# Area Compras :0.3565396639983509
# Area Créditos y Cobranzas :0.4692928596067609
# Area Legal :0.43678798001662783
# Area Finanzas :0.3636466386364664
# Area Transporte :0.2735867921962613
# Area Otros :0.3014150603422732
# Area Seguridad :0.3721891002647008
# Area Secretaria :0.7128073124606009
# Area Salud :0.2948067621000579
# Area Selección :0.38538174949926834
# Area Desarrollo de Negocios :0.27444351135880296
# Area Calidad :0.29555041351593725
# Area Farmacéutica :0.5468347049985424
# Area Impuestos :0.24815947445916864
# Area Ingeniería  Industrial :0.3963816749343449
# Area Medicina :0.17598474450692936
# Area Camareros :0.6128326784787604
# Area Jóvenes Profesionales :0.5024872339583306
# Area Construcción :0.26899783387118165
# Area Control de Gestión :0.3272287225022738
# Area Cadetería :0.5430754834684965
# Area Abastecimiento :0.35879218472468916
# Area Auditoría :0.26404667869390674
# Area Distribución :0.3774545691183887
# Area Arquitectura :0.3272206020463645
# Area Servicios :0.36308660690746114
# Area Análisis Funcional :0.15358474380547033
# Area Telecomunicaciones :0.1728059927152773
# Area Ingeniería  Mecánica :0.2471866867050328
# Area Facturación :0.4654069279412039
# Area Compras Internacionales/Importación :0.3984508811327218
# Area Asistente :0.6615717029449424
# Area Planeamiento comercial :0.3334880810608966
# Area Programación de producción :0.29332630981806396
# Area Ingeniería  Eléctrica y Electrónica :0.19902487810976371
# Area Producto :0.3418489368178458
# Area Testing / QA / QC :0.09100303268561159
# Area Gerencia / Dirección General :0.2926123772422963
# Area Laboratorio :0.3244354699697111
# Area Consultorías Comercio Exterior :0.42488524996898647
# Area Hotelería :0.49748743718592964
# Area Pasantía / Trainee :0.5877888214792824
# Area Liderazgo de Proyecto :0.1607435757244396
# Area Otras Ingenierias :0.2389161263113501
# Area Sistemas :0.17423601564978322
# Area Mineria/Petroleo/Gas :0.23080726233965995
# Area Ingeniería Civil :0.2388996138996139
# Area Diseño Gráfico :0.43269203199816497
# Area Business Intelligence :0.2964636661409681
# Area Capacitación :0.33198059378146644
# Area Comunicacion :0.5333251915855036
# Area Redes :0.21225362872421696
# Area Ingeniería Oficina Técnica / Proyecto :0.31511274794856886
# Area Análisis de Riesgos :0.458834727037868
# Area Data Entry :0.47697050073479336
# Area Infraestructura :0.16883499797294807
# Area Ventas Internacionales/Exportación :0.4458915987160093
# Area Ingeniería Química :0.3304024861669067
# Area Seguridad e Higiene :0.39545661753532896
# Area Caja :0.654980353259833
# Area Dirección de Obra :0.24992343032159264
# Area Tecnologías de la Información :0.12082664526484752
# Area Compensación y Planilla :0.2738360115368768
# Area Community Management :0.5002067311667907
# Area Seguros :0.49566919297076706
# Area Turismo :0.2919720692197597
# Area Ingeniería Electromecánica :0.2428727830085395
# Area Ingeniería de Procesos :0.3778173719376392
# Area Consultoria :0.307667011181058
# Area E-commerce :0.39580565572214843
# Area Relaciones Institucionales/Publicas :0.533032319391635
# Area Administracion de Seguros :0.4432330280564035
# Area Cuentas Corrientes :0.3857873058409012
# Area Educación/ Docentes :0.24265023778642456
# Area Organización y Métodos :0.2856547866960195
# Area Ingeniería en Alimentos :0.3166051660516605
# Area Planeamiento económico-financiero :0.3222173283835651
# Area Asistente de Tráfico :0.4619035064592671
# Area Venta de Seguros :0.45756660258170834
# Area Seguridad Informática :0.18528307135902072
# Area Ingeniería  Automotriz :0.20108108108108108
# Area Ingeniería Agrónoma :0.20168004757656854
# Area Corporate Finance / Banca Inversión :0.3209123569220486
# Area Educación :0.29222126188418324
# Area Ingeniería de Ventas :0.22034348441926346
# Area Estética y Cuidado Personal :0.0745697896749522
# Area Operaciones :0.21044362292051755
# Area Inversiones / Proyectos de Inversión :0.5363748458692972
# Area Administración de Base de Datos :0.19029495718363462
# Area Diseño :0.19564729638770473
# Area Diseño Industrial :0.12148265340716465
# Area Diseño Textil e Indumentaria :0.21090238561714877
# Area Prácticas Profesionales :0.19604612850082373
# Area Media Planning :0.3367050195979264
# Area Evaluación Económica :0.34775154951866016
# Area Ingeniería de Producto :0.29595266908699747
# Area Comunicaciones Externas :0.6920170051960322
# Area Comercio Exterior :0.16051956382296345
# Area Seguridad Industrial :0.36934754521963825
# Area Ingeniería  Metalurgica :0.1869608493696085
# Area Bioquímica :0.21708490890340323
# Area Otras áreas técnicas en salud :0.31446978930872366
# Area Planeamiento :0.2025448840857591
# Area Farmacia industrial :0.2418804952449309
# Area Promotoras/es :0.41451292246520877
# Area Diseño de Interiores / Decoración :0.3976171243941842
# Area Diseño Web :0.256996935648621
# Area Farmacia comercial :0.39164598842018195
# Area Internet :0.12036461570333541
# Area Back Office :0.39477503628447025
# Area Quimica :0.24078317017288065
# Area Otras Especialidades médicas :0.45395833333333335
# Area Tecnico de Seguros :0.35225778167470406
# Area Creatividad :0.342
# Area Química :0.2809152872444012
# Area Dirección :0.21610056164749933
# Area Veterinaria :0.09838753757857338
# Area Medio Ambiente :0.19319125380570162
# Area Comunicaciones Internas :0.43903818953323903
# Area Ingeniería en Petróleo y Petroquímica :0.3368876080691643
# Area Apoderado Aduanal :0.3879950495049505
# Area Investigación y Desarrollo :0.13757835697789508
# Area Ingeniería en Minas :0.14556962025316456
# Area Asesoría Legal Internacional :0.5163104611923509
# Area Diseño Multimedia :0.25584963559647106
# Area Bioquimica :0.24585741811175338
# Area Finanzas Internacionales :0.35647425897035884
# Area Independientes :0.17284464806330696
# Area Data Warehousing :0.288135593220339
# Area Emergentología :0.0470873786407767
# Area Negocios Internacionales :0.32856412876852326
# Area Multimedia :0.32398753894080995
# Area Responsabilidad Social :0.10892172961138478
# Area Periodismo :0.17042606516290726
# Area Auditoría Médica :0.16499372647427854
# Area Medicina Laboral :0.379110251450677
# Area Instrumentación :0.1776485788113695
# Area Telefonista :0.35071090047393366
# Area Bienestar Estudiantil :0.5542662116040956
# Area Topografía :0.04311649016641452
# Area Arte y Cultura :0.19656019656019655
# Area Trabajo social :0.17940199335548174
# Area Trabajo Social :0.09645131938125569
# Area Ingeniería Geológica :0.11813186813186813
# Area Kinesiología / terapia ocupacional :0.03358925143953935
# Area Clínica Médica :0.029498525073746312
# Area Psicología :0.009137055837563452
# Area Traduccion :0.002036659877800407
# Area Mercadotecnia Internacional :0.29935622317596566
# Area Diseño 3D :0.2793791574279379
# Area Exploración Minera y Petroquimica :0.267816091954023
# Area Idiomas :0.21077844311377245
# Area Instrumentación quirúrgica :0.17916137229987295
# Area Educación especial :0.12933333333333333
# Area Urbanismo :0.019345238095238096
# Area Odontología :0.004580152671755725
# Area Enfermería (ver Enfermería) :0.0
# Area Instrumentación Minera :0.3467741935483871
# Area Cuidados Intensivos Cardiologicos Adultos :0.17857142857142858
# Area Diagnóstico por imágenes :0.12021857923497267
# Area Farmacia hospitalaria :0.052941176470588235
# Area Maternidad :0.026470588235294117
# Area Prácticas cardiológicas :0.03571428571428571
# Area Esterilización :0.04242424242424243
# Area Fonoaudiología :0.003125
# Area Auditoría de Seguros :0.0
# 12763119    0.045156
# 12768996    0.308929
# 2413274     0.455480
# 3379673     0.327229
# 2681352     0.469293
# 3337634     0.503223
# 4934044     0.455480
# 6575915     0.333488
# 6187713     0.396382
# 8084904     0.179402
# Name: nombre_area, dtype: float64

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
# Out:
# Train:  13715150 Test:  721850

# %%
gc.collect()
# Out:
# 141

# %%
c=lgb.LGBMClassifier(learning_rate=0.05,objective='binary',num_leaves=12000,max_depth=18,n_estimators=1200,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train,eval_set=[(x_test,y_test)],verbose=True,early_stopping_rounds=1)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")
# Out:
# [1]	valid_0's binary_logloss: 0.659224
# Training until validation scores don't improve for 1 rounds.
# [2]	valid_0's binary_logloss: 0.62837
# [3]	valid_0's binary_logloss: 0.599282
# [4]	valid_0's binary_logloss: 0.571981
# [5]	valid_0's binary_logloss: 0.547213
# [6]	valid_0's binary_logloss: 0.524975
# [7]	valid_0's binary_logloss: 0.504348
# [8]	valid_0's binary_logloss: 0.484698
# [9]	valid_0's binary_logloss: 0.467058
# [10]	valid_0's binary_logloss: 0.450803
# [11]	valid_0's binary_logloss: 0.435071
# [12]	valid_0's binary_logloss: 0.420475
# [13]	valid_0's binary_logloss: 0.406921
# [14]	valid_0's binary_logloss: 0.395522
# [15]	valid_0's binary_logloss: 0.384394
# [16]	valid_0's binary_logloss: 0.374597
# [17]	valid_0's binary_logloss: 0.364074
# [18]	valid_0's binary_logloss: 0.355001
# [19]	valid_0's binary_logloss: 0.345687
# [20]	valid_0's binary_logloss: 0.337699
# [21]	valid_0's binary_logloss: 0.329487
# [22]	valid_0's binary_logloss: 0.321725
# [23]	valid_0's binary_logloss: 0.315023
# [24]	valid_0's binary_logloss: 0.309089
# [25]	valid_0's binary_logloss: 0.302519
# [26]	valid_0's binary_logloss: 0.296381
# [27]	valid_0's binary_logloss: 0.29064
# [28]	valid_0's binary_logloss: 0.286185
# [29]	valid_0's binary_logloss: 0.28152
# [30]	valid_0's binary_logloss: 0.276633
# [31]	valid_0's binary_logloss: 0.272659
# [32]	valid_0's binary_logloss: 0.268377
# [33]	valid_0's binary_logloss: 0.26469
# [34]	valid_0's binary_logloss: 0.26079
# [35]	valid_0's binary_logloss: 0.257213
# [36]	valid_0's binary_logloss: 0.254018
# [37]	valid_0's binary_logloss: 0.2511
# [38]	valid_0's binary_logloss: 0.248367
# [39]	valid_0's binary_logloss: 0.245334
# [40]	valid_0's binary_logloss: 0.242548
# [41]	valid_0's binary_logloss: 0.239788
# [42]	valid_0's binary_logloss: 0.237093
# [43]	valid_0's binary_logloss: 0.234569
# [44]	valid_0's binary_logloss: 0.232148
# [45]	valid_0's binary_logloss: 0.230023
# [46]	valid_0's binary_logloss: 0.227942
# [47]	valid_0's binary_logloss: 0.225851
# [48]	valid_0's binary_logloss: 0.22389
# [49]	valid_0's binary_logloss: 0.222224
# [50]	valid_0's binary_logloss: 0.220435
# [51]	valid_0's binary_logloss: 0.218824
# [52]	valid_0's binary_logloss: 0.217227
# [53]	valid_0's binary_logloss: 0.215805
# [54]	valid_0's binary_logloss: 0.214393
# [55]	valid_0's binary_logloss: 0.213043
# [56]	valid_0's binary_logloss: 0.211794
# [57]	valid_0's binary_logloss: 0.210547
# [58]	valid_0's binary_logloss: 0.20963
# [59]	valid_0's binary_logloss: 0.208484
# [60]	valid_0's binary_logloss: 0.20747
# [61]	valid_0's binary_logloss: 0.206471
# [62]	valid_0's binary_logloss: 0.205525
# [63]	valid_0's binary_logloss: 0.204519
# [64]	valid_0's binary_logloss: 0.203635
# [65]	valid_0's binary_logloss: 0.202995
# [66]	valid_0's binary_logloss: 0.202369
# [67]	valid_0's binary_logloss: 0.201504
# [68]	valid_0's binary_logloss: 0.200758
# [69]	valid_0's binary_logloss: 0.200113
# [70]	valid_0's binary_logloss: 0.199485
# [71]	valid_0's binary_logloss: 0.198768
# [72]	valid_0's binary_logloss: 0.197778
# [73]	valid_0's binary_logloss: 0.197116
# [74]	valid_0's binary_logloss: 0.196601
# [75]	valid_0's binary_logloss: 0.196186
# [76]	valid_0's binary_logloss: 0.195583
# [77]	valid_0's binary_logloss: 0.195162
# [78]	valid_0's binary_logloss: 0.194637
# [79]	valid_0's binary_logloss: 0.194225
# [80]	valid_0's binary_logloss: 0.193887
# [81]	valid_0's binary_logloss: 0.193565
# [82]	valid_0's binary_logloss: 0.193241
# [83]	valid_0's binary_logloss: 0.192552
# [84]	valid_0's binary_logloss: 0.192159
# [85]	valid_0's binary_logloss: 0.191857
# [86]	valid_0's binary_logloss: 0.191242
# [87]	valid_0's binary_logloss: 0.190954
# [88]	valid_0's binary_logloss: 0.190398
# [89]	valid_0's binary_logloss: 0.190076
# [90]	valid_0's binary_logloss: 0.189676
# [91]	valid_0's binary_logloss: 0.189448
# [92]	valid_0's binary_logloss: 0.189204
# [93]	valid_0's binary_logloss: 0.188906
# [94]	valid_0's binary_logloss: 0.188712
# [95]	valid_0's binary_logloss: 0.188176
# [96]	valid_0's binary_logloss: 0.187652
# [97]	valid_0's binary_logloss: 0.187407
# [98]	valid_0's binary_logloss: 0.187237
# [99]	valid_0's binary_logloss: 0.187066
# [100]	valid_0's binary_logloss: 0.186911
# [101]	valid_0's binary_logloss: 0.186746
# [102]	valid_0's binary_logloss: 0.186586
# [103]	valid_0's binary_logloss: 0.186431
# [104]	valid_0's binary_logloss: 0.1861
# [105]	valid_0's binary_logloss: 0.185961
# [106]	valid_0's binary_logloss: 0.185861
# [107]	valid_0's binary_logloss: 0.185773
# [108]	valid_0's binary_logloss: 0.185657
# [109]	valid_0's binary_logloss: 0.185537
# [110]	valid_0's binary_logloss: 0.185426
# [111]	valid_0's binary_logloss: 0.1853
# [112]	valid_0's binary_logloss: 0.18503
# [113]	valid_0's binary_logloss: 0.184937
# [114]	valid_0's binary_logloss: 0.184694
# [115]	valid_0's binary_logloss: 0.184628
# [116]	valid_0's binary_logloss: 0.184367
# [117]	valid_0's binary_logloss: 0.184273
# [118]	valid_0's binary_logloss: 0.18421
# [119]	valid_0's binary_logloss: 0.183929
# [120]	valid_0's binary_logloss: 0.183866
# [121]	valid_0's binary_logloss: 0.183562
# [122]	valid_0's binary_logloss: 0.183119
# [123]	valid_0's binary_logloss: 0.183079
# [124]	valid_0's binary_logloss: 0.183042
# [125]	valid_0's binary_logloss: 0.183008
# [126]	valid_0's binary_logloss: 0.182973
# [127]	valid_0's binary_logloss: 0.182941
# [128]	valid_0's binary_logloss: 0.182899
# [129]	valid_0's binary_logloss: 0.182868
# [130]	valid_0's binary_logloss: 0.182838
# [131]	valid_0's binary_logloss: 0.18281
# [132]	valid_0's binary_logloss: 0.182782
# [133]	valid_0's binary_logloss: 0.182527
# [134]	valid_0's binary_logloss: 0.182484
# [135]	valid_0's binary_logloss: 0.182458
# [136]	valid_0's binary_logloss: 0.182264
# [137]	valid_0's binary_logloss: 0.182238
# [138]	valid_0's binary_logloss: 0.182197
# [139]	valid_0's binary_logloss: 0.182165
# [140]	valid_0's binary_logloss: 0.181801
# [141]	valid_0's binary_logloss: 0.181745
# [142]	valid_0's binary_logloss: 0.181326
# [143]	valid_0's binary_logloss: 0.181008
# [144]	valid_0's binary_logloss: 0.180985
# [145]	valid_0's binary_logloss: 0.18096
# [146]	valid_0's binary_logloss: 0.180933
# [147]	valid_0's binary_logloss: 0.180792
# [148]	valid_0's binary_logloss: 0.18077
# [149]	valid_0's binary_logloss: 0.180746
# [150]	valid_0's binary_logloss: 0.180723
# [151]	valid_0's binary_logloss: 0.180255
# [152]	valid_0's binary_logloss: 0.180232
# [153]	valid_0's binary_logloss: 0.180204
# [154]	valid_0's binary_logloss: 0.180183
# [155]	valid_0's binary_logloss: 0.180112
# [156]	valid_0's binary_logloss: 0.180088
# [157]	valid_0's binary_logloss: 0.180034
# [158]	valid_0's binary_logloss: 0.180013
# [159]	valid_0's binary_logloss: 0.17999
# [160]	valid_0's binary_logloss: 0.179965
# [161]	valid_0's binary_logloss: 0.179871
# [162]	valid_0's binary_logloss: 0.179843
# [163]	valid_0's binary_logloss: 0.179775
# [164]	valid_0's binary_logloss: 0.179702
# [165]	valid_0's binary_logloss: 0.179468
# [166]	valid_0's binary_logloss: 0.179433
# [167]	valid_0's binary_logloss: 0.179412
# [168]	valid_0's binary_logloss: 0.179304
# [169]	valid_0's binary_logloss: 0.179272
# [170]	valid_0's binary_logloss: 0.179236
# [171]	valid_0's binary_logloss: 0.179184
# [172]	valid_0's binary_logloss: 0.179167
# [173]	valid_0's binary_logloss: 0.179142
# [174]	valid_0's binary_logloss: 0.179011
# [175]	valid_0's binary_logloss: 0.178992
# [176]	valid_0's binary_logloss: 0.178936
# [177]	valid_0's binary_logloss: 0.178545
# [178]	valid_0's binary_logloss: 0.178515
# [179]	valid_0's binary_logloss: 0.178275
# [180]	valid_0's binary_logloss: 0.177955
# [181]	valid_0's binary_logloss: 0.177673
# [182]	valid_0's binary_logloss: 0.177657
# [183]	valid_0's binary_logloss: 0.177607
# [184]	valid_0's binary_logloss: 0.17752
# [185]	valid_0's binary_logloss: 0.177503
# [186]	valid_0's binary_logloss: 0.177487
# [187]	valid_0's binary_logloss: 0.177454
# [188]	valid_0's binary_logloss: 0.177416
# [189]	valid_0's binary_logloss: 0.177401
# [190]	valid_0's binary_logloss: 0.177385
# [191]	valid_0's binary_logloss: 0.177368
# [192]	valid_0's binary_logloss: 0.177351
# [193]	valid_0's binary_logloss: 0.17732
# [194]	valid_0's binary_logloss: 0.177196
# [195]	valid_0's binary_logloss: 0.177179
# [196]	valid_0's binary_logloss: 0.177154
# [197]	valid_0's binary_logloss: 0.176834
# [198]	valid_0's binary_logloss: 0.176777
# [199]	valid_0's binary_logloss: 0.176757
# [200]	valid_0's binary_logloss: 0.176741
# [201]	valid_0's binary_logloss: 0.17673
# [202]	valid_0's binary_logloss: 0.176666
# [203]	valid_0's binary_logloss: 0.176546
# [204]	valid_0's binary_logloss: 0.176508
# [205]	valid_0's binary_logloss: 0.176495
# [206]	valid_0's binary_logloss: 0.176306
# [207]	valid_0's binary_logloss: 0.176283
# [208]	valid_0's binary_logloss: 0.176248
# [209]	valid_0's binary_logloss: 0.176178
# [210]	valid_0's binary_logloss: 0.176157
# [211]	valid_0's binary_logloss: 0.175843
# [212]	valid_0's binary_logloss: 0.175812
# [213]	valid_0's binary_logloss: 0.175802
# [214]	valid_0's binary_logloss: 0.175789
# [215]	valid_0's binary_logloss: 0.17576
# [216]	valid_0's binary_logloss: 0.175573
# [217]	valid_0's binary_logloss: 0.175553
# [218]	valid_0's binary_logloss: 0.17554
# [219]	valid_0's binary_logloss: 0.175525
# [220]	valid_0's binary_logloss: 0.175479
# [221]	valid_0's binary_logloss: 0.175192
# [222]	valid_0's binary_logloss: 0.175175
# [223]	valid_0's binary_logloss: 0.175125
# [224]	valid_0's binary_logloss: 0.175063
# [225]	valid_0's binary_logloss: 0.175036
# [226]	valid_0's binary_logloss: 0.175027
# [227]	valid_0's binary_logloss: 0.175004
# [228]	valid_0's binary_logloss: 0.174696
# [229]	valid_0's binary_logloss: 0.174655
# [230]	valid_0's binary_logloss: 0.174623
# [231]	valid_0's binary_logloss: 0.17434
# [232]	valid_0's binary_logloss: 0.174322
# [233]	valid_0's binary_logloss: 0.174171
# [234]	valid_0's binary_logloss: 0.174155
# [235]	valid_0's binary_logloss: 0.174143
# [236]	valid_0's binary_logloss: 0.174131
# [237]	valid_0's binary_logloss: 0.174113
# [238]	valid_0's binary_logloss: 0.174084
# [239]	valid_0's binary_logloss: 0.174062
# [240]	valid_0's binary_logloss: 0.174046
# [241]	valid_0's binary_logloss: 0.173979
# [242]	valid_0's binary_logloss: 0.173931
# [243]	valid_0's binary_logloss: 0.173914
# [244]	valid_0's binary_logloss: 0.173878
# [245]	valid_0's binary_logloss: 0.173858
# [246]	valid_0's binary_logloss: 0.173727
# [247]	valid_0's binary_logloss: 0.173698
# [248]	valid_0's binary_logloss: 0.173537
# [249]	valid_0's binary_logloss: 0.173375
# [250]	valid_0's binary_logloss: 0.173333
# [251]	valid_0's binary_logloss: 0.173321
# [252]	valid_0's binary_logloss: 0.173089
# [253]	valid_0's binary_logloss: 0.173068
# [254]	valid_0's binary_logloss: 0.172919
# [255]	valid_0's binary_logloss: 0.172853
# [256]	valid_0's binary_logloss: 0.172842
# [257]	valid_0's binary_logloss: 0.172832
# [258]	valid_0's binary_logloss: 0.172741
# [259]	valid_0's binary_logloss: 0.172717
# [260]	valid_0's binary_logloss: 0.172578
# [261]	valid_0's binary_logloss: 0.17256
# [262]	valid_0's binary_logloss: 0.172432
# [263]	valid_0's binary_logloss: 0.172301
# [264]	valid_0's binary_logloss: 0.172239
# [265]	valid_0's binary_logloss: 0.172217
# [266]	valid_0's binary_logloss: 0.172134
# [267]	valid_0's binary_logloss: 0.172071
# [268]	valid_0's binary_logloss: 0.172042
# [269]	valid_0's binary_logloss: 0.172028
# [270]	valid_0's binary_logloss: 0.172004
# [271]	valid_0's binary_logloss: 0.171969
# [272]	valid_0's binary_logloss: 0.171939
# [273]	valid_0's binary_logloss: 0.171772
# [274]	valid_0's binary_logloss: 0.171678
# [275]	valid_0's binary_logloss: 0.17162
# [276]	valid_0's binary_logloss: 0.171601
# [277]	valid_0's binary_logloss: 0.171567
# [278]	valid_0's binary_logloss: 0.171464
# [279]	valid_0's binary_logloss: 0.171454
# [280]	valid_0's binary_logloss: 0.171407
# [281]	valid_0's binary_logloss: 0.171394
# [282]	valid_0's binary_logloss: 0.171219
# [283]	valid_0's binary_logloss: 0.171195
# [284]	valid_0's binary_logloss: 0.171183
# [285]	valid_0's binary_logloss: 0.171159
# [286]	valid_0's binary_logloss: 0.171144
# [287]	valid_0's binary_logloss: 0.171087
# [288]	valid_0's binary_logloss: 0.171079
# [289]	valid_0's binary_logloss: 0.171065
# [290]	valid_0's binary_logloss: 0.171021
# [291]	valid_0's binary_logloss: 0.171002
# [292]	valid_0's binary_logloss: 0.170933
# [293]	valid_0's binary_logloss: 0.170899
# [294]	valid_0's binary_logloss: 0.17088
# [295]	valid_0's binary_logloss: 0.170705
# [296]	valid_0's binary_logloss: 0.170591
# [297]	valid_0's binary_logloss: 0.170537
# [298]	valid_0's binary_logloss: 0.170515
# [299]	valid_0's binary_logloss: 0.170498
# [300]	valid_0's binary_logloss: 0.170479
# [301]	valid_0's binary_logloss: 0.170447
# [302]	valid_0's binary_logloss: 0.170301
# [303]	valid_0's binary_logloss: 0.170285
# [304]	valid_0's binary_logloss: 0.170211
# [305]	valid_0's binary_logloss: 0.170193
# [306]	valid_0's binary_logloss: 0.170175
# [307]	valid_0's binary_logloss: 0.170159
# [308]	valid_0's binary_logloss: 0.17014
# [309]	valid_0's binary_logloss: 0.170128
# [310]	valid_0's binary_logloss: 0.170058
# [311]	valid_0's binary_logloss: 0.170046
# [312]	valid_0's binary_logloss: 0.170002
# [313]	valid_0's binary_logloss: 0.169917
# [314]	valid_0's binary_logloss: 0.169905
# [315]	valid_0's binary_logloss: 0.169884
# [316]	valid_0's binary_logloss: 0.169848
# [317]	valid_0's binary_logloss: 0.169822
# [318]	valid_0's binary_logloss: 0.169793
# [319]	valid_0's binary_logloss: 0.169609
# [320]	valid_0's binary_logloss: 0.169438
# [321]	valid_0's binary_logloss: 0.169413
# [322]	valid_0's binary_logloss: 0.169262
# [323]	valid_0's binary_logloss: 0.169226
# [324]	valid_0's binary_logloss: 0.169212
# [325]	valid_0's binary_logloss: 0.169179
# [326]	valid_0's binary_logloss: 0.169145
# [327]	valid_0's binary_logloss: 0.169131
# [328]	valid_0's binary_logloss: 0.169125
# [329]	valid_0's binary_logloss: 0.169105
# [330]	valid_0's binary_logloss: 0.169087
# [331]	valid_0's binary_logloss: 0.169049
# [332]	valid_0's binary_logloss: 0.16903
# [333]	valid_0's binary_logloss: 0.168996
# [334]	valid_0's binary_logloss: 0.168979
# [335]	valid_0's binary_logloss: 0.168969
# [336]	valid_0's binary_logloss: 0.16891
# [337]	valid_0's binary_logloss: 0.168878
# [338]	valid_0's binary_logloss: 0.168867
# [339]	valid_0's binary_logloss: 0.168855
# [340]	valid_0's binary_logloss: 0.168814
# [341]	valid_0's binary_logloss: 0.168781
# [342]	valid_0's binary_logloss: 0.168646
# [343]	valid_0's binary_logloss: 0.168624
# [344]	valid_0's binary_logloss: 0.168613
# [345]	valid_0's binary_logloss: 0.168573
# [346]	valid_0's binary_logloss: 0.168536
# [347]	valid_0's binary_logloss: 0.16852
# [348]	valid_0's binary_logloss: 0.168458
# [349]	valid_0's binary_logloss: 0.168367
# [350]	valid_0's binary_logloss: 0.168329
# [351]	valid_0's binary_logloss: 0.168312
# [352]	valid_0's binary_logloss: 0.168255
# [353]	valid_0's binary_logloss: 0.168214
# [354]	valid_0's binary_logloss: 0.168146
# [355]	valid_0's binary_logloss: 0.16813
# [356]	valid_0's binary_logloss: 0.168105
# [357]	valid_0's binary_logloss: 0.168073
# [358]	valid_0's binary_logloss: 0.167975
# [359]	valid_0's binary_logloss: 0.167952
# [360]	valid_0's binary_logloss: 0.167937
# [361]	valid_0's binary_logloss: 0.167873
# [362]	valid_0's binary_logloss: 0.167859
# [363]	valid_0's binary_logloss: 0.16782
# [364]	valid_0's binary_logloss: 0.167804
# [365]	valid_0's binary_logloss: 0.167763
# [366]	valid_0's binary_logloss: 0.167678
# [367]	valid_0's binary_logloss: 0.167644
# [368]	valid_0's binary_logloss: 0.167632
# [369]	valid_0's binary_logloss: 0.167593
# [370]	valid_0's binary_logloss: 0.167552
# [371]	valid_0's binary_logloss: 0.167385
# [372]	valid_0's binary_logloss: 0.167371
# [373]	valid_0's binary_logloss: 0.167343
# [374]	valid_0's binary_logloss: 0.167313
# [375]	valid_0's binary_logloss: 0.16727
# [376]	valid_0's binary_logloss: 0.167263
# [377]	valid_0's binary_logloss: 0.167226
# [378]	valid_0's binary_logloss: 0.167207
# [379]	valid_0's binary_logloss: 0.16718
# [380]	valid_0's binary_logloss: 0.16716
# [381]	valid_0's binary_logloss: 0.167127
# [382]	valid_0's binary_logloss: 0.166977
# [383]	valid_0's binary_logloss: 0.166963
# [384]	valid_0's binary_logloss: 0.166916
# [385]	valid_0's binary_logloss: 0.166907
# [386]	valid_0's binary_logloss: 0.1669
# [387]	valid_0's binary_logloss: 0.166891
# [388]	valid_0's binary_logloss: 0.16688
# [389]	valid_0's binary_logloss: 0.166863
# [390]	valid_0's binary_logloss: 0.166833
# [391]	valid_0's binary_logloss: 0.166813
# [392]	valid_0's binary_logloss: 0.166785
# [393]	valid_0's binary_logloss: 0.16667
# [394]	valid_0's binary_logloss: 0.166652
# [395]	valid_0's binary_logloss: 0.166625
# [396]	valid_0's binary_logloss: 0.166463
# [397]	valid_0's binary_logloss: 0.166443
# [398]	valid_0's binary_logloss: 0.166426
# [399]	valid_0's binary_logloss: 0.166399
# [400]	valid_0's binary_logloss: 0.166383
# [401]	valid_0's binary_logloss: 0.166277
# [402]	valid_0's binary_logloss: 0.166253
# [403]	valid_0's binary_logloss: 0.166234
# [404]	valid_0's binary_logloss: 0.166209
# [405]	valid_0's binary_logloss: 0.16617
# [406]	valid_0's binary_logloss: 0.166135
# [407]	valid_0's binary_logloss: 0.166123
# [408]	valid_0's binary_logloss: 0.166092
# [409]	valid_0's binary_logloss: 0.166065
# [410]	valid_0's binary_logloss: 0.166003
# [411]	valid_0's binary_logloss: 0.165944
# [412]	valid_0's binary_logloss: 0.16591
# [413]	valid_0's binary_logloss: 0.165826
# [414]	valid_0's binary_logloss: 0.165804
# [415]	valid_0's binary_logloss: 0.16578
# [416]	valid_0's binary_logloss: 0.165767
# [417]	valid_0's binary_logloss: 0.165727
# [418]	valid_0's binary_logloss: 0.165706
# [419]	valid_0's binary_logloss: 0.165606
# [420]	valid_0's binary_logloss: 0.165582
# [421]	valid_0's binary_logloss: 0.165454
# [422]	valid_0's binary_logloss: 0.165423
# [423]	valid_0's binary_logloss: 0.165403
# [424]	valid_0's binary_logloss: 0.165385
# [425]	valid_0's binary_logloss: 0.165333
# [426]	valid_0's binary_logloss: 0.165315
# [427]	valid_0's binary_logloss: 0.165299
# [428]	valid_0's binary_logloss: 0.165292
# [429]	valid_0's binary_logloss: 0.165288
# [430]	valid_0's binary_logloss: 0.165271
# [431]	valid_0's binary_logloss: 0.16524
# [432]	valid_0's binary_logloss: 0.165193
# [433]	valid_0's binary_logloss: 0.165167
# [434]	valid_0's binary_logloss: 0.165163
# [435]	valid_0's binary_logloss: 0.165088
# [436]	valid_0's binary_logloss: 0.165077
# [437]	valid_0's binary_logloss: 0.16507
# [438]	valid_0's binary_logloss: 0.165058
# [439]	valid_0's binary_logloss: 0.165049
# [440]	valid_0's binary_logloss: 0.165034
# [441]	valid_0's binary_logloss: 0.165005
# [442]	valid_0's binary_logloss: 0.164988
# [443]	valid_0's binary_logloss: 0.164969
# [444]	valid_0's binary_logloss: 0.164957
# [445]	valid_0's binary_logloss: 0.164894
# [446]	valid_0's binary_logloss: 0.1648
# [447]	valid_0's binary_logloss: 0.164792
# [448]	valid_0's binary_logloss: 0.164771
# [449]	valid_0's binary_logloss: 0.164766
# [450]	valid_0's binary_logloss: 0.164752
# [451]	valid_0's binary_logloss: 0.164744
# [452]	valid_0's binary_logloss: 0.164733
# [453]	valid_0's binary_logloss: 0.164728
# [454]	valid_0's binary_logloss: 0.164721
# [455]	valid_0's binary_logloss: 0.164699
# [456]	valid_0's binary_logloss: 0.164659
# [457]	valid_0's binary_logloss: 0.16465
# [458]	valid_0's binary_logloss: 0.16462
# [459]	valid_0's binary_logloss: 0.164606
# [460]	valid_0's binary_logloss: 0.164584
# [461]	valid_0's binary_logloss: 0.164566
# [462]	valid_0's binary_logloss: 0.164558
# [463]	valid_0's binary_logloss: 0.164555
# [464]	valid_0's binary_logloss: 0.164531
# [465]	valid_0's binary_logloss: 0.164518
# [466]	valid_0's binary_logloss: 0.164508
# [467]	valid_0's binary_logloss: 0.164489
# [468]	valid_0's binary_logloss: 0.16448
# [469]	valid_0's binary_logloss: 0.164458
# [470]	valid_0's binary_logloss: 0.164423
# [471]	valid_0's binary_logloss: 0.164414
# [472]	valid_0's binary_logloss: 0.16437
# [473]	valid_0's binary_logloss: 0.164308
# [474]	valid_0's binary_logloss: 0.164298
# [475]	valid_0's binary_logloss: 0.164291
# [476]	valid_0's binary_logloss: 0.16423
# [477]	valid_0's binary_logloss: 0.164171
# [478]	valid_0's binary_logloss: 0.164076
# [479]	valid_0's binary_logloss: 0.164059
# [480]	valid_0's binary_logloss: 0.164002
# [481]	valid_0's binary_logloss: 0.163989
# [482]	valid_0's binary_logloss: 0.163977
# [483]	valid_0's binary_logloss: 0.163966
# [484]	valid_0's binary_logloss: 0.163942
# [485]	valid_0's binary_logloss: 0.163929
# [486]	valid_0's binary_logloss: 0.16392
# [487]	valid_0's binary_logloss: 0.1639
# [488]	valid_0's binary_logloss: 0.163893
# [489]	valid_0's binary_logloss: 0.16386
# [490]	valid_0's binary_logloss: 0.163845
# [491]	valid_0's binary_logloss: 0.163841
# [492]	valid_0's binary_logloss: 0.163826
# [493]	valid_0's binary_logloss: 0.163733
# [494]	valid_0's binary_logloss: 0.163721
# [495]	valid_0's binary_logloss: 0.163718
# [496]	valid_0's binary_logloss: 0.163708
# [497]	valid_0's binary_logloss: 0.163702
# [498]	valid_0's binary_logloss: 0.1637
# [499]	valid_0's binary_logloss: 0.163695
# [500]	valid_0's binary_logloss: 0.163689
# [501]	valid_0's binary_logloss: 0.163673
# [502]	valid_0's binary_logloss: 0.163666
# [503]	valid_0's binary_logloss: 0.16366
# [504]	valid_0's binary_logloss: 0.163604
# [505]	valid_0's binary_logloss: 0.163534
# [506]	valid_0's binary_logloss: 0.163528
# [507]	valid_0's binary_logloss: 0.163523
# [508]	valid_0's binary_logloss: 0.163515
# [509]	valid_0's binary_logloss: 0.163472
# [510]	valid_0's binary_logloss: 0.16345
# [511]	valid_0's binary_logloss: 0.163426
# [512]	valid_0's binary_logloss: 0.163417
# [513]	valid_0's binary_logloss: 0.163414
# [514]	valid_0's binary_logloss: 0.163393
# [515]	valid_0's binary_logloss: 0.163381
# [516]	valid_0's binary_logloss: 0.163373
# [517]	valid_0's binary_logloss: 0.163349
# [518]	valid_0's binary_logloss: 0.163291
# [519]	valid_0's binary_logloss: 0.163282
# [520]	valid_0's binary_logloss: 0.163258
# [521]	valid_0's binary_logloss: 0.163253
# [522]	valid_0's binary_logloss: 0.163247
# [523]	valid_0's binary_logloss: 0.163227
# [524]	valid_0's binary_logloss: 0.163215
# [525]	valid_0's binary_logloss: 0.163208
# [526]	valid_0's binary_logloss: 0.163204
# [527]	valid_0's binary_logloss: 0.16317
# [528]	valid_0's binary_logloss: 0.163162
# [529]	valid_0's binary_logloss: 0.163093
# [530]	valid_0's binary_logloss: 0.163078
# [531]	valid_0's binary_logloss: 0.163064
# [532]	valid_0's binary_logloss: 0.163056
# [533]	valid_0's binary_logloss: 0.163031
# [534]	valid_0's binary_logloss: 0.163012
# [535]	valid_0's binary_logloss: 0.163
# [536]	valid_0's binary_logloss: 0.162993
# [537]	valid_0's binary_logloss: 0.162969
# [538]	valid_0's binary_logloss: 0.162911
# [539]	valid_0's binary_logloss: 0.162857
# [540]	valid_0's binary_logloss: 0.162848
# [541]	valid_0's binary_logloss: 0.16284
# [542]	valid_0's binary_logloss: 0.162833
# [543]	valid_0's binary_logloss: 0.162821
# [544]	valid_0's binary_logloss: 0.162805
# [545]	valid_0's binary_logloss: 0.162805
# [546]	valid_0's binary_logloss: 0.162794
# [547]	valid_0's binary_logloss: 0.162777
# [548]	valid_0's binary_logloss: 0.162767
# [549]	valid_0's binary_logloss: 0.162759
# [550]	valid_0's binary_logloss: 0.162746
# [551]	valid_0's binary_logloss: 0.162736
# [552]	valid_0's binary_logloss: 0.16273
# [553]	valid_0's binary_logloss: 0.162702
# [554]	valid_0's binary_logloss: 0.162695
# [555]	valid_0's binary_logloss: 0.162691
# [556]	valid_0's binary_logloss: 0.162685
# [557]	valid_0's binary_logloss: 0.16267
# [558]	valid_0's binary_logloss: 0.162665
# [559]	valid_0's binary_logloss: 0.162662
# [560]	valid_0's binary_logloss: 0.162645
# [561]	valid_0's binary_logloss: 0.162631
# [562]	valid_0's binary_logloss: 0.162549
# [563]	valid_0's binary_logloss: 0.162544
# [564]	valid_0's binary_logloss: 0.162463
# [565]	valid_0's binary_logloss: 0.162445
# [566]	valid_0's binary_logloss: 0.162432
# [567]	valid_0's binary_logloss: 0.162429
# [568]	valid_0's binary_logloss: 0.162422
# [569]	valid_0's binary_logloss: 0.162416
# [570]	valid_0's binary_logloss: 0.162389
# [571]	valid_0's binary_logloss: 0.162386
# [572]	valid_0's binary_logloss: 0.162368
# [573]	valid_0's binary_logloss: 0.162363
# [574]	valid_0's binary_logloss: 0.16229
# [575]	valid_0's binary_logloss: 0.16225
# [576]	valid_0's binary_logloss: 0.162243
# [577]	valid_0's binary_logloss: 0.16224
# [578]	valid_0's binary_logloss: 0.162222
# [579]	valid_0's binary_logloss: 0.162219
# [580]	valid_0's binary_logloss: 0.162199
# [581]	valid_0's binary_logloss: 0.162197
# [582]	valid_0's binary_logloss: 0.162179
# [583]	valid_0's binary_logloss: 0.162172
# [584]	valid_0's binary_logloss: 0.162163
# [585]	valid_0's binary_logloss: 0.162136
# [586]	valid_0's binary_logloss: 0.162135
# [587]	valid_0's binary_logloss: 0.162131
# [588]	valid_0's binary_logloss: 0.162082
# [589]	valid_0's binary_logloss: 0.16208
# [590]	valid_0's binary_logloss: 0.161973
# [591]	valid_0's binary_logloss: 0.161967
# [592]	valid_0's binary_logloss: 0.161965
# [593]	valid_0's binary_logloss: 0.161961
# [594]	valid_0's binary_logloss: 0.161957
# [595]	valid_0's binary_logloss: 0.16195
# [596]	valid_0's binary_logloss: 0.161946
# [597]	valid_0's binary_logloss: 0.161927
# [598]	valid_0's binary_logloss: 0.16192
# [599]	valid_0's binary_logloss: 0.161908
# [600]	valid_0's binary_logloss: 0.161882
# [601]	valid_0's binary_logloss: 0.161842
# [602]	valid_0's binary_logloss: 0.161798
# [603]	valid_0's binary_logloss: 0.161791
# [604]	valid_0's binary_logloss: 0.161784
# [605]	valid_0's binary_logloss: 0.161774
# [606]	valid_0's binary_logloss: 0.161771
# [607]	valid_0's binary_logloss: 0.161766
# [608]	valid_0's binary_logloss: 0.161759
# [609]	valid_0's binary_logloss: 0.161755
# [610]	valid_0's binary_logloss: 0.16173
# [611]	valid_0's binary_logloss: 0.161727
# [612]	valid_0's binary_logloss: 0.161722
# [613]	valid_0's binary_logloss: 0.161715
# [614]	valid_0's binary_logloss: 0.161711
# [615]	valid_0's binary_logloss: 0.161707
# [616]	valid_0's binary_logloss: 0.161705
# [617]	valid_0's binary_logloss: 0.161701
# [618]	valid_0's binary_logloss: 0.161696
# [619]	valid_0's binary_logloss: 0.161689
# [620]	valid_0's binary_logloss: 0.161685
# [621]	valid_0's binary_logloss: 0.161683
# [622]	valid_0's binary_logloss: 0.161682
# [623]	valid_0's binary_logloss: 0.161668
# [624]	valid_0's binary_logloss: 0.161633
# [625]	valid_0's binary_logloss: 0.161625
# [626]	valid_0's binary_logloss: 0.16162
# [627]	valid_0's binary_logloss: 0.161613
# [628]	valid_0's binary_logloss: 0.161585
# [629]	valid_0's binary_logloss: 0.161581
# [630]	valid_0's binary_logloss: 0.161577
# [631]	valid_0's binary_logloss: 0.161479
# [632]	valid_0's binary_logloss: 0.161476
# [633]	valid_0's binary_logloss: 0.16147
# [634]	valid_0's binary_logloss: 0.161464
# [635]	valid_0's binary_logloss: 0.161457
# [636]	valid_0's binary_logloss: 0.161454
# [637]	valid_0's binary_logloss: 0.161333
# [638]	valid_0's binary_logloss: 0.161327
# [639]	valid_0's binary_logloss: 0.16132
# [640]	valid_0's binary_logloss: 0.161311
# [641]	valid_0's binary_logloss: 0.161308
# [642]	valid_0's binary_logloss: 0.161301
# [643]	valid_0's binary_logloss: 0.161198
# [644]	valid_0's binary_logloss: 0.161191
# [645]	valid_0's binary_logloss: 0.161165
# [646]	valid_0's binary_logloss: 0.16116
# [647]	valid_0's binary_logloss: 0.161154
# [648]	valid_0's binary_logloss: 0.161148
# [649]	valid_0's binary_logloss: 0.16111
# [650]	valid_0's binary_logloss: 0.161106
# [651]	valid_0's binary_logloss: 0.161094
# [652]	valid_0's binary_logloss: 0.161093
# [653]	valid_0's binary_logloss: 0.161086
# [654]	valid_0's binary_logloss: 0.161075
# [655]	valid_0's binary_logloss: 0.161072
# [656]	valid_0's binary_logloss: 0.16107
# [657]	valid_0's binary_logloss: 0.161064
# [658]	valid_0's binary_logloss: 0.161056
# [659]	valid_0's binary_logloss: 0.161048
# [660]	valid_0's binary_logloss: 0.161045
# [661]	valid_0's binary_logloss: 0.161001
# [662]	valid_0's binary_logloss: 0.160993
# [663]	valid_0's binary_logloss: 0.160988
# [664]	valid_0's binary_logloss: 0.160984
# [665]	valid_0's binary_logloss: 0.160961
# [666]	valid_0's binary_logloss: 0.160954
# [667]	valid_0's binary_logloss: 0.160946
# [668]	valid_0's binary_logloss: 0.160942
# [669]	valid_0's binary_logloss: 0.160938
# [670]	valid_0's binary_logloss: 0.160929
# [671]	valid_0's binary_logloss: 0.160924
# [672]	valid_0's binary_logloss: 0.160919
# [673]	valid_0's binary_logloss: 0.160914
# [674]	valid_0's binary_logloss: 0.160911
# [675]	valid_0's binary_logloss: 0.160905
# [676]	valid_0's binary_logloss: 0.160896
# [677]	valid_0's binary_logloss: 0.160895
# [678]	valid_0's binary_logloss: 0.160888
# [679]	valid_0's binary_logloss: 0.160885
# [680]	valid_0's binary_logloss: 0.160879
# [681]	valid_0's binary_logloss: 0.160864
# [682]	valid_0's binary_logloss: 0.160805
# [683]	valid_0's binary_logloss: 0.160799
# [684]	valid_0's binary_logloss: 0.160792
# [685]	valid_0's binary_logloss: 0.160781
# [686]	valid_0's binary_logloss: 0.160775
# [687]	valid_0's binary_logloss: 0.160773
# [688]	valid_0's binary_logloss: 0.160767
# [689]	valid_0's binary_logloss: 0.160764
# [690]	valid_0's binary_logloss: 0.160721
# [691]	valid_0's binary_logloss: 0.160716
# [692]	valid_0's binary_logloss: 0.160714
# [693]	valid_0's binary_logloss: 0.160699
# [694]	valid_0's binary_logloss: 0.160694
# [695]	valid_0's binary_logloss: 0.160689
# [696]	valid_0's binary_logloss: 0.160653
# [697]	valid_0's binary_logloss: 0.160641
# [698]	valid_0's binary_logloss: 0.160635
# [699]	valid_0's binary_logloss: 0.160631
# [700]	valid_0's binary_logloss: 0.160618
# [701]	valid_0's binary_logloss: 0.160614
# [702]	valid_0's binary_logloss: 0.160605
# [703]	valid_0's binary_logloss: 0.160581
# [704]	valid_0's binary_logloss: 0.160575
# [705]	valid_0's binary_logloss: 0.160571
# [706]	valid_0's binary_logloss: 0.160569
# [707]	valid_0's binary_logloss: 0.160566
# [708]	valid_0's binary_logloss: 0.160565
# [709]	valid_0's binary_logloss: 0.160553
# [710]	valid_0's binary_logloss: 0.160551
# [711]	valid_0's binary_logloss: 0.160545
# [712]	valid_0's binary_logloss: 0.160544
# [713]	valid_0's binary_logloss: 0.160539
# [714]	valid_0's binary_logloss: 0.160524
# [715]	valid_0's binary_logloss: 0.160522
# [716]	valid_0's binary_logloss: 0.16047
# [717]	valid_0's binary_logloss: 0.160453
# [718]	valid_0's binary_logloss: 0.160443
# [719]	valid_0's binary_logloss: 0.160437
# [720]	valid_0's binary_logloss: 0.160436
# [721]	valid_0's binary_logloss: 0.16043
# [722]	valid_0's binary_logloss: 0.160429
# [723]	valid_0's binary_logloss: 0.160423
# [724]	valid_0's binary_logloss: 0.160421
# [725]	valid_0's binary_logloss: 0.160411
# [726]	valid_0's binary_logloss: 0.160336
# [727]	valid_0's binary_logloss: 0.160333
# [728]	valid_0's binary_logloss: 0.160311
# [729]	valid_0's binary_logloss: 0.160248
# [730]	valid_0's binary_logloss: 0.160247
# [731]	valid_0's binary_logloss: 0.16024
# [732]	valid_0's binary_logloss: 0.16024
# [733]	valid_0's binary_logloss: 0.160236
# [734]	valid_0's binary_logloss: 0.160229
# [735]	valid_0's binary_logloss: 0.160224
# [736]	valid_0's binary_logloss: 0.160221
# [737]	valid_0's binary_logloss: 0.160213
# [738]	valid_0's binary_logloss: 0.160208
# [739]	valid_0's binary_logloss: 0.160194
# [740]	valid_0's binary_logloss: 0.160176
# [741]	valid_0's binary_logloss: 0.160169
# [742]	valid_0's binary_logloss: 0.160167
# [743]	valid_0's binary_logloss: 0.160161
# [744]	valid_0's binary_logloss: 0.160153
# [745]	valid_0's binary_logloss: 0.160128
# [746]	valid_0's binary_logloss: 0.160057
# [747]	valid_0's binary_logloss: 0.160053
# [748]	valid_0's binary_logloss: 0.16005
# [749]	valid_0's binary_logloss: 0.16
# [750]	valid_0's binary_logloss: 0.159997
# [751]	valid_0's binary_logloss: 0.159996
# [752]	valid_0's binary_logloss: 0.159992
# [753]	valid_0's binary_logloss: 0.159989
# [754]	valid_0's binary_logloss: 0.159978
# [755]	valid_0's binary_logloss: 0.159978
# Early stopping, best iteration is:
# [754]	valid_0's binary_logloss: 0.159978

# %%
from sklearn.metrics import roc_auc_score
x_final=x_test[features]
y_final=c.predict_proba(x_final)
y_pred=[]
for elem in y_final:
    y_pred.append(elem[1])
score=roc_auc_score(y_test, y_pred)
print(score)
# Out:
# 0.9838675579020122

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV30.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV30.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idpostulante'],how='left')
prediccion=pd.merge(prediccion,vistas2,on=['idaviso','idpostulante'],how='left')
prediccion=pd.merge(prediccion,vistas3,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion['lo_vio']=(prediccion['cantidad']>0)
prediccion=pd.merge(prediccion,postulaciones_por_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['postulaciones_misma_area']=prediccion['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion['postulaciones_mismo_nivel']=prediccion['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion['postulaciones_mismo_tipo']=prediccion['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
prediccion=pd.merge(prediccion,vistas_por_area,on=['idpostulante','nombre_area'],how='left')
prediccion=pd.merge(prediccion,vistas_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,vistas_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['vistas_por_area']=prediccion['vistas_por_area'].fillna(0)
prediccion['vistas_por_tipo']=prediccion['vistas_por_tipo'].fillna(0)
prediccion['vistas_por_nivel']=prediccion['vistas_por_tipo'].fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado Master Otro  \
# 69481  15089  1112117185       6L65Zx   FEM  40.0         -      -    -
# 91480  98310  1112505661       ekGJdj  MASC  35.0         -      -    -
# 51820  19411  1112225050      ekvoXY4  MASC  24.0         -      -    -
# 73881  20012  1112245441       ND0wQ5  MASC  46.0         -      -    -
# 99536  99497  1112512292       Ebjo36  MASC  46.0         -      -    -
# 5501   83333  1112466363       NZd2j5   FEM  31.0         -      -    -
# 68960  72903  1112463226      0zdkqM1   FEM  25.0         -      -    -
# 98002  97819  1112502938       143wWE   FEM  41.0         -      -    -
# 20495  83451  1112466383      MVPYaJe  MASC  30.0         -      -    -
# 39644  42877  1112423974      MVr0mMo   FEM  20.0         -      -    -
#
#       Posgrado Secundario        ...        vistas_postulante vistas_al_aviso  \
# 69481        -          -        ...                      3.0             NaN
# 91480        -          -        ...                      4.0             NaN
# 51820        -   Graduado        ...                     59.0             1.0
# 73881        -          -        ...                     11.0             NaN
# 99536        -          -        ...                      4.0             NaN
# 5501         -          -        ...                      9.0             NaN
# 68960        -          -        ...                     41.0             2.0
# 98002        -   Graduado        ...                     12.0             NaN
# 20495        -   Graduado        ...                      NaN             NaN
# 39644        -   Graduado        ...                     34.0             2.0
#
#        cantidad lo_vio postulaciones_misma_area postulaciones_mismo_tipo  \
# 69481  0.000000  False                      0.0                     16.0
# 91480  0.000000  False                      0.0                     15.0
# 51820  0.016949   True                      8.0                     21.0
# 73881  0.000000  False                      1.0                     13.0
# 99536  0.000000  False                      0.0                     11.0
# 5501   0.000000  False                      0.0                     17.0
# 68960  0.048780   True                      0.0                      1.0
# 98002  0.000000  False                      2.0                     14.0
# 20495  0.000000  False                      4.0                     46.0
# 39644  0.058824   True                      5.0                     25.0
#
#       postulaciones_mismo_nivel vistas_por_area  vistas_por_tipo  \
# 69481                       0.0             2.0              2.0
# 91480                       1.0             0.0              4.0
# 51820                      12.0            44.0             48.0
# 73881                       0.0             0.0             11.0
# 99536                       9.0             0.0              4.0
# 5501                       12.0             0.0              2.0
# 68960                      13.0             2.0              4.0
# 98002                       9.0             0.0              6.0
# 20495                      40.0             0.0              0.0
# 39644                       6.0            10.0             24.0
#
#        vistas_por_nivel
# 69481               2.0
# 91480               4.0
# 51820              48.0
# 73881              11.0
# 99536               4.0
# 5501                2.0
# 68960               4.0
# 98002               6.0
# 20495               0.0
# 39644              24.0
#
# [10 rows x 45 columns]

# %%
prediccion['nombre_area']=prediccion["nombre_area"].replace(means)
prediccion['nombre_area'].sample(10)
# Out:
# 55791    0.510770
# 65062    0.436788
# 94559    0.510770
# 90824    0.455480
# 63418    0.662019
# 37570    0.425553
# 27034    0.546835
# 37872    0.230807
# 97724    0.455480
# 17521    0.469293
# Name: nombre_area, dtype: float64

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[9.92111109e-01, 7.88889139e-03],
#        [9.84810507e-01, 1.51894931e-02],
#        [9.97506114e-01, 2.49388581e-03],
#        ...,
#        [9.99238003e-01, 7.61997141e-04],
#        [9.99060032e-01, 9.39967848e-04],
#        [9.99504069e-01, 4.95930623e-04]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     vistas_al_aviso cantidad lo_vio  \
# 0   Graduado    ...                 NaN      0.0  False
# 1          -    ...                 NaN      0.0  False
# 2   Graduado    ...                 NaN      0.0  False
# 3   Graduado    ...                 NaN      0.0  False
# 4          -    ...                 NaN      0.0  False
#
#   postulaciones_misma_area postulaciones_mismo_tipo postulaciones_mismo_nivel  \
# 0                      0.0                     17.0                       0.0
# 1                      5.0                     57.0                       0.0
# 2                      2.0                     14.0                       0.0
# 3                      0.0                     16.0                       0.0
# 4                      1.0                     16.0                       2.0
#
#    vistas_por_area vistas_por_tipo  vistas_por_nivel  sepostulo
# 0              4.0            24.0              24.0   0.007889
# 1              0.0             6.0               6.0   0.015189
# 2              1.0             7.0               7.0   0.002494
# 3              0.0             0.0               0.0   0.000428
# 4              0.0             3.0               3.0   0.000327
#
# [5 rows x 46 columns]

# %%
prediccion=prediccion[['id','sepostulo']]
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.007889
# 1   1   0.015189
# 2   2   0.002494
# 3   3   0.000428
# 4   4   0.000327

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion61.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.4624751150504916
