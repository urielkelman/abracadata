# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')
avisos['denominacion_empresa']=avisos['denominacion_empresa'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas2=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2=vistas2.rename(columns={'idAviso': 'idaviso'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q        15
# 1        0005E        58
# 2        000R8        14
# 3        001XE        26
# 4        003k9        32

# %%
vistas2=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           2          28
# 1    48375       RwVdKR           1          15
# 2   169730        1KjXB           2          99
# 3   169730       2AKzxa           2           2
# 4   169730        6LJ64           1          23

# %%
vistas2['cantidad']=vistas2['cantidad_x']/vistas2['cantidad_y']
vistas2.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas=vistas2
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.071429
# 1    48375       RwVdKR  0.066667
# 2   169730        1KjXB  0.020202
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.043478

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/7.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/8.csv").sample(len(postulaciones2)//2).reset_index(drop=True))
print(len(postulaciones2))
postulaciones2
# Out:
# 9906801
#             idaviso idpostulante  sepostulo
# 0        1112389495       5NbOjG          0
# 1        1112024109      1QP841b          0
# 2        1112490884      96XQ6N9          0
# 3        1111474259      qe2QJj1          0
# 4        1112211292      KBzbBJm          0
# 5        1112328485      3NzZv26          0
# 6        1112474766      akDjWwE          0
# 7        1112312385       aZpBJW          0
# 8        1112285628      akDWj55          0
# 9        1112322843      GNd0KNN          0
# 10       1112355899      DrXPRJX          0
# 11       1112461865      8MPoBDR          0
# 12       1111673413       a1NjRN          0
# 13       1112299006      jkVWXRQ          0
# 14       1112501771      owz0YGW          0
# 15       1002543409       Ej5AAb          0
# 16       1112425310      KBrpAO2          0
# 17       1112498569      pzNMppM          0
# 18       1111866251       ZKqL85          0
# 19       1112289529      ow2awXr          0
# 20       1112493109      5mP1DWM          0
# 21       1112326017      0zd9GZ9          0
# 22       1112242315      3NQKV6Q          0
# 23       1112452417      DrlVEwW          0
# 24       1112402816      mzdk9dZ          0
# 25       1112359100      3NP46xq          0
# 26       1112410555      bOVKA32          0
# 27       1112511403      mzdlAQO          0
# 28       1111272539      6rPpNM4          0
# 29       1111591317      6rP4K13          0
# ...             ...          ...        ...
# 3302237  1112208780      1QPNkqN          0
# 3302238  1112269651      JBXBa5p          0
# 3302239  1112244139      EzZ9eRo          0
# 3302240  1112295423      3Nz2PVa          0
# 3302241  1112439122      KBzJDGX          0
# 3302242  1112241679      EzO2KYz          0
# 3302243  1112341851      EzeeYa6          0
# 3302244  1112320024      PmG64e1          0
# 3302245  1112247272      lDwRZrX          0
# 3302246  1112275169      BmBWe6Z          0
# 3302247  1112315073      4rPvm0z          0
# 3302248  1112359614      ow5aG4e          0
# 3302249  1112452723      96XB89w          0
# 3302250  1111933764      4rNoDkq          0
# 3302251  1112394955      bOjolaE          0
# 3302252  1112423725      BmB8lmz          0
# 3302253  1112438516      mzGJVBO          0
# 3302254  1112341127       1GEP8B          0
# 3302255  1112409567       a1KxlZ          0
# 3302256  1112315964      EzE50wJ          0
# 3302257  1112440545      ekO6jq4          0
# 3302258  1112348302      owzOYDe          0
# 3302259  1112227544       a8Gp3m          0
# 3302260  1112309052      xk92lNb          0
# 3302261  1112479858      rm0oWrO          0
# 3302262  1112259244       6rjJLl          0
# 3302263  1112514525       YA8PWY          0
# 3302264  1112272757      NzPPbjx          0
# 3302265  1112205454      zv8pkN6          0
# 3302266  1111533798      RzNjdwR          0
#
# [9906801 rows x 3 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 16511335
# 16502023

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo        sexo  edad Doctorado  \
# 6829887   1112483819      QNr2mpV          0        MASC  41.0         -
# 88375     1112345900       aNrO10          1        MASC  25.0         -
# 6066408   1112463786       6Ba0JR          0         FEM  37.0         -
# 2953569   1112316704      jkjeJmr          1        MASC  27.0         -
# 10620797  1112509474       NBbq6D          0         FEM  27.0         -
# 12497684  1112411609      OqrN5kv          1        MASC  23.0         -
# 6913884   1112325602      8M2kObO          1        MASC  23.0         -
# 8261020   1112393025      1QrkaRE          1         FEM  24.0         -
# 7060250   1111713648      KBrbN6j          0        MASC  23.0         -
# 8150837   1112222159      owzrxrW          1         FEM  20.0         -
# 1943445   1112322294      A3ADdJx          1  NO_DECLARA  46.0         -
# 8042119   1112416153      vVjzWx5          1        MASC  40.0         -
# 793704    1112416443      ek4MdqE          1         FEM  25.0         -
# 11870178  1112439474      dYzwWvM          0         FEM  26.0         -
# 8316316   1111590903      X9oMWlO          1        MASC  22.0         -
# 3053312   1112457991      MVOdJa9          1        MASC  26.0         -
# 13860382  1111662557       NwXzRL          0        MASC  35.0         -
# 5423094   1111970806      BmZQzea          0         FEM  26.0         -
# 9446303   1112387636      pzdmGl3          0         FEM  54.0         -
# 8020567   1111883254      6rPYZQv          0         FEM  22.0         -
#
#          Master      Otro Posgrado Secundario    ...    viajar  \
# 6829887       -         -        -          -    ...     False
# 88375         -         -        -   Graduado    ...     False
# 6066408       -         -        -          -    ...     False
# 2953569       -         -        -   Graduado    ...     False
# 10620797      -  Graduado        -   Graduado    ...     False
# 12497684      -         -        -   Graduado    ...     False
# 6913884       -         -        -   Graduado    ...      True
# 8261020       -         -        -   Graduado    ...     False
# 7060250       -         -        -          -    ...     False
# 8150837       -         -        -          -    ...     False
# 1943445       -         -        -          -    ...     False
# 8042119       -         -        -   Graduado    ...     False
# 793704        -         -        -   Graduado    ...     False
# 11870178      -  Graduado        -   Graduado    ...     False
# 8316316       -         -        -          -    ...     False
# 3053312       -         -        -   Graduado    ...     False
# 13860382      -         -        -          -    ...     False
# 5423094       -         -        -   Graduado    ...     False
# 9446303       -         -        -   Graduado    ...     False
# 8020567       -         -        -   Graduado    ...     False
#
#          empresa_importante capacitacion remuneracion_pretendida graduados  \
# 6829887               False        False                   False     False
# 88375                 False        False                   False     False
# 6066408                True        False                   False     False
# 2953569                True        False                   False     False
# 10620797              False         True                   False     False
# 12497684              False        False                   False     False
# 6913884               False        False                   False     False
# 8261020               False         True                   False     False
# 7060250                True        False                   False     False
# 8150837                True        False                   False     False
# 1943445               False        False                   False     False
# 8042119               False        False                   False     False
# 793704                False         True                   False     False
# 11870178              False        False                   False     False
# 8316316               False        False                   False     False
# 3053312                True        False                   False     False
# 13860382               True        False                   False     False
# 5423094                True        False                   False     False
# 9446303                True        False                   False     False
# 8020567               False         True                   False     False
#
#          estudiantes conocimientos_especificos buen_ambiente  discriminacion  \
# 6829887        False                     False         False           False
# 88375           True                     False         False           False
# 6066408        False                     False          True           False
# 2953569        False                     False         False           False
# 10620797       False                     False         False           False
# 12497684       False                      True         False            True
# 6913884        False                     False         False           False
# 8261020        False                     False          True           False
# 7060250        False                     False         False           False
# 8150837        False                      True         False            True
# 1943445        False                      True         False            True
# 8042119         True                      True         False            True
# 793704         False                     False          True           False
# 11870178       False                      True         False           False
# 8316316        False                     False         False           False
# 3053312        False                     False         False           False
# 13860382       False                     False         False           False
# 5423094        False                     False         False           False
# 9446303        False                     False         False           False
# 8020567        False                     False          True           False
#
#           cantidad
# 6829887        NaN
# 88375          NaN
# 6066408        NaN
# 2953569        NaN
# 10620797       NaN
# 12497684  0.010526
# 6913884        NaN
# 8261020        NaN
# 7060250        NaN
# 8150837        NaN
# 1943445        NaN
# 8042119   0.006098
# 793704         NaN
# 11870178       NaN
# 8316316        NaN
# 3053312   0.003401
# 13860382       NaN
# 5423094        NaN
# 9446303        NaN
# 8020567        NaN
#
# [20 rows x 36 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 8743163   1112324014      W9V5OAj          0   FEM  19.0         -      -
# 5609008   1112237502      mzV4Rj6          0  MASC  23.0         -      -
# 6212687   1112358453      Nzr6raz          0   FEM  19.0         -      -
# 3949918   1112267433      VNkOqBN          0  MASC  24.0         -      -
# 11067320  1112277359       545aRv          0   FEM  27.0         -      -
# 7783242   1112354947      wVor1QV          0  MASC  24.0         -      -
# 8303356   1112431131      LN8Y1zr          1   FEM  26.0         -      -
# 3191776   1112336052      8MrJdjW          1  MASC  32.0         -      -
# 13616247  1112243201       eKOXGj          0  MASC  30.0         -      -
# 10316956  1111578578      MVzjNYe          0  MASC  23.0         -      -
# 4683794   1112326299      EzlpaO0          1   FEM  22.0         -      -
# 14091989  1112353218       ERlja9          0   FEM  37.0         -      -
# 7953881   1112341461       e0jVP4          0   FEM  28.0         -      -
# 14160884  1111781078      jkjKDej          0   FEM  37.0         -      -
# 9991932   1112250374      zvx4qZb          0   FEM  28.0         -      -
# 4939978   1112357783      OqPRe2B          1  MASC  27.0         -      -
# 967965    1112094756      rmexLab          1   FEM  21.0         -      -
# 4317575   1112339658      5mdX5ZX          1   FEM  25.0         -      -
# 3945309   1112271720      rmRobEA          1  MASC  29.0         -      -
# 13813810  1111955806      mzdlEq9          0   FEM  30.0         -      -
#
#               Otro Posgrado Secundario    ...    viajar empresa_importante  \
# 8743163          -        -   Graduado    ...     False               True
# 5609008   Graduado        -   Graduado    ...     False              False
# 6212687          -        -          -    ...     False              False
# 3949918          -        -   Graduado    ...     False              False
# 11067320         -        -   Graduado    ...     False              False
# 7783242          -        -          -    ...     False              False
# 8303356   Graduado        -   Graduado    ...     False              False
# 3191776          -        -   Graduado    ...     False              False
# 13616247  Graduado        -          -    ...     False              False
# 10316956         -        -          -    ...     False              False
# 4683794          -        -   Graduado    ...     False              False
# 14091989         -        -          -    ...     False              False
# 7953881          -        -          -    ...     False              False
# 14160884         -        -   Graduado    ...     False              False
# 9991932          -        -          -    ...      True              False
# 4939978          -        -          -    ...     False               True
# 967965           -        -   Graduado    ...     False              False
# 4317575          -        -   Graduado    ...     False              False
# 3945309   Graduado        -          -    ...     False               True
# 13813810         -        -          -    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 8743163         False                   False     False       False
# 5609008         False                   False     False       False
# 6212687         False                   False     False       False
# 3949918         False                   False     False        True
# 11067320        False                   False     False       False
# 7783242         False                   False     False       False
# 8303356         False                   False     False       False
# 3191776          True                    True     False       False
# 13616247        False                   False     False       False
# 10316956        False                   False     False       False
# 4683794         False                   False     False       False
# 14091989        False                   False     False       False
# 7953881         False                   False      True        True
# 14160884        False                   False     False       False
# 9991932         False                   False     False       False
# 4939978          True                   False     False       False
# 967965          False                   False     False       False
# 4317575         False                   False     False       False
# 3945309         False                   False     False       False
# 13813810        False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 8743163                      False         False           False  0.000000
# 5609008                      False         False           False  0.000000
# 6212687                      False         False           False  0.000000
# 3949918                      False          True           False  0.000000
# 11067320                     False          True           False  0.000000
# 7783242                      False         False           False  0.000000
# 8303356                      False         False           False  0.000000
# 3191776                      False         False           False  0.000000
# 13616247                      True         False            True  0.000000
# 10316956                     False         False           False  0.000000
# 4683794                      False         False           False  0.000000
# 14091989                     False         False           False  0.000000
# 7953881                      False         False           False  0.000000
# 14160884                     False         False           False  0.000000
# 9991932                      False         False           False  0.000000
# 4939978                      False          True           False  0.333333
# 967965                       False         False           False  0.085106
# 4317575                      False         False           False  0.000000
# 3945309                      False         False           False  0.000000
# 13813810                     False         False           False  0.000000
#
# [20 rows x 36 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
# Out:
# Train:  15281890 Test:  804310

# %%
features=['sexo',
 'edad',
 'Doctorado',
 'Master',
 'Otro',
 'Posgrado',
 'Secundario',
 'Terciario/Técnico',
 'Universitario',
 'tipo_de_trabajo',
 'nivel_laboral',
 'nombre_area',
 'denominacion_empresa',
 'pide_hombre',
 'pide_mujer',
 'ingles',
 'secundario','cantidad']
features
# Out:
# ['sexo',
#  'edad',
#  'Doctorado',
#  'Master',
#  'Otro',
#  'Posgrado',
#  'Secundario',
#  'Terciario/Técnico',
#  'Universitario',
#  'tipo_de_trabajo',
#  'nivel_laboral',
#  'nombre_area',
#  'denominacion_empresa',
#  'pide_hombre',
#  'pide_mujer',
#  'ingles',
#  'secundario',
#  'cantidad']

# %%
x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']

# %%
postulaciones=0
vistas2=0
c=0
gc.collect()
# Out:
# 161

# %%
c=lgb.LGBMClassifier(learning_rate=0.01,objective='binary',num_leaves=6000,max_depth=13,n_estimators=1200,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train,eval_set=[(x_test,y_test)],verbose=True,early_stopping_rounds=1)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")
# Out:
# [1]	valid_0's binary_logloss: 0.68864
# Training until validation scores don't improve for 1 rounds.
# [2]	valid_0's binary_logloss: 0.685747
# [3]	valid_0's binary_logloss: 0.681747
# [4]	valid_0's binary_logloss: 0.677407
# [5]	valid_0's binary_logloss: 0.673152
# [6]	valid_0's binary_logloss: 0.669707
# [7]	valid_0's binary_logloss: 0.665871
# [8]	valid_0's binary_logloss: 0.662204
# [9]	valid_0's binary_logloss: 0.659051
# [10]	valid_0's binary_logloss: 0.655107
# [11]	valid_0's binary_logloss: 0.651639
# [12]	valid_0's binary_logloss: 0.648117
# [13]	valid_0's binary_logloss: 0.64442
# [14]	valid_0's binary_logloss: 0.642175
# [15]	valid_0's binary_logloss: 0.638693
# [16]	valid_0's binary_logloss: 0.637007
# [17]	valid_0's binary_logloss: 0.633462
# [18]	valid_0's binary_logloss: 0.631212
# [19]	valid_0's binary_logloss: 0.628558
# [20]	valid_0's binary_logloss: 0.626411
# [21]	valid_0's binary_logloss: 0.623445
# [22]	valid_0's binary_logloss: 0.620158
# [23]	valid_0's binary_logloss: 0.617288
# [24]	valid_0's binary_logloss: 0.613996
# [25]	valid_0's binary_logloss: 0.611555
# [26]	valid_0's binary_logloss: 0.608636
# [27]	valid_0's binary_logloss: 0.605854
# [28]	valid_0's binary_logloss: 0.602917
# [29]	valid_0's binary_logloss: 0.600171
# [30]	valid_0's binary_logloss: 0.597498
# [31]	valid_0's binary_logloss: 0.595482
# [32]	valid_0's binary_logloss: 0.592832
# [33]	valid_0's binary_logloss: 0.590047
# [34]	valid_0's binary_logloss: 0.587636
# [35]	valid_0's binary_logloss: 0.584942
# [36]	valid_0's binary_logloss: 0.58357
# [37]	valid_0's binary_logloss: 0.581363
# [38]	valid_0's binary_logloss: 0.579382
# [39]	valid_0's binary_logloss: 0.577581
# [40]	valid_0's binary_logloss: 0.574941
# [41]	valid_0's binary_logloss: 0.572574
# [42]	valid_0's binary_logloss: 0.570531
# [43]	valid_0's binary_logloss: 0.568255
# [44]	valid_0's binary_logloss: 0.566645
# [45]	valid_0's binary_logloss: 0.564441
# [46]	valid_0's binary_logloss: 0.562249
# [47]	valid_0's binary_logloss: 0.560104
# [48]	valid_0's binary_logloss: 0.558337
# [49]	valid_0's binary_logloss: 0.556486
# [50]	valid_0's binary_logloss: 0.554645
# [51]	valid_0's binary_logloss: 0.552368
# [52]	valid_0's binary_logloss: 0.550186
# [53]	valid_0's binary_logloss: 0.548613
# [54]	valid_0's binary_logloss: 0.546484
# [55]	valid_0's binary_logloss: 0.544305
# [56]	valid_0's binary_logloss: 0.542897
# [57]	valid_0's binary_logloss: 0.541519
# [58]	valid_0's binary_logloss: 0.539626
# [59]	valid_0's binary_logloss: 0.537596
# [60]	valid_0's binary_logloss: 0.535963
# [61]	valid_0's binary_logloss: 0.534146
# [62]	valid_0's binary_logloss: 0.532658
# [63]	valid_0's binary_logloss: 0.530901
# [64]	valid_0's binary_logloss: 0.529586
# [65]	valid_0's binary_logloss: 0.528026
# [66]	valid_0's binary_logloss: 0.526132
# [67]	valid_0's binary_logloss: 0.524602
# [68]	valid_0's binary_logloss: 0.522985
# [69]	valid_0's binary_logloss: 0.521189
# [70]	valid_0's binary_logloss: 0.519475
# [71]	valid_0's binary_logloss: 0.517819
# [72]	valid_0's binary_logloss: 0.516253
# [73]	valid_0's binary_logloss: 0.514576
# [74]	valid_0's binary_logloss: 0.512959
# [75]	valid_0's binary_logloss: 0.511828
# [76]	valid_0's binary_logloss: 0.510542
# [77]	valid_0's binary_logloss: 0.509245
# [78]	valid_0's binary_logloss: 0.507908
# [79]	valid_0's binary_logloss: 0.506317
# [80]	valid_0's binary_logloss: 0.504706
# [81]	valid_0's binary_logloss: 0.503267
# [82]	valid_0's binary_logloss: 0.501746
# [83]	valid_0's binary_logloss: 0.500375
# [84]	valid_0's binary_logloss: 0.499028
# [85]	valid_0's binary_logloss: 0.497572
# [86]	valid_0's binary_logloss: 0.496671
# [87]	valid_0's binary_logloss: 0.495584
# [88]	valid_0's binary_logloss: 0.494476
# [89]	valid_0's binary_logloss: 0.493495
# [90]	valid_0's binary_logloss: 0.492271
# [91]	valid_0's binary_logloss: 0.49158
# [92]	valid_0's binary_logloss: 0.491017
# [93]	valid_0's binary_logloss: 0.489937
# [94]	valid_0's binary_logloss: 0.489223
# [95]	valid_0's binary_logloss: 0.488
# [96]	valid_0's binary_logloss: 0.487099
# [97]	valid_0's binary_logloss: 0.485776
# [98]	valid_0's binary_logloss: 0.484615
# [99]	valid_0's binary_logloss: 0.483425
# [100]	valid_0's binary_logloss: 0.482404
# [101]	valid_0's binary_logloss: 0.481466
# [102]	valid_0's binary_logloss: 0.480377
# [103]	valid_0's binary_logloss: 0.479326
# [104]	valid_0's binary_logloss: 0.47845
# [105]	valid_0's binary_logloss: 0.477476
# [106]	valid_0's binary_logloss: 0.476439
# [107]	valid_0's binary_logloss: 0.475644
# [108]	valid_0's binary_logloss: 0.474532
# [109]	valid_0's binary_logloss: 0.473426
# [110]	valid_0's binary_logloss: 0.472564
# [111]	valid_0's binary_logloss: 0.471613
# [112]	valid_0's binary_logloss: 0.470836
# [113]	valid_0's binary_logloss: 0.469765
# [114]	valid_0's binary_logloss: 0.469282
# [115]	valid_0's binary_logloss: 0.468338
# [116]	valid_0's binary_logloss: 0.467617
# [117]	valid_0's binary_logloss: 0.466595
# [118]	valid_0's binary_logloss: 0.465665
# [119]	valid_0's binary_logloss: 0.464912
# [120]	valid_0's binary_logloss: 0.463926
# [121]	valid_0's binary_logloss: 0.462874
# [122]	valid_0's binary_logloss: 0.46199
# [123]	valid_0's binary_logloss: 0.461046
# [124]	valid_0's binary_logloss: 0.460208
# [125]	valid_0's binary_logloss: 0.459585
# [126]	valid_0's binary_logloss: 0.458818
# [127]	valid_0's binary_logloss: 0.458055
# [128]	valid_0's binary_logloss: 0.457291
# [129]	valid_0's binary_logloss: 0.456382
# [130]	valid_0's binary_logloss: 0.455513
# [131]	valid_0's binary_logloss: 0.454694
# [132]	valid_0's binary_logloss: 0.453812
# [133]	valid_0's binary_logloss: 0.453016
# [134]	valid_0's binary_logloss: 0.452178
# [135]	valid_0's binary_logloss: 0.45128
# [136]	valid_0's binary_logloss: 0.4506
# [137]	valid_0's binary_logloss: 0.449908
# [138]	valid_0's binary_logloss: 0.449265
# [139]	valid_0's binary_logloss: 0.448552
# [140]	valid_0's binary_logloss: 0.447983
# [141]	valid_0's binary_logloss: 0.447337
# [142]	valid_0's binary_logloss: 0.446613
# [143]	valid_0's binary_logloss: 0.445809
# [144]	valid_0's binary_logloss: 0.44524
# [145]	valid_0's binary_logloss: 0.444477
# [146]	valid_0's binary_logloss: 0.443995
# [147]	valid_0's binary_logloss: 0.443372
# [148]	valid_0's binary_logloss: 0.442715
# [149]	valid_0's binary_logloss: 0.441986
# [150]	valid_0's binary_logloss: 0.441237
# [151]	valid_0's binary_logloss: 0.440743
# [152]	valid_0's binary_logloss: 0.440283
# [153]	valid_0's binary_logloss: 0.439549
# [154]	valid_0's binary_logloss: 0.439195
# [155]	valid_0's binary_logloss: 0.438703
# [156]	valid_0's binary_logloss: 0.438138
# [157]	valid_0's binary_logloss: 0.437544
# [158]	valid_0's binary_logloss: 0.436946
# [159]	valid_0's binary_logloss: 0.436307
# [160]	valid_0's binary_logloss: 0.435647
# [161]	valid_0's binary_logloss: 0.435197
# [162]	valid_0's binary_logloss: 0.434687
# [163]	valid_0's binary_logloss: 0.434123
# [164]	valid_0's binary_logloss: 0.433469
# [165]	valid_0's binary_logloss: 0.432965
# [166]	valid_0's binary_logloss: 0.432512
# [167]	valid_0's binary_logloss: 0.431893
# [168]	valid_0's binary_logloss: 0.431264
# [169]	valid_0's binary_logloss: 0.430723
# [170]	valid_0's binary_logloss: 0.430209
# [171]	valid_0's binary_logloss: 0.429715
# [172]	valid_0's binary_logloss: 0.429215
# [173]	valid_0's binary_logloss: 0.428623
# [174]	valid_0's binary_logloss: 0.428109
# [175]	valid_0's binary_logloss: 0.427546
# [176]	valid_0's binary_logloss: 0.426972
# [177]	valid_0's binary_logloss: 0.426556
# [178]	valid_0's binary_logloss: 0.426301
# [179]	valid_0's binary_logloss: 0.42584
# [180]	valid_0's binary_logloss: 0.425335
# [181]	valid_0's binary_logloss: 0.424966
# [182]	valid_0's binary_logloss: 0.424392
# [183]	valid_0's binary_logloss: 0.423856
# [184]	valid_0's binary_logloss: 0.423436
# [185]	valid_0's binary_logloss: 0.423023
# [186]	valid_0's binary_logloss: 0.422507
# [187]	valid_0's binary_logloss: 0.421971
# [188]	valid_0's binary_logloss: 0.421593
# [189]	valid_0's binary_logloss: 0.421243
# [190]	valid_0's binary_logloss: 0.42075
# [191]	valid_0's binary_logloss: 0.420367
# [192]	valid_0's binary_logloss: 0.419988
# [193]	valid_0's binary_logloss: 0.419582
# [194]	valid_0's binary_logloss: 0.41907
# [195]	valid_0's binary_logloss: 0.418711
# [196]	valid_0's binary_logloss: 0.418384
# [197]	valid_0's binary_logloss: 0.418006
# [198]	valid_0's binary_logloss: 0.417544
# [199]	valid_0's binary_logloss: 0.417083
# [200]	valid_0's binary_logloss: 0.416794
# [201]	valid_0's binary_logloss: 0.416315
# [202]	valid_0's binary_logloss: 0.415929
# [203]	valid_0's binary_logloss: 0.415654
# [204]	valid_0's binary_logloss: 0.415315
# [205]	valid_0's binary_logloss: 0.415019
# [206]	valid_0's binary_logloss: 0.414677
# [207]	valid_0's binary_logloss: 0.414251
# [208]	valid_0's binary_logloss: 0.413794
# [209]	valid_0's binary_logloss: 0.413472
# [210]	valid_0's binary_logloss: 0.413138
# [211]	valid_0's binary_logloss: 0.412775
# [212]	valid_0's binary_logloss: 0.412346
# [213]	valid_0's binary_logloss: 0.411947
# [214]	valid_0's binary_logloss: 0.411639
# [215]	valid_0's binary_logloss: 0.411291
# [216]	valid_0's binary_logloss: 0.410958
# [217]	valid_0's binary_logloss: 0.410617
# [218]	valid_0's binary_logloss: 0.410282
# [219]	valid_0's binary_logloss: 0.40996
# [220]	valid_0's binary_logloss: 0.40957
# [221]	valid_0's binary_logloss: 0.409379
# [222]	valid_0's binary_logloss: 0.408995
# [223]	valid_0's binary_logloss: 0.408627
# [224]	valid_0's binary_logloss: 0.408262
# [225]	valid_0's binary_logloss: 0.407947
# [226]	valid_0's binary_logloss: 0.407658
# [227]	valid_0's binary_logloss: 0.407453
# [228]	valid_0's binary_logloss: 0.407151
# [229]	valid_0's binary_logloss: 0.406779
# [230]	valid_0's binary_logloss: 0.40644
# [231]	valid_0's binary_logloss: 0.40608
# [232]	valid_0's binary_logloss: 0.405729
# [233]	valid_0's binary_logloss: 0.405413
# [234]	valid_0's binary_logloss: 0.405145
# [235]	valid_0's binary_logloss: 0.404824
# [236]	valid_0's binary_logloss: 0.404561
# [237]	valid_0's binary_logloss: 0.404236
# [238]	valid_0's binary_logloss: 0.403907
# [239]	valid_0's binary_logloss: 0.403634
# [240]	valid_0's binary_logloss: 0.403304
# [241]	valid_0's binary_logloss: 0.40298
# [242]	valid_0's binary_logloss: 0.40286
# [243]	valid_0's binary_logloss: 0.402595
# [244]	valid_0's binary_logloss: 0.402288
# [245]	valid_0's binary_logloss: 0.40206
# [246]	valid_0's binary_logloss: 0.401789
# [247]	valid_0's binary_logloss: 0.401523
# [248]	valid_0's binary_logloss: 0.401253
# [249]	valid_0's binary_logloss: 0.401012
# [250]	valid_0's binary_logloss: 0.400763
# [251]	valid_0's binary_logloss: 0.400546
# [252]	valid_0's binary_logloss: 0.40026
# [253]	valid_0's binary_logloss: 0.4
# [254]	valid_0's binary_logloss: 0.399751
# [255]	valid_0's binary_logloss: 0.399502
# [256]	valid_0's binary_logloss: 0.39934
# [257]	valid_0's binary_logloss: 0.39906
# [258]	valid_0's binary_logloss: 0.398812
# [259]	valid_0's binary_logloss: 0.398602
# [260]	valid_0's binary_logloss: 0.398372
# [261]	valid_0's binary_logloss: 0.398152
# [262]	valid_0's binary_logloss: 0.397956
# [263]	valid_0's binary_logloss: 0.397703
# [264]	valid_0's binary_logloss: 0.39747
# [265]	valid_0's binary_logloss: 0.397238
# [266]	valid_0's binary_logloss: 0.397037
# [267]	valid_0's binary_logloss: 0.39677
# [268]	valid_0's binary_logloss: 0.396525
# [269]	valid_0's binary_logloss: 0.396338
# [270]	valid_0's binary_logloss: 0.396129
# [271]	valid_0's binary_logloss: 0.395891
# [272]	valid_0's binary_logloss: 0.395669
# [273]	valid_0's binary_logloss: 0.395503
# [274]	valid_0's binary_logloss: 0.395247
# [275]	valid_0's binary_logloss: 0.39508
# [276]	valid_0's binary_logloss: 0.394859
# [277]	valid_0's binary_logloss: 0.394616
# [278]	valid_0's binary_logloss: 0.394418
# [279]	valid_0's binary_logloss: 0.394209
# [280]	valid_0's binary_logloss: 0.393999
# [281]	valid_0's binary_logloss: 0.393828
# [282]	valid_0's binary_logloss: 0.393708
# [283]	valid_0's binary_logloss: 0.393503
# [284]	valid_0's binary_logloss: 0.393324
# [285]	valid_0's binary_logloss: 0.393134
# [286]	valid_0's binary_logloss: 0.392972
# [287]	valid_0's binary_logloss: 0.392781
# [288]	valid_0's binary_logloss: 0.392603
# [289]	valid_0's binary_logloss: 0.392449
# [290]	valid_0's binary_logloss: 0.392281
# [291]	valid_0's binary_logloss: 0.392136
# [292]	valid_0's binary_logloss: 0.392004
# [293]	valid_0's binary_logloss: 0.391836
# [294]	valid_0's binary_logloss: 0.391646
# [295]	valid_0's binary_logloss: 0.39151
# [296]	valid_0's binary_logloss: 0.391331
# [297]	valid_0's binary_logloss: 0.391156
# [298]	valid_0's binary_logloss: 0.390975
# [299]	valid_0's binary_logloss: 0.390803
# [300]	valid_0's binary_logloss: 0.390692
# [301]	valid_0's binary_logloss: 0.390478
# [302]	valid_0's binary_logloss: 0.390304
# [303]	valid_0's binary_logloss: 0.390146
# [304]	valid_0's binary_logloss: 0.390006
# [305]	valid_0's binary_logloss: 0.389763
# [306]	valid_0's binary_logloss: 0.389657
# [307]	valid_0's binary_logloss: 0.389496
# [308]	valid_0's binary_logloss: 0.389323
# [309]	valid_0's binary_logloss: 0.389166
# [310]	valid_0's binary_logloss: 0.389045
# [311]	valid_0's binary_logloss: 0.388892
# [312]	valid_0's binary_logloss: 0.388678
# [313]	valid_0's binary_logloss: 0.388462
# [314]	valid_0's binary_logloss: 0.38836
# [315]	valid_0's binary_logloss: 0.388197
# [316]	valid_0's binary_logloss: 0.388028
# [317]	valid_0's binary_logloss: 0.387894
# [318]	valid_0's binary_logloss: 0.387706
# [319]	valid_0's binary_logloss: 0.387548
# [320]	valid_0's binary_logloss: 0.387353
# [321]	valid_0's binary_logloss: 0.387234
# [322]	valid_0's binary_logloss: 0.387069
# [323]	valid_0's binary_logloss: 0.386873
# [324]	valid_0's binary_logloss: 0.386692
# [325]	valid_0's binary_logloss: 0.386564
# [326]	valid_0's binary_logloss: 0.386448
# [327]	valid_0's binary_logloss: 0.386314
# [328]	valid_0's binary_logloss: 0.386136
# [329]	valid_0's binary_logloss: 0.38601
# [330]	valid_0's binary_logloss: 0.385872
# [331]	valid_0's binary_logloss: 0.385746
# [332]	valid_0's binary_logloss: 0.38562
# [333]	valid_0's binary_logloss: 0.38547
# [334]	valid_0's binary_logloss: 0.385366
# [335]	valid_0's binary_logloss: 0.385217
# [336]	valid_0's binary_logloss: 0.385071
# [337]	valid_0's binary_logloss: 0.384936
# [338]	valid_0's binary_logloss: 0.384853
# [339]	valid_0's binary_logloss: 0.384737
# [340]	valid_0's binary_logloss: 0.384611
# [341]	valid_0's binary_logloss: 0.384488
# [342]	valid_0's binary_logloss: 0.384388
# [343]	valid_0's binary_logloss: 0.384253
# [344]	valid_0's binary_logloss: 0.384136
# [345]	valid_0's binary_logloss: 0.383933
# [346]	valid_0's binary_logloss: 0.383844
# [347]	valid_0's binary_logloss: 0.383715
# [348]	valid_0's binary_logloss: 0.383621
# [349]	valid_0's binary_logloss: 0.383488
# [350]	valid_0's binary_logloss: 0.383349
# [351]	valid_0's binary_logloss: 0.38319
# [352]	valid_0's binary_logloss: 0.383111
# [353]	valid_0's binary_logloss: 0.382993
# [354]	valid_0's binary_logloss: 0.382915
# [355]	valid_0's binary_logloss: 0.382824
# [356]	valid_0's binary_logloss: 0.38272
# [357]	valid_0's binary_logloss: 0.382594
# [358]	valid_0's binary_logloss: 0.382484
# [359]	valid_0's binary_logloss: 0.382383
# [360]	valid_0's binary_logloss: 0.38222
# [361]	valid_0's binary_logloss: 0.382118
# [362]	valid_0's binary_logloss: 0.382034
# [363]	valid_0's binary_logloss: 0.381894
# [364]	valid_0's binary_logloss: 0.381764
# [365]	valid_0's binary_logloss: 0.381646
# [366]	valid_0's binary_logloss: 0.381549
# [367]	valid_0's binary_logloss: 0.381447
# [368]	valid_0's binary_logloss: 0.381327
# [369]	valid_0's binary_logloss: 0.381244
# [370]	valid_0's binary_logloss: 0.381166
# [371]	valid_0's binary_logloss: 0.381075
# [372]	valid_0's binary_logloss: 0.380981
# [373]	valid_0's binary_logloss: 0.380895
# [374]	valid_0's binary_logloss: 0.380832
# [375]	valid_0's binary_logloss: 0.380746
# [376]	valid_0's binary_logloss: 0.380634
# [377]	valid_0's binary_logloss: 0.380553
# [378]	valid_0's binary_logloss: 0.380489
# [379]	valid_0's binary_logloss: 0.380429
# [380]	valid_0's binary_logloss: 0.380294
# [381]	valid_0's binary_logloss: 0.380221
# [382]	valid_0's binary_logloss: 0.380133
# [383]	valid_0's binary_logloss: 0.380045
# [384]	valid_0's binary_logloss: 0.379977
# [385]	valid_0's binary_logloss: 0.379913
# [386]	valid_0's binary_logloss: 0.379878
# [387]	valid_0's binary_logloss: 0.379785
# [388]	valid_0's binary_logloss: 0.379674
# [389]	valid_0's binary_logloss: 0.379589
# [390]	valid_0's binary_logloss: 0.379447
# [391]	valid_0's binary_logloss: 0.379399
# [392]	valid_0's binary_logloss: 0.379352
# [393]	valid_0's binary_logloss: 0.379307
# [394]	valid_0's binary_logloss: 0.379264
# [395]	valid_0's binary_logloss: 0.379207
# [396]	valid_0's binary_logloss: 0.379185
# [397]	valid_0's binary_logloss: 0.379162
# [398]	valid_0's binary_logloss: 0.379118
# [399]	valid_0's binary_logloss: 0.379046
# [400]	valid_0's binary_logloss: 0.379022
# [401]	valid_0's binary_logloss: 0.37898
# [402]	valid_0's binary_logloss: 0.378907
# [403]	valid_0's binary_logloss: 0.378779
# [404]	valid_0's binary_logloss: 0.378738
# [405]	valid_0's binary_logloss: 0.378595
# [406]	valid_0's binary_logloss: 0.378555
# [407]	valid_0's binary_logloss: 0.378531
# [408]	valid_0's binary_logloss: 0.378489
# [409]	valid_0's binary_logloss: 0.378364
# [410]	valid_0's binary_logloss: 0.378324
# [411]	valid_0's binary_logloss: 0.378237
# [412]	valid_0's binary_logloss: 0.378156
# [413]	valid_0's binary_logloss: 0.378111
# [414]	valid_0's binary_logloss: 0.377981
# [415]	valid_0's binary_logloss: 0.377907
# [416]	valid_0's binary_logloss: 0.377871
# [417]	valid_0's binary_logloss: 0.377833
# [418]	valid_0's binary_logloss: 0.377792
# [419]	valid_0's binary_logloss: 0.377752
# [420]	valid_0's binary_logloss: 0.377708
# [421]	valid_0's binary_logloss: 0.377666
# [422]	valid_0's binary_logloss: 0.377609
# [423]	valid_0's binary_logloss: 0.377535
# [424]	valid_0's binary_logloss: 0.377454
# [425]	valid_0's binary_logloss: 0.377387
# [426]	valid_0's binary_logloss: 0.377298
# [427]	valid_0's binary_logloss: 0.377265
# [428]	valid_0's binary_logloss: 0.377225
# [429]	valid_0's binary_logloss: 0.377123
# [430]	valid_0's binary_logloss: 0.377091
# [431]	valid_0's binary_logloss: 0.377043
# [432]	valid_0's binary_logloss: 0.377005
# [433]	valid_0's binary_logloss: 0.376974
# [434]	valid_0's binary_logloss: 0.376943
# [435]	valid_0's binary_logloss: 0.376789
# [436]	valid_0's binary_logloss: 0.376759
# [437]	valid_0's binary_logloss: 0.376742
# [438]	valid_0's binary_logloss: 0.376683
# [439]	valid_0's binary_logloss: 0.376653
# [440]	valid_0's binary_logloss: 0.376618
# [441]	valid_0's binary_logloss: 0.376588
# [442]	valid_0's binary_logloss: 0.376531
# [443]	valid_0's binary_logloss: 0.376502
# [444]	valid_0's binary_logloss: 0.376481
# [445]	valid_0's binary_logloss: 0.376338
# [446]	valid_0's binary_logloss: 0.37625
# [447]	valid_0's binary_logloss: 0.376222
# [448]	valid_0's binary_logloss: 0.376193
# [449]	valid_0's binary_logloss: 0.376165
# [450]	valid_0's binary_logloss: 0.376137
# [451]	valid_0's binary_logloss: 0.375998
# [452]	valid_0's binary_logloss: 0.375907
# [453]	valid_0's binary_logloss: 0.375879
# [454]	valid_0's binary_logloss: 0.375852
# [455]	valid_0's binary_logloss: 0.375818
# [456]	valid_0's binary_logloss: 0.375746
# [457]	valid_0's binary_logloss: 0.37572
# [458]	valid_0's binary_logloss: 0.375693
# [459]	valid_0's binary_logloss: 0.375596
# [460]	valid_0's binary_logloss: 0.375487
# [461]	valid_0's binary_logloss: 0.375456
# [462]	valid_0's binary_logloss: 0.37543
# [463]	valid_0's binary_logloss: 0.375317
# [464]	valid_0's binary_logloss: 0.375291
# [465]	valid_0's binary_logloss: 0.375227
# [466]	valid_0's binary_logloss: 0.375202
# [467]	valid_0's binary_logloss: 0.375177
# [468]	valid_0's binary_logloss: 0.375079
# [469]	valid_0's binary_logloss: 0.375054
# [470]	valid_0's binary_logloss: 0.37503
# [471]	valid_0's binary_logloss: 0.374928
# [472]	valid_0's binary_logloss: 0.37491
# [473]	valid_0's binary_logloss: 0.374886
# [474]	valid_0's binary_logloss: 0.374789
# [475]	valid_0's binary_logloss: 0.374758
# [476]	valid_0's binary_logloss: 0.374744
# [477]	valid_0's binary_logloss: 0.37472
# [478]	valid_0's binary_logloss: 0.374697
# [479]	valid_0's binary_logloss: 0.374673
# [480]	valid_0's binary_logloss: 0.37465
# [481]	valid_0's binary_logloss: 0.374628
# [482]	valid_0's binary_logloss: 0.374604
# [483]	valid_0's binary_logloss: 0.374503
# [484]	valid_0's binary_logloss: 0.374479
# [485]	valid_0's binary_logloss: 0.374457
# [486]	valid_0's binary_logloss: 0.374434
# [487]	valid_0's binary_logloss: 0.374413
# [488]	valid_0's binary_logloss: 0.3744
# [489]	valid_0's binary_logloss: 0.374371
# [490]	valid_0's binary_logloss: 0.374348
# [491]	valid_0's binary_logloss: 0.374324
# [492]	valid_0's binary_logloss: 0.374204
# [493]	valid_0's binary_logloss: 0.374175
# [494]	valid_0's binary_logloss: 0.37414
# [495]	valid_0's binary_logloss: 0.374052
# [496]	valid_0's binary_logloss: 0.374039
# [497]	valid_0's binary_logloss: 0.374017
# [498]	valid_0's binary_logloss: 0.373996
# [499]	valid_0's binary_logloss: 0.373969
# [500]	valid_0's binary_logloss: 0.373862
# [501]	valid_0's binary_logloss: 0.373818
# [502]	valid_0's binary_logloss: 0.373797
# [503]	valid_0's binary_logloss: 0.373777
# [504]	valid_0's binary_logloss: 0.373758
# [505]	valid_0's binary_logloss: 0.373745
# [506]	valid_0's binary_logloss: 0.373626
# [507]	valid_0's binary_logloss: 0.373512
# [508]	valid_0's binary_logloss: 0.373492
# [509]	valid_0's binary_logloss: 0.37348
# [510]	valid_0's binary_logloss: 0.373461
# [511]	valid_0's binary_logloss: 0.373441
# [512]	valid_0's binary_logloss: 0.373422
# [513]	valid_0's binary_logloss: 0.373403
# [514]	valid_0's binary_logloss: 0.373384
# [515]	valid_0's binary_logloss: 0.373365
# [516]	valid_0's binary_logloss: 0.373345
# [517]	valid_0's binary_logloss: 0.373293
# [518]	valid_0's binary_logloss: 0.373274
# [519]	valid_0's binary_logloss: 0.373256
# [520]	valid_0's binary_logloss: 0.373237
# [521]	valid_0's binary_logloss: 0.373216
# [522]	valid_0's binary_logloss: 0.373204
# [523]	valid_0's binary_logloss: 0.373181
# [524]	valid_0's binary_logloss: 0.373163
# [525]	valid_0's binary_logloss: 0.373151
# [526]	valid_0's binary_logloss: 0.373139
# [527]	valid_0's binary_logloss: 0.373085
# [528]	valid_0's binary_logloss: 0.373073
# [529]	valid_0's binary_logloss: 0.373055
# [530]	valid_0's binary_logloss: 0.373036
# [531]	valid_0's binary_logloss: 0.373017
# [532]	valid_0's binary_logloss: 0.373
# [533]	valid_0's binary_logloss: 0.372982
# [534]	valid_0's binary_logloss: 0.372958
# [535]	valid_0's binary_logloss: 0.372934
# [536]	valid_0's binary_logloss: 0.372828
# [537]	valid_0's binary_logloss: 0.372782
# [538]	valid_0's binary_logloss: 0.372724
# [539]	valid_0's binary_logloss: 0.372659
# [540]	valid_0's binary_logloss: 0.372642
# [541]	valid_0's binary_logloss: 0.372626
# [542]	valid_0's binary_logloss: 0.372586
# [543]	valid_0's binary_logloss: 0.372575
# [544]	valid_0's binary_logloss: 0.372558
# [545]	valid_0's binary_logloss: 0.37253
# [546]	valid_0's binary_logloss: 0.372419
# [547]	valid_0's binary_logloss: 0.372403
# [548]	valid_0's binary_logloss: 0.372387
# [549]	valid_0's binary_logloss: 0.372316
# [550]	valid_0's binary_logloss: 0.372305
# [551]	valid_0's binary_logloss: 0.372294
# [552]	valid_0's binary_logloss: 0.372178
# [553]	valid_0's binary_logloss: 0.372162
# [554]	valid_0's binary_logloss: 0.372146
# [555]	valid_0's binary_logloss: 0.372093
# [556]	valid_0's binary_logloss: 0.372077
# [557]	valid_0's binary_logloss: 0.372025
# [558]	valid_0's binary_logloss: 0.371926
# [559]	valid_0's binary_logloss: 0.371854
# [560]	valid_0's binary_logloss: 0.371838
# [561]	valid_0's binary_logloss: 0.371777
# [562]	valid_0's binary_logloss: 0.371761
# [563]	valid_0's binary_logloss: 0.371746
# [564]	valid_0's binary_logloss: 0.371731
# [565]	valid_0's binary_logloss: 0.371682
# [566]	valid_0's binary_logloss: 0.371668
# [567]	valid_0's binary_logloss: 0.371653
# [568]	valid_0's binary_logloss: 0.371642
# [569]	valid_0's binary_logloss: 0.371628
# [570]	valid_0's binary_logloss: 0.371571
# [571]	valid_0's binary_logloss: 0.371556
# [572]	valid_0's binary_logloss: 0.371542
# [573]	valid_0's binary_logloss: 0.371528
# [574]	valid_0's binary_logloss: 0.371514
# [575]	valid_0's binary_logloss: 0.371439
# [576]	valid_0's binary_logloss: 0.371425
# [577]	valid_0's binary_logloss: 0.371408
# [578]	valid_0's binary_logloss: 0.371394
# [579]	valid_0's binary_logloss: 0.371331
# [580]	valid_0's binary_logloss: 0.371275
# [581]	valid_0's binary_logloss: 0.371261
# [582]	valid_0's binary_logloss: 0.371168
# [583]	valid_0's binary_logloss: 0.371155
# [584]	valid_0's binary_logloss: 0.371143
# [585]	valid_0's binary_logloss: 0.371047
# [586]	valid_0's binary_logloss: 0.371034
# [587]	valid_0's binary_logloss: 0.37102
# [588]	valid_0's binary_logloss: 0.37101
# [589]	valid_0's binary_logloss: 0.370996
# [590]	valid_0's binary_logloss: 0.370983
# [591]	valid_0's binary_logloss: 0.370888
# [592]	valid_0's binary_logloss: 0.370874
# [593]	valid_0's binary_logloss: 0.370792
# [594]	valid_0's binary_logloss: 0.370782
# [595]	valid_0's binary_logloss: 0.370768
# [596]	valid_0's binary_logloss: 0.370756
# [597]	valid_0's binary_logloss: 0.370743
# [598]	valid_0's binary_logloss: 0.37073
# [599]	valid_0's binary_logloss: 0.370717
# [600]	valid_0's binary_logloss: 0.370703
# [601]	valid_0's binary_logloss: 0.37069
# [602]	valid_0's binary_logloss: 0.370603
# [603]	valid_0's binary_logloss: 0.370591
# [604]	valid_0's binary_logloss: 0.370502
# [605]	valid_0's binary_logloss: 0.370492
# [606]	valid_0's binary_logloss: 0.37048
# [607]	valid_0's binary_logloss: 0.370468
# [608]	valid_0's binary_logloss: 0.370455
# [609]	valid_0's binary_logloss: 0.370442
# [610]	valid_0's binary_logloss: 0.37043
# [611]	valid_0's binary_logloss: 0.37042
# [612]	valid_0's binary_logloss: 0.370408
# [613]	valid_0's binary_logloss: 0.370395
# [614]	valid_0's binary_logloss: 0.370383
# [615]	valid_0's binary_logloss: 0.370371
# [616]	valid_0's binary_logloss: 0.370361
# [617]	valid_0's binary_logloss: 0.370349
# [618]	valid_0's binary_logloss: 0.370334
# [619]	valid_0's binary_logloss: 0.370289
# [620]	valid_0's binary_logloss: 0.370234
# [621]	valid_0's binary_logloss: 0.370222
# [622]	valid_0's binary_logloss: 0.370212
# [623]	valid_0's binary_logloss: 0.3702
# [624]	valid_0's binary_logloss: 0.370112
# [625]	valid_0's binary_logloss: 0.3701
# [626]	valid_0's binary_logloss: 0.370088
# [627]	valid_0's binary_logloss: 0.370077
# [628]	valid_0's binary_logloss: 0.370066
# [629]	valid_0's binary_logloss: 0.370057
# [630]	valid_0's binary_logloss: 0.370046
# [631]	valid_0's binary_logloss: 0.369992
# [632]	valid_0's binary_logloss: 0.369912
# [633]	valid_0's binary_logloss: 0.369903
# [634]	valid_0's binary_logloss: 0.369892
# [635]	valid_0's binary_logloss: 0.36988
# [636]	valid_0's binary_logloss: 0.369869
# [637]	valid_0's binary_logloss: 0.369857
# [638]	valid_0's binary_logloss: 0.369846
# [639]	valid_0's binary_logloss: 0.369836
# [640]	valid_0's binary_logloss: 0.369824
# [641]	valid_0's binary_logloss: 0.369814
# [642]	valid_0's binary_logloss: 0.369803
# [643]	valid_0's binary_logloss: 0.369792
# [644]	valid_0's binary_logloss: 0.369734
# [645]	valid_0's binary_logloss: 0.369725
# [646]	valid_0's binary_logloss: 0.369714
# [647]	valid_0's binary_logloss: 0.369702
# [648]	valid_0's binary_logloss: 0.369693
# [649]	valid_0's binary_logloss: 0.369685
# [650]	valid_0's binary_logloss: 0.369675
# [651]	valid_0's binary_logloss: 0.369664
# [652]	valid_0's binary_logloss: 0.369649
# [653]	valid_0's binary_logloss: 0.369607
# [654]	valid_0's binary_logloss: 0.369568
# [655]	valid_0's binary_logloss: 0.369558
# [656]	valid_0's binary_logloss: 0.369547
# [657]	valid_0's binary_logloss: 0.369537
# [658]	valid_0's binary_logloss: 0.369457
# [659]	valid_0's binary_logloss: 0.369446
# [660]	valid_0's binary_logloss: 0.369436
# [661]	valid_0's binary_logloss: 0.369424
# [662]	valid_0's binary_logloss: 0.369416
# [663]	valid_0's binary_logloss: 0.369406
# [664]	valid_0's binary_logloss: 0.369323
# [665]	valid_0's binary_logloss: 0.369279
# [666]	valid_0's binary_logloss: 0.36927
# [667]	valid_0's binary_logloss: 0.369184
# [668]	valid_0's binary_logloss: 0.369174
# [669]	valid_0's binary_logloss: 0.369163
# [670]	valid_0's binary_logloss: 0.369155
# [671]	valid_0's binary_logloss: 0.369145
# [672]	valid_0's binary_logloss: 0.369136
# [673]	valid_0's binary_logloss: 0.369085
# [674]	valid_0's binary_logloss: 0.369073
# [675]	valid_0's binary_logloss: 0.369063
# [676]	valid_0's binary_logloss: 0.369012
# [677]	valid_0's binary_logloss: 0.368931
# [678]	valid_0's binary_logloss: 0.368922
# [679]	valid_0's binary_logloss: 0.368914
# [680]	valid_0's binary_logloss: 0.368906
# [681]	valid_0's binary_logloss: 0.368861
# [682]	valid_0's binary_logloss: 0.368831
# [683]	valid_0's binary_logloss: 0.368821
# [684]	valid_0's binary_logloss: 0.368812
# [685]	valid_0's binary_logloss: 0.36877
# [686]	valid_0's binary_logloss: 0.368761
# [687]	valid_0's binary_logloss: 0.368751
# [688]	valid_0's binary_logloss: 0.368742
# [689]	valid_0's binary_logloss: 0.368733
# [690]	valid_0's binary_logloss: 0.368725
# [691]	valid_0's binary_logloss: 0.368716
# [692]	valid_0's binary_logloss: 0.368707
# [693]	valid_0's binary_logloss: 0.368692
# [694]	valid_0's binary_logloss: 0.36864
# [695]	valid_0's binary_logloss: 0.36863
# [696]	valid_0's binary_logloss: 0.368622
# [697]	valid_0's binary_logloss: 0.368614
# [698]	valid_0's binary_logloss: 0.368606
# [699]	valid_0's binary_logloss: 0.368597
# [700]	valid_0's binary_logloss: 0.368588
# [701]	valid_0's binary_logloss: 0.368579
# [702]	valid_0's binary_logloss: 0.368571
# [703]	valid_0's binary_logloss: 0.368563
# [704]	valid_0's binary_logloss: 0.368553
# [705]	valid_0's binary_logloss: 0.368544
# [706]	valid_0's binary_logloss: 0.368535
# [707]	valid_0's binary_logloss: 0.368526
# [708]	valid_0's binary_logloss: 0.368516
# [709]	valid_0's binary_logloss: 0.368508
# [710]	valid_0's binary_logloss: 0.368499
# [711]	valid_0's binary_logloss: 0.36849
# [712]	valid_0's binary_logloss: 0.368483
# [713]	valid_0's binary_logloss: 0.368473
# [714]	valid_0's binary_logloss: 0.368464
# [715]	valid_0's binary_logloss: 0.368456
# [716]	valid_0's binary_logloss: 0.368401
# [717]	valid_0's binary_logloss: 0.368392
# [718]	valid_0's binary_logloss: 0.368384
# [719]	valid_0's binary_logloss: 0.368375
# [720]	valid_0's binary_logloss: 0.368294
# [721]	valid_0's binary_logloss: 0.368286
# [722]	valid_0's binary_logloss: 0.368277
# [723]	valid_0's binary_logloss: 0.368245
# [724]	valid_0's binary_logloss: 0.368237
# [725]	valid_0's binary_logloss: 0.368161
# [726]	valid_0's binary_logloss: 0.368111
# [727]	valid_0's binary_logloss: 0.368078
# [728]	valid_0's binary_logloss: 0.36807
# [729]	valid_0's binary_logloss: 0.368028
# [730]	valid_0's binary_logloss: 0.367987
# [731]	valid_0's binary_logloss: 0.367951
# [732]	valid_0's binary_logloss: 0.367943
# [733]	valid_0's binary_logloss: 0.367935
# [734]	valid_0's binary_logloss: 0.367879
# [735]	valid_0's binary_logloss: 0.367871
# [736]	valid_0's binary_logloss: 0.367864
# [737]	valid_0's binary_logloss: 0.367855
# [738]	valid_0's binary_logloss: 0.36782
# [739]	valid_0's binary_logloss: 0.367812
# [740]	valid_0's binary_logloss: 0.367758
# [741]	valid_0's binary_logloss: 0.367683
# [742]	valid_0's binary_logloss: 0.367673
# [743]	valid_0's binary_logloss: 0.367666
# [744]	valid_0's binary_logloss: 0.367658
# [745]	valid_0's binary_logloss: 0.367576
# [746]	valid_0's binary_logloss: 0.367568
# [747]	valid_0's binary_logloss: 0.36756
# [748]	valid_0's binary_logloss: 0.367553
# [749]	valid_0's binary_logloss: 0.367495
# [750]	valid_0's binary_logloss: 0.367487
# [751]	valid_0's binary_logloss: 0.36748
# [752]	valid_0's binary_logloss: 0.367472
# [753]	valid_0's binary_logloss: 0.367465
# [754]	valid_0's binary_logloss: 0.367455
# [755]	valid_0's binary_logloss: 0.367447
# [756]	valid_0's binary_logloss: 0.36744
# [757]	valid_0's binary_logloss: 0.367432
# [758]	valid_0's binary_logloss: 0.367394
# [759]	valid_0's binary_logloss: 0.367385
# [760]	valid_0's binary_logloss: 0.367378
# [761]	valid_0's binary_logloss: 0.367319
# [762]	valid_0's binary_logloss: 0.367311
# [763]	valid_0's binary_logloss: 0.367301
# [764]	valid_0's binary_logloss: 0.367295
# [765]	valid_0's binary_logloss: 0.367288
# [766]	valid_0's binary_logloss: 0.36728
# [767]	valid_0's binary_logloss: 0.367273
# [768]	valid_0's binary_logloss: 0.367265
# [769]	valid_0's binary_logloss: 0.367258
# [770]	valid_0's binary_logloss: 0.367251
# [771]	valid_0's binary_logloss: 0.367199
# [772]	valid_0's binary_logloss: 0.367191
# [773]	valid_0's binary_logloss: 0.367184
# [774]	valid_0's binary_logloss: 0.367177
# [775]	valid_0's binary_logloss: 0.367124
# [776]	valid_0's binary_logloss: 0.367115
# [777]	valid_0's binary_logloss: 0.367108
# [778]	valid_0's binary_logloss: 0.367059
# [779]	valid_0's binary_logloss: 0.367052
# [780]	valid_0's binary_logloss: 0.367045
# [781]	valid_0's binary_logloss: 0.367008
# [782]	valid_0's binary_logloss: 0.36697
# [783]	valid_0's binary_logloss: 0.366964
# [784]	valid_0's binary_logloss: 0.366957
# [785]	valid_0's binary_logloss: 0.366917
# [786]	valid_0's binary_logloss: 0.366908
# [787]	valid_0's binary_logloss: 0.3669
# [788]	valid_0's binary_logloss: 0.366893
# [789]	valid_0's binary_logloss: 0.366886
# [790]	valid_0's binary_logloss: 0.366879
# [791]	valid_0's binary_logloss: 0.366873
# [792]	valid_0's binary_logloss: 0.366866
# [793]	valid_0's binary_logloss: 0.36686
# [794]	valid_0's binary_logloss: 0.366851
# [795]	valid_0's binary_logloss: 0.366844
# [796]	valid_0's binary_logloss: 0.36679
# [797]	valid_0's binary_logloss: 0.366782
# [798]	valid_0's binary_logloss: 0.366775
# [799]	valid_0's binary_logloss: 0.366769
# [800]	valid_0's binary_logloss: 0.366761
# [801]	valid_0's binary_logloss: 0.366724
# [802]	valid_0's binary_logloss: 0.366717
# [803]	valid_0's binary_logloss: 0.36671
# [804]	valid_0's binary_logloss: 0.366703
# [805]	valid_0's binary_logloss: 0.366696
# [806]	valid_0's binary_logloss: 0.366689
# [807]	valid_0's binary_logloss: 0.366682
# [808]	valid_0's binary_logloss: 0.366629
# [809]	valid_0's binary_logloss: 0.366623
# [810]	valid_0's binary_logloss: 0.366616
# [811]	valid_0's binary_logloss: 0.366609
# [812]	valid_0's binary_logloss: 0.366602
# [813]	valid_0's binary_logloss: 0.366574
# [814]	valid_0's binary_logloss: 0.366564
# [815]	valid_0's binary_logloss: 0.36654
# [816]	valid_0's binary_logloss: 0.366533
# [817]	valid_0's binary_logloss: 0.366526
# [818]	valid_0's binary_logloss: 0.366519
# [819]	valid_0's binary_logloss: 0.366439
# [820]	valid_0's binary_logloss: 0.366432
# [821]	valid_0's binary_logloss: 0.366425
# [822]	valid_0's binary_logloss: 0.366418
# [823]	valid_0's binary_logloss: 0.366411
# [824]	valid_0's binary_logloss: 0.366405
# [825]	valid_0's binary_logloss: 0.366397
# [826]	valid_0's binary_logloss: 0.366357
# [827]	valid_0's binary_logloss: 0.366347
# [828]	valid_0's binary_logloss: 0.366339
# [829]	valid_0's binary_logloss: 0.366332
# [830]	valid_0's binary_logloss: 0.366325
# [831]	valid_0's binary_logloss: 0.366319
# [832]	valid_0's binary_logloss: 0.366309
# [833]	valid_0's binary_logloss: 0.366302
# [834]	valid_0's binary_logloss: 0.366295
# [835]	valid_0's binary_logloss: 0.366243
# [836]	valid_0's binary_logloss: 0.366235
# [837]	valid_0's binary_logloss: 0.366226
# [838]	valid_0's binary_logloss: 0.36622
# [839]	valid_0's binary_logloss: 0.366182
# [840]	valid_0's binary_logloss: 0.366176
# [841]	valid_0's binary_logloss: 0.366169
# [842]	valid_0's binary_logloss: 0.366162
# [843]	valid_0's binary_logloss: 0.366156
# [844]	valid_0's binary_logloss: 0.366125
# [845]	valid_0's binary_logloss: 0.366092
# [846]	valid_0's binary_logloss: 0.366083
# [847]	valid_0's binary_logloss: 0.366075
# [848]	valid_0's binary_logloss: 0.366069
# [849]	valid_0's binary_logloss: 0.366058
# [850]	valid_0's binary_logloss: 0.366052
# [851]	valid_0's binary_logloss: 0.366045
# [852]	valid_0's binary_logloss: 0.366039
# [853]	valid_0's binary_logloss: 0.366033
# [854]	valid_0's binary_logloss: 0.366026
# [855]	valid_0's binary_logloss: 0.36602
# [856]	valid_0's binary_logloss: 0.366013
# [857]	valid_0's binary_logloss: 0.366007
# [858]	valid_0's binary_logloss: 0.366001
# [859]	valid_0's binary_logloss: 0.365952
# [860]	valid_0's binary_logloss: 0.365945
# [861]	valid_0's binary_logloss: 0.365938
# [862]	valid_0's binary_logloss: 0.365932
# [863]	valid_0's binary_logloss: 0.365923
# [864]	valid_0's binary_logloss: 0.36588
# [865]	valid_0's binary_logloss: 0.365875
# [866]	valid_0's binary_logloss: 0.365865
# [867]	valid_0's binary_logloss: 0.365859
# [868]	valid_0's binary_logloss: 0.365851
# [869]	valid_0's binary_logloss: 0.365844
# [870]	valid_0's binary_logloss: 0.365787
# [871]	valid_0's binary_logloss: 0.365775
# [872]	valid_0's binary_logloss: 0.36577
# [873]	valid_0's binary_logloss: 0.365763
# [874]	valid_0's binary_logloss: 0.365748
# [875]	valid_0's binary_logloss: 0.365743
# [876]	valid_0's binary_logloss: 0.365737
# [877]	valid_0's binary_logloss: 0.365731
# [878]	valid_0's binary_logloss: 0.365725
# [879]	valid_0's binary_logloss: 0.365716
# [880]	valid_0's binary_logloss: 0.36571
# [881]	valid_0's binary_logloss: 0.365703
# [882]	valid_0's binary_logloss: 0.365697
# [883]	valid_0's binary_logloss: 0.365691
# [884]	valid_0's binary_logloss: 0.365684
# [885]	valid_0's binary_logloss: 0.365643
# [886]	valid_0's binary_logloss: 0.365637
# [887]	valid_0's binary_logloss: 0.36563
# [888]	valid_0's binary_logloss: 0.365622
# [889]	valid_0's binary_logloss: 0.365585
# [890]	valid_0's binary_logloss: 0.365533
# [891]	valid_0's binary_logloss: 0.365519
# [892]	valid_0's binary_logloss: 0.365507
# [893]	valid_0's binary_logloss: 0.3655
# [894]	valid_0's binary_logloss: 0.365494
# [895]	valid_0's binary_logloss: 0.365488
# [896]	valid_0's binary_logloss: 0.365482
# [897]	valid_0's binary_logloss: 0.36547
# [898]	valid_0's binary_logloss: 0.365409
# [899]	valid_0's binary_logloss: 0.365364
# [900]	valid_0's binary_logloss: 0.365358
# [901]	valid_0's binary_logloss: 0.365352
# [902]	valid_0's binary_logloss: 0.365345
# [903]	valid_0's binary_logloss: 0.365339
# [904]	valid_0's binary_logloss: 0.365333
# [905]	valid_0's binary_logloss: 0.365328
# [906]	valid_0's binary_logloss: 0.365322
# [907]	valid_0's binary_logloss: 0.365291
# [908]	valid_0's binary_logloss: 0.365255
# [909]	valid_0's binary_logloss: 0.365248
# [910]	valid_0's binary_logloss: 0.365242
# [911]	valid_0's binary_logloss: 0.365236
# [912]	valid_0's binary_logloss: 0.36523
# [913]	valid_0's binary_logloss: 0.365164
# [914]	valid_0's binary_logloss: 0.365157
# [915]	valid_0's binary_logloss: 0.365151
# [916]	valid_0's binary_logloss: 0.365144
# [917]	valid_0's binary_logloss: 0.365138
# [918]	valid_0's binary_logloss: 0.365132
# [919]	valid_0's binary_logloss: 0.365127
# [920]	valid_0's binary_logloss: 0.365121
# [921]	valid_0's binary_logloss: 0.365115
# [922]	valid_0's binary_logloss: 0.365109
# [923]	valid_0's binary_logloss: 0.365104
# [924]	valid_0's binary_logloss: 0.365097
# [925]	valid_0's binary_logloss: 0.365091
# [926]	valid_0's binary_logloss: 0.365058
# [927]	valid_0's binary_logloss: 0.365052
# [928]	valid_0's binary_logloss: 0.365045
# [929]	valid_0's binary_logloss: 0.365036
# [930]	valid_0's binary_logloss: 0.364989
# [931]	valid_0's binary_logloss: 0.364984
# [932]	valid_0's binary_logloss: 0.36494
# [933]	valid_0's binary_logloss: 0.364934
# [934]	valid_0's binary_logloss: 0.364926
# [935]	valid_0's binary_logloss: 0.364914
# [936]	valid_0's binary_logloss: 0.364908
# [937]	valid_0's binary_logloss: 0.364864
# [938]	valid_0's binary_logloss: 0.364859
# [939]	valid_0's binary_logloss: 0.364853
# [940]	valid_0's binary_logloss: 0.364848
# [941]	valid_0's binary_logloss: 0.36479
# [942]	valid_0's binary_logloss: 0.364784
# [943]	valid_0's binary_logloss: 0.36477
# [944]	valid_0's binary_logloss: 0.364763
# [945]	valid_0's binary_logloss: 0.364758
# [946]	valid_0's binary_logloss: 0.364753
# [947]	valid_0's binary_logloss: 0.364746
# [948]	valid_0's binary_logloss: 0.364736
# [949]	valid_0's binary_logloss: 0.364731
# [950]	valid_0's binary_logloss: 0.364714
# [951]	valid_0's binary_logloss: 0.364707
# [952]	valid_0's binary_logloss: 0.3647
# [953]	valid_0's binary_logloss: 0.364693
# [954]	valid_0's binary_logloss: 0.364687
# [955]	valid_0's binary_logloss: 0.364681
# [956]	valid_0's binary_logloss: 0.364675
# [957]	valid_0's binary_logloss: 0.364663
# [958]	valid_0's binary_logloss: 0.364658
# [959]	valid_0's binary_logloss: 0.364652
# [960]	valid_0's binary_logloss: 0.36461
# [961]	valid_0's binary_logloss: 0.364578
# [962]	valid_0's binary_logloss: 0.364573
# [963]	valid_0's binary_logloss: 0.364548
# [964]	valid_0's binary_logloss: 0.364537
# [965]	valid_0's binary_logloss: 0.364494
# [966]	valid_0's binary_logloss: 0.364477
# [967]	valid_0's binary_logloss: 0.364471
# [968]	valid_0's binary_logloss: 0.364463
# [969]	valid_0's binary_logloss: 0.364457
# [970]	valid_0's binary_logloss: 0.36445
# [971]	valid_0's binary_logloss: 0.364431
# [972]	valid_0's binary_logloss: 0.364424
# [973]	valid_0's binary_logloss: 0.364418
# [974]	valid_0's binary_logloss: 0.364411
# [975]	valid_0's binary_logloss: 0.364405
# [976]	valid_0's binary_logloss: 0.364397
# [977]	valid_0's binary_logloss: 0.364391
# [978]	valid_0's binary_logloss: 0.364383
# [979]	valid_0's binary_logloss: 0.364377
# [980]	valid_0's binary_logloss: 0.364372
# [981]	valid_0's binary_logloss: 0.364354
# [982]	valid_0's binary_logloss: 0.364347
# [983]	valid_0's binary_logloss: 0.364313
# [984]	valid_0's binary_logloss: 0.364307
# [985]	valid_0's binary_logloss: 0.364302
# [986]	valid_0's binary_logloss: 0.364297
# [987]	valid_0's binary_logloss: 0.364286
# [988]	valid_0's binary_logloss: 0.36428
# [989]	valid_0's binary_logloss: 0.364275
# [990]	valid_0's binary_logloss: 0.364228
# [991]	valid_0's binary_logloss: 0.364222
# [992]	valid_0's binary_logloss: 0.364211
# [993]	valid_0's binary_logloss: 0.364204
# [994]	valid_0's binary_logloss: 0.364198
# [995]	valid_0's binary_logloss: 0.364193
# [996]	valid_0's binary_logloss: 0.364187
# [997]	valid_0's binary_logloss: 0.364153
# [998]	valid_0's binary_logloss: 0.364131
# [999]	valid_0's binary_logloss: 0.364103
# [1000]	valid_0's binary_logloss: 0.364097
# [1001]	valid_0's binary_logloss: 0.364092
# [1002]	valid_0's binary_logloss: 0.364086
# [1003]	valid_0's binary_logloss: 0.36408
# [1004]	valid_0's binary_logloss: 0.364057
# [1005]	valid_0's binary_logloss: 0.364052
# [1006]	valid_0's binary_logloss: 0.364046
# [1007]	valid_0's binary_logloss: 0.364039
# [1008]	valid_0's binary_logloss: 0.364005
# [1009]	valid_0's binary_logloss: 0.363998
# [1010]	valid_0's binary_logloss: 0.363992
# [1011]	valid_0's binary_logloss: 0.363987
# [1012]	valid_0's binary_logloss: 0.363981
# [1013]	valid_0's binary_logloss: 0.363939
# [1014]	valid_0's binary_logloss: 0.363876
# [1015]	valid_0's binary_logloss: 0.363869
# [1016]	valid_0's binary_logloss: 0.363827
# [1017]	valid_0's binary_logloss: 0.36382
# [1018]	valid_0's binary_logloss: 0.363814
# [1019]	valid_0's binary_logloss: 0.363809
# [1020]	valid_0's binary_logloss: 0.363802
# [1021]	valid_0's binary_logloss: 0.36376
# [1022]	valid_0's binary_logloss: 0.363754
# [1023]	valid_0's binary_logloss: 0.363745
# [1024]	valid_0's binary_logloss: 0.363703
# [1025]	valid_0's binary_logloss: 0.363676
# [1026]	valid_0's binary_logloss: 0.363671
# [1027]	valid_0's binary_logloss: 0.363665
# [1028]	valid_0's binary_logloss: 0.36366
# [1029]	valid_0's binary_logloss: 0.363651
# [1030]	valid_0's binary_logloss: 0.363637
# [1031]	valid_0's binary_logloss: 0.363631
# [1032]	valid_0's binary_logloss: 0.36359
# [1033]	valid_0's binary_logloss: 0.363584
# [1034]	valid_0's binary_logloss: 0.363579
# [1035]	valid_0's binary_logloss: 0.363573
# [1036]	valid_0's binary_logloss: 0.363566
# [1037]	valid_0's binary_logloss: 0.363561
# [1038]	valid_0's binary_logloss: 0.363554
# [1039]	valid_0's binary_logloss: 0.363546
# [1040]	valid_0's binary_logloss: 0.36354
# [1041]	valid_0's binary_logloss: 0.363524
# [1042]	valid_0's binary_logloss: 0.363514
# [1043]	valid_0's binary_logloss: 0.363508
# [1044]	valid_0's binary_logloss: 0.363502
# [1045]	valid_0's binary_logloss: 0.363497
# [1046]	valid_0's binary_logloss: 0.363492
# [1047]	valid_0's binary_logloss: 0.363487
# [1048]	valid_0's binary_logloss: 0.363482
# [1049]	valid_0's binary_logloss: 0.363448
# [1050]	valid_0's binary_logloss: 0.363428
# [1051]	valid_0's binary_logloss: 0.363423
# [1052]	valid_0's binary_logloss: 0.363417
# [1053]	valid_0's binary_logloss: 0.363406
# [1054]	valid_0's binary_logloss: 0.363374
# [1055]	valid_0's binary_logloss: 0.363365
# [1056]	valid_0's binary_logloss: 0.363312
# [1057]	valid_0's binary_logloss: 0.363298
# [1058]	valid_0's binary_logloss: 0.36329
# [1059]	valid_0's binary_logloss: 0.363285
# [1060]	valid_0's binary_logloss: 0.36328
# [1061]	valid_0's binary_logloss: 0.363275
# [1062]	valid_0's binary_logloss: 0.363256
# [1063]	valid_0's binary_logloss: 0.363248
# [1064]	valid_0's binary_logloss: 0.363205
# [1065]	valid_0's binary_logloss: 0.363193
# [1066]	valid_0's binary_logloss: 0.363187
# [1067]	valid_0's binary_logloss: 0.363182
# [1068]	valid_0's binary_logloss: 0.363145
# [1069]	valid_0's binary_logloss: 0.36314
# [1070]	valid_0's binary_logloss: 0.363135
# [1071]	valid_0's binary_logloss: 0.36313
# [1072]	valid_0's binary_logloss: 0.363125
# [1073]	valid_0's binary_logloss: 0.36312
# [1074]	valid_0's binary_logloss: 0.363085
# [1075]	valid_0's binary_logloss: 0.36308
# [1076]	valid_0's binary_logloss: 0.363074
# [1077]	valid_0's binary_logloss: 0.36307
# [1078]	valid_0's binary_logloss: 0.363064
# [1079]	valid_0's binary_logloss: 0.363057
# [1080]	valid_0's binary_logloss: 0.363048
# [1081]	valid_0's binary_logloss: 0.363042
# [1082]	valid_0's binary_logloss: 0.363036
# [1083]	valid_0's binary_logloss: 0.363013
# [1084]	valid_0's binary_logloss: 0.363008
# [1085]	valid_0's binary_logloss: 0.363002
# [1086]	valid_0's binary_logloss: 0.362997
# [1087]	valid_0's binary_logloss: 0.36299
# [1088]	valid_0's binary_logloss: 0.362985
# [1089]	valid_0's binary_logloss: 0.362952
# [1090]	valid_0's binary_logloss: 0.362945
# [1091]	valid_0's binary_logloss: 0.362939
# [1092]	valid_0's binary_logloss: 0.3629
# [1093]	valid_0's binary_logloss: 0.362893
# [1094]	valid_0's binary_logloss: 0.362887
# [1095]	valid_0's binary_logloss: 0.362875
# [1096]	valid_0's binary_logloss: 0.362842
# [1097]	valid_0's binary_logloss: 0.36283
# [1098]	valid_0's binary_logloss: 0.362817
# [1099]	valid_0's binary_logloss: 0.362786
# [1100]	valid_0's binary_logloss: 0.36278
# [1101]	valid_0's binary_logloss: 0.362775
# [1102]	valid_0's binary_logloss: 0.362744
# [1103]	valid_0's binary_logloss: 0.362726
# [1104]	valid_0's binary_logloss: 0.362721
# [1105]	valid_0's binary_logloss: 0.362716
# [1106]	valid_0's binary_logloss: 0.362683
# [1107]	valid_0's binary_logloss: 0.362674
# [1108]	valid_0's binary_logloss: 0.362669
# [1109]	valid_0's binary_logloss: 0.362664
# [1110]	valid_0's binary_logloss: 0.362659
# [1111]	valid_0's binary_logloss: 0.362624
# [1112]	valid_0's binary_logloss: 0.362612
# [1113]	valid_0's binary_logloss: 0.362605
# [1114]	valid_0's binary_logloss: 0.3626
# [1115]	valid_0's binary_logloss: 0.362552
# [1116]	valid_0's binary_logloss: 0.362546
# [1117]	valid_0's binary_logloss: 0.362516
# [1118]	valid_0's binary_logloss: 0.362509
# [1119]	valid_0's binary_logloss: 0.362504
# [1120]	valid_0's binary_logloss: 0.362474
# [1121]	valid_0's binary_logloss: 0.362467
# [1122]	valid_0's binary_logloss: 0.362454
# [1123]	valid_0's binary_logloss: 0.362449
# [1124]	valid_0's binary_logloss: 0.362444
# [1125]	valid_0's binary_logloss: 0.362437
# [1126]	valid_0's binary_logloss: 0.362409
# [1127]	valid_0's binary_logloss: 0.362404
# [1128]	valid_0's binary_logloss: 0.362398
# [1129]	valid_0's binary_logloss: 0.362392
# [1130]	valid_0's binary_logloss: 0.362367
# [1131]	valid_0's binary_logloss: 0.362361
# [1132]	valid_0's binary_logloss: 0.362356
# [1133]	valid_0's binary_logloss: 0.362349
# [1134]	valid_0's binary_logloss: 0.362344
# [1135]	valid_0's binary_logloss: 0.362327
# [1136]	valid_0's binary_logloss: 0.362322
# [1137]	valid_0's binary_logloss: 0.362315
# [1138]	valid_0's binary_logloss: 0.362309
# [1139]	valid_0's binary_logloss: 0.362304
# [1140]	valid_0's binary_logloss: 0.362275
# [1141]	valid_0's binary_logloss: 0.362216
# [1142]	valid_0's binary_logloss: 0.362212
# [1143]	valid_0's binary_logloss: 0.362208
# [1144]	valid_0's binary_logloss: 0.362168
# [1145]	valid_0's binary_logloss: 0.362162
# [1146]	valid_0's binary_logloss: 0.36215
# [1147]	valid_0's binary_logloss: 0.362145
# [1148]	valid_0's binary_logloss: 0.362139
# [1149]	valid_0's binary_logloss: 0.362122
# [1150]	valid_0's binary_logloss: 0.362114
# [1151]	valid_0's binary_logloss: 0.36211
# [1152]	valid_0's binary_logloss: 0.362103
# [1153]	valid_0's binary_logloss: 0.362097
# [1154]	valid_0's binary_logloss: 0.362057
# [1155]	valid_0's binary_logloss: 0.362052
# [1156]	valid_0's binary_logloss: 0.362046
# [1157]	valid_0's binary_logloss: 0.362032
# [1158]	valid_0's binary_logloss: 0.361988
# [1159]	valid_0's binary_logloss: 0.361979
# [1160]	valid_0's binary_logloss: 0.361973
# [1161]	valid_0's binary_logloss: 0.361969
# [1162]	valid_0's binary_logloss: 0.361962
# [1163]	valid_0's binary_logloss: 0.361923
# [1164]	valid_0's binary_logloss: 0.361919
# [1165]	valid_0's binary_logloss: 0.36191
# [1166]	valid_0's binary_logloss: 0.361904
# [1167]	valid_0's binary_logloss: 0.3619
# [1168]	valid_0's binary_logloss: 0.361895
# [1169]	valid_0's binary_logloss: 0.361878
# [1170]	valid_0's binary_logloss: 0.361843
# [1171]	valid_0's binary_logloss: 0.361839
# [1172]	valid_0's binary_logloss: 0.361835
# [1173]	valid_0's binary_logloss: 0.361828
# [1174]	valid_0's binary_logloss: 0.361824
# [1175]	valid_0's binary_logloss: 0.361818
# [1176]	valid_0's binary_logloss: 0.361812
# [1177]	valid_0's binary_logloss: 0.361771
# [1178]	valid_0's binary_logloss: 0.361731
# [1179]	valid_0's binary_logloss: 0.361718
# [1180]	valid_0's binary_logloss: 0.361713
# [1181]	valid_0's binary_logloss: 0.361707
# [1182]	valid_0's binary_logloss: 0.361702
# [1183]	valid_0's binary_logloss: 0.361697
# [1184]	valid_0's binary_logloss: 0.361682
# [1185]	valid_0's binary_logloss: 0.361666
# [1186]	valid_0's binary_logloss: 0.36166
# [1187]	valid_0's binary_logloss: 0.361654
# [1188]	valid_0's binary_logloss: 0.361608
# [1189]	valid_0's binary_logloss: 0.361579
# [1190]	valid_0's binary_logloss: 0.361573
# [1191]	valid_0's binary_logloss: 0.361568
# [1192]	valid_0's binary_logloss: 0.361547
# [1193]	valid_0's binary_logloss: 0.361542
# [1194]	valid_0's binary_logloss: 0.361502
# [1195]	valid_0's binary_logloss: 0.361495
# [1196]	valid_0's binary_logloss: 0.361485
# [1197]	valid_0's binary_logloss: 0.361476
# [1198]	valid_0's binary_logloss: 0.36147
# [1199]	valid_0's binary_logloss: 0.361465
# [1200]	valid_0's binary_logloss: 0.361439
# Did not meet early stopping. Best iteration is:
# [1200]	valid_0's binary_logloss: 0.361439

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 83.31936691076824
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV19.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV19.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado    Master  \
# 64220  11199  1111943392       6PMvwj   FEM  33.0         -         -
# 23635  68396  1112460698       5PLpaZ  MASC  50.0         -         -
# 85190  33995  1112406350       5N8eOk  MASC  34.0         -         -
# 82524  30877  1112382140       8EleLD   FEM  55.0         -         -
# 84070  32787  1112397218       ZRKQp8   FEM  29.0         -         -
# 25871  86915  1112466773      Rz6O0xY  MASC  24.0         -         -
# 54412  78654  1112464538      JBdB0dW  MASC  28.0         -         -
# 54665  40433  1112418972       YNzwE1  MASC  41.0         -  Graduado
# 41683  12709  1112020631      akbeRl5   FEM  24.0         -         -
# 80225  27738  1112353541       5KXRPq  MASC  52.0         -         -
#
#            Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 64220         -         -   Graduado    ...     False              False
# 23635         -         -          -    ...     False              False
# 85190         -         -   Graduado    ...     False              False
# 82524  Graduado         -   Graduado    ...     False              False
# 84070         -         -   Graduado    ...     False              False
# 25871         -         -   Graduado    ...     False               True
# 54412  Graduado         -   Graduado    ...     False              False
# 54665         -         -   Graduado    ...     False              False
# 41683         -         -   Graduado    ...     False              False
# 80225         -  Graduado   Graduado    ...     False              False
#
#       capacitacion remuneracion_pretendida graduados estudiantes  \
# 64220        False                    True     False       False
# 23635        False                   False     False        True
# 85190        False                    True     False       False
# 82524        False                   False     False       False
# 84070         True                   False     False       False
# 25871        False                   False     False       False
# 54412        False                    True      True       False
# 54665        False                   False     False       False
# 41683        False                   False     False       False
# 80225        False                   False     False       False
#
#       conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 64220                     False         False           False  0.000000
# 23635                     False         False           False  0.000000
# 85190                     False         False           False  0.000000
# 82524                     False         False           False  0.000000
# 84070                     False          True           False  0.000000
# 25871                     False          True           False  0.009036
# 54412                     False         False           False  0.000000
# 54665                     False         False           False  0.000000
# 41683                     False          True           False  0.027027
# 80225                     False         False           False  0.000000
#
# [10 rows x 36 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.86152812, 0.13847188],
#        [0.84491501, 0.15508499],
#        [0.8480482 , 0.1519518 ],
#        ...,
#        [0.93114894, 0.06885106],
#        [0.93693369, 0.06306631],
#        [0.97623226, 0.02376774]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     empresa_importante capacitacion  \
# 0   Graduado    ...                  False        False
# 1          -    ...                  False        False
# 2   Graduado    ...                  False        False
# 3   Graduado    ...                  False        False
# 4          -    ...                  False        False
#
#   remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 0                   False     False       False                     False
# 1                   False     False       False                     False
# 2                   False     False       False                     False
# 3                   False     False       False                     False
# 4                   False     False       False                     False
#
#   buen_ambiente discriminacion  cantidad  sepostulo
# 0         False          False       0.0   0.138472
# 1         False          False       0.0   0.155085
# 2         False          False       0.0   0.151952
# 3         False          False       0.0   0.005752
# 4         False          False       0.0   0.004405
#
# [5 rows x 37 columns]

# %%
prediccion=prediccion[['id','sepostulo']]
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.138472
# 1   1   0.155085
# 2   2   0.151952
# 3   3   0.005752
# 4   4   0.004405

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion43.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5177329658183671
