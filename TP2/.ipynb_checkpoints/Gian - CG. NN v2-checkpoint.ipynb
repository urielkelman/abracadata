# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisosONEHOT.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantesONEHOT.csv")
areas=avisos['nombre_area'].value_counts()
avisos['nombre_area']=avisos['nombre_area'].replace(areas.index, areas.values)

avisos_no_one_hot= pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
avisos_no_one_hot=avisos_no_one_hot[['idaviso','tipo_de_trabajo','nivel_laboral','nombre_area']];
avisos_no_one_hot['tipo_de_trabajo']=avisos_no_one_hot['tipo_de_trabajo'].astype('category')
avisos_no_one_hot['nivel_laboral']=avisos_no_one_hot['nivel_laboral'].astype('category')
avisos_no_one_hot['nombre_area']=avisos_no_one_hot['nombre_area'].astype('category')
avisos_no_one_hot=avisos_no_one_hot.rename(columns={'nombre_area': 'nombre_area_aux'})

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas2=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2=vistas2.rename(columns={'idAviso': 'idaviso'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q        15
# 1        0005E        58
# 2        000R8        14
# 3        001XE        26
# 4        003k9        32

# %%
vistas3=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           2          28
# 1    48375       RwVdKR           1          15
# 2   169730        1KjXB           2          99
# 3   169730       2AKzxa           2           2
# 4   169730        6LJ64           1          23

# %%
vistas3['cantidad']=vistas3['cantidad_x']/vistas3['cantidad_y']
vistas3.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas3.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.071429
# 1    48375       RwVdKR  0.066667
# 2   169730        1KjXB  0.020202
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.043478

# %%
vistas=vistas.rename(columns={'cantidad': 'vistas_postulante'})
vistas2=vistas2.rename(columns={'cantidad': 'vistas_al_aviso'})

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/7.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/8.csv").sample(len(postulaciones2)//2).reset_index(drop=True))
print(len(postulaciones2))
postulaciones2
# Out:
# 9906801
#             idaviso idpostulante  sepostulo
# 0        1112389495       5NbOjG          0
# 1        1112024109      1QP841b          0
# 2        1112490884      96XQ6N9          0
# 3        1111474259      qe2QJj1          0
# 4        1112211292      KBzbBJm          0
# 5        1112328485      3NzZv26          0
# 6        1112474766      akDjWwE          0
# 7        1112312385       aZpBJW          0
# 8        1112285628      akDWj55          0
# 9        1112322843      GNd0KNN          0
# 10       1112355899      DrXPRJX          0
# 11       1112461865      8MPoBDR          0
# 12       1111673413       a1NjRN          0
# 13       1112299006      jkVWXRQ          0
# 14       1112501771      owz0YGW          0
# 15       1002543409       Ej5AAb          0
# 16       1112425310      KBrpAO2          0
# 17       1112498569      pzNMppM          0
# 18       1111866251       ZKqL85          0
# 19       1112289529      ow2awXr          0
# 20       1112493109      5mP1DWM          0
# 21       1112326017      0zd9GZ9          0
# 22       1112242315      3NQKV6Q          0
# 23       1112452417      DrlVEwW          0
# 24       1112402816      mzdk9dZ          0
# 25       1112359100      3NP46xq          0
# 26       1112410555      bOVKA32          0
# 27       1112511403      mzdlAQO          0
# 28       1111272539      6rPpNM4          0
# 29       1111591317      6rP4K13          0
# ...             ...          ...        ...
# 3302237  1112348260      ekX5EKB          0
# 3302238  1112438009       ZQoMX5          0
# 3302239  1112348675      2zQjKBv          0
# 3302240  1112410617      8MB5Qbj          0
# 3302241  1112420409       5LQNwG          0
# 3302242  1112190012      96XqL88          0
# 3302243  1112513842      8M2qqdl          0
# 3302244  1112336485      owEWPb0          0
# 3302245  1112490840      Yj5eRlY          0
# 3302246  1112276981      MV6j3Zp          0
# 3302247  1112292210       YO1lmw          0
# 3302248  1111983830      5md9Y8z          0
# 3302249  1112277631      GNeDjzb          0
# 3302250  1112493288      VNPKQWj          0
# 3302251  1112361153       ZOMZl5          0
# 3302252  1111046830      LNMOBkj          0
# 3302253  1112337758      8Ma0qZj          0
# 3302254  1112134868      KBdz2l2          0
# 3302255  1112114166      YjrKaBw          0
# 3302256  1112052295      Rz9OAox          0
# 3302257  1112303413      pz9wJaW          0
# 3302258  1112443846      vVjaJ9o          0
# 3302259  1112495784      lDXjkBM          0
# 3302260  1112309109      EzEP3kb          0
# 3302261  1112509783      ow5Ver0          0
# 3302262  1112423671      Drz2eAZ          0
# 3302263  1112205299       56zYKZ          0
# 3302264  1112432964      YjQVrXP          0
# 3302265  1111808018       ZQpLNR          0
# 3302266  1112453340      Yj5dmBX          0
#
# [9906801 rows x 3 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 16511335
# 16501996

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,avisos_no_one_hot,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas2,on=['idaviso','idpostulante'],how='left')
postulaciones=pd.merge(postulaciones,vistas3,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 1702151      1785430      mzdq1z9          0  23.0      True      False
# 15936651  1111478614      ow2bdo3          0  38.0     False       True
# 1011112   1112262301      ZDPdAkV          0  21.0      True      False
# 7589947   1111930643      QNEOmKz          1  19.0      True      False
# 3897049   1112176012      VNJlWlN          0  24.0      True      False
# 2550174   1112372593      W9WjaOa          0  25.0      True      False
# 15991734  1112433015      W9WNR8m          0  34.0     False       True
# 10189129  1112283399      pz9Yx6Z          1  32.0     False       True
# 12509738  1112289329      jk5Alz6          0  21.0      True      False
# 12288904  1111874823      zv8jq3b          0  55.0      True      False
# 14652706  1112246999       aM8zK0          0  39.0     False       True
# 14410382  1112506110      X95LjpP          0  33.0      True      False
# 7547877   1112239679      vVDxPrQ          1  43.0      True      False
# 10333625  1112429930      dYzZLYX          1  21.0      True      False
# 3674879   1112254546      ak56loZ          1  23.0      True      False
# 12584106  1112376995      pzdJvPW          0  24.0      True      False
# 4389179   1112291358      RzNPdbE          1  27.0     False       True
# 6714656   1112414725      969eQEw          1  24.0     False       True
# 10534477  1111849664       NZ9xql          0  30.0      True      False
# 11448924  1111285386       NRew4J          0  30.0      True      False
#
#           sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 1702151             False                 False               False
# 15936651            False                 False               False
# 1011112             False                 False               False
# 7589947             False                 False               False
# 3897049             False                 False               False
# 2550174             False                 False               False
# 15991734            False                 False               False
# 10189129            False                 False               False
# 12509738            False                 False               False
# 12288904            False                 False               False
# 14652706            False                 False               False
# 14410382            False                 False               False
# 7547877             False                 False               False
# 10333625            False                 False               False
# 3674879             False                 False               False
# 12584106            False                 False               False
# 4389179             False                 False               False
# 6714656             False                 False               False
# 10534477            False                 False               False
# 11448924            False                 False               False
#
#           Doctorado_Graduado    ...     \
# 1702151                False    ...
# 15936651               False    ...
# 1011112                False    ...
# 7589947                False    ...
# 3897049                False    ...
# 2550174                False    ...
# 15991734               False    ...
# 10189129               False    ...
# 12509738               False    ...
# 12288904               False    ...
# 14652706               False    ...
# 14410382               False    ...
# 7547877                False    ...
# 10333625               False    ...
# 3674879                False    ...
# 12584106               False    ...
# 4389179                False    ...
# 6714656                False    ...
# 10534477               False    ...
# 11448924               False    ...
#
#           nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 1702151                                           False                 False
# 15936651                                          False                 False
# 1011112                                           False                 False
# 7589947                                           False                 False
# 3897049                                            True                 False
# 2550174                                           False                 False
# 15991734                                          False                 False
# 10189129                                          False                 False
# 12509738                                          False                 False
# 12288904                                          False                  True
# 14652706                                          False                 False
# 14410382                                          False                 False
# 7547877                                           False                 False
# 10333625                                          False                  True
# 3674879                                           False                 False
# 12584106                                          False                 False
# 4389179                                           False                 False
# 6714656                                           False                  True
# 10534477                                          False                 False
# 11448924                                          False                 False
#
#           nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  \
# 1702151                 True                               False
# 15936651               False                                True
# 1011112                False                                True
# 7589947                False                                True
# 3897049                False                               False
# 2550174                False                                True
# 15991734               False                                True
# 10189129               False                                True
# 12509738               False                                True
# 12288904               False                               False
# 14652706               False                                True
# 14410382               False                                True
# 7547877                False                                True
# 10333625               False                               False
# 3674879                False                                True
# 12584106               False                                True
# 4389179                False                                True
# 6714656                False                               False
# 10534477               False                                True
# 11448924               False                                True
#
#           tipo_de_trabajo                    nivel_laboral  \
# 1702151         Full-time                             Otro
# 15936651        Full-time             Senior / Semi-Senior
# 1011112         Full-time             Senior / Semi-Senior
# 7589947         Full-time             Senior / Semi-Senior
# 3897049         Full-time  Jefe / Supervisor / Responsable
# 2550174         Full-time             Senior / Semi-Senior
# 15991734        Full-time             Senior / Semi-Senior
# 10189129        Full-time             Senior / Semi-Senior
# 12509738        Full-time             Senior / Semi-Senior
# 12288904        Full-time                           Junior
# 14652706        Full-time             Senior / Semi-Senior
# 14410382        Full-time             Senior / Semi-Senior
# 7547877         Full-time             Senior / Semi-Senior
# 10333625        Full-time                           Junior
# 3674879         Full-time             Senior / Semi-Senior
# 12584106        Full-time             Senior / Semi-Senior
# 4389179         Full-time             Senior / Semi-Senior
# 6714656         Part-time                           Junior
# 10534477        Full-time             Senior / Semi-Senior
# 11448924        Full-time             Senior / Semi-Senior
#
#                                nombre_area_aux  vistas_postulante  \
# 1702151                  Tecnologia / Sistemas               22.0
# 15936651                        Administración              115.0
# 1011112             Administración de Personal               60.0
# 7589947               Mantenimiento y Limpieza               19.0
# 3897049                             Producción                4.0
# 2550174                    Ingeniería Agrónoma                9.0
# 15991734                         Telemarketing                NaN
# 10189129                 Liderazgo de Proyecto                3.0
# 12509738                  Ingeniería de Ventas               91.0
# 12288904                        Administración                3.0
# 14652706                                Ventas               21.0
# 14410382  Inversiones / Proyectos de Inversión              323.0
# 7547877        Almacén / Depósito / Expedición              390.0
# 10333625                                Ventas               73.0
# 3674879                              Comercial                NaN
# 12584106                   Seguridad e Higiene                7.0
# 4389179                         Administración                NaN
# 6714656                              Comercial              319.0
# 10534477                          Programación              100.0
# 11448924                             Camareros                4.0
#
#           vistas_al_aviso  cantidad
# 1702151               NaN       NaN
# 15936651              NaN       NaN
# 1011112               NaN       NaN
# 7589947               NaN       NaN
# 3897049               NaN       NaN
# 2550174               NaN       NaN
# 15991734              NaN       NaN
# 10189129              NaN       NaN
# 12509738              NaN       NaN
# 12288904              NaN       NaN
# 14652706              NaN       NaN
# 14410382              NaN       NaN
# 7547877               NaN       NaN
# 10333625              1.0  0.013699
# 3674879               NaN       NaN
# 12584106              NaN       NaN
# 4389179               NaN       NaN
# 6714656               2.0  0.006270
# 10534477              NaN       NaN
# 11448924              NaN       NaN
#
# [20 rows x 82 columns]

# %%
postulaciones['cantidad']=postulaciones['cantidad'].fillna(0)
postulaciones['vistas_postulante']=postulaciones['vistas_postulante'].fillna(0)
postulaciones['vistas_al_aviso']=postulaciones['vistas_al_aviso'].fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 11714198  1112299970      ow2owkW          1  22.0     False       True
# 10858764  1112427941       YBdm8Z          1  34.0     False       True
# 3122603   1111987656      EzeOwj9          1  19.0      True      False
# 15885376  1112206174      dYjRJRA          0  44.0      True      False
# 7149775   1112263343      2zLVDdY          1  30.0     False       True
# 3855240   1112260140       1L8NzN          0  32.0     False       True
# 11629522  1112248964      MVrL2Ro          0  35.0     False       True
# 5925092   1112404097      RzP68MR          1  21.0      True      False
# 13636987  1111385700      LNMAmvb          0  20.0      True      False
# 11533734  1112397889       6LJGpL          0  45.0     False       True
# 12885351  1112148951      ZDaDKRY          0  25.0     False       True
# 14355580  1112481226      OqPYpQB          0  27.0      True      False
# 8383396   1112291328      bOjOdX4          0  44.0     False       True
# 1686107   1112415302      xkPKewP          0  28.0      True      False
# 9062052   1111736496      bOjM9BV          0  22.0     False       True
# 15731250  1112267828       55z8wp          1  27.0     False       True
# 2910401   1112444846      0zPKW6Y          0  28.0     False       True
# 5844237   1112376852      8MPWDqO          0  20.0      True      False
# 5077449   1112288763      W9W2Ldm          1  27.0     False       True
# 15537051  1112222757       eKNGoo          0  28.0     False       True
#
#           sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 11714198            False                 False               False
# 10858764            False                 False               False
# 3122603             False                 False               False
# 15885376            False                 False               False
# 7149775             False                 False               False
# 3855240             False                 False               False
# 11629522            False                 False               False
# 5925092             False                 False               False
# 13636987            False                 False               False
# 11533734            False                 False               False
# 12885351            False                 False               False
# 14355580            False                 False               False
# 8383396             False                 False               False
# 1686107             False                 False               False
# 9062052             False                 False               False
# 15731250            False                 False               False
# 2910401             False                 False               False
# 5844237             False                 False               False
# 5077449             False                 False               False
# 15537051            False                 False               False
#
#           Doctorado_Graduado    ...     \
# 11714198               False    ...
# 10858764               False    ...
# 3122603                False    ...
# 15885376               False    ...
# 7149775                False    ...
# 3855240                False    ...
# 11629522               False    ...
# 5925092                False    ...
# 13636987               False    ...
# 11533734               False    ...
# 12885351               False    ...
# 14355580               False    ...
# 8383396                False    ...
# 1686107                False    ...
# 9062052                False    ...
# 15731250               False    ...
# 2910401                False    ...
# 5844237                False    ...
# 5077449                False    ...
# 15537051               False    ...
#
#           nivel_laboral_Jefe / Supervisor / Responsable  nivel_laboral_Junior  \
# 11714198                                          False                 False
# 10858764                                          False                 False
# 3122603                                           False                 False
# 15885376                                          False                  True
# 7149775                                           False                 False
# 3855240                                           False                 False
# 11629522                                          False                 False
# 5925092                                           False                 False
# 13636987                                          False                 False
# 11533734                                          False                 False
# 12885351                                          False                 False
# 14355580                                          False                  True
# 8383396                                           False                 False
# 1686107                                           False                 False
# 9062052                                           False                 False
# 15731250                                          False                 False
# 2910401                                           False                 False
# 5844237                                           False                 False
# 5077449                                           False                  True
# 15537051                                          False                 False
#
#           nivel_laboral_Otro  nivel_laboral_Senior / Semi-Senior  \
# 11714198               False                                True
# 10858764               False                                True
# 3122603                 True                               False
# 15885376               False                               False
# 7149775                False                                True
# 3855240                 True                               False
# 11629522               False                                True
# 5925092                 True                               False
# 13636987               False                                True
# 11533734               False                                True
# 12885351               False                                True
# 14355580               False                               False
# 8383396                False                                True
# 1686107                False                                True
# 9062052                False                                True
# 15731250               False                                True
# 2910401                False                                True
# 5844237                False                                True
# 5077449                False                               False
# 15537051               False                                True
#
#           tipo_de_trabajo         nivel_laboral          nombre_area_aux  \
# 11714198        Full-time  Senior / Semi-Senior                Logística
# 10858764        Full-time  Senior / Semi-Senior                    Legal
# 3122603         Part-time                  Otro              Call Center
# 15885376        Full-time                Junior         Recursos Humanos
# 7149775         Full-time  Senior / Semi-Senior           Administración
# 3855240         Full-time                  Otro                Comercial
# 11629522        Full-time  Senior / Semi-Senior                Comercial
# 5925092         Full-time                  Otro                    Legal
# 13636987        Full-time  Senior / Semi-Senior                Comercial
# 11533734        Full-time  Senior / Semi-Senior                Logística
# 12885351        Full-time  Senior / Semi-Senior               Producción
# 14355580        Full-time                Junior               Producción
# 8383396         Full-time  Senior / Semi-Senior             Programación
# 1686107         Full-time  Senior / Semi-Senior                Auditoría
# 9062052         Full-time  Senior / Semi-Senior         Ingeniería Civil
# 15731250        Full-time  Senior / Semi-Senior                  Seguros
# 2910401         Full-time  Senior / Semi-Senior                Selección
# 5844237         Full-time  Senior / Semi-Senior           Administración
# 5077449         Full-time                Junior               Producción
# 15537051        Full-time  Senior / Semi-Senior  Ingeniería en Alimentos
#
#           vistas_postulante  vistas_al_aviso  cantidad
# 11714198                0.0              0.0       0.0
# 10858764                1.0              1.0       1.0
# 3122603                 0.0              0.0       0.0
# 15885376               50.0              0.0       0.0
# 7149775               496.0              0.0       0.0
# 3855240                 0.0              0.0       0.0
# 11629522                0.0              0.0       0.0
# 5925092                 4.0              2.0       0.5
# 13636987               40.0              0.0       0.0
# 11533734               16.0              0.0       0.0
# 12885351                7.0              0.0       0.0
# 14355580                2.0              0.0       0.0
# 8383396                 0.0              0.0       0.0
# 1686107                16.0              0.0       0.0
# 9062052                 0.0              0.0       0.0
# 15731250                0.0              0.0       0.0
# 2910401                 0.0              0.0       0.0
# 5844237                21.0              0.0       0.0
# 5077449                 6.0              0.0       0.0
# 15537051                0.0              0.0       0.0
#
# [20 rows x 82 columns]

# %%
postulaciones_por_area=postulaciones.copy()
postulaciones_por_area=postulaciones_por_area.groupby(by=['idpostulante','nombre_area_aux'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_area=postulaciones_por_area.rename(columns={'sepostulo':'postulaciones_misma_area'})
postulaciones_por_area.head()
# Out:
#   idpostulante                  nombre_area_aux  postulaciones_misma_area
# 0      0z5Dmrd                   Abastecimiento                         1
# 1      0z5Dmrd                   Administración                         1
# 2      0z5Dmrd       Administración de Personal                         1
# 3      0z5Dmrd  Almacén / Depósito / Expedición                         1
# 4      0z5Dmrd              Atención al Cliente                         1

# %%
postulaciones_por_nivel=postulaciones.copy()
postulaciones_por_nivel=postulaciones_por_nivel.groupby(by=['idpostulante','nivel_laboral'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_nivel=postulaciones_por_nivel.rename(columns={'sepostulo':'postulaciones_mismo_nivel'})
postulaciones_por_nivel.head()
# Out:
#   idpostulante                         nivel_laboral  \
# 0      0z5Dmrd  Gerencia / Alta Gerencia / Dirección
# 1      0z5Dmrd                                Junior
# 2      0z5Dmrd                                  Otro
# 3      0z5Dmrd                  Senior / Semi-Senior
# 4      0z5JW1r  Gerencia / Alta Gerencia / Dirección
#
#    postulaciones_mismo_nivel
# 0                          1
# 1                          3
# 2                          1
# 3                         16
# 4                          2

# %%
postulaciones_por_tipo=postulaciones.copy()
postulaciones_por_tipo=postulaciones_por_tipo.groupby(by=['idpostulante','tipo_de_trabajo'],as_index=False).agg({'sepostulo':'count'})
postulaciones_por_tipo=postulaciones_por_tipo.rename(columns={'sepostulo':'postulaciones_mismo_tipo'})
postulaciones_por_tipo.head()
# Out:
#   idpostulante tipo_de_trabajo  postulaciones_mismo_tipo
# 0      0z5Dmrd       Full-time                        20
# 1      0z5Dmrd       Part-time                         1
# 2      0z5JW1r       Full-time                        27
# 3      0z5JW1r     Teletrabajo                         1
# 4      0z5VvGv       Full-time                        57

# %%
postulaciones=pd.merge(postulaciones,postulaciones_por_area,on=['idpostulante','nombre_area_aux'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
postulaciones=pd.merge(postulaciones,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
postulaciones['postulaciones_misma_area']=postulaciones['postulaciones_misma_area'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_nivel']=postulaciones['postulaciones_mismo_nivel'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones['postulaciones_mismo_tipo']=postulaciones['postulaciones_mismo_tipo'].fillna(0).apply(lambda x: x if(x<=0) else x-1)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  edad  sexo_FEM  sexo_MASC  \
# 15843441  1111561858       eM4Y0o          0  50.0      True      False
# 11317520     1483300      0zPdR2a          0  19.0      True      False
# 385348    1112383270      4rd4BGA          1  26.0      True      False
# 2078960   1112489729       E9e2D8          0  33.0      True      False
# 2063812   1110466798       1R0Lv3          1  25.0      True      False
# 4251597   1112452063      rmvza2z          0  24.0     False       True
# 9650636   1112372940      5mkE91q          1  32.0      True      False
# 10045397  1112353171      QNLXKR4          0  24.0     False       True
# 9668744   1112444431      wVYDPZm          0  27.0     False       True
# 5517756   1112425759      QNrzakV          1  35.0      True      False
# 10180665  1112359615       aVxdq5          0  26.0      True      False
# 2424083   1112426841      QNrMGme          0  22.0      True      False
# 12764249  1111845164       EWO9kN          0  28.0     False       True
# 9816101   1112496477      969PDp8          0  48.0      True      False
# 11879852  1112412413      xkdqw2P          0  22.0      True      False
# 3334579   1112506469       5Qe9Zz          0  35.0     False       True
# 6222790   1112247945      GNJWLkA          0  27.0     False       True
# 14862341  1112349430      OqboWkN          0  20.0     False       True
# 10658531  1112411457      zv8jzA3          0  24.0      True      False
# 9479177   1112403199       5JK9Lp          1  27.0      True      False
#
#           sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 15843441            False                 False               False
# 11317520            False                 False               False
# 385348              False                 False               False
# 2078960             False                 False               False
# 2063812             False                 False               False
# 4251597             False                 False               False
# 9650636             False                 False               False
# 10045397            False                 False               False
# 9668744             False                 False               False
# 5517756             False                 False               False
# 10180665            False                 False               False
# 2424083             False                 False               False
# 12764249            False                 False               False
# 9816101             False                 False               False
# 11879852            False                 False               False
# 3334579             False                 False               False
# 6222790             False                 False               False
# 14862341            False                 False               False
# 10658531            False                 False               False
# 9479177             False                 False               False
#
#           Doctorado_Graduado            ...              \
# 15843441               False            ...
# 11317520               False            ...
# 385348                 False            ...
# 2078960                False            ...
# 2063812                False            ...
# 4251597                False            ...
# 9650636                False            ...
# 10045397               False            ...
# 9668744                False            ...
# 5517756                False            ...
# 10180665               False            ...
# 2424083                False            ...
# 12764249               False            ...
# 9816101                False            ...
# 11879852               False            ...
# 3334579                False            ...
# 6222790                False            ...
# 14862341               False            ...
# 10658531               False            ...
# 9479177                False            ...
#
#           nivel_laboral_Senior / Semi-Senior  tipo_de_trabajo  \
# 15843441                               False        Full-time
# 11317520                               False        Full-time
# 385348                                  True        Full-time
# 2078960                                 True        Full-time
# 2063812                                 True        Full-time
# 4251597                                False        Full-time
# 9650636                                 True        Full-time
# 10045397                                True        Full-time
# 9668744                                 True        Full-time
# 5517756                                 True        Full-time
# 10180665                               False        Part-time
# 2424083                                 True        Full-time
# 12764249                                True        Full-time
# 9816101                                 True        Full-time
# 11879852                                True        Full-time
# 3334579                                 True        Part-time
# 6222790                                 True        Full-time
# 14862341                               False        Full-time
# 10658531                               False        Full-time
# 9479177                                 True        Full-time
#
#                             nivel_laboral  \
# 15843441  Jefe / Supervisor / Responsable
# 11317520                             Otro
# 385348               Senior / Semi-Senior
# 2078960              Senior / Semi-Senior
# 2063812              Senior / Semi-Senior
# 4251597                            Junior
# 9650636              Senior / Semi-Senior
# 10045397             Senior / Semi-Senior
# 9668744              Senior / Semi-Senior
# 5517756              Senior / Semi-Senior
# 10180665                           Junior
# 2424083              Senior / Semi-Senior
# 12764249             Senior / Semi-Senior
# 9816101              Senior / Semi-Senior
# 11879852             Senior / Semi-Senior
# 3334579              Senior / Semi-Senior
# 6222790              Senior / Semi-Senior
# 14862341                             Otro
# 10658531                             Otro
# 9479177              Senior / Semi-Senior
#
#                               nombre_area_aux  vistas_postulante  \
# 15843441                             Medicina               45.0
# 11317520                      Soporte Técnico                0.0
# 385348             Administración de Personal               44.0
# 2078960                             Auditoría                3.0
# 2063812                   Atención al Cliente                0.0
# 4251597                              Finanzas                0.0
# 9650636                        Administración               97.0
# 10045397                          Facturación               11.0
# 9668744                          Programación               89.0
# 5517756   Relaciones Institucionales/Publicas               60.0
# 10180665                               Ventas                6.0
# 2424083         Tecnologías de la Información                5.0
# 12764249                         Contabilidad                3.0
# 9816101                             Comercial              138.0
# 11879852                           Producción               25.0
# 3334579                        Administración                2.0
# 6222790                             Logística              111.0
# 14862341                                Redes                6.0
# 10658531      Almacén / Depósito / Expedición                0.0
# 9479177                             Comercial               97.0
#
#           vistas_al_aviso  cantidad  postulaciones_misma_area  \
# 15843441              0.0  0.000000                         0
# 11317520              0.0  0.000000                         0
# 385348                0.0  0.000000                         5
# 2078960               0.0  0.000000                         0
# 2063812               0.0  0.000000                         0
# 4251597               0.0  0.000000                         0
# 9650636               0.0  0.000000                         9
# 10045397              0.0  0.000000                         0
# 9668744               0.0  0.000000                         1
# 5517756               7.0  0.116667                         4
# 10180665              0.0  0.000000                         1
# 2424083               0.0  0.000000                         0
# 12764249              0.0  0.000000                         0
# 9816101               0.0  0.000000                         2
# 11879852              0.0  0.000000                         1
# 3334579               0.0  0.000000                         3
# 6222790               0.0  0.000000                         0
# 14862341              0.0  0.000000                         0
# 10658531              0.0  0.000000                         0
# 9479177               0.0  0.000000                         9
#
#           postulaciones_mismo_tipo  postulaciones_mismo_nivel
# 15843441                        19                          0
# 11317520                        22                          3
# 385348                          46                         38
# 2078960                         24                         21
# 2063812                         43                         30
# 4251597                         18                          6
# 9650636                         49                         34
# 10045397                        15                         10
# 9668744                         88                         48
# 5517756                         44                         36
# 10180665                         2                          6
# 2424083                         41                         40
# 12764249                        17                         13
# 9816101                         23                         16
# 11879852                        41                         30
# 3334579                          0                         15
# 6222790                        132                         76
# 14862341                        23                          1
# 10658531                        48                          3
# 9479177                        118                         80
#
# [20 rows x 85 columns]

# %%
for i in range(0,len(postulaciones.columns)):
    print(postulaciones.columns[i])
# Out:
# idaviso
# idpostulante
# sepostulo
# edad
# sexo_FEM
# sexo_MASC
# sexo_NO_DECLARA
# Doctorado_Abandonado
# Doctorado_En Curso
# Doctorado_Graduado
# Master_Abandonado
# Master_En Curso
# Master_Graduado
# Posgrado_Abandonado
# Posgrado_En Curso
# Posgrado_Graduado
# Secundario_Abandonado
# Secundario_En Curso
# Secundario_Graduado
# Terciario/Técnico_Abandonado
# Terciario/Técnico_En Curso
# Terciario/Técnico_Graduado
# Universitario_Abandonado
# Universitario_En Curso
# Universitario_Graduado
# titulo
# nombre_area
# denominacion_empresa
# titulo_uppercase
# pide_hombre
# pide_mujer
# ingles
# experiencia
# paquete_office
# liderazgo
# secundario
# viajar
# empresa_importante
# capacitacion
# remuneracion_pretendida
# graduados
# estudiantes
# conocimientos_especificos
# buen_ambiente
# discriminacion
# nombre_zona_Buenos Aires (fuera de GBA)
# nombre_zona_Capital Federal
# nombre_zona_Catamarca
# nombre_zona_Ciudad de Mendoza
# nombre_zona_Cordoba
# nombre_zona_Corrientes
# nombre_zona_GBA Oeste
# nombre_zona_Gran Buenos Aires
# nombre_zona_La Plata
# nombre_zona_Mendoza
# nombre_zona_Neuquen
# nombre_zona_Rosario
# nombre_zona_San Juan
# nombre_zona_Santa Cruz
# nombre_zona_Santa Fe
# nombre_zona_Tucuman
# tipo_de_trabajo_Fines de Semana
# tipo_de_trabajo_Full-time
# tipo_de_trabajo_Part-time
# tipo_de_trabajo_Pasantia
# tipo_de_trabajo_Por Contrato
# tipo_de_trabajo_Por Horas
# tipo_de_trabajo_Primer empleo
# tipo_de_trabajo_Teletrabajo
# tipo_de_trabajo_Temporario
# tipo_de_trabajo_Voluntario
# nivel_laboral_Gerencia / Alta Gerencia / Dirección
# nivel_laboral_Jefe / Supervisor / Responsable
# nivel_laboral_Junior
# nivel_laboral_Otro
# nivel_laboral_Senior / Semi-Senior
# tipo_de_trabajo
# nivel_laboral
# nombre_area_aux
# vistas_postulante
# vistas_al_aviso
# cantidad
# postulaciones_misma_area
# postulaciones_mismo_tipo
# postulaciones_mismo_nivel

# %%
train, test=train_test_split(postulaciones.sample(2*(len(postulaciones)//3)),test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
# Out:
# Train:  10187908 Test:  536206

# %%
features=['edad','sexo_FEM', 'sexo_MASC','Doctorado_Abandonado',
'Doctorado_En Curso', 'Doctorado_Graduado', 'Master_Abandonado',
'Master_En Curso', 'Master_Graduado', 'Posgrado_Abandonado',
'Posgrado_En Curso', 'Posgrado_Graduado', 'Secundario_Abandonado',
'Secundario_En Curso', 'Secundario_Graduado', 'Terciario/Técnico_Abandonado',
'Terciario/Técnico_En Curso', 'Terciario/Técnico_Graduado', 'Universitario_Abandonado',
'Universitario_En Curso', 'Universitario_Graduado', 'pide_hombre',
'pide_mujer', 'ingles', 'experiencia', 'paquete_office', 'liderazgo', 'secundario',
'viajar', 'empresa_importante', 'capacitacion', 'remuneracion_pretendida', 'graduados',
'estudiantes', 'conocimientos_especificos', 'buen_ambiente', 'discriminacion',
'tipo_de_trabajo_Fines de Semana', 'tipo_de_trabajo_Full-time', 'tipo_de_trabajo_Part-time',
'tipo_de_trabajo_Pasantia', 'tipo_de_trabajo_Por Contrato', 'tipo_de_trabajo_Por Horas',
'tipo_de_trabajo_Primer empleo', 'tipo_de_trabajo_Teletrabajo', 'tipo_de_trabajo_Temporario',
'tipo_de_trabajo_Voluntario', 'nivel_laboral_Gerencia / Alta Gerencia / Dirección',
'nivel_laboral_Jefe / Supervisor / Responsable', 'nivel_laboral_Junior',
'nivel_laboral_Otro', 'nivel_laboral_Senior / Semi-Senior', 'vistas_postulante',
'vistas_al_aviso', 'cantidad', 'postulaciones_misma_area', 'postulaciones_mismo_tipo', 
'postulaciones_mismo_nivel']

# %%
x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']

# %%
postulaciones=0
c=0
gc.collect()
# Out:
# 295

# %%
c=MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto',epsilon=1e-08, hidden_layer_sizes=(len(features), 5), learning_rate='constant',learning_rate_init=0.001, max_iter=200,nesterovs_momentum=True, power_t=0.5, random_state=1, shuffle=True,solver='sgd', tol=0.0001, validation_fraction=0.1, verbose=True,warm_start=False)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/NN.pkl")
dt=c.fit(x_train,y_train)
# Out:
# Iteration 1, loss = 0.31668514
# Iteration 2, loss = 0.29777076
# Iteration 3, loss = 0.29390940
# Iteration 4, loss = 0.29095146
# Iteration 5, loss = 0.29086576
# Iteration 6, loss = 0.29179572
# Iteration 7, loss = 0.28970295
# Iteration 8, loss = 0.28840421
# Iteration 9, loss = 0.28824308
# Iteration 10, loss = 0.28663105
# Iteration 11, loss = 0.28569618
# Iteration 12, loss = 0.28548699
# Iteration 13, loss = 0.28443695
# Iteration 14, loss = 0.28339261
# Iteration 15, loss = 0.28243212
# Iteration 16, loss = 0.28166835
# Iteration 17, loss = 0.28117783
# Iteration 18, loss = 0.28062932
# Iteration 19, loss = 0.28015482
# Iteration 20, loss = 0.28012712
# Iteration 21, loss = 0.27968095
# Iteration 22, loss = 0.27953329
# Iteration 23, loss = 0.27932016
# Iteration 24, loss = 0.27990222
# Iteration 25, loss = 0.27868512
# Iteration 26, loss = 0.27853164
# Iteration 27, loss = 0.27959465
# Iteration 28, loss = 0.27888689
# Iteration 29, loss = 0.27809686
# Iteration 30, loss = 0.27779247
# Iteration 31, loss = 0.27746673
# Iteration 32, loss = 0.27717156
# Iteration 33, loss = 0.27743145
# Iteration 34, loss = 0.27709107
# Iteration 35, loss = 0.27694776
# Iteration 36, loss = 0.27679040
# Iteration 37, loss = 0.27669208
# Iteration 38, loss = 0.27667720
# Iteration 39, loss = 0.27655822
# Iteration 40, loss = 0.27626908
# Iteration 41, loss = 0.27641189
# Iteration 42, loss = 0.27635831
# Iteration 43, loss = 0.27614777
# Iteration 44, loss = 0.27618298
# Iteration 45, loss = 0.27592794
# Iteration 46, loss = 0.27588166
# Iteration 47, loss = 0.27587867
# Iteration 48, loss = 0.27613995
# Training loss did not improve more than tol=0.000100 for two consecutive epochs. Stopping.

# %%
from sklearn.metrics import roc_auc_score
x_final=x_test[features]
y_final=c.predict_proba(x_final)
y_pred=[]
for elem in y_final:
    y_pred.append(elem[1])
score=roc_auc_score(y_test, y_pred)
print(score)
# Out:
# 0.9485893179507313

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/NN v2.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/NN v2.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos_no_one_hot,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idpostulante'],how='left')
prediccion=pd.merge(prediccion,vistas2,on=['idaviso','idpostulante'],how='left')
prediccion=pd.merge(prediccion,vistas3,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion['vistas_postulante']=prediccion['vistas_postulante'].fillna(0)
prediccion['vistas_al_aviso']=prediccion['vistas_al_aviso'].fillna(0)
prediccion=pd.merge(prediccion,postulaciones_por_area,on=['idpostulante','nombre_area_aux'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_tipo,on=['idpostulante','tipo_de_trabajo'],how='left')
prediccion=pd.merge(prediccion,postulaciones_por_nivel,on=['idpostulante','nivel_laboral'],how='left')
prediccion['postulaciones_misma_area']=prediccion['postulaciones_misma_area'].fillna(0)
prediccion['postulaciones_mismo_nivel']=prediccion['postulaciones_mismo_nivel'].fillna(0)
prediccion['postulaciones_mismo_tipo']=prediccion['postulaciones_mismo_tipo'].fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  edad  sexo_FEM  sexo_MASC  \
# 74138  20245  1112252474      dY9aP50  32.0      True      False
# 29731  79973  1112464769      EzEvGNN  25.0     False       True
# 99478  99433  1112512046       eZaQwj  50.0     False       True
# 94532  93830  1112481084       5ox5Jw  31.0     False       True
# 69738  15284  1112130453       YqZVYP  33.0      True      False
# 18495  75863  1112464203      owE3G0e  29.0     False       True
# 53911   4619  1111476127       ERlja9  37.0      True      False
# 91988  90922  1112469923       86bG9x  28.0      True      False
# 33901  47738  1112432320       ZBNEZR  40.0     False       True
# 66442  12561  1112011284       aJ5l90  33.0     False       True
#
#        sexo_NO_DECLARA  Doctorado_Abandonado  Doctorado_En Curso  \
# 74138            False                 False               False
# 29731            False                 False               False
# 99478            False                 False               False
# 94532            False                 False               False
# 69738            False                 False               False
# 18495            False                 False               False
# 53911            False                 False               False
# 91988            False                 False               False
# 33901            False                  True               False
# 66442            False                 False               False
#
#        Doctorado_Graduado            ...              \
# 74138               False            ...
# 29731               False            ...
# 99478               False            ...
# 94532               False            ...
# 69738               False            ...
# 18495               False            ...
# 53911               False            ...
# 91988               False            ...
# 33901               False            ...
# 66442               False            ...
#
#        nivel_laboral_Senior / Semi-Senior  tipo_de_trabajo  \
# 74138                               False        Full-time
# 29731                               False        Full-time
# 99478                                True        Full-time
# 94532                                True        Full-time
# 69738                                True        Full-time
# 18495                                True        Full-time
# 53911                                True        Full-time
# 91988                                True        Full-time
# 33901                               False        Full-time
# 66442                               False        Part-time
#
#                          nivel_laboral                  nombre_area_aux  \
# 74138  Jefe / Supervisor / Responsable           Ingeniería  Industrial
# 29731                             Otro                       Producción
# 99478             Senior / Semi-Senior                        Asistente
# 94532             Senior / Semi-Senior                Diseño Industrial
# 69738             Senior / Semi-Senior            Oficios y Profesiones
# 18495             Senior / Semi-Senior                        Logística
# 53911             Senior / Semi-Senior  Almacén / Depósito / Expedición
# 91988             Senior / Semi-Senior  Almacén / Depósito / Expedición
# 33901  Jefe / Supervisor / Responsable           Ingeniería de Procesos
# 66442                           Junior                    Recepcionista
#
#        vistas_postulante  vistas_al_aviso  cantidad  postulaciones_misma_area  \
# 74138               32.0              1.0  0.031250                       2.0
# 29731              778.0              1.0  0.001285                      41.0
# 99478                4.0              0.0  0.000000                       0.0
# 94532                1.0              0.0  0.000000                       0.0
# 69738               56.0              0.0  0.000000                       1.0
# 18495                0.0              0.0  0.000000                       5.0
# 53911              172.0              0.0  0.000000                       2.0
# 91988                6.0              0.0  0.000000                       0.0
# 33901               20.0              0.0  0.000000                       6.0
# 66442               56.0              0.0  0.000000                       1.0
#
#        postulaciones_mismo_tipo  postulaciones_mismo_nivel
# 74138                      31.0                        1.0
# 29731                     703.0                       56.0
# 99478                      18.0                       11.0
# 94532                      25.0                       16.0
# 69738                      50.0                       28.0
# 18495                     226.0                      164.0
# 53911                      25.0                       20.0
# 91988                      23.0                       19.0
# 33901                      58.0                        8.0
# 66442                       5.0                       20.0
#
# [10 rows x 85 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.9724622 , 0.0275378 ],
#        [0.54032856, 0.45967144],
#        [0.78468584, 0.21531416],
#        ...,
#        [0.96947309, 0.03052691],
#        [0.93680852, 0.06319148],
#        [0.98622874, 0.01377126]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  edad  sexo_FEM  sexo_MASC  sexo_NO_DECLARA  \
# 0   0   739260       6M9ZQR  42.0      True      False            False
# 1   1   739260       6v1xdL  30.0     False       True            False
# 2   2   739260       ezRKm9  36.0      True      False            False
# 3   3   758580       1Q35ej  68.0     False       True            False
# 4   4   758580       EAN4J6  32.0      True      False            False
#
#    Doctorado_Abandonado  Doctorado_En Curso  Doctorado_Graduado    ...      \
# 0                 False               False                True    ...
# 1                 False               False               False    ...
# 2                 False               False               False    ...
# 3                 False               False               False    ...
# 4                 False               False               False    ...
#
#    tipo_de_trabajo                    nivel_laboral        nombre_area_aux  \
# 0        Full-time  Jefe / Supervisor / Responsable              Comercial
# 1        Full-time  Jefe / Supervisor / Responsable              Comercial
# 2        Full-time  Jefe / Supervisor / Responsable              Comercial
# 3        Full-time                             Otro  Tecnologia / Sistemas
# 4        Full-time                             Otro  Tecnologia / Sistemas
#
#    vistas_postulante  vistas_al_aviso  cantidad  postulaciones_misma_area  \
# 0               33.0              0.0       0.0                       1.0
# 1                8.0              0.0       0.0                       6.0
# 2               12.0              0.0       0.0                       3.0
# 3                0.0              0.0       0.0                       2.0
# 4                3.0              0.0       0.0                       2.0
#
#    postulaciones_mismo_tipo  postulaciones_mismo_nivel  sepostulo
# 0                      20.0                        0.0   0.027538
# 1                      59.0                        0.0   0.459671
# 2                      21.0                        2.0   0.215314
# 3                      20.0                        1.0   0.080371
# 4                      14.0                        2.0   0.008550
#
# [5 rows x 86 columns]

# %%
prediccion=prediccion[['id','sepostulo']]
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.027538
# 1   1   0.459671
# 2   2   0.215314
# 3   3   0.080371
# 4   4   0.008550

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion48.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.4919829571276072
