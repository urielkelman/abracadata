# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/1.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/2.csv").iloc[0:len(postulaciones2)//2], ignore_index=True)
print(len(postulaciones2))
postulaciones2.head()
# Out:
# 9906801
#       idaviso idpostulante  sepostulo
# 0  1112257047      akjmXXq          0
# 1  1111920714      wVoV89V          0
# 2  1112346945       eGJd8B          0
# 3  1112345547      ekOEVL8          0
# 4  1112237522      qekX8N9          0

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 16511335
# 16426692

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 6614769   1112262197      0zLjLYr          1   FEM  34.0         -      -
# 11456710  1112425681       8rj2Px          0   FEM  37.0         -      -
# 7169191   1112439200      OqbP9ON          0  MASC  54.0         -      -
# 3704279   1112279361      LNwZ3ww          1  MASC  34.0         -      -
# 1253465   1112285124       EkOw86          0  MASC  35.0         -      -
# 7670455   1112314890      6rZdWej          0  MASC  26.0         -      -
# 14206610  1112018104      vVk8KJo          1   FEM  37.0         -      -
# 2450146   1112424614       aMRMv9          1  MASC  26.0         -      -
# 8397162   1112299495      MVrGG9o          0  MASC  18.0         -      -
# 2769584   1112274893      BmB39MZ          0   FEM  34.0         -      -
# 12667204  1111533724      KBrDkZm          1   FEM  18.0         -      -
# 13267463  1111976179      ZDrkQA5          1  MASC  25.0         -      -
# 12294129  1112376846      DrXW5Bl          1  MASC  23.0         -      -
# 13545059  1112349826      6rPmMvv          1  MASC  25.0         -      -
# 14581071  1112374140       5rX3Vv          1   FEM  49.0         -      -
# 4051437   1112316434      qe2Jv4k          0   FEM  25.0         -      -
# 8418410   1112351410      dY9jV3a          1  MASC  22.0         -      -
# 3007568   1112414507      Rz92oBR          1   FEM  20.0         -      -
# 280726    1112345900      qeY64dw          0  MASC  32.0         -      -
# 7034815   1112245832      lDPrXG3          0   FEM  26.0         -      -
#
#               Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 6614769          -         -   Graduado    ...     False              False
# 11456710         -         -   Graduado    ...     False              False
# 7169191   Graduado         -          -    ...     False               True
# 3704279          -         -   Graduado    ...     False               True
# 1253465          -         -   Graduado    ...     False              False
# 7670455   Graduado         -   Graduado    ...     False              False
# 14206610         -         -   Graduado    ...     False               True
# 2450146          -         -   Graduado    ...      True               True
# 8397162          -         -   En Curso    ...     False              False
# 2769584          -         -          -    ...     False              False
# 12667204         -         -   Graduado    ...     False              False
# 13267463         -         -   Graduado    ...     False              False
# 12294129         -         -   Graduado    ...     False              False
# 13545059         -         -   Graduado    ...     False              False
# 14581071         -  Graduado   Graduado    ...     False              False
# 4051437   Graduado         -          -    ...     False              False
# 8418410          -         -   Graduado    ...     False              False
# 3007568          -         -   Graduado    ...     False               True
# 280726           -         -   Graduado    ...     False              False
# 7034815          -         -   Graduado    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 6614769         False                   False     False        True
# 11456710        False                   False     False       False
# 7169191         False                   False     False       False
# 3704279         False                   False     False       False
# 1253465         False                   False     False       False
# 7670455         False                   False     False       False
# 14206610        False                   False      True       False
# 2450146         False                   False     False       False
# 8397162         False                   False     False       False
# 2769584         False                   False     False       False
# 12667204        False                   False     False       False
# 13267463        False                   False     False       False
# 12294129        False                   False     False       False
# 13545059        False                   False     False       False
# 14581071         True                   False     False       False
# 4051437         False                   False     False        True
# 8418410         False                   False     False       False
# 3007568         False                   False     False       False
# 280726          False                   False     False        True
# 7034815         False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 6614769                      False         False           False       NaN
# 11456710                     False          True           False       NaN
# 7169191                      False         False           False       NaN
# 3704279                      False         False           False       NaN
# 1253465                      False         False           False       NaN
# 7670455                      False         False           False       NaN
# 14206610                     False         False           False       NaN
# 2450146                      False         False           False       1.0
# 8397162                      False         False           False       NaN
# 2769584                      False         False           False       NaN
# 12667204                     False          True            True       NaN
# 13267463                     False         False           False       1.0
# 12294129                     False         False           False       3.0
# 13545059                     False         False           False       NaN
# 14581071                     False         False           False       NaN
# 4051437                      False         False           False       NaN
# 8418410                      False          True           False       NaN
# 3007568                      False          True           False       1.0
# 280726                       False         False           False       NaN
# 7034815                      False         False           False       NaN
#
# [20 rows x 36 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo   edad Doctorado    Master  \
# 13039103  1112274839      MVr5jLx          0   FEM   26.0         -         -
# 14832525  1112300451      bO4QPMq          0   FEM   45.0         -         -
# 8079979   1112300607      mzV84E6          0   FEM   23.0         -         -
# 13066107  1112408670      5mrbk1q          1   FEM   25.0         -         -
# 6765777   1112198759      X95MWQQ          0   FEM  200.0         -         -
# 10947280  1111262064      5mq3KZz          0   FEM   22.0         -         -
# 2677665   1111455368       ejzev2          0   FEM   35.0         -         -
# 4011929   1112377229      GNJmBrE          1  MASC   27.0         -         -
# 5993962   1112352275      1QdJW43          1  MASC   29.0         -         -
# 4419697   1112299971      bOZr90V          1   FEM   31.0         -         -
# 7431544   1112179207      bOjedrV          0  MASC   18.0         -         -
# 8899876   1112326068      Ezekxx6          0   FEM   23.0         -  Graduado
# 12076400  1112296996      lDLrrxM          0   FEM   18.0         -         -
# 3987282   1112341315       1xPYVL          1  MASC   54.0         -         -
# 9940824   1112465893      3Nd5VWw          1  MASC   46.0         -         -
# 2319409   1111753681      zvaa6zm          0   FEM   43.0         -         -
# 11018950  1112415894      8MP4wzz          1  MASC   23.0         -         -
# 3355781   1112259567      Yj5mN0r          0  MASC   29.0         -         -
# 11930486  1112284652       YZEMkZ          0  MASC   49.0         -         -
# 6916334   1112296402      2zmBKYx          1  MASC   22.0         -         -
#
#               Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 13039103         -         -   Graduado    ...     False              False
# 14832525         -         -          -    ...      True              False
# 8079979          -         -   Graduado    ...     False              False
# 13066107         -         -   Graduado    ...     False              False
# 6765777          -         -   Graduado    ...     False               True
# 10947280         -         -          -    ...     False              False
# 2677665   Graduado  Graduado   Graduado    ...     False              False
# 4011929          -         -   Graduado    ...     False               True
# 5993962          -         -   Graduado    ...     False              False
# 4419697          -         -   Graduado    ...     False              False
# 7431544          -         -   En Curso    ...     False               True
# 8899876          -         -          -    ...     False              False
# 12076400         -         -   Graduado    ...     False              False
# 3987282          -         -   Graduado    ...     False              False
# 9940824          -         -   Graduado    ...     False               True
# 2319409          -         -   Graduado    ...     False              False
# 11018950         -         -   Graduado    ...     False              False
# 3355781          -         -   Graduado    ...     False              False
# 11930486         -         -          -    ...     False              False
# 6916334          -         -   Graduado    ...     False               True
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 13039103        False                   False     False       False
# 14832525        False                   False     False       False
# 8079979         False                   False     False       False
# 13066107        False                   False     False       False
# 6765777         False                   False     False       False
# 10947280         True                   False     False       False
# 2677665         False                   False     False        True
# 4011929         False                   False     False       False
# 5993962         False                   False     False       False
# 4419697         False                   False     False       False
# 7431544          True                   False     False       False
# 8899876         False                   False     False        True
# 12076400        False                   False     False       False
# 3987282         False                    True     False       False
# 9940824         False                   False     False       False
# 2319409         False                    True     False       False
# 11018950        False                   False     False       False
# 3355781         False                   False     False       False
# 11930486         True                   False     False       False
# 6916334         False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 13039103                      True         False            True       0.0
# 14832525                     False         False           False       0.0
# 8079979                      False         False           False       0.0
# 13066107                     False         False           False       0.0
# 6765777                      False         False           False       0.0
# 10947280                     False         False           False       0.0
# 2677665                      False         False           False       0.0
# 4011929                      False         False           False       0.0
# 5993962                      False         False           False       0.0
# 4419697                      False         False           False       0.0
# 7431544                      False          True           False       0.0
# 8899876                      False         False           False       0.0
# 12076400                     False         False           False       0.0
# 3987282                      False         False           False       4.0
# 9940824                       True         False            True       2.0
# 2319409                      False         False           False       0.0
# 11018950                     False         False           False       2.0
# 3355781                      False         False           False       0.0
# 11930486                     False          True           False       0.0
# 6916334                      False         False           False       0.0
#
# [20 rows x 36 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.10)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
# Out:
# Train:  13774011 Test:  1530446

# %%
gc.collect()
# Out:
# 156

# %%
c=lgb.LGBMClassifier(learning_rate=0.005,objective='binary',num_leaves=6000,max_depth=13,n_estimators=3000,colsample_bytree=0.7,n_jobs=3,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 75.80496142954406

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV6.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV6.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado    Master Otro  \
# 49412  57270  1112451194       YVmOJw  MASC  32.0         -  En Curso    -
# 22353  14537  1112094756      MVrKOZx   FEM  23.0         -         -    -
# 42498   1456  1110775234       1YRdPR  MASC  37.0         -         -    -
# 74590  50889  1112440597       1jmxN3   FEM  28.0         -         -    -
# 17209  71483  1112462556       1ZVrMN  MASC  30.0         -         -    -
# 10658  88310  1112467005      W9A2vVa   FEM  24.0         -         -    -
# 20470  83539  1112466383      EzlR256  MASC  25.0         -         -    -
# 59754  73020  1112463282       8XN6DM  MASC  53.0         -         -    -
# 40061  57165  1112451106       e3bxDW   FEM  28.0         -         -    -
# 94831  94183  1112483327       5aP4dk  MASC  49.0         -         -    -
#
#       Posgrado Secundario    ...    viajar empresa_importante capacitacion  \
# 49412        -   Graduado    ...     False              False        False
# 22353        -          -    ...     False              False        False
# 42498        -   Graduado    ...     False              False        False
# 74590        -          -    ...     False               True        False
# 17209        -   Graduado    ...     False               True        False
# 10658        -   Graduado    ...     False              False         True
# 20470        -          -    ...     False               True        False
# 59754        -   Graduado    ...     False              False        False
# 40061        -   Graduado    ...     False              False         True
# 94831        -          -    ...     False              False         True
#
#       remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 49412                   False     False       False                     False
# 22353                   False     False       False                     False
# 42498                   False     False       False                     False
# 74590                    True     False       False                     False
# 17209                   False     False       False                     False
# 10658                   False     False       False                     False
# 20470                   False     False       False                     False
# 59754                   False     False       False                      True
# 40061                   False     False       False                     False
# 94831                   False     False       False                     False
#
#       buen_ambiente  discriminacion  cantidad
# 49412         False           False       0.0
# 22353         False           False       2.0
# 42498         False           False       0.0
# 74590         False           False       0.0
# 17209         False           False       1.0
# 10658          True           False       1.0
# 20470         False           False       0.0
# 59754         False            True       0.0
# 40061          True           False       1.0
# 94831          True           False       0.0
#
# [10 rows x 36 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.84175234, 0.15824766],
#        [0.67573211, 0.32426789],
#        [0.71238821, 0.28761179],
#        ...,
#        [0.93452551, 0.06547449],
#        [0.76203122, 0.23796878],
#        [0.98019354, 0.01980646]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     empresa_importante capacitacion  \
# 0   Graduado    ...                  False        False
# 1          -    ...                  False        False
# 2   Graduado    ...                  False        False
# 3   Graduado    ...                  False        False
# 4          -    ...                  False        False
#
#   remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 0                   False     False       False                     False
# 1                   False     False       False                     False
# 2                   False     False       False                     False
# 3                   False     False       False                     False
# 4                   False     False       False                     False
#
#   buen_ambiente discriminacion  cantidad  sepostulo
# 0         False          False       0.0   0.158248
# 1         False          False       0.0   0.324268
# 2         False          False       0.0   0.287612
# 3         False          False       0.0   0.058789
# 4         False          False       0.0   0.209813
#
# [5 rows x 37 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.158248
# 1   1   0.324268
# 2   2   0.287612
# 3   3   0.058789
# 4   4   0.209813

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion19.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5559829965220403
