# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['total']=0
vistas2=vistas
vistas['puntos']=0
vistas2=vistas2.groupby(['idAviso','idpostulante'],as_index=False).agg({'puntos':'count'})
vistas2=vistas2.rename(columns={'idAviso': 'idaviso'})
vistas2.head()
# Out:
#    idaviso idpostulante  puntos
# 0       18        BolNL       2
# 1    48375       RwVdKR       1
# 2   169730        1KjXB       2
# 3   169730       2AKzxa       2
# 4   169730        6LJ64       1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'total':'count'});
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#   idpostulante  total
# 0        0002q     15
# 1        0005E     58
# 2        000R8     14
# 3        001XE     26
# 4        003k9     32

# %%
vistas2=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas2.head()
# Out:
#    idaviso idpostulante  puntos  total
# 0       18        BolNL       2     28
# 1    48375       RwVdKR       1     15
# 2   169730        1KjXB       2     99
# 3   169730       2AKzxa       2      2
# 4   169730        6LJ64       1     23

# %%
vistas2['vistas']=vistas2['puntos']
vistas2['puntos']=(vistas2['puntos']*10)/vistas2['total']
vistas=vistas2
vistas2.head()
# Out:
#    idaviso idpostulante     puntos  total  vistas
# 0       18        BolNL   0.714286     28       2
# 1    48375       RwVdKR   0.666667     15       1
# 2   169730        1KjXB   0.202020     99       2
# 3   169730       2AKzxa  10.000000      2       2
# 4   169730        6LJ64   0.434783     23       1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/3.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/4.csv").iloc[0:len(postulaciones2)//2], ignore_index=True)
print(len(postulaciones2))
postulaciones2.head()

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 16511335
# 16450211

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo        sexo   edad Doctorado  \
# 13960813  1112451413      xkp4PAY          1        MASC   25.0         -
# 11669095  1112277722      ekOqQMo          0         FEM   25.0         -
# 1164789   1112285188      1QPXmLQ          0  NO_DECLARA  200.0         -
# 7503657   1112390440      JB4zKak          0  NO_DECLARA  200.0         -
# 3071109   1112316288      96M3YD8          0        MASC   29.0         -
# 3970264   1112366283       aQjNmD          0        MASC   28.0         -
# 7939324   1112424264       EKZdJ0          0        MASC   38.0         -
# 12896419  1112450769      xk9Yq0j          1        MASC   42.0         -
# 14080315  1112311272      jkj6ep6          0        MASC   32.0         -
# 11564355  1112409290      vVjbN21          1        MASC   35.0         -
# 11203977  1112332536      akb9ALm          0         FEM   24.0         -
# 2922467   1112356254       1O1N3N          1         FEM   27.0         -
# 14420383  1112223051      EzepGLo          0         FEM   20.0         -
# 3634079   1112285529      Ezer0j4          0         FEM   24.0         -
# 5795141   1112297719      pzN8jQp          0        MASC   42.0         -
# 12718178  1112431142       eKNe84          1         FEM   52.0         -
# 6402431   1112199509      pzjLJAb          1        MASC   22.0         -
# 12468732  1112414653      EzldG8b          0         FEM   22.0         -
# 7598097   1112249085      PmVj3JJ          0        MASC   53.0         -
# 9319345   1112129870      1QPe4wB          0        MASC   29.0         -
#
#          Master      Otro  Posgrado Secundario  ...   empresa_importante  \
# 13960813      -         -         -   Graduado  ...                False
# 11669095      -         -         -   Graduado  ...                False
# 1164789       -         -         -          -  ...                False
# 7503657       -         -         -          -  ...                 True
# 3071109       -         -         -   Graduado  ...                False
# 3970264       -         -         -          -  ...                 True
# 7939324       -         -         -          -  ...                 True
# 12896419      -         -         -   Graduado  ...                False
# 14080315      -  Graduado         -   Graduado  ...                False
# 11564355      -         -         -   Graduado  ...                False
# 11203977      -  Graduado         -   Graduado  ...                False
# 2922467       -         -         -   Graduado  ...                False
# 14420383      -         -         -   Graduado  ...                False
# 3634079       -         -         -   Graduado  ...                False
# 5795141       -         -         -   Graduado  ...                 True
# 12718178      -         -  Graduado   Graduado  ...                 True
# 6402431       -         -         -          -  ...                False
# 12468732      -         -         -   Graduado  ...                False
# 7598097       -         -         -   Graduado  ...                False
# 9319345       -         -         -          -  ...                False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 13960813        False                   False     False       False
# 11669095         True                   False     False       False
# 1164789         False                   False     False       False
# 7503657         False                   False     False       False
# 3071109         False                   False     False       False
# 3970264         False                   False     False       False
# 7939324         False                   False     False       False
# 12896419         True                   False     False       False
# 14080315        False                   False      True        True
# 11564355        False                   False     False       False
# 11203977         True                   False     False       False
# 2922467         False                   False     False       False
# 14420383        False                   False     False       False
# 3634079         False                   False     False       False
# 5795141         False                   False     False       False
# 12718178        False                   False     False       False
# 6402431         False                   False     False       False
# 12468732        False                   False     False        True
# 7598097         False                   False     False       False
# 9319345         False                   False     False       False
#
#          conocimientos_especificos buen_ambiente discriminacion    puntos  \
# 13960813                     False         False          False  0.033223
# 11669095                     False         False          False       NaN
# 1164789                       True         False           True       NaN
# 7503657                      False         False          False       NaN
# 3071109                      False         False          False       NaN
# 3970264                      False         False          False       NaN
# 7939324                      False         False          False       NaN
# 12896419                     False         False          False       NaN
# 14080315                     False          True          False       NaN
# 11564355                      True         False           True  0.227273
# 11203977                     False         False          False       NaN
# 2922467                      False         False          False       NaN
# 14420383                     False         False          False       NaN
# 3634079                      False         False          False       NaN
# 5795141                      False         False          False       NaN
# 12718178                     False         False          False  0.909091
# 6402431                      False         False          False       NaN
# 12468732                     False         False          False       NaN
# 7598097                      False         False          False       NaN
# 9319345                      False         False          False       NaN
#
#           total
# 13960813  301.0
# 11669095    NaN
# 1164789     NaN
# 7503657     NaN
# 3071109     NaN
# 3970264     NaN
# 7939324     NaN
# 12896419    NaN
# 14080315    NaN
# 11564355   44.0
# 11203977    NaN
# 2922467     NaN
# 14420383    NaN
# 3634079     NaN
# 5795141     NaN
# 12718178   11.0
# 6402431     NaN
# 12468732    NaN
# 7598097     NaN
# 9319345     NaN
#
# [20 rows x 37 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo        sexo  edad Doctorado  \
# 12577745  1111422543       5qYO3M          0        MASC  39.0         -
# 5860315   1112361175       Y3WV11          0        MASC  33.0         -
# 811889    1112334788      wVkZPve          0        MASC  24.0         -
# 3378546   1112264644      VNPbG5l          0         FEM  36.0         -
# 6047262   1112405351      kPjvPZb          0        MASC  19.0         -
# 13619552  1112426717      vVjvl5j          1         FEM  32.0         -
# 6100182   1112456152       ZXRbXz          0         FEM  36.0         -
# 6921920   1112204683       5ErDRM          1         FEM  28.0         -
# 10527731  1112338055      969jNMZ          0        MASC  29.0         -
# 12304901  1112385586      ekmaDYj          1         FEM  25.0         -
# 6582929   1112115684       aBreLN          0        MASC  38.0         -
# 1204917   1112337868      3Nzozrq          0         FEM  29.0         -
# 7564810   1112412238      8MBNWQM          0        MASC  27.0         -
# 3217079   1112231508      X9xmQKQ          0         FEM  25.0         -
# 11248808  1112403848       Y82jR1          1         FEM  32.0         -
# 7783146   1112263388       5KOYWM          0        MASC  27.0         -
# 14814718  1112386793      DrXNDkL          0  NO_DECLARA  21.0         -
# 9386669   1112299778      Rzr4mk9          0        MASC  41.0         -
# 8779667   1112409680      5mP1mxX          1        MASC  26.0         -
# 7210103   1112319451      LNKOjeq          0        MASC  25.0         -
#
#               Master      Otro Posgrado Secundario    ...    viajar  \
# 12577745           -         -        -   Graduado    ...     False
# 5860315            -         -        -   Graduado    ...     False
# 811889             -         -        -   Graduado    ...     False
# 3378546            -  Graduado        -          -    ...     False
# 6047262            -         -        -   Graduado    ...     False
# 13619552           -         -        -   Graduado    ...     False
# 6100182            -         -        -          -    ...     False
# 6921920            -  Graduado        -   Graduado    ...     False
# 10527731           -         -        -   En Curso    ...     False
# 12304901           -  En Curso        -          -    ...     False
# 6582929     Graduado         -        -   Graduado    ...     False
# 1204917            -  Graduado        -   Graduado    ...     False
# 7564810            -         -        -   Graduado    ...     False
# 3217079            -         -        -   Graduado    ...     False
# 11248808           -         -        -          -    ...     False
# 7783146            -         -        -   Graduado    ...     False
# 14814718           -         -        -          -    ...     False
# 9386669            -         -        -   Graduado    ...     False
# 8779667            -         -        -          -    ...     False
# 7210103   Abandonado         -        -   Graduado    ...     False
#
#          empresa_importante capacitacion remuneracion_pretendida graduados  \
# 12577745              False        False                   False     False
# 5860315                True        False                   False     False
# 811889                False         True                   False     False
# 3378546               False        False                   False     False
# 6047262                True        False                   False     False
# 13619552              False        False                   False     False
# 6100182               False        False                   False     False
# 6921920               False         True                   False     False
# 10527731              False         True                   False     False
# 12304901              False        False                   False     False
# 6582929               False        False                   False     False
# 1204917               False        False                   False     False
# 7564810               False        False                   False      True
# 3217079               False        False                   False     False
# 11248808              False        False                   False     False
# 7783146               False        False                   False     False
# 14814718               True        False                   False     False
# 9386669               False        False                   False     False
# 8779667               False         True                   False     False
# 7210103               False         True                   False     False
#
#          estudiantes conocimientos_especificos buen_ambiente  discriminacion  \
# 12577745       False                     False         False           False
# 5860315        False                     False         False           False
# 811889         False                     False          True           False
# 3378546        False                     False         False           False
# 6047262        False                     False         False           False
# 13619552       False                     False          True           False
# 6100182        False                     False         False           False
# 6921920        False                     False          True           False
# 10527731       False                     False         False           False
# 12304901       False                     False         False           False
# 6582929        False                     False          True           False
# 1204917        False                     False         False           False
# 7564810         True                     False         False           False
# 3217079         True                     False         False           False
# 11248808       False                     False         False           False
# 7783146        False                     False         False           False
# 14814718       False                     False         False           False
# 9386669         True                     False         False           False
# 8779667        False                     False         False           False
# 7210103        False                     False          True           False
#
#           cantidad
# 12577745  0.000000
# 5860315   0.000000
# 811889    0.000000
# 3378546   0.000000
# 6047262   0.000000
# 13619552  0.068966
# 6100182   0.000000
# 6921920   0.000000
# 10527731  0.000000
# 12304901  0.002688
# 6582929   0.000000
# 1204917   0.000000
# 7564810   0.000000
# 3217079   0.000000
# 11248808  0.000000
# 7783146   0.000000
# 14814718  0.000000
# 9386669   0.000000
# 8779667   0.000000
# 7210103   0.000000
#
# [20 rows x 36 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
vistas2=0
# Out:
# Train:  14560399 Test:  766337

# %%
gc.collect()
# Out:
# 156

# %%
c=lgb.LGBMClassifier(learning_rate=0.005,objective='binary',num_leaves=6000,max_depth=13,n_estimators=1200,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 75.52564994251875
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV11.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV11.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado    Master  \
# 7175   51506  1112441719       YW3G6Y   FEM  31.0         -         -
# 58035   7131  1111687280       6kKWV3   FEM  48.0         -  Graduado
# 19697  79461  1112464706      0zPNOG1  MASC  44.0         -         -
# 16499  69661  1112461486      DrzPGza   FEM  30.0         -         -
# 78825  26176  1112338262       Nq9VbJ  MASC  38.0         -         -
# 89711  52109  1112442500       aPd9V0   FEM  29.0         -         -
# 92776  91865  1112473259       ZdjYjZ   FEM  31.0         -         -
# 63650  10914  1111931583       e0vvKj  MASC  37.0         -         -
# 1394   86364  1112466740      MVeOkAN   FEM  28.0         -         -
# 54448   4756  1111489974       ZvzVdR   FEM  39.0         -         -
#
#            Otro Posgrado Secundario    ...    viajar empresa_importante  \
# 7175   Graduado        -   Graduado    ...     False               True
# 58035         -        -          -    ...     False              False
# 19697  Graduado        -   Graduado    ...     False               True
# 16499         -        -   Graduado    ...     False              False
# 78825         -        -   Graduado    ...     False               True
# 89711         -        -          -    ...     False               True
# 92776         -        -          -    ...     False              False
# 63650  Graduado        -   Graduado    ...     False              False
# 1394   En Curso        -   Graduado    ...     False              False
# 54448         -        -          -    ...     False              False
#
#       capacitacion remuneracion_pretendida graduados estudiantes  \
# 7175          True                   False     False       False
# 58035        False                   False     False       False
# 19697        False                   False     False       False
# 16499        False                   False     False       False
# 78825        False                   False     False        True
# 89711        False                   False     False       False
# 92776         True                   False      True        True
# 63650        False                   False     False       False
# 1394         False                   False     False       False
# 54448        False                   False     False       False
#
#       conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 7175                      False          True           False  0.000000
# 58035                     False         False           False  0.000000
# 19697                     False         False           False  0.000000
# 16499                     False         False           False  0.000000
# 78825                     False         False           False  0.000000
# 89711                     False         False           False  0.000000
# 92776                     False         False           False  0.000000
# 63650                     False         False           False  0.000000
# 1394                      False         False           False  0.002513
# 54448                     False          True           False  0.000000
#
# [10 rows x 36 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.70404653, 0.29595347],
#        [0.66541747, 0.33458253],
#        [0.65816179, 0.34183821],
#        ...,
#        [0.87783004, 0.12216996],
#        [0.65230813, 0.34769187],
#        [0.9584104 , 0.0415896 ]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     empresa_importante capacitacion  \
# 0   Graduado    ...                  False        False
# 1          -    ...                  False        False
# 2   Graduado    ...                  False        False
# 3   Graduado    ...                  False        False
# 4          -    ...                  False        False
#
#   remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 0                   False     False       False                     False
# 1                   False     False       False                     False
# 2                   False     False       False                     False
# 3                   False     False       False                     False
# 4                   False     False       False                     False
#
#   buen_ambiente discriminacion  cantidad  sepostulo
# 0         False          False       0.0   0.295953
# 1         False          False       0.0   0.334583
# 2         False          False       0.0   0.341838
# 3         False          False       0.0   0.133917
# 4         False          False       0.0   0.339016
#
# [5 rows x 37 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.295953
# 1   1   0.334583
# 2   2   0.341838
# 3   3   0.133917
# 4   4   0.339016

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion26.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5393097843500064
