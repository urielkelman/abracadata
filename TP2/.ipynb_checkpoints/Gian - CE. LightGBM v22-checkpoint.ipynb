# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc
from sklearn.metrics import roc_auc_score

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')
avisos['denominacion_empresa']=avisos['denominacion_empresa'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas2=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2=vistas2.rename(columns={'idAviso': 'idaviso'})
vistas2.head()

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()

# %%
vistas2=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas2.head()

# %%
vistas2['cantidad']=vistas2['cantidad_x']/vistas2['cantidad_y']
vistas2.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas=vistas2
vistas2.head()

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/8.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/9.csv").sample(len(postulaciones2)//2).reset_index(drop=True))
print(len(postulaciones2))
postulaciones2

# %%
postulaciones.head()

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
vistas2=0

# %%
gc.collect()

# %%
c=lgb.LGBMClassifier(learning_rate=0.01,objective='binary',num_leaves=12000,max_depth=18,n_estimators=1200,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train,eval_set=[(x_test,y_test)],verbose=True,early_stopping_rounds=1)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")
# Out:
# [1]	valid_0's binary_logloss: 0.689845
# Training until validation scores don't improve for 1 rounds.
# [2]	valid_0's binary_logloss: 0.685605
# [3]	valid_0's binary_logloss: 0.681248
# [4]	valid_0's binary_logloss: 0.677889
# [5]	valid_0's binary_logloss: 0.67367
# [6]	valid_0's binary_logloss: 0.670048
# [7]	valid_0's binary_logloss: 0.666045
# [8]	valid_0's binary_logloss: 0.66243
# [9]	valid_0's binary_logloss: 0.660747
# [10]	valid_0's binary_logloss: 0.657808
# [11]	valid_0's binary_logloss: 0.65418
# [12]	valid_0's binary_logloss: 0.650489
# [13]	valid_0's binary_logloss: 0.647897
# [14]	valid_0's binary_logloss: 0.646287
# [15]	valid_0's binary_logloss: 0.643583
# [16]	valid_0's binary_logloss: 0.640247
# [17]	valid_0's binary_logloss: 0.636745
# [18]	valid_0's binary_logloss: 0.634198
# [19]	valid_0's binary_logloss: 0.631072
# [20]	valid_0's binary_logloss: 0.627665
# [21]	valid_0's binary_logloss: 0.624303
# [22]	valid_0's binary_logloss: 0.622065
# [23]	valid_0's binary_logloss: 0.619587
# [24]	valid_0's binary_logloss: 0.616445
# [25]	valid_0's binary_logloss: 0.613619
# [26]	valid_0's binary_logloss: 0.610566
# [27]	valid_0's binary_logloss: 0.607524
# [28]	valid_0's binary_logloss: 0.604757
# [29]	valid_0's binary_logloss: 0.601847
# [30]	valid_0's binary_logloss: 0.599297
# [31]	valid_0's binary_logloss: 0.596737
# [32]	valid_0's binary_logloss: 0.594682
# [33]	valid_0's binary_logloss: 0.591985
# [34]	valid_0's binary_logloss: 0.589263
# [35]	valid_0's binary_logloss: 0.586581
# [36]	valid_0's binary_logloss: 0.583877
# [37]	valid_0's binary_logloss: 0.581426
# [38]	valid_0's binary_logloss: 0.578817
# [39]	valid_0's binary_logloss: 0.576962
# [40]	valid_0's binary_logloss: 0.575063
# [41]	valid_0's binary_logloss: 0.573226
# [42]	valid_0's binary_logloss: 0.571567
# [43]	valid_0's binary_logloss: 0.569798
# [44]	valid_0's binary_logloss: 0.56746
# [45]	valid_0's binary_logloss: 0.56526
# [46]	valid_0's binary_logloss: 0.563554
# [47]	valid_0's binary_logloss: 0.561301
# [48]	valid_0's binary_logloss: 0.559032
# [49]	valid_0's binary_logloss: 0.557686
# [50]	valid_0's binary_logloss: 0.555435
# [51]	valid_0's binary_logloss: 0.554427
# [52]	valid_0's binary_logloss: 0.552761
# [53]	valid_0's binary_logloss: 0.551151
# [54]	valid_0's binary_logloss: 0.549005
# [55]	valid_0's binary_logloss: 0.548032
# [56]	valid_0's binary_logloss: 0.545979
# [57]	valid_0's binary_logloss: 0.543926
# [58]	valid_0's binary_logloss: 0.54199
# [59]	valid_0's binary_logloss: 0.540525
# [60]	valid_0's binary_logloss: 0.539037
# [61]	valid_0's binary_logloss: 0.537534
# [62]	valid_0's binary_logloss: 0.536067
# [63]	valid_0's binary_logloss: 0.534729
# [64]	valid_0's binary_logloss: 0.532935
# [65]	valid_0's binary_logloss: 0.531648
# [66]	valid_0's binary_logloss: 0.529903
# [67]	valid_0's binary_logloss: 0.528615
# [68]	valid_0's binary_logloss: 0.52681
# [69]	valid_0's binary_logloss: 0.525505
# [70]	valid_0's binary_logloss: 0.523742
# [71]	valid_0's binary_logloss: 0.522046
# [72]	valid_0's binary_logloss: 0.520823
# [73]	valid_0's binary_logloss: 0.519288
# [74]	valid_0's binary_logloss: 0.518124
# [75]	valid_0's binary_logloss: 0.517448
# [76]	valid_0's binary_logloss: 0.515915
# [77]	valid_0's binary_logloss: 0.514302
# [78]	valid_0's binary_logloss: 0.512914
# [79]	valid_0's binary_logloss: 0.511388
# [80]	valid_0's binary_logloss: 0.509906
# [81]	valid_0's binary_logloss: 0.508872
# [82]	valid_0's binary_logloss: 0.507328
# [83]	valid_0's binary_logloss: 0.505918
# [84]	valid_0's binary_logloss: 0.504337
# [85]	valid_0's binary_logloss: 0.502952
# [86]	valid_0's binary_logloss: 0.50182
# [87]	valid_0's binary_logloss: 0.500516
# [88]	valid_0's binary_logloss: 0.49916
# [89]	valid_0's binary_logloss: 0.498065
# [90]	valid_0's binary_logloss: 0.496659
# [91]	valid_0's binary_logloss: 0.495414
# [92]	valid_0's binary_logloss: 0.494429
# [93]	valid_0's binary_logloss: 0.493197
# [94]	valid_0's binary_logloss: 0.491863
# [95]	valid_0's binary_logloss: 0.491001
# [96]	valid_0's binary_logloss: 0.489649
# [97]	valid_0's binary_logloss: 0.488439
# [98]	valid_0's binary_logloss: 0.487442
# [99]	valid_0's binary_logloss: 0.486267
# [100]	valid_0's binary_logloss: 0.485402
# [101]	valid_0's binary_logloss: 0.484455
# [102]	valid_0's binary_logloss: 0.48324
# [103]	valid_0's binary_logloss: 0.482331
# [104]	valid_0's binary_logloss: 0.48111
# [105]	valid_0's binary_logloss: 0.480282
# [106]	valid_0's binary_logloss: 0.479086
# [107]	valid_0's binary_logloss: 0.477933
# [108]	valid_0's binary_logloss: 0.476769
# [109]	valid_0's binary_logloss: 0.475621
# [110]	valid_0's binary_logloss: 0.474573
# [111]	valid_0's binary_logloss: 0.473447
# [112]	valid_0's binary_logloss: 0.472624
# [113]	valid_0's binary_logloss: 0.471577
# [114]	valid_0's binary_logloss: 0.470791
# [115]	valid_0's binary_logloss: 0.469717
# [116]	valid_0's binary_logloss: 0.468723
# [117]	valid_0's binary_logloss: 0.467754
# [118]	valid_0's binary_logloss: 0.466728
# [119]	valid_0's binary_logloss: 0.465705
# [120]	valid_0's binary_logloss: 0.464702
# [121]	valid_0's binary_logloss: 0.463709
# [122]	valid_0's binary_logloss: 0.463004
# [123]	valid_0's binary_logloss: 0.462058
# [124]	valid_0's binary_logloss: 0.461094
# [125]	valid_0's binary_logloss: 0.460755
# [126]	valid_0's binary_logloss: 0.459829
# [127]	valid_0's binary_logloss: 0.458997
# [128]	valid_0's binary_logloss: 0.458347
# [129]	valid_0's binary_logloss: 0.45796
# [130]	valid_0's binary_logloss: 0.457001
# [131]	valid_0's binary_logloss: 0.456225
# [132]	valid_0's binary_logloss: 0.45554
# [133]	valid_0's binary_logloss: 0.45489
# [134]	valid_0's binary_logloss: 0.453954
# [135]	valid_0's binary_logloss: 0.453104
# [136]	valid_0's binary_logloss: 0.452427
# [137]	valid_0's binary_logloss: 0.451846
# [138]	valid_0's binary_logloss: 0.451085
# [139]	valid_0's binary_logloss: 0.450336
# [140]	valid_0's binary_logloss: 0.44964
# [141]	valid_0's binary_logloss: 0.449012
# [142]	valid_0's binary_logloss: 0.448203
# [143]	valid_0's binary_logloss: 0.447438
# [144]	valid_0's binary_logloss: 0.446692
# [145]	valid_0's binary_logloss: 0.445939
# [146]	valid_0's binary_logloss: 0.445142
# [147]	valid_0's binary_logloss: 0.444396
# [148]	valid_0's binary_logloss: 0.443856
# [149]	valid_0's binary_logloss: 0.443124
# [150]	valid_0's binary_logloss: 0.4426
# [151]	valid_0's binary_logloss: 0.44186
# [152]	valid_0's binary_logloss: 0.441179
# [153]	valid_0's binary_logloss: 0.440724
# [154]	valid_0's binary_logloss: 0.44005
# [155]	valid_0's binary_logloss: 0.439392
# [156]	valid_0's binary_logloss: 0.438855
# [157]	valid_0's binary_logloss: 0.438204
# [158]	valid_0's binary_logloss: 0.43754
# [159]	valid_0's binary_logloss: 0.436908
# [160]	valid_0's binary_logloss: 0.436222
# [161]	valid_0's binary_logloss: 0.435634
# [162]	valid_0's binary_logloss: 0.435078
# [163]	valid_0's binary_logloss: 0.434638
# [164]	valid_0's binary_logloss: 0.434191
# [165]	valid_0's binary_logloss: 0.433622
# [166]	valid_0's binary_logloss: 0.433039
# [167]	valid_0's binary_logloss: 0.432456
# [168]	valid_0's binary_logloss: 0.431981
# [169]	valid_0's binary_logloss: 0.43143
# [170]	valid_0's binary_logloss: 0.430823
# [171]	valid_0's binary_logloss: 0.430648
# [172]	valid_0's binary_logloss: 0.430172
# [173]	valid_0's binary_logloss: 0.429622
# [174]	valid_0's binary_logloss: 0.429008
# [175]	valid_0's binary_logloss: 0.428634
# [176]	valid_0's binary_logloss: 0.428101
# [177]	valid_0's binary_logloss: 0.427701
# [178]	valid_0's binary_logloss: 0.427244
# [179]	valid_0's binary_logloss: 0.426866
# [180]	valid_0's binary_logloss: 0.426495
# [181]	valid_0's binary_logloss: 0.42599
# [182]	valid_0's binary_logloss: 0.425507
# [183]	valid_0's binary_logloss: 0.425121
# [184]	valid_0's binary_logloss: 0.424581
# [185]	valid_0's binary_logloss: 0.424365
# [186]	valid_0's binary_logloss: 0.42395
# [187]	valid_0's binary_logloss: 0.423409
# [188]	valid_0's binary_logloss: 0.423072
# [189]	valid_0's binary_logloss: 0.422707
# [190]	valid_0's binary_logloss: 0.422183
# [191]	valid_0's binary_logloss: 0.421992
# [192]	valid_0's binary_logloss: 0.421588
# [193]	valid_0's binary_logloss: 0.421069
# [194]	valid_0's binary_logloss: 0.420586
# [195]	valid_0's binary_logloss: 0.420434
# [196]	valid_0's binary_logloss: 0.419949
# [197]	valid_0's binary_logloss: 0.419605
# [198]	valid_0's binary_logloss: 0.419163
# [199]	valid_0's binary_logloss: 0.418636
# [200]	valid_0's binary_logloss: 0.418342
# [201]	valid_0's binary_logloss: 0.417906
# [202]	valid_0's binary_logloss: 0.417594
# [203]	valid_0's binary_logloss: 0.417141
# [204]	valid_0's binary_logloss: 0.416974
# [205]	valid_0's binary_logloss: 0.416659
# [206]	valid_0's binary_logloss: 0.416278
# [207]	valid_0's binary_logloss: 0.415836
# [208]	valid_0's binary_logloss: 0.415385
# [209]	valid_0's binary_logloss: 0.415092
# [210]	valid_0's binary_logloss: 0.414664
# [211]	valid_0's binary_logloss: 0.414253
# [212]	valid_0's binary_logloss: 0.413965
# [213]	valid_0's binary_logloss: 0.413561
# [214]	valid_0's binary_logloss: 0.413391
# [215]	valid_0's binary_logloss: 0.413047
# [216]	valid_0's binary_logloss: 0.412708
# [217]	valid_0's binary_logloss: 0.412319
# [218]	valid_0's binary_logloss: 0.411942
# [219]	valid_0's binary_logloss: 0.411632
# [220]	valid_0's binary_logloss: 0.411235
# [221]	valid_0's binary_logloss: 0.410859
# [222]	valid_0's binary_logloss: 0.410477
# [223]	valid_0's binary_logloss: 0.410096
# [224]	valid_0's binary_logloss: 0.40998
# [225]	valid_0's binary_logloss: 0.409543
# [226]	valid_0's binary_logloss: 0.409169
# [227]	valid_0's binary_logloss: 0.40893
# [228]	valid_0's binary_logloss: 0.408676
# [229]	valid_0's binary_logloss: 0.408299
# [230]	valid_0's binary_logloss: 0.407985
# [231]	valid_0's binary_logloss: 0.407735
# [232]	valid_0's binary_logloss: 0.40737
# [233]	valid_0's binary_logloss: 0.407048
# [234]	valid_0's binary_logloss: 0.406692
# [235]	valid_0's binary_logloss: 0.406358
# [236]	valid_0's binary_logloss: 0.406023
# [237]	valid_0's binary_logloss: 0.405903
# [238]	valid_0's binary_logloss: 0.405523
# [239]	valid_0's binary_logloss: 0.405198
# [240]	valid_0's binary_logloss: 0.404867
# [241]	valid_0's binary_logloss: 0.404587
# [242]	valid_0's binary_logloss: 0.404284
# [243]	valid_0's binary_logloss: 0.403978
# [244]	valid_0's binary_logloss: 0.403721
# [245]	valid_0's binary_logloss: 0.403596
# [246]	valid_0's binary_logloss: 0.403392
# [247]	valid_0's binary_logloss: 0.403175
# [248]	valid_0's binary_logloss: 0.402845
# [249]	valid_0's binary_logloss: 0.40265
# [250]	valid_0's binary_logloss: 0.402543
# [251]	valid_0's binary_logloss: 0.4022
# [252]	valid_0's binary_logloss: 0.401905
# [253]	valid_0's binary_logloss: 0.401694
# [254]	valid_0's binary_logloss: 0.401423
# [255]	valid_0's binary_logloss: 0.401226
# [256]	valid_0's binary_logloss: 0.400986
# [257]	valid_0's binary_logloss: 0.400793
# [258]	valid_0's binary_logloss: 0.400621
# [259]	valid_0's binary_logloss: 0.400323
# [260]	valid_0's binary_logloss: 0.400117
# [261]	valid_0's binary_logloss: 0.399832
# [262]	valid_0's binary_logloss: 0.39957
# [263]	valid_0's binary_logloss: 0.399385
# [264]	valid_0's binary_logloss: 0.399135
# [265]	valid_0's binary_logloss: 0.398855
# [266]	valid_0's binary_logloss: 0.398596
# [267]	valid_0's binary_logloss: 0.398355
# [268]	valid_0's binary_logloss: 0.398114
# [269]	valid_0's binary_logloss: 0.397858
# [270]	valid_0's binary_logloss: 0.397598
# [271]	valid_0's binary_logloss: 0.397309
# [272]	valid_0's binary_logloss: 0.397046
# [273]	valid_0's binary_logloss: 0.396787
# [274]	valid_0's binary_logloss: 0.396613
# [275]	valid_0's binary_logloss: 0.396442
# [276]	valid_0's binary_logloss: 0.396287
# [277]	valid_0's binary_logloss: 0.39602
# [278]	valid_0's binary_logloss: 0.395777
# [279]	valid_0's binary_logloss: 0.395583
# [280]	valid_0's binary_logloss: 0.395359
# [281]	valid_0's binary_logloss: 0.395116
# [282]	valid_0's binary_logloss: 0.394924
# [283]	valid_0's binary_logloss: 0.39471
# [284]	valid_0's binary_logloss: 0.394616
# [285]	valid_0's binary_logloss: 0.394374
# [286]	valid_0's binary_logloss: 0.394161
# [287]	valid_0's binary_logloss: 0.393933
# [288]	valid_0's binary_logloss: 0.393668
# [289]	valid_0's binary_logloss: 0.393466
# [290]	valid_0's binary_logloss: 0.393205
# [291]	valid_0's binary_logloss: 0.392984
# [292]	valid_0's binary_logloss: 0.392827
# [293]	valid_0's binary_logloss: 0.392563
# [294]	valid_0's binary_logloss: 0.392435
# [295]	valid_0's binary_logloss: 0.392218
# [296]	valid_0's binary_logloss: 0.392044
# [297]	valid_0's binary_logloss: 0.391819
# [298]	valid_0's binary_logloss: 0.391704
# [299]	valid_0's binary_logloss: 0.391571
# [300]	valid_0's binary_logloss: 0.391354
# [301]	valid_0's binary_logloss: 0.391141
# [302]	valid_0's binary_logloss: 0.390917
# [303]	valid_0's binary_logloss: 0.390742
# [304]	valid_0's binary_logloss: 0.390604
# [305]	valid_0's binary_logloss: 0.390376
# [306]	valid_0's binary_logloss: 0.390255
# [307]	valid_0's binary_logloss: 0.390074
# [308]	valid_0's binary_logloss: 0.389889
# [309]	valid_0's binary_logloss: 0.389768
# [310]	valid_0's binary_logloss: 0.389561
# [311]	valid_0's binary_logloss: 0.389393
# [312]	valid_0's binary_logloss: 0.389212
# [313]	valid_0's binary_logloss: 0.389018
# [314]	valid_0's binary_logloss: 0.388912
# [315]	valid_0's binary_logloss: 0.388787
# [316]	valid_0's binary_logloss: 0.388673
# [317]	valid_0's binary_logloss: 0.388506
# [318]	valid_0's binary_logloss: 0.388416
# [319]	valid_0's binary_logloss: 0.388173
# [320]	valid_0's binary_logloss: 0.388001
# [321]	valid_0's binary_logloss: 0.387826
# [322]	valid_0's binary_logloss: 0.387704
# [323]	valid_0's binary_logloss: 0.387521
# [324]	valid_0's binary_logloss: 0.387337
# [325]	valid_0's binary_logloss: 0.387153
# [326]	valid_0's binary_logloss: 0.387049
# [327]	valid_0's binary_logloss: 0.386869
# [328]	valid_0's binary_logloss: 0.386617
# [329]	valid_0's binary_logloss: 0.386451
# [330]	valid_0's binary_logloss: 0.386291
# [331]	valid_0's binary_logloss: 0.386132
# [332]	valid_0's binary_logloss: 0.385961
# [333]	valid_0's binary_logloss: 0.385886
# [334]	valid_0's binary_logloss: 0.385734
# [335]	valid_0's binary_logloss: 0.385534
# [336]	valid_0's binary_logloss: 0.385349
# [337]	valid_0's binary_logloss: 0.385198
# [338]	valid_0's binary_logloss: 0.385016
# [339]	valid_0's binary_logloss: 0.384865
# [340]	valid_0's binary_logloss: 0.384686
# [341]	valid_0's binary_logloss: 0.384532
# [342]	valid_0's binary_logloss: 0.384391
# [343]	valid_0's binary_logloss: 0.384246
# [344]	valid_0's binary_logloss: 0.384088
# [345]	valid_0's binary_logloss: 0.383947
# [346]	valid_0's binary_logloss: 0.383795
# [347]	valid_0's binary_logloss: 0.383712
# [348]	valid_0's binary_logloss: 0.383627
# [349]	valid_0's binary_logloss: 0.383492
# [350]	valid_0's binary_logloss: 0.383346
# [351]	valid_0's binary_logloss: 0.383175
# [352]	valid_0's binary_logloss: 0.383042
# [353]	valid_0's binary_logloss: 0.382897
# [354]	valid_0's binary_logloss: 0.382794
# [355]	valid_0's binary_logloss: 0.382634
# [356]	valid_0's binary_logloss: 0.382474
# [357]	valid_0's binary_logloss: 0.382352
# [358]	valid_0's binary_logloss: 0.382218
# [359]	valid_0's binary_logloss: 0.382049
# [360]	valid_0's binary_logloss: 0.381933
# [361]	valid_0's binary_logloss: 0.381803
# [362]	valid_0's binary_logloss: 0.381688
# [363]	valid_0's binary_logloss: 0.381528
# [364]	valid_0's binary_logloss: 0.381405
# [365]	valid_0's binary_logloss: 0.381266
# [366]	valid_0's binary_logloss: 0.381145
# [367]	valid_0's binary_logloss: 0.381014
# [368]	valid_0's binary_logloss: 0.380893
# [369]	valid_0's binary_logloss: 0.38076
# [370]	valid_0's binary_logloss: 0.380689
# [371]	valid_0's binary_logloss: 0.380615
# [372]	valid_0's binary_logloss: 0.380491
# [373]	valid_0's binary_logloss: 0.380355
# [374]	valid_0's binary_logloss: 0.380221
# [375]	valid_0's binary_logloss: 0.380069
# [376]	valid_0's binary_logloss: 0.379999
# [377]	valid_0's binary_logloss: 0.379923
# [378]	valid_0's binary_logloss: 0.379794
# [379]	valid_0's binary_logloss: 0.379688
# [380]	valid_0's binary_logloss: 0.379552
# [381]	valid_0's binary_logloss: 0.379513
# [382]	valid_0's binary_logloss: 0.379344
# [383]	valid_0's binary_logloss: 0.379273
# [384]	valid_0's binary_logloss: 0.379139
# [385]	valid_0's binary_logloss: 0.379006
# [386]	valid_0's binary_logloss: 0.378895
# [387]	valid_0's binary_logloss: 0.378747
# [388]	valid_0's binary_logloss: 0.378678
# [389]	valid_0's binary_logloss: 0.378539
# [390]	valid_0's binary_logloss: 0.378433
# [391]	valid_0's binary_logloss: 0.378324
# [392]	valid_0's binary_logloss: 0.378192
# [393]	valid_0's binary_logloss: 0.378086
# [394]	valid_0's binary_logloss: 0.377959
# [395]	valid_0's binary_logloss: 0.377882
# [396]	valid_0's binary_logloss: 0.377771
# [397]	valid_0's binary_logloss: 0.377646
# [398]	valid_0's binary_logloss: 0.377527
# [399]	valid_0's binary_logloss: 0.377396
# [400]	valid_0's binary_logloss: 0.377364
# [401]	valid_0's binary_logloss: 0.377237
# [402]	valid_0's binary_logloss: 0.377116
# [403]	valid_0's binary_logloss: 0.377006
# [404]	valid_0's binary_logloss: 0.376893
# [405]	valid_0's binary_logloss: 0.376814
# [406]	valid_0's binary_logloss: 0.376682
# [407]	valid_0's binary_logloss: 0.376565
# [408]	valid_0's binary_logloss: 0.376461
# [409]	valid_0's binary_logloss: 0.376375
# [410]	valid_0's binary_logloss: 0.37627
# [411]	valid_0's binary_logloss: 0.376125
# [412]	valid_0's binary_logloss: 0.376015
# [413]	valid_0's binary_logloss: 0.375931
# [414]	valid_0's binary_logloss: 0.375834
# [415]	valid_0's binary_logloss: 0.375745
# [416]	valid_0's binary_logloss: 0.375654
# [417]	valid_0's binary_logloss: 0.375587
# [418]	valid_0's binary_logloss: 0.375476
# [419]	valid_0's binary_logloss: 0.375378
# [420]	valid_0's binary_logloss: 0.375253
# [421]	valid_0's binary_logloss: 0.375171
# [422]	valid_0's binary_logloss: 0.375065
# [423]	valid_0's binary_logloss: 0.374981
# [424]	valid_0's binary_logloss: 0.374895
# [425]	valid_0's binary_logloss: 0.374862
# [426]	valid_0's binary_logloss: 0.374755
# [427]	valid_0's binary_logloss: 0.374698
# [428]	valid_0's binary_logloss: 0.374608
# [429]	valid_0's binary_logloss: 0.374518
# [430]	valid_0's binary_logloss: 0.374417
# [431]	valid_0's binary_logloss: 0.374332
# [432]	valid_0's binary_logloss: 0.37422
# [433]	valid_0's binary_logloss: 0.374138
# [434]	valid_0's binary_logloss: 0.374062
# [435]	valid_0's binary_logloss: 0.373975
# [436]	valid_0's binary_logloss: 0.373924
# [437]	valid_0's binary_logloss: 0.37383
# [438]	valid_0's binary_logloss: 0.373735
# [439]	valid_0's binary_logloss: 0.37363
# [440]	valid_0's binary_logloss: 0.373542
# [441]	valid_0's binary_logloss: 0.373487
# [442]	valid_0's binary_logloss: 0.373338
# [443]	valid_0's binary_logloss: 0.37324
# [444]	valid_0's binary_logloss: 0.373162
# [445]	valid_0's binary_logloss: 0.373115
# [446]	valid_0's binary_logloss: 0.37304
# [447]	valid_0's binary_logloss: 0.372982
# [448]	valid_0's binary_logloss: 0.3729
# [449]	valid_0's binary_logloss: 0.372868
# [450]	valid_0's binary_logloss: 0.372774
# [451]	valid_0's binary_logloss: 0.372705
# [452]	valid_0's binary_logloss: 0.372637
# [453]	valid_0's binary_logloss: 0.372558
# [454]	valid_0's binary_logloss: 0.372499
# [455]	valid_0's binary_logloss: 0.372387
# [456]	valid_0's binary_logloss: 0.3723
# [457]	valid_0's binary_logloss: 0.372242
# [458]	valid_0's binary_logloss: 0.37214
# [459]	valid_0's binary_logloss: 0.372032
# [460]	valid_0's binary_logloss: 0.371938
# [461]	valid_0's binary_logloss: 0.371868
# [462]	valid_0's binary_logloss: 0.371773
# [463]	valid_0's binary_logloss: 0.371724
# [464]	valid_0's binary_logloss: 0.371658
# [465]	valid_0's binary_logloss: 0.37163
# [466]	valid_0's binary_logloss: 0.371578
# [467]	valid_0's binary_logloss: 0.371537
# [468]	valid_0's binary_logloss: 0.371446
# [469]	valid_0's binary_logloss: 0.371384
# [470]	valid_0's binary_logloss: 0.371347
# [471]	valid_0's binary_logloss: 0.371277
# [472]	valid_0's binary_logloss: 0.37121
# [473]	valid_0's binary_logloss: 0.371172
# [474]	valid_0's binary_logloss: 0.371085
# [475]	valid_0's binary_logloss: 0.371048
# [476]	valid_0's binary_logloss: 0.370977
# [477]	valid_0's binary_logloss: 0.370896
# [478]	valid_0's binary_logloss: 0.370857
# [479]	valid_0's binary_logloss: 0.370809
# [480]	valid_0's binary_logloss: 0.370727
# [481]	valid_0's binary_logloss: 0.370691
# [482]	valid_0's binary_logloss: 0.370659
# [483]	valid_0's binary_logloss: 0.37056
# [484]	valid_0's binary_logloss: 0.370492
# [485]	valid_0's binary_logloss: 0.370437
# [486]	valid_0's binary_logloss: 0.370388
# [487]	valid_0's binary_logloss: 0.370277
# [488]	valid_0's binary_logloss: 0.370224
# [489]	valid_0's binary_logloss: 0.370131
# [490]	valid_0's binary_logloss: 0.370091
# [491]	valid_0's binary_logloss: 0.370007
# [492]	valid_0's binary_logloss: 0.369976
# [493]	valid_0's binary_logloss: 0.36992
# [494]	valid_0's binary_logloss: 0.36987
# [495]	valid_0's binary_logloss: 0.369828
# [496]	valid_0's binary_logloss: 0.369791
# [497]	valid_0's binary_logloss: 0.369742
# [498]	valid_0's binary_logloss: 0.369677
# [499]	valid_0's binary_logloss: 0.369609
# [500]	valid_0's binary_logloss: 0.369528
# [501]	valid_0's binary_logloss: 0.369492
# [502]	valid_0's binary_logloss: 0.369429
# [503]	valid_0's binary_logloss: 0.369386
# [504]	valid_0's binary_logloss: 0.369321
# [505]	valid_0's binary_logloss: 0.369274
# [506]	valid_0's binary_logloss: 0.36925
# [507]	valid_0's binary_logloss: 0.369189
# [508]	valid_0's binary_logloss: 0.369147
# [509]	valid_0's binary_logloss: 0.369105
# [510]	valid_0's binary_logloss: 0.369053
# [511]	valid_0's binary_logloss: 0.369005
# [512]	valid_0's binary_logloss: 0.36893
# [513]	valid_0's binary_logloss: 0.368894
# [514]	valid_0's binary_logloss: 0.368832
# [515]	valid_0's binary_logloss: 0.368739
# [516]	valid_0's binary_logloss: 0.368683
# [517]	valid_0's binary_logloss: 0.368612
# [518]	valid_0's binary_logloss: 0.368561
# [519]	valid_0's binary_logloss: 0.368507
# [520]	valid_0's binary_logloss: 0.368456
# [521]	valid_0's binary_logloss: 0.368379
# [522]	valid_0's binary_logloss: 0.368341
# [523]	valid_0's binary_logloss: 0.368307
# [524]	valid_0's binary_logloss: 0.368244
# [525]	valid_0's binary_logloss: 0.368205
# [526]	valid_0's binary_logloss: 0.368164
# [527]	valid_0's binary_logloss: 0.368115
# [528]	valid_0's binary_logloss: 0.36808
# [529]	valid_0's binary_logloss: 0.368017
# [530]	valid_0's binary_logloss: 0.367983
# [531]	valid_0's binary_logloss: 0.367939
# [532]	valid_0's binary_logloss: 0.36789
# [533]	valid_0's binary_logloss: 0.367867
# [534]	valid_0's binary_logloss: 0.367811
# [535]	valid_0's binary_logloss: 0.367756
# [536]	valid_0's binary_logloss: 0.367712
# [537]	valid_0's binary_logloss: 0.367693
# [538]	valid_0's binary_logloss: 0.367661
# [539]	valid_0's binary_logloss: 0.367628
# [540]	valid_0's binary_logloss: 0.367601
# [541]	valid_0's binary_logloss: 0.36757
# [542]	valid_0's binary_logloss: 0.367547
# [543]	valid_0's binary_logloss: 0.367501
# [544]	valid_0's binary_logloss: 0.367462
# [545]	valid_0's binary_logloss: 0.367383
# [546]	valid_0's binary_logloss: 0.367302
# [547]	valid_0's binary_logloss: 0.36726
# [548]	valid_0's binary_logloss: 0.36717
# [549]	valid_0's binary_logloss: 0.36712
# [550]	valid_0's binary_logloss: 0.367091
# [551]	valid_0's binary_logloss: 0.36705
# [552]	valid_0's binary_logloss: 0.367018
# [553]	valid_0's binary_logloss: 0.366985
# [554]	valid_0's binary_logloss: 0.366907
# [555]	valid_0's binary_logloss: 0.366858
# [556]	valid_0's binary_logloss: 0.366819
# [557]	valid_0's binary_logloss: 0.366782
# [558]	valid_0's binary_logloss: 0.366729
# [559]	valid_0's binary_logloss: 0.366683
# [560]	valid_0's binary_logloss: 0.366621
# [561]	valid_0's binary_logloss: 0.366583
# [562]	valid_0's binary_logloss: 0.366539
# [563]	valid_0's binary_logloss: 0.366507
# [564]	valid_0's binary_logloss: 0.366454
# [565]	valid_0's binary_logloss: 0.366396
# [566]	valid_0's binary_logloss: 0.366338
# [567]	valid_0's binary_logloss: 0.366286
# [568]	valid_0's binary_logloss: 0.36623
# [569]	valid_0's binary_logloss: 0.366189
# [570]	valid_0's binary_logloss: 0.366142
# [571]	valid_0's binary_logloss: 0.366106
# [572]	valid_0's binary_logloss: 0.366071
# [573]	valid_0's binary_logloss: 0.366036
# [574]	valid_0's binary_logloss: 0.365979
# [575]	valid_0's binary_logloss: 0.365947
# [576]	valid_0's binary_logloss: 0.365906
# [577]	valid_0's binary_logloss: 0.365869
# [578]	valid_0's binary_logloss: 0.365857
# [579]	valid_0's binary_logloss: 0.365817
# [580]	valid_0's binary_logloss: 0.36578
# [581]	valid_0's binary_logloss: 0.365753
# [582]	valid_0's binary_logloss: 0.365736
# [583]	valid_0's binary_logloss: 0.365702
# [584]	valid_0's binary_logloss: 0.365675
# [585]	valid_0's binary_logloss: 0.36564
# [586]	valid_0's binary_logloss: 0.365621
# [587]	valid_0's binary_logloss: 0.365594
# [588]	valid_0's binary_logloss: 0.365569
# [589]	valid_0's binary_logloss: 0.36555
# [590]	valid_0's binary_logloss: 0.365491
# [591]	valid_0's binary_logloss: 0.365459
# [592]	valid_0's binary_logloss: 0.365435
# [593]	valid_0's binary_logloss: 0.365387
# [594]	valid_0's binary_logloss: 0.365341
# [595]	valid_0's binary_logloss: 0.365309
# [596]	valid_0's binary_logloss: 0.36527
# [597]	valid_0's binary_logloss: 0.36524
# [598]	valid_0's binary_logloss: 0.365199
# [599]	valid_0's binary_logloss: 0.365161
# [600]	valid_0's binary_logloss: 0.365132
# [601]	valid_0's binary_logloss: 0.36509
# [602]	valid_0's binary_logloss: 0.365068
# [603]	valid_0's binary_logloss: 0.365033
# [604]	valid_0's binary_logloss: 0.365004
# [605]	valid_0's binary_logloss: 0.364976
# [606]	valid_0's binary_logloss: 0.364928
# [607]	valid_0's binary_logloss: 0.364894
# [608]	valid_0's binary_logloss: 0.364864
# [609]	valid_0's binary_logloss: 0.364851
# [610]	valid_0's binary_logloss: 0.364805
# [611]	valid_0's binary_logloss: 0.364775
# [612]	valid_0's binary_logloss: 0.364743
# [613]	valid_0's binary_logloss: 0.364714
# [614]	valid_0's binary_logloss: 0.364688
# [615]	valid_0's binary_logloss: 0.364663
# [616]	valid_0's binary_logloss: 0.364605
# [617]	valid_0's binary_logloss: 0.364562
# [618]	valid_0's binary_logloss: 0.364524
# [619]	valid_0's binary_logloss: 0.364486
# [620]	valid_0's binary_logloss: 0.364462
# [621]	valid_0's binary_logloss: 0.364432
# [622]	valid_0's binary_logloss: 0.364386
# [623]	valid_0's binary_logloss: 0.364371
# [624]	valid_0's binary_logloss: 0.364355
# [625]	valid_0's binary_logloss: 0.364323
# [626]	valid_0's binary_logloss: 0.36429
# [627]	valid_0's binary_logloss: 0.364246
# [628]	valid_0's binary_logloss: 0.364234
# [629]	valid_0's binary_logloss: 0.364194
# [630]	valid_0's binary_logloss: 0.364171
# [631]	valid_0's binary_logloss: 0.364142
# [632]	valid_0's binary_logloss: 0.364081
# [633]	valid_0's binary_logloss: 0.364045
# [634]	valid_0's binary_logloss: 0.364029
# [635]	valid_0's binary_logloss: 0.363985
# [636]	valid_0's binary_logloss: 0.363952
# [637]	valid_0's binary_logloss: 0.363928
# [638]	valid_0's binary_logloss: 0.363891
# [639]	valid_0's binary_logloss: 0.363851
# [640]	valid_0's binary_logloss: 0.36384
# [641]	valid_0's binary_logloss: 0.363784
# [642]	valid_0's binary_logloss: 0.363709
# [643]	valid_0's binary_logloss: 0.363693
# [644]	valid_0's binary_logloss: 0.363649
# [645]	valid_0's binary_logloss: 0.363631
# [646]	valid_0's binary_logloss: 0.36361
# [647]	valid_0's binary_logloss: 0.363564
# [648]	valid_0's binary_logloss: 0.363538
# [649]	valid_0's binary_logloss: 0.363524
# [650]	valid_0's binary_logloss: 0.363495
# [651]	valid_0's binary_logloss: 0.363471
# [652]	valid_0's binary_logloss: 0.36343
# [653]	valid_0's binary_logloss: 0.363408
# [654]	valid_0's binary_logloss: 0.363393
# [655]	valid_0's binary_logloss: 0.363342
# [656]	valid_0's binary_logloss: 0.363295
# [657]	valid_0's binary_logloss: 0.363269
# [658]	valid_0's binary_logloss: 0.363245
# [659]	valid_0's binary_logloss: 0.363196
# [660]	valid_0's binary_logloss: 0.363182
# [661]	valid_0's binary_logloss: 0.363161
# [662]	valid_0's binary_logloss: 0.363134
# [663]	valid_0's binary_logloss: 0.363058
# [664]	valid_0's binary_logloss: 0.363041
# [665]	valid_0's binary_logloss: 0.363022
# [666]	valid_0's binary_logloss: 0.362998
# [667]	valid_0's binary_logloss: 0.362949
# [668]	valid_0's binary_logloss: 0.362934
# [669]	valid_0's binary_logloss: 0.362913
# [670]	valid_0's binary_logloss: 0.362861
# [671]	valid_0's binary_logloss: 0.362814
# [672]	valid_0's binary_logloss: 0.362796
# [673]	valid_0's binary_logloss: 0.362765
# [674]	valid_0's binary_logloss: 0.362693
# [675]	valid_0's binary_logloss: 0.362653
# [676]	valid_0's binary_logloss: 0.362643
# [677]	valid_0's binary_logloss: 0.362624
# [678]	valid_0's binary_logloss: 0.362603
# [679]	valid_0's binary_logloss: 0.362567
# [680]	valid_0's binary_logloss: 0.36255
# [681]	valid_0's binary_logloss: 0.362513
# [682]	valid_0's binary_logloss: 0.362475
# [683]	valid_0's binary_logloss: 0.362445
# [684]	valid_0's binary_logloss: 0.362407
# [685]	valid_0's binary_logloss: 0.362372
# [686]	valid_0's binary_logloss: 0.362342
# [687]	valid_0's binary_logloss: 0.362328
# [688]	valid_0's binary_logloss: 0.362312
# [689]	valid_0's binary_logloss: 0.362286
# [690]	valid_0's binary_logloss: 0.362252
# [691]	valid_0's binary_logloss: 0.362242
# [692]	valid_0's binary_logloss: 0.362205
# [693]	valid_0's binary_logloss: 0.362167
# [694]	valid_0's binary_logloss: 0.362148
# [695]	valid_0's binary_logloss: 0.362107
# [696]	valid_0's binary_logloss: 0.362035
# [697]	valid_0's binary_logloss: 0.362009
# [698]	valid_0's binary_logloss: 0.361991
# [699]	valid_0's binary_logloss: 0.361971
# [700]	valid_0's binary_logloss: 0.361951
# [701]	valid_0's binary_logloss: 0.36192
# [702]	valid_0's binary_logloss: 0.361903
# [703]	valid_0's binary_logloss: 0.361889
# [704]	valid_0's binary_logloss: 0.361871
# [705]	valid_0's binary_logloss: 0.361859
# [706]	valid_0's binary_logloss: 0.361841
# [707]	valid_0's binary_logloss: 0.361795
# [708]	valid_0's binary_logloss: 0.361769
# [709]	valid_0's binary_logloss: 0.361739
# [710]	valid_0's binary_logloss: 0.36169
# [711]	valid_0's binary_logloss: 0.361637
# [712]	valid_0's binary_logloss: 0.361613
# [713]	valid_0's binary_logloss: 0.361565
# [714]	valid_0's binary_logloss: 0.361517
# [715]	valid_0's binary_logloss: 0.361493
# [716]	valid_0's binary_logloss: 0.361474
# [717]	valid_0's binary_logloss: 0.361446
# [718]	valid_0's binary_logloss: 0.361412
# [719]	valid_0's binary_logloss: 0.361397
# [720]	valid_0's binary_logloss: 0.361372
# [721]	valid_0's binary_logloss: 0.361341
# [722]	valid_0's binary_logloss: 0.361299
# [723]	valid_0's binary_logloss: 0.361265
# [724]	valid_0's binary_logloss: 0.361235
# [725]	valid_0's binary_logloss: 0.361201
# [726]	valid_0's binary_logloss: 0.361169
# [727]	valid_0's binary_logloss: 0.361126
# [728]	valid_0's binary_logloss: 0.361072
# [729]	valid_0's binary_logloss: 0.361045
# [730]	valid_0's binary_logloss: 0.36102
# [731]	valid_0's binary_logloss: 0.360969
# [732]	valid_0's binary_logloss: 0.360949
# [733]	valid_0's binary_logloss: 0.360903
# [734]	valid_0's binary_logloss: 0.360896
# [735]	valid_0's binary_logloss: 0.360831
# [736]	valid_0's binary_logloss: 0.360772
# [737]	valid_0's binary_logloss: 0.360745
# [738]	valid_0's binary_logloss: 0.360734
# [739]	valid_0's binary_logloss: 0.360718
# [740]	valid_0's binary_logloss: 0.360677
# [741]	valid_0's binary_logloss: 0.36065
# [742]	valid_0's binary_logloss: 0.360589
# [743]	valid_0's binary_logloss: 0.360573
# [744]	valid_0's binary_logloss: 0.36053
# [745]	valid_0's binary_logloss: 0.36049
# [746]	valid_0's binary_logloss: 0.360456
# [747]	valid_0's binary_logloss: 0.36044
# [748]	valid_0's binary_logloss: 0.360402
# [749]	valid_0's binary_logloss: 0.360375
# [750]	valid_0's binary_logloss: 0.360356
# [751]	valid_0's binary_logloss: 0.360295
# [752]	valid_0's binary_logloss: 0.360252
# [753]	valid_0's binary_logloss: 0.360205
# [754]	valid_0's binary_logloss: 0.360191
# [755]	valid_0's binary_logloss: 0.360135
# [756]	valid_0's binary_logloss: 0.360103
# [757]	valid_0's binary_logloss: 0.360066
# [758]	valid_0's binary_logloss: 0.360052
# [759]	valid_0's binary_logloss: 0.360042
# [760]	valid_0's binary_logloss: 0.35997
# [761]	valid_0's binary_logloss: 0.359907
# [762]	valid_0's binary_logloss: 0.359891
# [763]	valid_0's binary_logloss: 0.359862
# [764]	valid_0's binary_logloss: 0.359833
# [765]	valid_0's binary_logloss: 0.359758
# [766]	valid_0's binary_logloss: 0.359745
# [767]	valid_0's binary_logloss: 0.359728
# [768]	valid_0's binary_logloss: 0.359678
# [769]	valid_0's binary_logloss: 0.359656
# [770]	valid_0's binary_logloss: 0.359608
# [771]	valid_0's binary_logloss: 0.359587
# [772]	valid_0's binary_logloss: 0.359564
# [773]	valid_0's binary_logloss: 0.359532
# [774]	valid_0's binary_logloss: 0.359515
# [775]	valid_0's binary_logloss: 0.359509
# [776]	valid_0's binary_logloss: 0.359479
# [777]	valid_0's binary_logloss: 0.359455
# [778]	valid_0's binary_logloss: 0.359418
# [779]	valid_0's binary_logloss: 0.35939
# [780]	valid_0's binary_logloss: 0.359347
# [781]	valid_0's binary_logloss: 0.359325
# [782]	valid_0's binary_logloss: 0.359305
# [783]	valid_0's binary_logloss: 0.35928
# [784]	valid_0's binary_logloss: 0.359253
# [785]	valid_0's binary_logloss: 0.359221
# [786]	valid_0's binary_logloss: 0.359198
# [787]	valid_0's binary_logloss: 0.359119
# [788]	valid_0's binary_logloss: 0.359066
# [789]	valid_0's binary_logloss: 0.359018
# [790]	valid_0's binary_logloss: 0.359002
# [791]	valid_0's binary_logloss: 0.358892
# [792]	valid_0's binary_logloss: 0.358881
# [793]	valid_0's binary_logloss: 0.358859
# [794]	valid_0's binary_logloss: 0.358845
# [795]	valid_0's binary_logloss: 0.358817
# [796]	valid_0's binary_logloss: 0.358775
# [797]	valid_0's binary_logloss: 0.358744
# [798]	valid_0's binary_logloss: 0.358711
# [799]	valid_0's binary_logloss: 0.358692
# [800]	valid_0's binary_logloss: 0.35865
# [801]	valid_0's binary_logloss: 0.358626
# [802]	valid_0's binary_logloss: 0.358606
# [803]	valid_0's binary_logloss: 0.358582
# [804]	valid_0's binary_logloss: 0.358566
# [805]	valid_0's binary_logloss: 0.358509
# [806]	valid_0's binary_logloss: 0.358461
# [807]	valid_0's binary_logloss: 0.358441
# [808]	valid_0's binary_logloss: 0.358437
# [809]	valid_0's binary_logloss: 0.358421
# [810]	valid_0's binary_logloss: 0.358397
# [811]	valid_0's binary_logloss: 0.358381
# [812]	valid_0's binary_logloss: 0.358326
# [813]	valid_0's binary_logloss: 0.358298
# [814]	valid_0's binary_logloss: 0.358251
# [815]	valid_0's binary_logloss: 0.358205
# [816]	valid_0's binary_logloss: 0.358173
# [817]	valid_0's binary_logloss: 0.358152
# [818]	valid_0's binary_logloss: 0.358104
# [819]	valid_0's binary_logloss: 0.35807
# [820]	valid_0's binary_logloss: 0.358014
# [821]	valid_0's binary_logloss: 0.357981
# [822]	valid_0's binary_logloss: 0.357972
# [823]	valid_0's binary_logloss: 0.357917
# [824]	valid_0's binary_logloss: 0.357886
# [825]	valid_0's binary_logloss: 0.35788
# [826]	valid_0's binary_logloss: 0.357863
# [827]	valid_0's binary_logloss: 0.35782
# [828]	valid_0's binary_logloss: 0.357783
# [829]	valid_0's binary_logloss: 0.357776
# [830]	valid_0's binary_logloss: 0.357677
# [831]	valid_0's binary_logloss: 0.35766
# [832]	valid_0's binary_logloss: 0.357636
# [833]	valid_0's binary_logloss: 0.357629
# [834]	valid_0's binary_logloss: 0.357562
# [835]	valid_0's binary_logloss: 0.357539
# [836]	valid_0's binary_logloss: 0.357526
# [837]	valid_0's binary_logloss: 0.357502
# [838]	valid_0's binary_logloss: 0.357483
# [839]	valid_0's binary_logloss: 0.357474
# [840]	valid_0's binary_logloss: 0.357464
# [841]	valid_0's binary_logloss: 0.357412
# [842]	valid_0's binary_logloss: 0.357342
# [843]	valid_0's binary_logloss: 0.357292
# [844]	valid_0's binary_logloss: 0.357267
# [845]	valid_0's binary_logloss: 0.357231
# [846]	valid_0's binary_logloss: 0.357161
# [847]	valid_0's binary_logloss: 0.357138
# [848]	valid_0's binary_logloss: 0.357133
# [849]	valid_0's binary_logloss: 0.357115
# [850]	valid_0's binary_logloss: 0.357103
# [851]	valid_0's binary_logloss: 0.357087
# [852]	valid_0's binary_logloss: 0.357067
# [853]	valid_0's binary_logloss: 0.356983
# [854]	valid_0's binary_logloss: 0.356944
# [855]	valid_0's binary_logloss: 0.356842
# [856]	valid_0's binary_logloss: 0.356833
# [857]	valid_0's binary_logloss: 0.356764
# [858]	valid_0's binary_logloss: 0.356737
# [859]	valid_0's binary_logloss: 0.356718
# [860]	valid_0's binary_logloss: 0.356648
# [861]	valid_0's binary_logloss: 0.35663
# [862]	valid_0's binary_logloss: 0.35662
# [863]	valid_0's binary_logloss: 0.356523
# [864]	valid_0's binary_logloss: 0.356506
# [865]	valid_0's binary_logloss: 0.356495
# [866]	valid_0's binary_logloss: 0.356456
# [867]	valid_0's binary_logloss: 0.356443
# [868]	valid_0's binary_logloss: 0.356386
# [869]	valid_0's binary_logloss: 0.356357
# [870]	valid_0's binary_logloss: 0.356333
# [871]	valid_0's binary_logloss: 0.356262
# [872]	valid_0's binary_logloss: 0.356211
# [873]	valid_0's binary_logloss: 0.356172
# [874]	valid_0's binary_logloss: 0.356068
# [875]	valid_0's binary_logloss: 0.35601
# [876]	valid_0's binary_logloss: 0.355997
# [877]	valid_0's binary_logloss: 0.355982
# [878]	valid_0's binary_logloss: 0.35596
# [879]	valid_0's binary_logloss: 0.355931
# [880]	valid_0's binary_logloss: 0.355897
# [881]	valid_0's binary_logloss: 0.35587
# [882]	valid_0's binary_logloss: 0.355841
# [883]	valid_0's binary_logloss: 0.355812
# [884]	valid_0's binary_logloss: 0.355768
# [885]	valid_0's binary_logloss: 0.35574
# [886]	valid_0's binary_logloss: 0.355698
# [887]	valid_0's binary_logloss: 0.35565
# [888]	valid_0's binary_logloss: 0.355622
# [889]	valid_0's binary_logloss: 0.355617
# [890]	valid_0's binary_logloss: 0.35559
# [891]	valid_0's binary_logloss: 0.355579
# [892]	valid_0's binary_logloss: 0.355555
# [893]	valid_0's binary_logloss: 0.355523
# [894]	valid_0's binary_logloss: 0.35544
# [895]	valid_0's binary_logloss: 0.355397
# [896]	valid_0's binary_logloss: 0.35535
# [897]	valid_0's binary_logloss: 0.355327
# [898]	valid_0's binary_logloss: 0.355296
# [899]	valid_0's binary_logloss: 0.355238
# [900]	valid_0's binary_logloss: 0.355223
# [901]	valid_0's binary_logloss: 0.355148
# [902]	valid_0's binary_logloss: 0.355142
# [903]	valid_0's binary_logloss: 0.355073
# [904]	valid_0's binary_logloss: 0.355033
# [905]	valid_0's binary_logloss: 0.355019
# [906]	valid_0's binary_logloss: 0.354995
# [907]	valid_0's binary_logloss: 0.354951
# [908]	valid_0's binary_logloss: 0.35488
# [909]	valid_0's binary_logloss: 0.354872
# [910]	valid_0's binary_logloss: 0.354858
# [911]	valid_0's binary_logloss: 0.354818
# [912]	valid_0's binary_logloss: 0.354773
# [913]	valid_0's binary_logloss: 0.354746
# [914]	valid_0's binary_logloss: 0.354713
# [915]	valid_0's binary_logloss: 0.354639
# [916]	valid_0's binary_logloss: 0.354592
# [917]	valid_0's binary_logloss: 0.354533
# [918]	valid_0's binary_logloss: 0.354518
# [919]	valid_0's binary_logloss: 0.354499
# [920]	valid_0's binary_logloss: 0.354467
# [921]	valid_0's binary_logloss: 0.354417
# [922]	valid_0's binary_logloss: 0.354352
# [923]	valid_0's binary_logloss: 0.354285
# [924]	valid_0's binary_logloss: 0.354265
# [925]	valid_0's binary_logloss: 0.354251
# [926]	valid_0's binary_logloss: 0.354204
# [927]	valid_0's binary_logloss: 0.354157
# [928]	valid_0's binary_logloss: 0.354135
# [929]	valid_0's binary_logloss: 0.354121
# [930]	valid_0's binary_logloss: 0.354099
# [931]	valid_0's binary_logloss: 0.354062
# [932]	valid_0's binary_logloss: 0.354031
# [933]	valid_0's binary_logloss: 0.353985
# [934]	valid_0's binary_logloss: 0.353957
# [935]	valid_0's binary_logloss: 0.353919
# [936]	valid_0's binary_logloss: 0.353893
# [937]	valid_0's binary_logloss: 0.35386
# [938]	valid_0's binary_logloss: 0.353829
# [939]	valid_0's binary_logloss: 0.353789
# [940]	valid_0's binary_logloss: 0.353771
# [941]	valid_0's binary_logloss: 0.353746
# [942]	valid_0's binary_logloss: 0.353727
# [943]	valid_0's binary_logloss: 0.353703
# [944]	valid_0's binary_logloss: 0.353686
# [945]	valid_0's binary_logloss: 0.35362
# [946]	valid_0's binary_logloss: 0.353612
# [947]	valid_0's binary_logloss: 0.353582
# [948]	valid_0's binary_logloss: 0.353533
# [949]	valid_0's binary_logloss: 0.353513
# [950]	valid_0's binary_logloss: 0.353482
# [951]	valid_0's binary_logloss: 0.353464
# [952]	valid_0's binary_logloss: 0.353412
# [953]	valid_0's binary_logloss: 0.353391
# [954]	valid_0's binary_logloss: 0.353342
# [955]	valid_0's binary_logloss: 0.353286
# [956]	valid_0's binary_logloss: 0.353263
# [957]	valid_0's binary_logloss: 0.353208
# [958]	valid_0's binary_logloss: 0.353165
# [959]	valid_0's binary_logloss: 0.353144
# [960]	valid_0's binary_logloss: 0.353087
# [961]	valid_0's binary_logloss: 0.353035
# [962]	valid_0's binary_logloss: 0.353018
# [963]	valid_0's binary_logloss: 0.353009
# [964]	valid_0's binary_logloss: 0.352985
# [965]	valid_0's binary_logloss: 0.352973
# [966]	valid_0's binary_logloss: 0.352966
# [967]	valid_0's binary_logloss: 0.352942
# [968]	valid_0's binary_logloss: 0.352935
# [969]	valid_0's binary_logloss: 0.352879
# [970]	valid_0's binary_logloss: 0.352862
# [971]	valid_0's binary_logloss: 0.352807
# [972]	valid_0's binary_logloss: 0.352759
# [973]	valid_0's binary_logloss: 0.352754
# [974]	valid_0's binary_logloss: 0.352744
# [975]	valid_0's binary_logloss: 0.352726
# [976]	valid_0's binary_logloss: 0.352722
# [977]	valid_0's binary_logloss: 0.352704
# [978]	valid_0's binary_logloss: 0.352633
# [979]	valid_0's binary_logloss: 0.352603
# [980]	valid_0's binary_logloss: 0.352547
# [981]	valid_0's binary_logloss: 0.352531
# [982]	valid_0's binary_logloss: 0.352519
# [983]	valid_0's binary_logloss: 0.352508
# [984]	valid_0's binary_logloss: 0.3525
# [985]	valid_0's binary_logloss: 0.35248
# [986]	valid_0's binary_logloss: 0.352466
# [987]	valid_0's binary_logloss: 0.352461
# [988]	valid_0's binary_logloss: 0.352428
# [989]	valid_0's binary_logloss: 0.352402
# [990]	valid_0's binary_logloss: 0.352395
# [991]	valid_0's binary_logloss: 0.352358
# [992]	valid_0's binary_logloss: 0.352338
# [993]	valid_0's binary_logloss: 0.352252
# [994]	valid_0's binary_logloss: 0.3522
# [995]	valid_0's binary_logloss: 0.352164
# [996]	valid_0's binary_logloss: 0.352149
# [997]	valid_0's binary_logloss: 0.352123
# [998]	valid_0's binary_logloss: 0.352098
# [999]	valid_0's binary_logloss: 0.352087
# [1000]	valid_0's binary_logloss: 0.352057
# [1001]	valid_0's binary_logloss: 0.352016
# [1002]	valid_0's binary_logloss: 0.351989
# [1003]	valid_0's binary_logloss: 0.35195
# [1004]	valid_0's binary_logloss: 0.351936
# [1005]	valid_0's binary_logloss: 0.351912
# [1006]	valid_0's binary_logloss: 0.35191
# [1007]	valid_0's binary_logloss: 0.351878
# [1008]	valid_0's binary_logloss: 0.351838
# [1009]	valid_0's binary_logloss: 0.351792
# [1010]	valid_0's binary_logloss: 0.351788
# [1011]	valid_0's binary_logloss: 0.351754
# [1012]	valid_0's binary_logloss: 0.351705
# [1013]	valid_0's binary_logloss: 0.351678
# [1014]	valid_0's binary_logloss: 0.351644
# [1015]	valid_0's binary_logloss: 0.351607
# [1016]	valid_0's binary_logloss: 0.351595
# [1017]	valid_0's binary_logloss: 0.351571
# [1018]	valid_0's binary_logloss: 0.351485
# [1019]	valid_0's binary_logloss: 0.351427
# [1020]	valid_0's binary_logloss: 0.351382
# [1021]	valid_0's binary_logloss: 0.351359
# [1022]	valid_0's binary_logloss: 0.35133
# [1023]	valid_0's binary_logloss: 0.351308
# [1024]	valid_0's binary_logloss: 0.351265
# [1025]	valid_0's binary_logloss: 0.351249
# [1026]	valid_0's binary_logloss: 0.351229
# [1027]	valid_0's binary_logloss: 0.351218
# [1028]	valid_0's binary_logloss: 0.351148
# [1029]	valid_0's binary_logloss: 0.35114
# [1030]	valid_0's binary_logloss: 0.351119
# [1031]	valid_0's binary_logloss: 0.351103
# [1032]	valid_0's binary_logloss: 0.351095
# [1033]	valid_0's binary_logloss: 0.351067
# [1034]	valid_0's binary_logloss: 0.351053
# [1035]	valid_0's binary_logloss: 0.351032
# [1036]	valid_0's binary_logloss: 0.35101
# [1037]	valid_0's binary_logloss: 0.350942
# [1038]	valid_0's binary_logloss: 0.350902
# [1039]	valid_0's binary_logloss: 0.350891
# [1040]	valid_0's binary_logloss: 0.350876
# [1041]	valid_0's binary_logloss: 0.350844
# [1042]	valid_0's binary_logloss: 0.350817
# [1043]	valid_0's binary_logloss: 0.350792
# [1044]	valid_0's binary_logloss: 0.350788
# [1045]	valid_0's binary_logloss: 0.350777
# [1046]	valid_0's binary_logloss: 0.350755
# [1047]	valid_0's binary_logloss: 0.3507
# [1048]	valid_0's binary_logloss: 0.350684
# [1049]	valid_0's binary_logloss: 0.350636
# [1050]	valid_0's binary_logloss: 0.350619
# [1051]	valid_0's binary_logloss: 0.350595
# [1052]	valid_0's binary_logloss: 0.350545
# [1053]	valid_0's binary_logloss: 0.350521
# [1054]	valid_0's binary_logloss: 0.350497
# [1055]	valid_0's binary_logloss: 0.350453
# [1056]	valid_0's binary_logloss: 0.350441
# [1057]	valid_0's binary_logloss: 0.3504
# [1058]	valid_0's binary_logloss: 0.350379
# [1059]	valid_0's binary_logloss: 0.350358
# [1060]	valid_0's binary_logloss: 0.350323
# [1061]	valid_0's binary_logloss: 0.350287
# [1062]	valid_0's binary_logloss: 0.350241
# [1063]	valid_0's binary_logloss: 0.350219
# [1064]	valid_0's binary_logloss: 0.350184
# [1065]	valid_0's binary_logloss: 0.350152
# [1066]	valid_0's binary_logloss: 0.350129
# [1067]	valid_0's binary_logloss: 0.350118
# [1068]	valid_0's binary_logloss: 0.350082
# [1069]	valid_0's binary_logloss: 0.350043
# [1070]	valid_0's binary_logloss: 0.350038
# [1071]	valid_0's binary_logloss: 0.350021
# [1072]	valid_0's binary_logloss: 0.350011
# [1073]	valid_0's binary_logloss: 0.349987
# [1074]	valid_0's binary_logloss: 0.349969
# [1075]	valid_0's binary_logloss: 0.349953
# [1076]	valid_0's binary_logloss: 0.349934
# [1077]	valid_0's binary_logloss: 0.349906
# [1078]	valid_0's binary_logloss: 0.349894
# [1079]	valid_0's binary_logloss: 0.349858
# [1080]	valid_0's binary_logloss: 0.349812
# [1081]	valid_0's binary_logloss: 0.349798
# [1082]	valid_0's binary_logloss: 0.349757
# [1083]	valid_0's binary_logloss: 0.349737
# [1084]	valid_0's binary_logloss: 0.349713
# [1085]	valid_0's binary_logloss: 0.349681
# [1086]	valid_0's binary_logloss: 0.349641
# [1087]	valid_0's binary_logloss: 0.349633
# [1088]	valid_0's binary_logloss: 0.349618
# [1089]	valid_0's binary_logloss: 0.349595
# [1090]	valid_0's binary_logloss: 0.349568
# [1091]	valid_0's binary_logloss: 0.349552
# [1092]	valid_0's binary_logloss: 0.349543
# [1093]	valid_0's binary_logloss: 0.349538
# [1094]	valid_0's binary_logloss: 0.349512
# [1095]	valid_0's binary_logloss: 0.349467
# [1096]	valid_0's binary_logloss: 0.349461
# [1097]	valid_0's binary_logloss: 0.349452
# [1098]	valid_0's binary_logloss: 0.349422
# [1099]	valid_0's binary_logloss: 0.349408
# [1100]	valid_0's binary_logloss: 0.349365
# [1101]	valid_0's binary_logloss: 0.349351
# [1102]	valid_0's binary_logloss: 0.349322
# [1103]	valid_0's binary_logloss: 0.349313
# [1104]	valid_0's binary_logloss: 0.34928
# [1105]	valid_0's binary_logloss: 0.349257
# [1106]	valid_0's binary_logloss: 0.349214
# [1107]	valid_0's binary_logloss: 0.349209
# [1108]	valid_0's binary_logloss: 0.349198
# [1109]	valid_0's binary_logloss: 0.349165
# [1110]	valid_0's binary_logloss: 0.349128
# [1111]	valid_0's binary_logloss: 0.349078
# [1112]	valid_0's binary_logloss: 0.349071
# [1113]	valid_0's binary_logloss: 0.349055
# [1114]	valid_0's binary_logloss: 0.349024
# [1115]	valid_0's binary_logloss: 0.349018
# [1116]	valid_0's binary_logloss: 0.348965
# [1117]	valid_0's binary_logloss: 0.348943
# [1118]	valid_0's binary_logloss: 0.34892
# [1119]	valid_0's binary_logloss: 0.348862
# [1120]	valid_0's binary_logloss: 0.348846
# [1121]	valid_0's binary_logloss: 0.348839
# [1122]	valid_0's binary_logloss: 0.348792
# [1123]	valid_0's binary_logloss: 0.348788
# [1124]	valid_0's binary_logloss: 0.348774
# [1125]	valid_0's binary_logloss: 0.348745
# [1126]	valid_0's binary_logloss: 0.348726
# [1127]	valid_0's binary_logloss: 0.348687
# [1128]	valid_0's binary_logloss: 0.348672
# [1129]	valid_0's binary_logloss: 0.348666
# [1130]	valid_0's binary_logloss: 0.348651
# [1131]	valid_0's binary_logloss: 0.348628
# [1132]	valid_0's binary_logloss: 0.348611
# [1133]	valid_0's binary_logloss: 0.34858
# [1134]	valid_0's binary_logloss: 0.348559
# [1135]	valid_0's binary_logloss: 0.348547
# [1136]	valid_0's binary_logloss: 0.34854
# [1137]	valid_0's binary_logloss: 0.348523
# [1138]	valid_0's binary_logloss: 0.348517
# [1139]	valid_0's binary_logloss: 0.348486
# [1140]	valid_0's binary_logloss: 0.348449
# [1141]	valid_0's binary_logloss: 0.348421
# [1142]	valid_0's binary_logloss: 0.348407
# [1143]	valid_0's binary_logloss: 0.348398
# [1144]	valid_0's binary_logloss: 0.348376
# [1145]	valid_0's binary_logloss: 0.348365
# [1146]	valid_0's binary_logloss: 0.348349
# [1147]	valid_0's binary_logloss: 0.348337
# [1148]	valid_0's binary_logloss: 0.348333
# [1149]	valid_0's binary_logloss: 0.348305
# [1150]	valid_0's binary_logloss: 0.348258
# [1151]	valid_0's binary_logloss: 0.348196
# [1152]	valid_0's binary_logloss: 0.348187
# [1153]	valid_0's binary_logloss: 0.34814
# [1154]	valid_0's binary_logloss: 0.348123
# [1155]	valid_0's binary_logloss: 0.348082
# [1156]	valid_0's binary_logloss: 0.348053
# [1157]	valid_0's binary_logloss: 0.348035
# [1158]	valid_0's binary_logloss: 0.348029
# [1159]	valid_0's binary_logloss: 0.347996
# [1160]	valid_0's binary_logloss: 0.347972
# [1161]	valid_0's binary_logloss: 0.347954
# [1162]	valid_0's binary_logloss: 0.347924
# [1163]	valid_0's binary_logloss: 0.347913
# [1164]	valid_0's binary_logloss: 0.347899
# [1165]	valid_0's binary_logloss: 0.347879
# [1166]	valid_0's binary_logloss: 0.34784
# [1167]	valid_0's binary_logloss: 0.347823
# [1168]	valid_0's binary_logloss: 0.34776
# [1169]	valid_0's binary_logloss: 0.347698
# [1170]	valid_0's binary_logloss: 0.347692
# [1171]	valid_0's binary_logloss: 0.347669
# [1172]	valid_0's binary_logloss: 0.347641
# [1173]	valid_0's binary_logloss: 0.347616
# [1174]	valid_0's binary_logloss: 0.347606
# [1175]	valid_0's binary_logloss: 0.347594
# [1176]	valid_0's binary_logloss: 0.347572
# [1177]	valid_0's binary_logloss: 0.34757
# [1178]	valid_0's binary_logloss: 0.347559
# [1179]	valid_0's binary_logloss: 0.347533
# [1180]	valid_0's binary_logloss: 0.347524
# [1181]	valid_0's binary_logloss: 0.347506
# [1182]	valid_0's binary_logloss: 0.347503
# [1183]	valid_0's binary_logloss: 0.347496
# [1184]	valid_0's binary_logloss: 0.347475
# [1185]	valid_0's binary_logloss: 0.347446
# [1186]	valid_0's binary_logloss: 0.347414
# [1187]	valid_0's binary_logloss: 0.347385
# [1188]	valid_0's binary_logloss: 0.347353
# [1189]	valid_0's binary_logloss: 0.347332
# [1190]	valid_0's binary_logloss: 0.347304
# [1191]	valid_0's binary_logloss: 0.347299
# [1192]	valid_0's binary_logloss: 0.34729
# [1193]	valid_0's binary_logloss: 0.347264
# [1194]	valid_0's binary_logloss: 0.347247
# [1195]	valid_0's binary_logloss: 0.34723
# [1196]	valid_0's binary_logloss: 0.347203
# [1197]	valid_0's binary_logloss: 0.347191
# [1198]	valid_0's binary_logloss: 0.347152
# [1199]	valid_0's binary_logloss: 0.347137
# [1200]	valid_0's binary_logloss: 0.347111
# Did not meet early stopping. Best iteration is:
# [1200]	valid_0's binary_logloss: 0.347111

# %%
from sklearn.metrics import roc_auc_score
x_final=x_test[features]
y_final=c.predict_proba(x_final)
y_pred=[]
for elem in y_final:
    y_pred.append(elem[1])
score=roc_auc_score(y_test, y_pred)
print(score)
# Out:
# 0.9175774168924725

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV22.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV22.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante        sexo   edad Doctorado Master  \
# 4427   65259  1112458667      pzjLoqb        MASC   21.0         -      -
# 82270  30568  1112378679        evY4W  NO_DECLARA  200.0         -      -
# 71415  16865  1112181382       YA8oOX         FEM   32.0         -      -
# 36560  74475  1112463746      ow5lAGr         FEM   24.0         -      -
# 8359   57757  1112451845      8MaZrWM        MASC   27.0         -      -
# 16263  69178  1112461143       NQeJjD         FEM   26.0         -      -
# 46776   2339  1111239880       6p6AlM        MASC   37.0         -      -
# 80353  55573  1112447934      JBm8eKp         FEM   28.0         -      -
# 11005  20983  1112264851      8MP9B6z         FEM   23.0         -      -
# 80493  27974  1112356532      vV9eExo        MASC   48.0         -      -
#
#       Otro Posgrado Secundario    ...    viajar empresa_importante  \
# 4427     -        -          -    ...     False              False
# 82270    -        -          -    ...     False              False
# 71415    -        -          -    ...     False              False
# 36560    -        -   Graduado    ...     False              False
# 8359     -        -   Graduado    ...     False              False
# 16263    -        -   Graduado    ...     False               True
# 46776    -        -   Graduado    ...     False              False
# 80353    -        -   Graduado    ...     False               True
# 11005    -        -          -    ...     False              False
# 80493    -        -   Graduado    ...     False               True
#
#       capacitacion remuneracion_pretendida graduados estudiantes  \
# 4427         False                   False     False       False
# 82270        False                   False     False       False
# 71415         True                   False      True        True
# 36560        False                   False     False       False
# 8359         False                   False     False       False
# 16263        False                   False     False       False
# 46776        False                   False     False       False
# 80353        False                   False     False       False
# 11005        False                   False     False       False
# 80493        False                   False      True       False
#
#       conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 4427                      False         False           False  0.000000
# 82270                      True         False            True  0.000000
# 71415                     False         False           False  0.000000
# 36560                      True         False            True  0.000000
# 8359                      False         False           False  0.071429
# 16263                     False         False           False  0.000000
# 46776                     False         False           False  0.000000
# 80353                     False         False           False  0.013699
# 11005                     False          True           False  0.016949
# 80493                     False         False           False  0.214286
#
# [10 rows x 36 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.9439482 , 0.0560518 ],
#        [0.8925479 , 0.1074521 ],
#        [0.91243139, 0.08756861],
#        ...,
#        [0.99566174, 0.00433826],
#        [0.99324857, 0.00675143],
#        [0.9984866 , 0.0015134 ]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     empresa_importante capacitacion  \
# 0   Graduado    ...                  False        False
# 1          -    ...                  False        False
# 2   Graduado    ...                  False        False
# 3   Graduado    ...                  False        False
# 4          -    ...                  False        False
#
#   remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 0                   False     False       False                     False
# 1                   False     False       False                     False
# 2                   False     False       False                     False
# 3                   False     False       False                     False
# 4                   False     False       False                     False
#
#   buen_ambiente discriminacion  cantidad  sepostulo
# 0         False          False       0.0   0.056052
# 1         False          False       0.0   0.107452
# 2         False          False       0.0   0.087569
# 3         False          False       0.0   0.014417
# 4         False          False       0.0   0.032841
#
# [5 rows x 37 columns]

# %%
prediccion=prediccion[['id','sepostulo']]
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.056052
# 1   1   0.107452
# 2   2   0.087569
# 3   3   0.014417
# 4   4   0.032841

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion46.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5088747302642473
