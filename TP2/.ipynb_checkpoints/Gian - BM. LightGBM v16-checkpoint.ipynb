# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas2=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas2=vistas2.rename(columns={'idAviso': 'idaviso'})
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
vistas=vistas.groupby(['idpostulante'],as_index=False).agg({'cantidad':'count'});
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#   idpostulante  cantidad
# 0        0002q        15
# 1        0005E        58
# 2        000R8        14
# 3        001XE        26
# 4        003k9        32

# %%
vistas2=pd.merge(vistas2,vistas,on='idpostulante',how='left')

# %%
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad_x  cantidad_y
# 0       18        BolNL           2          28
# 1    48375       RwVdKR           1          15
# 2   169730        1KjXB           2          99
# 3   169730       2AKzxa           2           2
# 4   169730        6LJ64           1          23

# %%
vistas2['cantidad']=vistas2['cantidad_x']/vistas2['cantidad_y']
vistas2.drop(['cantidad_x','cantidad_y'],axis=1,inplace=True)
vistas=vistas2
vistas2.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL  0.071429
# 1    48375       RwVdKR  0.066667
# 2   169730        1KjXB  0.020202
# 3   169730       2AKzxa  1.000000
# 4   169730        6LJ64  0.043478

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/7.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/8.csv").sample(len(postulaciones2)//2).reset_index(drop=True))
print(len(postulaciones2))
postulaciones2
# Out:
# 9906801
#             idaviso idpostulante  sepostulo
# 0        1112389495       5NbOjG          0
# 1        1112024109      1QP841b          0
# 2        1112490884      96XQ6N9          0
# 3        1111474259      qe2QJj1          0
# 4        1112211292      KBzbBJm          0
# 5        1112328485      3NzZv26          0
# 6        1112474766      akDjWwE          0
# 7        1112312385       aZpBJW          0
# 8        1112285628      akDWj55          0
# 9        1112322843      GNd0KNN          0
# 10       1112355899      DrXPRJX          0
# 11       1112461865      8MPoBDR          0
# 12       1111673413       a1NjRN          0
# 13       1112299006      jkVWXRQ          0
# 14       1112501771      owz0YGW          0
# 15       1002543409       Ej5AAb          0
# 16       1112425310      KBrpAO2          0
# 17       1112498569      pzNMppM          0
# 18       1111866251       ZKqL85          0
# 19       1112289529      ow2awXr          0
# 20       1112493109      5mP1DWM          0
# 21       1112326017      0zd9GZ9          0
# 22       1112242315      3NQKV6Q          0
# 23       1112452417      DrlVEwW          0
# 24       1112402816      mzdk9dZ          0
# 25       1112359100      3NP46xq          0
# 26       1112410555      bOVKA32          0
# 27       1112511403      mzdlAQO          0
# 28       1111272539      6rPpNM4          0
# 29       1111591317      6rP4K13          0
# ...             ...          ...        ...
# 3302237  1112283276       Y12Y4q          0
# 3302238  1112273698      1Q4b15j          0
# 3302239  1112437914      YjNbBrV          0
# 3302240  1112350693      1Qd28VE          0
# 3302241  1111912989      KBdQml0          0
# 3302242  1112415956      969DvXp          0
# 3302243  1112003384      wVkrR2L          0
# 3302244  1112198541      akjM41E          0
# 3302245  1110461839      YjlEdPV          0
# 3302246  1111797167      JBmDkdE          0
# 3302247  1112381646      rmezjzd          0
# 3302248  1112247256       8X006M          0
# 3302249  1112304029      6rPlbDj          0
# 3302250  1112470166      DrlJKaL          0
# 3302251  1112017183      zvaelWD          0
# 3302252  1112202158       1pj5pO          0
# 3302253  1112325260      96z3Oa9          0
# 3302254  1111463227      ak5RjOZ          0
# 3302255  1112485262      vVjaaY1          0
# 3302256  1112232119       Nx16Ml          0
# 3302257  1112017891       8w9vLl          0
# 3302258  1112255594      xkvz5Vb          0
# 3302259  1112356532      JBxj55O          0
# 3302260  1112286156      owzNo90          0
# 3302261  1112256054      mzb1DwO          0
# 3302262  1112249078      PmqMJDa          0
# 3302263  1112452772      4rPJpYP          0
# 3302264  1112353543       8lRxG3          0
# 3302265  1112440818      zvxr2d3          0
# 3302266  1112246086      MVrVONe          0
#
# [9906801 rows x 3 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 16511335
# 16502019

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo        sexo   edad Doctorado  \
# 5165194   1112266297       N12QNx          0        MASC   39.0         -
# 9353277   1112269758      PmGKP31          0         FEM   19.0         -
# 7553625   1112266386       YNE6rX          0         FEM   34.0         -
# 1909932   1112402512      xkPEobY          1        MASC   26.0         -
# 3607340   1112352459      4reQR5M          0         FEM   31.0         -
# 14317556  1112353640      ow5pwd4          0        MASC   25.0         -
# 10162264  1112280836      JBm0xOk          1        MASC   25.0         -
# 2876520   1112420476      wVkWWQL          0  NO_DECLARA  200.0         -
# 14670760  1112473287      GNJq0pE          0        MASC   24.0         -
# 1495506   1112372002       55ADjp          1         FEM   24.0         -
# 11475051  1112367904      Yj5eYrq          0         FEM   23.0         -
# 1167254   1112460061      jkjrawO          0         FEM   27.0         -
# 12272860  1112372019      rm0WJN9          1        MASC   51.0         -
# 2988797   1112334791      xkPXOWP          1        MASC   33.0         -
# 4496279   1112326068      X9lXLjK          1         FEM   25.0         -
# 13382807  1112047598      wVOmdxd          0        MASC   25.0         -
# 7816102   1112227518       aEMaV0          0         FEM   35.0         -
# 11123145  1112479826      xkv3BM6          0         FEM   36.0         -
# 4116332   1112366233       8kV03j          0        MASC   34.0         -
# 1834044   1112254124      8MBBRxR          0        MASC   31.0         -
#
#          Master Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 5165194       -    -         -          -    ...     False              False
# 9353277       -    -         -          -    ...     False               True
# 7553625       -    -  Graduado   Graduado    ...     False              False
# 1909932       -    -         -   Graduado    ...      True              False
# 3607340       -    -         -   Graduado    ...     False              False
# 14317556      -    -         -   Graduado    ...     False              False
# 10162264      -    -         -   Graduado    ...     False              False
# 2876520       -    -         -          -    ...     False              False
# 14670760      -    -         -   Graduado    ...     False              False
# 1495506       -    -         -          -    ...     False               True
# 11475051      -    -         -          -    ...     False               True
# 1167254       -    -  Graduado   Graduado    ...     False              False
# 12272860      -    -  Graduado   Graduado    ...     False              False
# 2988797       -    -         -   Graduado    ...     False              False
# 4496279       -    -         -   Graduado    ...     False              False
# 13382807      -    -         -   En Curso    ...     False              False
# 7816102       -    -         -   Graduado    ...     False              False
# 11123145      -    -         -   Graduado    ...     False              False
# 4116332       -    -         -   Graduado    ...     False              False
# 1834044       -    -         -   Graduado    ...     False               True
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 5165194          True                   False     False       False
# 9353277         False                   False     False       False
# 7553625         False                    True     False       False
# 1909932         False                   False     False       False
# 3607340         False                   False     False       False
# 14317556        False                   False     False       False
# 10162264        False                   False     False       False
# 2876520          True                   False     False       False
# 14670760         True                   False     False       False
# 1495506         False                   False      True       False
# 11475051        False                   False      True        True
# 1167254         False                   False     False       False
# 12272860        False                   False     False       False
# 2988797          True                   False     False       False
# 4496279         False                   False     False        True
# 13382807        False                   False     False       False
# 7816102         False                   False     False       False
# 11123145         True                   False     False       False
# 4116332         False                   False     False       False
# 1834044         False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 5165194                      False         False           False       NaN
# 9353277                      False         False           False       NaN
# 7553625                      False         False           False       NaN
# 1909932                      False         False           False  0.043478
# 3607340                      False         False           False       NaN
# 14317556                     False         False           False       NaN
# 10162264                     False         False           False       NaN
# 2876520                      False         False           False       NaN
# 14670760                     False         False           False       NaN
# 1495506                      False         False           False       NaN
# 11475051                     False         False           False       NaN
# 1167254                      False         False           False       NaN
# 12272860                     False          True           False  0.047619
# 2988797                      False          True           False       NaN
# 4496279                      False         False           False       NaN
# 13382807                     False         False           False       NaN
# 7816102                       True         False            True       NaN
# 11123145                     False         False           False       NaN
# 4116332                      False         False           False       NaN
# 1834044                      False         False           False       NaN
#
# [20 rows x 36 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 1561364   1112326333      2zP60rw          0  MASC  60.0         -      -
# 9093499   1111818090      MVPXqNL          1  MASC  36.0         -      -
# 5655219   1112335554      rmRoXl6          0  MASC  33.0         -      -
# 4643445   1112320432       695rA4          0   FEM  29.0         -      -
# 7527833   1110092958      LNKpr9r          1  MASC  26.0         -      -
# 9389654   1112335040      JBeQNPJ          1  MASC  30.0         -      -
# 2131598   1112204682      ZDP4olb          1  MASC  38.0         -      -
# 2459968   1112417700      2zkJ96w          0  MASC  31.0         -      -
# 15796146  1112473363      MVd00lN          0  MASC  39.0         -      -
# 12047360  1112395188      BmBPYAR          0   FEM  24.0         -      -
# 3756713   1112339832      owEW1W3          1  MASC  27.0         -      -
# 2955278   1112310415      EzZKbB0          1   FEM  25.0         -      -
# 8175823   1112362137       EKGWP0          1  MASC  27.0         -      -
# 14738838  1112493979      MV6AeQv          0  MASC  45.0         -      -
# 6342148   1112370636      2zPRq4o          0   FEM  38.0         -      -
# 15750225  1112513466      EzEQd28          0  MASC  55.0         -      -
# 13400323  1112361021      5ml2rJk          0   FEM  48.0         -      -
# 1220067   1112237727      2zN5zmx          1   FEM  30.0         -      -
# 1230530   1112441673      kP05oNa          0   FEM  22.0         -      -
# 9925558   1112501311      YjVrz8w          0   FEM  22.0         -      -
#
#               Otro Posgrado  Secundario    ...    viajar empresa_importante  \
# 1561364          -        -           -    ...     False              False
# 9093499          -        -           -    ...     False              False
# 5655219          -        -           -    ...     False              False
# 4643445          -        -    Graduado    ...     False              False
# 7527833          -        -    Graduado    ...     False              False
# 9389654   Graduado        -    Graduado    ...     False               True
# 2131598          -        -    Graduado    ...     False              False
# 2459968   Graduado        -    Graduado    ...     False              False
# 15796146         -        -           -    ...     False              False
# 12047360  Graduado        -           -    ...     False               True
# 3756713   Graduado        -    Graduado    ...     False               True
# 2955278          -        -    Graduado    ...     False              False
# 8175823   Graduado        -           -    ...     False              False
# 14738838         -        -    Graduado    ...     False               True
# 6342148          -        -    Graduado    ...     False              False
# 15750225         -        -           -    ...     False              False
# 13400323         -        -  Abandonado    ...     False              False
# 1220067          -        -           -    ...     False              False
# 1230530          -        -    Graduado    ...     False              False
# 9925558          -        -           -    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 1561364          True                   False     False       False
# 9093499         False                   False      True        True
# 5655219         False                   False     False       False
# 4643445         False                    True     False       False
# 7527833         False                   False     False       False
# 9389654         False                   False     False       False
# 2131598          True                   False     False       False
# 2459968         False                   False     False       False
# 15796146        False                   False     False       False
# 12047360        False                    True     False       False
# 3756713         False                   False     False       False
# 2955278         False                   False     False       False
# 8175823          True                   False     False       False
# 14738838        False                   False     False       False
# 6342148         False                   False     False       False
# 15750225        False                   False     False       False
# 13400323        False                   False     False       False
# 1220067         False                   False     False       False
# 1230530         False                    True     False       False
# 9925558         False                   False     False        True
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 1561364                      False         False           False  0.000000
# 9093499                      False         False           False  0.000000
# 5655219                      False          True           False  0.000000
# 4643445                      False          True           False  0.000000
# 7527833                      False         False           False  0.000000
# 9389654                      False         False           False  0.000000
# 2131598                      False          True           False  0.000000
# 2459968                      False         False           False  0.000000
# 15796146                     False         False           False  0.000000
# 12047360                     False         False           False  0.000000
# 3756713                       True         False            True  0.000000
# 2955278                      False         False            True  0.000000
# 8175823                      False         False           False  0.015152
# 14738838                      True         False            True  0.000000
# 6342148                      False         False           False  0.000000
# 15750225                     False         False           False  0.000000
# 13400323                      True         False            True  0.000000
# 1220067                      False         False           False  0.000000
# 1230530                      False         False           False  0.000000
# 9925558                      False         False           False  0.000000
#
# [20 rows x 36 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.05)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
vistas2=0
# Out:
# Train:  15281886 Test:  804310

# %%
gc.collect()
# Out:
# 520

# %%
c=lgb.LGBMClassifier(learning_rate=0.01,objective='binary',num_leaves=6000,max_depth=18,n_estimators=1200,colsample_bytree=0.9,n_jobs=-1,random_state=0,silent=False,subsample=1,sumsample_freq=1)

dt=c.fit(x_train,y_train,eval_set=[(x_test,y_test)],verbose=True,early_stopping_rounds=1)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")
# Out:
# [1]	valid_0's binary_logloss: 0.689857
# Training until validation scores don't improve for 1 rounds.
# [2]	valid_0's binary_logloss: 0.68559
# [3]	valid_0's binary_logloss: 0.68124
# [4]	valid_0's binary_logloss: 0.67778
# [5]	valid_0's binary_logloss: 0.673572
# [6]	valid_0's binary_logloss: 0.66991
# [7]	valid_0's binary_logloss: 0.665952
# [8]	valid_0's binary_logloss: 0.662251
# [9]	valid_0's binary_logloss: 0.659438
# [10]	valid_0's binary_logloss: 0.656451
# [11]	valid_0's binary_logloss: 0.652843
# [12]	valid_0's binary_logloss: 0.64921
# [13]	valid_0's binary_logloss: 0.64589
# [14]	valid_0's binary_logloss: 0.64423
# [15]	valid_0's binary_logloss: 0.64162
# [16]	valid_0's binary_logloss: 0.638071
# [17]	valid_0's binary_logloss: 0.63459
# [18]	valid_0's binary_logloss: 0.632071
# [19]	valid_0's binary_logloss: 0.62893
# [20]	valid_0's binary_logloss: 0.625568
# [21]	valid_0's binary_logloss: 0.622272
# [22]	valid_0's binary_logloss: 0.61941
# [23]	valid_0's binary_logloss: 0.616876
# [24]	valid_0's binary_logloss: 0.613784
# [25]	valid_0's binary_logloss: 0.610979
# [26]	valid_0's binary_logloss: 0.608012
# [27]	valid_0's binary_logloss: 0.605066
# [28]	valid_0's binary_logloss: 0.60238
# [29]	valid_0's binary_logloss: 0.599529
# [30]	valid_0's binary_logloss: 0.596993
# [31]	valid_0's binary_logloss: 0.594383
# [32]	valid_0's binary_logloss: 0.591656
# [33]	valid_0's binary_logloss: 0.588983
# [34]	valid_0's binary_logloss: 0.586289
# [35]	valid_0's binary_logloss: 0.583619
# [36]	valid_0's binary_logloss: 0.581
# [37]	valid_0's binary_logloss: 0.578622
# [38]	valid_0's binary_logloss: 0.576095
# [39]	valid_0's binary_logloss: 0.574248
# [40]	valid_0's binary_logloss: 0.572451
# [41]	valid_0's binary_logloss: 0.570662
# [42]	valid_0's binary_logloss: 0.568435
# [43]	valid_0's binary_logloss: 0.566054
# [44]	valid_0's binary_logloss: 0.563764
# [45]	valid_0's binary_logloss: 0.561639
# [46]	valid_0's binary_logloss: 0.559873
# [47]	valid_0's binary_logloss: 0.557712
# [48]	valid_0's binary_logloss: 0.555503
# [49]	valid_0's binary_logloss: 0.553385
# [50]	valid_0's binary_logloss: 0.551231
# [51]	valid_0's binary_logloss: 0.549124
# [52]	valid_0's binary_logloss: 0.547039
# [53]	valid_0's binary_logloss: 0.545553
# [54]	valid_0's binary_logloss: 0.543528
# [55]	valid_0's binary_logloss: 0.542567
# [56]	valid_0's binary_logloss: 0.540607
# [57]	valid_0's binary_logloss: 0.538675
# [58]	valid_0's binary_logloss: 0.536795
# [59]	valid_0's binary_logloss: 0.53491
# [60]	valid_0's binary_logloss: 0.533042
# [61]	valid_0's binary_logloss: 0.531185
# [62]	valid_0's binary_logloss: 0.52937
# [63]	valid_0's binary_logloss: 0.528111
# [64]	valid_0's binary_logloss: 0.526435
# [65]	valid_0's binary_logloss: 0.525219
# [66]	valid_0's binary_logloss: 0.52349
# [67]	valid_0's binary_logloss: 0.521806
# [68]	valid_0's binary_logloss: 0.520154
# [69]	valid_0's binary_logloss: 0.518857
# [70]	valid_0's binary_logloss: 0.517222
# [71]	valid_0's binary_logloss: 0.515603
# [72]	valid_0's binary_logloss: 0.514472
# [73]	valid_0's binary_logloss: 0.513028
# [74]	valid_0's binary_logloss: 0.511821
# [75]	valid_0's binary_logloss: 0.510608
# [76]	valid_0's binary_logloss: 0.509142
# [77]	valid_0's binary_logloss: 0.507617
# [78]	valid_0's binary_logloss: 0.506243
# [79]	valid_0's binary_logloss: 0.504779
# [80]	valid_0's binary_logloss: 0.503428
# [81]	valid_0's binary_logloss: 0.50233
# [82]	valid_0's binary_logloss: 0.50094
# [83]	valid_0's binary_logloss: 0.499557
# [84]	valid_0's binary_logloss: 0.498147
# [85]	valid_0's binary_logloss: 0.496744
# [86]	valid_0's binary_logloss: 0.495399
# [87]	valid_0's binary_logloss: 0.494174
# [88]	valid_0's binary_logloss: 0.492846
# [89]	valid_0's binary_logloss: 0.491866
# [90]	valid_0's binary_logloss: 0.490595
# [91]	valid_0's binary_logloss: 0.489435
# [92]	valid_0's binary_logloss: 0.488539
# [93]	valid_0's binary_logloss: 0.487388
# [94]	valid_0's binary_logloss: 0.486189
# [95]	valid_0's binary_logloss: 0.485117
# [96]	valid_0's binary_logloss: 0.483907
# [97]	valid_0's binary_logloss: 0.482745
# [98]	valid_0's binary_logloss: 0.481891
# [99]	valid_0's binary_logloss: 0.480749
# [100]	valid_0's binary_logloss: 0.479618
# [101]	valid_0's binary_logloss: 0.478794
# [102]	valid_0's binary_logloss: 0.477699
# [103]	valid_0's binary_logloss: 0.476887
# [104]	valid_0's binary_logloss: 0.475786
# [105]	valid_0's binary_logloss: 0.474745
# [106]	valid_0's binary_logloss: 0.473699
# [107]	valid_0's binary_logloss: 0.472629
# [108]	valid_0's binary_logloss: 0.471573
# [109]	valid_0's binary_logloss: 0.470564
# [110]	valid_0's binary_logloss: 0.469574
# [111]	valid_0's binary_logloss: 0.468583
# [112]	valid_0's binary_logloss: 0.467603
# [113]	valid_0's binary_logloss: 0.466671
# [114]	valid_0's binary_logloss: 0.465702
# [115]	valid_0's binary_logloss: 0.464766
# [116]	valid_0's binary_logloss: 0.463873
# [117]	valid_0's binary_logloss: 0.462988
# [118]	valid_0's binary_logloss: 0.462095
# [119]	valid_0's binary_logloss: 0.461209
# [120]	valid_0's binary_logloss: 0.460352
# [121]	valid_0's binary_logloss: 0.459479
# [122]	valid_0's binary_logloss: 0.458803
# [123]	valid_0's binary_logloss: 0.457938
# [124]	valid_0's binary_logloss: 0.457102
# [125]	valid_0's binary_logloss: 0.4565
# [126]	valid_0's binary_logloss: 0.45567
# [127]	valid_0's binary_logloss: 0.454881
# [128]	valid_0's binary_logloss: 0.454276
# [129]	valid_0's binary_logloss: 0.453656
# [130]	valid_0's binary_logloss: 0.452822
# [131]	valid_0's binary_logloss: 0.452111
# [132]	valid_0's binary_logloss: 0.451345
# [133]	valid_0's binary_logloss: 0.450774
# [134]	valid_0's binary_logloss: 0.449964
# [135]	valid_0's binary_logloss: 0.44922
# [136]	valid_0's binary_logloss: 0.448456
# [137]	valid_0's binary_logloss: 0.447744
# [138]	valid_0's binary_logloss: 0.447054
# [139]	valid_0's binary_logloss: 0.446367
# [140]	valid_0's binary_logloss: 0.445683
# [141]	valid_0's binary_logloss: 0.4451
# [142]	valid_0's binary_logloss: 0.444404
# [143]	valid_0's binary_logloss: 0.443724
# [144]	valid_0's binary_logloss: 0.443077
# [145]	valid_0's binary_logloss: 0.442407
# [146]	valid_0's binary_logloss: 0.441716
# [147]	valid_0's binary_logloss: 0.441073
# [148]	valid_0's binary_logloss: 0.440563
# [149]	valid_0's binary_logloss: 0.439935
# [150]	valid_0's binary_logloss: 0.439256
# [151]	valid_0's binary_logloss: 0.438638
# [152]	valid_0's binary_logloss: 0.438048
# [153]	valid_0's binary_logloss: 0.437479
# [154]	valid_0's binary_logloss: 0.436903
# [155]	valid_0's binary_logloss: 0.436323
# [156]	valid_0's binary_logloss: 0.435703
# [157]	valid_0's binary_logloss: 0.435103
# [158]	valid_0's binary_logloss: 0.434528
# [159]	valid_0's binary_logloss: 0.433969
# [160]	valid_0's binary_logloss: 0.433346
# [161]	valid_0's binary_logloss: 0.4328
# [162]	valid_0's binary_logloss: 0.43228
# [163]	valid_0's binary_logloss: 0.431742
# [164]	valid_0's binary_logloss: 0.431203
# [165]	valid_0's binary_logloss: 0.430671
# [166]	valid_0's binary_logloss: 0.430142
# [167]	valid_0's binary_logloss: 0.429621
# [168]	valid_0's binary_logloss: 0.429088
# [169]	valid_0's binary_logloss: 0.428603
# [170]	valid_0's binary_logloss: 0.428082
# [171]	valid_0's binary_logloss: 0.427743
# [172]	valid_0's binary_logloss: 0.427336
# [173]	valid_0's binary_logloss: 0.426844
# [174]	valid_0's binary_logloss: 0.426323
# [175]	valid_0's binary_logloss: 0.42584
# [176]	valid_0's binary_logloss: 0.425319
# [177]	valid_0's binary_logloss: 0.424957
# [178]	valid_0's binary_logloss: 0.424583
# [179]	valid_0's binary_logloss: 0.424241
# [180]	valid_0's binary_logloss: 0.423875
# [181]	valid_0's binary_logloss: 0.423398
# [182]	valid_0's binary_logloss: 0.422957
# [183]	valid_0's binary_logloss: 0.42261
# [184]	valid_0's binary_logloss: 0.422145
# [185]	valid_0's binary_logloss: 0.421797
# [186]	valid_0's binary_logloss: 0.421443
# [187]	valid_0's binary_logloss: 0.420952
# [188]	valid_0's binary_logloss: 0.420527
# [189]	valid_0's binary_logloss: 0.420198
# [190]	valid_0's binary_logloss: 0.419758
# [191]	valid_0's binary_logloss: 0.419555
# [192]	valid_0's binary_logloss: 0.419125
# [193]	valid_0's binary_logloss: 0.418673
# [194]	valid_0's binary_logloss: 0.418245
# [195]	valid_0's binary_logloss: 0.417904
# [196]	valid_0's binary_logloss: 0.417457
# [197]	valid_0's binary_logloss: 0.417016
# [198]	valid_0's binary_logloss: 0.416639
# [199]	valid_0's binary_logloss: 0.416207
# [200]	valid_0's binary_logloss: 0.415923
# [201]	valid_0's binary_logloss: 0.415548
# [202]	valid_0's binary_logloss: 0.415258
# [203]	valid_0's binary_logloss: 0.414887
# [204]	valid_0's binary_logloss: 0.414586
# [205]	valid_0's binary_logloss: 0.414315
# [206]	valid_0's binary_logloss: 0.413973
# [207]	valid_0's binary_logloss: 0.413605
# [208]	valid_0's binary_logloss: 0.413239
# [209]	valid_0's binary_logloss: 0.412892
# [210]	valid_0's binary_logloss: 0.41254
# [211]	valid_0's binary_logloss: 0.412179
# [212]	valid_0's binary_logloss: 0.411929
# [213]	valid_0's binary_logloss: 0.411569
# [214]	valid_0's binary_logloss: 0.411302
# [215]	valid_0's binary_logloss: 0.411025
# [216]	valid_0's binary_logloss: 0.410733
# [217]	valid_0's binary_logloss: 0.410414
# [218]	valid_0's binary_logloss: 0.410095
# [219]	valid_0's binary_logloss: 0.409827
# [220]	valid_0's binary_logloss: 0.409504
# [221]	valid_0's binary_logloss: 0.409197
# [222]	valid_0's binary_logloss: 0.40887
# [223]	valid_0's binary_logloss: 0.408559
# [224]	valid_0's binary_logloss: 0.408359
# [225]	valid_0's binary_logloss: 0.408004
# [226]	valid_0's binary_logloss: 0.407696
# [227]	valid_0's binary_logloss: 0.407476
# [228]	valid_0's binary_logloss: 0.407178
# [229]	valid_0's binary_logloss: 0.406876
# [230]	valid_0's binary_logloss: 0.406598
# [231]	valid_0's binary_logloss: 0.406292
# [232]	valid_0's binary_logloss: 0.405998
# [233]	valid_0's binary_logloss: 0.405731
# [234]	valid_0's binary_logloss: 0.405429
# [235]	valid_0's binary_logloss: 0.405159
# [236]	valid_0's binary_logloss: 0.404882
# [237]	valid_0's binary_logloss: 0.404758
# [238]	valid_0's binary_logloss: 0.404458
# [239]	valid_0's binary_logloss: 0.40419
# [240]	valid_0's binary_logloss: 0.403905
# [241]	valid_0's binary_logloss: 0.403701
# [242]	valid_0's binary_logloss: 0.403441
# [243]	valid_0's binary_logloss: 0.403184
# [244]	valid_0's binary_logloss: 0.402975
# [245]	valid_0's binary_logloss: 0.402784
# [246]	valid_0's binary_logloss: 0.402587
# [247]	valid_0's binary_logloss: 0.402349
# [248]	valid_0's binary_logloss: 0.402089
# [249]	valid_0's binary_logloss: 0.4019
# [250]	valid_0's binary_logloss: 0.401649
# [251]	valid_0's binary_logloss: 0.40139
# [252]	valid_0's binary_logloss: 0.401147
# [253]	valid_0's binary_logloss: 0.400891
# [254]	valid_0's binary_logloss: 0.400656
# [255]	valid_0's binary_logloss: 0.40047
# [256]	valid_0's binary_logloss: 0.400243
# [257]	valid_0's binary_logloss: 0.400072
# [258]	valid_0's binary_logloss: 0.39983
# [259]	valid_0's binary_logloss: 0.399568
# [260]	valid_0's binary_logloss: 0.399347
# [261]	valid_0's binary_logloss: 0.399101
# [262]	valid_0's binary_logloss: 0.398882
# [263]	valid_0's binary_logloss: 0.398711
# [264]	valid_0's binary_logloss: 0.398488
# [265]	valid_0's binary_logloss: 0.398265
# [266]	valid_0's binary_logloss: 0.398035
# [267]	valid_0's binary_logloss: 0.397823
# [268]	valid_0's binary_logloss: 0.397617
# [269]	valid_0's binary_logloss: 0.397387
# [270]	valid_0's binary_logloss: 0.397162
# [271]	valid_0's binary_logloss: 0.39694
# [272]	valid_0's binary_logloss: 0.396733
# [273]	valid_0's binary_logloss: 0.396522
# [274]	valid_0's binary_logloss: 0.396361
# [275]	valid_0's binary_logloss: 0.396211
# [276]	valid_0's binary_logloss: 0.39607
# [277]	valid_0's binary_logloss: 0.395851
# [278]	valid_0's binary_logloss: 0.395663
# [279]	valid_0's binary_logloss: 0.395464
# [280]	valid_0's binary_logloss: 0.395267
# [281]	valid_0's binary_logloss: 0.395045
# [282]	valid_0's binary_logloss: 0.394836
# [283]	valid_0's binary_logloss: 0.394638
# [284]	valid_0's binary_logloss: 0.394541
# [285]	valid_0's binary_logloss: 0.39434
# [286]	valid_0's binary_logloss: 0.394136
# [287]	valid_0's binary_logloss: 0.393936
# [288]	valid_0's binary_logloss: 0.393733
# [289]	valid_0's binary_logloss: 0.393543
# [290]	valid_0's binary_logloss: 0.393356
# [291]	valid_0's binary_logloss: 0.393155
# [292]	valid_0's binary_logloss: 0.392961
# [293]	valid_0's binary_logloss: 0.39277
# [294]	valid_0's binary_logloss: 0.39263
# [295]	valid_0's binary_logloss: 0.392421
# [296]	valid_0's binary_logloss: 0.392241
# [297]	valid_0's binary_logloss: 0.391987
# [298]	valid_0's binary_logloss: 0.391873
# [299]	valid_0's binary_logloss: 0.391673
# [300]	valid_0's binary_logloss: 0.39146
# [301]	valid_0's binary_logloss: 0.391227
# [302]	valid_0's binary_logloss: 0.391035
# [303]	valid_0's binary_logloss: 0.390894
# [304]	valid_0's binary_logloss: 0.390738
# [305]	valid_0's binary_logloss: 0.39058
# [306]	valid_0's binary_logloss: 0.390457
# [307]	valid_0's binary_logloss: 0.390295
# [308]	valid_0's binary_logloss: 0.390145
# [309]	valid_0's binary_logloss: 0.389987
# [310]	valid_0's binary_logloss: 0.389803
# [311]	valid_0's binary_logloss: 0.389647
# [312]	valid_0's binary_logloss: 0.389496
# [313]	valid_0's binary_logloss: 0.389328
# [314]	valid_0's binary_logloss: 0.38921
# [315]	valid_0's binary_logloss: 0.389089
# [316]	valid_0's binary_logloss: 0.38897
# [317]	valid_0's binary_logloss: 0.388817
# [318]	valid_0's binary_logloss: 0.388727
# [319]	valid_0's binary_logloss: 0.388552
# [320]	valid_0's binary_logloss: 0.388396
# [321]	valid_0's binary_logloss: 0.388237
# [322]	valid_0's binary_logloss: 0.388063
# [323]	valid_0's binary_logloss: 0.38789
# [324]	valid_0's binary_logloss: 0.387733
# [325]	valid_0's binary_logloss: 0.387594
# [326]	valid_0's binary_logloss: 0.387482
# [327]	valid_0's binary_logloss: 0.387319
# [328]	valid_0's binary_logloss: 0.387133
# [329]	valid_0's binary_logloss: 0.386981
# [330]	valid_0's binary_logloss: 0.386826
# [331]	valid_0's binary_logloss: 0.386675
# [332]	valid_0's binary_logloss: 0.386513
# [333]	valid_0's binary_logloss: 0.386424
# [334]	valid_0's binary_logloss: 0.386279
# [335]	valid_0's binary_logloss: 0.386119
# [336]	valid_0's binary_logloss: 0.385981
# [337]	valid_0's binary_logloss: 0.385843
# [338]	valid_0's binary_logloss: 0.385707
# [339]	valid_0's binary_logloss: 0.385589
# [340]	valid_0's binary_logloss: 0.385471
# [341]	valid_0's binary_logloss: 0.385342
# [342]	valid_0's binary_logloss: 0.385218
# [343]	valid_0's binary_logloss: 0.385105
# [344]	valid_0's binary_logloss: 0.384987
# [345]	valid_0's binary_logloss: 0.384856
# [346]	valid_0's binary_logloss: 0.384713
# [347]	valid_0's binary_logloss: 0.384612
# [348]	valid_0's binary_logloss: 0.384486
# [349]	valid_0's binary_logloss: 0.384371
# [350]	valid_0's binary_logloss: 0.384238
# [351]	valid_0's binary_logloss: 0.384108
# [352]	valid_0's binary_logloss: 0.383977
# [353]	valid_0's binary_logloss: 0.383848
# [354]	valid_0's binary_logloss: 0.38373
# [355]	valid_0's binary_logloss: 0.383586
# [356]	valid_0's binary_logloss: 0.383471
# [357]	valid_0's binary_logloss: 0.383358
# [358]	valid_0's binary_logloss: 0.38325
# [359]	valid_0's binary_logloss: 0.383131
# [360]	valid_0's binary_logloss: 0.383018
# [361]	valid_0's binary_logloss: 0.382896
# [362]	valid_0's binary_logloss: 0.382791
# [363]	valid_0's binary_logloss: 0.382663
# [364]	valid_0's binary_logloss: 0.382554
# [365]	valid_0's binary_logloss: 0.382449
# [366]	valid_0's binary_logloss: 0.382328
# [367]	valid_0's binary_logloss: 0.382222
# [368]	valid_0's binary_logloss: 0.382129
# [369]	valid_0's binary_logloss: 0.381982
# [370]	valid_0's binary_logloss: 0.381867
# [371]	valid_0's binary_logloss: 0.381787
# [372]	valid_0's binary_logloss: 0.381668
# [373]	valid_0's binary_logloss: 0.381539
# [374]	valid_0's binary_logloss: 0.381437
# [375]	valid_0's binary_logloss: 0.381316
# [376]	valid_0's binary_logloss: 0.381247
# [377]	valid_0's binary_logloss: 0.38117
# [378]	valid_0's binary_logloss: 0.381067
# [379]	valid_0's binary_logloss: 0.380973
# [380]	valid_0's binary_logloss: 0.380877
# [381]	valid_0's binary_logloss: 0.38083
# [382]	valid_0's binary_logloss: 0.380701
# [383]	valid_0's binary_logloss: 0.380609
# [384]	valid_0's binary_logloss: 0.380501
# [385]	valid_0's binary_logloss: 0.380394
# [386]	valid_0's binary_logloss: 0.380295
# [387]	valid_0's binary_logloss: 0.380201
# [388]	valid_0's binary_logloss: 0.380113
# [389]	valid_0's binary_logloss: 0.380028
# [390]	valid_0's binary_logloss: 0.379955
# [391]	valid_0's binary_logloss: 0.379855
# [392]	valid_0's binary_logloss: 0.379761
# [393]	valid_0's binary_logloss: 0.379669
# [394]	valid_0's binary_logloss: 0.379576
# [395]	valid_0's binary_logloss: 0.379507
# [396]	valid_0's binary_logloss: 0.379399
# [397]	valid_0's binary_logloss: 0.379304
# [398]	valid_0's binary_logloss: 0.379213
# [399]	valid_0's binary_logloss: 0.379114
# [400]	valid_0's binary_logloss: 0.379063
# [401]	valid_0's binary_logloss: 0.37898
# [402]	valid_0's binary_logloss: 0.378894
# [403]	valid_0's binary_logloss: 0.378812
# [404]	valid_0's binary_logloss: 0.378733
# [405]	valid_0's binary_logloss: 0.378669
# [406]	valid_0's binary_logloss: 0.378597
# [407]	valid_0's binary_logloss: 0.378497
# [408]	valid_0's binary_logloss: 0.378381
# [409]	valid_0's binary_logloss: 0.378227
# [410]	valid_0's binary_logloss: 0.378144
# [411]	valid_0's binary_logloss: 0.37804
# [412]	valid_0's binary_logloss: 0.377948
# [413]	valid_0's binary_logloss: 0.377869
# [414]	valid_0's binary_logloss: 0.377776
# [415]	valid_0's binary_logloss: 0.377673
# [416]	valid_0's binary_logloss: 0.377584
# [417]	valid_0's binary_logloss: 0.377525
# [418]	valid_0's binary_logloss: 0.377433
# [419]	valid_0's binary_logloss: 0.377353
# [420]	valid_0's binary_logloss: 0.377221
# [421]	valid_0's binary_logloss: 0.377138
# [422]	valid_0's binary_logloss: 0.377046
# [423]	valid_0's binary_logloss: 0.376979
# [424]	valid_0's binary_logloss: 0.376898
# [425]	valid_0's binary_logloss: 0.376851
# [426]	valid_0's binary_logloss: 0.37678
# [427]	valid_0's binary_logloss: 0.376708
# [428]	valid_0's binary_logloss: 0.376651
# [429]	valid_0's binary_logloss: 0.376592
# [430]	valid_0's binary_logloss: 0.376527
# [431]	valid_0's binary_logloss: 0.376446
# [432]	valid_0's binary_logloss: 0.376345
# [433]	valid_0's binary_logloss: 0.376273
# [434]	valid_0's binary_logloss: 0.376213
# [435]	valid_0's binary_logloss: 0.37614
# [436]	valid_0's binary_logloss: 0.376072
# [437]	valid_0's binary_logloss: 0.376021
# [438]	valid_0's binary_logloss: 0.375948
# [439]	valid_0's binary_logloss: 0.375895
# [440]	valid_0's binary_logloss: 0.375844
# [441]	valid_0's binary_logloss: 0.375793
# [442]	valid_0's binary_logloss: 0.37569
# [443]	valid_0's binary_logloss: 0.375637
# [444]	valid_0's binary_logloss: 0.375587
# [445]	valid_0's binary_logloss: 0.375548
# [446]	valid_0's binary_logloss: 0.375489
# [447]	valid_0's binary_logloss: 0.375429
# [448]	valid_0's binary_logloss: 0.375382
# [449]	valid_0's binary_logloss: 0.375332
# [450]	valid_0's binary_logloss: 0.375268
# [451]	valid_0's binary_logloss: 0.375217
# [452]	valid_0's binary_logloss: 0.375169
# [453]	valid_0's binary_logloss: 0.375122
# [454]	valid_0's binary_logloss: 0.375075
# [455]	valid_0's binary_logloss: 0.37501
# [456]	valid_0's binary_logloss: 0.374964
# [457]	valid_0's binary_logloss: 0.374921
# [458]	valid_0's binary_logloss: 0.374867
# [459]	valid_0's binary_logloss: 0.374799
# [460]	valid_0's binary_logloss: 0.374755
# [461]	valid_0's binary_logloss: 0.374683
# [462]	valid_0's binary_logloss: 0.374633
# [463]	valid_0's binary_logloss: 0.374586
# [464]	valid_0's binary_logloss: 0.374531
# [465]	valid_0's binary_logloss: 0.374495
# [466]	valid_0's binary_logloss: 0.374436
# [467]	valid_0's binary_logloss: 0.374396
# [468]	valid_0's binary_logloss: 0.37435
# [469]	valid_0's binary_logloss: 0.374309
# [470]	valid_0's binary_logloss: 0.374274
# [471]	valid_0's binary_logloss: 0.374213
# [472]	valid_0's binary_logloss: 0.374166
# [473]	valid_0's binary_logloss: 0.374081
# [474]	valid_0's binary_logloss: 0.374039
# [475]	valid_0's binary_logloss: 0.374002
# [476]	valid_0's binary_logloss: 0.37396
# [477]	valid_0's binary_logloss: 0.373918
# [478]	valid_0's binary_logloss: 0.373866
# [479]	valid_0's binary_logloss: 0.373808
# [480]	valid_0's binary_logloss: 0.373763
# [481]	valid_0's binary_logloss: 0.373706
# [482]	valid_0's binary_logloss: 0.37367
# [483]	valid_0's binary_logloss: 0.373624
# [484]	valid_0's binary_logloss: 0.373579
# [485]	valid_0's binary_logloss: 0.373424
# [486]	valid_0's binary_logloss: 0.373386
# [487]	valid_0's binary_logloss: 0.373345
# [488]	valid_0's binary_logloss: 0.373299
# [489]	valid_0's binary_logloss: 0.373242
# [490]	valid_0's binary_logloss: 0.373193
# [491]	valid_0's binary_logloss: 0.373117
# [492]	valid_0's binary_logloss: 0.373078
# [493]	valid_0's binary_logloss: 0.373028
# [494]	valid_0's binary_logloss: 0.372994
# [495]	valid_0's binary_logloss: 0.372958
# [496]	valid_0's binary_logloss: 0.372925
# [497]	valid_0's binary_logloss: 0.372851
# [498]	valid_0's binary_logloss: 0.372799
# [499]	valid_0's binary_logloss: 0.372752
# [500]	valid_0's binary_logloss: 0.372719
# [501]	valid_0's binary_logloss: 0.372679
# [502]	valid_0's binary_logloss: 0.372621
# [503]	valid_0's binary_logloss: 0.372555
# [504]	valid_0's binary_logloss: 0.372505
# [505]	valid_0's binary_logloss: 0.37247
# [506]	valid_0's binary_logloss: 0.372443
# [507]	valid_0's binary_logloss: 0.372401
# [508]	valid_0's binary_logloss: 0.372348
# [509]	valid_0's binary_logloss: 0.372313
# [510]	valid_0's binary_logloss: 0.372268
# [511]	valid_0's binary_logloss: 0.372233
# [512]	valid_0's binary_logloss: 0.372186
# [513]	valid_0's binary_logloss: 0.372109
# [514]	valid_0's binary_logloss: 0.372062
# [515]	valid_0's binary_logloss: 0.372019
# [516]	valid_0's binary_logloss: 0.371978
# [517]	valid_0's binary_logloss: 0.371939
# [518]	valid_0's binary_logloss: 0.37189
# [519]	valid_0's binary_logloss: 0.371851
# [520]	valid_0's binary_logloss: 0.371812
# [521]	valid_0's binary_logloss: 0.371739
# [522]	valid_0's binary_logloss: 0.37171
# [523]	valid_0's binary_logloss: 0.371674
# [524]	valid_0's binary_logloss: 0.371634
# [525]	valid_0's binary_logloss: 0.371593
# [526]	valid_0's binary_logloss: 0.371551
# [527]	valid_0's binary_logloss: 0.371505
# [528]	valid_0's binary_logloss: 0.371471
# [529]	valid_0's binary_logloss: 0.371391
# [530]	valid_0's binary_logloss: 0.371357
# [531]	valid_0's binary_logloss: 0.371322
# [532]	valid_0's binary_logloss: 0.371287
# [533]	valid_0's binary_logloss: 0.371244
# [534]	valid_0's binary_logloss: 0.37121
# [535]	valid_0's binary_logloss: 0.371179
# [536]	valid_0's binary_logloss: 0.371106
# [537]	valid_0's binary_logloss: 0.371086
# [538]	valid_0's binary_logloss: 0.371047
# [539]	valid_0's binary_logloss: 0.370978
# [540]	valid_0's binary_logloss: 0.37095
# [541]	valid_0's binary_logloss: 0.370912
# [542]	valid_0's binary_logloss: 0.370832
# [543]	valid_0's binary_logloss: 0.370754
# [544]	valid_0's binary_logloss: 0.370681
# [545]	valid_0's binary_logloss: 0.370647
# [546]	valid_0's binary_logloss: 0.370578
# [547]	valid_0's binary_logloss: 0.37054
# [548]	valid_0's binary_logloss: 0.370489
# [549]	valid_0's binary_logloss: 0.370454
# [550]	valid_0's binary_logloss: 0.370425
# [551]	valid_0's binary_logloss: 0.370395
# [552]	valid_0's binary_logloss: 0.370354
# [553]	valid_0's binary_logloss: 0.370285
# [554]	valid_0's binary_logloss: 0.37025
# [555]	valid_0's binary_logloss: 0.370195
# [556]	valid_0's binary_logloss: 0.370166
# [557]	valid_0's binary_logloss: 0.370102
# [558]	valid_0's binary_logloss: 0.370076
# [559]	valid_0's binary_logloss: 0.37004
# [560]	valid_0's binary_logloss: 0.370001
# [561]	valid_0's binary_logloss: 0.369949
# [562]	valid_0's binary_logloss: 0.369908
# [563]	valid_0's binary_logloss: 0.369883
# [564]	valid_0's binary_logloss: 0.369828
# [565]	valid_0's binary_logloss: 0.369787
# [566]	valid_0's binary_logloss: 0.369758
# [567]	valid_0's binary_logloss: 0.369734
# [568]	valid_0's binary_logloss: 0.369693
# [569]	valid_0's binary_logloss: 0.369622
# [570]	valid_0's binary_logloss: 0.369596
# [571]	valid_0's binary_logloss: 0.369559
# [572]	valid_0's binary_logloss: 0.369528
# [573]	valid_0's binary_logloss: 0.369487
# [574]	valid_0's binary_logloss: 0.369414
# [575]	valid_0's binary_logloss: 0.369363
# [576]	valid_0's binary_logloss: 0.369329
# [577]	valid_0's binary_logloss: 0.369298
# [578]	valid_0's binary_logloss: 0.369282
# [579]	valid_0's binary_logloss: 0.369267
# [580]	valid_0's binary_logloss: 0.369213
# [581]	valid_0's binary_logloss: 0.369178
# [582]	valid_0's binary_logloss: 0.369155
# [583]	valid_0's binary_logloss: 0.369139
# [584]	valid_0's binary_logloss: 0.369122
# [585]	valid_0's binary_logloss: 0.369106
# [586]	valid_0's binary_logloss: 0.369033
# [587]	valid_0's binary_logloss: 0.369019
# [588]	valid_0's binary_logloss: 0.36899
# [589]	valid_0's binary_logloss: 0.368969
# [590]	valid_0's binary_logloss: 0.368932
# [591]	valid_0's binary_logloss: 0.368868
# [592]	valid_0's binary_logloss: 0.368841
# [593]	valid_0's binary_logloss: 0.368788
# [594]	valid_0's binary_logloss: 0.368762
# [595]	valid_0's binary_logloss: 0.368717
# [596]	valid_0's binary_logloss: 0.368695
# [597]	valid_0's binary_logloss: 0.368652
# [598]	valid_0's binary_logloss: 0.368628
# [599]	valid_0's binary_logloss: 0.368599
# [600]	valid_0's binary_logloss: 0.368558
# [601]	valid_0's binary_logloss: 0.368525
# [602]	valid_0's binary_logloss: 0.368505
# [603]	valid_0's binary_logloss: 0.36848
# [604]	valid_0's binary_logloss: 0.368454
# [605]	valid_0's binary_logloss: 0.36844
# [606]	valid_0's binary_logloss: 0.368428
# [607]	valid_0's binary_logloss: 0.368392
# [608]	valid_0's binary_logloss: 0.368379
# [609]	valid_0's binary_logloss: 0.368353
# [610]	valid_0's binary_logloss: 0.368341
# [611]	valid_0's binary_logloss: 0.368292
# [612]	valid_0's binary_logloss: 0.368271
# [613]	valid_0's binary_logloss: 0.36824
# [614]	valid_0's binary_logloss: 0.368217
# [615]	valid_0's binary_logloss: 0.368161
# [616]	valid_0's binary_logloss: 0.368108
# [617]	valid_0's binary_logloss: 0.368065
# [618]	valid_0's binary_logloss: 0.368043
# [619]	valid_0's binary_logloss: 0.367991
# [620]	valid_0's binary_logloss: 0.367953
# [621]	valid_0's binary_logloss: 0.367926
# [622]	valid_0's binary_logloss: 0.367907
# [623]	valid_0's binary_logloss: 0.367875
# [624]	valid_0's binary_logloss: 0.367852
# [625]	valid_0's binary_logloss: 0.367826
# [626]	valid_0's binary_logloss: 0.367797
# [627]	valid_0's binary_logloss: 0.367764
# [628]	valid_0's binary_logloss: 0.367745
# [629]	valid_0's binary_logloss: 0.367703
# [630]	valid_0's binary_logloss: 0.367685
# [631]	valid_0's binary_logloss: 0.367666
# [632]	valid_0's binary_logloss: 0.367614
# [633]	valid_0's binary_logloss: 0.367596
# [634]	valid_0's binary_logloss: 0.367576
# [635]	valid_0's binary_logloss: 0.367557
# [636]	valid_0's binary_logloss: 0.367523
# [637]	valid_0's binary_logloss: 0.367503
# [638]	valid_0's binary_logloss: 0.367449
# [639]	valid_0's binary_logloss: 0.367436
# [640]	valid_0's binary_logloss: 0.367416
# [641]	valid_0's binary_logloss: 0.367373
# [642]	valid_0's binary_logloss: 0.36735
# [643]	valid_0's binary_logloss: 0.367325
# [644]	valid_0's binary_logloss: 0.367271
# [645]	valid_0's binary_logloss: 0.36725
# [646]	valid_0's binary_logloss: 0.367211
# [647]	valid_0's binary_logloss: 0.367168
# [648]	valid_0's binary_logloss: 0.367147
# [649]	valid_0's binary_logloss: 0.367118
# [650]	valid_0's binary_logloss: 0.367088
# [651]	valid_0's binary_logloss: 0.367068
# [652]	valid_0's binary_logloss: 0.367047
# [653]	valid_0's binary_logloss: 0.367002
# [654]	valid_0's binary_logloss: 0.366982
# [655]	valid_0's binary_logloss: 0.366961
# [656]	valid_0's binary_logloss: 0.366919
# [657]	valid_0's binary_logloss: 0.366877
# [658]	valid_0's binary_logloss: 0.366855
# [659]	valid_0's binary_logloss: 0.366835
# [660]	valid_0's binary_logloss: 0.366818
# [661]	valid_0's binary_logloss: 0.366799
# [662]	valid_0's binary_logloss: 0.366767
# [663]	valid_0's binary_logloss: 0.366727
# [664]	valid_0's binary_logloss: 0.36671
# [665]	valid_0's binary_logloss: 0.366679
# [666]	valid_0's binary_logloss: 0.366637
# [667]	valid_0's binary_logloss: 0.366589
# [668]	valid_0's binary_logloss: 0.366571
# [669]	valid_0's binary_logloss: 0.366549
# [670]	valid_0's binary_logloss: 0.366511
# [671]	valid_0's binary_logloss: 0.366476
# [672]	valid_0's binary_logloss: 0.366452
# [673]	valid_0's binary_logloss: 0.36643
# [674]	valid_0's binary_logloss: 0.366394
# [675]	valid_0's binary_logloss: 0.366371
# [676]	valid_0's binary_logloss: 0.366353
# [677]	valid_0's binary_logloss: 0.366336
# [678]	valid_0's binary_logloss: 0.366317
# [679]	valid_0's binary_logloss: 0.366299
# [680]	valid_0's binary_logloss: 0.366287
# [681]	valid_0's binary_logloss: 0.366258
# [682]	valid_0's binary_logloss: 0.366246
# [683]	valid_0's binary_logloss: 0.366229
# [684]	valid_0's binary_logloss: 0.366182
# [685]	valid_0's binary_logloss: 0.366144
# [686]	valid_0's binary_logloss: 0.366111
# [687]	valid_0's binary_logloss: 0.366086
# [688]	valid_0's binary_logloss: 0.366063
# [689]	valid_0's binary_logloss: 0.366044
# [690]	valid_0's binary_logloss: 0.366012
# [691]	valid_0's binary_logloss: 0.36599
# [692]	valid_0's binary_logloss: 0.365954
# [693]	valid_0's binary_logloss: 0.365923
# [694]	valid_0's binary_logloss: 0.365898
# [695]	valid_0's binary_logloss: 0.365866
# [696]	valid_0's binary_logloss: 0.365841
# [697]	valid_0's binary_logloss: 0.365815
# [698]	valid_0's binary_logloss: 0.365777
# [699]	valid_0's binary_logloss: 0.365758
# [700]	valid_0's binary_logloss: 0.36573
# [701]	valid_0's binary_logloss: 0.365704
# [702]	valid_0's binary_logloss: 0.365663
# [703]	valid_0's binary_logloss: 0.365639
# [704]	valid_0's binary_logloss: 0.365624
# [705]	valid_0's binary_logloss: 0.365583
# [706]	valid_0's binary_logloss: 0.365567
# [707]	valid_0's binary_logloss: 0.365517
# [708]	valid_0's binary_logloss: 0.365497
# [709]	valid_0's binary_logloss: 0.365473
# [710]	valid_0's binary_logloss: 0.365441
# [711]	valid_0's binary_logloss: 0.365426
# [712]	valid_0's binary_logloss: 0.365381
# [713]	valid_0's binary_logloss: 0.365339
# [714]	valid_0's binary_logloss: 0.365323
# [715]	valid_0's binary_logloss: 0.3653
# [716]	valid_0's binary_logloss: 0.365231
# [717]	valid_0's binary_logloss: 0.365211
# [718]	valid_0's binary_logloss: 0.365202
# [719]	valid_0's binary_logloss: 0.365187
# [720]	valid_0's binary_logloss: 0.365171
# [721]	valid_0's binary_logloss: 0.365151
# [722]	valid_0's binary_logloss: 0.365135
# [723]	valid_0's binary_logloss: 0.365118
# [724]	valid_0's binary_logloss: 0.365098
# [725]	valid_0's binary_logloss: 0.365091
# [726]	valid_0's binary_logloss: 0.365041
# [727]	valid_0's binary_logloss: 0.365013
# [728]	valid_0's binary_logloss: 0.364974
# [729]	valid_0's binary_logloss: 0.364938
# [730]	valid_0's binary_logloss: 0.364904
# [731]	valid_0's binary_logloss: 0.364856
# [732]	valid_0's binary_logloss: 0.364828
# [733]	valid_0's binary_logloss: 0.364816
# [734]	valid_0's binary_logloss: 0.364795
# [735]	valid_0's binary_logloss: 0.364778
# [736]	valid_0's binary_logloss: 0.364752
# [737]	valid_0's binary_logloss: 0.364702
# [738]	valid_0's binary_logloss: 0.36468
# [739]	valid_0's binary_logloss: 0.364654
# [740]	valid_0's binary_logloss: 0.364643
# [741]	valid_0's binary_logloss: 0.364626
# [742]	valid_0's binary_logloss: 0.364588
# [743]	valid_0's binary_logloss: 0.364578
# [744]	valid_0's binary_logloss: 0.364568
# [745]	valid_0's binary_logloss: 0.364531
# [746]	valid_0's binary_logloss: 0.3645
# [747]	valid_0's binary_logloss: 0.364488
# [748]	valid_0's binary_logloss: 0.36447
# [749]	valid_0's binary_logloss: 0.364436
# [750]	valid_0's binary_logloss: 0.364413
# [751]	valid_0's binary_logloss: 0.364394
# [752]	valid_0's binary_logloss: 0.364384
# [753]	valid_0's binary_logloss: 0.364359
# [754]	valid_0's binary_logloss: 0.364338
# [755]	valid_0's binary_logloss: 0.36432
# [756]	valid_0's binary_logloss: 0.364309
# [757]	valid_0's binary_logloss: 0.364294
# [758]	valid_0's binary_logloss: 0.364284
# [759]	valid_0's binary_logloss: 0.364275
# [760]	valid_0's binary_logloss: 0.364241
# [761]	valid_0's binary_logloss: 0.364229
# [762]	valid_0's binary_logloss: 0.364203
# [763]	valid_0's binary_logloss: 0.364174
# [764]	valid_0's binary_logloss: 0.364146
# [765]	valid_0's binary_logloss: 0.364079
# [766]	valid_0's binary_logloss: 0.364074
# [767]	valid_0's binary_logloss: 0.364049
# [768]	valid_0's binary_logloss: 0.364029
# [769]	valid_0's binary_logloss: 0.364025
# [770]	valid_0's binary_logloss: 0.364016
# [771]	valid_0's binary_logloss: 0.363991
# [772]	valid_0's binary_logloss: 0.363944
# [773]	valid_0's binary_logloss: 0.363929
# [774]	valid_0's binary_logloss: 0.363904
# [775]	valid_0's binary_logloss: 0.363897
# [776]	valid_0's binary_logloss: 0.363884
# [777]	valid_0's binary_logloss: 0.36385
# [778]	valid_0's binary_logloss: 0.363827
# [779]	valid_0's binary_logloss: 0.363799
# [780]	valid_0's binary_logloss: 0.363785
# [781]	valid_0's binary_logloss: 0.363751
# [782]	valid_0's binary_logloss: 0.363745
# [783]	valid_0's binary_logloss: 0.363716
# [784]	valid_0's binary_logloss: 0.363671
# [785]	valid_0's binary_logloss: 0.363652
# [786]	valid_0's binary_logloss: 0.363622
# [787]	valid_0's binary_logloss: 0.363602
# [788]	valid_0's binary_logloss: 0.363586
# [789]	valid_0's binary_logloss: 0.36356
# [790]	valid_0's binary_logloss: 0.363533
# [791]	valid_0's binary_logloss: 0.36352
# [792]	valid_0's binary_logloss: 0.363512
# [793]	valid_0's binary_logloss: 0.3635
# [794]	valid_0's binary_logloss: 0.363466
# [795]	valid_0's binary_logloss: 0.363435
# [796]	valid_0's binary_logloss: 0.363386
# [797]	valid_0's binary_logloss: 0.36336
# [798]	valid_0's binary_logloss: 0.363339
# [799]	valid_0's binary_logloss: 0.363309
# [800]	valid_0's binary_logloss: 0.363232
# [801]	valid_0's binary_logloss: 0.363221
# [802]	valid_0's binary_logloss: 0.363201
# [803]	valid_0's binary_logloss: 0.363155
# [804]	valid_0's binary_logloss: 0.363127
# [805]	valid_0's binary_logloss: 0.363105
# [806]	valid_0's binary_logloss: 0.363098
# [807]	valid_0's binary_logloss: 0.363079
# [808]	valid_0's binary_logloss: 0.363066
# [809]	valid_0's binary_logloss: 0.363039
# [810]	valid_0's binary_logloss: 0.36298
# [811]	valid_0's binary_logloss: 0.362963
# [812]	valid_0's binary_logloss: 0.362911
# [813]	valid_0's binary_logloss: 0.362879
# [814]	valid_0's binary_logloss: 0.362848
# [815]	valid_0's binary_logloss: 0.362799
# [816]	valid_0's binary_logloss: 0.362736
# [817]	valid_0's binary_logloss: 0.362718
# [818]	valid_0's binary_logloss: 0.362704
# [819]	valid_0's binary_logloss: 0.36269
# [820]	valid_0's binary_logloss: 0.362679
# [821]	valid_0's binary_logloss: 0.362665
# [822]	valid_0's binary_logloss: 0.36266
# [823]	valid_0's binary_logloss: 0.362612
# [824]	valid_0's binary_logloss: 0.362589
# [825]	valid_0's binary_logloss: 0.362581
# [826]	valid_0's binary_logloss: 0.362563
# [827]	valid_0's binary_logloss: 0.362547
# [828]	valid_0's binary_logloss: 0.362515
# [829]	valid_0's binary_logloss: 0.362501
# [830]	valid_0's binary_logloss: 0.362419
# [831]	valid_0's binary_logloss: 0.362358
# [832]	valid_0's binary_logloss: 0.362345
# [833]	valid_0's binary_logloss: 0.36232
# [834]	valid_0's binary_logloss: 0.362298
# [835]	valid_0's binary_logloss: 0.362283
# [836]	valid_0's binary_logloss: 0.362254
# [837]	valid_0's binary_logloss: 0.362221
# [838]	valid_0's binary_logloss: 0.362209
# [839]	valid_0's binary_logloss: 0.362203
# [840]	valid_0's binary_logloss: 0.362173
# [841]	valid_0's binary_logloss: 0.362146
# [842]	valid_0's binary_logloss: 0.362127
# [843]	valid_0's binary_logloss: 0.362086
# [844]	valid_0's binary_logloss: 0.362064
# [845]	valid_0's binary_logloss: 0.362034
# [846]	valid_0's binary_logloss: 0.361966
# [847]	valid_0's binary_logloss: 0.361921
# [848]	valid_0's binary_logloss: 0.361889
# [849]	valid_0's binary_logloss: 0.361867
# [850]	valid_0's binary_logloss: 0.361847
# [851]	valid_0's binary_logloss: 0.361822
# [852]	valid_0's binary_logloss: 0.361798
# [853]	valid_0's binary_logloss: 0.361769
# [854]	valid_0's binary_logloss: 0.361746
# [855]	valid_0's binary_logloss: 0.36174
# [856]	valid_0's binary_logloss: 0.361725
# [857]	valid_0's binary_logloss: 0.361709
# [858]	valid_0's binary_logloss: 0.361667
# [859]	valid_0's binary_logloss: 0.361657
# [860]	valid_0's binary_logloss: 0.361616
# [861]	valid_0's binary_logloss: 0.361589
# [862]	valid_0's binary_logloss: 0.361569
# [863]	valid_0's binary_logloss: 0.361541
# [864]	valid_0's binary_logloss: 0.361494
# [865]	valid_0's binary_logloss: 0.361467
# [866]	valid_0's binary_logloss: 0.36145
# [867]	valid_0's binary_logloss: 0.361417
# [868]	valid_0's binary_logloss: 0.361389
# [869]	valid_0's binary_logloss: 0.361369
# [870]	valid_0's binary_logloss: 0.361321
# [871]	valid_0's binary_logloss: 0.361302
# [872]	valid_0's binary_logloss: 0.361288
# [873]	valid_0's binary_logloss: 0.361275
# [874]	valid_0's binary_logloss: 0.361261
# [875]	valid_0's binary_logloss: 0.361251
# [876]	valid_0's binary_logloss: 0.361248
# [877]	valid_0's binary_logloss: 0.361216
# [878]	valid_0's binary_logloss: 0.361191
# [879]	valid_0's binary_logloss: 0.361169
# [880]	valid_0's binary_logloss: 0.361139
# [881]	valid_0's binary_logloss: 0.361094
# [882]	valid_0's binary_logloss: 0.361059
# [883]	valid_0's binary_logloss: 0.361031
# [884]	valid_0's binary_logloss: 0.361001
# [885]	valid_0's binary_logloss: 0.360966
# [886]	valid_0's binary_logloss: 0.360948
# [887]	valid_0's binary_logloss: 0.360907
# [888]	valid_0's binary_logloss: 0.360862
# [889]	valid_0's binary_logloss: 0.360842
# [890]	valid_0's binary_logloss: 0.360817
# [891]	valid_0's binary_logloss: 0.360804
# [892]	valid_0's binary_logloss: 0.360773
# [893]	valid_0's binary_logloss: 0.360738
# [894]	valid_0's binary_logloss: 0.360712
# [895]	valid_0's binary_logloss: 0.360675
# [896]	valid_0's binary_logloss: 0.360642
# [897]	valid_0's binary_logloss: 0.360606
# [898]	valid_0's binary_logloss: 0.360592
# [899]	valid_0's binary_logloss: 0.360527
# [900]	valid_0's binary_logloss: 0.360475
# [901]	valid_0's binary_logloss: 0.360409
# [902]	valid_0's binary_logloss: 0.360394
# [903]	valid_0's binary_logloss: 0.360329
# [904]	valid_0's binary_logloss: 0.360296
# [905]	valid_0's binary_logloss: 0.360259
# [906]	valid_0's binary_logloss: 0.360221
# [907]	valid_0's binary_logloss: 0.360198
# [908]	valid_0's binary_logloss: 0.360154
# [909]	valid_0's binary_logloss: 0.360118
# [910]	valid_0's binary_logloss: 0.360109
# [911]	valid_0's binary_logloss: 0.360091
# [912]	valid_0's binary_logloss: 0.360052
# [913]	valid_0's binary_logloss: 0.360013
# [914]	valid_0's binary_logloss: 0.359958
# [915]	valid_0's binary_logloss: 0.359921
# [916]	valid_0's binary_logloss: 0.359867
# [917]	valid_0's binary_logloss: 0.359802
# [918]	valid_0's binary_logloss: 0.359745
# [919]	valid_0's binary_logloss: 0.359729
# [920]	valid_0's binary_logloss: 0.359681
# [921]	valid_0's binary_logloss: 0.35966
# [922]	valid_0's binary_logloss: 0.35965
# [923]	valid_0's binary_logloss: 0.359555
# [924]	valid_0's binary_logloss: 0.35954
# [925]	valid_0's binary_logloss: 0.35943
# [926]	valid_0's binary_logloss: 0.359412
# [927]	valid_0's binary_logloss: 0.359394
# [928]	valid_0's binary_logloss: 0.359377
# [929]	valid_0's binary_logloss: 0.359338
# [930]	valid_0's binary_logloss: 0.359303
# [931]	valid_0's binary_logloss: 0.359209
# [932]	valid_0's binary_logloss: 0.359172
# [933]	valid_0's binary_logloss: 0.359152
# [934]	valid_0's binary_logloss: 0.359102
# [935]	valid_0's binary_logloss: 0.359007
# [936]	valid_0's binary_logloss: 0.358924
# [937]	valid_0's binary_logloss: 0.358896
# [938]	valid_0's binary_logloss: 0.358855
# [939]	valid_0's binary_logloss: 0.358846
# [940]	valid_0's binary_logloss: 0.358831
# [941]	valid_0's binary_logloss: 0.358813
# [942]	valid_0's binary_logloss: 0.35879
# [943]	valid_0's binary_logloss: 0.358763
# [944]	valid_0's binary_logloss: 0.358729
# [945]	valid_0's binary_logloss: 0.35868
# [946]	valid_0's binary_logloss: 0.358671
# [947]	valid_0's binary_logloss: 0.358625
# [948]	valid_0's binary_logloss: 0.358576
# [949]	valid_0's binary_logloss: 0.358561
# [950]	valid_0's binary_logloss: 0.358546
# [951]	valid_0's binary_logloss: 0.358533
# [952]	valid_0's binary_logloss: 0.358503
# [953]	valid_0's binary_logloss: 0.358493
# [954]	valid_0's binary_logloss: 0.358444
# [955]	valid_0's binary_logloss: 0.358404
# [956]	valid_0's binary_logloss: 0.358396
# [957]	valid_0's binary_logloss: 0.358387
# [958]	valid_0's binary_logloss: 0.358376
# [959]	valid_0's binary_logloss: 0.35834
# [960]	valid_0's binary_logloss: 0.358303
# [961]	valid_0's binary_logloss: 0.358291
# [962]	valid_0's binary_logloss: 0.358262
# [963]	valid_0's binary_logloss: 0.358236
# [964]	valid_0's binary_logloss: 0.358228
# [965]	valid_0's binary_logloss: 0.358181
# [966]	valid_0's binary_logloss: 0.358167
# [967]	valid_0's binary_logloss: 0.358152
# [968]	valid_0's binary_logloss: 0.358143
# [969]	valid_0's binary_logloss: 0.358131
# [970]	valid_0's binary_logloss: 0.358106
# [971]	valid_0's binary_logloss: 0.358098
# [972]	valid_0's binary_logloss: 0.358031
# [973]	valid_0's binary_logloss: 0.358008
# [974]	valid_0's binary_logloss: 0.358003
# [975]	valid_0's binary_logloss: 0.35797
# [976]	valid_0's binary_logloss: 0.357955
# [977]	valid_0's binary_logloss: 0.35794
# [978]	valid_0's binary_logloss: 0.357895
# [979]	valid_0's binary_logloss: 0.357876
# [980]	valid_0's binary_logloss: 0.357833
# [981]	valid_0's binary_logloss: 0.357804
# [982]	valid_0's binary_logloss: 0.357795
# [983]	valid_0's binary_logloss: 0.357778
# [984]	valid_0's binary_logloss: 0.357757
# [985]	valid_0's binary_logloss: 0.35775
# [986]	valid_0's binary_logloss: 0.357726
# [987]	valid_0's binary_logloss: 0.357701
# [988]	valid_0's binary_logloss: 0.357675
# [989]	valid_0's binary_logloss: 0.357648
# [990]	valid_0's binary_logloss: 0.357642
# [991]	valid_0's binary_logloss: 0.357623
# [992]	valid_0's binary_logloss: 0.357597
# [993]	valid_0's binary_logloss: 0.357589
# [994]	valid_0's binary_logloss: 0.357559
# [995]	valid_0's binary_logloss: 0.357522
# [996]	valid_0's binary_logloss: 0.357505
# [997]	valid_0's binary_logloss: 0.3575
# [998]	valid_0's binary_logloss: 0.357492
# [999]	valid_0's binary_logloss: 0.357486
# [1000]	valid_0's binary_logloss: 0.357473
# [1001]	valid_0's binary_logloss: 0.357435
# [1002]	valid_0's binary_logloss: 0.357423
# [1003]	valid_0's binary_logloss: 0.357364
# [1004]	valid_0's binary_logloss: 0.357302
# [1005]	valid_0's binary_logloss: 0.357282
# [1006]	valid_0's binary_logloss: 0.357277
# [1007]	valid_0's binary_logloss: 0.357261
# [1008]	valid_0's binary_logloss: 0.357245
# [1009]	valid_0's binary_logloss: 0.357237
# [1010]	valid_0's binary_logloss: 0.357235
# [1011]	valid_0's binary_logloss: 0.357228
# [1012]	valid_0's binary_logloss: 0.357222
# [1013]	valid_0's binary_logloss: 0.357216
# [1014]	valid_0's binary_logloss: 0.357198
# [1015]	valid_0's binary_logloss: 0.357192
# [1016]	valid_0's binary_logloss: 0.357183
# [1017]	valid_0's binary_logloss: 0.357172
# [1018]	valid_0's binary_logloss: 0.357163
# [1019]	valid_0's binary_logloss: 0.357123
# [1020]	valid_0's binary_logloss: 0.357109
# [1021]	valid_0's binary_logloss: 0.357056
# [1022]	valid_0's binary_logloss: 0.357024
# [1023]	valid_0's binary_logloss: 0.356978
# [1024]	valid_0's binary_logloss: 0.356917
# [1025]	valid_0's binary_logloss: 0.356854
# [1026]	valid_0's binary_logloss: 0.356818
# [1027]	valid_0's binary_logloss: 0.356789
# [1028]	valid_0's binary_logloss: 0.356764
# [1029]	valid_0's binary_logloss: 0.356717
# [1030]	valid_0's binary_logloss: 0.356694
# [1031]	valid_0's binary_logloss: 0.356675
# [1032]	valid_0's binary_logloss: 0.356655
# [1033]	valid_0's binary_logloss: 0.356623
# [1034]	valid_0's binary_logloss: 0.356596
# [1035]	valid_0's binary_logloss: 0.356571
# [1036]	valid_0's binary_logloss: 0.356547
# [1037]	valid_0's binary_logloss: 0.356527
# [1038]	valid_0's binary_logloss: 0.356432
# [1039]	valid_0's binary_logloss: 0.356409
# [1040]	valid_0's binary_logloss: 0.356387
# [1041]	valid_0's binary_logloss: 0.356372
# [1042]	valid_0's binary_logloss: 0.356361
# [1043]	valid_0's binary_logloss: 0.356347
# [1044]	valid_0's binary_logloss: 0.356339
# [1045]	valid_0's binary_logloss: 0.356321
# [1046]	valid_0's binary_logloss: 0.35629
# [1047]	valid_0's binary_logloss: 0.356235
# [1048]	valid_0's binary_logloss: 0.35621
# [1049]	valid_0's binary_logloss: 0.356133
# [1050]	valid_0's binary_logloss: 0.356096
# [1051]	valid_0's binary_logloss: 0.35605
# [1052]	valid_0's binary_logloss: 0.356036
# [1053]	valid_0's binary_logloss: 0.356017
# [1054]	valid_0's binary_logloss: 0.355994
# [1055]	valid_0's binary_logloss: 0.355977
# [1056]	valid_0's binary_logloss: 0.355956
# [1057]	valid_0's binary_logloss: 0.35595
# [1058]	valid_0's binary_logloss: 0.355915
# [1059]	valid_0's binary_logloss: 0.355898
# [1060]	valid_0's binary_logloss: 0.355868
# [1061]	valid_0's binary_logloss: 0.355858
# [1062]	valid_0's binary_logloss: 0.355817
# [1063]	valid_0's binary_logloss: 0.355801
# [1064]	valid_0's binary_logloss: 0.355776
# [1065]	valid_0's binary_logloss: 0.355735
# [1066]	valid_0's binary_logloss: 0.355701
# [1067]	valid_0's binary_logloss: 0.355689
# [1068]	valid_0's binary_logloss: 0.355648
# [1069]	valid_0's binary_logloss: 0.355623
# [1070]	valid_0's binary_logloss: 0.35561
# [1071]	valid_0's binary_logloss: 0.355591
# [1072]	valid_0's binary_logloss: 0.35558
# [1073]	valid_0's binary_logloss: 0.355523
# [1074]	valid_0's binary_logloss: 0.355508
# [1075]	valid_0's binary_logloss: 0.355483
# [1076]	valid_0's binary_logloss: 0.355438
# [1077]	valid_0's binary_logloss: 0.355421
# [1078]	valid_0's binary_logloss: 0.355408
# [1079]	valid_0's binary_logloss: 0.355373
# [1080]	valid_0's binary_logloss: 0.355344
# [1081]	valid_0's binary_logloss: 0.355315
# [1082]	valid_0's binary_logloss: 0.35526
# [1083]	valid_0's binary_logloss: 0.355256
# [1084]	valid_0's binary_logloss: 0.35521
# [1085]	valid_0's binary_logloss: 0.35519
# [1086]	valid_0's binary_logloss: 0.355148
# [1087]	valid_0's binary_logloss: 0.355109
# [1088]	valid_0's binary_logloss: 0.355068
# [1089]	valid_0's binary_logloss: 0.355045
# [1090]	valid_0's binary_logloss: 0.355006
# [1091]	valid_0's binary_logloss: 0.354992
# [1092]	valid_0's binary_logloss: 0.354988
# [1093]	valid_0's binary_logloss: 0.354974
# [1094]	valid_0's binary_logloss: 0.354925
# [1095]	valid_0's binary_logloss: 0.354909
# [1096]	valid_0's binary_logloss: 0.354889
# [1097]	valid_0's binary_logloss: 0.354885
# [1098]	valid_0's binary_logloss: 0.35487
# [1099]	valid_0's binary_logloss: 0.35486
# [1100]	valid_0's binary_logloss: 0.354839
# [1101]	valid_0's binary_logloss: 0.35482
# [1102]	valid_0's binary_logloss: 0.354793
# [1103]	valid_0's binary_logloss: 0.354773
# [1104]	valid_0's binary_logloss: 0.354745
# [1105]	valid_0's binary_logloss: 0.354735
# [1106]	valid_0's binary_logloss: 0.354661
# [1107]	valid_0's binary_logloss: 0.354637
# [1108]	valid_0's binary_logloss: 0.354616
# [1109]	valid_0's binary_logloss: 0.354592
# [1110]	valid_0's binary_logloss: 0.354536
# [1111]	valid_0's binary_logloss: 0.354522
# [1112]	valid_0's binary_logloss: 0.35449
# [1113]	valid_0's binary_logloss: 0.354456
# [1114]	valid_0's binary_logloss: 0.35443
# [1115]	valid_0's binary_logloss: 0.354409
# [1116]	valid_0's binary_logloss: 0.354398
# [1117]	valid_0's binary_logloss: 0.35437
# [1118]	valid_0's binary_logloss: 0.354342
# [1119]	valid_0's binary_logloss: 0.354315
# [1120]	valid_0's binary_logloss: 0.354273
# [1121]	valid_0's binary_logloss: 0.354258
# [1122]	valid_0's binary_logloss: 0.354241
# [1123]	valid_0's binary_logloss: 0.354226
# [1124]	valid_0's binary_logloss: 0.354214
# [1125]	valid_0's binary_logloss: 0.354179
# [1126]	valid_0's binary_logloss: 0.354116
# [1127]	valid_0's binary_logloss: 0.354098
# [1128]	valid_0's binary_logloss: 0.354078
# [1129]	valid_0's binary_logloss: 0.354066
# [1130]	valid_0's binary_logloss: 0.354038
# [1131]	valid_0's binary_logloss: 0.354022
# [1132]	valid_0's binary_logloss: 0.354012
# [1133]	valid_0's binary_logloss: 0.353993
# [1134]	valid_0's binary_logloss: 0.353983
# [1135]	valid_0's binary_logloss: 0.353968
# [1136]	valid_0's binary_logloss: 0.353949
# [1137]	valid_0's binary_logloss: 0.353924
# [1138]	valid_0's binary_logloss: 0.353915
# [1139]	valid_0's binary_logloss: 0.353897
# [1140]	valid_0's binary_logloss: 0.353878
# [1141]	valid_0's binary_logloss: 0.353865
# [1142]	valid_0's binary_logloss: 0.35384
# [1143]	valid_0's binary_logloss: 0.353821
# [1144]	valid_0's binary_logloss: 0.353807
# [1145]	valid_0's binary_logloss: 0.353789
# [1146]	valid_0's binary_logloss: 0.353769
# [1147]	valid_0's binary_logloss: 0.353719
# [1148]	valid_0's binary_logloss: 0.353688
# [1149]	valid_0's binary_logloss: 0.353672
# [1150]	valid_0's binary_logloss: 0.353647
# [1151]	valid_0's binary_logloss: 0.353635
# [1152]	valid_0's binary_logloss: 0.353628
# [1153]	valid_0's binary_logloss: 0.353609
# [1154]	valid_0's binary_logloss: 0.35355
# [1155]	valid_0's binary_logloss: 0.353529
# [1156]	valid_0's binary_logloss: 0.353509
# [1157]	valid_0's binary_logloss: 0.353489
# [1158]	valid_0's binary_logloss: 0.353468
# [1159]	valid_0's binary_logloss: 0.353448
# [1160]	valid_0's binary_logloss: 0.353384
# [1161]	valid_0's binary_logloss: 0.353358
# [1162]	valid_0's binary_logloss: 0.353341
# [1163]	valid_0's binary_logloss: 0.353313
# [1164]	valid_0's binary_logloss: 0.353291
# [1165]	valid_0's binary_logloss: 0.353276
# [1166]	valid_0's binary_logloss: 0.353236
# [1167]	valid_0's binary_logloss: 0.353207
# [1168]	valid_0's binary_logloss: 0.353178
# [1169]	valid_0's binary_logloss: 0.353146
# [1170]	valid_0's binary_logloss: 0.353108
# [1171]	valid_0's binary_logloss: 0.353101
# [1172]	valid_0's binary_logloss: 0.353082
# [1173]	valid_0's binary_logloss: 0.353033
# [1174]	valid_0's binary_logloss: 0.353009
# [1175]	valid_0's binary_logloss: 0.352982
# [1176]	valid_0's binary_logloss: 0.352976
# [1177]	valid_0's binary_logloss: 0.352928
# [1178]	valid_0's binary_logloss: 0.352913
# [1179]	valid_0's binary_logloss: 0.352872
# [1180]	valid_0's binary_logloss: 0.352855
# [1181]	valid_0's binary_logloss: 0.352806
# [1182]	valid_0's binary_logloss: 0.352803
# [1183]	valid_0's binary_logloss: 0.352757
# [1184]	valid_0's binary_logloss: 0.352728
# [1185]	valid_0's binary_logloss: 0.352707
# [1186]	valid_0's binary_logloss: 0.352666
# [1187]	valid_0's binary_logloss: 0.352609
# [1188]	valid_0's binary_logloss: 0.352598
# [1189]	valid_0's binary_logloss: 0.352571
# [1190]	valid_0's binary_logloss: 0.352517
# [1191]	valid_0's binary_logloss: 0.352514
# [1192]	valid_0's binary_logloss: 0.352493
# [1193]	valid_0's binary_logloss: 0.35248
# [1194]	valid_0's binary_logloss: 0.352422
# [1195]	valid_0's binary_logloss: 0.352407
# [1196]	valid_0's binary_logloss: 0.352375
# [1197]	valid_0's binary_logloss: 0.352344
# [1198]	valid_0's binary_logloss: 0.352315
# [1199]	valid_0's binary_logloss: 0.352273
# [1200]	valid_0's binary_logloss: 0.35225
# Did not meet early stopping. Best iteration is:
# [1200]	valid_0's binary_logloss: 0.35225

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 83.62497047158433
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV16.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV16.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado Master Otro  \
# 27801  67462  1112460307       YD6mxP  MASC  29.0         -      -    -
# 356    66829  1112460141      MV6ZzKo   FEM  30.0         -      -    -
# 21717  44649  1112426878       60Lv3j   FEM  32.0         -      -    -
# 65544  12057  1111978618       Z2b1o8   FEM  39.0         -      -    -
# 59125  57622  1112451640       eD8GXr  MASC  30.0         -      -    -
# 42471  39707  1112417808       e3bxDW   FEM  28.0         -      -    -
# 19707  79455  1112464706      mzdokNQ  MASC  22.0         -      -    -
# 19590  79122  1112464628      2zkzEvx   FEM  20.0         -      -    -
# 73448  71633  1112462848      xkdO98x   FEM  26.0         -      -    -
# 81237  28807  1112366593       5l0VRZ   FEM  40.0         -      -    -
#
#       Posgrado Secundario    ...    viajar empresa_importante capacitacion  \
# 27801        -   Graduado    ...     False               True        False
# 356          -   Graduado    ...     False              False        False
# 21717        -   Graduado    ...     False              False        False
# 65544        -   Graduado    ...     False              False         True
# 59125        -   Graduado    ...     False              False        False
# 42471        -   Graduado    ...     False               True        False
# 19707        -   Graduado    ...     False               True        False
# 19590        -   Graduado    ...     False               True        False
# 73448        -   Graduado    ...     False              False        False
# 81237        -   Graduado    ...     False              False        False
#
#       remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 27801                   False      True        True                     False
# 356                     False     False       False                     False
# 21717                   False     False        True                     False
# 65544                   False     False       False                     False
# 59125                   False     False       False                     False
# 42471                   False      True        True                     False
# 19707                   False     False       False                     False
# 19590                   False     False       False                     False
# 73448                   False     False       False                     False
# 81237                   False     False       False                     False
#
#       buen_ambiente  discriminacion  cantidad
# 27801         False           False  0.009091
# 356            True           False  0.000952
# 21717         False           False  0.000000
# 65544          True           False  0.000000
# 59125         False           False  0.000000
# 42471         False           False  0.020408
# 19707         False           False  0.099099
# 19590         False           False  0.000000
# 73448         False           False  0.000000
# 81237          True           False  0.000000
#
# [10 rows x 36 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.94238344, 0.05761656],
#        [0.89617899, 0.10382101],
#        [0.90227165, 0.09772835],
#        ...,
#        [0.99256907, 0.00743093],
#        [0.98846665, 0.01153335],
#        [0.99798068, 0.00201932]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     empresa_importante capacitacion  \
# 0   Graduado    ...                  False        False
# 1          -    ...                  False        False
# 2   Graduado    ...                  False        False
# 3   Graduado    ...                  False        False
# 4          -    ...                  False        False
#
#   remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 0                   False     False       False                     False
# 1                   False     False       False                     False
# 2                   False     False       False                     False
# 3                   False     False       False                     False
# 4                   False     False       False                     False
#
#   buen_ambiente discriminacion  cantidad  sepostulo
# 0         False          False       0.0   0.057617
# 1         False          False       0.0   0.103821
# 2         False          False       0.0   0.097728
# 3         False          False       0.0   0.009877
# 4         False          False       0.0   0.025875
#
# [5 rows x 37 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.057617
# 1   1   0.103821
# 2   2   0.097728
# 3   3   0.009877
# 4   4   0.025875

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion34.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5111304203260066
