# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/1.csv")

postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones2=pd.merge(postulaciones2,postulantes,on='idpostulante')

postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones2=pd.merge(postulaciones2,avisos,on='idaviso')

postulaciones2.head()
# Out:
#       idaviso idpostulante  sepostulo  sexo  edad Doctorado Master Otro  \
# 0  1112257047      akjmXXq          0   FEM  28.0         -      -    -
# 1  1112257047      MV6b6R9          0   FEM  30.0         -      -    -
# 2  1112257047      zvxv1Rm          0   FEM  22.0         -      -    -
# 3  1112257047       8oqJzL          0  MASC  34.0         -      -    -
# 4  1112257047       ez533B          0  MASC  32.0         -      -    -
#
#   Posgrado Secundario       ...       secundario viajar empresa_importante  \
# 0        -   Graduado       ...             True  False              False
# 1        -          -       ...             True  False              False
# 2        -   Graduado       ...             True  False              False
# 3        -          -       ...             True  False              False
# 4        -   Graduado       ...             True  False              False
#
#   capacitacion remuneracion_pretendida graduados estudiantes  \
# 0         True                   False     False       False
# 1         True                   False     False       False
# 2         True                   False     False       False
# 3         True                   False     False       False
# 4         True                   False     False       False
#
#   conocimientos_especificos  buen_ambiente  discriminacion
# 0                     False          False           False
# 1                     False          False           False
# 2                     False          False           False
# 3                     False          False           False
# 4                     False          False           False
#
# [5 rows x 35 columns]

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo sexo  edad Doctorado Master Otro  \
# 0  1112257047         NM5M          1  FEM  47.0         -      -    -
# 1  1112257047       1kJqGb          1  FEM  34.0         -      -    -
# 2  1112257047       eOE9Rr          1  FEM  39.0         -      -    -
# 3  1112257047       Zrx8Xz          1  FEM  39.0         -      -    -
# 4  1112257047       ZrKNQY          1  FEM  32.0         -      -    -
#
#   Posgrado Secundario       ...       secundario viajar empresa_importante  \
# 0        -   Graduado       ...             True  False              False
# 1        -          -       ...             True  False              False
# 2        -   Graduado       ...             True  False              False
# 3        -          -       ...             True  False              False
# 4        -   Graduado       ...             True  False              False
#
#   capacitacion remuneracion_pretendida graduados estudiantes  \
# 0         True                   False     False       False
# 1         True                   False     False       False
# 2         True                   False     False       False
# 3         True                   False     False       False
# 4         True                   False     False       False
#
#   conocimientos_especificos  buen_ambiente  discriminacion
# 0                     False          False           False
# 1                     False          False           False
# 2                     False          False           False
# 3                     False          False           False
# 4                     False          False           False
#
# [5 rows x 35 columns]

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 12377268
# 12332167

# %%
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado    Master  \
# 10729878  1112298005      EzELAZ9          0   FEM  19.0         -         -
# 1867564   1111934356      ekmlqbj          1   FEM  29.0         -         -
# 1955676   1112285529      ek4wxbo          1   FEM  19.0         -         -
# 2335273   1112253336      8MZVxpL          1  MASC  28.0         -         -
# 2293586   1112309001      kPNE41a          1   FEM  22.0         -         -
# 10581954  1112452752      3NkBmdr          0   FEM  25.0         -         -
# 9370877   1112402823       54zDMp          0   FEM  29.0         -         -
# 5057661   1112218941      wVXPeZL          1  MASC  29.0         -         -
# 10802022  1112222991       5PvpGG          0  MASC  38.0         -         -
# 8345219   1112309025      MVdXkkN          0  MASC  25.0         -         -
# 9697672   1112375075      KBrWrDq          0  MASC  19.0         -         -
# 4706207   1112223068      JBmVERb          1  MASC  31.0         -         -
# 2711384   1112428511      lDbovR2          1  MASC  27.0         -  En Curso
# 4348070   1112209253      dYj80DA          1   FEM  22.0         -         -
# 8396553   1112413164       1V9Y1B          0   FEM  25.0         -         -
# 10449780  1111793085       aPP9B9          0  MASC  30.0         -         -
# 7385015   1111455368      Drp6aR5          0  MASC  22.0         -         -
# 6664077   1112397527      qew83MR          0   FEM  32.0         -         -
# 1017200   1111753681      akjL6QW          1   FEM  27.0         -         -
# 370270    1112353834      YjAmoaX          1   FEM  28.0         -         -
#
#                 Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 10729878    Graduado         -   Graduado    ...     False               True
# 1867564     Graduado         -   Graduado    ...     False              False
# 1955676            -         -   Graduado    ...     False              False
# 2335273            -         -          -    ...     False              False
# 2293586            -         -   Graduado    ...     False              False
# 10581954    Graduado         -   Graduado    ...     False              False
# 9370877            -         -   Graduado    ...     False              False
# 5057661            -         -   Graduado    ...     False              False
# 10802022           -  Graduado   Graduado    ...     False              False
# 8345219            -         -   Graduado    ...     False              False
# 9697672            -         -   Graduado    ...     False              False
# 4706207            -         -   Graduado    ...     False              False
# 2711384            -         -   Graduado    ...     False              False
# 4348070            -         -   Graduado    ...     False              False
# 8396553            -         -          -    ...     False               True
# 10449780           -         -   Graduado    ...     False               True
# 7385015            -         -          -    ...     False              False
# 6664077            -         -   Graduado    ...     False              False
# 1017200   Abandonado         -   Graduado    ...     False              False
# 370270             -         -   Graduado    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 10729878        False                   False     False       False
# 1867564         False                   False     False        True
# 1955676         False                   False     False       False
# 2335273         False                   False     False       False
# 2293586         False                   False     False       False
# 10581954        False                   False     False       False
# 9370877         False                   False     False       False
# 5057661         False                   False     False       False
# 10802022        False                   False     False       False
# 8345219         False                   False     False       False
# 9697672         False                   False     False       False
# 4706207          True                   False     False       False
# 2711384          True                   False      True        True
# 4348070         False                   False     False       False
# 8396553          True                   False     False       False
# 10449780        False                   False     False       False
# 7385015         False                   False     False        True
# 6664077         False                   False     False       False
# 1017200         False                    True     False       False
# 370270          False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 10729878                     False          True           False       NaN
# 1867564                       True         False            True       NaN
# 1955676                      False         False           False       NaN
# 2335273                      False         False           False       NaN
# 2293586                      False          True           False       NaN
# 10581954                     False         False           False       NaN
# 9370877                      False         False           False       NaN
# 5057661                      False         False           False       NaN
# 10802022                      True         False            True       NaN
# 8345219                      False         False           False       NaN
# 9697672                      False         False           False       NaN
# 4706207                      False         False           False       NaN
# 2711384                      False          True           False       1.0
# 4348070                      False         False           False       NaN
# 8396553                      False         False           False       NaN
# 10449780                     False         False           False       NaN
# 7385015                      False         False           False       NaN
# 6664077                      False         False           False       NaN
# 1017200                      False         False           False       NaN
# 370270                       False         False           False       NaN
#
# [20 rows x 36 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 2931355   1112439246       YGpNkr          1   FEM  29.0         -      -
# 4366376   1112399864      xkve6vP          1   FEM  32.0         -      -
# 5222944   1112285761      vVjGva5          1  MASC  19.0         -      -
# 3309171   1112273328      PmGKoO0          1  MASC  23.0         -      -
# 12205117  1112444563       YAZ0w1          0  MASC  49.0         -      -
# 2176587   1112335018       5DmMrZ          1   FEM  32.0         -      -
# 2920414   1112334788      Nz01w05          1   FEM  21.0         -      -
# 1884035   1112282919       NxBNrl          1   FEM  44.0         -      -
# 6191451   1112235610      KBrVWj2          0  MASC  30.0         -      -
# 7481755   1111753928       52OpQp          0   FEM  41.0         -      -
# 5977755   1112243426      vV3VQwQ          1   FEM  31.0         -      -
# 11425162  1112414508      KBdN04A          0   FEM  30.0         -      -
# 1461930   1112386615      qe2VBrw          1   FEM  35.0         -      -
# 7148768   1112386615      dYj5Yqb          0  MASC  29.0         -      -
# 8048533   1112454235      JBeBeKJ          0  MASC  38.0         -      -
# 3489556   1112259657      ZDa9Pxb          1  MASC  23.0         -      -
# 3676493   1112444274       6z6q0l          1   FEM  31.0         -      -
# 8839298   1112428442       aGRmaW          0  MASC  36.0         -      -
# 1836394   1111796567      ZDlWBER          1  MASC  24.0         -      -
# 5274311   1112298883       a053Y5          1  MASC  33.0         -      -
#
#               Otro Posgrado Secundario    ...    viajar empresa_importante  \
# 2931355          -        -   Graduado    ...     False              False
# 4366376          -        -          -    ...     False              False
# 5222944          -        -   Graduado    ...     False              False
# 3309171          -        -   Graduado    ...     False              False
# 12205117         -        -   Graduado    ...     False              False
# 2176587   En Curso        -   Graduado    ...     False               True
# 2920414          -        -   Graduado    ...     False              False
# 1884035          -        -   Graduado    ...     False              False
# 6191451          -        -   Graduado    ...     False              False
# 7481755   Graduado        -   Graduado    ...     False              False
# 5977755          -        -          -    ...     False              False
# 11425162         -        -   Graduado    ...     False              False
# 1461930          -        -          -    ...     False              False
# 7148768   Graduado        -   Graduado    ...     False              False
# 8048533          -        -   Graduado    ...     False              False
# 3489556          -        -   Graduado    ...     False               True
# 3676493          -        -   Graduado    ...     False               True
# 8839298          -        -          -    ...     False              False
# 1836394          -        -   Graduado    ...     False              False
# 5274311          -        -          -    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 2931355         False                   False     False       False
# 4366376         False                   False     False       False
# 5222944          True                   False      True        True
# 3309171         False                   False     False       False
# 12205117        False                   False     False       False
# 2176587         False                   False     False       False
# 2920414          True                   False     False       False
# 1884035         False                   False      True        True
# 6191451         False                   False     False       False
# 7481755         False                   False     False       False
# 5977755         False                   False     False       False
# 11425162        False                   False     False       False
# 1461930         False                   False     False       False
# 7148768         False                   False     False       False
# 8048533          True                   False     False       False
# 3489556          True                   False     False       False
# 3676493         False                   False     False       False
# 8839298         False                   False     False       False
# 1836394         False                   False      True        True
# 5274311         False                   False     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 2931355                      False         False           False       0.0
# 4366376                       True         False            True       0.0
# 5222944                      False         False           False       0.0
# 3309171                       True         False            True       0.0
# 12205117                     False         False           False       0.0
# 2176587                      False         False           False       0.0
# 2920414                      False          True           False       0.0
# 1884035                      False         False           False       0.0
# 6191451                      False         False           False       0.0
# 7481755                      False         False           False       0.0
# 5977755                      False         False           False       0.0
# 11425162                     False         False           False       0.0
# 1461930                      False         False           False       0.0
# 7148768                      False         False           False       0.0
# 8048533                      False         False           False       0.0
# 3489556                      False          True           False       0.0
# 3676493                      False         False           False       1.0
# 8839298                      False         False           False       0.0
# 1836394                      False         False           False       0.0
# 5274311                      False         False           False       0.0
#
# [20 rows x 36 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.10)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
postulaciones2=0
# Out:
# Train:  11098950 Test:  1233217

# %%
import gc
gc.collect()
# Out:
# 379

# %%
c=lgb.LGBMClassifier(learning_rate=0.005,objective='binary',num_leaves=6000,max_depth=13,n_estimators=1000,colsample_bytree=0.7,n_jobs=-1,random_state=0,silent=False,subsample=0.7,sumsample_freq=1)

dt=c.fit(x_train,y_train)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# 73.12541101849878
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV4.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV4.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado    Master  \
# 80109  27594  1112352275       5GewEX   FEM  28.0         -         -
# 42052  48662  1112433770      MVOO20v   FEM  25.0         -         -
# 95750  95234  1112487995       aXGmKq  MASC  36.0         -  En Curso
# 20121  81062  1112465355      BmDBVbz  MASC  30.0         -         -
# 64722  11654  1111963981       ZBDVYz  MASC  32.0         -         -
# 81836  29683  1112373339       axG1G9  MASC  49.0         -         -
# 39443  83789  1112466410      96zMzeZ   FEM  20.0         -         -
# 67391  13477  1112040532        Y6PD1  MASC  42.0         -  Graduado
# 63678  53888  1112445541      YjlbJzr   FEM  23.0         -         -
# 24188  79205  1112464639       1PjLab   FEM  35.0         -         -
#
#            Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 80109         -         -          -    ...     False              False
# 42052  Graduado         -   Graduado    ...     False              False
# 95750         -         -   Graduado    ...     False              False
# 20121         -         -          -    ...     False              False
# 64722         -         -   Graduado    ...     False              False
# 81836         -         -   Graduado    ...     False              False
# 39443         -         -   Graduado    ...     False               True
# 67391         -  Graduado   Graduado    ...     False              False
# 63678         -         -          -    ...     False              False
# 24188         -         -          -    ...     False               True
#
#       capacitacion remuneracion_pretendida graduados estudiantes  \
# 80109        False                   False     False       False
# 42052        False                   False      True        True
# 95750        False                   False     False       False
# 20121         True                   False     False        True
# 64722        False                   False     False       False
# 81836        False                   False     False       False
# 39443        False                   False     False       False
# 67391        False                   False      True        True
# 63678        False                   False     False       False
# 24188        False                   False     False       False
#
#       conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 80109                     False         False           False       0.0
# 42052                      True         False            True       1.0
# 95750                     False         False           False       0.0
# 20121                     False         False           False       2.0
# 64722                     False         False           False       0.0
# 81836                     False         False           False       0.0
# 39443                     False         False           False       0.0
# 67391                     False          True           False       0.0
# 63678                     False         False           False       0.0
# 24188                     False         False           False       0.0
#
# [10 rows x 36 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.57340882, 0.42659118],
#        [0.60312152, 0.39687848],
#        [0.61200069, 0.38799931],
#        ...,
#        [0.87191205, 0.12808795],
#        [0.63907433, 0.36092567],
#        [0.95238621, 0.04761379]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     empresa_importante capacitacion  \
# 0   Graduado    ...                  False        False
# 1          -    ...                  False        False
# 2   Graduado    ...                  False        False
# 3   Graduado    ...                  False        False
# 4          -    ...                  False        False
#
#   remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 0                   False     False       False                     False
# 1                   False     False       False                     False
# 2                   False     False       False                     False
# 3                   False     False       False                     False
# 4                   False     False       False                     False
#
#   buen_ambiente discriminacion  cantidad  sepostulo
# 0         False          False       0.0   0.426591
# 1         False          False       0.0   0.396878
# 2         False          False       0.0   0.387999
# 3         False          False       0.0   0.231194
# 4         False          False       0.0   0.320712
#
# [5 rows x 37 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.426591
# 1   1   0.396878
# 2   2   0.387999
# 3   3   0.231194
# 4   4   0.320712

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion17.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.5987484259566261
