# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn.externals import joblib
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
import gc

# %matplotlib inline

# %%
plt.rc('figure',dpi=100);

# %%
avisos = pd.read_csv("../../Data/fiuba_entrenamiento/gian/avisos.csv")
postulaciones = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulaciones.csv")
postulantes = pd.read_csv("../../Data/fiuba_entrenamiento/gian/postulantes.csv")

postulantes['sexo']=postulantes['sexo'].astype('category')
postulantes['Doctorado']=postulantes['Doctorado'].astype('category')
postulantes['Master']=postulantes['Master'].astype('category')
postulantes['Otro']=postulantes['Otro'].astype('category')
postulantes['Posgrado']=postulantes['Posgrado'].astype('category')
postulantes['Secundario']=postulantes['Secundario'].astype('category')
postulantes['Terciario/Técnico']=postulantes['Terciario/Técnico'].astype('category')
postulantes['Universitario']=postulantes['Universitario'].astype('category')

avisos['nombre_zona']=avisos['nombre_zona'].astype('category')
avisos['tipo_de_trabajo']=avisos['tipo_de_trabajo'].astype('category')
avisos['nivel_laboral']=avisos['nivel_laboral'].astype('category')
avisos['nombre_area']=avisos['nombre_area'].astype('category')

postulaciones['sepostulo']=1
postulaciones.drop(['fechapostulacion','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)

# %%
vistas = pd.read_csv("../../Data/fiuba_entrenamiento/gian/vistas.csv")
vistas.head()
# Out:
#       idAviso                timestamp idpostulante  dia  mes  semana  \
# 0  1111780242  2018-02-23 18:38:13.187      YjVJQ6Z   23    2       8
# 1  1112263876  2018-02-23 18:38:14.296      BmVpYoR   23    2       8
# 2  1112327963  2018-02-23 18:38:14.329      wVkBzZd   23    2       8
# 3  1112318643  2018-02-23 18:38:17.921      OqmP9pv   23    2       8
# 4  1111903673  2018-02-23 18:38:18.973      DrpbXDP   23    2       8
#
#   diadelasemana  hora
# 0       Viernes    18
# 1       Viernes    18
# 2       Viernes    18
# 3       Viernes    18
# 4       Viernes    18

# %%
vistas.drop(['timestamp','dia','mes','semana','diadelasemana','hora'],axis=1,inplace=True)
vistas['cantidad']=0
vistas=vistas.groupby(['idAviso','idpostulante'],as_index=False).agg({'cantidad':'count'})
vistas=vistas.rename(columns={'idAviso': 'idaviso'})
vistas.head()
# Out:
#    idaviso idpostulante  cantidad
# 0       18        BolNL         2
# 1    48375       RwVdKR         1
# 2   169730        1KjXB         2
# 3   169730       2AKzxa         2
# 4   169730        6LJ64         1

# %%
postulaciones2= pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/3.csv")
postulaciones2=postulaciones2.append(pd.read_csv("../../Data/fiuba_entrenamiento/gian/no-postulaciones/4.csv"), ignore_index=True)
print(len(postulaciones2))
postulaciones2.head()
# Out:
# 13209068
#       idaviso idpostulante  sepostulo
# 0  1112257047      ow2xPaj          0
# 1  1111920714      LNKXqJB          0
# 2  1112346945      8MBPqYD          0
# 3  1112345547      ek4P2Wr          0
# 4  1112237522       NpqMD5          0

# %%
postulaciones.head()
# Out:
#       idaviso idpostulante  sepostulo
# 0  1112257047         NM5M          1
# 1  1111920714         NM5M          1
# 2  1112346945         NM5M          1
# 3  1112345547         NM5M          1
# 4  1112237522         5awk          1

# %%
postulaciones=postulaciones.append(postulaciones2, ignore_index=True)
print(len(postulaciones))
postulaciones2=0
gc.collect()
postulaciones.drop_duplicates(['idaviso','idpostulante'],keep='first',inplace=True)
print(len(postulaciones))
# Out:
# 19813602
# 19722959

# %%
postulaciones=pd.merge(postulaciones,postulantes,on='idpostulante')
postulaciones=pd.merge(postulaciones,avisos,on='idaviso')
postulaciones=pd.merge(postulaciones,vistas,on=['idaviso','idpostulante'],how='left')
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo        sexo   edad Doctorado  \
# 8550737   1112115684      2zwm9vQ          0        MASC   28.0         -
# 2555601   1112260365      owaA9Gk          1        MASC   19.0         -
# 774320    1112412960      akjG8mE          0        MASC   34.0         -
# 4332701   1112424481      ZDrXXD8          0         FEM   20.0         -
# 16005151  1112227446       N0w6p5          0         FEM   38.0         -
# 8015724   1112430277      6rZ8WOv          1         FEM   20.0         -
# 9530866   1112303993      Bm51vVR          0  NO_DECLARA  200.0         -
# 17376001  1112452624       eBvZ69          0        MASC   27.0         -
# 11747878  1112387712      X95xlpQ          0         FEM   26.0         -
# 2825975   1112351932      QNr5j54          1        MASC   29.0         -
# 1619301   1112339658       EdXEp6          0         FEM   41.0         -
# 8791219   1112295675      1QPxleL          0        MASC   49.0         -
# 1023821   1112204682      bOJdzDB          1         FEM   23.0         -
# 14592151  1112399046      96X348Y          0         FEM   20.0         -
# 15962500  1112289312      W9A0qpj          1         FEM   24.0         -
# 17245950  1112468883      8MB6Ko3          0        MASC   35.0         -
# 18393426  1112220810      4rlBzze          0         FEM   31.0         -
# 17926089  1112245297      Bm5kYMR          1         FEM   19.0         -
# 767817    1112286095      bOjB6x4          0         FEM   33.0         -
# 116644    1112304011      VNxM39l          0         FEM   26.0         -
#
#             Master      Otro  Posgrado Secundario    ...    viajar  \
# 8550737          -         -  En Curso   Graduado    ...     False
# 2555601          -         -         -          -    ...     False
# 774320           -         -         -   Graduado    ...     False
# 4332701          -         -         -          -    ...     False
# 16005151         -  Graduado  Graduado   Graduado    ...     False
# 8015724          -  En Curso         -          -    ...     False
# 9530866          -         -         -          -    ...     False
# 17376001  Graduado  Graduado  Graduado          -    ...     False
# 11747878         -         -         -          -    ...     False
# 2825975          -         -         -   Graduado    ...     False
# 1619301          -         -         -   Graduado    ...     False
# 8791219          -         -         -   Graduado    ...     False
# 1023821          -  Graduado         -   Graduado    ...     False
# 14592151         -         -         -   Graduado    ...     False
# 15962500         -         -         -   Graduado    ...     False
# 17245950         -         -         -   Graduado    ...     False
# 18393426         -         -         -   Graduado    ...     False
# 17926089         -         -         -   Graduado    ...     False
# 767817           -         -         -   Graduado    ...     False
# 116644           -         -         -   Graduado    ...     False
#
#          empresa_importante capacitacion remuneracion_pretendida graduados  \
# 8550737               False        False                   False     False
# 2555601                True        False                   False     False
# 774320                False        False                   False     False
# 4332701               False         True                   False     False
# 16005151              False        False                   False     False
# 8015724               False        False                   False     False
# 9530866               False        False                   False     False
# 17376001               True        False                   False     False
# 11747878               True        False                   False     False
# 2825975                True        False                   False     False
# 1619301               False        False                   False     False
# 8791219               False         True                   False     False
# 1023821               False         True                   False     False
# 14592151               True        False                   False     False
# 15962500               True        False                   False     False
# 17245950              False         True                   False     False
# 18393426              False         True                   False     False
# 17926089              False        False                   False     False
# 767817                 True         True                   False     False
# 116644                False        False                   False     False
#
#          estudiantes conocimientos_especificos buen_ambiente  discriminacion  \
# 8550737        False                     False          True           False
# 2555601        False                     False         False            True
# 774320         False                     False         False           False
# 4332701        False                     False          True           False
# 16005151       False                     False         False           False
# 8015724        False                     False         False           False
# 9530866        False                     False         False           False
# 17376001       False                     False         False           False
# 11747878       False                     False         False           False
# 2825975        False                     False         False           False
# 1619301        False                     False         False           False
# 8791219        False                     False         False           False
# 1023821        False                     False          True           False
# 14592151       False                     False          True           False
# 15962500       False                     False         False           False
# 17245950       False                     False          True           False
# 18393426       False                     False          True           False
# 17926089       False                     False          True           False
# 767817         False                     False         False           False
# 116644         False                     False         False           False
#
#           cantidad
# 8550737        NaN
# 2555601        NaN
# 774320         NaN
# 4332701        NaN
# 16005151       NaN
# 8015724        NaN
# 9530866        NaN
# 17376001       NaN
# 11747878       NaN
# 2825975        NaN
# 1619301        NaN
# 8791219        NaN
# 1023821        NaN
# 14592151       NaN
# 15962500       NaN
# 17245950       NaN
# 18393426       NaN
# 17926089       NaN
# 767817         NaN
# 116644         NaN
#
# [20 rows x 36 columns]

# %%
postulaciones.cantidad=postulaciones.cantidad.fillna(0)
postulaciones.sample(20)
# Out:
#              idaviso idpostulante  sepostulo  sexo  edad Doctorado Master  \
# 9199434   1112179527      6rZYzvL          0  MASC  36.0         -      -
# 7404489   1112467018       604GmM          0  MASC  40.0         -      -
# 10456274  1112289103      JBr9ALJ          1   FEM  20.0         -      -
# 17673340  1112261978      X9oOE9Q          0  MASC  41.0         -      -
# 16074590  1112437366       NRY9EB          1   FEM  41.0         -      -
# 833429    1112033906      DrX3LdW          0   FEM  19.0         -      -
# 7872022   1112296457       EmQMr9          0  MASC  30.0         -      -
# 14457304  1112312682      0zBv1Bv          1   FEM  28.0         -      -
# 17191305  1112266518      JBrEl3r          0   FEM  38.0         -      -
# 17524873  1112362652      96ZNkOp          0   FEM  30.0         -      -
# 1402735   1112145679      6rPaZvr          1   FEM  37.0         -      -
# 6818129   1112203317       eL9NQ8          0  MASC  30.0         -      -
# 14398095  1112297986      MVPmD0K          0  MASC  24.0         -      -
# 12856854  1112404260       5ZLAXN          0   FEM  37.0         -      -
# 3439271   1112246257      ekOrWBr          0  MASC  48.0         -      -
# 5197364   1112337991      Rz6ddGR          1   FEM  29.0         -      -
# 3427220   1112378604      Yj5xNvP          0  MASC  31.0         -      -
# 9068808   1112352022      PmavQab          1   FEM  21.0         -      -
# 9624095   1112320003      bOzD4mY          1   FEM  33.0         -      -
# 12926593  1112460309      xkdRMKP          0   FEM  18.0         -      -
#
#               Otro  Posgrado Secundario    ...    viajar empresa_importante  \
# 9199434          -         -   Graduado    ...     False              False
# 7404489          -         -   Graduado    ...     False              False
# 10456274  Graduado         -   Graduado    ...     False               True
# 17673340         -         -   Graduado    ...      True              False
# 16074590         -  Graduado          -    ...     False               True
# 833429           -         -   Graduado    ...     False              False
# 7872022          -         -          -    ...     False               True
# 14457304         -         -   Graduado    ...     False              False
# 17191305         -         -          -    ...     False              False
# 17524873         -         -   Graduado    ...     False              False
# 1402735          -         -          -    ...     False              False
# 6818129   Graduado         -   Graduado    ...     False               True
# 14398095         -         -   Graduado    ...     False               True
# 12856854         -  Graduado   Graduado    ...     False               True
# 3439271          -         -   Graduado    ...     False              False
# 5197364          -         -   Graduado    ...     False              False
# 3427220          -         -          -    ...     False              False
# 9068808          -         -   Graduado    ...     False              False
# 9624095          -         -   Graduado    ...     False              False
# 12926593         -         -          -    ...     False              False
#
#          capacitacion remuneracion_pretendida graduados estudiantes  \
# 9199434         False                   False     False       False
# 7404489          True                   False     False       False
# 10456274        False                   False     False       False
# 17673340        False                   False     False       False
# 16074590        False                   False     False       False
# 833429           True                   False     False       False
# 7872022         False                   False     False       False
# 14457304        False                   False     False       False
# 17191305        False                   False     False       False
# 17524873        False                   False     False       False
# 1402735         False                   False     False        True
# 6818129          True                   False     False       False
# 14398095        False                   False     False       False
# 12856854        False                   False     False       False
# 3439271         False                   False     False       False
# 5197364         False                   False     False       False
# 3427220         False                   False     False       False
# 9068808         False                   False     False       False
# 9624095         False                   False     False        True
# 12926593        False                    True     False       False
#
#          conocimientos_especificos buen_ambiente  discriminacion  cantidad
# 9199434                      False         False           False       0.0
# 7404489                      False         False           False       0.0
# 10456274                     False         False           False       0.0
# 17673340                     False         False           False       0.0
# 16074590                     False         False           False       1.0
# 833429                       False          True           False       0.0
# 7872022                       True         False            True       0.0
# 14457304                     False         False           False       0.0
# 17191305                     False          True           False       0.0
# 17524873                     False          True           False       0.0
# 1402735                      False          True           False       1.0
# 6818129                       True         False            True       0.0
# 14398095                     False          True           False       0.0
# 12856854                     False         False           False       0.0
# 3439271                      False         False           False       0.0
# 5197364                      False         False           False       0.0
# 3427220                      False         False           False       0.0
# 9068808                      False         False           False       0.0
# 9624095                      False         False           False       0.0
# 12926593                     False         False           False       0.0
#
# [20 rows x 36 columns]

# %%
train, test=train_test_split(postulaciones,test_size=0.10)
print("Train: ",len(train),"Test: ",len(test))
features=list(postulaciones.columns)
features.remove('idaviso')
features.remove('idpostulante')
features.remove('sepostulo')
features.remove('titulo')
features.remove('denominacion_empresa')

x_train=train[features]
y_train=train['sepostulo']

x_test=test[features]
y_test=test['sepostulo']
postulaciones=0
# Out:
# Train:  16631472 Test:  1847942

# %%
gc.collect()
# Out:
# 156

# %%
c=lgb.LGBMClassifier(learning_rate=0.005,objective='binary',num_leaves=6000,max_depth=13,n_estimators=3000,colsample_bytree=0.8,n_jobs=-1,random_state=0,silent=False,subsample=0.8,sumsample_freq=0.5)

dt=c.fit(x_train,y_train)
#c = joblib.load("../../Data/fiuba_entrenamiento/gian/modelos/....pkl")

# %%
score=c.score(x_test,y_test)*100
print(score)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# 78.6032786743307

# %%
joblib.dump(c, "../../Data/fiuba_entrenamiento/gian/modelos/LGBMV8.pkl")
# Out:
# ['../../Data/fiuba_entrenamiento/gian/modelos/LGBMV8.pkl']

# %%
prediccion = pd.read_csv("../../Data/fiuba_entrenamiento/test_final_100k.csv")
print(len(prediccion))
prediccion=pd.merge(prediccion,postulantes,on='idpostulante',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,avisos,on='idaviso',how='inner')
print(len(prediccion))
prediccion=pd.merge(prediccion,vistas,on=['idaviso','idpostulante'],how='left')
prediccion.cantidad=prediccion.cantidad.fillna(0)
prediccion.sample(10)
# Out:
# 100000
# 100000
# 100000
#           id     idaviso idpostulante  sexo  edad Doctorado    Master Otro  \
# 55412  29523  1112372181       Z2WE8z   FEM  38.0         -         -    -
# 90238  56087  1112448346       5ODK6M   FEM  56.0         -         -    -
# 12708  18374  1112213148      akjK4e5  MASC  19.0         -         -    -
# 18999  77029  1112464306      6rLNvPR  MASC  22.0         -         -    -
# 42036  48574  1112433301       YkwD8X   FEM  30.0         -         -    -
# 31834  70377  1112461769       NAQOaM   FEM  41.0         -         -    -
# 92155  91133  1112470393       5POB3X   FEM  33.0         -         -    -
# 96580  96211  1112493250       Y9L4PJ  MASC  32.0         -         -    -
# 57194   6501  1111647536        5ZaZG  MASC  43.0         -  En Curso    -
# 56143   5753  1111586823       199NBE  MASC  30.0         -         -    -
#
#       Posgrado Secundario    ...    viajar empresa_importante capacitacion  \
# 55412        -          -    ...     False              False        False
# 90238        -          -    ...     False              False         True
# 12708        -   Graduado    ...     False               True        False
# 18999        -   Graduado    ...     False               True        False
# 42036        -          -    ...     False              False        False
# 31834        -          -    ...     False              False        False
# 92155        -   Graduado    ...     False              False        False
# 96580        -   Graduado    ...     False               True        False
# 57194        -   Graduado    ...     False              False        False
# 56143        -          -    ...     False              False        False
#
#       remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 55412                   False     False       False                     False
# 90238                   False     False       False                     False
# 12708                   False     False       False                     False
# 18999                   False     False       False                     False
# 42036                   False     False       False                     False
# 31834                   False     False       False                     False
# 92155                   False      True       False                     False
# 96580                   False     False       False                     False
# 57194                   False     False       False                     False
# 56143                   False     False        True                     False
#
#       buen_ambiente  discriminacion  cantidad
# 55412         False           False       0.0
# 90238         False           False       0.0
# 12708         False           False       2.0
# 18999         False           False       0.0
# 42036         False           False       0.0
# 31834         False           False       0.0
# 92155          True           False       0.0
# 96580         False           False       0.0
# 57194         False           False       0.0
# 56143         False           False       0.0
#
# [10 rows x 36 columns]

# %%
x_final=prediccion[features]
y_final=c.predict_proba(x_final)
y_final
# Out:
# array([[0.85018134, 0.14981866],
#        [0.73992104, 0.26007896],
#        [0.74209626, 0.25790374],
#        ...,
#        [0.94863247, 0.05136753],
#        [0.80231836, 0.19768164],
#        [0.98182767, 0.01817233]])

# %%
y_final2=[]
print(c.classes_)
print(len(y_final))
for elem in y_final:
    y_final2.append(elem[1])
print(len(y_final2))
# Out:
# [0 1]
# 100000
# 100000

# %%
prediccion['sepostulo']=y_final2

# %%
prediccion.head()
# Out:
#    id  idaviso idpostulante  sexo  edad Doctorado Master      Otro  Posgrado  \
# 0   0   739260       6M9ZQR   FEM  42.0  Graduado      -         -         -
# 1   1   739260       6v1xdL  MASC  30.0         -      -  Graduado         -
# 2   2   739260       ezRKm9   FEM  36.0         -      -         -         -
# 3   3   758580       1Q35ej  MASC  68.0         -      -         -  Graduado
# 4   4   758580       EAN4J6   FEM  32.0         -      -         -         -
#
#   Secundario    ...     empresa_importante capacitacion  \
# 0   Graduado    ...                  False        False
# 1          -    ...                  False        False
# 2   Graduado    ...                  False        False
# 3   Graduado    ...                  False        False
# 4          -    ...                  False        False
#
#   remuneracion_pretendida graduados estudiantes conocimientos_especificos  \
# 0                   False     False       False                     False
# 1                   False     False       False                     False
# 2                   False     False       False                     False
# 3                   False     False       False                     False
# 4                   False     False       False                     False
#
#   buen_ambiente discriminacion  cantidad  sepostulo
# 0         False          False       0.0   0.149819
# 1         False          False       0.0   0.260079
# 2         False          False       0.0   0.257904
# 3         False          False       0.0   0.057610
# 4         False          False       0.0   0.196804
#
# [5 rows x 37 columns]

# %%
prediccion.drop(features,axis=1,inplace=True)
prediccion.drop(['idaviso','idpostulante','titulo','denominacion_empresa'],axis=1,inplace=True)
prediccion.head()
# Out:
#    id  sepostulo
# 0   0   0.149819
# 1   1   0.260079
# 2   2   0.257904
# 3   3   0.057610
# 4   4   0.196804

# %%
prediccion.to_csv("../../Data/fiuba_entrenamiento/gian/predicciones/prediccion22.csv",index=False)

# %%
prediccion.sepostulo.mean()
# Out:
# 0.49580879962828034
