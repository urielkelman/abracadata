# %%
# importacion general de librerias y de visualizacion (matplotlib y seaborn)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib
#plt.rcParams['figure.figsize'] = (20, 10)

sns.set(style="whitegrid") # seteando tipo de grid en seaborn

# %%
plt.rc('figure',dpi=100);

# %%
postulaciones = pd.read_csv("../Data/datos_navent_fiuba/fiuba_4_postulaciones.csv");
postulaciones.head()
# Out:
#       idaviso idpostulante     fechapostulacion
# 0  1112257047         NM5M  2018-01-15 16:22:34
# 1  1111920714         NM5M  2018-02-06 09:04:50
# 2  1112346945         NM5M  2018-02-22 09:04:47
# 3  1112345547         NM5M  2018-02-22 09:04:59
# 4  1112237522         5awk  2018-01-25 18:55:03

# %%
avisos = pd.read_csv("../Data/datos_navent_fiuba/fiuba_6_avisos_detalle.csv");
avisos.head()
# Out:
#       idaviso  idpais                                         titulo  \
# 0     8725750       1               VENDEDOR/A PROVINCIA DE SANTA FE
# 1    17903700       1                                     Enfermeras
# 2  1000150677       1                                 Chofer de taxi
# 3  1000610287       1  CHOFER DE CAMIONETA BAHIA BLANCA - PUNTA ALTA
# 4  1000872556       1  Operarios de Planta - Rubro Electrodomésticos
#
#                                          descripcion        nombre_zona  \
# 0  <p><strong><strong>Empresa:</strong></strong> ...  Gran Buenos Aires
# 1  <p>Solicitamos para importante cadena de farma...  Gran Buenos Aires
# 2  <p>TE GUSTA MANEJAR? QUERES GANAR PLATA HACIEN...    Capital Federal
# 3  <p><strong>Somos una empresa multinacional que...  Gran Buenos Aires
# 4  <p><strong>OPERARIOS DE PLANTA</strong></p><p>...  Gran Buenos Aires
#
#   ciudad       mapacalle tipo_de_trabajo         nivel_laboral nombre_area  \
# 0    NaN             NaN       Full-time  Senior / Semi-Senior   Comercial
# 1    NaN             NaN       Full-time  Senior / Semi-Senior       Salud
# 2    NaN  Empedrado 2336       Full-time  Senior / Semi-Senior  Transporte
# 3    NaN             NaN       Full-time  Senior / Semi-Senior  Transporte
# 4    NaN             NaN       Full-time  Senior / Semi-Senior  Producción
#
#       denominacion_empresa
# 0                   VENTOR
# 1  Farmacias Central Oeste
# 2              FAMITAX SRL
# 3      Wurth Argentina S.A
# 4       ELECTRO OUTLET SRL

# %%
avisos.drop(['descripcion','nombre_zona','ciudad','mapacalle','titulo','denominacion_empresa'],axis=1,inplace=True);
avisos.head()
# Out:
#       idaviso  idpais tipo_de_trabajo         nivel_laboral nombre_area
# 0     8725750       1       Full-time  Senior / Semi-Senior   Comercial
# 1    17903700       1       Full-time  Senior / Semi-Senior       Salud
# 2  1000150677       1       Full-time  Senior / Semi-Senior  Transporte
# 3  1000610287       1       Full-time  Senior / Semi-Senior  Transporte
# 4  1000872556       1       Full-time  Senior / Semi-Senior  Producción

# %%
postulaciones_con_aviso=pd.merge(postulaciones, avisos, on='idaviso',how='inner');
postulaciones_con_aviso.head()
# Out:
#       idaviso idpostulante     fechapostulacion  idpais tipo_de_trabajo  \
# 0  1112257047         NM5M  2018-01-15 16:22:34       1       Part-time
# 1  1112257047       1kJqGb  2018-01-15 10:23:11       1       Part-time
# 2  1112257047       eOE9Rr  2018-01-15 10:42:07       1       Part-time
# 3  1112257047       Zrx8Xz  2018-01-30 10:18:14       1       Part-time
# 4  1112257047       ZrKNQY  2018-01-16 17:19:38       1       Part-time
#
#   nivel_laboral          nombre_area
# 0          Otro  Atención al Cliente
# 1          Otro  Atención al Cliente
# 2          Otro  Atención al Cliente
# 3          Otro  Atención al Cliente
# 4          Otro  Atención al Cliente

# %%
postulantes_genero_y_edad=pd.read_csv("../Data/datos_navent_fiuba/fiuba_2_postulantes_genero_y_edad.csv");
postulaciones_completas=pd.merge(postulaciones_con_aviso, postulantes_genero_y_edad, on='idpostulante',how='inner');
postulaciones_completas.head()
# Out:
#       idaviso idpostulante     fechapostulacion  idpais tipo_de_trabajo  \
# 0  1112257047         NM5M  2018-01-15 16:22:34       1       Part-time
# 1  1111920714         NM5M  2018-02-06 09:04:50       1       Part-time
# 2  1112346945         NM5M  2018-02-22 09:04:47       1       Full-time
# 3  1112345547         NM5M  2018-02-22 09:04:59       1       Full-time
# 4  1112257047       1kJqGb  2018-01-15 10:23:11       1       Part-time
#
#           nivel_laboral          nombre_area fechanacimiento sexo
# 0                  Otro  Atención al Cliente      1970-12-03  FEM
# 1  Senior / Semi-Senior        Telemarketing      1970-12-03  FEM
# 2  Senior / Semi-Senior        Telemarketing      1970-12-03  FEM
# 3  Senior / Semi-Senior        Telemarketing      1970-12-03  FEM
# 4                  Otro  Atención al Cliente      1984-04-21  FEM

# %%
postulaciones_completas['fechanacimiento']=pd.to_datetime(postulaciones_completas['fechanacimiento'], errors = 'coerce')
postulaciones_completas['fechapostulacion']=postulaciones_completas['fechapostulacion'].astype('datetime64[ns]');
postulaciones_completas.dtypes
# Out:
# idaviso                      int64
# idpostulante                object
# fechapostulacion    datetime64[ns]
# idpais                       int64
# tipo_de_trabajo             object
# nivel_laboral               object
# nombre_area                 object
# fechanacimiento     datetime64[ns]
# sexo                        object
# dtype: object

# %%
postulaciones_completas['edad']=postulaciones_completas['fechapostulacion']-postulaciones_completas['fechanacimiento'];
postulaciones_completas['edad']=pd.TimedeltaIndex(postulaciones_completas['edad']).days;
postulaciones_completas['edad']=np.floor(postulaciones_completas['edad']/365);
postulaciones_completas.head()
# Out:
#       idaviso idpostulante    fechapostulacion  idpais tipo_de_trabajo  \
# 0  1112257047         NM5M 2018-01-15 16:22:34       1       Part-time
# 1  1111920714         NM5M 2018-02-06 09:04:50       1       Part-time
# 2  1112346945         NM5M 2018-02-22 09:04:47       1       Full-time
# 3  1112345547         NM5M 2018-02-22 09:04:59       1       Full-time
# 4  1112257047       1kJqGb 2018-01-15 10:23:11       1       Part-time
#
#           nivel_laboral          nombre_area fechanacimiento sexo  edad
# 0                  Otro  Atención al Cliente      1970-12-03  FEM  47.0
# 1  Senior / Semi-Senior        Telemarketing      1970-12-03  FEM  47.0
# 2  Senior / Semi-Senior        Telemarketing      1970-12-03  FEM  47.0
# 3  Senior / Semi-Senior        Telemarketing      1970-12-03  FEM  47.0
# 4                  Otro  Atención al Cliente      1984-04-21  FEM  33.0

# %%
postulaciones_completas.dtypes
# Out:
# idaviso                      int64
# idpostulante                object
# fechapostulacion    datetime64[ns]
# idpais                       int64
# tipo_de_trabajo             object
# nivel_laboral               object
# nombre_area                 object
# fechanacimiento     datetime64[ns]
# sexo                        object
# edad                       float64
# dtype: object

# %%
#18-24,25-34,35-49,50-65
def rango_etario(x):
    if(x>=18 and x<=24):
        return '18-24'
    elif(x>=25 and x<=34):
        return '25-34'
    elif(x>=35 and x<=49):
        return '35-49'
    elif(x>=50 and x<=65):
        return '50-65'
    else:
        return 'error'
postulaciones_completas['18-24']=( (postulaciones_completas['edad']>=18) & (postulaciones_completas['edad']<=24) );
postulaciones_completas['25-34']=( (postulaciones_completas['edad']>=25) & (postulaciones_completas['edad']<=34) );
postulaciones_completas['35-49']=( (postulaciones_completas['edad']>=35) & (postulaciones_completas['edad']<=49) );
postulaciones_completas['50-65']=( (postulaciones_completas['edad']>=50) & (postulaciones_completas['edad']<=65) );
postulaciones_completas['rango']=postulaciones_completas['edad'].apply(lambda x:rango_etario(x))
postulaciones_completas['edad']=postulaciones_completas['edad'].fillna(0).astype(int);
postulaciones_completas['edad_string']=postulaciones_completas['edad'].apply(lambda x: str(x));
postulaciones_completas.head()
# Out:
#       idaviso idpostulante    fechapostulacion  idpais tipo_de_trabajo  \
# 0  1112257047         NM5M 2018-01-15 16:22:34       1       Part-time
# 1  1111920714         NM5M 2018-02-06 09:04:50       1       Part-time
# 2  1112346945         NM5M 2018-02-22 09:04:47       1       Full-time
# 3  1112345547         NM5M 2018-02-22 09:04:59       1       Full-time
# 4  1112257047       1kJqGb 2018-01-15 10:23:11       1       Part-time
#
#           nivel_laboral          nombre_area fechanacimiento sexo  edad  \
# 0                  Otro  Atención al Cliente      1970-12-03  FEM    47
# 1  Senior / Semi-Senior        Telemarketing      1970-12-03  FEM    47
# 2  Senior / Semi-Senior        Telemarketing      1970-12-03  FEM    47
# 3  Senior / Semi-Senior        Telemarketing      1970-12-03  FEM    47
# 4                  Otro  Atención al Cliente      1984-04-21  FEM    33
#
#    18-24  25-34  35-49  50-65  rango edad_string
# 0  False  False   True  False  35-49          47
# 1  False  False   True  False  35-49          47
# 2  False  False   True  False  35-49          47
# 3  False  False   True  False  35-49          47
# 4  False   True  False  False  25-34          33

# %%
areas_por_edad=postulaciones_completas.groupby('nombre_area', as_index=False).agg({'edad':'mean', 'idpostulante':'count'});
promedio_edad=postulaciones_completas['edad'].mean()
areas_por_edad['distancia_del_promedio']=np.abs(promedio_edad-areas_por_edad['edad']);
areas_por_edad.sort_values(by='distancia_del_promedio',ascending=False,inplace=True);
areas_por_edad.head()
# Out:
#                       nombre_area       edad  idpostulante  \
# 158                     Urbanismo  38.333333            12
# 46              Dirección de Obra  35.284053          3010
# 70   Gerencia / Dirección General  35.153573          6186
# 113                   Operaciones  34.715455           977
# 107                Medio Ambiente  34.115468           459
#
#      distancia_del_promedio
# 158               10.094398
# 46                 7.045118
# 70                 6.914637
# 113                6.476520
# 107                5.876533

# %%
#filtramos areas con mas de 500 postulaciones.
areas_por_edad = areas_por_edad[areas_por_edad['idpostulante'] > 500]
areas_por_edad.rename(columns={'idpostulante':'cantidad_postulantes'}, inplace=True)
areas_por_edad.head(20)
# Out:
#                              nombre_area       edad  cantidad_postulantes  \
# 46                     Dirección de Obra  35.284053                  3010
# 70          Gerencia / Dirección General  35.153573                  6186
# 113                          Operaciones  34.715455                   977
# 100                Liderazgo de Proyecto  33.449829                  3219
# 83            Ingeniería Electromecánica  33.241509                  2385
# 109                 Mineria/Petroleo/Gas  33.019956                  4109
# 82                      Ingeniería Civil  32.884871                  4369
# 23                          Capacitación  32.597630                  4389
# 118                   Pasantía / Trainee  23.903390                  6666
# 137                 Seguridad Industrial  32.545241                   851
# 121    Planeamiento económico-financiero  32.537792                  4022
# 33                          Construcción  32.506442                  9158
# 77   Ingeniería  Eléctrica y Electrónica  32.145760                  5413
# 28                               Compras  32.096610                 23921
# 126                        Promotoras/es  24.404050                  1037
# 139                  Seguridad e Higiene  31.543299                  4850
# 106                             Medicina  31.522840                  6830
# 101                            Logística  31.456905                 37139
# 38   Corporate Finance / Banca Inversión  31.447359                  2707
# 22                             Camareros  25.033440                 27482
#
#      distancia_del_promedio
# 46                 7.045118
# 70                 6.914637
# 113                6.476520
# 100                5.210894
# 83                 5.002574
# 109                4.781021
# 82                 4.645935
# 23                 4.358695
# 118                4.335545
# 137                4.306305
# 121                4.298857
# 33                 4.267507
# 77                 3.906825
# 28                 3.857674
# 126                3.834885
# 139                3.304363
# 106                3.283905
# 101                3.217970
# 38                 3.208423
# 22                 3.205495

# %%
post_filtrada_desiguales=postulaciones_completas[postulaciones_completas['nombre_area'].isin(areas_por_edad.iloc[:20].nombre_area.values)];
post_filtrada_desiguales.head()
# Out:
#         idaviso idpostulante    fechapostulacion  idpais tipo_de_trabajo  \
# 127  1112293594       Zrx8Xz 2018-01-27 16:58:35       1       Full-time
# 140  1112263387       Zrx8Xz 2018-01-17 14:33:25       1       Full-time
# 157  1112300688       Zrx8Xz 2018-02-20 17:40:22       1       Full-time
# 328  1112267830       NEvxD4 2018-01-18 18:16:50       1       Full-time
# 346  1112088913       NEvxD4 2018-01-18 21:05:36       1       Full-time
#
#             nivel_laboral            nombre_area fechanacimiento sexo  edad  \
# 127  Senior / Semi-Senior                Compras      1978-07-28  FEM    39
# 140                Junior              Logística      1978-07-28  FEM    39
# 157  Senior / Semi-Senior  Liderazgo de Proyecto      1978-07-28  FEM    39
# 328  Senior / Semi-Senior              Logística      1986-07-14  FEM    31
# 346  Senior / Semi-Senior              Logística      1986-07-14  FEM    31
#
#      18-24  25-34  35-49  50-65  rango edad_string
# 127  False  False   True  False  35-49          39
# 140  False  False   True  False  35-49          39
# 157  False  False   True  False  35-49          39
# 328  False   True  False  False  25-34          31
# 346  False   True  False  False  25-34          31

# %%
tabla = post_filtrada_desiguales.pivot_table(index='nombre_area', columns='edad_string', values='edad', aggfunc='count')
tabla.drop(['0','12','17','73','75','78'],axis=1,inplace=True);
tabla.head()
# Out:
# edad_string                              18      19      20      21      22  \
# nombre_area
# Camareros                            1250.0  1710.0  2081.0  2340.0  2504.0
# Capacitación                           18.0    15.0    46.0    69.0    74.0
# Compras                               112.0   212.0   318.0   476.0   650.0
# Construcción                           21.0    54.0    99.0   175.0   159.0
# Corporate Finance / Banca Inversión     1.0    22.0    24.0    63.0    88.0
#
# edad_string                              23      24      25      26      27  \
# nombre_area
# Camareros                            2367.0  1928.0  1790.0  1546.0  1457.0
# Capacitación                          166.0   178.0   214.0   218.0   269.0
# Compras                               957.0   940.0  1104.0  1432.0  1421.0
# Construcción                          296.0   425.0   559.0   698.0   611.0
# Corporate Finance / Banca Inversión   107.0   148.0   156.0   201.0   183.0
#
# edad_string                         ...    62    63    64   65   66   67   68  \
# nombre_area                         ...
# Camareros                           ...   NaN   3.0   NaN  NaN  NaN  1.0  NaN
# Capacitación                        ...   5.0   2.0   6.0  1.0  1.0  1.0  NaN
# Compras                             ...   3.0  22.0  10.0  1.0  1.0  NaN  NaN
# Construcción                        ...  36.0  12.0   8.0  2.0  4.0  6.0  9.0
# Corporate Finance / Banca Inversión ...   2.0   1.0   1.0  2.0  NaN  1.0  NaN
#
# edad_string                          69    70  71
# nombre_area
# Camareros                           NaN   NaN NaN
# Capacitación                        NaN   NaN NaN
# Compras                             NaN   NaN NaN
# Construcción                        NaN  11.0 NaN
# Corporate Finance / Banca Inversión NaN   NaN NaN
#
# [5 rows x 54 columns]

# %%
#Aplico logaritmo
tabla.fillna(0,inplace=True);
tabla=tabla.applymap(lambda x: 0 if x==0 else np.log(x));
tabla.head()
# Out:
# edad_string                                18        19        20        21  \
# nombre_area
# Camareros                            7.130899  7.444249  7.640604  7.757906
# Capacitación                         2.890372  2.708050  3.828641  4.234107
# Compras                              4.718499  5.356586  5.762051  6.165418
# Construcción                         3.044522  3.988984  4.595120  5.164786
# Corporate Finance / Banca Inversión  0.000000  3.091042  3.178054  4.143135
#
# edad_string                                22        23        24        25  \
# nombre_area
# Camareros                            7.825645  7.769379  7.564238  7.489971
# Capacitación                         4.304065  5.111988  5.181784  5.365976
# Compras                              6.476972  6.863803  6.845880  7.006695
# Construcción                         5.068904  5.690359  6.052089  6.326149
# Corporate Finance / Banca Inversión  4.477337  4.672829  4.997212  5.049856
#
# edad_string                                26        27 ...         62  \
# nombre_area                                             ...
# Camareros                            7.343426  7.284135 ...   0.000000
# Capacitación                         5.384495  5.594711 ...   1.609438
# Compras                              7.266827  7.259116 ...   1.098612
# Construcción                         6.548219  6.415097 ...   3.583519
# Corporate Finance / Banca Inversión  5.303305  5.209486 ...   0.693147
#
# edad_string                                63        64        65        66  \
# nombre_area
# Camareros                            1.098612  0.000000  0.000000  0.000000
# Capacitación                         0.693147  1.791759  0.000000  0.000000
# Compras                              3.091042  2.302585  0.000000  0.000000
# Construcción                         2.484907  2.079442  0.693147  1.386294
# Corporate Finance / Banca Inversión  0.000000  0.000000  0.693147  0.000000
#
# edad_string                                67        68   69        70   71
# nombre_area
# Camareros                            0.000000  0.000000  0.0  0.000000  0.0
# Capacitación                         0.000000  0.000000  0.0  0.000000  0.0
# Compras                              0.000000  0.000000  0.0  0.000000  0.0
# Construcción                         1.791759  2.197225  0.0  2.397895  0.0
# Corporate Finance / Banca Inversión  0.000000  0.000000  0.0  0.000000  0.0
#
# [5 rows x 54 columns]

# %%
g = sns.heatmap(tabla,  cmap="Blues")
g.set_title("Postulaciones por Edad en las 20 áreas \nmás separadas del promedio de edad", fontsize=18)
g.set_yticklabels(g.get_yticklabels(), fontsize=10, weight='bold')
g.set_xlabel("Edad",fontsize=18)
g.set_ylabel("", fontsize=18)
# Out:
# Text(52.316,0.5,'')

# %%
tabla2 = post_filtrada_desiguales.pivot_table(index='nombre_area', columns='rango', values='edad', aggfunc='count')
tabla2.drop('error',axis=1,inplace=True);
tabla2.fillna(0,inplace=True);
tabla2=tabla2.applymap(lambda x: 0 if x==0 else np.log(x));
g = sns.heatmap(tabla2,  cmap="Blues")
g.set_yticklabels(g.get_yticklabels(), fontsize=10, weight='bold')
g.set_title("Postulaciones por Rango Etario en las 20 áreas \nmás separadas del promedio de edad", fontsize=18)
g.set_xlabel("Rango etario",fontsize=18)
g.set_ylabel("", fontsize=18)
# Out:
# Text(52.316,0.5,'')

# %%
post_filtrada_no_desiguales=postulaciones_completas[~postulaciones_completas['nombre_area'].isin(areas_por_edad.iloc[:20].nombre_area.values)];
tabla3 = post_filtrada_no_desiguales.pivot_table(index='nombre_area', columns='rango', values='edad', aggfunc='count')
tabla3.drop('error',axis=1,inplace=True);
tabla3.fillna(0,inplace=True);
tabla3 = tabla3.applymap(lambda x: 0 if x==0 else np.log(x));

tabla3 = tabla3.iloc[:20];
g = sns.heatmap(tabla3,  cmap="Blues")
g.set_yticklabels(g.get_yticklabels(), fontsize=10, weight='bold')
g.set_title("Postulaciones por Rango Etario en 20 áreas", fontsize=18)
g.set_xlabel("Rango etario",fontsize=18)
g.set_ylabel("", fontsize=18)
# Out:
# Text(52.316,0.5,'')

# %%
tabla4 = post_filtrada_no_desiguales.pivot_table(index='nombre_area', columns='edad_string', values='edad', aggfunc='count');
tabla4.drop(['0','12','17','73','75','100','96','242'],axis=1,inplace=True);
# Out:
# edad_string                          18      19      20       21       22  \
# nombre_area
# Abastecimiento                    215.0   396.0   580.0    661.0    686.0
# Administracion de Seguros          38.0    79.0   124.0    211.0    207.0
# Administración                   2440.0  5863.0  9184.0  13947.0  15751.0
# Administración de Base de Datos     5.0     9.0    17.0     20.0     19.0
# Administración de Personal        358.0   701.0  1140.0   1777.0   2031.0
#
# edad_string                           23       24       25       26       27  \
# nombre_area
# Abastecimiento                     771.0    668.0    735.0    722.0    700.0
# Administracion de Seguros          289.0    269.0    314.0    314.0    297.0
# Administración                   19963.0  21165.0  20679.0  20193.0  20477.0
# Administración de Base de Datos     18.0     32.0     45.0     34.0     51.0
# Administración de Personal        2436.0   2738.0   2480.0   2498.0   2623.0
#
# edad_string                     ...     64   65    66   67   68  69  70  71  \
# nombre_area                     ...
# Abastecimiento                  ...    2.0  NaN   NaN  NaN  NaN NaN NaN NaN
# Administracion de Seguros       ...    NaN  NaN   NaN  1.0  NaN NaN NaN NaN
# Administración                  ...   32.0  3.0  17.0  6.0  3.0 NaN NaN NaN
# Administración de Base de Datos ...    NaN  NaN   NaN  NaN  NaN NaN NaN NaN
# Administración de Personal      ...   19.0  3.0   2.0  NaN  NaN NaN NaN NaN
#
# edad_string                      74   76
# nombre_area
# Abastecimiento                  NaN  NaN
# Administracion de Seguros       NaN  NaN
# Administración                  NaN  1.0
# Administración de Base de Datos NaN  2.0
# Administración de Personal      NaN  NaN
#
# [5 rows x 56 columns]

# %%
tabla4.fillna(0,inplace=True);
tabla4=tabla4.applymap(lambda x: 0 if x==0 else np.log(x));
tabla4 = tabla4.iloc[:20];

g = sns.heatmap(tabla4,  cmap="Blues")
g.set_title("Postulaciones por Edad en 20 areas", fontsize=18)
g.set_yticklabels(g.get_yticklabels(), fontsize=10, weight='bold')
g.set_xlabel("Edad",fontsize=18)
g.set_ylabel("", fontsize=18)
# Out:
# Text(52.316,0.5,'')

# %%
area_por_edad_nuevo=areas_por_edad.iloc[:20];
area_por_edad_nuevo.loc[-1]=['Promedio de todas las Postulaciones',promedio_edad,0,0];
area_por_edad_nuevo.sort_values('edad', ascending=False, inplace=True);
area_por_edad_nuevo
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                               nombre_area       edad  cantidad_postulantes  \
#  46                     Dirección de Obra  35.284053                  3010
#  70          Gerencia / Dirección General  35.153573                  6186
#  113                          Operaciones  34.715455                   977
#  100                Liderazgo de Proyecto  33.449829                  3219
#  83            Ingeniería Electromecánica  33.241509                  2385
#  109                 Mineria/Petroleo/Gas  33.019956                  4109
#  82                      Ingeniería Civil  32.884871                  4369
#  23                          Capacitación  32.597630                  4389
#  137                 Seguridad Industrial  32.545241                   851
#  121    Planeamiento económico-financiero  32.537792                  4022
#  33                          Construcción  32.506442                  9158
#  77   Ingeniería  Eléctrica y Electrónica  32.145760                  5413
#  28                               Compras  32.096610                 23921
#  139                  Seguridad e Higiene  31.543299                  4850
#  106                             Medicina  31.522840                  6830
#  101                            Logística  31.456905                 37139
#  38   Corporate Finance / Banca Inversión  31.447359                  2707
# -1    Promedio de todas las Postulaciones  28.238936                     0
#  22                             Camareros  25.033440                 27482
#  126                        Promotoras/es  24.404050                  1037
#  118                   Pasantía / Trainee  23.903390                  6666
#
#       distancia_del_promedio
#  46                 7.045118
#  70                 6.914637
#  113                6.476520
#  100                5.210894
#  83                 5.002574
#  109                4.781021
#  82                 4.645935
#  23                 4.358695
#  137                4.306305
#  121                4.298857
#  33                 4.267507
#  77                 3.906825
#  28                 3.857674
#  139                3.304363
#  106                3.283905
#  101                3.217970
#  38                 3.208423
# -1                  0.000000
#  22                 3.205495
#  126                3.834885
#  118                4.335545

# %%
colores=['darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','darkblue','red']
g = sns.barplot(x="nombre_area",y="edad",data=area_por_edad_nuevo, orient='v', palette=colores)
g.set_title("Promedio de edad de las 20 áreas más distintas \nal promedio de edad de todas las Postulaciones", fontsize=18)
g.set_xticklabels(g.get_xticklabels(), rotation=90, fontsize=12, weight='bold')
g.set_xlabel("",fontsize=18)
g.set_ylabel("Edad", fontsize=18)
# Out:
# Text(0,0.5,'Edad')
